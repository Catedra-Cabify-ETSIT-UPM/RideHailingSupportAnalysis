# %%
import numpy as np
import matplotlib.pyplot as plt

import joblib

import random
from deap import base
from deap import creator
from deap import tools

from deap import algorithms
from time import time
import multiprocessing

import array
import random
import json

import os

import pandas as pd

# %%
matrix_np = joblib.load('matrix_np.pkl')

# %%
#reduced_matrix_np = joblib.load('reduced_matrix_np.pkl')

# %% [markdown]
# # Functions

# %% [markdown]
# ## Modify parameters

# %%
matrix_algorithm = matrix_np
NUM_CLUSTERS = 7

# %% [markdown]
# # Distance to cluster function

# %%
def auxiliarFunction(documents, dimensions, number_topics):

    counter_docs = [0 for x in range(0,number_topics)]
    
    distance_to_cluster_2 = [0 for x in range(0,number_topics)] # distances to cluster
    
    for document in documents: 
        distance_to_cluster = []   
        counter = 0
        for dim in range(0,number_topics): 
            distance_to_cluster.append(np.linalg.norm(document-dimensions[counter:counter+7]))
            counter = counter + 7
            
        best_distance_index = distance_to_cluster.index(min(distance_to_cluster)) 
        
        counter_docs[best_distance_index] += 1
    
        distance_to_cluster_2[best_distance_index] += pow(distance_to_cluster[best_distance_index], 2)
        
     
    return counter_docs, distance_to_cluster_2

# %% [markdown]
# ## Objetive Function 2

# %%
def fobjQuadraticError(k):

    num_topics = int((len(k))/7)
    
    # 1º Number of documents to each cluster
    counter_documents, euclidean_dist_2 = auxiliarFunction(documents = matrix_algorithm, dimensions= k, number_topics = num_topics)
    
    bool_check = 0 in counter_documents    

   # 2º Fitness fuction
    if(bool_check):
        total_value = 5 # We give a high value to those clusters who do not have documents
        
    else:
        value1 = 0
        for i in range(0,num_topics): #para cada uno de los clusters
            value2 = euclidean_dist_2[i] 
            value1 += ((1/counter_documents[i])*value2)

        total_value = (value1 / num_topics) 

    return (total_value),

# %% [markdown]
# # Genetic Algorithm

# %% [markdown]
# ## Folders

# %%
path = "./results/fobjQuadraticError"
try:
    if not os.path.isdir(path):
        os.makedirs(path)
except OSError:
    print ("Creation of the directory %s failed" % path)
else:
    print ("Successfully created the directory %s " % path)
# Out:
# Successfully created the directory ./results/fobjQuadraticError

# %% [markdown]
# ## Save results

# %%
if __name__ == "__main__":
    
    CLUSTER_DIM = 7 * NUM_CLUSTERS

    creator.create("FitnessMin", base.Fitness, weights=(-1.0,))
    creator.create("Individual", list, fitness=creator.FitnessMin)

    toolbox = base.Toolbox()

    toolbox.register("attr_flt", random.uniform, 0, 1)
    toolbox.register("individual", tools.initRepeat, creator.Individual, toolbox.attr_flt,n=CLUSTER_DIM)

    toolbox.register("population", tools.initRepeat, list, toolbox.individual)


    def customMutate(ind, indpb):
        for i in range(len(ind)):
            if random.random() < indpb:
                ind[i] = random.random()
        return ind


    def evalfobj(individual):
        return fobjQuadraticError(individual)

    def evalfobjInertia(individual):
        return fobjInertia(individual) 


    toolbox.register("mate", tools.cxTwoPoint)
    toolbox.register("mutate", customMutate, indpb = 0.05)

    toolbox.register("select", tools.selTournament, tournsize=30)
    
    toolbox.register("evaluate", evalfobj)
    
    pool = multiprocessing.Pool(processes = 4)
    toolbox.register('map', pool.map)
    
    numberInd = 150
    
    # MAIN GENETIC ALGORITHM
    random.seed(169)
    min_iterations = []
    max_iterations = []
    avg_iterations = []
    std_iterations = []
    ind_iterations = []
    
    CXPB, MUTPB = 0.8, 0.2
    
    pop = toolbox.population(n=numberInd)
    fitnesses = list(toolbox.map(toolbox.evaluate, pop))
    for ind, fit in zip(pop, fitnesses):
        ind.fitness.values = fit 
        
    fits = [ind.fitness.values[0] for ind in pop] 
    
    t = 0
    g = 0
    # Begin the evolution
    while g < 4000:
 
        start_time = time()
    
        # A new generation
        g = g + 1
        print("-- Generation %i --" % g)

        offspring = toolbox.select(pop, len(pop))

        offspring = list(map(toolbox.clone, offspring))

        for child1, child2 in zip(offspring[::2], offspring[1::2]): #DE los padres, creas 2 hijos con mate
            if random.random() < CXPB:
                toolbox.mate(child1, child2)
                del child1.fitness.values 
                del child2.fitness.values 
                
        for mutant in offspring:
            if random.random() < MUTPB:
                toolbox.mutate(mutant)
                del mutant.fitness.values  

        invalid_ind = [ind for ind in offspring if not ind.fitness.valid]
        fitnesses = toolbox.map(toolbox.evaluate, invalid_ind)
            
        for ind, fit in zip(invalid_ind, fitnesses):
            ind.fitness.values = fit
                        
        fit_maxi = 100000000000000000000
        individ = []
        for ind in pop:
            if (ind.fitness.values[0]<fit_maxi):
                fit_maxi = ind.fitness.values[0]
                individ = ind

        pop[:] = offspring

        
        fits = [ind.fitness.values[0] for ind in pop]
            
        length = len(pop)
        mean = sum(fits) / length
        sum2 = sum(x*x for x in fits)
        std = abs(sum2 / length - mean**2)**0.5
        print("  Min %s" % min(fits))
  
        
        min_iterations.append(min(fits))
        max_iterations.append(max(fits))
        avg_iterations.append(mean)
        std_iterations.append(std)
        ind_iterations.append(individ)
        
        if (g % 200 == 0):
            path = "./results/fobjQuadraticError/iteration{}".format(g)
            try:
                if not os.path.isdir(path):
                    os.makedirs(path)
            except OSError:
                print ("Creation of the directory %s failed" % path)
            else:
                print ("Successfully created the directory %s " % path)
        
            print("-----------------------------------------------------------------------------------------")
            print("Guardamos valores")
            joblib.dump(min_iterations, "results/fobjQuadraticError/iteration{}/best_gen_fitness_iter{}.pkl".format(g, g))
            joblib.dump(max_iterations, "results/fobjQuadraticError/iteration{}/worst_gen_fitness_iter{}.pkl".format(g, g))
            joblib.dump(avg_iterations, "results/fobjQuadraticError/iteration{}/mean_gen_fitness_iter{}.pkl".format(g, g))
            joblib.dump(std_iterations, "results/fobjQuadraticError/iteration{}/std_gen_fitness_iter{}.pkl".format(g, g))
            joblib.dump(ind_iterations, "results/fobjQuadraticError/iteration{}/best_gen_individuals_iter{}.pkl".format(g, g))
            joblib.dump(pop[:], "results/fobjQuadraticError/iteration{}/last_pop{}.pkl".format(g, g))

            print('-----------------------------------------------------------------------------------------')

        print("--- {} s seconds to perform iteration number: {} ---".format((time() - start_time), g))
            
    #best = pop[np.argmin([toolbox.evaluate(x) for x in pop])]
    final_pop = pop[:]
    
    joblib.dump(min_iterations, "results/fobjQuadraticError/best_gen_fitness_iter{}.pkl".format(4000))
    joblib.dump(max_iterations, "results/fobjQuadraticError/worst_gen_fitness_iter{}.pkl".format(4000))
    joblib.dump(avg_iterations, "results/fobjQuadraticError/mean_gen_fitness_iter{}.pkl".format(4000))
    joblib.dump(std_iterations, "results/fobjQuadraticError/std_gen_fitness_iter{}.pkl".format(4000))
    joblib.dump(ind_iterations, "results/fobjQuadraticError/best_gen_individuals_iter{}.pkl".format(4000))
    joblib.dump(final_pop, "results/fobjQuadraticError/final_pop_iter{}.pkl".format(4000))
# Out:
# -- Generation 1 --
#   Min 1.157260523059852
# --- 342.1356155872345 s seconds to perform iteration number: 1 ---
# -- Generation 2 --
#   Min 1.0382464224703958
# --- 343.8213412761688 s seconds to perform iteration number: 2 ---
# -- Generation 3 --
#   Min 0.9721409368925277
# --- 344.4454243183136 s seconds to perform iteration number: 3 ---
# -- Generation 4 --
#   Min 0.9105069854188278
# --- 342.8107805252075 s seconds to perform iteration number: 4 ---
# -- Generation 5 --
#   Min 0.8207402361356174
# --- 343.93267917633057 s seconds to perform iteration number: 5 ---
# -- Generation 6 --
#   Min 0.7517098481379408
# --- 384.52825450897217 s seconds to perform iteration number: 6 ---
# -- Generation 7 --
#   Min 0.7043979527172493
# --- 344.28119134902954 s seconds to perform iteration number: 7 ---
# -- Generation 8 --
#   Min 0.6571204922893941
# --- 343.2225983142853 s seconds to perform iteration number: 8 ---
# -- Generation 9 --
#   Min 0.6273788413691943
# --- 342.8766441345215 s seconds to perform iteration number: 9 ---
# -- Generation 10 --
#   Min 0.5876851901053474
# --- 343.44486355781555 s seconds to perform iteration number: 10 ---
# -- Generation 11 --
#   Min 0.5669160258268169
# --- 344.5380573272705 s seconds to perform iteration number: 11 ---
# -- Generation 12 --
#   Min 0.5307412680744128
# --- 342.7731556892395 s seconds to perform iteration number: 12 ---
# -- Generation 13 --
#   Min 0.5002455249015176
# --- 344.6646294593811 s seconds to perform iteration number: 13 ---
# -- Generation 14 --
#   Min 0.454699152894822
# --- 345.3045871257782 s seconds to perform iteration number: 14 ---
# -- Generation 15 --
#   Min 0.42642458109055503
# --- 339.03599786758423 s seconds to perform iteration number: 15 ---
# -- Generation 16 --
#   Min 0.36191199703425714
# --- 385.4756875038147 s seconds to perform iteration number: 16 ---
# -- Generation 17 --
#   Min 0.3283520426012749
# --- 340.6921362876892 s seconds to perform iteration number: 17 ---
# -- Generation 18 --
#   Min 0.30701164951240967
# --- 345.0749626159668 s seconds to perform iteration number: 18 ---
# -- Generation 19 --
#   Min 0.2955055148411991
# --- 346.5383446216583 s seconds to perform iteration number: 19 ---
# -- Generation 20 --
#   Min 0.2738783058630908
# --- 343.73403787612915 s seconds to perform iteration number: 20 ---
# -- Generation 21 --
#   Min 0.26164798461544575
# --- 346.4171862602234 s seconds to perform iteration number: 21 ---
# -- Generation 22 --
#   Min 0.2604478825680892
# --- 343.3044102191925 s seconds to perform iteration number: 22 ---
# -- Generation 23 --
#   Min 0.2508437769539148
# --- 345.44611644744873 s seconds to perform iteration number: 23 ---
# -- Generation 24 --
#   Min 0.24156873741407986
# --- 343.09923791885376 s seconds to perform iteration number: 24 ---
# -- Generation 25 --
#   Min 0.22921409413118088
# --- 384.2130720615387 s seconds to perform iteration number: 25 ---
# -- Generation 26 --
#   Min 0.22033443831784716
# --- 383.7565734386444 s seconds to perform iteration number: 26 ---
# -- Generation 27 --
#   Min 0.2091996958059206
# --- 384.78454542160034 s seconds to perform iteration number: 27 ---
# -- Generation 28 --
#   Min 0.2030018415021943
# --- 382.5958921909332 s seconds to perform iteration number: 28 ---
# -- Generation 29 --
#   Min 0.20277724108583314
# --- 344.21047592163086 s seconds to perform iteration number: 29 ---
# -- Generation 30 --
#   Min 0.20023258301318525
# --- 383.21455931663513 s seconds to perform iteration number: 30 ---
# -- Generation 31 --
#   Min 0.19637962918306634
# --- 343.8300507068634 s seconds to perform iteration number: 31 ---
# -- Generation 32 --
#   Min 0.19333383973435578
# --- 344.61915731430054 s seconds to perform iteration number: 32 ---
# -- Generation 33 --
#   Min 0.1927184762976981
# --- 342.7984268665314 s seconds to perform iteration number: 33 ---
# -- Generation 34 --
#   Min 0.18445651360959614
# --- 343.8839168548584 s seconds to perform iteration number: 34 ---
# -- Generation 35 --
#   Min 0.18240802393139705
# --- 341.44258165359497 s seconds to perform iteration number: 35 ---
# -- Generation 36 --
#   Min 0.1784994482130182
# --- 340.4847264289856 s seconds to perform iteration number: 36 ---
# -- Generation 37 --
#   Min 0.17368867460154333
# --- 344.5639913082123 s seconds to perform iteration number: 37 ---
# -- Generation 38 --
#   Min 0.167424079277067
# --- 381.71035861968994 s seconds to perform iteration number: 38 ---
# -- Generation 39 --
#   Min 0.1639963392722364
# --- 343.3982484340668 s seconds to perform iteration number: 39 ---
# -- Generation 40 --
#   Min 0.16143636830110278
# --- 342.8488714694977 s seconds to perform iteration number: 40 ---
# -- Generation 41 --
#   Min 0.15606131694736372
# --- 343.314001083374 s seconds to perform iteration number: 41 ---
# -- Generation 42 --
#   Min 0.15350484891139254
# --- 381.5267951488495 s seconds to perform iteration number: 42 ---
# -- Generation 43 --
#   Min 0.14761118754341118
# --- 343.0762221813202 s seconds to perform iteration number: 43 ---
# -- Generation 44 --
#   Min 0.1406358541153374
# --- 344.60657477378845 s seconds to perform iteration number: 44 ---
# -- Generation 45 --
#   Min 0.1397798544560602
# --- 342.5132532119751 s seconds to perform iteration number: 45 ---
# -- Generation 46 --
#   Min 0.13830533515130053
# --- 344.1483504772186 s seconds to perform iteration number: 46 ---
# -- Generation 47 --
#   Min 0.13510564764388053
# --- 343.848281621933 s seconds to perform iteration number: 47 ---
# -- Generation 48 --
#   Min 0.13381429154148444
# --- 344.4555821418762 s seconds to perform iteration number: 48 ---
# -- Generation 49 --
#   Min 0.13302175448648917
# --- 382.35074973106384 s seconds to perform iteration number: 49 ---
# -- Generation 50 --
#   Min 0.13216962165988982
# --- 344.8211827278137 s seconds to perform iteration number: 50 ---
# -- Generation 51 --
#   Min 0.1317155660310056
# --- 344.21159863471985 s seconds to perform iteration number: 51 ---
# -- Generation 52 --
#   Min 0.13016295191899585
# --- 344.3293204307556 s seconds to perform iteration number: 52 ---
# -- Generation 53 --
#   Min 0.12914235874896624
# --- 340.8937473297119 s seconds to perform iteration number: 53 ---
# -- Generation 54 --
#   Min 0.12865725817944387
# --- 346.7052159309387 s seconds to perform iteration number: 54 ---
# -- Generation 55 --
#   Min 0.12865725817944387
# --- 341.7800073623657 s seconds to perform iteration number: 55 ---
# -- Generation 56 --
#   Min 0.125825977389337
# --- 382.9609594345093 s seconds to perform iteration number: 56 ---
# -- Generation 57 --
#   Min 0.125825977389337
# --- 343.050057888031 s seconds to perform iteration number: 57 ---
# -- Generation 58 --
#   Min 0.125825977389337
# --- 342.3150751590729 s seconds to perform iteration number: 58 ---
# -- Generation 59 --
#   Min 0.12394631401569964
# --- 342.090359210968 s seconds to perform iteration number: 59 ---
# -- Generation 60 --
#   Min 0.12325568845965375
# --- 385.3603653907776 s seconds to perform iteration number: 60 ---
# -- Generation 61 --
#   Min 0.11991120488298128
# --- 344.845716714859 s seconds to perform iteration number: 61 ---
# -- Generation 62 --
#   Min 0.11991120488298128
# --- 386.9773325920105 s seconds to perform iteration number: 62 ---
# -- Generation 63 --
#   Min 0.11884947076425988
# --- 342.07214856147766 s seconds to perform iteration number: 63 ---
# -- Generation 64 --
#   Min 0.11743131699081873
# --- 345.6330056190491 s seconds to perform iteration number: 64 ---
# -- Generation 65 --
#   Min 0.11734672009581389
# --- 344.7915823459625 s seconds to perform iteration number: 65 ---
# -- Generation 66 --
#   Min 0.11734672009581389
# --- 382.49076533317566 s seconds to perform iteration number: 66 ---
# -- Generation 67 --
#   Min 0.11734672009581389
# --- 343.31124544143677 s seconds to perform iteration number: 67 ---
# -- Generation 68 --
#   Min 0.11734672009581389
# --- 382.2727687358856 s seconds to perform iteration number: 68 ---
# -- Generation 69 --
#   Min 0.11523225799250791
# --- 382.3495306968689 s seconds to perform iteration number: 69 ---
# -- Generation 70 --
#   Min 0.11523225799250791
# --- 383.6084840297699 s seconds to perform iteration number: 70 ---
# -- Generation 71 --
#   Min 0.11523225799250791
# --- 383.6189773082733 s seconds to perform iteration number: 71 ---
# -- Generation 72 --
#   Min 0.11523225799250791
# --- 340.759850025177 s seconds to perform iteration number: 72 ---
# -- Generation 73 --
#   Min 0.11500086518831713
# --- 384.8437588214874 s seconds to perform iteration number: 73 ---
# -- Generation 74 --
#   Min 0.11500086518831713
# --- 346.3235573768616 s seconds to perform iteration number: 74 ---
# -- Generation 75 --
#   Min 0.11500086518831713
# --- 385.5358958244324 s seconds to perform iteration number: 75 ---
# -- Generation 76 --
#   Min 0.11500086518831713
# --- 343.5414140224457 s seconds to perform iteration number: 76 ---
# -- Generation 77 --
#   Min 0.11467513091310033
# --- 341.94401693344116 s seconds to perform iteration number: 77 ---
# -- Generation 78 --
#   Min 0.11321495620738027
# --- 345.4007818698883 s seconds to perform iteration number: 78 ---
# -- Generation 79 --
#   Min 0.1117353771872864
# --- 382.8132231235504 s seconds to perform iteration number: 79 ---
# -- Generation 80 --
#   Min 0.11115882351643773
# --- 342.0109496116638 s seconds to perform iteration number: 80 ---
# -- Generation 81 --
#   Min 0.11020743030566683
# --- 386.64602756500244 s seconds to perform iteration number: 81 ---
# -- Generation 82 --
#   Min 0.10726382226058641
# --- 384.52075576782227 s seconds to perform iteration number: 82 ---
# -- Generation 83 --
#   Min 0.10444110219748294
# --- 386.3484971523285 s seconds to perform iteration number: 83 ---
# -- Generation 84 --
#   Min 0.10444110219748294
# --- 343.43308997154236 s seconds to perform iteration number: 84 ---
# -- Generation 85 --
#   Min 0.10441160842868827
# --- 385.63520336151123 s seconds to perform iteration number: 85 ---
# -- Generation 86 --
#   Min 0.10441160842868827
# --- 343.7023084163666 s seconds to perform iteration number: 86 ---
# -- Generation 87 --
#   Min 0.10441160842868827
# --- 384.0101783275604 s seconds to perform iteration number: 87 ---
# -- Generation 88 --
#   Min 0.10441160842868827
# --- 344.4299511909485 s seconds to perform iteration number: 88 ---
# -- Generation 89 --
#   Min 0.10426739651660726
# --- 384.69767713546753 s seconds to perform iteration number: 89 ---
# -- Generation 90 --
#   Min 0.10426739651660726
# --- 342.4316985607147 s seconds to perform iteration number: 90 ---
# -- Generation 91 --
#   Min 0.10426739651660726
# --- 342.43149495124817 s seconds to perform iteration number: 91 ---
# -- Generation 92 --
#   Min 0.1040341532233187
# --- 344.11852383613586 s seconds to perform iteration number: 92 ---
# -- Generation 93 --
#   Min 0.10399184856229372
# --- 344.89110684394836 s seconds to perform iteration number: 93 ---
# -- Generation 94 --
#   Min 0.10395323308933545
# --- 385.86735105514526 s seconds to perform iteration number: 94 ---
# -- Generation 95 --
#   Min 0.10392808965081037
# --- 343.50743079185486 s seconds to perform iteration number: 95 ---
# -- Generation 96 --
#   Min 0.10392808965081037
# --- 384.15064215660095 s seconds to perform iteration number: 96 ---
# -- Generation 97 --
#   Min 0.10392808965081037
# --- 343.93469429016113 s seconds to perform iteration number: 97 ---
# -- Generation 98 --
#   Min 0.10384424707350302
# --- 345.58377599716187 s seconds to perform iteration number: 98 ---
# -- Generation 99 --
#   Min 0.10232179481650187
# --- 345.3655927181244 s seconds to perform iteration number: 99 ---
# -- Generation 100 --
#   Min 0.10223927989496658
# --- 346.0507028102875 s seconds to perform iteration number: 100 ---
# -- Generation 101 --
#   Min 0.10223927989496658
# --- 343.4586730003357 s seconds to perform iteration number: 101 ---
# -- Generation 102 --
#   Min 0.0988422715074235
# --- 345.9796996116638 s seconds to perform iteration number: 102 ---
# -- Generation 103 --
#   Min 0.09862065988919907
# --- 344.15630316734314 s seconds to perform iteration number: 103 ---
# -- Generation 104 --
#   Min 0.09858878398967784
# --- 344.32029604911804 s seconds to perform iteration number: 104 ---
# -- Generation 105 --
#   Min 0.09825330182216271
# --- 344.03765082359314 s seconds to perform iteration number: 105 ---
# -- Generation 106 --
#   Min 0.09825330182216271
# --- 386.8170258998871 s seconds to perform iteration number: 106 ---
# -- Generation 107 --
#   Min 0.09825330182216271
# --- 303.85748624801636 s seconds to perform iteration number: 107 ---
# -- Generation 108 --
#   Min 0.0981774495969824
# --- 344.5481593608856 s seconds to perform iteration number: 108 ---
# -- Generation 109 --
#   Min 0.09817411391144461
# --- 344.112295627594 s seconds to perform iteration number: 109 ---
# -- Generation 110 --
#   Min 0.09817408613445612
# --- 343.97823667526245 s seconds to perform iteration number: 110 ---
# -- Generation 111 --
#   Min 0.09535948384667152
# --- 385.41091775894165 s seconds to perform iteration number: 111 ---
# -- Generation 112 --
#   Min 0.0949152861406964
# --- 342.28857135772705 s seconds to perform iteration number: 112 ---
# -- Generation 113 --
#   Min 0.0949152861406964
# --- 343.85794472694397 s seconds to perform iteration number: 113 ---
# -- Generation 114 --
#   Min 0.09458845472279072
# --- 343.657418012619 s seconds to perform iteration number: 114 ---
# -- Generation 115 --
#   Min 0.09419369750784908
# --- 383.4539113044739 s seconds to perform iteration number: 115 ---
# -- Generation 116 --
#   Min 0.09404938200398301
# --- 344.786030292511 s seconds to perform iteration number: 116 ---
# -- Generation 117 --
#   Min 0.09404938200398301
# --- 344.4506411552429 s seconds to perform iteration number: 117 ---
# -- Generation 118 --
#   Min 0.09404482158549109
# --- 343.0870976448059 s seconds to perform iteration number: 118 ---
# -- Generation 119 --
#   Min 0.09404482158549109
# --- 341.6169695854187 s seconds to perform iteration number: 119 ---
# -- Generation 120 --
#   Min 0.09394614814031799
# --- 383.74039793014526 s seconds to perform iteration number: 120 ---
# -- Generation 121 --
#   Min 0.09394614814031799
# --- 343.48889541625977 s seconds to perform iteration number: 121 ---
# -- Generation 122 --
#   Min 0.09394614814031799
# --- 342.1439166069031 s seconds to perform iteration number: 122 ---
# -- Generation 123 --
#   Min 0.09394614814031799
# --- 384.9992907047272 s seconds to perform iteration number: 123 ---
# -- Generation 124 --
#   Min 0.09394614814031799
# --- 383.87268686294556 s seconds to perform iteration number: 124 ---
# -- Generation 125 --
#   Min 0.09394614814031799
# --- 385.97264337539673 s seconds to perform iteration number: 125 ---
# -- Generation 126 --
#   Min 0.09378455119597028
# --- 342.52226400375366 s seconds to perform iteration number: 126 ---
# -- Generation 127 --
#   Min 0.09370573151496556
# --- 342.8685908317566 s seconds to perform iteration number: 127 ---
# -- Generation 128 --
#   Min 0.09370573151496556
# --- 343.3215980529785 s seconds to perform iteration number: 128 ---
# -- Generation 129 --
#   Min 0.09370573151496556
# --- 343.64455246925354 s seconds to perform iteration number: 129 ---
# -- Generation 130 --
#   Min 0.09370573151496556
# --- 344.5555453300476 s seconds to perform iteration number: 130 ---
# -- Generation 131 --
#   Min 0.09370573151496556
# --- 385.2555718421936 s seconds to perform iteration number: 131 ---
# -- Generation 132 --
#   Min 0.09370573151496556
# --- 343.31802010536194 s seconds to perform iteration number: 132 ---
# -- Generation 133 --
#   Min 0.09370573151496556
# --- 383.29059648513794 s seconds to perform iteration number: 133 ---
# -- Generation 134 --
#   Min 0.09370573151496556
# --- 340.73573184013367 s seconds to perform iteration number: 134 ---
# -- Generation 135 --
#   Min 0.09370573151496556
# --- 344.42007303237915 s seconds to perform iteration number: 135 ---
# -- Generation 136 --
#   Min 0.09369764673954693
# --- 343.8179180622101 s seconds to perform iteration number: 136 ---
# -- Generation 137 --
#   Min 0.09369764673954693
# --- 344.48535919189453 s seconds to perform iteration number: 137 ---
# -- Generation 138 --
#   Min 0.09369764673954693
# --- 342.95311856269836 s seconds to perform iteration number: 138 ---
# -- Generation 139 --
#   Min 0.09369764673954693
# --- 383.5409805774689 s seconds to perform iteration number: 139 ---
# -- Generation 140 --
#   Min 0.09364986431403735
# --- 382.52809143066406 s seconds to perform iteration number: 140 ---
# -- Generation 141 --
#   Min 0.0935684171239398
# --- 384.1305832862854 s seconds to perform iteration number: 141 ---
# -- Generation 142 --
#   Min 0.09352135105967016
# --- 344.9661421775818 s seconds to perform iteration number: 142 ---
# -- Generation 143 --
#   Min 0.09352135105967016
# --- 346.05249977111816 s seconds to perform iteration number: 143 ---
# -- Generation 144 --
#   Min 0.09352135105967016
# --- 383.26429510116577 s seconds to perform iteration number: 144 ---
# -- Generation 145 --
#   Min 0.09352135105967016
# --- 344.6104152202606 s seconds to perform iteration number: 145 ---
# -- Generation 146 --
#   Min 0.09352135105967016
# --- 385.75602746009827 s seconds to perform iteration number: 146 ---
# -- Generation 147 --
#   Min 0.09349702146270038
# --- 342.7977089881897 s seconds to perform iteration number: 147 ---
# -- Generation 148 --
#   Min 0.09333019084752958
# --- 344.94979786872864 s seconds to perform iteration number: 148 ---
# -- Generation 149 --
#   Min 0.09333019084752958
# --- 384.1469211578369 s seconds to perform iteration number: 149 ---
# -- Generation 150 --
#   Min 0.09322396043451545
# --- 339.70922350883484 s seconds to perform iteration number: 150 ---
# -- Generation 151 --
#   Min 0.09322396043451545
# --- 344.32304191589355 s seconds to perform iteration number: 151 ---
# -- Generation 152 --
#   Min 0.09321064850605985
# --- 340.6077446937561 s seconds to perform iteration number: 152 ---
# -- Generation 153 --
#   Min 0.09321064850605985
# --- 345.58161878585815 s seconds to perform iteration number: 153 ---
# -- Generation 154 --
#   Min 0.09321064850605985
# --- 385.2170310020447 s seconds to perform iteration number: 154 ---
# -- Generation 155 --
#   Min 0.09321064850605985
# --- 385.12569856643677 s seconds to perform iteration number: 155 ---
# -- Generation 156 --
#   Min 0.09321064850605985
# --- 343.6905052661896 s seconds to perform iteration number: 156 ---
# -- Generation 157 --
#   Min 0.09321064850605985
# --- 344.27564907073975 s seconds to perform iteration number: 157 ---
# -- Generation 158 --
#   Min 0.09321064850605985
# --- 383.525039434433 s seconds to perform iteration number: 158 ---
# -- Generation 159 --
#   Min 0.09320341702585926
# --- 346.6618826389313 s seconds to perform iteration number: 159 ---
# -- Generation 160 --
#   Min 0.09320341702585926
# --- 343.4324746131897 s seconds to perform iteration number: 160 ---
# -- Generation 161 --
#   Min 0.09320341702585926
# --- 343.61138010025024 s seconds to perform iteration number: 161 ---
# -- Generation 162 --
#   Min 0.09320341702585926
# --- 384.2816061973572 s seconds to perform iteration number: 162 ---
# -- Generation 163 --
#   Min 0.09320341702585926
# --- 344.66189408302307 s seconds to perform iteration number: 163 ---
# -- Generation 164 --
#   Min 0.0930327162494327
# --- 384.1908299922943 s seconds to perform iteration number: 164 ---
# -- Generation 165 --
#   Min 0.0930327162494327
# --- 343.5891206264496 s seconds to perform iteration number: 165 ---
# -- Generation 166 --
#   Min 0.09287183066648841
# --- 342.0073251724243 s seconds to perform iteration number: 166 ---
# -- Generation 167 --
#   Min 0.09287183066648841
# --- 341.61999773979187 s seconds to perform iteration number: 167 ---
# -- Generation 168 --
#   Min 0.09287183066648841
# --- 344.50558161735535 s seconds to perform iteration number: 168 ---
# -- Generation 169 --
#   Min 0.09287183066648841
# --- 343.3679280281067 s seconds to perform iteration number: 169 ---
# -- Generation 170 --
#   Min 0.09283773334930191
# --- 383.78943371772766 s seconds to perform iteration number: 170 ---
# -- Generation 171 --
#   Min 0.0928305073730027
# --- 299.9267466068268 s seconds to perform iteration number: 171 ---
# -- Generation 172 --
#   Min 0.0928305073730027
# --- 343.84370136260986 s seconds to perform iteration number: 172 ---
# -- Generation 173 --
#   Min 0.0928305073730027
# --- 343.86044120788574 s seconds to perform iteration number: 173 ---
# -- Generation 174 --
#   Min 0.09280000254379073
# --- 343.8799340724945 s seconds to perform iteration number: 174 ---
# -- Generation 175 --
#   Min 0.09274923852921449
# --- 386.45654249191284 s seconds to perform iteration number: 175 ---
# -- Generation 176 --
#   Min 0.09274923852921449
# --- 384.2157266139984 s seconds to perform iteration number: 176 ---
# -- Generation 177 --
#   Min 0.09274923852921449
# --- 382.4396688938141 s seconds to perform iteration number: 177 ---
# -- Generation 178 --
#   Min 0.09262106414691632
# --- 345.2535705566406 s seconds to perform iteration number: 178 ---
# -- Generation 179 --
#   Min 0.09258650504618152
# --- 384.2158796787262 s seconds to perform iteration number: 179 ---
# -- Generation 180 --
#   Min 0.09258650504618152
# --- 384.7860369682312 s seconds to perform iteration number: 180 ---
# -- Generation 181 --
#   Min 0.09227131364312725
# --- 341.20732021331787 s seconds to perform iteration number: 181 ---
# -- Generation 182 --
#   Min 0.09216449057429456
# --- 384.0789487361908 s seconds to perform iteration number: 182 ---
# -- Generation 183 --
#   Min 0.09216449057429456
# --- 343.91523599624634 s seconds to perform iteration number: 183 ---
# -- Generation 184 --
#   Min 0.09216449057429456
# --- 382.54546546936035 s seconds to perform iteration number: 184 ---
# -- Generation 185 --
#   Min 0.09216449057429456
# --- 344.8942530155182 s seconds to perform iteration number: 185 ---
# -- Generation 186 --
#   Min 0.09216449057429456
# --- 343.1396107673645 s seconds to perform iteration number: 186 ---
# -- Generation 187 --
#   Min 0.09216449057429456
# --- 343.6547281742096 s seconds to perform iteration number: 187 ---
# -- Generation 188 --
#   Min 0.09210865924686847
# --- 383.3309803009033 s seconds to perform iteration number: 188 ---
# -- Generation 189 --
#   Min 0.09210865924686847
# --- 341.53243231773376 s seconds to perform iteration number: 189 ---
# -- Generation 190 --
#   Min 0.09210865924686847
# --- 384.62673449516296 s seconds to perform iteration number: 190 ---
# -- Generation 191 --
#   Min 0.09208874655719425
# --- 344.6218421459198 s seconds to perform iteration number: 191 ---
# -- Generation 192 --
#   Min 0.09208874655719425
# --- 342.1727283000946 s seconds to perform iteration number: 192 ---
# -- Generation 193 --
#   Min 0.09208874655719425
# --- 344.2536931037903 s seconds to perform iteration number: 193 ---
# -- Generation 194 --
#   Min 0.09208874655719425
# --- 344.43341088294983 s seconds to perform iteration number: 194 ---
# -- Generation 195 --
#   Min 0.0920875799397022
# --- 384.3717129230499 s seconds to perform iteration number: 195 ---
# -- Generation 196 --
#   Min 0.09202792045078008
# --- 383.39280343055725 s seconds to perform iteration number: 196 ---
# -- Generation 197 --
#   Min 0.09193267536958025
# --- 384.2605347633362 s seconds to perform iteration number: 197 ---
# -- Generation 198 --
#   Min 0.09192628854731226
# --- 300.840261220932 s seconds to perform iteration number: 198 ---
# -- Generation 199 --
#   Min 0.09192628854731226
# --- 343.34433460235596 s seconds to perform iteration number: 199 ---
# -- Generation 200 --
#   Min 0.09192628854731226
# Successfully created the directory ./results/fobjQuadraticError/iteration200
# -----------------------------------------------------------------------------------------
# Guardamos valores
# -----------------------------------------------------------------------------------------
# --- 344.7672770023346 s seconds to perform iteration number: 200 ---
# -- Generation 201 --
#   Min 0.09192628854731226
# --- 386.96617317199707 s seconds to perform iteration number: 201 ---
# -- Generation 202 --
#   Min 0.09192628854731226
# --- 300.3532748222351 s seconds to perform iteration number: 202 ---
# -- Generation 203 --
#   Min 0.09192628854731226
# --- 345.53555560112 s seconds to perform iteration number: 203 ---
# -- Generation 204 --
#   Min 0.09192628854731226
# --- 344.8936324119568 s seconds to perform iteration number: 204 ---
# -- Generation 205 --
#   Min 0.09192628854731226
# --- 384.3613221645355 s seconds to perform iteration number: 205 ---
# -- Generation 206 --
#   Min 0.09192628854731226
# --- 345.59638810157776 s seconds to perform iteration number: 206 ---
# -- Generation 207 --
#   Min 0.09192628854731226
# --- 345.71858859062195 s seconds to perform iteration number: 207 ---
# -- Generation 208 --
#   Min 0.09192628854731226
# --- 343.63204288482666 s seconds to perform iteration number: 208 ---
# -- Generation 209 --
#   Min 0.09192628854731226
# --- 344.6291642189026 s seconds to perform iteration number: 209 ---
# -- Generation 210 --
#   Min 0.09192628854731226
# --- 385.22478699684143 s seconds to perform iteration number: 210 ---
# -- Generation 211 --
#   Min 0.09192628854731226
# --- 344.00414299964905 s seconds to perform iteration number: 211 ---
# -- Generation 212 --
#   Min 0.09192628854731226
# --- 344.4792699813843 s seconds to perform iteration number: 212 ---
# -- Generation 213 --
#   Min 0.09192628854731226
# --- 343.12732458114624 s seconds to perform iteration number: 213 ---
# -- Generation 214 --
#   Min 0.09192628854731226
# --- 384.24193930625916 s seconds to perform iteration number: 214 ---
# -- Generation 215 --
#   Min 0.09174721313801852
# --- 343.9571499824524 s seconds to perform iteration number: 215 ---
# -- Generation 216 --
#   Min 0.09174721313801852
# --- 339.2753257751465 s seconds to perform iteration number: 216 ---
# -- Generation 217 --
#   Min 0.09174721313801852
# --- 343.2417652606964 s seconds to perform iteration number: 217 ---
# -- Generation 218 --
#   Min 0.09174721313801852
# --- 345.19023299217224 s seconds to perform iteration number: 218 ---
# -- Generation 219 --
#   Min 0.09174721313801852
# --- 345.5500235557556 s seconds to perform iteration number: 219 ---
# -- Generation 220 --
#   Min 0.09174721313801852
# --- 342.81062602996826 s seconds to perform iteration number: 220 ---
# -- Generation 221 --
#   Min 0.09174721313801852
# --- 383.85732340812683 s seconds to perform iteration number: 221 ---
# -- Generation 222 --
#   Min 0.09174721313801852
# --- 343.81950092315674 s seconds to perform iteration number: 222 ---
# -- Generation 223 --
#   Min 0.09174721313801852
# --- 301.2678954601288 s seconds to perform iteration number: 223 ---
# -- Generation 224 --
#   Min 0.09174721313801852
# --- 343.883424282074 s seconds to perform iteration number: 224 ---
# -- Generation 225 --
#   Min 0.09174721313801852
# --- 344.58275985717773 s seconds to perform iteration number: 225 ---
# -- Generation 226 --
#   Min 0.09174721313801852
# --- 345.0742280483246 s seconds to perform iteration number: 226 ---
# -- Generation 227 --
#   Min 0.09174721313801852
# --- 346.5999348163605 s seconds to perform iteration number: 227 ---
# -- Generation 228 --
#   Min 0.09174721313801852
# --- 344.7982976436615 s seconds to perform iteration number: 228 ---
# -- Generation 229 --
#   Min 0.0912857311039935
# --- 383.8147642612457 s seconds to perform iteration number: 229 ---
# -- Generation 230 --
#   Min 0.0912857311039935
# --- 384.39351773262024 s seconds to perform iteration number: 230 ---
# -- Generation 231 --
#   Min 0.09125007575378406
# --- 344.9589307308197 s seconds to perform iteration number: 231 ---
# -- Generation 232 --
#   Min 0.09125007575378406
# --- 342.3814015388489 s seconds to perform iteration number: 232 ---
# -- Generation 233 --
#   Min 0.09125007575378406
# --- 344.6365101337433 s seconds to perform iteration number: 233 ---
# -- Generation 234 --
#   Min 0.09125007575378406
# --- 340.04494047164917 s seconds to perform iteration number: 234 ---
# -- Generation 235 --
#   Min 0.09125007575378406
# --- 343.54719948768616 s seconds to perform iteration number: 235 ---
# -- Generation 236 --
#   Min 0.09123051342248546
# --- 383.9111738204956 s seconds to perform iteration number: 236 ---
# -- Generation 237 --
#   Min 0.09123051342248546
# --- 341.2258415222168 s seconds to perform iteration number: 237 ---
# -- Generation 238 --
#   Min 0.09123051342248546
# --- 383.9133150577545 s seconds to perform iteration number: 238 ---
# -- Generation 239 --
#   Min 0.09123051342248546
# --- 344.3013951778412 s seconds to perform iteration number: 239 ---
# -- Generation 240 --
#   Min 0.09122959290959316
# --- 341.4861171245575 s seconds to perform iteration number: 240 ---
# -- Generation 241 --
#   Min 0.09122959290959316
# --- 344.18922209739685 s seconds to perform iteration number: 241 ---
# -- Generation 242 --
#   Min 0.09122959290959316
# --- 341.3827221393585 s seconds to perform iteration number: 242 ---
# -- Generation 243 --
#   Min 0.09122959290959316
# --- 383.48056530952454 s seconds to perform iteration number: 243 ---
# -- Generation 244 --
#   Min 0.09122959290959316
# --- 341.28265023231506 s seconds to perform iteration number: 244 ---
# -- Generation 245 --
#   Min 0.09122959290959316
# --- 345.2468731403351 s seconds to perform iteration number: 245 ---
# -- Generation 246 --
#   Min 0.09122959290959316
# --- 345.7544527053833 s seconds to perform iteration number: 246 ---
# -- Generation 247 --
#   Min 0.09122959290959316
# --- 343.91868829727173 s seconds to perform iteration number: 247 ---
# -- Generation 248 --
#   Min 0.09122959290959316
# --- 345.519917011261 s seconds to perform iteration number: 248 ---
# -- Generation 249 --
#   Min 0.09114055647708363
# --- 344.7638053894043 s seconds to perform iteration number: 249 ---
# -- Generation 250 --
#   Min 0.09114055647708363
# --- 344.0094017982483 s seconds to perform iteration number: 250 ---
# -- Generation 251 --
#   Min 0.09114055647708363
# --- 342.02480268478394 s seconds to perform iteration number: 251 ---
# -- Generation 252 --
#   Min 0.09114055647708363
# --- 384.21357107162476 s seconds to perform iteration number: 252 ---
# -- Generation 253 --
#   Min 0.09114055647708363
# --- 383.2793095111847 s seconds to perform iteration number: 253 ---
# -- Generation 254 --
#   Min 0.09051965706678293
# --- 385.7333266735077 s seconds to perform iteration number: 254 ---
# -- Generation 255 --
#   Min 0.09051965706678293
# --- 344.19168162345886 s seconds to perform iteration number: 255 ---
# -- Generation 256 --
#   Min 0.09051965706678293
# --- 344.4006538391113 s seconds to perform iteration number: 256 ---
# -- Generation 257 --
#   Min 0.09051965706678293
# --- 386.08898735046387 s seconds to perform iteration number: 257 ---
# -- Generation 258 --
#   Min 0.09051965706678293
# --- 343.0459349155426 s seconds to perform iteration number: 258 ---
# -- Generation 259 --
#   Min 0.09051965706678293
# --- 342.7672083377838 s seconds to perform iteration number: 259 ---
# -- Generation 260 --
#   Min 0.0902563582865882
# --- 383.3355076313019 s seconds to perform iteration number: 260 ---
# -- Generation 261 --
#   Min 0.0902563582865882
# --- 386.42433857917786 s seconds to perform iteration number: 261 ---
# -- Generation 262 --
#   Min 0.0902563582865882
# --- 346.5237543582916 s seconds to perform iteration number: 262 ---
# -- Generation 263 --
#   Min 0.0902563582865882
# --- 343.8226296901703 s seconds to perform iteration number: 263 ---
# -- Generation 264 --
#   Min 0.09025527646488318
# --- 340.5674159526825 s seconds to perform iteration number: 264 ---
# -- Generation 265 --
#   Min 0.09025527646488318
# --- 383.6765170097351 s seconds to perform iteration number: 265 ---
# -- Generation 266 --
#   Min 0.09025527646488318
# --- 342.3319797515869 s seconds to perform iteration number: 266 ---
# -- Generation 267 --
#   Min 0.09024567594373531
# --- 383.76238465309143 s seconds to perform iteration number: 267 ---
# -- Generation 268 --
#   Min 0.09024567594373531
# --- 344.04443407058716 s seconds to perform iteration number: 268 ---
# -- Generation 269 --
#   Min 0.09024567594373531
# --- 383.52419686317444 s seconds to perform iteration number: 269 ---
# -- Generation 270 --
#   Min 0.09024567594373531
# --- 345.02418303489685 s seconds to perform iteration number: 270 ---
# -- Generation 271 --
#   Min 0.09024567594373531
# --- 384.24158906936646 s seconds to perform iteration number: 271 ---
# -- Generation 272 --
#   Min 0.09024567594373531
# --- 345.60852456092834 s seconds to perform iteration number: 272 ---
# -- Generation 273 --
#   Min 0.09024567594373531
# --- 345.6317582130432 s seconds to perform iteration number: 273 ---
# -- Generation 274 --
#   Min 0.09024567594373531
# --- 343.39338302612305 s seconds to perform iteration number: 274 ---
# -- Generation 275 --
#   Min 0.09024567594373531
# --- 342.8437469005585 s seconds to perform iteration number: 275 ---
# -- Generation 276 --
#   Min 0.09003902093363256
# --- 345.5586452484131 s seconds to perform iteration number: 276 ---
# -- Generation 277 --
#   Min 0.09003902093363256
# --- 344.16816091537476 s seconds to perform iteration number: 277 ---
# -- Generation 278 --
#   Min 0.09003902093363256
# --- 385.43369913101196 s seconds to perform iteration number: 278 ---
# -- Generation 279 --
#   Min 0.09003902093363256
# --- 342.4198200702667 s seconds to perform iteration number: 279 ---
# -- Generation 280 --
#   Min 0.09003902093363256
# --- 384.0780704021454 s seconds to perform iteration number: 280 ---
# -- Generation 281 --
#   Min 0.09003902093363256
# --- 387.5824716091156 s seconds to perform iteration number: 281 ---
# -- Generation 282 --
#   Min 0.09003902093363256
# --- 342.68873929977417 s seconds to perform iteration number: 282 ---
# -- Generation 283 --
#   Min 0.09003902093363256
# --- 345.8104064464569 s seconds to perform iteration number: 283 ---
# -- Generation 284 --
#   Min 0.09003902093363256
# --- 383.9560191631317 s seconds to perform iteration number: 284 ---
# -- Generation 285 --
#   Min 0.09003902093363256
# --- 386.3175549507141 s seconds to perform iteration number: 285 ---
# -- Generation 286 --
#   Min 0.08994070171629096
# --- 344.07914090156555 s seconds to perform iteration number: 286 ---
# -- Generation 287 --
#   Min 0.08994070171629096
# --- 384.0228748321533 s seconds to perform iteration number: 287 ---
# -- Generation 288 --
#   Min 0.08994070171629096
# --- 341.8516426086426 s seconds to perform iteration number: 288 ---
# -- Generation 289 --
#   Min 0.08994070171629096
# --- 382.94535756111145 s seconds to perform iteration number: 289 ---
# -- Generation 290 --
#   Min 0.08994070171629096
# --- 344.0632863044739 s seconds to perform iteration number: 290 ---
# -- Generation 291 --
#   Min 0.08994070171629096
# --- 345.5458827018738 s seconds to perform iteration number: 291 ---
# -- Generation 292 --
#   Min 0.08985273069567248
# --- 343.9673025608063 s seconds to perform iteration number: 292 ---
# -- Generation 293 --
#   Min 0.08985273069567248
# --- 384.1021797657013 s seconds to perform iteration number: 293 ---
# -- Generation 294 --
#   Min 0.08985273069567248
# --- 341.6603229045868 s seconds to perform iteration number: 294 ---
# -- Generation 295 --
#   Min 0.08985273069567248
# --- 348.45713663101196 s seconds to perform iteration number: 295 ---
# -- Generation 296 --
#   Min 0.08985273069567248
# --- 344.12521958351135 s seconds to perform iteration number: 296 ---
# -- Generation 297 --
#   Min 0.0898366747623566
# --- 342.0856258869171 s seconds to perform iteration number: 297 ---
# -- Generation 298 --
#   Min 0.0898366747623566
# --- 383.8067100048065 s seconds to perform iteration number: 298 ---
# -- Generation 299 --
#   Min 0.0898366747623566
# --- 344.5601236820221 s seconds to perform iteration number: 299 ---
# -- Generation 300 --
#   Min 0.0898366747623566
# --- 343.20992040634155 s seconds to perform iteration number: 300 ---
# -- Generation 301 --
#   Min 0.08981227381417993
# --- 345.05845642089844 s seconds to perform iteration number: 301 ---
# -- Generation 302 --
#   Min 0.08981227381417993
# --- 343.38552927970886 s seconds to perform iteration number: 302 ---
# -- Generation 303 --
#   Min 0.08981227381417993
# --- 341.481716632843 s seconds to perform iteration number: 303 ---
# -- Generation 304 --
#   Min 0.08981227381417993
# --- 386.0849144458771 s seconds to perform iteration number: 304 ---
# -- Generation 305 --
#   Min 0.08981227381417993
# --- 344.1527419090271 s seconds to perform iteration number: 305 ---
# -- Generation 306 --
#   Min 0.08981227381417993
# --- 386.66823148727417 s seconds to perform iteration number: 306 ---
# -- Generation 307 --
#   Min 0.08981227381417993
# --- 384.77023482322693 s seconds to perform iteration number: 307 ---
# -- Generation 308 --
#   Min 0.08981227381417993
# --- 344.8154857158661 s seconds to perform iteration number: 308 ---
# -- Generation 309 --
#   Min 0.08981227381417993
# --- 342.96516370773315 s seconds to perform iteration number: 309 ---
# -- Generation 310 --
#   Min 0.08981227381417993
# --- 345.09803533554077 s seconds to perform iteration number: 310 ---
# -- Generation 311 --
#   Min 0.08981227381417993
# --- 342.1724193096161 s seconds to perform iteration number: 311 ---
# -- Generation 312 --
#   Min 0.08981227381417993
# --- 342.03789043426514 s seconds to perform iteration number: 312 ---
# -- Generation 313 --
#   Min 0.08981227381417993
# --- 383.3706226348877 s seconds to perform iteration number: 313 ---
# -- Generation 314 --
#   Min 0.08981227381417993
# --- 346.8499228954315 s seconds to perform iteration number: 314 ---
# -- Generation 315 --
#   Min 0.08981227381417993
# --- 347.6386570930481 s seconds to perform iteration number: 315 ---
# -- Generation 316 --
#   Min 0.08981227381417993
# --- 347.7326145172119 s seconds to perform iteration number: 316 ---
# -- Generation 317 --
#   Min 0.08972546154037984
# --- 384.16517186164856 s seconds to perform iteration number: 317 ---
# -- Generation 318 --
#   Min 0.08972546154037984
# --- 345.6909191608429 s seconds to perform iteration number: 318 ---
# -- Generation 319 --
#   Min 0.08972546154037984
# --- 383.14352536201477 s seconds to perform iteration number: 319 ---
# -- Generation 320 --
#   Min 0.08972546154037984
# --- 387.53780460357666 s seconds to perform iteration number: 320 ---
# -- Generation 321 --
#   Min 0.08972546154037984
# --- 341.9676094055176 s seconds to perform iteration number: 321 ---
# -- Generation 322 --
#   Min 0.08972546154037984
# --- 340.41664958000183 s seconds to perform iteration number: 322 ---
# -- Generation 323 --
#   Min 0.08972546154037984
# --- 385.3567564487457 s seconds to perform iteration number: 323 ---
# -- Generation 324 --
#   Min 0.08972546154037984
# --- 344.3231325149536 s seconds to perform iteration number: 324 ---
# -- Generation 325 --
#   Min 0.08972546154037984
# --- 343.8256757259369 s seconds to perform iteration number: 325 ---
# -- Generation 326 --
#   Min 0.08972546154037984
# --- 345.08973813056946 s seconds to perform iteration number: 326 ---
# -- Generation 327 --
#   Min 0.08972546154037984
# --- 343.1473455429077 s seconds to perform iteration number: 327 ---
# -- Generation 328 --
#   Min 0.08972546154037984
# --- 383.3765094280243 s seconds to perform iteration number: 328 ---
# -- Generation 329 --
#   Min 0.08972546154037984
# --- 340.3224368095398 s seconds to perform iteration number: 329 ---
# -- Generation 330 --
#   Min 0.08972546154037984
# --- 384.29967761039734 s seconds to perform iteration number: 330 ---
# -- Generation 331 --
#   Min 0.08972546154037984
# --- 384.4203054904938 s seconds to perform iteration number: 331 ---
# -- Generation 332 --
#   Min 0.08972546154037984
# --- 343.66663575172424 s seconds to perform iteration number: 332 ---
# -- Generation 333 --
#   Min 0.08972546154037984
# --- 384.12633657455444 s seconds to perform iteration number: 333 ---
# -- Generation 334 --
#   Min 0.08972546154037984
# --- 344.5053086280823 s seconds to perform iteration number: 334 ---
# -- Generation 335 --
#   Min 0.08972546154037984
# --- 383.54690384864807 s seconds to perform iteration number: 335 ---
# -- Generation 336 --
#   Min 0.08972546154037984
# --- 383.01830101013184 s seconds to perform iteration number: 336 ---
# -- Generation 337 --
#   Min 0.08972546154037984
# --- 344.8834493160248 s seconds to perform iteration number: 337 ---
# -- Generation 338 --
#   Min 0.08972546154037984
# --- 384.2724874019623 s seconds to perform iteration number: 338 ---
# -- Generation 339 --
#   Min 0.08972546154037984
# --- 344.185870885849 s seconds to perform iteration number: 339 ---
# -- Generation 340 --
#   Min 0.08972457103595011
# --- 382.01651430130005 s seconds to perform iteration number: 340 ---
# -- Generation 341 --
#   Min 0.08972457103595011
# --- 342.9274241924286 s seconds to perform iteration number: 341 ---
# -- Generation 342 --
#   Min 0.08972457103595011
# --- 383.6955244541168 s seconds to perform iteration number: 342 ---
# -- Generation 343 --
#   Min 0.08972457103595011
# --- 343.17879724502563 s seconds to perform iteration number: 343 ---
# -- Generation 344 --
#   Min 0.08972457103595011
# --- 341.0367274284363 s seconds to perform iteration number: 344 ---
# -- Generation 345 --
#   Min 0.08972457103595011
# --- 384.33046317100525 s seconds to perform iteration number: 345 ---
# -- Generation 346 --
#   Min 0.08972457103595011
# --- 385.81388664245605 s seconds to perform iteration number: 346 ---
# -- Generation 347 --
#   Min 0.08972457103595011
# --- 343.907995223999 s seconds to perform iteration number: 347 ---
# -- Generation 348 --
#   Min 0.08972457103595011
# --- 384.3448598384857 s seconds to perform iteration number: 348 ---
# -- Generation 349 --
#   Min 0.08972457103595011
# --- 345.8052816390991 s seconds to perform iteration number: 349 ---
# -- Generation 350 --
#   Min 0.08972457103595011
# --- 384.74455165863037 s seconds to perform iteration number: 350 ---
# -- Generation 351 --
#   Min 0.08972457103595011
# --- 382.7470893859863 s seconds to perform iteration number: 351 ---
# -- Generation 352 --
#   Min 0.08972457103595011
# --- 340.41587018966675 s seconds to perform iteration number: 352 ---
# -- Generation 353 --
#   Min 0.08972457103595011
# --- 343.09610772132874 s seconds to perform iteration number: 353 ---
# -- Generation 354 --
#   Min 0.08972340566266705
# --- 344.7716267108917 s seconds to perform iteration number: 354 ---
# -- Generation 355 --
#   Min 0.08972340566266705
# --- 344.256849527359 s seconds to perform iteration number: 355 ---
# -- Generation 356 --
#   Min 0.08966940382846551
# --- 302.15948939323425 s seconds to perform iteration number: 356 ---
# -- Generation 357 --
#   Min 0.08966940382846551
# --- 343.88722372055054 s seconds to perform iteration number: 357 ---
# -- Generation 358 --
#   Min 0.08966940382846551
# --- 384.60471367836 s seconds to perform iteration number: 358 ---
# -- Generation 359 --
#   Min 0.08966940382846551
# --- 344.3860545158386 s seconds to perform iteration number: 359 ---
# -- Generation 360 --
#   Min 0.08966918073846046
# --- 341.753545999527 s seconds to perform iteration number: 360 ---
# -- Generation 361 --
#   Min 0.08936313113841612
# --- 383.933837890625 s seconds to perform iteration number: 361 ---
# -- Generation 362 --
#   Min 0.08936313113841612
# --- 344.67941665649414 s seconds to perform iteration number: 362 ---
# -- Generation 363 --
#   Min 0.08936313113841612
# --- 343.6401882171631 s seconds to perform iteration number: 363 ---
# -- Generation 364 --
#   Min 0.08936313113841612
# --- 344.51297068595886 s seconds to perform iteration number: 364 ---
# -- Generation 365 --
#   Min 0.08936313113841612
# --- 384.0012068748474 s seconds to perform iteration number: 365 ---
# -- Generation 366 --
#   Min 0.08936313113841612
# --- 383.68556666374207 s seconds to perform iteration number: 366 ---
# -- Generation 367 --
#   Min 0.08936313113841612
# --- 344.3671803474426 s seconds to perform iteration number: 367 ---
# -- Generation 368 --
#   Min 0.08936313113841612
# --- 345.8765604496002 s seconds to perform iteration number: 368 ---
# -- Generation 369 --
#   Min 0.08936313113841612
# --- 386.4864900112152 s seconds to perform iteration number: 369 ---
# -- Generation 370 --
#   Min 0.08936313113841612
# --- 345.067106962204 s seconds to perform iteration number: 370 ---
# -- Generation 371 --
#   Min 0.08936313113841612
# --- 345.07883644104004 s seconds to perform iteration number: 371 ---
# -- Generation 372 --
#   Min 0.08936313113841612
# --- 384.235799074173 s seconds to perform iteration number: 372 ---
# -- Generation 373 --
#   Min 0.08936313113841612
# --- 383.7743377685547 s seconds to perform iteration number: 373 ---
# -- Generation 374 --
#   Min 0.08936313113841612
# --- 343.5641529560089 s seconds to perform iteration number: 374 ---
# -- Generation 375 --
#   Min 0.08936313113841612
# --- 382.3410506248474 s seconds to perform iteration number: 375 ---
# -- Generation 376 --
#   Min 0.08936313113841612
# --- 382.62114429473877 s seconds to perform iteration number: 376 ---
# -- Generation 377 --
#   Min 0.08936313113841612
# --- 384.8850028514862 s seconds to perform iteration number: 377 ---
# -- Generation 378 --
#   Min 0.08936313113841612
# --- 383.67236065864563 s seconds to perform iteration number: 378 ---
# -- Generation 379 --
#   Min 0.08936313113841612
# --- 343.4773836135864 s seconds to perform iteration number: 379 ---
# -- Generation 380 --
#   Min 0.08936313113841612
# --- 342.87327909469604 s seconds to perform iteration number: 380 ---
# -- Generation 381 --
#   Min 0.08936313113841612
# --- 385.48675775527954 s seconds to perform iteration number: 381 ---
# -- Generation 382 --
#   Min 0.08936313113841612
# --- 343.19430112838745 s seconds to perform iteration number: 382 ---
# -- Generation 383 --
#   Min 0.08936313113841612
# --- 343.4575250148773 s seconds to perform iteration number: 383 ---
# -- Generation 384 --
#   Min 0.08936313113841612
# --- 346.3818528652191 s seconds to perform iteration number: 384 ---
# -- Generation 385 --
#   Min 0.08910200482070688
# --- 383.32002115249634 s seconds to perform iteration number: 385 ---
# -- Generation 386 --
#   Min 0.0890958396503553
# --- 342.284973859787 s seconds to perform iteration number: 386 ---
# -- Generation 387 --
#   Min 0.0890958396503553
# --- 341.88815426826477 s seconds to perform iteration number: 387 ---
# -- Generation 388 --
#   Min 0.0890958396503553
# --- 344.48141074180603 s seconds to perform iteration number: 388 ---
# -- Generation 389 --
#   Min 0.0890958396503553
# --- 344.01048135757446 s seconds to perform iteration number: 389 ---
# -- Generation 390 --
#   Min 0.0890958396503553
# --- 383.83345127105713 s seconds to perform iteration number: 390 ---
# -- Generation 391 --
#   Min 0.08880432963556338
# --- 382.8425371646881 s seconds to perform iteration number: 391 ---
# -- Generation 392 --
#   Min 0.08880432963556338
# --- 347.11198687553406 s seconds to perform iteration number: 392 ---
# -- Generation 393 --
#   Min 0.08880432963556338
# --- 341.91469979286194 s seconds to perform iteration number: 393 ---
# -- Generation 394 --
#   Min 0.08880432963556338
# --- 344.9024181365967 s seconds to perform iteration number: 394 ---
# -- Generation 395 --
#   Min 0.08880432963556338
# --- 386.2859139442444 s seconds to perform iteration number: 395 ---
# -- Generation 396 --
#   Min 0.08880432963556338
# --- 343.808611869812 s seconds to perform iteration number: 396 ---
# -- Generation 397 --
#   Min 0.08880432963556338
# --- 384.5657320022583 s seconds to perform iteration number: 397 ---
# -- Generation 398 --
#   Min 0.08880432963556338
# --- 343.09799909591675 s seconds to perform iteration number: 398 ---
# -- Generation 399 --
#   Min 0.08880432963556338
# --- 382.6508631706238 s seconds to perform iteration number: 399 ---
# -- Generation 400 --
#   Min 0.08880432963556338
# Successfully created the directory ./results/fobjQuadraticError/iteration400
# -----------------------------------------------------------------------------------------
# Guardamos valores
# -----------------------------------------------------------------------------------------
# --- 343.7390468120575 s seconds to perform iteration number: 400 ---
# -- Generation 401 --
#   Min 0.08880432963556338
# --- 340.69442915916443 s seconds to perform iteration number: 401 ---
# -- Generation 402 --
#   Min 0.08880432963556338
# --- 383.19570755958557 s seconds to perform iteration number: 402 ---
# -- Generation 403 --
#   Min 0.08880432963556338
# --- 386.3906571865082 s seconds to perform iteration number: 403 ---
# -- Generation 404 --
#   Min 0.08880432963556338
# --- 344.81155943870544 s seconds to perform iteration number: 404 ---
# -- Generation 405 --
#   Min 0.08880432963556338
# --- 343.81540060043335 s seconds to perform iteration number: 405 ---
# -- Generation 406 --
#   Min 0.08880432963556338
# --- 343.70015573501587 s seconds to perform iteration number: 406 ---
# -- Generation 407 --
#   Min 0.08880432963556338
# --- 342.93685817718506 s seconds to perform iteration number: 407 ---
# -- Generation 408 --
#   Min 0.08880432963556338
# --- 382.8725485801697 s seconds to perform iteration number: 408 ---
# -- Generation 409 --
#   Min 0.08880432963556338
# --- 343.2918207645416 s seconds to perform iteration number: 409 ---
# -- Generation 410 --
#   Min 0.08880432963556338
# --- 383.9935052394867 s seconds to perform iteration number: 410 ---
# -- Generation 411 --
# ...
# --- 385.7374951839447 s seconds to perform iteration number: 1705 ---
# -- Generation 1706 --
#   Min 0.08806430235982643
# --- 384.2637526988983 s seconds to perform iteration number: 1706 ---
# -- Generation 1707 --
#   Min 0.08806430235982643
# --- 346.0726547241211 s seconds to perform iteration number: 1707 ---
# -- Generation 1708 --
#   Min 0.08806430235982643
# --- 386.3820159435272 s seconds to perform iteration number: 1708 ---
# -- Generation 1709 --
#   Min 0.08806430235982643
# --- 344.1524953842163 s seconds to perform iteration number: 1709 ---
# -- Generation 1710 --
#   Min 0.08806430235982643
# --- 341.8614912033081 s seconds to perform iteration number: 1710 ---
# -- Generation 1711 --
#   Min 0.08806430235982643
# --- 383.9021933078766 s seconds to perform iteration number: 1711 ---
# -- Generation 1712 --
#   Min 0.08806430235982643
# --- 341.96180415153503 s seconds to perform iteration number: 1712 ---
# -- Generation 1713 --
#   Min 0.08806430235982643
# --- 385.8338315486908 s seconds to perform iteration number: 1713 ---
# -- Generation 1714 --
#   Min 0.08806430235982643
# --- 383.32246446609497 s seconds to perform iteration number: 1714 ---
# -- Generation 1715 --
#   Min 0.08806430235982643
# --- 343.08636379241943 s seconds to perform iteration number: 1715 ---
# -- Generation 1716 --
#   Min 0.08806430235982643
# --- 339.9462606906891 s seconds to perform iteration number: 1716 ---
# -- Generation 1717 --
#   Min 0.08806430235982643
# --- 346.0077290534973 s seconds to perform iteration number: 1717 ---
# -- Generation 1718 --
#   Min 0.08806430235982643
# --- 345.37775897979736 s seconds to perform iteration number: 1718 ---
# -- Generation 1719 --
#   Min 0.08806430235982643
# --- 343.13597679138184 s seconds to perform iteration number: 1719 ---
# -- Generation 1720 --
#   Min 0.08806430235982643
# --- 385.8283417224884 s seconds to perform iteration number: 1720 ---
# -- Generation 1721 --
#   Min 0.08806430235982643
# --- 342.31556510925293 s seconds to perform iteration number: 1721 ---
# -- Generation 1722 --
#   Min 0.08806430235982643
# --- 384.5826516151428 s seconds to perform iteration number: 1722 ---
# -- Generation 1723 --
#   Min 0.08806430235982643
# --- 343.69387006759644 s seconds to perform iteration number: 1723 ---
# -- Generation 1724 --
#   Min 0.08806430235982643
# --- 344.0139617919922 s seconds to perform iteration number: 1724 ---
# -- Generation 1725 --
#   Min 0.08806430235982643
# --- 383.5005807876587 s seconds to perform iteration number: 1725 ---
# -- Generation 1726 --
#   Min 0.08806430235982643
# --- 346.78394055366516 s seconds to perform iteration number: 1726 ---
# -- Generation 1727 --
#   Min 0.08806430235982643
# --- 342.71629548072815 s seconds to perform iteration number: 1727 ---
# -- Generation 1728 --
#   Min 0.08806430235982643
# --- 343.8067226409912 s seconds to perform iteration number: 1728 ---
# -- Generation 1729 --
#   Min 0.08806430235982643
# --- 383.42792773246765 s seconds to perform iteration number: 1729 ---
# -- Generation 1730 --
#   Min 0.08806430235982643
# --- 384.0950565338135 s seconds to perform iteration number: 1730 ---
# -- Generation 1731 --
#   Min 0.08806430235982643
# --- 383.27573132514954 s seconds to perform iteration number: 1731 ---
# -- Generation 1732 --
#   Min 0.08806430235982643
# --- 343.72841787338257 s seconds to perform iteration number: 1732 ---
# -- Generation 1733 --
#   Min 0.08806430235982643
# --- 385.6708517074585 s seconds to perform iteration number: 1733 ---
# -- Generation 1734 --
#   Min 0.08806430235982643
# --- 344.009628534317 s seconds to perform iteration number: 1734 ---
# -- Generation 1735 --
#   Min 0.08806430235982643
# --- 384.33379578590393 s seconds to perform iteration number: 1735 ---
# -- Generation 1736 --
#   Min 0.08806430235982643
# --- 345.4389805793762 s seconds to perform iteration number: 1736 ---
# -- Generation 1737 --
#   Min 0.08806430235982643
# --- 385.57179522514343 s seconds to perform iteration number: 1737 ---
# -- Generation 1738 --
#   Min 0.08806430235982643
# --- 384.67898201942444 s seconds to perform iteration number: 1738 ---
# -- Generation 1739 --
#   Min 0.08806430235982643
# --- 342.842657327652 s seconds to perform iteration number: 1739 ---
# -- Generation 1740 --
#   Min 0.08806430235982643
# --- 386.21888184547424 s seconds to perform iteration number: 1740 ---
# -- Generation 1741 --
#   Min 0.08806430235982643
# --- 385.34961438179016 s seconds to perform iteration number: 1741 ---
# -- Generation 1742 --
#   Min 0.08806430235982643
# --- 385.4372375011444 s seconds to perform iteration number: 1742 ---
# -- Generation 1743 --
#   Min 0.08806430235982643
# --- 386.94867968559265 s seconds to perform iteration number: 1743 ---
# -- Generation 1744 --
#   Min 0.08806430235982643
# --- 345.16951417922974 s seconds to perform iteration number: 1744 ---
# -- Generation 1745 --
#   Min 0.08806430235982643
# --- 342.52531576156616 s seconds to perform iteration number: 1745 ---
# -- Generation 1746 --
#   Min 0.08806430235982643
# --- 383.9057397842407 s seconds to perform iteration number: 1746 ---
# -- Generation 1747 --
#   Min 0.08805697933786115
# --- 382.0922453403473 s seconds to perform iteration number: 1747 ---
# -- Generation 1748 --
#   Min 0.08805697933786115
# --- 344.69709062576294 s seconds to perform iteration number: 1748 ---
# -- Generation 1749 --
#   Min 0.08805697933786115
# --- 344.784414768219 s seconds to perform iteration number: 1749 ---
# -- Generation 1750 --
#   Min 0.08805697933786115
# --- 382.7579598426819 s seconds to perform iteration number: 1750 ---
# -- Generation 1751 --
#   Min 0.08805697933786115
# --- 382.72332096099854 s seconds to perform iteration number: 1751 ---
# -- Generation 1752 --
#   Min 0.08805697933786115
# --- 343.1599462032318 s seconds to perform iteration number: 1752 ---
# -- Generation 1753 --
#   Min 0.08805697933786115
# --- 384.24257135391235 s seconds to perform iteration number: 1753 ---
# -- Generation 1754 --
#   Min 0.08805697933786115
# --- 384.9248094558716 s seconds to perform iteration number: 1754 ---
# -- Generation 1755 --
#   Min 0.08805697933786115
# --- 344.16994404792786 s seconds to perform iteration number: 1755 ---
# -- Generation 1756 --
#   Min 0.08805697933786115
# --- 342.8650555610657 s seconds to perform iteration number: 1756 ---
# -- Generation 1757 --
#   Min 0.08805697933786115
# --- 383.9432773590088 s seconds to perform iteration number: 1757 ---
# -- Generation 1758 --
#   Min 0.08805697933786115
# --- 301.8844783306122 s seconds to perform iteration number: 1758 ---
# -- Generation 1759 --
#   Min 0.08805697933786115
# --- 346.5423216819763 s seconds to perform iteration number: 1759 ---
# -- Generation 1760 --
#   Min 0.08805697933786115
# --- 344.0166039466858 s seconds to perform iteration number: 1760 ---
# -- Generation 1761 --
#   Min 0.08805697933786115
# --- 384.343435049057 s seconds to perform iteration number: 1761 ---
# -- Generation 1762 --
#   Min 0.08805697933786115
# --- 346.6795198917389 s seconds to perform iteration number: 1762 ---
# -- Generation 1763 --
#   Min 0.08805697933786115
# --- 341.4009485244751 s seconds to perform iteration number: 1763 ---
# -- Generation 1764 --
#   Min 0.08805697933786115
# --- 343.51756596565247 s seconds to perform iteration number: 1764 ---
# -- Generation 1765 --
#   Min 0.08805697933786115
# --- 344.28427290916443 s seconds to perform iteration number: 1765 ---
# -- Generation 1766 --
#   Min 0.08805697933786115
# --- 386.66808819770813 s seconds to perform iteration number: 1766 ---
# -- Generation 1767 --
#   Min 0.08805697933786115
# --- 343.83945965766907 s seconds to perform iteration number: 1767 ---
# -- Generation 1768 --
#   Min 0.08805697933786115
# --- 346.7560029029846 s seconds to perform iteration number: 1768 ---
# -- Generation 1769 --
#   Min 0.08805697933786115
# --- 384.61114287376404 s seconds to perform iteration number: 1769 ---
# -- Generation 1770 --
#   Min 0.08805697933786115
# --- 345.56178617477417 s seconds to perform iteration number: 1770 ---
# -- Generation 1771 --
#   Min 0.08805697933786115
# --- 344.67530250549316 s seconds to perform iteration number: 1771 ---
# -- Generation 1772 --
#   Min 0.08805697933786115
# --- 384.0814473628998 s seconds to perform iteration number: 1772 ---
# -- Generation 1773 --
#   Min 0.08805697933786115
# --- 385.5467538833618 s seconds to perform iteration number: 1773 ---
# -- Generation 1774 --
#   Min 0.08805697933786115
# --- 344.1257972717285 s seconds to perform iteration number: 1774 ---
# -- Generation 1775 --
#   Min 0.08805697933786115
# --- 344.3552088737488 s seconds to perform iteration number: 1775 ---
# -- Generation 1776 --
#   Min 0.08805697933786115
# --- 345.21416902542114 s seconds to perform iteration number: 1776 ---
# -- Generation 1777 --
#   Min 0.08805697933786115
# --- 342.9401047229767 s seconds to perform iteration number: 1777 ---
# -- Generation 1778 --
#   Min 0.08805697933786115
# --- 387.7933886051178 s seconds to perform iteration number: 1778 ---
# -- Generation 1779 --
#   Min 0.08805697933786115
# --- 344.66087007522583 s seconds to perform iteration number: 1779 ---
# -- Generation 1780 --
#   Min 0.08805697933786115
# --- 384.41279006004333 s seconds to perform iteration number: 1780 ---
# -- Generation 1781 --
#   Min 0.08805697933786115
# --- 386.1187574863434 s seconds to perform iteration number: 1781 ---
# -- Generation 1782 --
#   Min 0.08805697933786115
# --- 345.1741416454315 s seconds to perform iteration number: 1782 ---
# -- Generation 1783 --
#   Min 0.08805697933786115
# --- 345.97767066955566 s seconds to perform iteration number: 1783 ---
# -- Generation 1784 --
#   Min 0.08805697933786115
# --- 344.4261317253113 s seconds to perform iteration number: 1784 ---
# -- Generation 1785 --
#   Min 0.08805697933786115
# --- 345.61616373062134 s seconds to perform iteration number: 1785 ---
# -- Generation 1786 --
#   Min 0.08805697933786115
# --- 344.6405415534973 s seconds to perform iteration number: 1786 ---
# -- Generation 1787 --
#   Min 0.08805697933786115
# --- 344.08979654312134 s seconds to perform iteration number: 1787 ---
# -- Generation 1788 --
#   Min 0.08805697933786115
# --- 342.78030490875244 s seconds to perform iteration number: 1788 ---
# -- Generation 1789 --
#   Min 0.08805697933786115
# --- 383.8189642429352 s seconds to perform iteration number: 1789 ---
# -- Generation 1790 --
#   Min 0.08805697933786115
# --- 341.58136558532715 s seconds to perform iteration number: 1790 ---
# -- Generation 1791 --
#   Min 0.08805697933786115
# --- 384.13374853134155 s seconds to perform iteration number: 1791 ---
# -- Generation 1792 --
#   Min 0.08805697933786115
# --- 345.0062053203583 s seconds to perform iteration number: 1792 ---
# -- Generation 1793 --
#   Min 0.08805697933786115
# --- 341.94893074035645 s seconds to perform iteration number: 1793 ---
# -- Generation 1794 --
#   Min 0.08805697933786115
# --- 383.2532398700714 s seconds to perform iteration number: 1794 ---
# -- Generation 1795 --
#   Min 0.08805697933786115
# --- 345.1669318675995 s seconds to perform iteration number: 1795 ---
# -- Generation 1796 --
#   Min 0.08805697933786115
# --- 343.3459270000458 s seconds to perform iteration number: 1796 ---
# -- Generation 1797 --
#   Min 0.08805697933786115
# --- 385.9138135910034 s seconds to perform iteration number: 1797 ---
# -- Generation 1798 --
#   Min 0.08805697933786115
# --- 344.7162947654724 s seconds to perform iteration number: 1798 ---
# -- Generation 1799 --
#   Min 0.08805697933786115
# --- 343.34386229515076 s seconds to perform iteration number: 1799 ---
# -- Generation 1800 --
#   Min 0.08805697933786115
# Successfully created the directory ./results/fobjQuadraticError/iteration1800
# -----------------------------------------------------------------------------------------
# Guardamos valores
# -----------------------------------------------------------------------------------------
# --- 346.54379439353943 s seconds to perform iteration number: 1800 ---
# -- Generation 1801 --
#   Min 0.08805697933786115
# --- 383.20285272598267 s seconds to perform iteration number: 1801 ---
# -- Generation 1802 --
#   Min 0.08805697933786115
# --- 341.42484307289124 s seconds to perform iteration number: 1802 ---
# -- Generation 1803 --
#   Min 0.08805697933786115
# --- 342.34151697158813 s seconds to perform iteration number: 1803 ---
# -- Generation 1804 --
#   Min 0.08805697933786115
# --- 342.85098123550415 s seconds to perform iteration number: 1804 ---
# -- Generation 1805 --
#   Min 0.08805697933786115
# --- 342.01892161369324 s seconds to perform iteration number: 1805 ---
# -- Generation 1806 --
#   Min 0.08805697933786115
# --- 344.9796721935272 s seconds to perform iteration number: 1806 ---
# -- Generation 1807 --
#   Min 0.08805697933786115
# --- 341.86709332466125 s seconds to perform iteration number: 1807 ---
# -- Generation 1808 --
#   Min 0.08805697933786115
# --- 383.93865489959717 s seconds to perform iteration number: 1808 ---
# -- Generation 1809 --
#   Min 0.08805697933786115
# --- 344.21311807632446 s seconds to perform iteration number: 1809 ---
# -- Generation 1810 --
#   Min 0.08805697933786115
# --- 341.8620150089264 s seconds to perform iteration number: 1810 ---
# -- Generation 1811 --
#   Min 0.08805697933786115
# --- 381.9929578304291 s seconds to perform iteration number: 1811 ---
# -- Generation 1812 --
#   Min 0.08805697933786115
# --- 344.8787932395935 s seconds to perform iteration number: 1812 ---
# -- Generation 1813 --
#   Min 0.08805697933786115
# --- 342.57779264450073 s seconds to perform iteration number: 1813 ---
# -- Generation 1814 --
#   Min 0.08805697933786115
# --- 383.1352744102478 s seconds to perform iteration number: 1814 ---
# -- Generation 1815 --
#   Min 0.08805697933786115
# --- 343.9681730270386 s seconds to perform iteration number: 1815 ---
# -- Generation 1816 --
#   Min 0.08805697933786115
# --- 342.540367603302 s seconds to perform iteration number: 1816 ---
# -- Generation 1817 --
#   Min 0.08805697933786115
# --- 343.2785186767578 s seconds to perform iteration number: 1817 ---
# -- Generation 1818 --
#   Min 0.08805697933786115
# --- 387.23839378356934 s seconds to perform iteration number: 1818 ---
# -- Generation 1819 --
#   Min 0.08805697933786115
# --- 384.5717258453369 s seconds to perform iteration number: 1819 ---
# -- Generation 1820 --
#   Min 0.08805697933786115
# --- 343.87024784088135 s seconds to perform iteration number: 1820 ---
# -- Generation 1821 --
#   Min 0.08778950718298299
# --- 344.4278476238251 s seconds to perform iteration number: 1821 ---
# -- Generation 1822 --
#   Min 0.08778950718298299
# --- 347.6640512943268 s seconds to perform iteration number: 1822 ---
# -- Generation 1823 --
#   Min 0.08778950718298299
# --- 343.753958940506 s seconds to perform iteration number: 1823 ---
# -- Generation 1824 --
#   Min 0.08778950718298299
# --- 344.19299817085266 s seconds to perform iteration number: 1824 ---
# -- Generation 1825 --
#   Min 0.08778950718298299
# --- 386.6241295337677 s seconds to perform iteration number: 1825 ---
# -- Generation 1826 --
#   Min 0.08697543963403163
# --- 384.11191034317017 s seconds to perform iteration number: 1826 ---
# -- Generation 1827 --
#   Min 0.0866283093142968
# --- 346.05430817604065 s seconds to perform iteration number: 1827 ---
# -- Generation 1828 --
#   Min 0.0866283093142968
# --- 344.00320386886597 s seconds to perform iteration number: 1828 ---
# -- Generation 1829 --
#   Min 0.0866283093142968
# --- 342.07431054115295 s seconds to perform iteration number: 1829 ---
# -- Generation 1830 --
#   Min 0.0866283093142968
# --- 383.5372920036316 s seconds to perform iteration number: 1830 ---
# -- Generation 1831 --
#   Min 0.0866283093142968
# --- 343.81527042388916 s seconds to perform iteration number: 1831 ---
# -- Generation 1832 --
#   Min 0.0858468792331888
# --- 385.35280990600586 s seconds to perform iteration number: 1832 ---
# -- Generation 1833 --
#   Min 0.08580049954027899
# --- 348.26966166496277 s seconds to perform iteration number: 1833 ---
# -- Generation 1834 --
#   Min 0.08571850714257678
# --- 344.94682812690735 s seconds to perform iteration number: 1834 ---
# -- Generation 1835 --
#   Min 0.08571850714257678
# --- 384.03245520591736 s seconds to perform iteration number: 1835 ---
# -- Generation 1836 --
#   Min 0.08571850714257678
# --- 384.28577876091003 s seconds to perform iteration number: 1836 ---
# -- Generation 1837 --
#   Min 0.08571850714257678
# --- 345.1033709049225 s seconds to perform iteration number: 1837 ---
# -- Generation 1838 --

# %%
# Last iteration saved
g = 1800

# %%
if __name__ == "__main__":
    
    CLUSTER_DIM = 7 * NUM_CLUSTERS

    creator.create("FitnessMin", base.Fitness, weights=(-1.0,))
    creator.create("Individual", list, fitness=creator.FitnessMin)

    toolbox = base.Toolbox()

    toolbox.register("attr_flt", random.uniform, 0, 1)
    toolbox.register("individual", tools.initRepeat, creator.Individual, toolbox.attr_flt,n=CLUSTER_DIM)

    toolbox.register("population", tools.initRepeat, list, toolbox.individual)


    def customMutate(ind, indpb):
        for i in range(len(ind)):
            if random.random() < indpb:
                ind[i] = random.random()
        return ind


    def evalfobj(individual):
        return fobjQuadraticError(individual)

    def evalfobjInertia(individual):
        return fobjInertia(individual) 


    toolbox.register("mate", tools.cxTwoPoint)
    toolbox.register("mutate", customMutate, indpb = 0.05)

    toolbox.register("select", tools.selTournament, tournsize=30)
    
    toolbox.register("evaluate", evalfobj)
    
    pool = multiprocessing.Pool(processes = 4)
    toolbox.register('map', pool.map)
    
    numberInd = 150
    
    # MAIN GENETIC ALGORITHM
    random.seed(169)
    min_iterations = []
    max_iterations = []
    avg_iterations = []
    std_iterations = []
    ind_iterations = []
    
    CXPB, MUTPB = 0.8, 0.2
    
    # ----------------------------------------------------------------------------------------------------------------------------------------------------------------
    pop = joblib.load("results/fobjQuadraticError/iteration{}/last_pop{}.pkl".format(g, g))
    # ----------------------------------------------------------------------------------------------------------------------------------------------------------------

    
    fitnesses = list(toolbox.map(toolbox.evaluate, pop))
    for ind, fit in zip(pop, fitnesses):
        ind.fitness.values = fit 
        
    fits = [ind.fitness.values[0] for ind in pop] 
    
    t = 0
    
    # Begin the evolution
    while g < 4000:
 
        start_time = time()
    
        # A new generation
        g = g + 1
        print("-- Generation %i --" % g)

        offspring = toolbox.select(pop, len(pop))

        offspring = list(map(toolbox.clone, offspring))

        for child1, child2 in zip(offspring[::2], offspring[1::2]): #DE los padres, creas 2 hijos con mate
            if random.random() < CXPB:
                toolbox.mate(child1, child2)
                del child1.fitness.values 
                del child2.fitness.values 
                
        for mutant in offspring:
            if random.random() < MUTPB:
                toolbox.mutate(mutant)
                del mutant.fitness.values  

        invalid_ind = [ind for ind in offspring if not ind.fitness.valid]
        fitnesses = toolbox.map(toolbox.evaluate, invalid_ind)
            
        for ind, fit in zip(invalid_ind, fitnesses):
            ind.fitness.values = fit
                        
        fit_maxi = 100000000000000000000
        individ = []
        for ind in pop:
            if (ind.fitness.values[0]<fit_maxi):
                fit_maxi = ind.fitness.values[0]
                individ = ind

        pop[:] = offspring

        
        fits = [ind.fitness.values[0] for ind in pop]
            
        length = len(pop)
        mean = sum(fits) / length
        sum2 = sum(x*x for x in fits)
        std = abs(sum2 / length - mean**2)**0.5
        print("  Min %s" % min(fits))
  
        
        min_iterations.append(min(fits))
        max_iterations.append(max(fits))
        avg_iterations.append(mean)
        std_iterations.append(std)
        ind_iterations.append(individ)
        
        if (g % 200 == 0):
            path = "./results/fobjQuadraticError/iteration{}".format(g)
            try:
                if not os.path.isdir(path):
                    os.makedirs(path)
            except OSError:
                print ("Creation of the directory %s failed" % path)
            else:
                print ("Successfully created the directory %s " % path)
        
            print("-----------------------------------------------------------------------------------------")
            print("Guardamos valores")
            joblib.dump(min_iterations, "results/fobjQuadraticError/iteration{}/best_gen_fitness_iter{}.pkl".format(g, g))
            joblib.dump(max_iterations, "results/fobjQuadraticError/iteration{}/worst_gen_fitness_iter{}.pkl".format(g, g))
            joblib.dump(avg_iterations, "results/fobjQuadraticError/iteration{}/mean_gen_fitness_iter{}.pkl".format(g, g))
            joblib.dump(std_iterations, "results/fobjQuadraticError/iteration{}/std_gen_fitness_iter{}.pkl".format(g, g))
            joblib.dump(ind_iterations, "results/fobjQuadraticError/iteration{}/best_gen_individuals_iter{}.pkl".format(g, g))
            joblib.dump(pop[:], "results/fobjQuadraticError/iteration{}/last_pop{}.pkl".format(g, g))

            print('-----------------------------------------------------------------------------------------')

        print("--- {} s seconds to perform iteration number: {} ---".format((time() - start_time), g))
            
    #best = pop[np.argmin([toolbox.evaluate(x) for x in pop])]
    final_pop = pop[:]
    
    joblib.dump(min_iterations, "results/fobjQuadraticError/best_gen_fitness_iter{}.pkl".format(4000))
    joblib.dump(max_iterations, "results/fobjQuadraticError/worst_gen_fitness_iter{}.pkl".format(4000))
    joblib.dump(avg_iterations, "results/fobjQuadraticError/mean_gen_fitness_iter{}.pkl".format(4000))
    joblib.dump(std_iterations, "results/fobjQuadraticError/std_gen_fitness_iter{}.pkl".format(4000))
    joblib.dump(ind_iterations, "results/fobjQuadraticError/best_gen_individuals_iter{}.pkl".format(4000))
    joblib.dump(final_pop, "results/fobjQuadraticError/final_pop_iter{}.pkl".format(4000))
# Out:
# -- Generation 1801 --
#   Min 0.08805697933786115
# --- 357.639821767807 s seconds to perform iteration number: 1801 ---
# -- Generation 1802 --
#   Min 0.08805697933786115
# --- 399.5424904823303 s seconds to perform iteration number: 1802 ---
# -- Generation 1803 --
#   Min 0.08805697933786115
# --- 355.938453912735 s seconds to perform iteration number: 1803 ---
# -- Generation 1804 --
#   Min 0.08805697933786115
# --- 351.7446894645691 s seconds to perform iteration number: 1804 ---
# -- Generation 1805 --
#   Min 0.08805697933786115
# --- 355.6586151123047 s seconds to perform iteration number: 1805 ---
# -- Generation 1806 --
#   Min 0.08805697933786115
# --- 357.7503981590271 s seconds to perform iteration number: 1806 ---
# -- Generation 1807 --
#   Min 0.08805697933786115
# --- 355.68826270103455 s seconds to perform iteration number: 1807 ---
# -- Generation 1808 --
#   Min 0.08805697933786115
# --- 399.0840301513672 s seconds to perform iteration number: 1808 ---
# -- Generation 1809 --
#   Min 0.08805697933786115
# --- 359.5072772502899 s seconds to perform iteration number: 1809 ---
# -- Generation 1810 --
#   Min 0.08805697933786115
# --- 355.00856614112854 s seconds to perform iteration number: 1810 ---
# -- Generation 1811 --
#   Min 0.08805697933786115
# --- 353.6248047351837 s seconds to perform iteration number: 1811 ---
# -- Generation 1812 --
#   Min 0.08805697933786115
# --- 352.0891876220703 s seconds to perform iteration number: 1812 ---
# -- Generation 1813 --
#   Min 0.08805697933786115
# --- 396.78051137924194 s seconds to perform iteration number: 1813 ---
# -- Generation 1814 --
#   Min 0.08805697933786115
# --- 395.5889115333557 s seconds to perform iteration number: 1814 ---
# -- Generation 1815 --
#   Min 0.08805697933786115
# --- 356.86711382865906 s seconds to perform iteration number: 1815 ---
# -- Generation 1816 --
#   Min 0.08805697933786115
# --- 357.2368004322052 s seconds to perform iteration number: 1816 ---
# -- Generation 1817 --
# Process ForkPoolWorker-1:
# Process ForkPoolWorker-2:
# Process ForkPoolWorker-4:
# Traceback (most recent call last):
# Process ForkPoolWorker-3:
# Traceback (most recent call last):
# Traceback (most recent call last):
#   File "/home/alex/anaconda3/lib/python3.7/multiprocessing/process.py", line 297, in _bootstrap
#     self.run()
#   File "/home/alex/anaconda3/lib/python3.7/multiprocessing/process.py", line 297, in _bootstrap
#     self.run()
#   File "/home/alex/anaconda3/lib/python3.7/multiprocessing/process.py", line 99, in run
#     self._target(*self._args, **self._kwargs)
# Traceback (most recent call last):
#   File "/home/alex/anaconda3/lib/python3.7/multiprocessing/process.py", line 297, in _bootstrap
#     self.run()
#   File "/home/alex/anaconda3/lib/python3.7/multiprocessing/process.py", line 99, in run
#     self._target(*self._args, **self._kwargs)
#   File "/home/alex/anaconda3/lib/python3.7/multiprocessing/pool.py", line 121, in worker
#     result = (True, func(*args, **kwds))
#   File "/home/alex/anaconda3/lib/python3.7/multiprocessing/process.py", line 297, in _bootstrap
#     self.run()
#   File "/home/alex/anaconda3/lib/python3.7/multiprocessing/pool.py", line 44, in mapstar
#     return list(map(*args))
#   File "/home/alex/anaconda3/lib/python3.7/multiprocessing/process.py", line 99, in run
#     self._target(*self._args, **self._kwargs)
#   File "<ipython-input-9-8382b2c8d47b>", line 24, in evalfobj
#     return fobjQuadraticError(individual)
#   File "<ipython-input-6-cb37a6901673>", line 6, in fobjQuadraticError
#     counter_documents, euclidean_dist_2 = auxiliarFunction(documents = matrix_algorithm, dimensions= k, number_topics = num_topics)
#   File "/home/alex/anaconda3/lib/python3.7/multiprocessing/pool.py", line 121, in worker
#     result = (True, func(*args, **kwds))
#   File "/home/alex/anaconda3/lib/python3.7/multiprocessing/pool.py", line 44, in mapstar
#     return list(map(*args))
#   File "<ipython-input-9-8382b2c8d47b>", line 24, in evalfobj
#     return fobjQuadraticError(individual)
#   File "/home/alex/anaconda3/lib/python3.7/multiprocessing/process.py", line 99, in run
#     self._target(*self._args, **self._kwargs)
#   File "<ipython-input-6-cb37a6901673>", line 6, in fobjQuadraticError
#     counter_documents, euclidean_dist_2 = auxiliarFunction(documents = matrix_algorithm, dimensions= k, number_topics = num_topics)
#   File "<ipython-input-5-4645ef4c969d>", line 11, in auxiliarFunction
#     distance_to_cluster.append(np.linalg.norm(document-dimensions[counter:counter+7]))
# KeyboardInterrupt
#   File "<ipython-input-5-4645ef4c969d>", line 11, in auxiliarFunction
#     distance_to_cluster.append(np.linalg.norm(document-dimensions[counter:counter+7]))
#   File "/home/alex/anaconda3/lib/python3.7/multiprocessing/pool.py", line 121, in worker
#     result = (True, func(*args, **kwds))
#   File "/home/alex/anaconda3/lib/python3.7/multiprocessing/pool.py", line 121, in worker
#     result = (True, func(*args, **kwds))
#   File "<__array_function__ internals>", line 6, in norm
#   File "/home/alex/anaconda3/lib/python3.7/multiprocessing/pool.py", line 44, in mapstar
#     return list(map(*args))
#   File "/home/alex/anaconda3/lib/python3.7/multiprocessing/pool.py", line 44, in mapstar
#     return list(map(*args))
#   File "<ipython-input-9-8382b2c8d47b>", line 24, in evalfobj
#     return fobjQuadraticError(individual)
#   File "<ipython-input-6-cb37a6901673>", line 6, in fobjQuadraticError
#     counter_documents, euclidean_dist_2 = auxiliarFunction(documents = matrix_algorithm, dimensions= k, number_topics = num_topics)
#   File "<ipython-input-5-4645ef4c969d>", line 11, in auxiliarFunction
#     distance_to_cluster.append(np.linalg.norm(document-dimensions[counter:counter+7]))
#   File "<__array_function__ internals>", line 6, in norm
#   File "/home/alex/anaconda3/lib/python3.7/site-packages/numpy/linalg/linalg.py", line 2530, in norm
#     sqnorm = dot(x, x)
#   File "<__array_function__ internals>", line 6, in dot
# KeyboardInterrupt
#   File "<ipython-input-9-8382b2c8d47b>", line 24, in evalfobj
#     return fobjQuadraticError(individual)
#   File "<ipython-input-6-cb37a6901673>", line 6, in fobjQuadraticError
#     counter_documents, euclidean_dist_2 = auxiliarFunction(documents = matrix_algorithm, dimensions= k, number_topics = num_topics)
#   File "<ipython-input-5-4645ef4c969d>", line 11, in auxiliarFunction
#     distance_to_cluster.append(np.linalg.norm(document-dimensions[counter:counter+7]))
#   File "<__array_function__ internals>", line 6, in norm
#   File "/home/alex/anaconda3/lib/python3.7/site-packages/numpy/linalg/linalg.py", line 2531, in norm
#     ret = sqrt(sqnorm)
# KeyboardInterrupt
#   File "/home/alex/anaconda3/lib/python3.7/site-packages/numpy/linalg/linalg.py", line 2530, in norm
#     sqnorm = dot(x, x)
#   File "<__array_function__ internals>", line 6, in dot
# KeyboardInterrupt
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-9-8382b2c8d47b> in <module>
#      88
#      89         invalid_ind = [ind for ind in offspring if not ind.fitness.valid]
# ---> 90         fitnesses = toolbox.map(toolbox.evaluate, invalid_ind)
#      91
#      92         for ind, fit in zip(invalid_ind, fitnesses):
#
# ~/anaconda3/lib/python3.7/multiprocessing/pool.py in map(self, func, iterable, chunksize)
#     266         in a list that is returned.
#     267         '''
# --> 268         return self._map_async(func, iterable, mapstar, chunksize).get()
#     269
#     270     def starmap(self, func, iterable, chunksize=None):
#
# ~/anaconda3/lib/python3.7/multiprocessing/pool.py in get(self, timeout)
#     649
#     650     def get(self, timeout=None):
# --> 651         self.wait(timeout)
#     652         if not self.ready():
#     653             raise TimeoutError
#
# ~/anaconda3/lib/python3.7/multiprocessing/pool.py in wait(self, timeout)
#     646
#     647     def wait(self, timeout=None):
# --> 648         self._event.wait(timeout)
#     649
#     650     def get(self, timeout=None):
#
# ~/anaconda3/lib/python3.7/threading.py in wait(self, timeout)
#     550             signaled = self._flag
#     551             if not signaled:
# --> 552                 signaled = self._cond.wait(timeout)
#     553             return signaled
#     554
#
# ~/anaconda3/lib/python3.7/threading.py in wait(self, timeout)
#     294         try:    # restore state no matter what (e.g., KeyboardInterrupt)
#     295             if timeout is None:
# --> 296                 waiter.acquire()
#     297                 gotit = True
#     298             else:
#
# KeyboardInterrupt:
# Process ForkPoolWorker-5:
# Process ForkPoolWorker-6:
# Traceback (most recent call last):
#   File "/home/alex/anaconda3/lib/python3.7/multiprocessing/process.py", line 297, in _bootstrap
#     self.run()
# Traceback (most recent call last):
#   File "/home/alex/anaconda3/lib/python3.7/multiprocessing/process.py", line 99, in run
#     self._target(*self._args, **self._kwargs)
#   File "/home/alex/anaconda3/lib/python3.7/multiprocessing/process.py", line 297, in _bootstrap
#     self.run()
#   File "/home/alex/anaconda3/lib/python3.7/multiprocessing/process.py", line 99, in run
#     self._target(*self._args, **self._kwargs)
#   File "/home/alex/anaconda3/lib/python3.7/multiprocessing/pool.py", line 121, in worker
#     result = (True, func(*args, **kwds))
#   File "/home/alex/anaconda3/lib/python3.7/multiprocessing/pool.py", line 44, in mapstar
#     return list(map(*args))
#   File "/home/alex/anaconda3/lib/python3.7/multiprocessing/pool.py", line 121, in worker
#     result = (True, func(*args, **kwds))
#   File "/home/alex/anaconda3/lib/python3.7/multiprocessing/pool.py", line 44, in mapstar
#     return list(map(*args))
#   File "<ipython-input-9-8382b2c8d47b>", line 24, in evalfobj
#     return fobjQuadraticError(individual)
#   File "<ipython-input-9-8382b2c8d47b>", line 24, in evalfobj
#     return fobjQuadraticError(individual)
#   File "<ipython-input-6-cb37a6901673>", line 6, in fobjQuadraticError
#     counter_documents, euclidean_dist_2 = auxiliarFunction(documents = matrix_algorithm, dimensions= k, number_topics = num_topics)
#   File "<ipython-input-5-4645ef4c969d>", line 11, in auxiliarFunction
#     distance_to_cluster.append(np.linalg.norm(document-dimensions[counter:counter+7]))
#   File "<__array_function__ internals>", line 6, in norm
#   File "/home/alex/anaconda3/lib/python3.7/site-packages/numpy/linalg/linalg.py", line 2526, in norm
#     x = x.ravel(order='K')
# KeyboardInterrupt
#   File "<ipython-input-6-cb37a6901673>", line 6, in fobjQuadraticError
#     counter_documents, euclidean_dist_2 = auxiliarFunction(documents = matrix_algorithm, dimensions= k, number_topics = num_topics)
#   File "<ipython-input-5-4645ef4c969d>", line 11, in auxiliarFunction
#     distance_to_cluster.append(np.linalg.norm(document-dimensions[counter:counter+7]))
# KeyboardInterrupt

# %%
import numpy as np
import matplotlib.pyplot as plt

import joblib

import random
from deap import base
from deap import creator
from deap import tools

from deap import algorithms
from time import time
import multiprocessing

import array
import random
import json

import os

import pandas as pd

# %%
matrix_np = joblib.load('matrix_np.pkl')

# %%
#reduced_matrix_np = joblib.load('reduced_matrix_np.pkl')

# %% [markdown]
# # Functions

# %% [markdown]
# # Modify parameters

# %%
matrix_algorithm = matrix_np
NUM_CLUSTERS = 7

# %% [markdown]
# # Distance to cluster functions

# %%
def auxiliarFunction(documents, dimensions, number_topics):

    counter_docs = [0 for x in range(0,number_topics)]
    
    distance_to_cluster_2 = [0 for x in range(0,number_topics)] # distances to cluster
    
    for document in documents: 
        distance_to_cluster = []   
        counter = 0
        for dim in range(0,number_topics): 
            distance_to_cluster.append(np.linalg.norm(document-dimensions[counter:counter+7]))
            counter = counter + 7
            
        best_distance_index = distance_to_cluster.index(min(distance_to_cluster)) 
        
        counter_docs[best_distance_index] += 1
    
        distance_to_cluster_2[best_distance_index] += pow(distance_to_cluster[best_distance_index], 2)
        
     
    return counter_docs, distance_to_cluster_2

# %% [markdown]
# ## Objetive function

# %%
def fobjQuadraticError(k):

    num_topics = int((len(k))/7)
    
    # 1º Number of documents to each cluster
    counter_documents, euclidean_dist_2 = auxiliarFunction(documents = matrix_algorithm, dimensions= k, number_topics = num_topics)
    
    bool_check = 0 in counter_documents    

   # 2º Fitness fuction
    if(bool_check):
        total_value = 5 # We give a high value to those clusters who do not have documents
        
    else:
        value1 = 0
        for i in range(0,num_topics): 
            value2 = euclidean_dist_2[i] 
            value1 += ((1/counter_documents[i])*value2)

        total_value = (value1 / num_topics) 

    return (total_value),

# %% [markdown]
# ## Objetive function with penalty factor

# %%
def fobjQuadraticErrorConst(k,Rfactor):

    num_topics = int((len(k))/7)
    const = [0 for x in range(0,num_topics)]
    # 1º Number of documents to each cluster
    counter_documents, euclidean_dist_2 = auxiliarFunction(documents = matrix_algorithm, dimensions= k, number_topics = num_topics)
    
    bool_check = 0 in counter_documents    

   # 2º Fitness fuction
    if(bool_check):
        total_value = 5000000000000000000000000 # We give a high value to those clusters who do not have documents
        
    else:
        value1 = 0
        for i in range(0,num_topics): #para cada uno de los clusters
            const.append(0)
            value2 = euclidean_dist_2[i] 
            value1 += ((1/counter_documents[i])*value2)
            for j in range(0,num_topics):
                const[i] += k[7*i+j]
            const[i] -= 1
            
        total_value = (value1 / num_topics)
        for i in range(0,num_topics):
            
            total_value += Rfactor*max(0,(abs(const[i])- 0.00000000001))**2
            
    return (total_value),

# %% [markdown]
# # Genetic Algorithm

# %% [markdown]
# ## Folders

# %%
path = "./results/fobjQuadraticError"
try:
    if not os.path.isdir(path):
        os.makedirs(path)
except OSError:
    print ("Creation of the directory %s failed" % path)
else:
    print ("Successfully created the directory %s " % path)
# Out:
# Successfully created the directory ./results/fobjQuadraticError

# %% [markdown]
# ## Genetic process and save results

# %%
if __name__ == "__main__":
    
    CLUSTER_DIM = 7 * NUM_CLUSTERS
    creator.create("FitnessMin", base.Fitness, weights=(-1.0,))
    creator.create("Individual", list, fitness=creator.FitnessMin)

    toolbox = base.Toolbox()

    toolbox.register("attr_flt", random.uniform, 0, 1)
    toolbox.register("individual", tools.initRepeat, creator.Individual, toolbox.attr_flt,n=CLUSTER_DIM)

    toolbox.register("population", tools.initRepeat, list, toolbox.individual)

    def customMutate(ind, indpb):
        for i in range(len(ind)):
            if random.random() < indpb:
                ind[i] = random.random()
        return ind


    def evalfobjConst(individual,Rfactor):
        return fobjQuadraticErrorConst(individual,Rfactor) 


    toolbox.register("mate", tools.cxTwoPoint)
    toolbox.register("mutate", customMutate, indpb = 0.1)

    toolbox.register("select", tools.selTournament, tournsize=20)
    
    toolbox.register("evaluate", evalfobjConst, Rfactor=0)
    
    pool = multiprocessing.Pool(processes = 25)
    toolbox.register('map', pool.map)
    
    numberInd = 100
    
    
    
    # MAIN GENETIC ALGORITHM
    random.seed(169)
    min_iterations = []
    max_iterations = []
    avg_iterations = []
    std_iterations = []
    ind_iterations = []
    R_values = []
    
    CXPB, MUTPB = 0.8, 0.35
    
    pop = toolbox.population(n=numberInd)
    fitnesses = list(toolbox.map(toolbox.evaluate, pop))
    for ind, fit in zip(pop, fitnesses):
        ind.fitness.values = fit 
        
    fits = [ind.fitness.values[0] for ind in pop] 
    
    g = 0
    # Begin the evolution
    while g < 10000:
        current_Rfactor = (0.005*g)**2 #Penalty Rfactor
        toolbox.register("evaluate", evalfobjConst, Rfactor=current_Rfactor) #Penalty Rfactor
 
        
        start_time = time()
    
        # A new generation
        g = g + 1
        print("-- Generation %i --" % g)

        offspring = toolbox.select(pop, len(pop))

        offspring = list(map(toolbox.clone, offspring))

        for child1, child2 in zip(offspring[::2], offspring[1::2]): 
            if random.random() < CXPB:
                toolbox.mate(child1, child2)
                del child1.fitness.values 
                del child2.fitness.values 
                
        for mutant in offspring:
            if random.random() < MUTPB:
                toolbox.mutate(mutant)
                del mutant.fitness.values  

        invalid_ind = [ind for ind in offspring]
        fitnesses = toolbox.map(toolbox.evaluate, invalid_ind)
            
        for ind, fit in zip(invalid_ind, fitnesses):
            ind.fitness.values = fit
                        
    
        pop[:] = offspring

        
        fits = [ind.fitness.values[0] for ind in pop]
        
        fit_maxi = 100000000000000000000
        individ = []
        
        for ind in pop:
            if (ind.fitness.values[0]<fit_maxi):
                fit_maxi = ind.fitness.values[0]
                individ = ind
            
        length = len(pop)
        mean = sum(fits) / length
        sum2 = sum(x*x for x in fits)
        std = abs(sum2 / length - mean**2)**0.5
        print("  FobjModificada %s" % min(fits))
  
        
        min_iterations.append(min(fits))
        max_iterations.append(max(fits))
        avg_iterations.append(mean)
        std_iterations.append(std)
        ind_iterations.append(individ)
        R_values.append(current_Rfactor)
        
        if (g % 100 == 0):
            print("FobjReal {}".format(fobjQuadraticError(individ)))
            print(individ)
            path = "./results/fobjQuadraticError/iteration{}".format(g)
            try:
                if not os.path.isdir(path):
                    os.makedirs(path)
            except OSError:
                print ("Creation of the directory %s failed" % path)
            else:
                print ("Successfully created the directory %s " % path)
        
            print("-----------------------------------------------------------------------------------------")
            print("Guardamos valores")
            joblib.dump(min_iterations, "results/fobjQuadraticError/iteration{}/best_gen_fitness_iter{}.pkl".format(g, g))
            joblib.dump(max_iterations, "results/fobjQuadraticError/iteration{}/worst_gen_fitness_iter{}.pkl".format(g, g))
            joblib.dump(avg_iterations, "results/fobjQuadraticError/iteration{}/mean_gen_fitness_iter{}.pkl".format(g, g))
            joblib.dump(std_iterations, "results/fobjQuadraticError/iteration{}/std_gen_fitness_iter{}.pkl".format(g, g))
            joblib.dump(ind_iterations, "results/fobjQuadraticError/iteration{}/best_gen_individuals_iter{}.pkl".format(g, g))
            joblib.dump(pop[:], "results/fobjQuadraticError/iteration{}/last_pop{}.pkl".format(g, g))
            joblib.dump(R_values, "results/fobjQuadraticError/iteration{}/R_values{}.pkl".format(g, g))

            print('-----------------------------------------------------------------------------------------')

        print("--- {} s seconds to perform iteration number: {} ---".format((time() - start_time), g))
            
    #best = pop[np.argmin([toolbox.evaluate(x) for x in pop])]
    final_pop = pop[:]
    
    joblib.dump(min_iterations, "results/fobjQuadraticError/best_gen_fitness_iter{}.pkl".format(10000))
    joblib.dump(max_iterations, "results/fobjQuadraticError/worst_gen_fitness_iter{}.pkl".format(10000))
    joblib.dump(avg_iterations, "results/fobjQuadraticError/mean_gen_fitness_iter{}.pkl".format(10000))
    joblib.dump(std_iterations, "results/fobjQuadraticError/std_gen_fitness_iter{}.pkl".format(10000))
    joblib.dump(ind_iterations, "results/fobjQuadraticError/best_gen_individuals_iter{}.pkl".format(10000))
    joblib.dump(final_pop, "results/fobjQuadraticError/final_pop_iter{}.pkl".format(10000))
# Out:
# -- Generation 1 --
#   FobjModificada 1.607416999128839
# --- 124.64128232002258 s seconds to perform iteration number: 1 ---
# -- Generation 2 --
#   FobjModificada 1.386604021298699
# --- 124.75251150131226 s seconds to perform iteration number: 2 ---
# -- Generation 3 --
#   FobjModificada 1.3859513099769543
# --- 125.25821542739868 s seconds to perform iteration number: 3 ---
# -- Generation 4 --
#   FobjModificada 1.230576328811492
# --- 127.95676159858704 s seconds to perform iteration number: 4 ---
# -- Generation 5 --
#   FobjModificada 1.2373716896078244
# --- 125.64879488945007 s seconds to perform iteration number: 5 ---
# -- Generation 6 --
#   FobjModificada 1.2096294074689973
# --- 125.04844641685486 s seconds to perform iteration number: 6 ---
# -- Generation 7 --
#   FobjModificada 1.0730889767261809
# --- 125.57368540763855 s seconds to perform iteration number: 7 ---
# -- Generation 8 --
#   FobjModificada 1.0070281112687074
# --- 124.95376324653625 s seconds to perform iteration number: 8 ---
# -- Generation 9 --
#   FobjModificada 0.9238925849642264
# --- 124.67977404594421 s seconds to perform iteration number: 9 ---
# -- Generation 10 --
#   FobjModificada 0.8980886771762193
# --- 125.23597621917725 s seconds to perform iteration number: 10 ---
# -- Generation 11 --
#   FobjModificada 0.8661858989629375
# --- 125.55834436416626 s seconds to perform iteration number: 11 ---
# -- Generation 12 --
#   FobjModificada 0.7975016238817524
# --- 127.23104000091553 s seconds to perform iteration number: 12 ---
# -- Generation 13 --
#   FobjModificada 0.716211195029978
# --- 125.01394033432007 s seconds to perform iteration number: 13 ---
# -- Generation 14 --
#   FobjModificada 0.6135177255230762
# --- 125.42423677444458 s seconds to perform iteration number: 14 ---
# -- Generation 15 --
#   FobjModificada 0.5553150102034505
# --- 125.70672869682312 s seconds to perform iteration number: 15 ---
# -- Generation 16 --
#   FobjModificada 0.5632043904230547
# --- 125.30474829673767 s seconds to perform iteration number: 16 ---
# -- Generation 17 --
#   FobjModificada 0.47433667566500753
# --- 125.85761952400208 s seconds to perform iteration number: 17 ---
# -- Generation 18 --
#   FobjModificada 0.43678993478540323
# --- 126.4531614780426 s seconds to perform iteration number: 18 ---
# -- Generation 19 --
#   FobjModificada 0.38997632342683974
# --- 125.96448111534119 s seconds to perform iteration number: 19 ---
# -- Generation 20 --
#   FobjModificada 0.36740378822542663
# --- 126.426504611969 s seconds to perform iteration number: 20 ---
# -- Generation 21 --
#   FobjModificada 0.34181340171569197
# --- 125.80769300460815 s seconds to perform iteration number: 21 ---
# -- Generation 22 --
#   FobjModificada 0.34717088375898947
# --- 125.23734307289124 s seconds to perform iteration number: 22 ---
# -- Generation 23 --
#   FobjModificada 0.3445059270291113
# --- 125.99492359161377 s seconds to perform iteration number: 23 ---
# -- Generation 24 --
#   FobjModificada 0.3275595411836705
# --- 125.33982634544373 s seconds to perform iteration number: 24 ---
# -- Generation 25 --
#   FobjModificada 0.3155994394533574
# --- 125.48581862449646 s seconds to perform iteration number: 25 ---
# -- Generation 26 --
#   FobjModificada 0.29190891152832427
# --- 124.88437032699585 s seconds to perform iteration number: 26 ---
# -- Generation 27 --
#   FobjModificada 0.28315452582888717
# --- 125.37180614471436 s seconds to perform iteration number: 27 ---
# -- Generation 28 --
#   FobjModificada 0.2825048156654051
# --- 125.93313193321228 s seconds to perform iteration number: 28 ---
# -- Generation 29 --
#   FobjModificada 0.27998860609679166
# --- 124.81050205230713 s seconds to perform iteration number: 29 ---
# -- Generation 30 --
#   FobjModificada 0.2736623508137826
# --- 125.71710729598999 s seconds to perform iteration number: 30 ---
# -- Generation 31 --
#   FobjModificada 0.2618255124082113
# --- 126.94283771514893 s seconds to perform iteration number: 31 ---
# -- Generation 32 --
#   FobjModificada 0.2548322819088849
# --- 124.86581349372864 s seconds to perform iteration number: 32 ---
# -- Generation 33 --
#   FobjModificada 0.25316268362394007
# --- 125.37222456932068 s seconds to perform iteration number: 33 ---
# -- Generation 34 --
#   FobjModificada 0.2345433059470774
# --- 126.53480243682861 s seconds to perform iteration number: 34 ---
# -- Generation 35 --
#   FobjModificada 0.2270976744798647
# --- 127.68382930755615 s seconds to perform iteration number: 35 ---
# -- Generation 36 --
#   FobjModificada 0.20629896952149424
# --- 126.43271160125732 s seconds to perform iteration number: 36 ---
# -- Generation 37 --
#   FobjModificada 0.19796124192113526
# --- 125.34293365478516 s seconds to perform iteration number: 37 ---
# -- Generation 38 --
#   FobjModificada 0.19540794585236906
# --- 125.49540305137634 s seconds to perform iteration number: 38 ---
# -- Generation 39 --
#   FobjModificada 0.1966067023491638
# --- 126.04460430145264 s seconds to perform iteration number: 39 ---
# -- Generation 40 --
#   FobjModificada 0.19326169168191074
# --- 125.46404027938843 s seconds to perform iteration number: 40 ---
# -- Generation 41 --
#   FobjModificada 0.19318300908348848
# --- 126.53214073181152 s seconds to perform iteration number: 41 ---
# -- Generation 42 --
#   FobjModificada 0.194417239791637
# --- 124.44239258766174 s seconds to perform iteration number: 42 ---
# -- Generation 43 --
#   FobjModificada 0.1956819453320855
# --- 126.85517501831055 s seconds to perform iteration number: 43 ---
# -- Generation 44 --
#   FobjModificada 0.19464216872530832
# --- 126.07381439208984 s seconds to perform iteration number: 44 ---
# -- Generation 45 --
#   FobjModificada 0.1948323152442533
# --- 127.43384766578674 s seconds to perform iteration number: 45 ---
# -- Generation 46 --
#   FobjModificada 0.1817093941050006
# --- 125.1515440940857 s seconds to perform iteration number: 46 ---
# -- Generation 47 --
#   FobjModificada 0.18269272819864227
# --- 126.41941499710083 s seconds to perform iteration number: 47 ---
# -- Generation 48 --
#   FobjModificada 0.18369767403060586
# --- 125.65136861801147 s seconds to perform iteration number: 48 ---
# -- Generation 49 --
#   FobjModificada 0.18472423160089113
# --- 125.21651029586792 s seconds to perform iteration number: 49 ---
# -- Generation 50 --
#   FobjModificada 0.18336109811512163
# --- 126.97725009918213 s seconds to perform iteration number: 50 ---
# -- Generation 51 --
#   FobjModificada 0.182702668887853
# --- 126.07599997520447 s seconds to perform iteration number: 51 ---
# -- Generation 52 --
#   FobjModificada 0.1702497632234237
# --- 125.53792333602905 s seconds to perform iteration number: 52 ---
# -- Generation 53 --
#   FobjModificada 0.16441174586584686
# --- 125.23553442955017 s seconds to perform iteration number: 53 ---
# -- Generation 54 --
#   FobjModificada 0.16495958247489176
# --- 126.33376812934875 s seconds to perform iteration number: 54 ---
# -- Generation 55 --
#   FobjModificada 0.15694431629485542
# --- 124.68277311325073 s seconds to perform iteration number: 55 ---
# -- Generation 56 --
#   FobjModificada 0.1534227023432658
# --- 125.3553237915039 s seconds to perform iteration number: 56 ---
# -- Generation 57 --
#   FobjModificada 0.1477618306087978
# --- 127.57214832305908 s seconds to perform iteration number: 57 ---
# -- Generation 58 --
#   FobjModificada 0.14806793620361686
# --- 126.77910304069519 s seconds to perform iteration number: 58 ---
# -- Generation 59 --
#   FobjModificada 0.14837945959657428
# --- 124.35623860359192 s seconds to perform iteration number: 59 ---
# -- Generation 60 --
#   FobjModificada 0.14869640078767007
# --- 125.7480685710907 s seconds to perform iteration number: 60 ---
# -- Generation 61 --
#   FobjModificada 0.14901875977690426
# --- 125.76800799369812 s seconds to perform iteration number: 61 ---
# -- Generation 62 --
#   FobjModificada 0.1493465365642769
# --- 126.23967218399048 s seconds to perform iteration number: 62 ---
# -- Generation 63 --
#   FobjModificada 0.1496797311497879
# --- 125.12521529197693 s seconds to perform iteration number: 63 ---
# -- Generation 64 --
#   FobjModificada 0.15001834353343727
# --- 124.80762648582458 s seconds to perform iteration number: 64 ---
# -- Generation 65 --
#   FobjModificada 0.15036237371522504
# --- 127.1718065738678 s seconds to perform iteration number: 65 ---
# -- Generation 66 --
#   FobjModificada 0.15071182169515118
# --- 124.99980664253235 s seconds to perform iteration number: 66 ---
# -- Generation 67 --
#   FobjModificada 0.1510666874732158
# --- 126.27979683876038 s seconds to perform iteration number: 67 ---
# -- Generation 68 --
#   FobjModificada 0.1514269710494187
# --- 127.42719912528992 s seconds to perform iteration number: 68 ---
# -- Generation 69 --
#   FobjModificada 0.1503816678020439
# --- 125.40744853019714 s seconds to perform iteration number: 69 ---
# -- Generation 70 --
#   FobjModificada 0.15080092642519233
# --- 126.95081448554993 s seconds to perform iteration number: 70 ---
# -- Generation 71 --
#   FobjModificada 0.15122630561218237
# --- 125.34809350967407 s seconds to perform iteration number: 71 ---
# -- Generation 72 --
#   FobjModificada 0.15165780536301396
# --- 125.73993134498596 s seconds to perform iteration number: 72 ---
# -- Generation 73 --
#   FobjModificada 0.15209542567768716
# --- 124.80577564239502 s seconds to perform iteration number: 73 ---
# -- Generation 74 --
#   FobjModificada 0.15253916655620195
# --- 126.69781041145325 s seconds to perform iteration number: 74 ---
# -- Generation 75 --
#   FobjModificada 0.15298902799855837
# --- 128.04837203025818 s seconds to perform iteration number: 75 ---
# -- Generation 76 --
#   FobjModificada 0.15289599262738499
# --- 126.34267354011536 s seconds to perform iteration number: 76 ---
# -- Generation 77 --
#   FobjModificada 0.15298725563743806
# --- 126.02354383468628 s seconds to perform iteration number: 77 ---
# -- Generation 78 --
#   FobjModificada 0.15340520944282232
# --- 125.94863653182983 s seconds to perform iteration number: 78 ---
# -- Generation 79 --
#   FobjModificada 0.15382862669664293
# --- 125.19351768493652 s seconds to perform iteration number: 79 ---
# -- Generation 80 --
#   FobjModificada 0.15425750739889998
# --- 126.44106459617615 s seconds to perform iteration number: 80 ---
# -- Generation 81 --
#   FobjModificada 0.15469185154959345
# --- 126.13552784919739 s seconds to perform iteration number: 81 ---
# -- Generation 82 --
#   FobjModificada 0.15513165914872326
# --- 126.62166905403137 s seconds to perform iteration number: 82 ---
# -- Generation 83 --
#   FobjModificada 0.1555769301962895
# --- 124.47799897193909 s seconds to perform iteration number: 83 ---
# -- Generation 84 --
#   FobjModificada 0.15602766469229215
# --- 125.43986892700195 s seconds to perform iteration number: 84 ---
# -- Generation 85 --
#   FobjModificada 0.1564838626367311
# --- 125.21232295036316 s seconds to perform iteration number: 85 ---
# -- Generation 86 --
#   FobjModificada 0.15614822453744573
# --- 125.83085417747498 s seconds to perform iteration number: 86 ---
# -- Generation 87 --
#   FobjModificada 0.15664514196402796
# --- 128.28750681877136 s seconds to perform iteration number: 87 ---
# -- Generation 88 --
#   FobjModificada 0.15714787129033628
# --- 125.31662034988403 s seconds to perform iteration number: 88 ---
# -- Generation 89 --
#   FobjModificada 0.15647858917944082
# --- 125.7435245513916 s seconds to perform iteration number: 89 ---
# -- Generation 90 --
#   FobjModificada 0.15697103957731087
# --- 124.89743423461914 s seconds to perform iteration number: 90 ---
# -- Generation 91 --
#   FobjModificada 0.15746905438645628
# --- 124.36059975624084 s seconds to perform iteration number: 91 ---
# -- Generation 92 --
#   FobjModificada 0.15797263360687708
# --- 125.79678344726562 s seconds to perform iteration number: 92 ---
# -- Generation 93 --
#   FobjModificada 0.15848177723857318
# --- 125.2037467956543 s seconds to perform iteration number: 93 ---
# -- Generation 94 --
#   FobjModificada 0.1589964852815447
# --- 125.98978090286255 s seconds to perform iteration number: 94 ---
# -- Generation 95 --
#   FobjModificada 0.1564493407764696
# --- 126.73234939575195 s seconds to perform iteration number: 95 ---
# -- Generation 96 --
#   FobjModificada 0.15692200129191788
# --- 124.7382140159607 s seconds to perform iteration number: 96 ---
# -- Generation 97 --
#   FobjModificada 0.1573996635059424
# --- 126.90292143821716 s seconds to perform iteration number: 97 ---
# -- Generation 98 --
#   FobjModificada 0.157882327418543
# --- 124.89688920974731 s seconds to perform iteration number: 98 ---
# -- Generation 99 --
#   FobjModificada 0.15836999302971985
# --- 126.24139618873596 s seconds to perform iteration number: 99 ---
# -- Generation 100 --
#   FobjModificada 0.1588626603394728
# FobjReal (0.13435183646693985,)
# [0.02995747599180998, 0.046447982483862615, 0.17119075820982488, 0.06162511769163359, 0.3491573475826749, 0.10011034964000232, 0.21836437122573782, 0.11239605450825563, 0.13844304752557712, 0.2109275579378549, 0.07569218097379515, 0.07723504270988624, 0.2318304510476289, 0.44118104486429266, 0.06286493008844951, 0.14853410578233384, 0.1077178591379706, 0.31384824799779, 0.10887023893875647, 0.03441998183251005, 0.24789199515971982, 0.1931800911518552, 0.23724225980740887, 0.08845656034215799, 0.06143049011736412, 0.1293502477408527, 0.18659278020296166, 0.1089426901698155, 0.01576873502184728, 0.10561757253841919, 0.023801524161582543, 0.6336465566965671, 0.07727884168936017, 0.012571838997599283, 0.11319935678818305, 0.1217048718239162, 0.0013076746239722992, 0.45555175105926804, 0.06821696553583478, 0.065548109307775, 0.23083033990045587, 0.18142027975851693, 0.04624530602777477, 0.051367593887434504, 0.09623982727865121, 0.1405861846854336, 0.5659507886920198, 0.09571211220262488, 0.020188936004134073]
# Successfully created the directory ./results/fobjQuadraticError/iteration100
# -----------------------------------------------------------------------------------------
# Guardamos valores
# -----------------------------------------------------------------------------------------
# --- 146.25075483322144 s seconds to perform iteration number: 100 ---
# -- Generation 101 --
#   FobjModificada 0.15936032934780195
# --- 125.7439124584198 s seconds to perform iteration number: 101 ---
# -- Generation 102 --
#   FobjModificada 0.1598630000547073
# --- 124.93386840820312 s seconds to perform iteration number: 102 ---
# -- Generation 103 --
#   FobjModificada 0.1603706724601888
# --- 125.37737894058228 s seconds to perform iteration number: 103 ---
# -- Generation 104 --
#   FobjModificada 0.16088334656424647
# --- 125.90204572677612 s seconds to perform iteration number: 104 ---
# -- Generation 105 --
#   FobjModificada 0.16122349187720583
# --- 127.5406596660614 s seconds to perform iteration number: 105 ---
# -- Generation 106 --
#   FobjModificada 0.16175127786501442
# --- 124.85049080848694 s seconds to perform iteration number: 106 ---
# -- Generation 107 --
#   FobjModificada 0.16228411443643848
# --- 126.71273159980774 s seconds to perform iteration number: 107 ---
# -- Generation 108 --
#   FobjModificada 0.1628220015914779
# --- 125.19204688072205 s seconds to perform iteration number: 108 ---
# -- Generation 109 --
#   FobjModificada 0.16336493933013269
# --- 124.57778739929199 s seconds to perform iteration number: 109 ---
# -- Generation 110 --
#   FobjModificada 0.16391292765240295
# --- 125.07909822463989 s seconds to perform iteration number: 110 ---
# -- Generation 111 --
#   FobjModificada 0.16446596655828855
# --- 125.74555349349976 s seconds to perform iteration number: 111 ---
# -- Generation 112 --
#   FobjModificada 0.16502405604778952
# --- 125.14991688728333 s seconds to perform iteration number: 112 ---
# -- Generation 113 --
#   FobjModificada 0.16558719612090592
# --- 126.41705179214478 s seconds to perform iteration number: 113 ---
# -- Generation 114 --
#   FobjModificada 0.16615538677763772
# --- 126.71854329109192 s seconds to perform iteration number: 114 ---
# -- Generation 115 --
#   FobjModificada 0.16672862801798483
# --- 126.13956022262573 s seconds to perform iteration number: 115 ---
# -- Generation 116 --
#   FobjModificada 0.16730691984194745
# --- 124.87343859672546 s seconds to perform iteration number: 116 ---
# -- Generation 117 --
#   FobjModificada 0.16789026224952536
# --- 125.83599257469177 s seconds to perform iteration number: 117 ---
# -- Generation 118 --
#   FobjModificada 0.16847865524071878
# --- 125.87247514724731 s seconds to perform iteration number: 118 ---
# -- Generation 119 --
#   FobjModificada 0.1690720988155275
# --- 127.77394127845764 s seconds to perform iteration number: 119 ---
# -- Generation 120 --
#   FobjModificada 0.16967059297395168
# --- 125.10892939567566 s seconds to perform iteration number: 120 ---
# -- Generation 121 --
#   FobjModificada 0.17027413771599123
# --- 124.9836757183075 s seconds to perform iteration number: 121 ---
# -- Generation 122 --
#   FobjModificada 0.17088273304164614
# --- 125.134521484375 s seconds to perform iteration number: 122 ---
# -- Generation 123 --
#   FobjModificada 0.1714963789509165
# --- 124.44620060920715 s seconds to perform iteration number: 123 ---
# -- Generation 124 --
#   FobjModificada 0.17211507544380217
# --- 125.64709568023682 s seconds to perform iteration number: 124 ---
# -- Generation 125 --
#   FobjModificada 0.1727388225203033
# --- 125.36694860458374 s seconds to perform iteration number: 125 ---
# -- Generation 126 --
#   FobjModificada 0.1733676201804198
# --- 126.01609969139099 s seconds to perform iteration number: 126 ---
# -- Generation 127 --
#   FobjModificada 0.17400146842415173
# --- 125.00613451004028 s seconds to perform iteration number: 127 ---
# -- Generation 128 --
#   FobjModificada 0.17464036725149898
# --- 124.887699842453 s seconds to perform iteration number: 128 ---
# -- Generation 129 --
#   FobjModificada 0.17528431666246166
# --- 127.8188054561615 s seconds to perform iteration number: 129 ---
# -- Generation 130 --
#   FobjModificada 0.17593331665703973
# --- 125.5272159576416 s seconds to perform iteration number: 130 ---
# -- Generation 131 --
#   FobjModificada 0.17658736723523324
# --- 126.8960075378418 s seconds to perform iteration number: 131 ---
# -- Generation 132 --
#   FobjModificada 0.17724646839704214
# --- 126.69008183479309 s seconds to perform iteration number: 132 ---
# -- Generation 133 --
#   FobjModificada 0.1779106201424664
# --- 125.0566086769104 s seconds to perform iteration number: 133 ---
# -- Generation 134 --
#   FobjModificada 0.17857982247150606
# --- 127.13110399246216 s seconds to perform iteration number: 134 ---
# -- Generation 135 --
#   FobjModificada 0.17242525773791295
# --- 126.46895265579224 s seconds to perform iteration number: 135 ---
# -- Generation 136 --
#   FobjModificada 0.17260657584669428
# --- 125.05193495750427 s seconds to perform iteration number: 136 ---
# -- Generation 137 --
#   FobjModificada 0.17278924204550375
# --- 125.46657586097717 s seconds to perform iteration number: 137 ---
# -- Generation 138 --
#   FobjModificada 0.1729732563343413
# --- 125.28272199630737 s seconds to perform iteration number: 138 ---
# -- Generation 139 --
#   FobjModificada 0.1686768343718704
# --- 126.21224284172058 s seconds to perform iteration number: 139 ---
# -- Generation 140 --
#   FobjModificada 0.15840648526926987
# --- 125.33996748924255 s seconds to perform iteration number: 140 ---
# -- Generation 141 --
#   FobjModificada 0.15853787320084672
# --- 127.64437699317932 s seconds to perform iteration number: 141 ---
# -- Generation 142 --
#   FobjModificada 0.15648751622867
# --- 126.11971116065979 s seconds to perform iteration number: 142 ---
# -- Generation 143 --
#   FobjModificada 0.1566200940727783
# --- 125.40188956260681 s seconds to perform iteration number: 143 ---
# -- Generation 144 --
#   FobjModificada 0.15675360886278134
# --- 127.56248307228088 s seconds to perform iteration number: 144 ---
# -- Generation 145 --
#   FobjModificada 0.15688806059867913
# --- 126.59570980072021 s seconds to perform iteration number: 145 ---
# -- Generation 146 --
#   FobjModificada 0.15702344928047168
# --- 125.61569452285767 s seconds to perform iteration number: 146 ---
# -- Generation 147 --
#   FobjModificada 0.15715977490815902
# --- 126.45011043548584 s seconds to perform iteration number: 147 ---
# -- Generation 148 --
#   FobjModificada 0.1572970374817411
# --- 125.45966911315918 s seconds to perform iteration number: 148 ---
# -- Generation 149 --
#   FobjModificada 0.15743523700121792
# --- 126.42301821708679 s seconds to perform iteration number: 149 ---
# -- Generation 150 --
#   FobjModificada 0.15757437346658953
# --- 125.59756183624268 s seconds to perform iteration number: 150 ---
# -- Generation 151 --
#   FobjModificada 0.15771444687785588
# --- 125.8716299533844 s seconds to perform iteration number: 151 ---
# -- Generation 152 --
#   FobjModificada 0.15785545723501698
# --- 125.30398988723755 s seconds to perform iteration number: 152 ---
# -- Generation 153 --
#   FobjModificada 0.15799740453807287
# --- 125.51183605194092 s seconds to perform iteration number: 153 ---
# -- Generation 154 --
#   FobjModificada 0.15814028878702346
# --- 124.99156188964844 s seconds to perform iteration number: 154 ---
# -- Generation 155 --
#   FobjModificada 0.1582841099818689
# --- 127.01415538787842 s seconds to perform iteration number: 155 ---
# -- Generation 156 --
#   FobjModificada 0.15842886812260903
# --- 126.6010582447052 s seconds to perform iteration number: 156 ---
# -- Generation 157 --
#   FobjModificada 0.15857456320924393
# --- 124.39219999313354 s seconds to perform iteration number: 157 ---
# -- Generation 158 --
#   FobjModificada 0.15872119524177358
# --- 125.38153338432312 s seconds to perform iteration number: 158 ---
# -- Generation 159 --
#   FobjModificada 0.15886876422019805
# --- 124.73353409767151 s seconds to perform iteration number: 159 ---
# -- Generation 160 --
#   FobjModificada 0.15901727014451725
# --- 124.8487708568573 s seconds to perform iteration number: 160 ---
# -- Generation 161 --
#   FobjModificada 0.15916671301473112
# --- 128.1543483734131 s seconds to perform iteration number: 161 ---
# -- Generation 162 --
#   FobjModificada 0.15931709283083986
# --- 125.1681878566742 s seconds to perform iteration number: 162 ---
# -- Generation 163 --
#   FobjModificada 0.15946840959284334
# --- 127.61905264854431 s seconds to perform iteration number: 163 ---
# -- Generation 164 --
#   FobjModificada 0.1596206633007415
# --- 125.07552075386047 s seconds to perform iteration number: 164 ---
# -- Generation 165 --
#   FobjModificada 0.15977385395453453
# --- 126.76731944084167 s seconds to perform iteration number: 165 ---
# -- Generation 166 --
#   FobjModificada 0.15992798155422225
# --- 125.49557614326477 s seconds to perform iteration number: 166 ---
# -- Generation 167 --
#   FobjModificada 0.16008304609980467
# --- 125.2207727432251 s seconds to perform iteration number: 167 ---
# -- Generation 168 --
#   FobjModificada 0.16023904759128194
# --- 125.3286862373352 s seconds to perform iteration number: 168 ---
# -- Generation 169 --
#   FobjModificada 0.15359307971590713
# --- 126.53742814064026 s seconds to perform iteration number: 169 ---
# -- Generation 170 --
#   FobjModificada 0.1536810209423237
# --- 125.21308016777039 s seconds to perform iteration number: 170 ---
# -- Generation 171 --
#   FobjModificada 0.15376948407512853
# --- 124.63118004798889 s seconds to perform iteration number: 171 ---
# -- Generation 172 --
#   FobjModificada 0.15385846911432155
# --- 125.12927627563477 s seconds to perform iteration number: 172 ---
# -- Generation 173 --
#   FobjModificada 0.15394797605990276
# --- 124.84077858924866 s seconds to perform iteration number: 173 ---
# -- Generation 174 --
#   FobjModificada 0.15403800491187228
# --- 126.49791526794434 s seconds to perform iteration number: 174 ---
# -- Generation 175 --
#   FobjModificada 0.15412855567023007
# --- 125.41647744178772 s seconds to perform iteration number: 175 ---
# -- Generation 176 --
#   FobjModificada 0.15421962833497596
# --- 126.03072428703308 s seconds to perform iteration number: 176 ---
# -- Generation 177 --
#   FobjModificada 0.15431122290611018
# --- 125.61251139640808 s seconds to perform iteration number: 177 ---
# -- Generation 178 --
#   FobjModificada 0.1544033393836326
# --- 126.25100874900818 s seconds to perform iteration number: 178 ---
# -- Generation 179 --
#   FobjModificada 0.15449597776754323
# --- 125.28827166557312 s seconds to perform iteration number: 179 ---
# -- Generation 180 --
#   FobjModificada 0.1545891380578421
# --- 126.4597978591919 s seconds to perform iteration number: 180 ---
# -- Generation 181 --
#   FobjModificada 0.15468282025452923
# --- 126.41474604606628 s seconds to perform iteration number: 181 ---
# -- Generation 182 --
#   FobjModificada 0.15477702435760454
# --- 126.05722284317017 s seconds to perform iteration number: 182 ---
# -- Generation 183 --
#   FobjModificada 0.15487175036706807
# --- 128.64838099479675 s seconds to perform iteration number: 183 ---
# -- Generation 184 --
#   FobjModificada 0.15496699828291988
# --- 124.75346732139587 s seconds to perform iteration number: 184 ---
# -- Generation 185 --
#   FobjModificada 0.1550627681051599
# --- 125.27487754821777 s seconds to perform iteration number: 185 ---
# -- Generation 186 --
#   FobjModificada 0.15515905983378814
# --- 125.62922263145447 s seconds to perform iteration number: 186 ---
# -- Generation 187 --
#   FobjModificada 0.15494419961885
# --- 125.26318621635437 s seconds to perform iteration number: 187 ---
# -- Generation 188 --
#   FobjModificada 0.15449601338292143
# --- 125.17364740371704 s seconds to perform iteration number: 188 ---
# -- Generation 189 --
#   FobjModificada 0.15458228272786925
# --- 125.19782614707947 s seconds to perform iteration number: 189 ---
# -- Generation 190 --
#   FobjModificada 0.1546690121759901
# --- 125.7520866394043 s seconds to perform iteration number: 190 ---
# -- Generation 191 --
#   FobjModificada 0.15472092535097406
# --- 125.21404933929443 s seconds to perform iteration number: 191 ---
# -- Generation 192 --
#   FobjModificada 0.15480833386379195
# --- 125.40484714508057 s seconds to perform iteration number: 192 ---
# -- Generation 193 --
#   FobjModificada 0.15489620121394745
# --- 125.11076617240906 s seconds to perform iteration number: 193 ---
# -- Generation 194 --
#   FobjModificada 0.15498452740144056
# --- 124.92669749259949 s seconds to perform iteration number: 194 ---
# -- Generation 195 --
#   FobjModificada 0.15507331242627137
# --- 125.96790146827698 s seconds to perform iteration number: 195 ---
# -- Generation 196 --
#   FobjModificada 0.15516255628843975
# --- 125.41191267967224 s seconds to perform iteration number: 196 ---
# -- Generation 197 --
#   FobjModificada 0.15525225898794578
# --- 126.4471366405487 s seconds to perform iteration number: 197 ---
# -- Generation 198 --
#   FobjModificada 0.15534242052478942
# --- 125.60510420799255 s seconds to perform iteration number: 198 ---
# -- Generation 199 --
#   FobjModificada 0.15543304089897073
# --- 125.47643494606018 s seconds to perform iteration number: 199 ---
# -- Generation 200 --
#   FobjModificada 0.15552412011048963
# FobjReal (0.14643891140681156,)
# [0.02995747599180998, 0.046447982483862615, 0.17119075820982488, 0.06162511769163359, 0.3491573475826749, 0.10011034964000232, 0.21836437122573782, 0.11239605450825563, 0.13844304752557712, 0.1640418163191345, 0.07569218097379515, 0.07723504270988624, 0.16291396677736103, 0.24688077052407253, 0.06286493008844951, 0.08487983949445055, 0.1652450723813852, 0.31384824799779, 0.10887023893875647, 0.03441998183251005, 0.24789199515971982, 0.1931800911518552, 0.23724225980740887, 0.08845656034215799, 0.06143049011736412, 0.1293502477408527, 0.18010438640992432, 0.1089426901698155, 0.01576873502184728, 0.10561757253841919, 0.023801524161582543, 0.6336465566965671, 0.07727884168936017, 0.012571838997599283, 0.11319935678818305, 0.1217048718239162, 0.0013076746239722992, 0.45555175105926804, 0.06821696553583478, 0.065548109307775, 0.19121730780908341, 0.18142027975851693, 0.04624530602777477, 0.051367593887434504, 0.09623982727865121, 0.1405861846854336, 0.5659507886920198, 0.09571211220262488, 0.020188936004134073]
# Successfully created the directory ./results/fobjQuadraticError/iteration200
# -----------------------------------------------------------------------------------------
# Guardamos valores
# -----------------------------------------------------------------------------------------
# --- 145.89452004432678 s seconds to perform iteration number: 200 ---
# -- Generation 201 --
#   FobjModificada 0.15561565815934617
# --- 127.69882822036743 s seconds to perform iteration number: 201 ---
# -- Generation 202 --
#   FobjModificada 0.15570765504554032
# --- 125.05853056907654 s seconds to perform iteration number: 202 ---
# -- Generation 203 --
#   FobjModificada 0.1558001107690721
# --- 125.22455596923828 s seconds to perform iteration number: 203 ---
# -- Generation 204 --
#   FobjModificada 0.15589302532994154
# --- 126.73162412643433 s seconds to perform iteration number: 204 ---
# -- Generation 205 --
#   FobjModificada 0.15598639872814857
# --- 125.2353024482727 s seconds to perform iteration number: 205 ---
# -- Generation 206 --
#   FobjModificada 0.15608023096369322
# --- 126.09320616722107 s seconds to perform iteration number: 206 ---
# -- Generation 207 --
#   FobjModificada 0.1561745220365755
# --- 126.54446411132812 s seconds to perform iteration number: 207 ---
# -- Generation 208 --
#   FobjModificada 0.15626927194679543
# --- 125.31111145019531 s seconds to perform iteration number: 208 ---
# -- Generation 209 --
#   FobjModificada 0.156364480694353
# --- 124.89021682739258 s seconds to perform iteration number: 209 ---
# -- Generation 210 --
#   FobjModificada 0.15646014827924817
# --- 125.91861867904663 s seconds to perform iteration number: 210 ---
# -- Generation 211 --
#   FobjModificada 0.15655627470148092
# --- 125.17376232147217 s seconds to perform iteration number: 211 ---
# -- Generation 212 --
#   FobjModificada 0.15665285996105136
# --- 125.72292685508728 s seconds to perform iteration number: 212 ---
# -- Generation 213 --
#   FobjModificada 0.15674990405795944
# --- 126.1181333065033 s seconds to perform iteration number: 213 ---
# -- Generation 214 --
#   FobjModificada 0.15653716999076606
# --- 124.605544090271 s seconds to perform iteration number: 214 ---
# -- Generation 215 --
#   FobjModificada 0.1566317127933712
# --- 125.43339204788208 s seconds to perform iteration number: 215 ---
# -- Generation 216 --
#   FobjModificada 0.15672669841940778
# --- 126.53705334663391 s seconds to perform iteration number: 216 ---
# -- Generation 217 --
#   FobjModificada 0.15682212686887573
# --- 126.11675930023193 s seconds to perform iteration number: 217 ---
# -- Generation 218 --
#   FobjModificada 0.15691799814177515
# --- 126.18052887916565 s seconds to perform iteration number: 218 ---
# -- Generation 219 --
#   FobjModificada 0.15701431223810594
# --- 124.965096950531 s seconds to perform iteration number: 219 ---
# -- Generation 220 --
#   FobjModificada 0.15711106915786813
# --- 127.476797580719 s seconds to perform iteration number: 220 ---
# -- Generation 221 --
#   FobjModificada 0.15720826890106174
# --- 126.23971271514893 s seconds to perform iteration number: 221 ---
# -- Generation 222 --
#   FobjModificada 0.15730591146768677
# --- 125.78960943222046 s seconds to perform iteration number: 222 ---
# -- Generation 223 --
#   FobjModificada 0.15477326778344086
# --- 126.11908268928528 s seconds to perform iteration number: 223 ---
# -- Generation 224 --
#   FobjModificada 0.15485023323763952
# --- 125.07080841064453 s seconds to perform iteration number: 224 ---
# -- Generation 225 --
#   FobjModificada 0.1549275446039919
# --- 124.7631025314331 s seconds to perform iteration number: 225 ---
# -- Generation 226 --
#   FobjModificada 0.15500520188249797
# --- 125.2983934879303 s seconds to perform iteration number: 226 ---
# -- Generation 227 --
#   FobjModificada 0.15508320507315768
# --- 125.29715776443481 s seconds to perform iteration number: 227 ---
# -- Generation 228 --
#   FobjModificada 0.15516155417597122
# --- 125.92070770263672 s seconds to perform iteration number: 228 ---
# -- Generation 229 --
#   FobjModificada 0.15524024919093837
# --- 125.64623022079468 s seconds to perform iteration number: 229 ---
# -- Generation 230 --
#   FobjModificada 0.15531929011805923
# --- 125.78246188163757 s seconds to perform iteration number: 230 ---
# -- Generation 231 --
#   FobjModificada 0.15539867695733378
# --- 125.36805868148804 s seconds to perform iteration number: 231 ---
# -- Generation 232 --
#   FobjModificada 0.15547840970876206
# --- 126.51491618156433 s seconds to perform iteration number: 232 ---
# -- Generation 233 --
#   FobjModificada 0.15555848837234407
# --- 127.19976949691772 s seconds to perform iteration number: 233 ---
# -- Generation 234 --
#   FobjModificada 0.15563891294807972
# --- 125.58524107933044 s seconds to perform iteration number: 234 ---
# -- Generation 235 --
#   FobjModificada 0.15571968343596912
# --- 125.85585522651672 s seconds to perform iteration number: 235 ---
# -- Generation 236 --
#   FobjModificada 0.15217622880698317
# --- 128.09569239616394 s seconds to perform iteration number: 236 ---
# -- Generation 237 --
#   FobjModificada 0.14803668856979074
# --- 125.88083863258362 s seconds to perform iteration number: 237 ---
# -- Generation 238 --
#   FobjModificada 0.14805536286517873
# --- 125.45681047439575 s seconds to perform iteration number: 238 ---
# -- Generation 239 --
#   FobjModificada 0.14671419594053373
# --- 125.35514855384827 s seconds to perform iteration number: 239 ---
# -- Generation 240 --
#   FobjModificada 0.14678686457371704
# --- 125.73222804069519 s seconds to perform iteration number: 240 ---
# -- Generation 241 --
#   FobjModificada 0.14685983789718624
# --- 124.81678581237793 s seconds to perform iteration number: 241 ---
# -- Generation 242 --
#   FobjModificada 0.1469331159109413
# --- 125.47801542282104 s seconds to perform iteration number: 242 ---
# -- Generation 243 --
#   FobjModificada 0.14700669861498225
# --- 125.55298066139221 s seconds to perform iteration number: 243 ---
# -- Generation 244 --
#   FobjModificada 0.14708058600930912
# --- 126.60737609863281 s seconds to perform iteration number: 244 ---
# -- Generation 245 --
#   FobjModificada 0.14715477809392183
# --- 124.67702960968018 s seconds to perform iteration number: 245 ---
# -- Generation 246 --
#   FobjModificada 0.14722927486882048
# --- 127.39021253585815 s seconds to perform iteration number: 246 ---
# -- Generation 247 --
#   FobjModificada 0.14730407633400497
# --- 125.62073564529419 s seconds to perform iteration number: 247 ---
# -- Generation 248 --
#   FobjModificada 0.1473791824894753
# --- 125.77751541137695 s seconds to perform iteration number: 248 ---
# -- Generation 249 --
#   FobjModificada 0.1474545933352316
# --- 126.31436824798584 s seconds to perform iteration number: 249 ---
# -- Generation 250 --
#   FobjModificada 0.14753030887127372
# --- 125.01915240287781 s seconds to perform iteration number: 250 ---
# -- Generation 251 --
#   FobjModificada 0.14760632909760177
# --- 126.12963771820068 s seconds to perform iteration number: 251 ---
# -- Generation 252 --
#   FobjModificada 0.1476826540142157
# --- 125.25658059120178 s seconds to perform iteration number: 252 ---
# -- Generation 253 --
#   FobjModificada 0.14775928362111548
# --- 125.04218602180481 s seconds to perform iteration number: 253 ---
# -- Generation 254 --
#   FobjModificada 0.14783621791830115
# --- 125.69118762016296 s seconds to perform iteration number: 254 ---
# -- Generation 255 --
#   FobjModificada 0.14755393299448852
# --- 126.35343098640442 s seconds to perform iteration number: 255 ---
# -- Generation 256 --
#   FobjModificada 0.147628644122242
# --- 126.6809012889862 s seconds to perform iteration number: 256 ---
# -- Generation 257 --
#   FobjModificada 0.1477036488104188
# --- 127.25679206848145 s seconds to perform iteration number: 257 ---
# -- Generation 258 --
#   FobjModificada 0.14454621017005362
# --- 125.93502235412598 s seconds to perform iteration number: 258 ---
# -- Generation 259 --
#   FobjModificada 0.14163830690800142
# --- 126.51423120498657 s seconds to perform iteration number: 259 ---
# -- Generation 260 --
#   FobjModificada 0.14172199112520095
# --- 125.05050349235535 s seconds to perform iteration number: 260 ---
# -- Generation 261 --
#   FobjModificada 0.14180599907244767
# --- 126.86872482299805 s seconds to perform iteration number: 261 ---
# -- Generation 262 --
#   FobjModificada 0.14189033074974164
# --- 125.61095881462097 s seconds to perform iteration number: 262 ---
# -- Generation 263 --
#   FobjModificada 0.14197498615708273
# --- 124.55828666687012 s seconds to perform iteration number: 263 ---
# -- Generation 264 --
#   FobjModificada 0.1420599652944711
# --- 126.6807541847229 s seconds to perform iteration number: 264 ---
# -- Generation 265 --
#   FobjModificada 0.1421452681619066
# --- 126.51691031455994 s seconds to perform iteration number: 265 ---
# -- Generation 266 --
#   FobjModificada 0.1422308947593893
# --- 124.9420051574707 s seconds to perform iteration number: 266 ---
# -- Generation 267 --
#   FobjModificada 0.14231684508691922
# --- 125.17198848724365 s seconds to perform iteration number: 267 ---
# -- Generation 268 --
#   FobjModificada 0.14240311914449633
# --- 125.57951521873474 s seconds to perform iteration number: 268 ---
# -- Generation 269 --
#   FobjModificada 0.1424897169321206
# --- 125.28633260726929 s seconds to perform iteration number: 269 ---
# -- Generation 270 --
#   FobjModificada 0.14257663844979213
# --- 125.04401087760925 s seconds to perform iteration number: 270 ---
# -- Generation 271 --
#   FobjModificada 0.14266388369751082
# --- 125.91132473945618 s seconds to perform iteration number: 271 ---
# -- Generation 272 --
#   FobjModificada 0.1427514526752766
# --- 124.6686840057373 s seconds to perform iteration number: 272 ---
# -- Generation 273 --
#   FobjModificada 0.1428393453830897
# --- 124.854159116745 s seconds to perform iteration number: 273 ---
# -- Generation 274 --
#   FobjModificada 0.14292756182094996
# --- 125.02433776855469 s seconds to perform iteration number: 274 ---
# -- Generation 275 --
#   FobjModificada 0.14301610198885742
# --- 126.08328223228455 s seconds to perform iteration number: 275 ---
# -- Generation 276 --
#   FobjModificada 0.14310496588681207
# --- 125.50429677963257 s seconds to perform iteration number: 276 ---
# -- Generation 277 --
#   FobjModificada 0.14319415351481388
# --- 125.77241659164429 s seconds to perform iteration number: 277 ---
# -- Generation 278 --
#   FobjModificada 0.14328366487286293
# --- 124.7382562160492 s seconds to perform iteration number: 278 ---
# -- Generation 279 --
#   FobjModificada 0.1433734999609591
# --- 125.30029582977295 s seconds to perform iteration number: 279 ---
# -- Generation 280 --
#   FobjModificada 0.14346365877910258
# --- 124.89751982688904 s seconds to perform iteration number: 280 ---
# -- Generation 281 --
#   FobjModificada 0.14355414132729322
# --- 125.72848010063171 s seconds to perform iteration number: 281 ---
# -- Generation 282 --
#   FobjModificada 0.143644947605531
# --- 126.9546000957489 s seconds to perform iteration number: 282 ---
# -- Generation 283 --
#   FobjModificada 0.143736077613816
# --- 124.33787178993225 s seconds to perform iteration number: 283 ---
# -- Generation 284 --
#   FobjModificada 0.14382753135214824
# --- 123.80923700332642 s seconds to perform iteration number: 284 ---
# -- Generation 285 --
#   FobjModificada 0.14391930882052759
# --- 126.21113657951355 s seconds to perform iteration number: 285 ---
# -- Generation 286 --
#   FobjModificada 0.1440114100189542
# --- 125.47458481788635 s seconds to perform iteration number: 286 ---
# -- Generation 287 --
#   FobjModificada 0.14410383494742793
# --- 125.00820827484131 s seconds to perform iteration number: 287 ---
# -- Generation 288 --
#   FobjModificada 0.14419658360594895
# --- 126.22534656524658 s seconds to perform iteration number: 288 ---
# -- Generation 289 --
#   FobjModificada 0.1442896559945171
# --- 126.01740956306458 s seconds to perform iteration number: 289 ---
# -- Generation 290 --
#   FobjModificada 0.14438305211313243
# --- 125.66830444335938 s seconds to perform iteration number: 290 ---
# -- Generation 291 --
#   FobjModificada 0.144476771961795
# --- 124.99062871932983 s seconds to perform iteration number: 291 ---
# -- Generation 292 --
#   FobjModificada 0.14457081554050474
# --- 125.27964925765991 s seconds to perform iteration number: 292 ---
# -- Generation 293 --
#   FobjModificada 0.14466518284926164
# --- 124.5642819404602 s seconds to perform iteration number: 293 ---
# -- Generation 294 --
#   FobjModificada 0.1447598738880658
# --- 127.79693961143494 s seconds to perform iteration number: 294 ---
# -- Generation 295 --
#   FobjModificada 0.14485488865691715
# --- 124.59264612197876 s seconds to perform iteration number: 295 ---
# -- Generation 296 --
#   FobjModificada 0.14495022715581565
# --- 125.77761101722717 s seconds to perform iteration number: 296 ---
# -- Generation 297 --
#   FobjModificada 0.1450458893847614
# --- 125.33677530288696 s seconds to perform iteration number: 297 ---
# -- Generation 298 --
#   FobjModificada 0.14514187534375428
# --- 125.60096263885498 s seconds to perform iteration number: 298 ---
# -- Generation 299 --
#   FobjModificada 0.14523818503279434
# --- 125.0354413986206 s seconds to perform iteration number: 299 ---
# -- Generation 300 --
#   FobjModificada 0.14533481845188168
# FobjReal (0.13086392347730363,)
# [0.02995747599180998, 0.05189803449200936, 0.17119075820982488, 0.06162511769163359, 0.3491573475826749, 0.10011034964000232, 0.21836437122573782, 0.11239605450825563, 0.13844304752557712, 0.1640418163191345, 0.07569218097379515, 0.07723504270988624, 0.16291396677736103, 0.24688077052407253, 0.06046663518348483, 0.08487983949445055, 0.001637301835555216, 0.31384824799779, 0.10887023893875647, 0.03441998183251005, 0.42498857235627674, 0.1931800911518552, 0.23724225980740887, 0.08845656034215799, 0.06143049011736412, 0.1293502477408527, 0.18010438640992432, 0.1089426901698155, 0.01576873502184728, 0.10561757253841919, 0.023801524161582543, 0.6336465566965671, 0.09258445129713833, 0.012571838997599283, 0.11319935678818305, 0.0538104699015568, 0.0013076746239722992, 0.11627686110969437, 0.06821696553583478, 0.065548109307775, 0.1789219291549342, 0.5832782573200954, 0.04624530602777477, 0.051367593887434504, 0.09623982727865121, 0.1405861846854336, 0.5659507886920198, 0.09571211220262488, 0.020188936004134073]
# Successfully created the directory ./results/fobjQuadraticError/iteration300
# -----------------------------------------------------------------------------------------
# Guardamos valores
# -----------------------------------------------------------------------------------------
# --- 147.6408166885376 s seconds to perform iteration number: 300 ---
# -- Generation 301 --
#   FobjModificada 0.1454317756010162
# --- 125.8882303237915 s seconds to perform iteration number: 301 ---
# -- Generation 302 --
#   FobjModificada 0.14552905648019784
# --- 125.11707639694214 s seconds to perform iteration number: 302 ---
# -- Generation 303 --
#   FobjModificada 0.1456266610894267
# --- 124.20398831367493 s seconds to perform iteration number: 303 ---
# -- Generation 304 --
#   FobjModificada 0.14572458942870278
# --- 124.78235936164856 s seconds to perform iteration number: 304 ---
# -- Generation 305 --
#   FobjModificada 0.14582284149802602
# --- 124.92098641395569 s seconds to perform iteration number: 305 ---
# -- Generation 306 --
#   FobjModificada 0.1459214172973965
# --- 125.59629559516907 s seconds to perform iteration number: 306 ---
# -- Generation 307 --
#   FobjModificada 0.14602031682681418
# --- 125.6606068611145 s seconds to perform iteration number: 307 ---
# -- Generation 308 --
#   FobjModificada 0.146119540086279
# --- 125.95540809631348 s seconds to perform iteration number: 308 ---
# -- Generation 309 --
#   FobjModificada 0.146219087075791
# --- 126.04072427749634 s seconds to perform iteration number: 309 ---
# -- Generation 310 --
#   FobjModificada 0.14631895779535026
# --- 126.81075191497803 s seconds to perform iteration number: 310 ---
# -- Generation 311 --
#   FobjModificada 0.14641915224495666
# --- 125.72298550605774 s seconds to perform iteration number: 311 ---
# -- Generation 312 --
#   FobjModificada 0.1465196704246103
# --- 125.80265855789185 s seconds to perform iteration number: 312 ---
# -- Generation 313 --
#   FobjModificada 0.1466205123343111
# --- 126.00662875175476 s seconds to perform iteration number: 313 ---
# -- Generation 314 --
#   FobjModificada 0.1467216779740591
# --- 124.61034345626831 s seconds to perform iteration number: 314 ---
# -- Generation 315 --
#   FobjModificada 0.14682316734385428
# --- 125.07270884513855 s seconds to perform iteration number: 315 ---
# -- Generation 316 --
#   FobjModificada 0.1469249804436967
# --- 124.63174653053284 s seconds to perform iteration number: 316 ---
# -- Generation 317 --
#   FobjModificada 0.14702711727358633
# --- 125.41328883171082 s seconds to perform iteration number: 317 ---
# -- Generation 318 --
#   FobjModificada 0.14712957783352304
# --- 124.56967949867249 s seconds to perform iteration number: 318 ---
# -- Generation 319 --
#   FobjModificada 0.14723236212350704
# --- 125.19942688941956 s seconds to perform iteration number: 319 ---
# -- Generation 320 --
#   FobjModificada 0.1473354701435382
# --- 125.02671957015991 s seconds to perform iteration number: 320 ---
# -- Generation 321 --
#   FobjModificada 0.14743890189361653
# --- 126.11137008666992 s seconds to perform iteration number: 321 ---
# -- Generation 322 --
#   FobjModificada 0.1475426573737421
# --- 125.01392650604248 s seconds to perform iteration number: 322 ---
# -- Generation 323 --
#   FobjModificada 0.1476467365839148
# --- 125.0064070224762 s seconds to perform iteration number: 323 ---
# -- Generation 324 --
#   FobjModificada 0.14775113952413477
# --- 124.32287073135376 s seconds to perform iteration number: 324 ---
# -- Generation 325 --
#   FobjModificada 0.14785586619440186
# --- 126.01007390022278 s seconds to perform iteration number: 325 ---
# -- Generation 326 --
#   FobjModificada 0.14796091659471622
# --- 124.38059520721436 s seconds to perform iteration number: 326 ---
# -- Generation 327 --
#   FobjModificada 0.14806629072507776
# --- 126.6003258228302 s seconds to perform iteration number: 327 ---
# -- Generation 328 --
#   FobjModificada 0.14817198858548647
# --- 124.66245126724243 s seconds to perform iteration number: 328 ---
# -- Generation 329 --
#   FobjModificada 0.1482780101759424
# --- 125.64173126220703 s seconds to perform iteration number: 329 ---
# -- Generation 330 --
#   FobjModificada 0.1483843554964455
# --- 125.85769391059875 s seconds to perform iteration number: 330 ---
# -- Generation 331 --
#   FobjModificada 0.14849102454699578
# --- 127.06024217605591 s seconds to perform iteration number: 331 ---
# -- Generation 332 --
#   FobjModificada 0.14859801732759328
# --- 125.33459997177124 s seconds to perform iteration number: 332 ---
# -- Generation 333 --
#   FobjModificada 0.14870533383823797
# --- 125.04481244087219 s seconds to perform iteration number: 333 ---
# -- Generation 334 --
#   FobjModificada 0.14881297407892982
# --- 125.02269792556763 s seconds to perform iteration number: 334 ---
# -- Generation 335 --
#   FobjModificada 0.1489209380496689
# --- 125.33411312103271 s seconds to perform iteration number: 335 ---
# -- Generation 336 --
#   FobjModificada 0.14902922575045513
# --- 124.56824398040771 s seconds to perform iteration number: 336 ---
# -- Generation 337 --
#   FobjModificada 0.1491378371812886
# --- 124.75924372673035 s seconds to perform iteration number: 337 ---
# -- Generation 338 --
#   FobjModificada 0.14924677234216924
# --- 125.23821568489075 s seconds to perform iteration number: 338 ---
# -- Generation 339 --
#   FobjModificada 0.1493560312330971
# --- 127.8199028968811 s seconds to perform iteration number: 339 ---
# -- Generation 340 --
#   FobjModificada 0.14946561385407214
# --- 127.4377613067627 s seconds to perform iteration number: 340 ---
# -- Generation 341 --
#   FobjModificada 0.14957552020509438
# --- 125.23212099075317 s seconds to perform iteration number: 341 ---
# -- Generation 342 --
#   FobjModificada 0.1496857502861638
# --- 126.24757599830627 s seconds to perform iteration number: 342 ---
# -- Generation 343 --
#   FobjModificada 0.14938455522905925
# --- 125.47889375686646 s seconds to perform iteration number: 343 ---
# -- Generation 344 --
#   FobjModificada 0.14949354220370772
# --- 127.3600640296936 s seconds to perform iteration number: 344 ---
# -- Generation 345 --
#   FobjModificada 0.14960284738850113
# --- 125.94640159606934 s seconds to perform iteration number: 345 ---
# -- Generation 346 --
#   FobjModificada 0.14971247078343958
# --- 125.21829628944397 s seconds to perform iteration number: 346 ---
# -- Generation 347 --
#   FobjModificada 0.14982241238852284
# ...
# -- Generation 1487 --
#   FobjModificada 0.13630130650077868
# --- 125.00900983810425 s seconds to perform iteration number: 1487 ---
# -- Generation 1488 --
#   FobjModificada 0.136303192411167
# --- 126.13626384735107 s seconds to perform iteration number: 1488 ---
# -- Generation 1489 --
#   FobjModificada 0.1363050795902471
# --- 124.96594476699829 s seconds to perform iteration number: 1489 ---
# -- Generation 1490 --
#   FobjModificada 0.13630696803801906
# --- 124.00507521629333 s seconds to perform iteration number: 1490 ---
# -- Generation 1491 --
#   FobjModificada 0.1363088577544828
# --- 126.89672994613647 s seconds to perform iteration number: 1491 ---
# -- Generation 1492 --
#   FobjModificada 0.13631074873963842
# --- 125.558185338974 s seconds to perform iteration number: 1492 ---
# -- Generation 1493 --
#   FobjModificada 0.1363126409934858
# --- 124.8209228515625 s seconds to perform iteration number: 1493 ---
# -- Generation 1494 --
#   FobjModificada 0.13631453451602502
# --- 125.02269053459167 s seconds to perform iteration number: 1494 ---
# -- Generation 1495 --
#   FobjModificada 0.13631642930725604
# --- 124.85811400413513 s seconds to perform iteration number: 1495 ---
# -- Generation 1496 --
#   FobjModificada 0.13631832536717886
# --- 125.85731720924377 s seconds to perform iteration number: 1496 ---
# -- Generation 1497 --
#   FobjModificada 0.13632022269579355
# --- 124.99612188339233 s seconds to perform iteration number: 1497 ---
# -- Generation 1498 --
#   FobjModificada 0.1363221212931001
# --- 127.33615851402283 s seconds to perform iteration number: 1498 ---
# -- Generation 1499 --
#   FobjModificada 0.1363240211590984
# --- 125.45865631103516 s seconds to perform iteration number: 1499 ---
# -- Generation 1500 --
#   FobjModificada 0.13632592229378854
# FobjReal (0.1349005464012789,)
# [0.02995747599180998, 0.05189803449200936, 0.17119075820982488, 0.0781928662720297, 0.35156440357560426, 0.10011034964000232, 0.21836437122573782, 0.11239605450825563, 0.1523112578375445, 0.15579946224084884, 0.07569218097379515, 0.05350700338168346, 0.16291396677736103, 0.2845967345045688, 0.06046663518348483, 0.06766271318957728, 0.001637301835555216, 0.3109553327024568, 0.10887023893875647, 0.033619498540574666, 0.4204934989210156, 0.1931800911518552, 0.23724225980740887, 0.08845656034215799, 0.06143049011736412, 0.1293502477408527, 0.18010438640992432, 0.1089426901698155, 0.01576873502184728, 0.10561757253841919, 0.025331684374688024, 0.6336465566965671, 0.09390427861460926, 0.012571838997599283, 0.11319935678818305, 0.0538104699015568, 0.0013076746239722992, 0.11627686110969437, 0.06821696553583478, 0.065548109307775, 0.1789219291549342, 0.515177472838407, 0.04624530602777477, 0.051367593887434504, 0.09623982727865121, 0.1405861846854336, 0.5659507886920198, 0.07057000072178565, 0.028836013021360296]
# Successfully created the directory ./results/fobjQuadraticError/iteration1500
# -----------------------------------------------------------------------------------------
# Guardamos valores
# -----------------------------------------------------------------------------------------
# --- 147.68482208251953 s seconds to perform iteration number: 1500 ---
# -- Generation 1501 --
#   FobjModificada 0.13632782469717045
# --- 124.28463077545166 s seconds to perform iteration number: 1501 ---
# -- Generation 1502 --
#   FobjModificada 0.13632972836924423
# --- 126.65094256401062 s seconds to perform iteration number: 1502 ---
# -- Generation 1503 --
#   FobjModificada 0.13633163331000978
# --- 126.50030541419983 s seconds to perform iteration number: 1503 ---
# -- Generation 1504 --
#   FobjModificada 0.1363335395194672
# --- 125.3258764743805 s seconds to perform iteration number: 1504 ---
# -- Generation 1505 --
#   FobjModificada 0.13633544699761643
# --- 125.03540444374084 s seconds to perform iteration number: 1505 ---
# -- Generation 1506 --
#   FobjModificada 0.13633735574445743
# --- 125.91609692573547 s seconds to perform iteration number: 1506 ---
# -- Generation 1507 --
#   FobjModificada 0.1363392657599903
# --- 125.28295731544495 s seconds to perform iteration number: 1507 ---
# -- Generation 1508 --
#   FobjModificada 0.136341177044215
# --- 126.8766508102417 s seconds to perform iteration number: 1508 ---
# -- Generation 1509 --
#   FobjModificada 0.13634308959713148
# --- 124.37822890281677 s seconds to perform iteration number: 1509 ---
# -- Generation 1510 --
#   FobjModificada 0.1363450034187398
# --- 125.66010403633118 s seconds to perform iteration number: 1510 ---
# -- Generation 1511 --
#   FobjModificada 0.13634691850903993
# --- 124.92659616470337 s seconds to perform iteration number: 1511 ---
# -- Generation 1512 --
#   FobjModificada 0.13634883486803184
# --- 125.65673303604126 s seconds to perform iteration number: 1512 ---
# -- Generation 1513 --
#   FobjModificada 0.13635075249571565
# --- 124.9595365524292 s seconds to perform iteration number: 1513 ---
# -- Generation 1514 --
#   FobjModificada 0.13635267139209123
# --- 126.32833003997803 s seconds to perform iteration number: 1514 ---
# -- Generation 1515 --
#   FobjModificada 0.13635459155715865
# --- 126.24556922912598 s seconds to perform iteration number: 1515 ---
# -- Generation 1516 --
#   FobjModificada 0.13635651299091783
# --- 125.92486023902893 s seconds to perform iteration number: 1516 ---
# -- Generation 1517 --
#   FobjModificada 0.1363584356933689
# --- 127.4269437789917 s seconds to perform iteration number: 1517 ---
# -- Generation 1518 --
#   FobjModificada 0.13636035966451177
# --- 126.93707656860352 s seconds to perform iteration number: 1518 ---
# -- Generation 1519 --
#   FobjModificada 0.13636228490434643
# --- 125.81312108039856 s seconds to perform iteration number: 1519 ---
# -- Generation 1520 --
#   FobjModificada 0.13636421141287297
# --- 127.22407388687134 s seconds to perform iteration number: 1520 ---
# -- Generation 1521 --
#   FobjModificada 0.13636613919009127
# --- 126.95095014572144 s seconds to perform iteration number: 1521 ---
# -- Generation 1522 --
#   FobjModificada 0.13636806823600142
# --- 125.03192257881165 s seconds to perform iteration number: 1522 ---
# -- Generation 1523 --
#   FobjModificada 0.13636999855060336
# --- 125.55618453025818 s seconds to perform iteration number: 1523 ---
# -- Generation 1524 --
#   FobjModificada 0.13637193013389715
# --- 125.94387078285217 s seconds to perform iteration number: 1524 ---
# -- Generation 1525 --
#   FobjModificada 0.1363738629858827
# --- 125.88888478279114 s seconds to perform iteration number: 1525 ---
# -- Generation 1526 --
#   FobjModificada 0.13637579710656011
# --- 127.34659504890442 s seconds to perform iteration number: 1526 ---
# -- Generation 1527 --
#   FobjModificada 0.13637773249592938
# --- 125.5248155593872 s seconds to perform iteration number: 1527 ---
# -- Generation 1528 --
#   FobjModificada 0.13637966915399038
# --- 124.82328748703003 s seconds to perform iteration number: 1528 ---
# -- Generation 1529 --
#   FobjModificada 0.1363816070807433
# --- 126.0794107913971 s seconds to perform iteration number: 1529 ---
# -- Generation 1530 --
#   FobjModificada 0.13638354627618796
# --- 126.02283382415771 s seconds to perform iteration number: 1530 ---
# -- Generation 1531 --
#   FobjModificada 0.1363854867403245
# --- 125.32240533828735 s seconds to perform iteration number: 1531 ---
# -- Generation 1532 --
#   FobjModificada 0.13638742847315274
# --- 127.92841339111328 s seconds to perform iteration number: 1532 ---
# -- Generation 1533 --
#   FobjModificada 0.13638937147467292
# --- 124.90853357315063 s seconds to perform iteration number: 1533 ---
# -- Generation 1534 --
#   FobjModificada 0.1363913157448849
# --- 125.40434050559998 s seconds to perform iteration number: 1534 ---
# -- Generation 1535 --
#   FobjModificada 0.1363932612837887
# --- 126.72731399536133 s seconds to perform iteration number: 1535 ---
# -- Generation 1536 --
#   FobjModificada 0.13639520809138425
# --- 126.0270004272461 s seconds to perform iteration number: 1536 ---
# -- Generation 1537 --
#   FobjModificada 0.13639715616767167
# --- 124.52185010910034 s seconds to perform iteration number: 1537 ---
# -- Generation 1538 --
#   FobjModificada 0.13639910551265097
# --- 125.56587529182434 s seconds to perform iteration number: 1538 ---
# -- Generation 1539 --
#   FobjModificada 0.13640105612632197
# --- 125.11921548843384 s seconds to perform iteration number: 1539 ---
# -- Generation 1540 --
#   FobjModificada 0.13640300800868488
# --- 125.89217257499695 s seconds to perform iteration number: 1540 ---
# -- Generation 1541 --
#   FobjModificada 0.13640496115973952
# --- 124.92288279533386 s seconds to perform iteration number: 1541 ---
# -- Generation 1542 --
#   FobjModificada 0.136406915579486
# --- 127.00266361236572 s seconds to perform iteration number: 1542 ---
# -- Generation 1543 --
#   FobjModificada 0.13640887126792436
# --- 127.18701672554016 s seconds to perform iteration number: 1543 ---
# -- Generation 1544 --
#   FobjModificada 0.1364108282250545
# --- 125.27599740028381 s seconds to perform iteration number: 1544 ---
# -- Generation 1545 --
#   FobjModificada 0.13641278645087643
# --- 126.69580674171448 s seconds to perform iteration number: 1545 ---
# -- Generation 1546 --
#   FobjModificada 0.13641474594539021
# --- 127.04721879959106 s seconds to perform iteration number: 1546 ---
# -- Generation 1547 --
#   FobjModificada 0.13641670670859585
# --- 124.44933295249939 s seconds to perform iteration number: 1547 ---
# -- Generation 1548 --
#   FobjModificada 0.13641866874049327
# --- 124.24949598312378 s seconds to perform iteration number: 1548 ---
# -- Generation 1549 --
#   FobjModificada 0.13642063204108248
# --- 126.3041844367981 s seconds to perform iteration number: 1549 ---
# -- Generation 1550 --
#   FobjModificada 0.13642259661036357
# --- 125.48999834060669 s seconds to perform iteration number: 1550 ---
# -- Generation 1551 --
#   FobjModificada 0.13642456244833645
# --- 126.15258288383484 s seconds to perform iteration number: 1551 ---
# -- Generation 1552 --
#   FobjModificada 0.13642652955500112
# --- 125.472580909729 s seconds to perform iteration number: 1552 ---
# -- Generation 1553 --
#   FobjModificada 0.13642849793035763
# --- 124.30192685127258 s seconds to perform iteration number: 1553 ---
# -- Generation 1554 --
#   FobjModificada 0.1364304675744059
# --- 126.26000475883484 s seconds to perform iteration number: 1554 ---
# -- Generation 1555 --
#   FobjModificada 0.13643243848714612
# --- 127.14049315452576 s seconds to perform iteration number: 1555 ---
# -- Generation 1556 --
#   FobjModificada 0.13643441066857806
# --- 126.8322525024414 s seconds to perform iteration number: 1556 ---
# -- Generation 1557 --
#   FobjModificada 0.13643638411870185
# --- 126.18596625328064 s seconds to perform iteration number: 1557 ---
# -- Generation 1558 --
#   FobjModificada 0.13643835883751748
# --- 124.68187260627747 s seconds to perform iteration number: 1558 ---
# -- Generation 1559 --
#   FobjModificada 0.13644033482502488
# --- 126.75250506401062 s seconds to perform iteration number: 1559 ---
# -- Generation 1560 --
#   FobjModificada 0.13644231208122412
# --- 124.64778709411621 s seconds to perform iteration number: 1560 ---
# -- Generation 1561 --
#   FobjModificada 0.1364442906061152
# --- 128.77846479415894 s seconds to perform iteration number: 1561 ---
# -- Generation 1562 --
#   FobjModificada 0.13644627039969806
# --- 124.70454478263855 s seconds to perform iteration number: 1562 ---
# -- Generation 1563 --
#   FobjModificada 0.13644825146197273
# --- 128.10461807250977 s seconds to perform iteration number: 1563 ---
# -- Generation 1564 --
#   FobjModificada 0.13645023379293925
# --- 127.84662508964539 s seconds to perform iteration number: 1564 ---
# -- Generation 1565 --
#   FobjModificada 0.13645221739259764
# --- 126.84982395172119 s seconds to perform iteration number: 1565 ---
# -- Generation 1566 --
#   FobjModificada 0.1364542022609478
# --- 126.17848658561707 s seconds to perform iteration number: 1566 ---
# -- Generation 1567 --
#   FobjModificada 0.13645618839798976
# --- 125.5263876914978 s seconds to perform iteration number: 1567 ---
# -- Generation 1568 --
#   FobjModificada 0.1364581758037235
# --- 126.28964567184448 s seconds to perform iteration number: 1568 ---
# -- Generation 1569 --
#   FobjModificada 0.13646016447814913
# --- 127.20681691169739 s seconds to perform iteration number: 1569 ---
# -- Generation 1570 --
#   FobjModificada 0.13646215442126655
# --- 126.31742715835571 s seconds to perform iteration number: 1570 ---
# -- Generation 1571 --
#   FobjModificada 0.13646414563307582
# --- 125.06454229354858 s seconds to perform iteration number: 1571 ---
# -- Generation 1572 --
#   FobjModificada 0.13646613811357688
# --- 128.0677969455719 s seconds to perform iteration number: 1572 ---
# -- Generation 1573 --
#   FobjModificada 0.13646813186276976
# --- 126.2714204788208 s seconds to perform iteration number: 1573 ---
# -- Generation 1574 --
#   FobjModificada 0.13647012688065446
# --- 126.40018272399902 s seconds to perform iteration number: 1574 ---
# -- Generation 1575 --
#   FobjModificada 0.13647212316723095
# --- 125.18174338340759 s seconds to perform iteration number: 1575 ---
# -- Generation 1576 --
#   FobjModificada 0.13647412072249931
# --- 124.7909345626831 s seconds to perform iteration number: 1576 ---
# -- Generation 1577 --
#   FobjModificada 0.1364761195464595
# --- 125.33925461769104 s seconds to perform iteration number: 1577 ---
# -- Generation 1578 --
#   FobjModificada 0.13647811963911147
# --- 125.5460147857666 s seconds to perform iteration number: 1578 ---
# -- Generation 1579 --
#   FobjModificada 0.13648012100045523
# --- 126.89060616493225 s seconds to perform iteration number: 1579 ---
# -- Generation 1580 --
#   FobjModificada 0.1364821236304909
# --- 125.27064824104309 s seconds to perform iteration number: 1580 ---
# -- Generation 1581 --
#   FobjModificada 0.1364841275292183
# --- 124.47267127037048 s seconds to perform iteration number: 1581 ---
# -- Generation 1582 --
#   FobjModificada 0.13648613269663754
# --- 124.89349389076233 s seconds to perform iteration number: 1582 ---
# -- Generation 1583 --
#   FobjModificada 0.13648813913274863
# --- 125.54695105552673 s seconds to perform iteration number: 1583 ---
# -- Generation 1584 --
#   FobjModificada 0.1364901468375515
# --- 125.90105652809143 s seconds to perform iteration number: 1584 ---
# -- Generation 1585 --
#   FobjModificada 0.13649215581104623
# --- 125.09178185462952 s seconds to perform iteration number: 1585 ---
# -- Generation 1586 --
#   FobjModificada 0.13649416605323275
# --- 125.45143985748291 s seconds to perform iteration number: 1586 ---
# -- Generation 1587 --
#   FobjModificada 0.13649617756411112
# --- 125.1669225692749 s seconds to perform iteration number: 1587 ---
# -- Generation 1588 --
#   FobjModificada 0.1364981903436812
# --- 124.15294241905212 s seconds to perform iteration number: 1588 ---
# -- Generation 1589 --
#   FobjModificada 0.13650020439194327
# --- 125.38529443740845 s seconds to perform iteration number: 1589 ---
# -- Generation 1590 --
#   FobjModificada 0.13650221970889703
# --- 125.71586537361145 s seconds to perform iteration number: 1590 ---
# -- Generation 1591 --
#   FobjModificada 0.1365042362945426
# --- 126.26972579956055 s seconds to perform iteration number: 1591 ---
# -- Generation 1592 --
#   FobjModificada 0.13650625414888007
# --- 127.90563201904297 s seconds to perform iteration number: 1592 ---
# -- Generation 1593 --
#   FobjModificada 0.13650827327190931
# --- 126.43631148338318 s seconds to perform iteration number: 1593 ---
# -- Generation 1594 --
#   FobjModificada 0.1365102936636304
# --- 124.64422869682312 s seconds to perform iteration number: 1594 ---
# -- Generation 1595 --
#   FobjModificada 0.1365123153240433
# --- 124.66082119941711 s seconds to perform iteration number: 1595 ---
# -- Generation 1596 --
#   FobjModificada 0.136514338253148
# --- 125.34314560890198 s seconds to perform iteration number: 1596 ---
# -- Generation 1597 --
#   FobjModificada 0.13651636245094453
# --- 125.83763837814331 s seconds to perform iteration number: 1597 ---
# -- Generation 1598 --
#   FobjModificada 0.13651838791743287
# --- 126.18737864494324 s seconds to perform iteration number: 1598 ---
# -- Generation 1599 --
#   FobjModificada 0.13652041465261303
# --- 125.96957349777222 s seconds to perform iteration number: 1599 ---
# -- Generation 1600 --

# %%
import numpy as np
import pandas as pd
import nltk
import re
import joblib
import gensim.corpora as corpora
from gensim.corpora import MmCorpus
from nltk.tokenize import TweetTokenizer
from wordfreq import top_n_list
from collections import Counter

import os

from time import time

from numpy import *
import math
import matplotlib.pyplot as plt


from gensim.models.coherencemodel import CoherenceModel

from nltk import FreqDist
from nltk.stem.snowball import SnowballStemmer
from nltk.corpus import stopwords
import string

import gensim
import spacy
import en_core_web_sm

import pyLDAvis.gensim

# %% [markdown]
# # Model number

# %%
y = 3

# %% [markdown]
# # Dataset

# %%
df = pd.read_csv("../../../Data_Extract&Analysis/uber_support_csv_with_duplicates/uber_support.csv")
df.shape
# Out:
# (223474, 35)

# %% [markdown]
# ## Drop duplicates

# %%
df.drop_duplicates(inplace=True, subset="tweet")

# %%
df
# Out:
#        cashtags    created_at                 date  day  geo  \
# 0            []  1.585699e+12  2020-03-31 23:58:31  2.0  NaN
# 1            []  1.585699e+12  2020-03-31 23:52:51  2.0  NaN
# 2            []  1.585699e+12  2020-03-31 23:51:11  2.0  NaN
# 3            []  1.585699e+12  2020-03-31 23:50:58  2.0  NaN
# 4            []  1.585698e+12  2020-03-31 23:46:27  2.0  NaN
# 5            []  1.585698e+12  2020-03-31 23:40:39  2.0  NaN
# 6            []  1.585698e+12  2020-03-31 23:33:37  2.0  NaN
# 7            []  1.585697e+12  2020-03-31 23:28:49  2.0  NaN
# 8            []  1.585697e+12  2020-03-31 23:28:13  2.0  NaN
# 9            []  1.585697e+12  2020-03-31 23:27:48  2.0  NaN
# 10           []  1.585697e+12  2020-03-31 23:21:43  2.0  NaN
# 11           []  1.585697e+12  2020-03-31 23:21:19  2.0  NaN
# 12           []  1.585697e+12  2020-03-31 23:15:19  2.0  NaN
# 13           []  1.585696e+12  2020-03-31 23:13:14  2.0  NaN
# 14           []  1.585696e+12  2020-03-31 23:11:02  2.0  NaN
# 15           []  1.585696e+12  2020-03-31 23:08:01  2.0  NaN
# 16           []  1.585696e+12  2020-03-31 23:03:40  2.0  NaN
# 17           []  1.585696e+12  2020-03-31 23:03:10  2.0  NaN
# 18           []  1.585696e+12  2020-03-31 23:01:09  2.0  NaN
# 19           []  1.585695e+12  2020-03-31 22:56:23  2.0  NaN
# 20           []  1.585695e+12  2020-03-31 22:56:21  2.0  NaN
# 21           []  1.585695e+12  2020-03-31 22:45:14  2.0  NaN
# 22           []  1.585694e+12  2020-03-31 22:35:29  2.0  NaN
# 23           []  1.585694e+12  2020-03-31 22:31:58  2.0  NaN
# 24           []  1.585694e+12  2020-03-31 22:29:11  2.0  NaN
# 25           []  1.585694e+12  2020-03-31 22:29:00  2.0  NaN
# 26           []  1.585694e+12  2020-03-31 22:27:48  2.0  NaN
# 27           []  1.585693e+12  2020-03-31 22:23:50  2.0  NaN
# 28           []  1.585693e+12  2020-03-31 22:22:34  2.0  NaN
# 29           []  1.585693e+12  2020-03-31 22:19:37  2.0  NaN
# ...         ...           ...                  ...  ...  ...
# 223444       []  1.596243e+12  2020-08-01 00:51:04  6.0  NaN
# 223445       []  1.596243e+12  2020-08-01 00:49:17  6.0  NaN
# 223446       []  1.596243e+12  2020-08-01 00:48:03  6.0  NaN
# 223447       []  1.596243e+12  2020-08-01 00:46:54  6.0  NaN
# 223448       []  1.596243e+12  2020-08-01 00:46:25  6.0  NaN
# 223449       []  1.596243e+12  2020-08-01 00:44:06  6.0  NaN
# 223450       []  1.596243e+12  2020-08-01 00:42:04  6.0  NaN
# 223451       []  1.596243e+12  2020-08-01 00:42:02  6.0  NaN
# 223452       []  1.596242e+12  2020-08-01 00:38:52  6.0  NaN
# 223453       []  1.596242e+12  2020-08-01 00:33:55  6.0  NaN
# 223454       []  1.596242e+12  2020-08-01 00:31:31  6.0  NaN
# 223455       []  1.596242e+12  2020-08-01 00:31:01  6.0  NaN
# 223456       []  1.596242e+12  2020-08-01 00:26:49  6.0  NaN
# 223457       []  1.596242e+12  2020-08-01 00:26:20  6.0  NaN
# 223458       []  1.596241e+12  2020-08-01 00:23:11  6.0  NaN
# 223459       []  1.596241e+12  2020-08-01 00:22:35  6.0  NaN
# 223460       []  1.596241e+12  2020-08-01 00:21:36  6.0  NaN
# 223461       []  1.596241e+12  2020-08-01 00:20:50  6.0  NaN
# 223462       []  1.596241e+12  2020-08-01 00:19:58  6.0  NaN
# 223463       []  1.596241e+12  2020-08-01 00:17:31  6.0  NaN
# 223464       []  1.596241e+12  2020-08-01 00:13:43  6.0  NaN
# 223465       []  1.596241e+12  2020-08-01 00:09:15  6.0  NaN
# 223466       []  1.596240e+12  2020-08-01 00:07:52  6.0  NaN
# 223467       []  1.596240e+12  2020-08-01 00:07:31  6.0  NaN
# 223468       []  1.596240e+12  2020-08-01 00:07:25  6.0  NaN
# 223469       []  1.596240e+12  2020-08-01 00:06:47  6.0  NaN
# 223470       []  1.596240e+12  2020-08-01 00:06:36  6.0  NaN
# 223471       []  1.596240e+12  2020-08-01 00:04:39  6.0  NaN
# 223472       []  1.596240e+12  2020-08-01 00:00:41  6.0  NaN
# 223473       []  1.596240e+12  2020-08-01 00:00:10  6.0  NaN
#
#                  hashtags  hour            id language  \
# 0                      []  23.0  1.245138e+18       en
# 1                      []  23.0  1.245137e+18       en
# 2                      []  23.0  1.245137e+18       en
# 3                      []  23.0  1.245137e+18       en
# 4                      []  23.0  1.245135e+18       en
# 5                      []  23.0  1.245134e+18       en
# 6                      []  23.0  1.245132e+18       en
# 7                      []  23.0  1.245131e+18       en
# 8                      []  23.0  1.245131e+18       en
# 9                      []  23.0  1.245131e+18       en
# 10                     []  23.0  1.245129e+18       en
# 11                     []  23.0  1.245129e+18       en
# 12                     []  23.0  1.245128e+18       en
# 13                     []  23.0  1.245127e+18       en
# 14                     []  23.0  1.245126e+18       en
# 15                     []  23.0  1.245126e+18       en
# 16                     []  23.0  1.245125e+18       en
# 17                     []  23.0  1.245125e+18       en
# 18                     []  23.0  1.245124e+18       en
# 19                     []  22.0  1.245123e+18       en
# 20                     []  22.0  1.245123e+18       en
# 21                     []  22.0  1.245120e+18       en
# 22                     []  22.0  1.245118e+18       en
# 23                     []  22.0  1.245117e+18       en
# 24                     []  22.0  1.245116e+18       en
# 25                     []  22.0  1.245116e+18       en
# 26                     []  22.0  1.245116e+18       en
# 27                     []  22.0  1.245115e+18       en
# 28                     []  22.0  1.245114e+18       en
# 29                     []  22.0  1.245114e+18       en
# ...                   ...   ...           ...      ...
# 223444                 []   0.0  1.289363e+18       en
# 223445                 []   0.0  1.289363e+18       en
# 223446                 []   0.0  1.289362e+18       en
# 223447                 []   0.0  1.289362e+18       en
# 223448                 []   0.0  1.289362e+18       en
# 223449                 []   0.0  1.289361e+18       en
# 223450                 []   0.0  1.289361e+18       en
# 223451                 []   0.0  1.289361e+18       en
# 223452                 []   0.0  1.289360e+18       en
# 223453                 []   0.0  1.289359e+18       en
# 223454                 []   0.0  1.289358e+18       en
# 223455                 []   0.0  1.289358e+18       en
# 223456                 []   0.0  1.289357e+18       en
# 223457                 []   0.0  1.289357e+18       en
# 223458                 []   0.0  1.289356e+18       en
# 223459                 []   0.0  1.289356e+18       en
# 223460                 []   0.0  1.289356e+18       en
# 223461                 []   0.0  1.289355e+18       en
# 223462  ['garrettfoster']   0.0  1.289355e+18       en
# 223463                 []   0.0  1.289355e+18       en
# 223464                 []   0.0  1.289354e+18       en
# 223465                 []   0.0  1.289352e+18       en
# 223466                 []   0.0  1.289352e+18       en
# 223467                 []   0.0  1.289352e+18       en
# 223468                 []   0.0  1.289352e+18       en
# 223469                 []   0.0  1.289352e+18       en
# 223470                 []   0.0  1.289352e+18       en
# 223471                 []   0.0  1.289351e+18       en
# 223472                 []   0.0  1.289350e+18       en
# 223473                 []   0.0  1.289350e+18       en
#
#                                                      link  ...   trans_src  \
# 0       https://twitter.com/ExposedUber/status/1245138...  ...         NaN
# 1       https://twitter.com/ExposedUber/status/1245137...  ...         NaN
# 2       https://twitter.com/ExposedUber/status/1245136...  ...         NaN
# 3       https://twitter.com/cjm118/status/124513653487...  ...         NaN
# 4       https://twitter.com/Behemoth0089/status/124513...  ...         NaN
# 5       https://twitter.com/James201185/status/1245133...  ...         NaN
# 6       https://twitter.com/IPCusername/status/1245132...  ...         NaN
# 7       https://twitter.com/JohnKir74833568/status/124...  ...         NaN
# 8       https://twitter.com/OneTruGreenberg/status/124...  ...         NaN
# 9       https://twitter.com/fwhatdo/status/12451307070...  ...         NaN
# 10      https://twitter.com/1Chronicler/status/1245129...  ...         NaN
# 11      https://twitter.com/andrew_the_pom/status/1245...  ...         NaN
# 12      https://twitter.com/bryantabares/status/124512...  ...         NaN
# 13      https://twitter.com/wonderfunk99/status/124512...  ...         NaN
# 14      https://twitter.com/cherylj22/status/124512648...  ...         NaN
# 15      https://twitter.com/Jigsawbanks/status/1245125...  ...         NaN
# 16      https://twitter.com/kayceeprag/status/12451246...  ...         NaN
# 17      https://twitter.com/Tanyabie7788/status/124512...  ...         NaN
# 18      https://twitter.com/megan_philibin/status/1245...  ...         NaN
# 19      https://twitter.com/Gabrielbryant1/status/1245...  ...         NaN
# 20      https://twitter.com/larrynannery/status/124512...  ...         NaN
# 21      https://twitter.com/alinyode/status/1245119996...  ...         NaN
# 22      https://twitter.com/HoneysCloset216/status/124...  ...         NaN
# 23      https://twitter.com/naagkartileh/status/124511...  ...         NaN
# 24      https://twitter.com/Mark38319218/status/124511...  ...         NaN
# 25      https://twitter.com/HaydenTHEBMXER/status/1245...  ...         NaN
# 26      https://twitter.com/BSofaspud/status/124511560...  ...         NaN
# 27      https://twitter.com/coachdoyle44/status/124511...  ...         NaN
# 28      https://twitter.com/CMYK_Avenger/status/124511...  ...         NaN
# 29      https://twitter.com/alirazak27/status/12451135...  ...         NaN
# ...                                                   ...  ...         ...
# 223444  https://twitter.com/esteeelaudeer/status/12893...  ...         NaN
# 223445  https://twitter.com/ariellec/status/1289362532...  ...         NaN
# 223446  https://twitter.com/bakahoe2/status/1289362222...  ...         NaN
# 223447  https://twitter.com/AndrewKam/status/128936193...  ...         NaN
# 223448  https://twitter.com/MrEakins/status/1289361811...  ...         NaN
# 223449  https://twitter.com/JellyBunny8/status/1289361...  ...         NaN
# 223450  https://twitter.com/lukegash/status/1289360716...  ...         NaN
# 223451  https://twitter.com/ariellec/status/1289360705...  ...         NaN
# 223452  https://twitter.com/AndrewKam/status/128935991...  ...         NaN
# 223453  https://twitter.com/BWS58/status/1289358666152...  ...         NaN
# 223454  https://twitter.com/MistressVice/status/128935...  ...         NaN
# 223455  https://twitter.com/karlafancyy/status/1289357...  ...         NaN
# 223456  https://twitter.com/GaryAllenMiles/status/1289...  ...         NaN
# 223457  https://twitter.com/Rae_Bay/status/12893567578...  ...         NaN
# 223458  https://twitter.com/Paulamaya2001/status/12893...  ...         NaN
# 223459  https://twitter.com/TheBillyBShow/status/12893...  ...         NaN
# 223460  https://twitter.com/KitOConnell/status/1289355...  ...         NaN
# 223461  https://twitter.com/BigMoeDC/status/1289355371...  ...         NaN
# 223462  https://twitter.com/KitOConnell/status/1289355...  ...         NaN
# 223463  https://twitter.com/gailifshin/status/12893545...  ...         NaN
# 223464  https://twitter.com/DeJai24/status/12893535804...  ...         NaN
# 223465  https://twitter.com/KitOConnell/status/1289352...  ...         NaN
# 223466  https://twitter.com/lostcooky/status/128935210...  ...         NaN
# 223467  https://twitter.com/kittenpocalypse/status/128...  ...         NaN
# 223468  https://twitter.com/NEWTSONLY1/status/12893519...  ...         NaN
# 223469  https://twitter.com/decemberangel86/status/128...  ...         NaN
# 223470  https://twitter.com/haleyluu_/status/128935179...  ...         NaN
# 223471  https://twitter.com/ninjitalia/status/12893513...  ...         NaN
# 223472  https://twitter.com/raveneverdies/status/12893...  ...         NaN
# 223473  https://twitter.com/dcooode/status/12893501727...  ...         NaN
#
#         translate                                              tweet  \
# 0             NaN  @LauraKellyKS @KansasGOP why did @Uber_Support...
# 1             NaN  @Uber_Support why did @Uber_Support and uber  ...
# 2             NaN  why did @Uber_Support @Uber not follow thru wi...
# 3             NaN  Same song and dance @Uber @Uber_Support @dkhos...
# 4             NaN  @Uber_Support Hey, I'm receiving ride reports ...
# 5             NaN                                 @Uber_Support Done
# 6             NaN  @Uber_Support Uber gives me a ride request the...
# 7             NaN  @Uber_Support No way. I’m not worried about my...
# 8             NaN  @Uber_Support I'm trying to file for my Califo...
# 9             NaN  @Uber_Support Please @Uber_Support answer me i...
# 10            NaN  @Uber_Support Why is there no contact info? Ho...
# 11            NaN  @Uber_Support Read my original tweet and answe...
# 12            NaN  @Uber_Support how are you handling the drivers...
# 13            NaN  @Uber_Support my insurance has been pending ap...
# 14            NaN  @Uber_Support hello ordered 70$ worth of east ...
# 15            NaN  @Uber_Support That wasn't help it was justific...
# 16            NaN  Hi @Uber_Support,   Is there any way my @Ubere...
# 17            NaN  @Uber_Support I called multiple times and no o...
# 18            NaN  @Uber_Support  Is Uber going to provide driver...
# 19            NaN  @Uber_Support Our local greenlight hub support...
# 20            NaN  Can you help with an uber eats order issue @Ub...
# 21            NaN  @Uber_Support hello, i have to recieve my ther...
# 22            NaN           @dkhos  still nothing from @Uber_Support
# 23            NaN  @Uber_Support @uber why is no one checking my ...
# 24            NaN  @Uber_Support Latin Creations is  now Senor Fr...
# 25            NaN  @Uber_Support The email is haydenmechielsen@gm...
# 26            NaN  @Uber_Support don't ya just love getting charg...
# 27            NaN  @Uber @Uber_Support @dkhos m hoping that someo...
# 28            NaN  @Uber_Support I ordered, the restaurant screwe...
# 29            NaN  @Uber_Support  why did you deny @txthtxllxer c...
# ...           ...                                                ...
# 223444        NaN  @Uber_Support Please check your DMs as I just ...
# 223445        NaN  @AndrewKam @AskLyft @Uber_Support I’m sorry. ☹...
# 223446        NaN  Soo why is @Uber_Support are you committing fr...
# 223447        NaN  @ariellec @AskLyft @Uber_Support I used to nev...
# 223448        NaN  @Uber_Support how do I get in contact with som...
# 223449        NaN  Still screaming about how absolutely awful Ube...
# 223450        NaN  @UberEats @Uber_Support  my Amex $15 cash does...
# 223451        NaN  @AndrewKam @AskLyft @Uber_Support Don’t put a ...
# 223452        NaN  Do @AskLyft or @Uber_Support drivers see your ...
# 223453        NaN  @Uber_Support So your uber eats sends me an em...
# 223454        NaN  How the fuck does uber Eats stay in business w...
# 223455        NaN  @Uber_Support How is that possible if I litera...
# 223456        NaN  @Uber_Support I have t received an Uber Eats r...
# 223457        NaN  @UberEats is terrible, my order is either wron...
# 223458        NaN  @Uber_Support Just saw it I replied could you ...
# 223459        NaN  @Uber @UberEats @Uber_Support y’all suck  http...
# 223460        NaN  @Uber @lyft @chadloder @Uber_Support In additi...
# 223461        NaN  @Uber_Support Why yall tell me to dm yall if y...
# 223462        NaN  @Uber @lyft @chadloder @Uber_Support Another U...
# 223463        NaN  wow @ubereats...you see $900+ of charges in on...
# 223464        NaN  @UberEats @Uber_Support I will literally pay e...
# 223465        NaN  @Uber @lyft @chadloder @Uber_Support Update: L...
# 223466        NaN  @Uber_Support - it's unacceptable that I pre-o...
# 223467        NaN  @Real_CGThomas @Uber @Uber_Support @dkhos @che...
# 223468        NaN  @Uber_Support @becauseoflwt yeah that same guy...
# 223469        NaN      @Uber_Support need help asap on current order
# 223470        NaN           @Uber_Support Nothing got resolved  🤷‍♀️
# 223471        NaN  @Uber_Support @Tesla 2 trips in a row now as I...
# 223472        NaN  after @Uber_Support card changed, they did not...
# 223473        NaN  @Uber_Support How is UberEats "Not available i...
#
#                                                      urls       user_id  \
# 0                                                      []  1.142463e+18
# 1                                                      []  1.142463e+18
# 2                                                      []  1.142463e+18
# 3                                                      []  2.588586e+07
# 4                                                      []  9.841742e+07
# 5                                                      []  2.346636e+07
# 6                                                      []  1.132059e+18
# 7                                                      []  1.244829e+18
# 8                                                      []  1.007368e+08
# 9                                                      []  5.505001e+08
# 10                                                     []  4.138178e+07
# 11                                                     []  5.892575e+08
# 12                                                     []  1.307516e+08
# 13                                                     []  1.836272e+07
# 14                                                     []  3.302313e+07
# 15                                                     []  2.234427e+09
# 16                                                     []  1.064708e+08
# 17                                                     []  8.696494e+17
# 18                                                     []  2.227457e+09
# 19                                                     []  2.598860e+07
# 20                                                     []  2.019226e+07
# 21                                                     []  2.617035e+09
# 22                                                     []  1.133582e+18
# 23                                                     []  9.552132e+17
# 24                                                     []  9.129759e+17
# 25                                                     []  2.094115e+08
# 26                                                     []  1.035643e+18
# 27                                                     []  2.938308e+08
# 28                                                     []  4.170392e+08
# 29                                                     []  8.457477e+08
# ...                                                   ...           ...
# 223444                                                 []  1.131036e+18
# 223445                                                 []  9.149492e+06
# 223446                                                 []  1.282174e+18
# 223447                                                 []  8.678970e+07
# 223448                                                 []  1.323863e+08
# 223449                                                 []  1.054533e+18
# 223450                                                 []  8.044489e+07
# 223451                                                 []  9.149492e+06
# 223452                                                 []  8.678970e+07
# 223453                                                 []  4.944674e+07
# 223454                                                 []  9.995789e+17
# 223455                                                 []  2.438006e+09
# 223456                                                 []  9.980284e+07
# 223457                                                 []  3.061190e+07
# 223458                                                 []  2.843227e+09
# 223459                                                 []  2.662840e+08
# 223460                                                 []  2.094630e+07
# 223461                                                 []  1.599579e+08
# 223462                                                 []  2.094630e+07
# 223463                                                 []  9.467706e+07
# 223464                                                 []  1.041376e+18
# 223465  ['https://twitter.com/alcaprari23/status/12893...  2.094630e+07
# 223466                                                 []  7.624521e+07
# 223467                                                 []  4.141801e+09
# 223468                                                 []  1.180914e+18
# 223469                                                 []  1.258379e+09
# 223470                                                 []  3.838520e+08
# 223471                                                 []  1.800323e+08
# 223472                                                 []  5.038246e+08
# 223473                                                 []  2.941674e+09
#
#          user_id_str user_rt user_rt_id         username  video
# 0       1.142463e+18     NaN        NaN      ExposedUber    0.0
# 1       1.142463e+18     NaN        NaN      ExposedUber    0.0
# 2       1.142463e+18     NaN        NaN      ExposedUber    0.0
# 3       2.588586e+07     NaN        NaN           cjm118    1.0
# 4       9.841742e+07     NaN        NaN     Behemoth0089    0.0
# 5       2.346636e+07     NaN        NaN      James201185    0.0
# 6       1.132059e+18     NaN        NaN      IPCusername    0.0
# 7       1.244829e+18     NaN        NaN  JohnKir74833568    0.0
# 8       1.007368e+08     NaN        NaN  OneTruGreenberg    0.0
# 9       5.505001e+08     NaN        NaN          fwhatdo    0.0
# 10      4.138178e+07     NaN        NaN      1Chronicler    0.0
# 11      5.892575e+08     NaN        NaN   andrew_the_pom    0.0
# 12      1.307516e+08     NaN        NaN     bryantabares    0.0
# 13      1.836272e+07     NaN        NaN     wonderfunk99    0.0
# 14      3.302313e+07     NaN        NaN        cherylj22    0.0
# 15      2.234427e+09     NaN        NaN      Jigsawbanks    0.0
# 16      1.064708e+08     NaN        NaN       kayceeprag    0.0
# 17      8.696494e+17     NaN        NaN     Tanyabie7788    0.0
# 18      2.227457e+09     NaN        NaN   megan_philibin    0.0
# 19      2.598860e+07     NaN        NaN   Gabrielbryant1    1.0
# 20      2.019226e+07     NaN        NaN     larrynannery    0.0
# 21      2.617035e+09     NaN        NaN         alinyode    0.0
# 22      1.133582e+18     NaN        NaN  HoneysCloset216    0.0
# 23      9.552132e+17     NaN        NaN     naagkartileh    0.0
# 24      9.129759e+17     NaN        NaN     Mark38319218    0.0
# 25      2.094115e+08     NaN        NaN   HaydenTHEBMXER    0.0
# 26      1.035643e+18     NaN        NaN        BSofaspud    0.0
# 27      2.938308e+08     NaN        NaN     coachdoyle44    0.0
# 28      4.170392e+08     NaN        NaN     CMYK_Avenger    0.0
# 29      8.457477e+08     NaN        NaN       alirazak27    1.0
# ...              ...     ...        ...              ...    ...
# 223444  1.131036e+18     NaN        NaN    esteeelaudeer    0.0
# 223445  9.149492e+06     NaN        NaN         ariellec    0.0
# 223446  1.282174e+18     NaN        NaN         bakahoe2    0.0
# 223447  8.678970e+07     NaN        NaN        AndrewKam    0.0
# 223448  1.323863e+08     NaN        NaN         MrEakins    0.0
# 223449  1.054533e+18     NaN        NaN      JellyBunny8    1.0
# 223450  8.044489e+07     NaN        NaN         lukegash    0.0
# 223451  9.149492e+06     NaN        NaN         ariellec    0.0
# 223452  8.678970e+07     NaN        NaN        AndrewKam    0.0
# 223453  4.944674e+07     NaN        NaN            BWS58    0.0
# 223454  9.995789e+17     NaN        NaN     MistressVice    0.0
# 223455  2.438006e+09     NaN        NaN      karlafancyy    0.0
# 223456  9.980284e+07     NaN        NaN   GaryAllenMiles    0.0
# 223457  3.061190e+07     NaN        NaN          Rae_Bay    0.0
# 223458  2.843227e+09     NaN        NaN    Paulamaya2001    0.0
# 223459  2.662840e+08     NaN        NaN    TheBillyBShow    1.0
# 223460  2.094630e+07     NaN        NaN      KitOConnell    0.0
# 223461  1.599579e+08     NaN        NaN         BigMoeDC    0.0
# 223462  2.094630e+07     NaN        NaN      KitOConnell    1.0
# 223463  9.467706e+07     NaN        NaN       gailifshin    0.0
# 223464  1.041376e+18     NaN        NaN          DeJai24    0.0
# 223465  2.094630e+07     NaN        NaN      KitOConnell    0.0
# 223466  7.624521e+07     NaN        NaN        lostcooky    0.0
# 223467  4.141801e+09     NaN        NaN  kittenpocalypse    0.0
# 223468  1.180914e+18     NaN        NaN       NEWTSONLY1    1.0
# 223469  1.258379e+09     NaN        NaN  decemberangel86    0.0
# 223470  3.838520e+08     NaN        NaN        haleyluu_    0.0
# 223471  1.800323e+08     NaN        NaN       ninjitalia    0.0
# 223472  5.038246e+08     NaN        NaN    raveneverdies    0.0
# 223473  2.941674e+09     NaN        NaN          dcooode    1.0
#
# [215387 rows x 35 columns]

# %% [markdown]
# # Functions

# %% [markdown]
# ## Emoticons variable

# %%
EMOTICONS = {
    u":‑\)":"Happy face or smiley",
    u":\)":"Happy face or smiley",
    u":-\]":"Happy face or smiley",
    u":\]":"Happy face or smiley",
    u":-3":"Happy face smiley",
    u":3":"Happy face smiley",
    u":->":"Happy face smiley",
    u":>":"Happy face smiley",
    u"8-\)":"Happy face smiley",
    u":o\)":"Happy face smiley",
    u":-\}":"Happy face smiley",
    u":\}":"Happy face smiley",
    u":-\)":"Happy face smiley",
    u":c\)":"Happy face smiley",
    u":\^\)":"Happy face smiley",
    u"=\]":"Happy face smiley",
    u"=\)":"Happy face smiley",
    u":‑D":"Laughing, big grin or laugh with glasses",
    u":D":"Laughing, big grin or laugh with glasses",
    u"8‑D":"Laughing, big grin or laugh with glasses",
    u"8D":"Laughing, big grin or laugh with glasses",
    u"X‑D":"Laughing, big grin or laugh with glasses",
    u"XD":"Laughing, big grin or laugh with glasses",
    u"=D":"Laughing, big grin or laugh with glasses",
    u"=3":"Laughing, big grin or laugh with glasses",
    u"B\^D":"Laughing, big grin or laugh with glasses",
    u":-\)\)":"Very happy",
    u":‑\(":"Frown, sad, andry or pouting",
    u":-\(":"Frown, sad, andry or pouting",
    u":\(":"Frown, sad, andry or pouting",
    u":‑c":"Frown, sad, andry or pouting",
    u":c":"Frown, sad, andry or pouting",
    u":‑<":"Frown, sad, andry or pouting",
    u":<":"Frown, sad, andry or pouting",
    u":‑\[":"Frown, sad, andry or pouting",
    u":\[":"Frown, sad, andry or pouting",
    u":-\|\|":"Frown, sad, andry or pouting",
    u">:\[":"Frown, sad, andry or pouting",
    u":\{":"Frown, sad, andry or pouting",
    u":@":"Frown, sad, andry or pouting",
    u">:\(":"Frown, sad, andry or pouting",
    u":'‑\(":"Crying",
    u":'\(":"Crying",
    u":'‑\)":"Tears of happiness",
    u":'\)":"Tears of happiness",
    u"D‑':":"Horror",
    u"D:<":"Disgust",
    u"D:":"Sadness",
    u"D8":"Great dismay",
    u"D;":"Great dismay",
    u"D=":"Great dismay",
    u"DX":"Great dismay",
    u":‑O":"Surprise",
    u":O":"Surprise",
    u":‑o":"Surprise",
    u":o":"Surprise",
    u":-0":"Shock",
    u"8‑0":"Yawn",
    u">:O":"Yawn",
    u":-\*":"Kiss",
    u":\*":"Kiss",
    u":X":"Kiss",
    u";‑\)":"Wink or smirk",
    u";\)":"Wink or smirk",
    u"\*-\)":"Wink or smirk",
    u"\*\)":"Wink or smirk",
    u";‑\]":"Wink or smirk",
    u";\]":"Wink or smirk",
    u";\^\)":"Wink or smirk",
    u":‑,":"Wink or smirk",
    u";D":"Wink or smirk",
    u":‑P":"Tongue sticking out, cheeky, playful or blowing a raspberry",
    u":P":"Tongue sticking out, cheeky, playful or blowing a raspberry",
    u"X‑P":"Tongue sticking out, cheeky, playful or blowing a raspberry",
    u"XP":"Tongue sticking out, cheeky, playful or blowing a raspberry",
    u":‑Þ":"Tongue sticking out, cheeky, playful or blowing a raspberry",
    u":Þ":"Tongue sticking out, cheeky, playful or blowing a raspberry",
    u":b":"Tongue sticking out, cheeky, playful or blowing a raspberry",
    u"d:":"Tongue sticking out, cheeky, playful or blowing a raspberry",
    u"=p":"Tongue sticking out, cheeky, playful or blowing a raspberry",
    u">:P":"Tongue sticking out, cheeky, playful or blowing a raspberry",
    u":‑/":"Skeptical, annoyed, undecided, uneasy or hesitant",
    u":/":"Skeptical, annoyed, undecided, uneasy or hesitant",
    u":-[.]":"Skeptical, annoyed, undecided, uneasy or hesitant",
    u">:[(\\\)]":"Skeptical, annoyed, undecided, uneasy or hesitant",
    u">:/":"Skeptical, annoyed, undecided, uneasy or hesitant",
    u":[(\\\)]":"Skeptical, annoyed, undecided, uneasy or hesitant",
    u"=/":"Skeptical, annoyed, undecided, uneasy or hesitant",
    u"=[(\\\)]":"Skeptical, annoyed, undecided, uneasy or hesitant",
    u":L":"Skeptical, annoyed, undecided, uneasy or hesitant",
    u"=L":"Skeptical, annoyed, undecided, uneasy or hesitant",
    u":S":"Skeptical, annoyed, undecided, uneasy or hesitant",
    u":‑\|":"Straight face",
    u":\|":"Straight face",
    u":$":"Embarrassed or blushing",
    u":‑x":"Sealed lips or wearing braces or tongue-tied",
    u":x":"Sealed lips or wearing braces or tongue-tied",
    u":‑#":"Sealed lips or wearing braces or tongue-tied",
    u":#":"Sealed lips or wearing braces or tongue-tied",
    u":‑&":"Sealed lips or wearing braces or tongue-tied",
    u":&":"Sealed lips or wearing braces or tongue-tied",
    u"O:‑\)":"Angel, saint or innocent",
    u"O:\)":"Angel, saint or innocent",
    u"0:‑3":"Angel, saint or innocent",
    u"0:3":"Angel, saint or innocent",
    u"0:‑\)":"Angel, saint or innocent",
    u"0:\)":"Angel, saint or innocent",
    u":‑b":"Tongue sticking out, cheeky, playful or blowing a raspberry",
    u"0;\^\)":"Angel, saint or innocent",
    u">:‑\)":"Evil or devilish",
    u">:\)":"Evil or devilish",
    u"\}:‑\)":"Evil or devilish",
    u"\}:\)":"Evil or devilish",
    u"3:‑\)":"Evil or devilish",
    u"3:\)":"Evil or devilish",
    u">;\)":"Evil or devilish",
    u"\|;‑\)":"Cool",
    u"\|‑O":"Bored",
    u":‑J":"Tongue-in-cheek",
    u"#‑\)":"Party all night",
    u"%‑\)":"Drunk or confused",
    u"%\)":"Drunk or confused",
    u":-###..":"Being sick",
    u":###..":"Being sick",
    u"<:‑\|":"Dump",
    u"\(>_<\)":"Troubled",
    u"\(>_<\)>":"Troubled",
    u"\(';'\)":"Baby",
    u"\(\^\^>``":"Nervous or Embarrassed or Troubled or Shy or Sweat drop",
    u"\(\^_\^;\)":"Nervous or Embarrassed or Troubled or Shy or Sweat drop",
    u"\(-_-;\)":"Nervous or Embarrassed or Troubled or Shy or Sweat drop",
    u"\(~_~;\) \(・\.・;\)":"Nervous or Embarrassed or Troubled or Shy or Sweat drop",
    u"\(-_-\)zzz":"Sleeping",
    u"\(\^_-\)":"Wink",
    u"\(\(\+_\+\)\)":"Confused",
    u"\(\+o\+\)":"Confused",
    u"\(o\|o\)":"Ultraman",
    u"\^_\^":"Joyful",
    u"\(\^_\^\)/":"Joyful",
    u"\(\^O\^\)／":"Joyful",
    u"\(\^o\^\)／":"Joyful",
    u"\(__\)":"Kowtow as a sign of respect, or dogeza for apology",
    u"_\(\._\.\)_":"Kowtow as a sign of respect, or dogeza for apology",
    u"<\(_ _\)>":"Kowtow as a sign of respect, or dogeza for apology",
    u"<m\(__\)m>":"Kowtow as a sign of respect, or dogeza for apology",
    u"m\(__\)m":"Kowtow as a sign of respect, or dogeza for apology",
    u"m\(_ _\)m":"Kowtow as a sign of respect, or dogeza for apology",
    u"\('_'\)":"Sad or Crying",
    u"\(/_;\)":"Sad or Crying",
    u"\(T_T\) \(;_;\)":"Sad or Crying",
    u"\(;_;":"Sad of Crying",
    u"\(;_:\)":"Sad or Crying",
    u"\(;O;\)":"Sad or Crying",
    u"\(:_;\)":"Sad or Crying",
    u"\(ToT\)":"Sad or Crying",
    u";_;":"Sad or Crying",
    u";-;":"Sad or Crying",
    u";n;":"Sad or Crying",
    u";;":"Sad or Crying",
    u"Q\.Q":"Sad or Crying",
    u"T\.T":"Sad or Crying",
    u"QQ":"Sad or Crying",
    u"Q_Q":"Sad or Crying",
    u"\(-\.-\)":"Shame",
    u"\(-_-\)":"Shame",
    u"\(一一\)":"Shame",
    u"\(；一_一\)":"Shame",
    u"\(=_=\)":"Tired",
    u"\(=\^\·\^=\)":"cat",
    u"\(=\^\·\·\^=\)":"cat",
    u"=_\^=	":"cat",
    u"\(\.\.\)":"Looking down",
    u"\(\._\.\)":"Looking down",
    u"\^m\^":"Giggling with hand covering mouth",
    u"\(\・\・?":"Confusion",
    u"\(?_?\)":"Confusion",
    u">\^_\^<":"Normal Laugh",
    u"<\^!\^>":"Normal Laugh",
    u"\^/\^":"Normal Laugh",
    u"\（\*\^_\^\*）" :"Normal Laugh",
    u"\(\^<\^\) \(\^\.\^\)":"Normal Laugh",
    u"\(^\^\)":"Normal Laugh",
    u"\(\^\.\^\)":"Normal Laugh",
    u"\(\^_\^\.\)":"Normal Laugh",
    u"\(\^_\^\)":"Normal Laugh",
    u"\(\^\^\)":"Normal Laugh",
    u"\(\^J\^\)":"Normal Laugh",
    u"\(\*\^\.\^\*\)":"Normal Laugh",
    u"\(\^—\^\）":"Normal Laugh",
    u"\(#\^\.\^#\)":"Normal Laugh",
    u"\（\^—\^\）":"Waving",
    u"\(;_;\)/~~~":"Waving",
    u"\(\^\.\^\)/~~~":"Waving",
    u"\(-_-\)/~~~ \($\·\·\)/~~~":"Waving",
    u"\(T_T\)/~~~":"Waving",
    u"\(ToT\)/~~~":"Waving",
    u"\(\*\^0\^\*\)":"Excited",
    u"\(\*_\*\)":"Amazed",
    u"\(\*_\*;":"Amazed",
    u"\(\+_\+\) \(@_@\)":"Amazed",
    u"\(\*\^\^\)v":"Laughing,Cheerful",
    u"\(\^_\^\)v":"Laughing,Cheerful",
    u"\(\(d[-_-]b\)\)":"Headphones,Listening to music",
    u'\(-"-\)':"Worried",
    u"\(ーー;\)":"Worried",
    u"\(\^0_0\^\)":"Eyeglasses",
    u"\(\＾ｖ\＾\)":"Happy",
    u"\(\＾ｕ\＾\)":"Happy",
    u"\(\^\)o\(\^\)":"Happy",
    u"\(\^O\^\)":"Happy",
    u"\(\^o\^\)":"Happy",
    u"\)\^o\^\(":"Happy",
    u":O o_O":"Surprised",
    u"o_0":"Surprised",
    u"o\.O":"Surpised",
    u"\(o\.o\)":"Surprised",
    u"oO":"Surprised",
    u"\(\*￣m￣\)":"Dissatisfied",
    u"\(‘A`\)":"Snubbed or Deflated"
}

# %% [markdown]
# ## Preprocess

# %%
def preprocess(words):
    
    tokens = []
   
    # Clean urls, punct, strange characters, emojis, emoticons
    char= re.compile(r'^[a-zA-Z]$')
    punct=re.compile(r'[.,-,:,<,;,(,=]')
    ht = re.compile(r'http.')
    bar = re.compile(r'//*')
    pr = ["rt","@","http","https","'s",'...', 'english', 'translation','):',
          '. .', '..','2-5','<3',']:','“','”','’','. ...','___','__','=(','‘','—','°','¢','•','®','—','…',
          '... .','--->','–','»','«','£','-->','×','->','©','\n','™','¤']
    no_emoji = re.compile("["
                           u"\U0001F600-\U0001F64F"  # emoticons
                           u"\U0001F300-\U0001F5FF"  # symbols & pictographs
                           u"\U0001F680-\U0001F6FF"  # transport & map symbols
                           u"\U0001F1E0-\U0001F1FF"  # flags (iOS)
                           u"\U00002702-\U000027B0"
                           u"\U000024C2-\U0001F251"
                           "]+", flags=re.UNICODE) 
    
    no_emoticon = re.compile(u'(' + u'|'.join(k for k in EMOTICONS) + u')')
    no_html_pattern = re.compile('<.*?>')
    
    stoplist = stopwords.words('english')
    punctuation = set(string.punctuation)
    
   
    # TOKENIZER
    tknzr = TweetTokenizer()
    tokens = tknzr.tokenize(words)
    tokens = [w.lower() for w in tokens] 
    
    #Remove numbers
    pattern = '[0-9]'
    tokens = [re.sub(pattern, '', i) for i in tokens] 
    
    # Punctuation
    tokens = [w for w in tokens if  w not in punctuation]
        
    # Clean emojis,urls,bars
    tokens = [w.replace('#', '') for w in tokens if not w.startswith('@') if w not in pr 
            if not bar.search(w) if not ht.search(w) if not char.search(w) if not punct.search(w)
            if not w.isdigit() if not no_emoji.search(w) if not no_emoticon.search(w) if not no_html_pattern.search(w)]
    
    # Remove non alphanumeric
    tokens = [w for w in tokens if w.isalpha()]

    
    # Remove english stopwords
    tokens = [w for w in tokens if w not in stoplist]
    
    #Remove tokens with length < 1
    tokens = [word for word in tokens if len(word)>1] 
    
    return tokens

# %% [markdown]
# ## Lemmatization

# %%
nlp = en_core_web_sm.load()

def lemmatization(texts, allowed_postags=['NOUN', 'ADJ', 'VERB', 'ADV']):
    """https://spacy.io/api/annotation"""
    texts_out = []
    for sent in texts:
        
        doc = nlp(" ".join(sent)) 
        texts_out.append([token.lemma_ for token in doc if token.pos_ in allowed_postags])
    return texts_out

# %% [markdown]
# ## Preprocess

# %% [markdown]
# ### Simple preprocess

# %%
texts = [preprocess(document) for document in df['tweet']]

# %%
texts
# Out:
# [['follow',
#   'thru',
#   'promise',
#   'disinfecting',
#   'materials',
#   'drivers',
#   'cars',
#   'supplies',
#   'keep',
#   'drivers',
#   'safe',
#   'tele',
#   'agents',
#   'hang',
#   'drivers',
#   'call',
#   'ask',
#   'sbout',
#   'supplies'],
#  ['uber',
#   'follow',
#   'thru',
#   'promise',
#   'disinfecting',
#   'materials',
#   'drivers',
#   'cars',
#   'supplies',
#   'keep',
#   'drivers',
#   'safe',
#   'tele',
#   'agents',
#   'hang',
#   'drivers',
#   'call',
#   'ask',
#   'sbout',
#   'supplies',
#   'explain',
#   'please'],
#  ['follow',
#   'thru',
#   'promise',
#   'disinfecting',
#   'materials',
#   'drivers',
#   'cars',
#   'supplies',
#   'keep',
#   'drivers',
#   'safe',
#   'tele',
#   'agents',
#   'hang',
#   'drivers',
#   'call',
#   'ask',
#   'sbout',
#   'supplies',
#   'explain',
#   'please'],
#  ['song',
#   'dance',
#   'dead',
#   'wrong',
#   'handling',
#   'pandemic',
#   'plight',
#   'workers',
#   'know'],
#  ['hey', 'receiving', 'ride', 'reports', 'email', 'even', 'account', 'guys'],
#  ['done'],
#  ['uber', 'gives', 'ride', 'request', 'go', 'app', 'gone', 'right', 'away'],
#  ['way',
#   'worried',
#   'privacy',
#   'dm',
#   'said',
#   'please',
#   'continue',
#   'working',
#   'support',
#   'team',
#   'even',
#   'though',
#   'one',
#   'emailing',
#   'help',
#   'deception'],
#  ['trying',
#   'file',
#   'california',
#   'state',
#   'unemployment',
#   'insurance',
#   'ever',
#   'since',
#   'pay',
#   'cut',
#   'dramatically',
#   'uber',
#   'ca',
#   'state',
#   'etin',
#   'tried',
#   'find',
#   'number',
#   'call',
#   'hr',
#   'department',
#   'find',
#   'one',
#   'also',
#   'still',
#   'waiting',
#   'file',
#   'tax'],
#  ['please', 'answer', 'message', 'box'],
#  ['contact',
#   'info',
#   'avoid',
#   'charges',
#   'driver',
#   'says',
#   'business',
#   'closed'],
#  ['read', 'original', 'tweet', 'answer', 'question', 'nothing', 'account'],
#  ['handling',
#   'drivers',
#   'situation',
#   'restricted',
#   'lockdown',
#   'example',
#   'panama',
#   'central',
#   'america'],
#  ['insurance', 'pending', 'approval', 'hours'],
#  ['hello',
#   'ordered',
#   'worth',
#   'east',
#   'sides',
#   'came',
#   'cold',
#   'chicken',
#   'cooked',
#   'veggies',
#   'fries',
#   'cooked',
#   'pasta',
#   'cold',
#   'desert',
#   'kids',
#   'meal',
#   'worst',
#   'time',
#   'ever',
#   'eating',
#   'food',
#   'restaurant',
#   'said',
#   'bad',
#   'night',
#   'call',
#   'uber',
#   'refund'],
#  ['help', 'justification', 'horrible', 'practice'],
#  ['hi',
#   'way',
#   'bicycle',
#   'delivery',
#   'profile',
#   'modified',
#   'enable',
#   'use',
#   'vehicle',
#   'provided',
#   'every',
#   'necessary',
#   'nyc',
#   'clearance',
#   'start',
#   'delivery',
#   'vehicle',
#   'thanks',
#   'look',
#   'forward',
#   'getting',
#   'support'],
#  ['called', 'multiple', 'times', 'one', 'approve', 'insurance', 'days'],
#  ['uber',
#   'going',
#   'provide',
#   'drivers',
#   'sanitizing',
#   'wipes',
#   'vehicle',
#   'interiors',
#   'hands',
#   'keep',
#   'seeing',
#   'emails',
#   'yet',
#   'word',
#   'shipment',
#   'products',
#   'actual',
#   'drivers'],
#  ['local',
#   'greenlight',
#   'hub',
#   'support',
#   'offices',
#   'closed',
#   'til',
#   'least',
#   'april',
#   'prob',
#   'longer',
#   'gave',
#   'us',
#   'paper',
#   'call',
#   'uber',
#   'support',
#   'get',
#   'boston',
#   'driver',
#   'certificate',
#   'called',
#   'told',
#   'hubs',
#   'get',
#   'certificate'],
#  ['help', 'uber', 'eats', 'order', 'issue', 'going', 'bonkers'],
#  ['hello',
#   'recieve',
#   'thermal',
#   'bag',
#   'start',
#   'delivery',
#   'job',
#   'went',
#   'office',
#   'told',
#   'closed',
#   'due',
#   'covid',
#   'situation',
#   'hand',
#   'yet',
#   'recieve',
#   'texts',
#   'emails',
#   'everyday',
#   'collection',
#   'told',
#   'back',
#   'th'],
#  ['still', 'nothing'],
#  ['one', 'checking', 'important', 'dm'],
#  ['latin',
#   'creations',
#   'senor',
#   'frog',
#   'cancel',
#   'wrong',
#   'menu',
#   'able',
#   'contact',
#   'branden',
#   'plan'],
#  ['email', 'ever', 'access', 'account', 'changed', 'phone', 'number'],
#  ['ya',
#   'love',
#   'getting',
#   'charged',
#   'cancelling',
#   'driver',
#   'went',
#   'double',
#   'distance',
#   'way',
#   'absolutely',
#   'ridiculous',
#   'second',
#   'time',
#   'shit',
#   'like',
#   'happened',
#   'taken',
#   'money',
#   'reason',
#   'bunch',
#   'thieves'],
#  ['hoping',
#   'someone',
#   'smart',
#   'enough',
#   'realize',
#   'drivers',
#   'keep',
#   'current',
#   'uber',
#   'pro',
#   'status',
#   'time',
#   'fair',
#   'reasonable',
#   'thing',
#   'ask',
#   'people',
#   'ride',
#   'thanks'],
#  ['ordered',
#   'restaurant',
#   'screwed',
#   'order',
#   'talk',
#   'get',
#   'item',
#   'eat',
#   'since',
#   'toppings',
#   'included',
#   'make',
#   'gag'],
#  ['deny', 'claim', 'self', 'isolation', 'compensation'],
#  ['send',
#   'uber',
#   'customer',
#   'service',
#   'number',
#   'live',
#   'person',
#   'stat',
#   'lawyer',
#   'call'],
#  ['stop',
#   'unauthorized',
#   'removal',
#   'funds',
#   'bank',
#   'account',
#   'global',
#   'pandemic',
#   'resources',
#   'already',
#   'scarce',
#   'taken',
#   'uber',
#   'months',
#   'absurd',
#   'give',
#   'money',
#   'back'],
#  ['week',
#   'waiting',
#   'support',
#   'got',
#   'copy',
#   'paste',
#   'reply',
#   'dm',
#   'first',
#   'last',
#   'time',
#   'using',
#   'guys',
#   'understand',
#   'increase',
#   'due',
#   'everything',
#   'going',
#   'week',
#   'insane'],
#  ['anyone',
#   'else',
#   'issues',
#   'second',
#   'day',
#   'row',
#   'food',
#   'never',
#   'arrived',
#   'app',
#   'says',
#   'delivered',
#   'hell'],
#  ['tell', 'deny', 'claim'],
#  ['still', 'received', 'uber', 'eats', 'support'],
#  ['want',
#   'know',
#   'ignored',
#   'weeks',
#   'ok',
#   'completely',
#   'unacceptable',
#   'unprofessional',
#   'company',
#   'blatantly',
#   'lie',
#   'drivers',
#   'covid'],
#  ['app',
#   'talk',
#   'someone',
#   'emails',
#   'charged',
#   'twice',
#   'trip',
#   'car',
#   'never',
#   'showed',
#   'different',
#   'info'],
#  ['please', 'help', 'help'],
#  ['still', 'looking', 'answers'],
#  ['took',
#   'uber',
#   'restaurant',
#   'give',
#   'order',
#   'cause',
#   'given',
#   'driver',
#   'spend',
#   'money',
#   'retrieving',
#   'order',
#   'unsuccessful',
#   'still',
#   'nothing',
#   'support',
#   'good',
#   'enough'],
#  ['weeks', 'unacceptable', 'stated', 'days', 'payment', 'think', 'ok'],
#  ['help', 'uber', 'support', 'wont', 'help', 'please', 'help'],
#  ['tell',
#   'three',
#   'weeks',
#   'since',
#   'waiting',
#   'get',
#   'paid',
#   'point',
#   'believe',
#   'lying',
#   'drivers'],
#  ['promotion', 'expire', 'april', 'th', 'yet'],
#  ['leave',
#   'bottle',
#   'coke',
#   'see',
#   'going',
#   'find',
#   'reliable',
#   'delivery',
#   'service',
#   'make',
#   'second',
#   'time',
#   'messed',
#   'left',
#   'item',
#   'order'],
#  ['pls',
#   'hurry',
#   'last',
#   'dime',
#   'showering',
#   'neighbors',
#   'sprinkler',
#   'going',
#   'report',
#   'soon'],
#  ['met',
#   'criteria',
#   'current',
#   'time',
#   'submission',
#   'enough',
#   'instead',
#   'keep',
#   'getting',
#   'denied',
#   'criteria',
#   'gets',
#   'changed',
#   'way',
#   'anything',
#   'help'],
#  ['still', 'looking', 'callback', 'worstcustomerservice'],
#  ['way', 'go'],
#  ['yet',
#   'reaching',
#   'something',
#   'answer',
#   'application',
#   'put',
#   'uber',
#   'driver',
#   'months',
#   'ago',
#   'reviewed',
#   'thanks'],
#  ['dm', 'number', 'text', 'set', 'time', 'chat'],
#  ['uber',
#   'drivers',
#   'beware',
#   'uber',
#   'paying',
#   'promised',
#   'quarantined',
#   'drive',
#   'lyft',
#   'another',
#   'company',
#   'protect',
#   'needed',
#   'uber',
#   'breaking',
#   'texas',
#   'payday',
#   'law'],
#  ['shouldnt',
#   'guys',
#   'treating',
#   'couriers',
#   'like',
#   'gold',
#   'instead',
#   'keeping',
#   'tips',
#   'shorting',
#   'pay',
#   'outs',
#   'pandemic',
#   'ones',
#   'essential',
#   'wew',
#   'making',
#   'millions',
#   'yoy',
#   'still',
#   'uner',
#   'pay',
#   'us'],
#  ['uber',
#   'breaking',
#   'texas',
#   'payday',
#   'law',
#   'uber',
#   'refusing',
#   'pay',
#   'drivers',
#   'shieldvoc'],
#  ['hear', 'yet'],
#  ['still', 'get'],
#  ['uber',
#   'account',
#   'let',
#   'update',
#   'email',
#   'address',
#   'activate',
#   'nhs',
#   'promo'],
#  ['happy',
#   'mcdonald',
#   'uk',
#   'dream',
#   'abt',
#   'restaurants',
#   'co',
#   'closed',
#   'wont',
#   'open',
#   'anytime',
#   'soon',
#   'id',
#   'love',
#   'double',
#   'cheeseburger',
#   'even',
#   'ubereats',
#   'deliver'],
#  ['uber',
#   'got',
#   'another',
#   'problem',
#   'check',
#   'dms',
#   'got',
#   'charged',
#   'wrong'],
#  ['live',
#   'portugal',
#   'ordered',
#   'delivery',
#   'man',
#   'asked',
#   'go',
#   'downstairs',
#   'collect',
#   'food',
#   'outside',
#   'building',
#   'said',
#   'due',
#   'covid',
#   'new',
#   'rules',
#   'get',
#   'covid',
#   'leave',
#   'flat',
#   'get',
#   'food',
#   'downstairs',
#   'outside',
#   'comments'],
#  ['worst', 'support', 'world', 'goes'],
#  ['need', 'help', 'verification', 'code', 'email', 'getting'],
#  ['need',
#   'know',
#   'uber',
#   'driver',
#   'probably',
#   'back',
#   'work',
#   'due',
#   'covid',
#   'rule',
#   'please',
#   'let',
#   'know',
#   'soon',
#   'thank'],
#  ['dear',
#   'first',
#   'responder',
#   'driver',
#   'quarantine',
#   'heard',
#   'back',
#   'guys',
#   'far',
#   'submit',
#   'paperwork',
#   'get',
#   'help'],
#  ['please',
#   'follow',
#   'dm',
#   'locked',
#   'nhs',
#   'uber',
#   'eats',
#   'account',
#   'please',
#   'help'],
#  ['good',
#   'afternoon',
#   'name',
#   'tina',
#   'ordered',
#   'uber',
#   'eats',
#   'app',
#   'first',
#   'time',
#   'used',
#   'promotional',
#   'code',
#   'given',
#   'manager',
#   'place',
#   'work',
#   'registered',
#   'nurse',
#   'first',
#   'responder',
#   'covid',
#   'pandemic'],
#  ['essential',
#   'workers',
#   'ny',
#   'ever',
#   'considered',
#   'giving',
#   'us',
#   'discount',
#   'trips',
#   'work',
#   'since',
#   'risk',
#   'work',
#   'risk',
#   'commutes',
#   'flattenthecurvetogether'],
#  ['clear',
#   'whether',
#   'worked',
#   'let',
#   'yet',
#   'price',
#   'remains',
#   'unchanged',
#   'go',
#   'help',
#   'page',
#   'way',
#   'interract',
#   'tweet',
#   'twitter',
#   'address'],
#  ['got',
#   'couple',
#   'issues',
#   'trying',
#   'work',
#   'feel',
#   'like',
#   'getting',
#   'run',
#   'around',
#   'online',
#   'outlets',
#   'text',
#   'uber',
#   'app',
#   'twitter',
#   'direct',
#   'messaging',
#   'need',
#   'help',
#   'direction',
#   'assistance',
#   'advice',
#   'support',
#   'tried',
#   'go',
#   'kc',
#   'greenlight',
#   'hub',
#   'closed'],
#  ['loooooool', 'nearly', 'spat', 'one', 'good', 'slice'],
#  ['could', 'get', 'uberxl', 'use', 'pick', 'flatpack', 'furniture'],
#  ['hi',
#   'guys',
#   'trying',
#   'use',
#   'uber',
#   'eats',
#   'promo',
#   'code',
#   'emailed',
#   'meant',
#   'valid',
#   'pm',
#   'tonight',
#   'apply',
#   'tried',
#   'phone',
#   'website',
#   'help'],
#  ['thanks', 'usual', 'email', 'stated', 'got', 'papers'],
#  ['uh', 'huh'],
#  ['looool', 'man', 'got', 'calzone'],
#  ['week', 'guys', 'still', 'verified', 'insurance', 'registration'],
#  ['go', 'getting', 'pizzas', 'redelivered', 'refund'],
#  ['hello',
#   'doctor',
#   'nhs',
#   'recently',
#   'updated',
#   'ubereats',
#   'email',
#   'nhs',
#   'email',
#   'still',
#   'received',
#   'promo',
#   'code'],
#  ['leave', 'answer', 'dms'],
#  ['nhsapril',
#   'code',
#   'work',
#   'says',
#   'applied',
#   'show',
#   'promotions',
#   'fully',
#   'charged'],
#  ['unable',
#   'pay',
#   'bills',
#   'unable',
#   'work',
#   'even',
#   'though',
#   'sent',
#   'documents',
#   'days',
#   'ago',
#   'lack',
#   'response',
#   'hurting',
#   'vulnerable',
#   'drivers',
#   'already',
#   'loosing',
#   'money',
#   'due',
#   'scenario',
#   'shameful'],
#  ['week',
#   'since',
#   'applied',
#   'nothing',
#   'checked',
#   'please',
#   'help',
#   'really',
#   'like',
#   'work',
#   'need',
#   'new',
#   'form',
#   'income',
#   'soon',
#   'please',
#   'let',
#   'know',
#   'something',
#   'wrong',
#   'application'],
#  ['hello',
#   'somebody',
#   'trying',
#   'register',
#   'uber',
#   'number',
#   'got',
#   'verification',
#   'codes',
#   'phone',
#   'need',
#   'dont',
#   'use',
#   'uber',
#   'help',
#   'would',
#   'greatly',
#   'appreciated'],
#  ['go', 'days', 'without', 'work'],
#  ['replied', 'back', 'refunded', 'please'],
#  ['able', 'update', 'documentation', 'via', 'driver', 'app', 'uber', 'brasil'],
#  ['since',
#   'state',
#   'oklahoma',
#   'extended',
#   'validity',
#   'drivers',
#   'licenses',
#   'impact',
#   'ability',
#   'continue',
#   'running',
#   'trips',
#   'even',
#   'mine',
#   'originally',
#   'set',
#   'expire',
#   'april'],
#  ['attitude', 'employees', 'disgusting', 'talk', 'awful', 'support'],
#  ['state',
#   'stay',
#   'home',
#   'mandate',
#   'stop',
#   'permitted',
#   'work',
#   'obtain',
#   'paperwork',
#   'say',
#   'work'],
#  ['cancelling',
#   'delivery',
#   'requests',
#   'get',
#   'really',
#   'could',
#   'care',
#   'less',
#   'diamond',
#   'rating',
#   'spoken',
#   'unprofessionally',
#   'manager',
#   'cambridge',
#   'franklin',
#   'rd',
#   'half'],
#  ['food', 'never', 'arrived'],
#  ['days',
#   'able',
#   'work',
#   'one',
#   'approved',
#   'insurance',
#   'forward',
#   'messages',
#   'tell',
#   'going'],
#  ['help'],
#  ['ok',
#   'looks',
#   'like',
#   'someone',
#   'manually',
#   'fixed',
#   'account',
#   'appreciate',
#   'support',
#   'team',
#   'still',
#   'needs',
#   'better',
#   'understand',
#   'requests',
#   'respond',
#   'context',
#   'rather',
#   'using',
#   'canned',
#   'responses'],
#  ['email',
#   'send',
#   'documents',
#   'guys',
#   'four',
#   'years',
#   'new',
#   'bull',
#   'shit',
#   'sick',
#   'say',
#   'sure',
#   'news',
#   'find',
#   'interesting',
#   'one'],
#  ['hey',
#   'shady',
#   'fall',
#   'guidelines',
#   'financial',
#   'support',
#   'sent',
#   'required',
#   'docs',
#   'doctor',
#   'getti',
#   'fucking',
#   'run',
#   'around',
#   'suspend',
#   'account'],
#  ['still', 'heard', 'order', 'still', 'pending', 'app', 'please', 'reach'],
#  ['access', 'account', 'cel', 'doesnt', 'receive', 'msm', 'code', 'number'],
#  ['phone', 'number', 'email', 'iam', 'located', 'chihuahua', 'mexico'],
#  ['please', 'respond', 'dm', 'concerning', 'uber', 'rewards'],
#  ['hey',
#   'need',
#   'help',
#   'account',
#   'need',
#   'get',
#   'back',
#   'know',
#   'email',
#   'registration',
#   'pending',
#   'pending',
#   'week',
#   'please',
#   'help'],
#  ['linked',
#   'nhs',
#   'email',
#   'uber',
#   'account',
#   'long',
#   'take',
#   'get',
#   'code',
#   'thanks'],
#  ['ill',
#   'reaching',
#   'near',
#   'future',
#   'im',
#   'disgusted',
#   'even',
#   'talk',
#   'people',
#   'today'],
#  ['absolute',
#   'worst',
#   'trying',
#   'coming',
#   'days',
#   'get',
#   'tax',
#   'information',
#   'issue',
#   'got',
#   'problem',
#   'solved',
#   'less',
#   'minutes',
#   'uberistrash'],
#  ['hey',
#   'uber',
#   'received',
#   'ubereats',
#   'nhs',
#   'promotion',
#   'code',
#   'email',
#   'yet',
#   'help',
#   'please'],
#  ['signed',
#   'driver',
#   'got',
#   'message',
#   'contact',
#   'support',
#   'due',
#   'coronavirus'],
#  ['anyone', 'customer', 'service', 'anyone', 'answering'],
#  ['need', 'help', 'promo', 'code'],
#  ['need', 'speak', 'someone', 'setting', 'corporate', 'account'],
#  ['sent', 'two', 'dm', 'keep', 'getting', 'automated', 'response', 'covid'],
#  ['documentation',
#   'need',
#   'give',
#   'prove',
#   'unable',
#   'renew',
#   'license',
#   'plate',
#   'registration',
#   'since',
#   'emissions',
#   'stations',
#   'closed',
#   'illinois',
#   'extended',
#   'expiration',
#   'dates',
#   'days',
#   'past',
#   'time',
#   'lockdown',
#   'ended'],
#  ['uber', 'eats', 'order', 'never', 'arrived', 'someone', 'please', 'reach'],
#  ['hi',
#   'trying',
#   'add',
#   'nhs',
#   'discount',
#   'account',
#   'try',
#   'verify',
#   'email',
#   'address',
#   'opens',
#   'duplicate',
#   'tab',
#   'browser',
#   'please',
#   'help'],
#  ['leeches',
#   'parasites',
#   'world',
#   'surprised',
#   'make',
#   'fact',
#   'drain',
#   'country'],
#  ['need',
#   'help',
#   'approval',
#   'uber',
#   'eats',
#   'deliver',
#   'partner',
#   'documents',
#   'days',
#   'since',
#   'uploaded',
#   'please',
#   'help'],
#  ['need', 'send', 'bank', 'transactions', 'review', 'tell', 'send'],
#  ['hi', 'nhs', 'staff', 'code', 'yet'],
#  ['dm', 'requested', 'got', 'response', 'help', 'number', 'please', 'respond'],
#  ['issue', 'lol', 'taken', 'care'],
#  ['work',
#   'nhs',
#   'activated',
#   'code',
#   'free',
#   'rides',
#   'still',
#   'received',
#   'email',
#   'regarding',
#   'uber',
#   'eats'],
#  ['one', 'answered', 'dozen', 'times', 'sent'],
#  ['able', 'app', 'working'],
#  ['promo', 'code', 'valid', 'today', 'work', 'checkout'],
#  ['ordered',
#   'food',
#   'almost',
#   'hours',
#   'app',
#   'still',
#   'unable',
#   'find',
#   'driver',
#   'pick',
#   'food',
#   'eta',
#   'time',
#   'keep',
#   'going',
#   'canceled',
#   'get',
#   'charge',
#   'fee',
#   'lose',
#   'promo',
#   'fault',
#   'app',
#   'cant',
#   'find',
#   'driver'],
#  ['replied', 'never', 'got', 'response'],
#  ['license',
#   'expired',
#   'renew',
#   'dmv',
#   'closed',
#   'service',
#   'state',
#   'extended',
#   'expiration',
#   'days',
#   'drive',
#   'update',
#   'license',
#   'yet'],
#  ['order', 'waiting', 'hrs'],
#  ['tried',
#   'set',
#   'uber',
#   'eats',
#   'business',
#   'account',
#   'days',
#   'ago',
#   'hold',
#   'around',
#   'hours',
#   'phone',
#   'times',
#   'already',
#   'either',
#   'one',
#   'someone',
#   'transferred',
#   'nothing',
#   'set',
#   'new',
#   'restaurant',
#   'trying',
#   'set',
#   'delivery'],
#  ['sending', 'phone', 'number', 'twitter', 'even', 'dms'],
#  ['tried',
#   'set',
#   'uber',
#   'eats',
#   'business',
#   'account',
#   'days',
#   'ago',
#   'hold',
#   'around',
#   'hours',
#   'phone',
#   'times',
#   'already',
#   'either',
#   'one',
#   'someone',
#   'transferred',
#   'nothing',
#   'set',
#   'new',
#   'restaurant',
#   'trying',
#   'set',
#   'delivery'],
#  ['middle',
#   'maddening',
#   'case',
#   'support',
#   'reps',
#   'clearly',
#   'even',
#   'reading',
#   'messages',
#   'looking',
#   'screenshots',
#   'getting',
#   'canned',
#   'responses',
#   'might',
#   'well',
#   'delete',
#   'account',
#   'already'],
#  ['goog',
#   'guys',
#   'really',
#   'add',
#   'automated',
#   'chat',
#   'response',
#   'sets',
#   'expectations',
#   'instead',
#   'response'],
#  ['changed',
#   'email',
#   'address',
#   'still',
#   'recieved',
#   'message',
#   'uber',
#   'eats',
#   'code',
#   'trying',
#   'suss',
#   'behalf',
#   'us',
#   'hosp',
#   'dying',
#   'pizza'],
#  ['sent'],
#  ['lucky',
#   'talked',
#   'live',
#   'person',
#   'email',
#   'support',
#   'takes',
#   'hrs',
#   'get',
#   'reply',
#   'back'],
#  ['uber',
#   'driver',
#   'almost',
#   'year',
#   'would',
#   'like',
#   'able',
#   'drive',
#   'uber',
#   'eats',
#   'well',
#   'get',
#   'capability'],
#  ['read', 'looks', 'like', 'tip', 'drivers', 'restaurants', 'pick', 'stuff'],
#  ['need', 'years', 'ago', 'funny', 'story', 'get', 'tell'],
#  ['phone', 'number', 'going', 'twitter', 'even', 'dms'],
#  ['hey',
#   'really',
#   'cool',
#   'charged',
#   'ride',
#   'direct',
#   'means',
#   'customer',
#   'service'],
#  ['dm'],
#  ['nhs', 'code', 'uber', 'eats', 'arrived', 'nhs', 'mail', 'account'],
#  ['thank', 'added', 'details', 'requested'],
#  ['shame',
#   'uber',
#   'set',
#   'qualifications',
#   'make',
#   'getting',
#   'payment',
#   'impossible'],
#  ['thanks', 'help'],
#  ['got',
#   'response',
#   'really',
#   'answer',
#   'grammatically',
#   'correct',
#   'enough',
#   'actually',
#   'tell',
#   'mean',
#   'concerned',
#   'account',
#   'compromised',
#   'getting',
#   'bunch',
#   'needless',
#   'messages',
#   'phone',
#   'please',
#   'try',
#   'harder'],
#  ['hospitals',
#   'cant',
#   'legally',
#   'put',
#   'documentation',
#   'quarantine',
#   'covid',
#   'unless',
#   'tested',
#   'test',
#   'positive',
#   'uber',
#   'requires',
#   'covid',
#   'specifically',
#   'noted',
#   'reason',
#   'quarantined',
#   'tested',
#   'results',
#   'immediate',
#   'impossible',
#   'get',
#   'paid'],
#  ['dynamic', 'day', 'dollars', 'way', 'pay', 'go', 'blocks'],
#  ['think',
#   'uber',
#   'want',
#   'approve',
#   'documents',
#   'reduce',
#   'amount',
#   'drivers'],
#  ['still',
#   'need',
#   'customer',
#   'support',
#   'ubereats',
#   'tablet',
#   'working',
#   'cannot',
#   'get',
#   'thru',
#   'ubereats',
#   'phone',
#   'please',
#   'live',
#   'person',
#   'contact',
#   'us'],
#  ['uploaded',
#   'insurance',
#   'days',
#   'ago',
#   'still',
#   'times',
#   'still',
#   'pending',
#   'expire',
#   'suppose'],
#  ['ordered',
#   'ramen',
#   'pickup',
#   'way',
#   'tip',
#   'restaurant',
#   'figure',
#   'intuitively',
#   'ubereats',
#   'tipyourwaitstaff',
#   'covid',
#   'yow',
#   'hospitalityindustry',
#   'socialdistancing',
#   'covidottawa',
#   'uber'],
#  ['use', 'nhs', 'discount', 'ubereats'],
#  ['cant',
#   'get',
#   'app',
#   'link',
#   'email',
#   'one',
#   'sent',
#   'delete',
#   'account',
#   'let',
#   'start'],
#  ['way',
#   'disable',
#   'uber',
#   'cash',
#   'used',
#   'rider',
#   'using',
#   'business',
#   'profile'],
#  ['hi',
#   'made',
#   'order',
#   'order',
#   'completely',
#   'wrong',
#   'told',
#   'delivery',
#   'driver',
#   'said',
#   'problem',
#   'restaurant',
#   'called'],
#  ['already',
#   'contacted',
#   'night',
#   'incident',
#   'told',
#   'look',
#   'thats',
#   'communication'],
#  ['received',
#   'uber',
#   'code',
#   'via',
#   'sms',
#   'even',
#   'though',
#   'accessed',
#   'app',
#   'two',
#   'weeks',
#   'account',
#   'compromised',
#   'could',
#   'glitch',
#   'thank'],
#  ['resolved', 'thank'],
#  ['got',
#   'money',
#   'taken',
#   'account',
#   'used',
#   'uber',
#   'almost',
#   'year',
#   'please',
#   'help'],
#  ['agree',
#   'rosie',
#   'try',
#   'talking',
#   'sometime',
#   'joke',
#   'nothing',
#   'canned',
#   'responses',
#   'till',
#   'run',
#   'read',
#   'anything',
#   'else',
#   'help',
#   'today',
#   'uber'],
#  ['received', 'email', 'ubereats', 'promo', 'code', 'nhs', 'workers', 'get'],
#  ['thanks',
#   'replied',
#   'hrs',
#   'ago',
#   'response',
#   'yet',
#   'better',
#   'efficient',
#   'way',
#   'support',
#   'access',
#   'account',
#   'hrs',
#   'since',
#   'initia',
#   'contact',
#   'moved',
#   'inch',
#   'resolving'],
#  ['hi',
#   'trying',
#   'make',
#   'account',
#   'nhs',
#   'id',
#   'claim',
#   'free',
#   'ride',
#   'food',
#   'however',
#   'got',
#   'uber',
#   'mobile',
#   'number',
#   'already',
#   'allowing',
#   'way',
#   'round',
#   'please'],
#  ['believe',
#   'please',
#   'explain',
#   'understand',
#   'decision',
#   'unfair',
#   'bias',
#   'incorrect',
#   'pax',
#   'accusations',
#   'based',
#   'odor',
#   'shall',
#   'lawyer',
#   'false',
#   'accusations',
#   'really',
#   'unfair',
#   'really',
#   'need',
#   'assistance'],
#  ['uber', 'pay', 'drivers'],
#  ['thanks',
#   'pass',
#   'along',
#   'appears',
#   'user',
#   'error',
#   'hope',
#   'find',
#   'use'],
#  ['hold', 'support', 'hopefully', 'figure'],
#  ['happened',
#   'talk',
#   'earlier',
#   'steps',
#   'going',
#   'protect',
#   'driver',
#   'partners',
#   'pandemic',
#   'supposed',
#   'supply',
#   'us',
#   'sanitizers',
#   'abd',
#   'kinds',
#   'stuff',
#   'instead',
#   'close',
#   'leave',
#   'us',
#   'hanging',
#   'good',
#   'job'],
#  ['fever',
#   'still',
#   'feeling',
#   'like',
#   'shit',
#   'something',
#   'going',
#   'cost',
#   'lives',
#   'cannot',
#   'sit',
#   'let',
#   'happen'],
#  ['unable', 'go', 'online', 'driver', 'restricted', 'access', 'drivers'],
#  ['hey', 'im', 'place', 'uber', 'eats', 'order', 'cant', 'keep', 'getting'],
#  ['dm', 'alot', 'people', 'point', 'willing', 'meet'],
#  ['update'],
#  ['mama', 'never', 'raised', 'snitch'],
#  ['hello',
#   'thanks',
#   'kind',
#   'free',
#   'meal',
#   'offer',
#   'nhs',
#   'finished',
#   'long',
#   'shift',
#   'would',
#   'love',
#   'food',
#   'sent',
#   'promo',
#   'code',
#   'yet',
#   'could',
#   'please',
#   'send',
#   'sarah'],
#  ['please',
#   'update',
#   'driver',
#   'navigation',
#   'app',
#   'townsend',
#   'street',
#   'suggested',
#   'dropoff',
#   'caltrain',
#   'station',
#   'bike',
#   'lane',
#   'dangerous',
#   'stopping',
#   'allowed'],
#  ['great', 'decision', 'worstcompany'],
#  ['boys',
#   'girls',
#   'rideshare',
#   'world',
#   'refer',
#   'paxhole',
#   'word',
#   'used',
#   'interchangeably',
#   'arsehole',
#   'asshole',
#   'anus'],
#  ['hi',
#   'trying',
#   'use',
#   'discount',
#   'code',
#   'due',
#   'expire',
#   'end',
#   'today',
#   'working',
#   'says',
#   'promotion',
#   'expired'],
#  ['rating', 'apps', 'work'],
#  ['seriously', 'week', 'disappointing'],
#  ['verify',
#   'documents',
#   'background',
#   'check',
#   'week',
#   'could',
#   'appreciate',
#   'work'],
#  ['thanks'],
#  ['blind',
#   'voiceover',
#   'user',
#   'please',
#   'let',
#   'know',
#   'order',
#   'coke',
#   'ice',
#   'mcdonalds',
#   'since',
#   'refuse',
#   'fix',
#   'bug',
#   'customization',
#   'screen'],
#  ['surely',
#   'going',
#   'possible',
#   'please',
#   'dm',
#   'us',
#   'additional',
#   'details',
#   'experience',
#   'team',
#   'assist',
#   'appreciate',
#   'chance',
#   'review',
#   'concerns'],
#  ['difficult',
#   'find',
#   'phone',
#   'number',
#   'need',
#   'call',
#   'complain',
#   'food',
#   'order',
#   'morning',
#   'want',
#   'refund',
#   'want',
#   'wait',
#   'hours',
#   'want',
#   'food',
#   'hungry',
#   'understand',
#   'please',
#   'give',
#   'number'],
#  ['keep', 'sending', 'dm', 'provide', 'assistance'],
#  ['need',
#   'help',
#   'account',
#   'car',
#   'insurance',
#   'still',
#   'pending',
#   'need',
#   'get',
#   'second',
#   'day',
#   'loosing',
#   'money',
#   'please',
#   'fix',
#   'account'],
#  ['im',
#   'unable',
#   'cancel',
#   'uber',
#   'pass',
#   'never',
#   'signed',
#   'uber',
#   'pass',
#   'get',
#   'canceled',
#   'get',
#   'refund',
#   'money',
#   'tight',
#   'unacceptable'],
#  ['done', 'thank'],
#  ['yesterday',
#   'governor',
#   'maryland',
#   'said',
#   'one',
#   'leave',
#   'house',
#   'unless',
#   'essential',
#   'job',
#   'go',
#   'doctor',
#   'would',
#   'like',
#   'know',
#   'continue',
#   'uber',
#   'eats',
#   'need',
#   'letter'],
#  ['issue'],
#  ['calling',
#   'chicago',
#   'based',
#   'uber',
#   'drivers',
#   'planning',
#   'protest',
#   'outside',
#   'uber',
#   'greenlight',
#   'hub',
#   'north',
#   'ave',
#   'wants'],
#  ['download',
#   'invoice',
#   'homepage',
#   'options',
#   'file',
#   'support',
#   'case',
#   'bad',
#   'performance'],
#  ['dm', 'sent'],
#  ['received',
#   'nhs',
#   'uber',
#   'eat',
#   'code',
#   'registered',
#   'yesterday',
#   'thank'],
#  ['would',
#   'need',
#   'taxi',
#   'outstation',
#   'travel',
#   'medical',
#   'condition',
#   'arrange',
#   'pass',
#   'uninterrupted',
#   'journey',
#   'please',
#   'suggest',
#   'possible',
#   'destination',
#   'bhadohi',
#   'approx',
#   'km',
#   'delhi'],
#  ['heys',
#   'guys',
#   'helping',
#   'covid',
#   'sent',
#   'documents',
#   'guys',
#   'answering'],
#  ['thank', 'hard', 'work', 'thankyounhs'],
#  ['free', 'food', 'nhs', 'code', 'work'],
#  ['wont', 'work', 'dude', 'haha', 'cheerio'],
#  ['uber',
#   'want',
#   'pay',
#   'days',
#   'financial',
#   'aid',
#   'affected',
#   'corona',
#   'virus',
#   'hospital',
#   'tell',
#   'lock',
#   'home',
#   'symptoms'],
#  ['sorry',
#   'hear',
#   'seems',
#   'uber',
#   'overwhelmed',
#   'many',
#   'new',
#   'drivers',
#   'joining',
#   'uber',
#   'due',
#   'unemployment',
#   'uber',
#   'also',
#   'cancelled',
#   'referral',
#   'bonus',
#   'joke',
#   'ideas',
#   'free',
#   'book',
#   'work',
#   'home',
#   'free',
#   'ebook',
#   'makemoney',
#   'workfromhome',
#   'take',
#   'care'],
#  ['weeks',
#   'old',
#   'risk',
#   'two',
#   'passengers',
#   'driving',
#   'presenting',
#   'symptoms',
#   'hospital',
#   'denied',
#   'medical',
#   'attention',
#   'uber',
#   'denied',
#   'financial',
#   'help',
#   'stay',
#   'locked',
#   'home'],
#  ['impossible'],
#  ['question',
#   'able',
#   'access',
#   'accounts',
#   'drivers',
#   'shoppers',
#   'adjust',
#   'acceptance',
#   'ratings',
#   'seems',
#   'like',
#   'simple',
#   'thing',
#   'implement',
#   'anything',
#   'done',
#   'fix'],
#  ['still', 'find', 'help'],
#  ['th',
#   'day',
#   'since',
#   'uploaded',
#   'insurance',
#   'certificate',
#   'still',
#   'pending',
#   'without',
#   'covid',
#   'unacceptable',
#   'apologises',
#   'put',
#   'food',
#   'table',
#   'pay',
#   'bills'],
#  ['five', 'days', 'still', 'waiting', 'respond', 'please', 'help'],
#  ['trying',
#   'add',
#   'nhs',
#   'account',
#   'existin',
#   'uber',
#   'account',
#   'unable',
#   'says',
#   'cannot',
#   'send',
#   'email',
#   'account',
#   'help'],
#  ['support',
#   'site',
#   'uber',
#   'eats',
#   'work',
#   'trying',
#   'get',
#   'help',
#   'since',
#   'order',
#   'never',
#   'delivered',
#   'last',
#   'saturday',
#   'app',
#   'marked',
#   'delivered',
#   'want',
#   'money',
#   'back'],
#  ['taking', 'two', 'days', 'approve', 'insurance', 'doc', 'unacceptable'],
#  ['deleting', 'never', 'using'],
#  ['need', 'contact', 'uber'],
#  ['uber',
#   'told',
#   'weeks',
#   'one',
#   'point',
#   'right',
#   'supposed',
#   'business',
#   'days',
#   'wtaf'],
#  ['resolved', 'quickly', 'thank', 'much'],
#  ['still',
#   'waiting',
#   'uberdriver',
#   'uber',
#   'driverssupport',
#   'uberseattle',
#   'kingcounty',
#   'wa'],
#  ['help',
#   'understand',
#   'rating',
#   'trips',
#   'account',
#   'put',
#   'hold',
#   'need',
#   'consent',
#   'background',
#   'check',
#   'agreed',
#   'many',
#   'terms',
#   'gives',
#   'consent',
#   'drive',
#   'continually',
#   'provided',
#   'par',
#   'service'],
#  ['new',
#   'jersey',
#   'motor',
#   'vehicle',
#   'agencies',
#   'closed',
#   'month',
#   'extension',
#   'documents',
#   'despite',
#   'trying',
#   'proactive',
#   'uber',
#   'put',
#   'platform',
#   'morning',
#   'global',
#   'pandemic',
#   'making',
#   'bad',
#   'situation',
#   'worse'],
#  ['registered',
#   'nhs',
#   'email',
#   'account',
#   'added',
#   'nhs',
#   'promo',
#   'promo',
#   'showing',
#   'uber',
#   'eats',
#   'uber',
#   'try',
#   'enter',
#   'checkout',
#   'says',
#   'enter',
#   'code',
#   'twice',
#   'discount',
#   'applied',
#   'please',
#   'help'],
#  ['received',
#   'email',
#   'saying',
#   'charged',
#   'cancelled',
#   'ride',
#   'yet',
#   'corporate',
#   'card',
#   'charged',
#   'yesterday',
#   'assist'],
#  ['given',
#   'complete',
#   'documents',
#   'including',
#   'everything',
#   'told',
#   'needed',
#   'pmt',
#   'took',
#   'platform',
#   'based',
#   'documents',
#   'end',
#   'quarantine',
#   'refusing',
#   'pay'],
#  ['need',
#   'copy',
#   'cases',
#   'covid',
#   'yall',
#   'dealt',
#   'fucking',
#   'way',
#   'able',
#   'use',
#   'uber',
#   'cash',
#   'week',
#   'response',
#   'legit',
#   'fucking',
#   'messages',
#   'told'],
#  ['orderedmeal',
#   'food',
#   'arrived',
#   'cold',
#   'chicken',
#   'felt',
#   'like',
#   'old',
#   'kept',
#   'chicken',
#   'last',
#   'dhs',
#   'compensation',
#   'dhs',
#   'order',
#   'enough',
#   'need',
#   'refund',
#   'back',
#   'asap',
#   'worst',
#   'food',
#   'delivery',
#   'expected'],
#  ['nobody',
#   'addressing',
#   'issue',
#   'uber',
#   'required',
#   'incomplete',
#   'uber',
#   'took',
#   'platform',
#   'despite',
#   'required',
#   'uber',
#   'refusing',
#   'pay',
#   'single',
#   'mom',
#   'please',
#   'help',
#   'shieldvoc'],
#  ['store',
#   'cancel',
#   'order',
#   'arrived',
#   'store',
#   'didnt',
#   'compensation',
#   'money',
#   'cancel',
#   'order'],
#  ['know', 'hopefully', 'get', 'one', 'later', 'today', 'tomorrow'],
#  ['ima',
#   'post',
#   'supporting',
#   'documents',
#   'conversations',
#   'show',
#   'drivers',
#   'may',
#   'issue',
#   'gave',
#   'false',
#   'hope'],
#  ['offered',
#   'drivers',
#   'financial',
#   'assistance',
#   'taken',
#   'road',
#   'gave',
#   'false',
#   'hope',
#   'instead',
#   'said',
#   'help',
#   'drivers',
#   'taken',
#   'road',
#   'lay',
#   'turn',
#   'app',
#   'tell',
#   'deal'],
#  ['lose',
#   'gold',
#   'status',
#   'virus',
#   'chosen',
#   'drive',
#   'taking',
#   'classes',
#   'asu',
#   'right',
#   'want',
#   'lose',
#   'ability',
#   'get',
#   'paid',
#   'uber',
#   'thanks'],
#  ['disabled',
#   'app',
#   'able',
#   'make',
#   'money',
#   'feed',
#   'goes',
#   'denies',
#   'assistance',
#   'even',
#   'though',
#   'documents',
#   'saying',
#   'drive',
#   'find',
#   'good',
#   'companies',
#   'times',
#   'like'],
#  ['please', 'check', 'dm'],
#  ['since',
#   'seen',
#   'elsewhere',
#   'twitter',
#   'offer',
#   'available',
#   'first',
#   'despite',
#   'cs',
#   'pretty',
#   'sure',
#   'legal',
#   'anyway',
#   'delete',
#   'app',
#   'justeat',
#   'cheaper',
#   'reliable'],
#  ['thanks', 'never', 'use', 'uber', 'service'],
#  ['simply',
#   'type',
#   'steps',
#   'taking',
#   'ensure',
#   'driver',
#   'ill',
#   'words',
#   'none',
#   'uber',
#   'might',
#   'greatest',
#   'threat',
#   'health',
#   'safety',
#   'employed',
#   'many',
#   'terrorists',
#   'know',
#   'guess',
#   'germ',
#   'warfare',
#   'next',
#   'uber',
#   'scary'],
#  ['willing',
#   'pay',
#   'way',
#   'get',
#   'contact',
#   'someone',
#   'need',
#   'one',
#   'document',
#   'reviewed',
#   'approved',
#   'even',
#   'new',
#   'document',
#   'updated',
#   'one',
#   'account',
#   'hold',
#   'almost',
#   'days',
#   'limited',
#   'staff',
#   'quick',
#   'fix'],
#  ['anyone',
#   'unpublished',
#   'phone',
#   'numbers',
#   'know',
#   'someone',
#   'work',
#   'uber',
#   'uber',
#   'support',
#   'dm',
#   'woth',
#   'info',
#   'need',
#   'drive',
#   'days',
#   'zero',
#   'income',
#   'done',
#   'nothing',
#   'wrong',
#   'except',
#   'choose',
#   'drive',
#   'versus',
#   'need',
#   'one',
#   'person'],
#  ['waiting',
#   'two',
#   'circles',
#   'expand',
#   'year',
#   'software',
#   'design',
#   'issue',
#   'deliver',
#   'locations',
#   'neighborhood',
#   'drive',
#   'house',
#   'add',
#   'feature',
#   'something',
#   'people',
#   'trying',
#   'food',
#   'delivery',
#   'right'],
#  ['wow',
#   'bull',
#   'drivers',
#   'fam',
#   'got',
#   'uber',
#   'cash',
#   'credits',
#   'gave',
#   'cant',
#   'use',
#   'em',
#   'cause',
#   'invalid',
#   'keep',
#   'trying',
#   'get',
#   'shit',
#   'make',
#   'sense',
#   'screen',
#   'shot',
#   'phone',
#   'setting',
#   'ro',
#   'price',
#   'number',
#   'real',
#   'illegal'],
#  ['account', 'activation', 'email', 'number'],
#  ['hi', 'kylie', 'please', 'direct', 'inquiry', 'able', 'assist'],
#  ['already', 'reached', 'via', 'link', 'check', 'dms', 'please'],
#  ['worst',
#   'customer',
#   'service',
#   'ever',
#   'dealt',
#   'stuck',
#   'home',
#   'trying',
#   'order',
#   'food',
#   'contacted',
#   'via',
#   'dms',
#   'get',
#   'automated',
#   'message',
#   'trying',
#   'order',
#   'breakfast',
#   'family'],
#  ['still',
#   'willing',
#   'put',
#   'risk',
#   'financial',
#   'option',
#   'suspended',
#   'account',
#   'expired',
#   'document',
#   'even',
#   'though',
#   'current',
#   'one',
#   'provided',
#   'many',
#   'days',
#   'expiration',
#   'days',
#   'waited',
#   'one',
#   'person',
#   'review'],
#  ['sure',
#   'allowed',
#   'buy',
#   'voucher',
#   'us',
#   'dollars',
#   'refund',
#   'quote',
#   'happy',
#   'hear',
#   'experience',
#   'described',
#   'unfortunately',
#   'making',
#   'refunds'],
#  ['day',
#   'still',
#   'waiting',
#   'response',
#   'emailed',
#   'year',
#   'ago',
#   'last',
#   'week',
#   'able',
#   'create',
#   'account',
#   'today',
#   'uber',
#   'ubereats',
#   'ubersupport',
#   'uberfail',
#   'ubereatsfail',
#   'ubercustomerservice',
#   'rideshareapp',
#   'ridesharing',
#   'fooddelivery'],
#  ['ive',
#   'lost',
#   'gift',
#   'code',
#   'due',
#   'ur',
#   'system',
#   'days',
#   'still',
#   'help',
#   'fuck'],
#  ['want',
#   'organize',
#   'protest',
#   'outside',
#   'ubers',
#   'greenlight',
#   'hub',
#   'chicago'],
#  ['moved',
#   'delaware',
#   'set',
#   'open',
#   'inspection',
#   'test',
#   'place',
#   'hours',
#   'away',
#   'tolls',
#   'uber',
#   'pay',
#   'car',
#   'tiguan',
#   'vw'],
#  ['fix',
#   'support',
#   'system',
#   'suspended',
#   'accounts',
#   'resources',
#   'available',
#   'review',
#   'doxuments',
#   'perhaps',
#   'time',
#   'change',
#   'review',
#   'process',
#   'still',
#   'earn',
#   'living'],
#  ['talking',
#   'trip',
#   'showing',
#   'link',
#   'talking',
#   'trip',
#   'ordered',
#   'yesterday',
#   'mins',
#   'going',
#   'charged',
#   'order',
#   'total',
#   'taking',
#   'advantage',
#   'situation',
#   'make',
#   'profit'],
#  ['nothing',
#   'delivery',
#   'fee',
#   'service',
#   'charge',
#   'tip',
#   'right',
#   'add',
#   'another',
#   'tip',
#   'restaurants',
#   'option',
#   'adding',
#   'tip',
#   'placing',
#   'online',
#   'order',
#   'ubereats'],
#  ['days',
#   'starving',
#   'girl',
#   'tries',
#   'help',
#   'deactivate',
#   'acc',
#   'use',
#   'code',
#   'wasting',
#   'ppl',
#   'money'],
#  ['also',
#   'try',
#   'contact',
#   'paypal',
#   'bank',
#   'fighting',
#   'covid',
#   'bad',
#   'getting',
#   'hold',
#   'uber',
#   'eats',
#   'even',
#   'worse',
#   'would',
#   'rather',
#   'spend',
#   'days',
#   'relaxing',
#   'stressing',
#   'losing',
#   'money'],
#  ['also',
#   'tried',
#   'cancel',
#   'order',
#   'vendor',
#   'cancel',
#   'food',
#   'left',
#   'outside',
#   'door',
#   'thank',
#   'uber',
#   'eats',
#   'totally',
#   'messing',
#   'day',
#   'emergency',
#   'ambulance',
#   'day',
#   'resting',
#   'ringing',
#   'around'],
#  ['would',
#   'also',
#   'like',
#   'report',
#   'serious',
#   'payment',
#   'option',
#   'breach',
#   'point',
#   'authorise',
#   'save',
#   'paypal',
#   'payment',
#   'details',
#   'pressing',
#   'paypal',
#   'option',
#   'take',
#   'paypal',
#   'site',
#   'pay',
#   'items',
#   'purchased',
#   'uber',
#   'eats',
#   'company'],
#  ['fuck',
#   'cannot',
#   'one',
#   'members',
#   'uber',
#   'leadership',
#   'team',
#   'leaders',
#   'reach',
#   'lifeblood',
#   'company',
#   'dont',
#   'give',
#   'shit',
#   'drivers'],
#  ['help',
#   'quarantined',
#   'documents',
#   'submitted',
#   'uber',
#   'took',
#   'platform',
#   'end',
#   'quarantine',
#   'still',
#   'platform',
#   'uber',
#   'pay',
#   'promised'],
#  ['thanks',
#   'reply',
#   'taking',
#   'delivery',
#   'though',
#   'talking',
#   'food',
#   'preparation',
#   'guarantee',
#   'chef',
#   'symptoms',
#   'spreading',
#   'virus',
#   'delivering',
#   'food',
#   'responsibility',
#   'customers',
#   'make',
#   'ill'],
#  ['help',
#   'quarantined',
#   'documents',
#   'submitted',
#   'uber',
#   'took',
#   'platform',
#   'end',
#   'quarantine',
#   'still',
#   'platform',
#   'uber',
#   'pay',
#   'promised'],
#  ['sent',
#   'info',
#   'right',
#   'away',
#   'hope',
#   'hear',
#   'would',
#   'make',
#   'sense',
#   'send',
#   'excel',
#   'bank',
#   'transactions',
#   'ahead',
#   'time',
#   'go',
#   'initial',
#   'explanation'],
#  ['appears',
#   'uber',
#   'stopped',
#   'supporting',
#   'drivers',
#   'absolutely',
#   'zero',
#   'response',
#   'via',
#   'avenue',
#   'smh',
#   'good',
#   'news',
#   'lyft',
#   'supporting',
#   'users',
#   'add',
#   'vehicle',
#   'normal',
#   'car',
#   'shop',
#   'lyft',
#   'driving',
#   'mins',
#   'waiting',
#   'uber',
#   'week'],
#  ['recieved',
#   'email',
#   'wont',
#   'helping',
#   'taken',
#   'account',
#   'recieved',
#   'email',
#   'charge',
#   'order',
#   'make'],
#  ['taken', 'care', 'already', 'thanks'],
#  ['sent', 'guys', 'message'],
#  ['everything',
#   'comes',
#   'put',
#   'mouths',
#   'nothing',
#   'lies',
#   'submitted',
#   'damn',
#   'paperwork',
#   'asked',
#   'claim',
#   'denied',
#   'suck'],
#  ['crazy',
#   'drivers',
#   'take',
#   'money',
#   'never',
#   'pick',
#   'defend',
#   'refund',
#   'us',
#   'better',
#   'go',
#   'guess'],
#  ['update',
#   'order',
#   'cancelled',
#   'also',
#   'pressed',
#   'paypal',
#   'take',
#   'paypal',
#   'sign',
#   'took',
#   'money',
#   'straight',
#   'away',
#   'without',
#   'signing',
#   'security',
#   'breached',
#   'time',
#   'authorise',
#   'save',
#   'details'],
#  ['keep', 'rejecting', 'drivers', 'license', 'drive', 'uber', 'eats'],
#  ['careful', 'posting', 'online'],
#  ['order',
#   'restaurant',
#   'still',
#   'open',
#   'explicitly',
#   'selecting',
#   'want',
#   'order',
#   'fulfilled',
#   'later',
#   'opened'],
#  ['okay',
#   'spoke',
#   'someone',
#   'app',
#   'really',
#   'resolve',
#   'issue',
#   'take',
#   'bank',
#   'instead',
#   'thanks',
#   'reaching'],
#  ['hey',
#   'talked',
#   'rep',
#   'phone',
#   'sent',
#   'several',
#   'messages',
#   'week',
#   'one',
#   'turn',
#   'ubereats',
#   'please',
#   'help'],
#  ['know',
#   'change',
#   'tip',
#   'made',
#   'one',
#   'ubereats',
#   'tip',
#   'first',
#   'place',
#   'cannot'],
#  ['totally', 'agree'],
#  ['contacting', 'bank', 'charge', 'back', 'order', 'cancelled', 'uber'],
#  ['neither'],
#  ['shocking',
#   'service',
#   'uber',
#   'eats',
#   'one',
#   'answering',
#   'phones',
#   'cancelled',
#   'order',
#   'cancellation',
#   'confirmations',
#   'cancelled',
#   'instantly',
#   'within',
#   'seconds',
#   'promo',
#   'applied',
#   'discount',
#   'subtracted',
#   'total',
#   'contact',
#   'method',
#   'rediculous',
#   'nobody',
#   'answering'],
#  ['hi',
#   'couple',
#   'promo',
#   'codes',
#   'ubereats',
#   'account',
#   'use',
#   'australia',
#   'please',
#   'help'],
#  ['think', 'someone', 'trying', 'use', 'uber', 'account'],
#  ['uber',
#   'eats',
#   'credits',
#   'unable',
#   'use',
#   'credits',
#   'zomato',
#   'benefit',
#   'given',
#   'zomato',
#   'like',
#   'free',
#   'zomato',
#   'gold',
#   'membership'],
#  ['financial', 'support', 'guarantee', 'uber'],
#  ['top',
#   'priority',
#   'follow',
#   'sir',
#   'uber',
#   'cancellation',
#   'trending',
#   'finding',
#   'solutions',
#   'reoccurring',
#   'issues',
#   'hyderabad',
#   'secunderabad',
#   'delhi',
#   'bengaluru',
#   'chennai',
#   'kolkata',
#   'mumbai'],
#  ['done',
#   'twice',
#   'first',
#   'time',
#   'lot',
#   'decided',
#   'ignore',
#   'next',
#   'one',
#   'force',
#   'fixed'],
#  ['done', 'thanks'],
#  ['issue',
#   'order',
#   'day',
#   'kindly',
#   'refunded',
#   'part',
#   'money',
#   'checked',
#   'bank',
#   'statement',
#   'money',
#   'refunded',
#   'taken',
#   'along',
#   'original',
#   'price',
#   'meal',
#   'taking',
#   'account',
#   'double',
#   'meal',
#   'cost'],
#  ['sending', 'dms', 'nobody', 'reply', 'need', 'help', 'please'],
#  ['acct',
#   'hold',
#   'expired',
#   'uploaded',
#   'txdeptofpublic',
#   'safety',
#   'letter',
#   'officialy',
#   'authorizing',
#   'days',
#   'extension',
#   'online',
#   'ironical',
#   'represent',
#   'uber',
#   'well',
#   'treated',
#   'system',
#   'fails',
#   'us',
#   'go',
#   'work'],
#  ['thank', 'much', 'support'],
#  ['hello',
#   'enough',
#   'uber',
#   'rewards',
#   'apple',
#   'news',
#   'subscription',
#   'two',
#   'months',
#   'disappeared',
#   'chance',
#   'redeem',
#   'happened',
#   'rewards',
#   'points'],
#  ['trying',
#   'months',
#   'retrieve',
#   'invoices',
#   'travel',
#   'avail',
#   'extremely',
#   'disheartening',
#   'encounter',
#   'service'],
#  ['sent',
#   'dm',
#   'phone',
#   'number',
#   'thank',
#   'looking',
#   'matter',
#   'deactivated',
#   'expired',
#   'registration',
#   'governor',
#   'extended',
#   'deadline',
#   'till',
#   'april',
#   'th'],
#  ['sent',
#   'dm',
#   'days',
#   'ago',
#   'reply',
#   'side',
#   'till',
#   'really',
#   'upset',
#   'way',
#   'handling',
#   'customer',
#   'complaint',
#   'filed',
#   'complaint',
#   'weeks',
#   'ago',
#   'also',
#   'reply',
#   'addition',
#   'unprofessional',
#   'supervisors',
#   'phone'],
#  ['human',
#   'please',
#   'help',
#   'submitted',
#   'documentation',
#   'financial',
#   'assistance',
#   'appears',
#   'date',
#   'cut',
#   'top',
#   'image',
#   'doctors',
#   'letter',
#   'submitted',
#   'cant',
#   'get',
#   'anyone',
#   'attention',
#   'help',
#   'denied'],
#  ['added', 'uber', 'nhs', 'code', 'used', 'straight', 'away'],
#  ['hey',
#   'days',
#   'simple',
#   'updated',
#   'vehicle',
#   'inspection',
#   'submitted',
#   'days',
#   'expiration',
#   'account',
#   'hold',
#   'days',
#   'suspend',
#   'people',
#   'accounts',
#   'man',
#   'power',
#   'review',
#   'documents'],
#  ['could',
#   'please',
#   'start',
#   'thinking',
#   'outside',
#   'box',
#   'due',
#   'covid',
#   'situation',
#   'tn',
#   'licensing',
#   'commission',
#   'closed',
#   'several',
#   'drivers',
#   'unable',
#   'renew',
#   'permit',
#   'please',
#   'note',
#   'attached',
#   'screenshot',
#   'website'],
#  ['good',
#   'went',
#   'deliveroo',
#   'instead',
#   'honestly',
#   'guys',
#   'great',
#   'sort',
#   'tech',
#   'issues'],
#  ['gave',
#   'coupon',
#   'lasted',
#   'seven',
#   'days',
#   'added',
#   'code',
#   'said',
#   'expired',
#   'gives'],
#  ['holy', 'bots', 'read', 'damn', 'thing', 'one', 'twunts'],
#  ['changed', 'phone', 'cannot', 'login', 'account', 'help'],
#  ['please', 'check', 'dm'],
#  ['times',
#   'rides',
#   'still',
#   'refuse',
#   'fix',
#   'serious',
#   'safety',
#   'issue',
#   'happening',
#   'since',
#   'april',
#   'uber',
#   'absolutely',
#   'refuse',
#   'fix',
#   'serious',
#   'safety',
#   'issue'],
#  ['phone',
#   'system',
#   'says',
#   'live',
#   'order',
#   'location',
#   'closed',
#   'hiw',
#   'tti',
#   'resolve'],
#  ['frustrated',
#   'stress',
#   'figuring',
#   'refunds',
#   'canceling',
#   'issuing',
#   'new',
#   'card',
#   'still',
#   'wait',
#   'days',
#   'hacked',
#   'account',
#   'permanently',
#   'deleted',
#   'personal',
#   'information',
#   'stays',
#   'vulnerable'],
#  ['silkwood', 'phone', 'support', 'restaurant', 'closed'],
#  ['need',
#   'help',
#   'nyc',
#   'dmv',
#   'cancelled',
#   'resgistration',
#   'renewals',
#   'extended',
#   'resgistration',
#   'expiring',
#   'march',
#   'oayed',
#   'registration',
#   'jo',
#   'way',
#   'get',
#   'keep',
#   'driving',
#   'documents',
#   'expired',
#   'uber',
#   'account'],
#  ['mine', 'either', 'got', 'yet'],
#  ['payment', 'receive', 'pay', 'fair', 'us'],
#  ['theres',
#   'nothing',
#   'found',
#   'way',
#   'sending',
#   'concern',
#   'charged',
#   'multiple',
#   'times',
#   'card'],
#  ['bill',
#   'masucci',
#   'license',
#   'registration',
#   'done',
#   'two',
#   'cars',
#   'account',
#   'sold',
#   'one',
#   'bought',
#   'another'],
#  ['app',
#   'broken',
#   'charged',
#   'multiple',
#   'times',
#   'theres',
#   'support',
#   'available',
#   'app',
#   'site'],
#  ['hey',
#   'please',
#   'help',
#   'us',
#   'registered',
#   'number',
#   'uber',
#   'eats',
#   'via',
#   'private',
#   'message',
#   'look'],
#  ['dear',
#   'sir',
#   'uber',
#   'eats',
#   'sold',
#   'zomato',
#   'received',
#   'emails',
#   'promising',
#   'us',
#   'zomato',
#   'gold',
#   'membership',
#   'placed',
#   'certain',
#   'number',
#   'orders',
#   'zomato',
#   'yest',
#   'offered',
#   'us',
#   'promised',
#   'months',
#   'free',
#   'zomato',
#   'gold',
#   'membership',
#   'promised',
#   'please',
#   'followup'],
#  ['initiated',
#   'uber',
#   'pass',
#   'january',
#   'year',
#   'feature',
#   'turned',
#   'cancelled',
#   'march',
#   'utilizing',
#   'uber',
#   'foreseeable',
#   'future',
#   'please',
#   'remove',
#   'charge'],
#  ['account',
#   'deactivated',
#   'really',
#   'never',
#   'helped',
#   'represent',
#   'uber',
#   'excellence',
#   'get',
#   'crappy',
#   'deactivation',
#   'notice',
#   'email',
#   'unacceptable',
#   'pls',
#   'go',
#   'back',
#   'investigate',
#   'tx',
#   'dept',
#   'public',
#   'safety',
#   'lettr',
#   'need',
#   'income',
#   'ubereats'],
#  ['hope',
#   'guys',
#   'saved',
#   'lots',
#   'people',
#   'virus',
#   'cuz',
#   'many',
#   'replies',
#   'got',
#   'guys',
#   'guys',
#   'busy',
#   'helping',
#   'people',
#   'virus',
#   'shit'],
#  ['last', 'week', 'account', 'kept', 'hold', 'whole', 'week'],
#  ['hi',
#   'received',
#   'email',
#   'free',
#   'meals',
#   'nhs',
#   'staff',
#   'previously',
#   'linked',
#   'account',
#   'nhs',
#   'email',
#   'account',
#   'see',
#   'promotion',
#   'app'],
#  ['well',
#   'done',
#   'ola',
#   'wish',
#   'cabs',
#   'operating',
#   'india',
#   'follow',
#   'suit'],
#  ['sent', 'number', 'details'],
#  ['know',
#   'giving',
#   'contracts',
#   'driver',
#   'program',
#   'telling',
#   'us',
#   'charged',
#   'return',
#   'vehicle',
#   'barely',
#   'charging',
#   'day',
#   'called',
#   'message',
#   'saying',
#   'overdue',
#   'return'],
#  ['management',
#   'communicate',
#   'partner',
#   'drivers',
#   'regards',
#   'movement',
#   'cessation',
#   'lagos',
#   'whether',
#   'affected',
#   'next',
#   'think',
#   'big',
#   'flop',
#   'path',
#   'information',
#   'integral',
#   'part',
#   'uber',
#   'system'],
#  ['contacted',
#   'via',
#   'mobile',
#   'without',
#   'consent',
#   'response',
#   'process',
#   'ask',
#   'personal',
#   'information',
#   'want',
#   'uber',
#   'info',
#   'never',
#   'wanted',
#   'first',
#   'place',
#   'impressed'],
#  ['want',
#   'get',
#   'emergency',
#   'passengers',
#   'cab',
#   'plz',
#   'help',
#   'us',
#   'get',
#   'registered',
#   'system',
#   'wb'],
#  ['hey',
#   'thanks',
#   'free',
#   'rides',
#   'nhs',
#   'staff',
#   'meals',
#   'really',
#   'making',
#   'getting',
#   'work',
#   'easier',
#   'heroes',
#   'wear',
#   'capes',
#   'drop',
#   'work',
#   'free',
#   'charge',
#   'global',
#   'pandemic'],
#  [],
#  ['side',
#   'per',
#   'right',
#   'partners',
#   'uber',
#   'deserve',
#   'noncooperative',
#   'behavior',
#   'awaiting',
#   'positive',
#   'action',
#   'revert',
#   'please'],
#  ['close',
#   'account',
#   'expected',
#   'company',
#   'like',
#   'uber',
#   'need',
#   'know',
#   'made',
#   'allegations',
#   'uber',
#   'without',
#   'letting',
#   'justify'],
#  ['couple',
#   'negative',
#   'comments',
#   'ignoring',
#   'entire',
#   'history',
#   'work',
#   'completely',
#   'unprofessional',
#   'act',
#   'called',
#   'uber',
#   'partner',
#   'treated',
#   'like',
#   'nothing',
#   'putting',
#   'much',
#   'company'],
#  ['without',
#   'even',
#   'sharing',
#   'reason',
#   'uber',
#   'treat',
#   'loyal',
#   'hardworking',
#   'partners',
#   'specially',
#   'pandemic',
#   'situation',
#   'trying',
#   'hard',
#   'give',
#   'services',
#   'fulfilling',
#   'family',
#   'needs'],
#  ['uber',
#   'partner',
#   'months',
#   'completed',
#   'trips',
#   'ratings',
#   'many',
#   'positive',
#   'feedbacks',
#   'however',
#   'one',
#   'rider',
#   'wrong',
#   'accusation',
#   'allegations',
#   'surely',
#   'mistake',
#   'closed',
#   'account'],
#  ['please',
#   'help',
#   'time',
#   'sensitive',
#   'really',
#   'need',
#   'account',
#   'frozen'],
#  ['trying', 'hour', 'tomorrow', 'assist'],
#  ['people',
#   'hacked',
#   'account',
#   'put',
#   'step',
#   'verification',
#   'know',
#   'phone',
#   'number',
#   'need',
#   'way',
#   'delete',
#   'account',
#   'asap',
#   'please',
#   'help',
#   'scared',
#   'cards',
#   'attached',
#   'account'],
#  ['need',
#   'desperate',
#   'help',
#   'find',
#   'way',
#   'reach',
#   'guys',
#   'account',
#   'hacked',
#   'log',
#   'know',
#   'hacked',
#   'still',
#   'attached',
#   'email',
#   'address',
#   'charge',
#   'around',
#   'put',
#   'credit',
#   'card',
#   'uber',
#   'eats'],
#  ['thank'],
#  ['understand',
#   'things',
#   'busy',
#   'right',
#   'order',
#   'canceled',
#   'hour',
#   'placed',
#   'card',
#   'charged',
#   'food',
#   'made',
#   'uber',
#   'driver',
#   'restaurant',
#   'give',
#   'food',
#   'extremely',
#   'ridiculous',
#   'unprofessional',
#   'want',
#   'money'],
#  ['customer',
#   'service',
#   'email',
#   'uber',
#   'india',
#   'already',
#   'raise',
#   'request',
#   'riders',
#   'data',
#   'trip',
#   'info',
#   'know',
#   'specific',
#   'trip',
#   'arrival',
#   'time'],
#  ['midnight',
#   'fell',
#   'asleep',
#   'easily',
#   'gives',
#   'enough',
#   'time',
#   'especially',
#   'phone',
#   'dead',
#   'fell',
#   'asleep',
#   'soon',
#   'got',
#   'home',
#   'didnt',
#   'even',
#   'watch',
#   'netflix'],
#  ['worries',
#   'thank',
#   'support',
#   'app',
#   'finally',
#   'respond',
#   'appreciate',
#   'getting',
#   'back',
#   'good',
#   'night'],
#  ['sucks', 'hope', 'get', 'refunded'],
#  ['cool', 'take', 'note'],
#  ['waiting',
#   'days',
#   'submitted',
#   'documents',
#   'financial',
#   'help',
#   'tell',
#   'kids',
#   'food',
#   'delay',
#   'due',
#   'volume',
# ...
#   'worrying',
#   'money',
#   'first',
#   'last',
#   'using',
#   'bum',
#   'ass',
#   'app'],
#  ['applied', 'week', 'ago', 'deliver', 'hold'],
#  ['glad', 'hear'],
#  ['keep',
#   'getting',
#   'messages',
#   'scam',
#   'suspect',
#   'scam',
#   'know',
#   'supposed',
#   'arrive',
#   'randomly'],
#  ['morning',
#   'pls',
#   'worries',
#   'get',
#   'ty',
#   'amex',
#   'getting',
#   'charged',
#   'like',
#   'crazy',
#   'even',
#   'tho',
#   'orders',
#   'canceled',
#   'appreciate',
#   'guys'],
#  ['really', 'sad'],
#  ['tried',
#   'use',
#   'ubereats',
#   'first',
#   'time',
#   'unpleasant',
#   'experience',
#   'charged',
#   'twice',
#   'order'],
#  ['resolved', 'thanks'],
#  ['trying',
#   'sign',
#   'cycler',
#   'courier',
#   'despite',
#   'uploading',
#   'documents',
#   'criminal',
#   'background',
#   'check',
#   'stays',
#   'grey',
#   'untouchable',
#   'keep',
#   'getting',
#   'say',
#   'please',
#   'upload',
#   'remaining',
#   'documents',
#   'indicate',
#   'help'],
#  ['please',
#   'help',
#   'account',
#   'documents',
#   'pending',
#   'change',
#   'moped',
#   'app',
#   'let',
#   'go',
#   'online',
#   'th',
#   'phone',
#   'number',
#   'asociate',
#   'app'],
#  ['uber',
#   'account',
#   'issue',
#   'trying',
#   'get',
#   'elderly',
#   'father',
#   'set',
#   'could',
#   'bothered',
#   'providing',
#   'phone',
#   'support',
#   'problem'],
#  ['already', 'told', 'asking', 'setting', 'account', 'read', 'damn', 'tweet'],
#  ['guys', 'review', 'insurance', 'please'],
#  ['access', 'menu', 'tab', 'update', 'hours'],
#  ['even', 'read', 'question', 'please', 'respond', 'question'],
#  ['need', 'help', 'cancelling', 'order', 'pls'],
#  ['drive',
#   'dropped',
#   'food',
#   'wrong',
#   'place',
#   'never',
#   'contacted',
#   'still',
#   'charged',
#   'food'],
#  ['actually', 'driver', 'aswell'],
#  ['took',
#   'days',
#   'authorize',
#   'new',
#   'insurance',
#   'get',
#   'back',
#   'online',
#   'meanwhile',
#   'lyft',
#   'took',
#   'hour'],
#  ['crap', 'getting', 'days', 'told', 'give', 'days'],
#  ['promised',
#   'via',
#   'dm',
#   'update',
#   'email',
#   'got',
#   'nothing',
#   'need',
#   'update',
#   'stop',
#   'passing',
#   'buck'],
#  ['dm', 'sent', 'many', 'thanks', 'team'],
#  ['tf', 'connecting', 'drivers', 'minutes', 'away'],
#  ['received',
#   'discount',
#   'mail',
#   'order',
#   'trying',
#   'apply',
#   'discount',
#   'code',
#   'appears',
#   'code',
#   'longer',
#   'available',
#   'whilst',
#   'deadline',
#   'today'],
#  ['maybe',
#   'receiving',
#   'higher',
#   'normal',
#   'support',
#   'volume',
#   'keep',
#   'sending',
#   'needless',
#   'texts',
#   'random',
#   'users',
#   'trusted',
#   'credit',
#   'card',
#   'numbers',
#   'thought'],
#  ['rather',
#   'cancel',
#   'eats',
#   'pass',
#   'subscription',
#   'seeing',
#   'delivering',
#   'whole',
#   'month',
#   'march',
#   'defer',
#   'payment',
#   'month'],
#  ['account',
#   'temporarily',
#   'placed',
#   'hold',
#   'indianapolis',
#   'indiana',
#   'going'],
#  ['give', 'essential', 'workers', 'discounts', 'rides', 'work'],
#  ['trying',
#   'get',
#   'assistance',
#   'covid',
#   'mess',
#   'worse',
#   'thing',
#   'ever',
#   'done',
#   'way',
#   'care',
#   'people',
#   'work',
#   'giving',
#   'run',
#   'around'],
#  ['uploaded',
#   'document',
#   'since',
#   'th',
#   'march',
#   'till',
#   'today',
#   'updated',
#   'due',
#   'unable',
#   'drive',
#   'uber',
#   'please',
#   'reactivate',
#   'soon',
#   'possible'],
#  ['doubt', 'happened', 'say', 'questions', 'tall', 'exactly', 'much', 'weigh'],
#  ['ordered',
#   'meal',
#   'gift',
#   'card',
#   'account',
#   'got',
#   'charged',
#   'total',
#   'amount',
#   'card',
#   'please',
#   'refund',
#   'money',
#   'order'],
#  ['hi',
#   'tried',
#   'change',
#   'phone',
#   'number',
#   'account',
#   'received',
#   'message',
#   'phone',
#   'number',
#   'taken',
#   'please',
#   'help',
#   'immediately'],
#  ['sent'],
#  ['really',
#   'nobody',
#   'available',
#   'verify',
#   'driver',
#   'insurance',
#   'uploaded'],
#  ['cannot', 'se', 'reply', 'calls', 'say', 'heck', 'uber'],
#  ['file', 'unemployment', 'states', 'website'],
#  ['driver',
#   'sleeping',
#   'food',
#   'watter',
#   'biscuits',
#   'help',
#   'im',
#   'also',
#   'driver',
#   'partner',
#   'im',
#   'alsoin',
#   'verry',
#   'trubbel'],
#  ['hey', 'keep', 'getting', 'sent', 'uber', 'code', 'texts', 'ask', 'going'],
#  ['perhaps', 'could', 'assist', 'query'],
#  ['good',
#   'morning',
#   'uber',
#   'please',
#   'help',
#   'approve',
#   'insurance',
#   'document',
#   'submitted',
#   'past',
#   'hrs'],
#  ['one',
#   'pls',
#   'look',
#   'rego',
#   'pending',
#   'approval',
#   'days',
#   'work',
#   'past',
#   'days',
#   'mail',
#   'id',
#   'phone'],
#  ['filed',
#   'week',
#   'half',
#   'ago',
#   'promised',
#   'days',
#   'get',
#   'things',
#   'sorted',
#   'submitted',
#   'necessary',
#   'paperwork',
#   'response',
#   'imagine',
#   'lot',
#   'drivers',
#   'work',
#   'sick',
#   'rather',
#   'notifying',
#   'uber',
#   'families',
#   'starve'],
#  ['use',
#   'uber',
#   'eats',
#   'website',
#   'app',
#   'website',
#   'go',
#   'clicking',
#   'help'],
#  ['still', 'waiting'],
#  ['bought',
#   'new',
#   'sim',
#   'mobile',
#   'find',
#   'already',
#   'blocked',
#   'please',
#   'help'],
#  ['issues',
#   'account',
#   'logged',
#   'avon',
#   'solved',
#   'issue',
#   'love',
#   'promo',
#   'codes',
#   'free',
#   'delivery',
#   'get',
#   'back'],
#  ['please',
#   'help',
#   'ordered',
#   'uber',
#   'eats',
#   'driver',
#   'said',
#   'food',
#   'door',
#   'nothing',
#   'got',
#   'charged',
#   'something',
#   'get'],
#  ['great',
#   'glad',
#   'hear',
#   'definitely',
#   'lot',
#   'questions',
#   'figured',
#   'state',
#   'state',
#   'thing'],
#  ['thank', 'free', 'bike', 'rides'],
#  ['anyone', 'uber', 'support', 'help', 'cant', 'get', 'contact', 'support'],
#  ['girl', 'mine'],
#  ['promotion', 'saying', 'expired', 'april', 'th', 'date', 'happened', 'yet'],
#  ['dm'],
#  ['meal', 'order', 'delivered', 'feel', 'ripped', 'follow', 'order', 'ddbd'],
#  ['well', 'hella', 'alarming'],
#  ['registered',
#   'phone',
#   'number',
#   'uploaded',
#   'documents',
#   'around',
#   'days',
#   'ago',
#   'order',
#   'uber',
#   'eats',
#   'driver',
#   'vevo',
#   'check',
#   'still',
#   'pending',
#   'also',
#   'one',
#   'thing',
#   'please',
#   'tell',
#   'upload',
#   'criminal',
#   'background',
#   'check'],
#  ['bank',
#   'transactions',
#   'day',
#   'never',
#   'took',
#   'uber',
#   'basically',
#   'questioning',
#   'transactions',
#   'would',
#   'need',
#   'help',
#   'making',
#   'sure',
#   'fraud',
#   'please',
#   'advise',
#   'thanks'],
#  ['waiting',
#   'respond',
#   'month',
#   'emails',
#   'menssages',
#   'app',
#   'need',
#   'answer'],
#  ['reconciling',
#   'business',
#   'expense',
#   'looking',
#   'period',
#   'jan',
#   'feb',
#   'got',
#   'bank',
#   'transaction',
#   'count',
#   'trips',
#   'happy',
#   'share',
#   'details',
#   'transactions',
#   'passed',
#   'card',
#   'help'],
#  ['please', 'activate', 'uber', 'account', 'blocked', 'low', 'uber', 'rating'],
#  ['nope',
#   'closed',
#   'enquiry',
#   'email',
#   'confirmed',
#   'credits',
#   'know',
#   'part',
#   'business',
#   'plan',
#   'lie',
#   'teeth'],
#  ['actually',
#   'care',
#   'quality',
#   'food',
#   'client',
#   'receiving',
#   'driver',
#   'take',
#   'orders',
#   'saying'],
#  ['guys',
#   'going',
#   'post',
#   'anything',
#   'help',
#   'people',
#   'file',
#   'unemployment',
#   'mess'],
#  ['hey',
#   'waitlisted',
#   'years',
#   'pls',
#   'look',
#   'account',
#   'eligible',
#   'ubereats',
#   'uberx',
#   'pls',
#   'dm'],
#  ['uber',
#   'credit',
#   'amex',
#   'platinum',
#   'card',
#   'added',
#   'next',
#   'month',
#   'credit'],
#  ['one',
#   'uber',
#   'driver',
#   'partner',
#   'please',
#   'help',
#   'us',
#   'universal',
#   'calamities',
#   'please',
#   'donate',
#   'amount',
#   'uber',
#   'account',
#   'stand',
#   'corona',
#   'war',
#   'also',
#   'daily',
#   'wages',
#   'labour',
#   'pls',
#   'think',
#   'us'],
#  ['way',
#   'change',
#   'tip',
#   'amount',
#   'uber',
#   'eats',
#   'order',
#   'hour',
#   'credit',
#   'card',
#   'authorization',
#   'window',
#   'passed'],
#  ['nah',
#   'dismissed',
#   'mistaking',
#   'woman',
#   'reality',
#   'lol',
#   'stupid',
#   'languages'],
#  ['thanks',
#   'concern',
#   'pal',
#   'fleet',
#   'partner',
#   'manage',
#   'somehow',
#   'even',
#   'recession',
#   'worried',
#   'millions',
#   'drivers',
#   'drivers',
#   'every',
#   'organisation',
#   'trying',
#   'best',
#   'save',
#   'humanity',
#   'one',
#   'take',
#   'care'],
#  ['hey',
#   'lied',
#   'said',
#   'applied',
#   'credits',
#   'account',
#   'driver',
#   'tried',
#   'endanger',
#   'health',
#   'want',
#   'take',
#   'lift',
#   'refund',
#   'money',
#   'credit',
#   'never',
#   'gave',
#   'never',
#   'order'],
#  ['know',
#   'mate',
#   'wasnt',
#   'dig',
#   'seen',
#   'uber',
#   'drivers',
#   'say',
#   'around',
#   'globe',
#   'mean',
#   'personal',
#   'account',
#   'hope',
#   'get',
#   'sorted',
#   'uber',
#   'government',
#   'also',
#   'responsibility',
#   'care',
#   'keep',
#   'family',
#   'safe'],
#  ['done',
#   'something',
#   'wanted',
#   'like',
#   'trying',
#   'help',
#   'least',
#   'words',
#   'partners',
#   'ola',
#   'like',
#   'worried',
#   'get',
#   'new',
#   'drivers',
#   'partners',
#   'poor',
#   'families',
#   'starves',
#   'death'],
#  ['hello', 'things', 'finally', 'resolved'],
#  ['get', 'anywhere', 'classed', 'self', 'employed', 'dont', 'help'],
#  ['hour',
#   'greatest',
#   'need',
#   'driver',
#   'fleet',
#   'partners',
#   'every',
#   'company',
#   'paying',
#   'employees',
#   'wanna',
#   'something',
#   'people',
#   'earn',
#   'commission'],
#  ['hi',
#   'harry',
#   'actively',
#   'working',
#   'gather',
#   'relevant',
#   'information',
#   'drivers',
#   'varies',
#   'state',
#   'state',
#   'touch',
#   'soon',
#   'possible',
#   'likely',
#   'monday'],
#  ['better',
#   'verify',
#   'credit',
#   'cards',
#   'bring',
#   'submitted',
#   'app',
#   'charges',
#   'fraudulently',
#   'charged',
#   'today',
#   'system',
#   'guys',
#   'put',
#   'flag',
#   'catch',
#   'number',
#   'used',
#   'zip',
#   'code',
#   'match',
#   'billing',
#   'zip'],
#  ['guys', 'resetting', 'something', 'rating', 'went', 'issue'],
#  ['guys', 'sleep', 'day', 'work', 'night'],
#  ['save', 'podcast', 'gem', 'lol'],
#  ['dm', 'sent'],
#  ['canto', 'register', 'motorcycle'],
#  ['wait'],
#  ['payment',
#   'methods',
#   'give',
#   'error',
#   'saying',
#   'payment',
#   'method',
#   'unavailable',
#   'every',
#   'card',
#   'try'],
#  ['uber',
#   'eats',
#   'allowed',
#   'order',
#   'closed',
#   'restaurant',
#   'drivers',
#   'keep',
#   'pulling',
#   'clearly',
#   'get',
#   'food',
#   'trying',
#   'use',
#   'help',
#   'support',
#   'option',
#   'order',
#   'never',
#   'arrived',
#   'app',
#   'still',
#   'marking',
#   'en',
#   'route',
#   'want',
#   'money',
#   'back',
#   'please'],
#  ['could', 'read', 'tweet', 'answer', 'question'],
#  ['covid',
#   'pandemic',
#   'lot',
#   'companies',
#   'taking',
#   'care',
#   'people',
#   'making',
#   'sure',
#   'pay',
#   'dealing',
#   'public',
#   'premium',
#   'rate',
#   'fact',
#   'cut',
#   'driver',
#   'support',
#   'weekends',
#   'refuse',
#   'respond',
#   'drivers'],
#  ['ola',
#   'uber',
#   'company',
#   'takes',
#   'commission',
#   'unable',
#   'give',
#   'drivers',
#   'hour',
#   'trouble'],
#  ['hell',
#   'happening',
#   'order',
#   'cancelled',
#   'told',
#   'still',
#   'pay',
#   'hung',
#   'disconnected',
#   'charging',
#   'order',
#   'back',
#   'deleting',
#   'good'],
#  ['someone', 'know', 'using', 'email', 'account'],
#  ['hey',
#   'harsha',
#   'vardhan',
#   'know',
#   'covid',
#   'outbreaking',
#   'hard',
#   'australia',
#   'tough',
#   'time',
#   'go',
#   'outside',
#   'without',
#   'cab',
#   'please',
#   'would',
#   'sincerely',
#   'request',
#   'please',
#   'uber',
#   'account',
#   'helpful',
#   'covid',
#   'outbreak'],
#  ['would', 'considered', 'benefits', 'fraud', 'felony'],
#  ['terrified', 'got', 'scammed'],
#  ['happen', 'course', 'would', 'nice', 'could', 'actually', 'get', 'touch'],
#  ['yrs',
#   'specifically',
#   'endorsing',
#   'uber',
#   'yesterday',
#   'ordered',
#   'uber',
#   'car',
#   'filthy',
#   'dirty',
#   'car',
#   'showed',
#   'huge',
#   'lyft',
#   'sign',
#   'interior',
#   'filthy',
#   'well',
#   'rusty',
#   'dirty',
#   'rags',
#   'back',
#   'seat',
#   'ewwwwe',
#   'upholstery',
#   'also',
#   'disgustingly',
#   'filthy'],
#  ['days', 'ago', 'still', 'heard', 'back'],
#  ['thank', 'able', 'get', 'things', 'resolved', 'yesterday'],
#  ['man', 'get', 'response'],
#  ['going',
#   'state',
#   'level',
#   'fed',
#   'reimburse',
#   'states',
#   'keep',
#   'process',
#   'catching'],
#  ['ordered',
#   'first',
#   'time',
#   'tonight',
#   'used',
#   'first',
#   'order',
#   'coupon',
#   'get',
#   'applied',
#   'order',
#   'use',
#   'since',
#   'first',
#   'order',
#   'halp',
#   'plz'],
#  ['need',
#   'help',
#   'trying',
#   'create',
#   'account',
#   'keeps',
#   'saying',
#   'number',
#   'already',
#   'account',
#   'must',
#   'last',
#   'person',
#   'number',
#   'help'],
#  ['shout',
#   'guy',
#   'tried',
#   'scam',
#   'uber',
#   'eats',
#   'posing',
#   'laughed',
#   'waaay',
#   'hard',
#   'locked',
#   'payouts',
#   'closed',
#   'praise',
#   'network',
#   'issues',
#   'working',
#   'app'],
#  ['get', 'response'],
#  ['corona',
#   'virus',
#   'relief',
#   'legislation',
#   'indicates',
#   'uber',
#   'drivers',
#   'usa',
#   'apply',
#   'unemployment',
#   'guideline',
#   'process',
#   'follow',
#   'apply',
#   'benefit'],
#  ['issue', 'resolved', 'thanks'],
#  ['uber', 'famous', 'fraud', 'ubersucks'],
#  ['thats', 'absolutely', 'disgusting'],
#  ['understood', 'uninstalled', 'reinstalled', 'app', 'get', 'back', 'working'],
#  ['stop',
#   'surge',
#   'pricing',
#   'pandemic',
#   'pls',
#   'icu',
#   'nurse',
#   'trying',
#   'get',
#   'work',
#   'help',
#   'affordably',
#   'wearethefrontline',
#   'gougepricing'],
#  ['electronic',
#   'funds',
#   'transfer',
#   'act',
#   'efta',
#   'deal',
#   'fraud',
#   'directly',
#   'card',
#   'issuer',
#   'cancel',
#   'card',
#   'issue',
#   'new',
#   'one',
#   'pain',
#   'change',
#   'new',
#   'number',
#   'automatic',
#   'bill',
#   'pay'],
#  ['yes', 'knows', 'already', 'contacted', 'credit', 'union'],
#  ['called', 'past', 'wait', 'time', 'bit', 'long'],
#  ['call',
#   'debit',
#   'card',
#   'company',
#   'card',
#   'physically',
#   'lost',
#   'stolen',
#   'days',
#   'report',
#   'fraudulent',
#   'transactions',
#   'zero',
#   'liability',
#   'days',
#   'starts',
#   'date',
#   'statement',
#   'fraudulent',
#   'transaction',
#   'appears'],
#  ['call', 'customer', 'service', 'dispute'],
#  ['vehicle',
#   'trunk',
#   'release',
#   'back',
#   'seat',
#   'making',
#   'false',
#   'accusations',
#   'even',
#   'lower',
#   'snitching'],
#  ['hey',
#   'someone',
#   'fraudulently',
#   'used',
#   'mother',
#   'debit',
#   'card',
#   'make',
#   'three',
#   'large',
#   'orders',
#   'uber',
#   'eats',
#   'uber',
#   'account',
#   'public',
#   'phone',
#   'number',
#   'listed',
#   'contact',
#   'get',
#   'touch'],
#  ['hi', 'majiira', 'talk', 'hope', 'ur', 'well'],
#  ['time', 'phone', 'line', 'need', 'talk'],
#  ['still',
#   'getting',
#   'texts',
#   'better',
#   'homie',
#   'get',
#   'response',
#   'getting',
#   'hacked',
#   'russia'],
#  ['general',
#   'everyone',
#   'safe',
#   'make',
#   'sure',
#   'big',
#   'bold',
#   'drivers',
#   'know',
#   'new',
#   'missed'],
#  ['excited',
#   'support',
#   'local',
#   'restaurant',
#   'tonight',
#   'ubereats',
#   'using',
#   'ubercash',
#   'giftcard',
#   'made',
#   'sure',
#   'uber',
#   'cash',
#   'ready',
#   'pay',
#   'instead',
#   'whole',
#   'meal',
#   'charged',
#   'credit',
#   'card',
#   'need',
#   'help'],
#  ['world',
#   'pandemic',
#   'going',
#   'people',
#   'loosing',
#   'jobs',
#   'top',
#   'discount',
#   'trip',
#   'rates',
#   'charging',
#   'surge',
#   'peek',
#   'hours',
#   'smh',
#   'uber',
#   'better'],
#  ['wrongfully',
#   'restricted',
#   'suspended',
#   'account',
#   'apparently',
#   'violating',
#   'terms',
#   'service',
#   'file',
#   'ticket',
#   'tell',
#   'going',
#   'lift',
#   'wrongfully',
#   'system',
#   'applied',
#   'ban',
#   'say',
#   'kidding',
#   'lifting',
#   'suspension'],
#  ['sent', 'dm', 'ave', 'got', 'automated', 'response'],
#  ['round',
#   'mail',
#   'chain',
#   'prof',
#   'nd',
#   'answer',
#   'guys',
#   'shying',
#   'away',
#   'frm',
#   'acknowledging',
#   'mistake',
#   'uber',
#   'nd',
#   'accepting',
#   'shortcoming',
#   'least',
#   'cant',
#   'refund',
#   'disgusting',
#   'shameful',
#   'nd',
#   'pathetic',
#   'guys',
#   'lied',
#   'least'],
#  ['still',
#   'response',
#   'three',
#   'weeks',
#   'documents',
#   'pending',
#   'ubereats',
#   'hand',
#   'ridiculous',
#   'something',
#   'needs',
#   'done',
#   'someone',
#   'needs',
#   'handle',
#   'asap'],
#  ['thanks', 'sent', 'message'],
#  ['confused',
#   'want',
#   'give',
#   'driver',
#   'proper',
#   'tip',
#   'without',
#   'accidentally',
#   'sending',
#   'meager',
#   'life',
#   'savings',
#   'help',
#   'hope'],
#  ['hi',
#   'pleeeeze',
#   'help',
#   'desperately',
#   'need',
#   'send',
#   'message',
#   'uber',
#   'delivery',
#   'deliverers',
#   'help',
#   'private',
#   'help',
#   'section',
#   'giving',
#   'options',
#   'send',
#   'message',
#   'go',
#   'thanks',
#   'advance'],
#  ...]

# %% [markdown]
# ### Lemmatize

# %%
texts = lemmatization(texts)

# %% [markdown]
# ### Save texts

# %%
joblib.dump(texts, 'texts.pkl')
# Out:
# ['texts.pkl']

# %%
texts = joblib.load('texts.pkl')

# %%
texts
# Out:
# [['follow',
#   'promise',
#   'disinfect',
#   'material',
#   'driver',
#   'car',
#   'supply',
#   'keep',
#   'driver',
#   'safe',
#   'tele',
#   'agent',
#   'hang',
#   'driver',
#   'call',
#   'ask',
#   'sbout',
#   'supply'],
#  ['uber',
#   'follow',
#   'thru',
#   'promise',
#   'disinfect',
#   'material',
#   'driver',
#   'car',
#   'supply',
#   'keep',
#   'driver',
#   'safe',
#   'tele',
#   'agent',
#   'hang',
#   'driver',
#   'call',
#   'ask',
#   'sbout',
#   'supply',
#   'explain'],
#  ['follow',
#   'promise',
#   'disinfect',
#   'material',
#   'driver',
#   'car',
#   'supply',
#   'keep',
#   'driver',
#   'safe',
#   'tele',
#   'agent',
#   'hang',
#   'driver',
#   'call',
#   'ask',
#   'sbout',
#   'supply',
#   'explain'],
#  ['song',
#   'dance',
#   'dead',
#   'wrong',
#   'handle',
#   'pandemic',
#   'plight',
#   'worker',
#   'know'],
#  ['receive', 'ride', 'report', 'email', 'even', 'account', 'guy'],
#  ['do'],
#  ['uber', 'give', 'ride', 'request', 'go', 'app', 'go', 'right', 'away'],
#  ['way',
#   'worried',
#   'privacy',
#   'dm',
#   'say',
#   'continue',
#   'work',
#   'support',
#   'team',
#   'even',
#   'emailing',
#   'help',
#   'deception'],
#  ['try',
#   'file',
#   'california',
#   'state',
#   'unemployment',
#   'insurance',
#   'ever',
#   'pay',
#   'cut',
#   'dramatically',
#   'uber',
#   'state',
#   'etin',
#   'try',
#   'find',
#   'number',
#   'call',
#   'hr',
#   'department',
#   'find',
#   'one',
#   'also',
#   'still',
#   'wait',
#   'file',
#   'tax'],
#  ['answer', 'message', 'box'],
#  ['contact', 'info', 'avoid', 'charge', 'driver', 'say', 'business', 'close'],
#  ['read', 'original', 'tweet', 'answer', 'question', 'account'],
#  ['handle',
#   'driver',
#   'situation',
#   'restrict',
#   'example',
#   'panama',
#   'central',
#   'america'],
#  ['insurance', 'pende', 'approval', 'hour'],
#  ['order',
#   'worth',
#   'east',
#   'side',
#   'come',
#   'cold',
#   'chicken',
#   'cook',
#   'veggie',
#   'fry',
#   'cook',
#   'pasta',
#   'cold',
#   'desert',
#   'kid',
#   'meal',
#   'bad',
#   'time',
#   'ever',
#   'eat',
#   'food',
#   'restaurant',
#   'say',
#   'bad',
#   'night',
#   'call',
#   'uber',
#   'refund'],
#  ['help', 'justification', 'horrible', 'practice'],
#  ['way',
#   'bicycle',
#   'delivery',
#   'profile',
#   'modify',
#   'enable',
#   'use',
#   'vehicle',
#   'provide',
#   'necessary',
#   'nyc',
#   'clearance',
#   'start',
#   'delivery',
#   'vehicle',
#   'thank',
#   'look',
#   'forward',
#   'get',
#   'support'],
#  ['call', 'multiple', 'time', 'approve', 'insurance', 'day'],
#  ['uber',
#   'go',
#   'provide',
#   'driver',
#   'sanitizing',
#   'wipe',
#   'vehicle',
#   'interior',
#   'hand',
#   'keep',
#   'see',
#   'email',
#   'yet',
#   'word',
#   'shipment',
#   'product',
#   'actual',
#   'driver'],
#  ['local',
#   'greenlight',
#   'hub',
#   'support',
#   'office',
#   'close',
#   'least',
#   'april',
#   'prob',
#   'long',
#   'give',
#   'paper',
#   'call',
#   'uber',
#   'support',
#   'get',
#   'boston',
#   'driver',
#   'certificate',
#   'call',
#   'tell',
#   'hub',
#   'get',
#   'certificate'],
#  ['help', 'uber', 'eat', 'order', 'issue', 'go', 'bonker'],
#  ['recieve',
#   'thermal',
#   'bag',
#   'start',
#   'delivery',
#   'job',
#   'go',
#   'office',
#   'tell',
#   'closed',
#   'due',
#   'covid',
#   'situation',
#   'hand',
#   'recieve',
#   'text',
#   'email',
#   'everyday',
#   'collection',
#   'tell',
#   'back',
#   'th'],
#  ['still'],
#  ['check', 'important', 'dm'],
#  ['latin',
#   'creation',
#   'senor',
#   'frog',
#   'cancel',
#   'wrong',
#   'menu',
#   'able',
#   'contact',
#   'branden',
#   'plan'],
#  ['email', 'ever', 'access', 'account', 'change', 'phone', 'number'],
#  ['love',
#   'charge',
#   'cancel',
#   'driver',
#   'go',
#   'double',
#   'distance',
#   'way',
#   'absolutely',
#   'ridiculous',
#   'second',
#   'time',
#   'shit',
#   'happen',
#   'take',
#   'money',
#   'reason',
#   'bunch',
#   'thief'],
#  ['hope',
#   'smart',
#   'enough',
#   'realize',
#   'driver',
#   'keep',
#   'current',
#   'uber',
#   'pro',
#   'status',
#   'time',
#   'fair',
#   'reasonable',
#   'thing',
#   'ask',
#   'people',
#   'ride',
#   'thank'],
#  ['order',
#   'restaurant',
#   'screw',
#   'order',
#   'talk',
#   'get',
#   'item',
#   'eat',
#   'topping',
#   'include',
#   'make',
#   'gag'],
#  ['deny', 'claim', 'self', 'isolation', 'compensation'],
#  ['send',
#   'uber',
#   'customer',
#   'service',
#   'number',
#   'live',
#   'person',
#   'stat',
#   'lawyer',
#   'call'],
#  ['stop',
#   'unauthorized',
#   'removal',
#   'fund',
#   'bank',
#   'account',
#   'global',
#   'pandemic',
#   'resource',
#   'already',
#   'scarce',
#   'take',
#   'uber',
#   'month',
#   'absurd',
#   'give',
#   'money',
#   'back'],
#  ['week',
#   'wait',
#   'support',
#   'get',
#   'copy',
#   'paste',
#   'reply',
#   'dm',
#   'first',
#   'last',
#   'time',
#   'use',
#   'guy',
#   'understand',
#   'increase',
#   'due',
#   'go',
#   'week',
#   'insane'],
#  ['else',
#   'issue',
#   'second',
#   'day',
#   'row',
#   'food',
#   'never',
#   'arrive',
#   'app',
#   'say',
#   'deliver',
#   'hell'],
#  ['tell', 'deny', 'claim'],
#  ['still', 'receive', 'uber', 'eat', 'support'],
#  ['know',
#   'ignore',
#   'week',
#   'completely',
#   'unacceptable',
#   'unprofessional',
#   'company',
#   'blatantly',
#   'lie',
#   'driver',
#   'covid'],
#  ['app',
#   'talk',
#   'email',
#   'charge',
#   'trip',
#   'car',
#   'never',
#   'show',
#   'different',
#   'info'],
#  ['help', 'help'],
#  ['still', 'look', 'answer'],
#  ['take',
#   'uber',
#   'restaurant',
#   'give',
#   'order',
#   'cause',
#   'give',
#   'driver',
#   'spend',
#   'money',
#   'retrieve',
#   'order',
#   'unsuccessful',
#   'still',
#   'support',
#   'good',
#   'enough'],
#  ['week', 'unacceptable', 'state', 'day', 'payment', 'think'],
#  ['help', 'uber', 'support', 'help', 'help'],
#  ['tell', 'week', 'wait', 'pay', 'point', 'believe', 'lie', 'driver'],
#  ['promotion', 'expire', 'april', 'th', 'yet'],
#  ['leave',
#   'bottle',
#   'coke',
#   'see',
#   'go',
#   'find',
#   'reliable',
#   'delivery',
#   'service',
#   'make',
#   'second',
#   'time',
#   'mess',
#   'left',
#   'item',
#   'order'],
#  ['hurry',
#   'last',
#   'dime',
#   'shower',
#   'neighbor',
#   'sprinkler',
#   'go',
#   'report',
#   'soon'],
#  ['meet',
#   'criterion',
#   'current',
#   'time',
#   'submission',
#   'enough',
#   'instead',
#   'keep',
#   'deny',
#   'criterion',
#   'change',
#   'way',
#   'help'],
#  ['still', 'look', 'callback', 'worstcustomerservice'],
#  ['way', 'go'],
#  ['yet',
#   'reach',
#   'answer',
#   'application',
#   'put',
#   'uber',
#   'driver',
#   'month',
#   'ago',
#   'review',
#   'thank'],
#  ['dm', 'number', 'text', 'set', 'time', 'chat'],
#  ['uber',
#   'driver',
#   'beware',
#   'uber',
#   'pay',
#   'promise',
#   'quarantine',
#   'drive',
#   'lyft',
#   'company',
#   'protect',
#   'need',
#   'uber',
#   'break',
#   'texas',
#   'payday',
#   'law'],
#  ['guy',
#   'treat',
#   'courier',
#   'gold',
#   'instead',
#   'keep',
#   'tip',
#   'short',
#   'pay',
#   'out',
#   'pandemic',
#   'one',
#   'essential',
#   'wew',
#   'make',
#   'million',
#   'still',
#   'uner',
#   'pay'],
#  ['uber',
#   'breaking',
#   'texas',
#   'payday',
#   'law',
#   'uber',
#   'refuse',
#   'pay',
#   'driver',
#   'shieldvoc'],
#  ['hear', 'yet'],
#  ['still', 'get'],
#  ['uber',
#   'account',
#   'let',
#   'update',
#   'email',
#   'address',
#   'activate',
#   'nhs',
#   'promo'],
#  ['happy',
#   'mcdonald',
#   'uk',
#   'dream',
#   'abt',
#   'restaurant',
#   'co',
#   'close',
#   'open',
#   'anytime',
#   'soon',
#   'i',
#   'd',
#   'love',
#   'double',
#   'cheeseburger',
#   'even',
#   'ubereat',
#   'deliver'],
#  ['uber', 'get', 'problem', 'check', 'dms', 'charge', 'wrong'],
#  ['live',
#   'portugal',
#   'order',
#   'delivery',
#   'man',
#   'ask',
#   'go',
#   'downstairs',
#   'collect',
#   'food',
#   'building',
#   'say',
#   'due',
#   'covid',
#   'new',
#   'rule',
#   'get',
#   'covid',
#   'leave',
#   'flat',
#   'get',
#   'food',
#   'downstairs',
#   'comment'],
#  ['bad', 'support', 'world', 'go'],
#  ['need', 'help', 'verification', 'code', 'email', 'get'],
#  ['know',
#   'uber',
#   'driver',
#   'probably',
#   'back',
#   'work',
#   'due',
#   'covid',
#   'rule',
#   'let',
#   'know',
#   'soon',
#   'thank'],
#  ['dear',
#   'first',
#   'responder',
#   'driver',
#   'quarantine',
#   'hear',
#   'back',
#   'guy',
#   'far',
#   'submit',
#   'paperwork',
#   'get',
#   'help'],
#  ['follow', 'dm', 'lock', 'nhs', 'uber', 'eat', 'account', 'help'],
#  ['good',
#   'afternoon',
#   'name',
#   'tina',
#   'order',
#   'uber',
#   'eat',
#   'app',
#   'first',
#   'time',
#   'use',
#   'promotional',
#   'code',
#   'give',
#   'manager',
#   'place',
#   'work',
#   'register',
#   'nurse',
#   'first',
#   'responder',
#   'covid',
#   'pandemic'],
#  ['essential',
#   'worker',
#   'ny',
#   'ever',
#   'consider',
#   'give',
#   'discount',
#   'trip',
#   'work',
#   'risk',
#   'work',
#   'risk',
#   'commute',
#   'flattenthecurvetogether'],
#  ['clear',
#   'work',
#   'let',
#   'yet',
#   'price',
#   'remain',
#   'unchanged',
#   'go',
#   'help',
#   'page',
#   'way',
#   'interract',
#   'tweet',
#   'twitter',
#   'address'],
#  ['get',
#   'couple',
#   'issue',
#   'try',
#   'work',
#   'feel',
#   'run',
#   'online',
#   'outlet',
#   'text',
#   'uber',
#   'app',
#   'twitter',
#   'direct',
#   'message',
#   'need',
#   'help',
#   'direction',
#   'assistance',
#   'advice',
#   'support',
#   'try',
#   'go',
#   'greenlight',
#   'hub',
#   'close'],
#  ['loooooool', 'nearly', 'spit', 'good', 'slice'],
#  ['get', 'uberxl', 'use', 'pick', 'flatpack', 'furniture'],
#  ['guy',
#   'try',
#   'use',
#   'uber',
#   'eat',
#   'promo',
#   'code',
#   'email',
#   'mean',
#   'valid',
#   'pm',
#   'tonight',
#   'apply',
#   'try',
#   'phone',
#   'website',
#   'help'],
#  ['thank', 'usual', 'email', 'state', 'get', 'paper'],
#  [],
#  ['looool', 'man', 'get', 'calzone'],
#  ['week', 'guy', 'still', 'verify', 'insurance', 'registration'],
#  ['go', 'get', 'pizza', 'redelivere', 'refund'],
#  ['doctor',
#   'nhs',
#   'recently',
#   'update',
#   'ubereat',
#   'email',
#   'nhs',
#   'email',
#   'still',
#   'receive',
#   'promo',
#   'code'],
#  ['leave', 'answer', 'dms'],
#  ['nhsapril',
#   'code',
#   'work',
#   'say',
#   'apply',
#   'show',
#   'promotion',
#   'fully',
#   'charge'],
#  ['unable',
#   'pay',
#   'bill',
#   'unable',
#   'work',
#   'even',
#   'send',
#   'document',
#   'day',
#   'ago',
#   'lack',
#   'response',
#   'hurt',
#   'vulnerable',
#   'driver',
#   'already',
#   'loose',
#   'money',
#   'due',
#   'scenario',
#   'shameful'],
#  ['week',
#   'apply',
#   'check',
#   'help',
#   'really',
#   'work',
#   'need',
#   'new',
#   'form',
#   'income',
#   'soon',
#   'let',
#   'know',
#   'wrong',
#   'application'],
#  ['try',
#   'register',
#   'uber',
#   'number',
#   'get',
#   'verification',
#   'code',
#   'phone',
#   'need',
#   'use',
#   'uber',
#   'help',
#   'greatly',
#   'appreciate'],
#  ['go', 'day', 'work'],
#  ['reply', 'back', 'refunded'],
#  ['able', 'update', 'documentation', 'driver', 'app', 'uber', 'brasil'],
#  ['state',
#   'oklahoma',
#   'extend',
#   'validity',
#   'driver',
#   'license',
#   'impact',
#   'ability',
#   'continue',
#   'run',
#   'trip',
#   'even',
#   'originally',
#   'set',
#   'expire',
#   'april'],
#  ['attitude', 'employee', 'disgusting', 'talk', 'awful', 'support'],
#  ['state',
#   'stay',
#   'home',
#   'mandate',
#   'stop',
#   'permit',
#   'work',
#   'obtain',
#   'paperwork',
#   'say',
#   'work'],
#  ['cancel',
#   'delivery',
#   'request',
#   'really',
#   'care',
#   'less',
#   'diamond',
#   'rating',
#   'speak',
#   'unprofessionally',
#   'manager',
#   'cambridge',
#   'franklin',
#   'rd',
#   'half'],
#  ['food', 'never', 'arrive'],
#  ['day', 'able', 'work', 'approve', 'insurance', 'message', 'tell', 'go'],
#  ['help'],
#  ['look',
#   'manually',
#   'fix',
#   'account',
#   'appreciate',
#   'support',
#   'team',
#   'still',
#   'need',
#   'well',
#   'understand',
#   'request',
#   'respond',
#   'context',
#   'rather',
#   'use',
#   'can',
#   'response'],
#  ['email',
#   'send',
#   'document',
#   'guy',
#   'year',
#   'new',
#   'bull',
#   'shit',
#   'sick',
#   'say',
#   'sure',
#   'news',
#   'find',
#   'interesting',
#   'one'],
#  ['shady',
#   'fall',
#   'guideline',
#   'financial',
#   'support',
#   'send',
#   'require',
#   'doc',
#   'doctor',
#   'getti',
#   'fucking',
#   'run',
#   'suspend',
#   'account'],
#  ['still', 'hear', 'order', 'still', 'pende', 'app', 'reach'],
#  ['access', 'account', 'cel', 'receive', 'msm', 'code', 'number'],
#  ['phone', 'number', 'email', 'iam', 'locate', 'chihuahua', 'mexico'],
#  ['respond', 'dm', 'concern', 'uber', 'reward'],
#  ['need',
#   'help',
#   'account',
#   'get',
#   'back',
#   'know',
#   'email',
#   'registration',
#   'pende',
#   'pende',
#   'week',
#   'help'],
#  ['link',
#   'nhs',
#   'email',
#   'uber',
#   'account',
#   'long',
#   'take',
#   'get',
#   'code',
#   'thank'],
#  ['ill', 'reach', 'future', 'disgust', 'even', 'talk', 'people', 'today'],
#  ['absolute',
#   'bad',
#   'try',
#   'come',
#   'day',
#   'get',
#   'tax',
#   'information',
#   'issue',
#   'get',
#   'problem',
#   'solve',
#   'less',
#   'minute',
#   'uberistrash'],
#  ['uber',
#   'receive',
#   'ubereat',
#   'nhs',
#   'promotion',
#   'code',
#   'email',
#   'yet',
#   'help'],
#  ['sign',
#   'driver',
#   'get',
#   'message',
#   'contact',
#   'support',
#   'due',
#   'coronavirus'],
#  ['customer', 'service', 'answer'],
#  ['need', 'help', 'promo', 'code'],
#  ['speak', 'set', 'corporate', 'account'],
#  ['send', 'dm', 'keep', 'get', 'automate', 'response', 'covid'],
#  ['documentation',
#   'prove',
#   'unable',
#   'renew',
#   'license',
#   'plate',
#   'registration',
#   'emission',
#   'station',
#   'close',
#   'illinois',
#   'extended',
#   'expiration',
#   'date',
#   'day',
#   'time',
#   'lockdown',
#   'end'],
#  ['uber', 'eat', 'order', 'never', 'arrive', 'reach'],
#  ['try',
#   'add',
#   'nhs',
#   'discount',
#   'account',
#   'verify',
#   'email',
#   'address',
#   'open',
#   'duplicate',
#   'tab',
#   'browser',
#   'help'],
#  ['leech',
#   'parasite',
#   'world',
#   'surprise',
#   'make',
#   'fact',
#   'drain',
#   'country'],
#  ['need',
#   'help',
#   'approval',
#   'uber',
#   'eat',
#   'deliver',
#   'partner',
#   'document',
#   'day',
#   'upload',
#   'help'],
#  ['send', 'bank', 'transaction', 'review', 'tell', 'send'],
#  ['nhs', 'staff', 'code', 'yet'],
#  ['dm', 'request', 'get', 'response', 'help', 'number', 'respond'],
#  ['issue', 'lol', 'take', 'care'],
#  ['work',
#   'nhs',
#   'activate',
#   'code',
#   'free',
#   'ride',
#   'still',
#   'receive',
#   'email',
#   'regard',
#   'uber',
#   'eat'],
#  ['answer', 'dozen', 'time', 'send'],
#  ['able', 'app', 'work'],
#  ['promo', 'code', 'valid', 'today', 'work', 'checkout'],
#  ['order',
#   'food',
#   'almost',
#   'hour',
#   'app',
#   'still',
#   'unable',
#   'find',
#   'driver',
#   'pick',
#   'food',
#   'eta',
#   'time',
#   'keep',
#   'cancel',
#   'get',
#   'charge',
#   'fee',
#   'promo',
#   'fault',
#   'app',
#   'find',
#   'driver'],
#  ['never', 'get', 'response'],
#  ['license',
#   'expire',
#   'renew',
#   'dmv',
#   'closed',
#   'service',
#   'state',
#   'extend',
#   'expiration',
#   'day',
#   'drive',
#   'update',
#   'license',
#   'yet'],
#  ['order', 'wait'],
#  ['try',
#   'set',
#   'uber',
#   'eat',
#   'business',
#   'account',
#   'day',
#   'ago',
#   'hold',
#   'hour',
#   'phone',
#   'time',
#   'already',
#   'one',
#   'transfer',
#   'set',
#   'new',
#   'restaurant',
#   'try',
#   'set',
#   'delivery'],
#  ['send', 'phone', 'number', 'twitter', 'even', 'dms'],
#  ['try',
#   'set',
#   'uber',
#   'eat',
#   'business',
#   'account',
#   'day',
#   'ago',
#   'hold',
#   'hour',
#   'phone',
#   'time',
#   'already',
#   'one',
#   'transfer',
#   'set',
#   'new',
#   'restaurant',
#   'try',
#   'set',
#   'delivery'],
#  ['middle',
#   'maddening',
#   'case',
#   'support',
#   'rep',
#   'clearly',
#   'even',
#   'read',
#   'message',
#   'look',
#   'screenshot',
#   'get',
#   'can',
#   'response',
#   'well',
#   'delete',
#   'account',
#   'already'],
#  ['goog',
#   'guy',
#   'really',
#   'add',
#   'automate',
#   'chat',
#   'response',
#   'set',
#   'expectation',
#   'instead',
#   'response'],
#  ['change',
#   'email',
#   'address',
#   'still',
#   'recieve',
#   'message',
#   'uber',
#   'eat',
#   'code',
#   'try',
#   'suss',
#   'behalf',
#   'hosp',
#   'die',
#   'pizza'],
#  ['send'],
#  ['lucky',
#   'talk',
#   'live',
#   'person',
#   'email',
#   'support',
#   'take',
#   'hrs',
#   'get',
#   'reply',
#   'back'],
#  ['uber',
#   'driver',
#   'almost',
#   'year',
#   'like',
#   'able',
#   'drive',
#   'uber',
#   'eat',
#   'well',
#   'get',
#   'capability'],
#  ['read', 'look', 'tip', 'driver', 'restaurant', 'pick', 'stuff'],
#  ['need', 'year', 'ago', 'funny', 'story', 'get', 'tell'],
#  ['phone', 'number', 'go', 'twitter', 'even', 'dms'],
#  ['really', 'cool', 'charge', 'ride', 'direct', 'mean', 'customer', 'service'],
#  ['dm'],
#  ['nhs', 'code', 'uber', 'eat', 'arrive', 'nhs', 'mail', 'account'],
#  ['thank', 'add', 'detail', 'request'],
#  ['shame',
#   'uber',
#   'set',
#   'qualification',
#   'make',
#   'get',
#   'payment',
#   'impossible'],
#  ['thank', 'help'],
#  ['get',
#   'response',
#   'really',
#   'answer',
#   'grammatically',
#   'correct',
#   'enough',
#   'actually',
#   'tell',
#   'mean',
#   'concerned',
#   'account',
#   'compromise',
#   'get',
#   'bunch',
#   'needless',
#   'message',
#   'phone',
#   'try',
#   'hard'],
#  ['hospital',
#   'legally',
#   'put',
#   'documentation',
#   'quarantine',
#   'covid',
#   'test',
#   'test',
#   'positive',
#   'uber',
#   'require',
#   'specifically',
#   'note',
#   'reason',
#   'quarantine',
#   'test',
#   'result',
#   'immediate',
#   'impossible',
#   'get',
#   'pay'],
#  ['dynamic', 'day', 'dollar', 'way', 'go', 'block'],
#  ['think',
#   'uber',
#   'want',
#   'approve',
#   'document',
#   'reduce',
#   'amount',
#   'driver'],
#  ['still',
#   'need',
#   'customer',
#   'support',
#   'ubereat',
#   'tablet',
#   'working',
#   'get',
#   'thru',
#   'ubereat',
#   'phone',
#   'live',
#   'person',
#   'contact'],
#  ['upload',
#   'insurance',
#   'day',
#   'ago',
#   'still',
#   'time',
#   'still',
#   'pende',
#   'expire',
#   'suppose'],
#  ['order',
#   'raman',
#   'pickup',
#   'way',
#   'tip',
#   'restaurant',
#   'figure',
#   'intuitively',
#   'ubereat',
#   'tipyourwaitstaff',
#   'covid',
#   'yow',
#   'hospitalityindustry',
#   'socialdistance',
#   'covidottawa',
#   'uber'],
#  ['use', 'nhs', 'discount', 'ubereat'],
#  ['get',
#   'app',
#   'link',
#   'email',
#   'one',
#   'send',
#   'delete',
#   'account',
#   'let',
#   'start'],
#  ['way',
#   'disable',
#   'uber',
#   'cash',
#   'use',
#   'rider',
#   'use',
#   'business',
#   'profile'],
#  ['make',
#   'order',
#   'order',
#   'completely',
#   'wrong',
#   'tell',
#   'delivery',
#   'driver',
#   'say',
#   'problem',
#   'restaurant',
#   'call'],
#  ['already',
#   'contact',
#   'night',
#   'incident',
#   'tell',
#   'look',
#   's',
#   'communication'],
#  ['receive',
#   'uber',
#   'code',
#   'sm',
#   'even',
#   'access',
#   'app',
#   'week',
#   'account',
#   'compromise',
#   'glitch',
#   'thank'],
#  ['resolve', 'thank'],
#  ['get', 'money', 'take', 'account', 'use', 'uber', 'almost', 'year', 'help'],
#  ['agree',
#   'rosie',
#   'try',
#   'talk',
#   'sometime',
#   'joke',
#   'can',
#   'response',
#   'run',
#   'read',
#   'else',
#   'help',
#   'today',
#   'uber'],
#  ['receive', 'email', 'ubereat', 'promo', 'code', 'nhs', 'worker', 'get'],
#  ['thank',
#   'reply',
#   'ago',
#   'response',
#   'yet',
#   'well',
#   'efficient',
#   'way',
#   'support',
#   'access',
#   'account',
#   'hrs',
#   'initia',
#   'contact',
#   'move',
#   'inch',
#   'resolve'],
#  ['try',
#   'make',
#   'account',
#   'nhs',
#   'd',
#   'claim',
#   'free',
#   'ride',
#   'food',
#   'however',
#   'get',
#   'uber',
#   'mobile',
#   'number',
#   'already',
#   'allow',
#   'way',
#   'round'],
#  ['believe',
#   'explain',
#   'understand',
#   'decision',
#   'unfair',
#   'bias',
#   'incorrect',
#   'pax',
#   'accusation',
#   'base',
#   'odor',
#   'lawyer',
#   'false',
#   'accusation',
#   'really',
#   'unfair',
#   'really',
#   'need',
#   'assistance'],
#  ['uber', 'pay', 'driver'],
#  ['thank', 'pass', 'appear', 'user', 'error', 'hope', 'find', 'use'],
#  ['hold', 'support', 'hopefully', 'figure'],
#  ['happen',
#   'talk',
#   'early',
#   'step',
#   'go',
#   'protect',
#   'driver',
#   'partner',
#   'pandemic',
#   'suppose',
#   'supply',
#   'sanitizer',
#   'abd',
#   'kind',
#   'stuff',
#   'instead',
#   'close',
#   'leave',
#   'hang',
#   'good',
#   'job'],
#  ['fever',
#   'still',
#   'feel',
#   'shit',
#   'go',
#   'cost',
#   'life',
#   'sit',
#   'let',
#   'happen'],
#  ['unable', 'go', 'online', 'driver', 'restrict', 'access', 'driver'],
#  ['place', 'uber', 'eat', 'order', 'keep', 'get'],
#  ['dm', 'alot', 'people', 'point', 'willing', 'meet'],
#  ['update'],
#  ['mama', 'never', 'raise', 'snitch'],
#  ['thank',
#   'kind',
#   'free',
#   'meal',
#   'offer',
#   'nhs',
#   'finish',
#   'long',
#   'shift',
#   'love',
#   'food',
#   'send',
#   'promo',
#   'code',
#   'yet',
#   'send'],
#  ['update',
#   'driver',
#   'navigation',
#   'app',
#   'townsend',
#   'street',
#   'suggest',
#   'dropoff',
#   'caltrain',
#   'station',
#   'bike',
#   'lane',
#   'dangerous',
#   'stopping',
#   'allow'],
#  ['great', 'decision', 'worstcompany'],
#  ['boy',
#   'girl',
#   'rideshare',
#   'world',
#   'refer',
#   'paxhole',
#   'word',
#   'use',
#   'interchangeably',
#   'arsehole',
#   'asshole',
#   'anus'],
#  ['try',
#   'use',
#   'discount',
#   'code',
#   'due',
#   'expire',
#   'end',
#   'today',
#   'working',
#   'say',
#   'promotion',
#   'expire'],
#  ['rating', 'app', 'work'],
#  ['seriously', 'week', 'disappointing'],
#  ['verify', 'document', 'background', 'check', 'week', 'appreciate', 'work'],
#  ['thank'],
#  ['blind',
#   'voiceover',
#   'user',
#   'let',
#   'know',
#   'order',
#   'coke',
#   'ice',
#   'mcdonald',
#   'refuse',
#   'fix',
#   'bug',
#   'customization',
#   'screen'],
#  ['surely',
#   'go',
#   'possible',
#   'dm',
#   'additional',
#   'detail',
#   'experience',
#   'team',
#   'assist',
#   'appreciate',
#   'chance',
#   'review',
#   'concern'],
#  ['difficult',
#   'find',
#   'phone',
#   'number',
#   'need',
#   'call',
#   'complain',
#   'food',
#   'order',
#   'morning',
#   'want',
#   'refund',
#   'want',
#   'wait',
#   'hour',
#   'want',
#   'food',
#   'hungry',
#   'understand',
#   'give',
#   'number'],
#  ['keep', 'send', 'dm', 'provide', 'assistance'],
#  ['need',
#   'help',
#   'account',
#   'car',
#   'insurance',
#   'still',
#   'pende',
#   'need',
#   'get',
#   'second',
#   'day',
#   'loose',
#   'money',
#   'fix',
#   'account'],
#  ['m',
#   'unable',
#   'cancel',
#   'uber',
#   'pass',
#   'never',
#   'sign',
#   'uber',
#   'pass',
#   'cancel',
#   'get',
#   'refund',
#   'money',
#   'tight',
#   'unacceptable'],
#  ['do', 'thank'],
#  ['yesterday',
#   'governor',
#   'maryland',
#   'say',
#   'leave',
#   'house',
#   'essential',
#   'job',
#   'go',
#   'doctor',
#   'know',
#   'continue',
#   'uber',
#   'eat',
#   'need',
#   'letter'],
#  ['issue'],
#  ['call',
#   'chicago',
#   'base',
#   'uber',
#   'driver',
#   'plan',
#   'protest',
#   'uber',
#   'greenlight',
#   'hub',
#   'north',
#   'ave',
#   'want'],
#  ['download',
#   'invoice',
#   'homepage',
#   'option',
#   'file',
#   'support',
#   'case',
#   'bad',
#   'performance'],
#  ['dm', 'send'],
#  ['receive', 'nhs', 'uber', 'eat', 'code', 'register', 'yesterday', 'thank'],
#  ['need',
#   'taxi',
#   'outstation',
#   'travel',
#   'medical',
#   'condition',
#   'arrange',
#   'pass',
#   'uninterrupted',
#   'journey',
#   'suggest',
#   'possible',
#   'destination',
#   'bhadohi',
#   'approx',
#   'km',
#   'delhi'],
#  ['hey', 'guy', 'help', 'covid', 'send', 'document', 'guy', 'answer'],
#  ['thank', 'hard', 'work', 'thankyounhs'],
#  ['free', 'food', 'nhs', 'code', 'work'],
#  ['work', 'dude', 'haha', 'cheerio'],
#  ['uber',
#   'want',
#   'pay',
#   'day',
#   'financial',
#   'aid',
#   'affect',
#   'corona',
#   'virus',
#   'hospital',
#   'tell',
#   'lock',
#   'home',
#   'symptom'],
#  ['hear',
#   'seem',
#   'uber',
#   'overwhelm',
#   'many',
#   'new',
#   'driver',
#   'join',
#   'uber',
#   'due',
#   'unemployment',
#   'uber',
#   'also',
#   'cancel',
#   'referral',
#   'bonus',
#   'joke',
#   'idea',
#   'free',
#   'book',
#   'work',
#   'home',
#   'free',
#   'ebook',
#   'makemoney',
#   'workfromhome',
#   'take',
#   'care'],
#  ['week',
#   'old',
#   'risk',
#   'passenger',
#   'drive',
#   'present',
#   'symptom',
#   'hospital',
#   'deny',
#   'medical',
#   'attention',
#   'uber',
#   'deny',
#   'financial',
#   'help',
#   'stay',
#   'locked',
#   'home'],
#  ['impossible'],
#  ['question',
#   'able',
#   'access',
#   'account',
#   'driver',
#   'shopper',
#   'adjust',
#   'acceptance',
#   'rating',
#   'seem',
#   'simple',
#   'thing',
#   'implement',
#   'do',
#   'fix'],
#  ['still', 'find', 'help'],
#  ['day',
#   'upload',
#   'insurance',
#   'certificate',
#   'still',
#   'pende',
#   'covid',
#   'unacceptable',
#   'apologise',
#   'put',
#   'food',
#   'table',
#   'pay',
#   'bill'],
#  ['day', 'still', 'wait', 'respond', 'help'],
#  ['try',
#   'add',
#   'nhs',
#   'account',
#   'existin',
#   'uber',
#   'account',
#   'unable',
#   'say',
#   'send',
#   'email',
#   'account',
#   'help'],
#  ['support',
#   'site',
#   'uber',
#   'eat',
#   'work',
#   'try',
#   'get',
#   'help',
#   'order',
#   'never',
#   'deliver',
#   'last',
#   'saturday',
#   'app',
#   'mark',
#   'deliver',
#   'want',
#   'money',
#   'back'],
#  ['take', 'day', 'approve', 'insurance', 'doc', 'unacceptable'],
#  ['never', 'use'],
#  ['need', 'contact', 'uber'],
#  ['uber',
#   'tell',
#   'week',
#   'point',
#   'right',
#   'suppose',
#   'business',
#   'day',
#   'wtaf'],
#  ['resolve', 'quickly', 'thank', 'much'],
#  ['still',
#   'wait',
#   'uberdriver',
#   'uber',
#   'driverssupport',
#   'uberseattle',
#   'kingcounty',
#   'wa'],
#  ['understand',
#   'rating',
#   'trip',
#   'account',
#   'put',
#   'hold',
#   'need',
#   'consent',
#   'background',
#   'check',
#   'agree',
#   'many',
#   'term',
#   'give',
#   'consent',
#   'drive',
#   'continually',
#   'provide',
#   'par',
#   'service'],
#  ['new',
#   'jersey',
#   'motor',
#   'vehicle',
#   'agency',
#   'close',
#   'month',
#   'extension',
#   'document',
#   'try',
#   'proactive',
#   'uber',
#   'put',
#   'platform',
#   'morning',
#   'global',
#   'pandemic',
#   'make',
#   'bad',
#   'situation',
#   'bad'],
#  ['register',
#   'nhs',
#   'email',
#   'account',
#   'add',
#   'nhs',
#   'promo',
#   'promo',
#   'show',
#   'uber',
#   'eat',
#   'uber',
#   'try',
#   'enter',
#   'checkout',
#   'say',
#   'enter',
#   'code',
#   'twice',
#   'discount',
#   'apply',
#   'help'],
#  ['receive',
#   'email',
#   'say',
#   'charge',
#   'cancel',
#   'ride',
#   'corporate',
#   'card',
#   'charge',
#   'yesterday',
#   'assist'],
#  ['give',
#   'complete',
#   'document',
#   'include',
#   'tell',
#   'need',
#   'pmt',
#   'take',
#   'platform',
#   'base',
#   'document',
#   'end',
#   'quarantine',
#   'refuse',
#   'pay'],
#  ['need',
#   'copy',
#   'case',
#   'covid',
#   'deal',
#   'fucking',
#   'way',
#   'able',
#   'use',
#   'uber',
#   'cash',
#   'week',
#   'response',
#   'legit',
#   'fucking',
#   'message',
#   'tell'],
#  ['orderedmeal',
#   'food',
#   'arrive',
#   'cold',
#   'chicken',
#   'feel',
#   'old',
#   'keep',
#   'chicken',
#   'last',
#   'dhs',
#   'compensation',
#   'dhs',
#   'order',
#   'enough',
#   'need',
#   'refund',
#   'back',
#   'asap',
#   'bad',
#   'food',
#   'delivery',
#   'expect'],
#  ['address',
#   'issue',
#   'uber',
#   'require',
#   'incomplete',
#   'uber',
#   'take',
#   'platform',
#   'require',
#   'uber',
#   'refuse',
#   'pay',
#   'single',
#   'mom',
#   'help',
#   'shieldvoc'],
#  ['store',
#   'cancel',
#   'order',
#   'arrive',
#   'store',
#   'compensation',
#   'money',
#   'cancel',
#   'order'],
#  ['know', 'hopefully', 'get', 'later', 'today', 'tomorrow'],
#  ['m',
#   'post',
#   'support',
#   'document',
#   'conversation',
#   'show',
#   'driver',
#   'issue',
#   'give',
#   'false',
#   'hope'],
#  ['offer',
#   'driver',
#   'financial',
#   'assistance',
#   'take',
#   'road',
#   'give',
#   'false',
#   'hope',
#   'instead',
#   'say',
#   'help',
#   'driver',
#   'take',
#   'road',
#   'lie',
#   'turn',
#   'app',
#   'tell',
#   'deal'],
#  ['lose',
#   'gold',
#   'status',
#   'virus',
#   'choose',
#   'drive',
#   'taking',
#   'class',
#   'right',
#   'want',
#   'lose',
#   'ability',
#   'pay',
#   'uber',
#   'thank'],
#  ['disabled',
#   'app',
#   'able',
#   'make',
#   'money',
#   'feed',
#   'go',
#   'deny',
#   'assistance',
#   'even',
#   'document',
#   'say',
#   'drive',
#   'find',
#   'good',
#   'company',
#   'time'],
#  ['check', 'dm'],
#  ['see',
#   'elsewhere',
#   'twitter',
#   'offer',
#   'available',
#   'first',
#   'cs',
#   'pretty',
#   'sure',
#   'legal',
#   'anyway',
#   'delete',
#   'app',
#   'justeat',
#   'cheaper',
#   'reliable'],
#  ['thank', 'never', 'use', 'uber', 'service'],
#  ['simply',
#   'type',
#   'step',
#   'take',
#   'ensure',
#   'driver',
#   'ill',
#   'word',
#   'none',
#   'uber',
#   'great',
#   'threat',
#   'health',
#   'safety',
#   'employ',
#   'many',
#   'terrorist',
#   'know',
#   'guess',
#   'germ',
#   'warfare',
#   'next',
#   'uber',
#   'scary'],
#  ['willing',
#   'pay',
#   'way',
#   'get',
#   'contact',
#   'need',
#   'document',
#   'review',
#   'approve',
#   'even',
#   'new',
#   'document',
#   'update',
#   'account',
#   'hold',
#   'almost',
#   'day',
#   'limited',
#   'staff',
#   'quick',
#   'fix'],
#  ['unpublished',
#   'phone',
#   'number',
#   'know',
#   'work',
#   'uber',
#   'uber',
#   'support',
#   'dm',
#   'info',
#   'need',
#   'drive',
#   'day',
#   'income',
#   'do',
#   'wrong',
#   'choose',
#   'drive',
#   'need',
#   'person'],
#  ['wait',
#   'circle',
#   'expand',
#   'year',
#   'software',
#   'design',
#   'issue',
#   'deliver',
#   'location',
#   'neighborhood',
#   'drive',
#   'house',
#   'add',
#   'feature',
#   'people',
#   'try',
#   'food',
#   'delivery',
#   'right'],
#  ['bull',
#   'driver',
#   'fam',
#   'get',
#   'uber',
#   'cash',
#   'credit',
#   'give',
#   'use',
#   'cause',
#   'invalid',
#   'keep',
#   'try',
#   'get',
#   'shit',
#   'make',
#   'sense',
#   'screen',
#   'shoot',
#   'phone',
#   'setting',
#   'price',
#   'number',
#   'real',
#   'illegal'],
#  ['account', 'activation', 'email', 'number'],
#  ['kylie', 'direct', 'inquiry', 'able', 'assist'],
#  ['already', 'reach', 'link', 'check', 'dms'],
#  ['bad',
#   'customer',
#   'service',
#   'ever',
#   'stick',
#   'home',
#   'trying',
#   'order',
#   'food',
#   'contact',
#   'dms',
#   'get',
#   'automate',
#   'message',
#   'try',
#   'order',
#   'breakfast',
#   'family'],
#  ['still',
#   'willing',
#   'put',
#   'risk',
#   'financial',
#   'option',
#   'suspend',
#   'account',
#   'expire',
#   'document',
#   'even',
#   'current',
#   'provide',
#   'many',
#   'day',
#   'expiration',
#   'day',
#   'wait',
#   'person',
#   'review'],
#  ['sure',
#   'allow',
#   'buy',
#   'voucher',
#   'dollar',
#   'refund',
#   'happy',
#   'hear',
#   'experience',
#   'describe',
#   'unfortunately',
#   'make',
#   'refund'],
#  ['day',
#   'still',
#   'wait',
#   'response',
#   'email',
#   'year',
#   'ago',
#   'last',
#   'week',
#   'able',
#   'create',
#   'account',
#   'today',
#   'uber',
#   'ubereat',
#   'ubersupport',
#   'uberfail',
#   'ubereatsfail',
#   'ubercustomerservice',
#   'rideshareapp',
#   'ridesharing',
#   'fooddelivery'],
#  ['lose', 'gift', 'code', 'due', 'system', 'day', 'still', 'help', 'fuck'],
#  ['want', 'organize', 'protest', 'uber', 'greenlight', 'hub', 'chicago'],
#  ['move',
#   'delaware',
#   'set',
#   'open',
#   'inspection',
#   'test',
#   'place',
#   'hour',
#   'away',
#   'toll',
#   'uber',
#   'pay',
#   'car',
#   'tiguan'],
#  ['fix',
#   'support',
#   'system',
#   'suspend',
#   'account',
#   'resource',
#   'available',
#   'review',
#   'doxument',
#   'perhaps',
#   'time',
#   'change',
#   'review',
#   'process',
#   'still',
#   'earn',
#   'live'],
#  ['talk',
#   'trip',
#   'show',
#   'link',
#   'talking',
#   'trip',
#   'order',
#   'yesterday',
#   'min',
#   'go',
#   'charge',
#   'order',
#   'total',
#   'take',
#   'advantage',
#   'situation',
#   'make',
#   'profit'],
#  ['delivery',
#   'fee',
#   'service',
#   'charge',
#   'tip',
#   'right',
#   'add',
#   'tip',
#   'restaurant',
#   'option',
#   'add',
#   'tip',
#   'place',
#   'online',
#   'order',
#   'ubereat'],
#  ['day',
#   'starve',
#   'girl',
#   'try',
#   'help',
#   'deactivate',
#   'acc',
#   'use',
#   'code',
#   'waste',
#   'ppl',
#   'money'],
#  ['also',
#   'try',
#   'contact',
#   'paypal',
#   'bank',
#   'fighting',
#   'covid',
#   'bad',
#   'get',
#   'hold',
#   'uber',
#   'eat',
#   'even',
#   'bad',
#   'rather',
#   'spend',
#   'day',
#   'relax',
#   'stress',
#   'lose',
#   'money'],
#  ['also',
#   'try',
#   'cancel',
#   'order',
#   'vendor',
#   'cancel',
#   'food',
#   'leave',
#   'door',
#   'thank',
#   'uber',
#   'eat',
#   'totally',
#   'mess',
#   'day',
#   'emergency',
#   'ambulance',
#   'day',
#   'rest',
#   'ring'],
#  ['also',
#   'report',
#   'serious',
#   'payment',
#   'option',
#   'breach',
#   'point',
#   'authorise',
#   'save',
#   'paypal',
#   'payment',
#   'detail',
#   'press',
#   'paypal',
#   'option',
#   'take',
#   'paypal',
#   'site',
#   'pay',
#   'item',
#   'purchase',
#   'uber',
#   'eat',
#   'company'],
#  ['fuck',
#   'member',
#   'uber',
#   'leadership',
#   'team',
#   'leader',
#   'reach',
#   'lifeblood',
#   'company',
#   'give',
#   'shit',
#   'driver'],
#  ['help',
#   'quarantine',
#   'document',
#   'submit',
#   'uber',
#   'take',
#   'platform',
#   'end',
#   'quarantine',
#   'still',
#   'platform',
#   'uber',
#   'pay',
#   'promise'],
#  ['thank',
#   'reply',
#   'take',
#   'delivery',
#   'talk',
#   'food',
#   'preparation',
#   'guarantee',
#   'chef',
#   'symptom',
#   'spread',
#   'virus',
#   'deliver',
#   'food',
#   'responsibility',
#   'customer',
#   'make',
#   'ill'],
#  ['help',
#   'quarantine',
#   'document',
#   'submit',
#   'uber',
#   'take',
#   'platform',
#   'end',
#   'quarantine',
#   'still',
#   'platform',
#   'uber',
#   'pay',
#   'promise'],
#  ['send',
#   'info',
#   'right',
#   'away',
#   'hope',
#   'hear',
#   'make',
#   'sense',
#   'send',
#   'excel',
#   'bank',
#   'transaction',
#   'ahead',
#   'time',
#   'go',
#   'initial',
#   'explanation'],
#  ['appear',
#   'uber',
#   'stop',
#   'support',
#   'driver',
#   'absolutely',
#   'response',
#   'avenue',
#   'smh',
#   'good',
#   'news',
#   'lyft',
#   'support',
#   'user',
#   'add',
#   'vehicle',
#   'normal',
#   'car',
#   'shop',
#   'lyft',
#   'driving',
#   'min',
#   'wait',
#   'uber',
#   'week'],
#  ['recieve',
#   'email',
#   'take',
#   'account',
#   'recieve',
#   'email',
#   'charge',
#   'order',
#   'make'],
#  ['take', 'care', 'already', 'thank'],
#  ['send', 'guy', 'message'],
#  ['come',
#   'put',
#   'mouth',
#   'lie',
#   'submit',
#   'damn',
#   'paperwork',
#   'ask',
#   'claim',
#   'deny',
#   'suck'],
#  ['crazy',
#   'driver',
#   'take',
#   'money',
#   'never',
#   'pick',
#   'defend',
#   'refund',
#   'well',
#   'go',
#   'guess'],
#  ['update',
#   'order',
#   'cancel',
#   'also',
#   'press',
#   'paypal',
#   'take',
#   'paypal',
#   'sign',
#   'take',
#   'money',
#   'straight',
#   'away',
#   'sign',
#   'security',
#   'breach',
#   'time',
#   'authorise',
#   'save',
#   'detail'],
#  ['keep', 'reject', 'driver', 'license', 'drive', 'uber', 'eat'],
#  ['careful', 'post', 'online'],
#  ['order',
#   'restaurant',
#   'still',
#   'open',
#   'explicitly',
#   'select',
#   'want',
#   'order',
#   'fulfil',
#   'later',
#   'open'],
#  ['speak',
#   'app',
#   'really',
#   'resolve',
#   'issue',
#   'take',
#   'bank',
#   'instead',
#   'thank',
#   'reach'],
#  ['talk',
#   'rep',
#   'phone',
#   'send',
#   'several',
#   'message',
#   'week',
#   'turn',
#   'ubereat',
#   'help'],
#  ['know', 'change', 'tip', 'make', 'ubereat', 'tip', 'first', 'place'],
#  ['totally', 'agree'],
#  ['contact', 'bank', 'charge', 'back', 'order', 'cancel', 'uber'],
#  ['neither'],
#  ['shocking',
#   'service',
#   'uber',
#   'eat',
#   'answer',
#   'phone',
#   'cancel',
#   'order',
#   'cancellation',
#   'confirmation',
#   'cancel',
#   'instantly',
#   'second',
#   'promo',
#   'apply',
#   'discount',
#   'subtract',
#   'total',
#   'contact',
#   'method',
#   'rediculous',
#   'answer'],
#  ['couple', 'promo', 'code', 'ubereat', 'account', 'use', 'australia', 'help'],
#  ['think', 'try', 'use', 'uber', 'account'],
#  ['uber',
#   'eat',
#   'credit',
#   'unable',
#   'use',
#   'credit',
#   'zomato',
#   'benefit',
#   'give',
#   'zomato',
#   'free',
#   'zomato',
#   'gold',
#   'membership'],
#  ['financial', 'support', 'guarantee', 'uber'],
#  ['top',
#   'priority',
#   'follow',
#   'sir',
#   'uber',
#   'cancellation',
#   'trend',
#   'finding',
#   'solution',
#   'reoccurring',
#   'issue',
#   'hyderabad',
#   'secunderabad',
#   'delhi',
#   'bengaluru',
#   'chennai',
#   'kolkata',
#   'mumbai'],
#  ['do', 'first', 'time', 'lot', 'decide', 'ignore', 'force', 'fix'],
#  ['do', 'thank'],
#  ['issue',
#   'order',
#   'day',
#   'kindly',
#   'refunded',
#   'part',
#   'money',
#   'check',
#   'bank',
#   'statement',
#   'money',
#   'refund',
#   'take',
#   'original',
#   'price',
#   'meal',
#   'take',
#   'account',
#   'double',
#   'meal',
#   'cost'],
#  ['send', 'dms', 'reply', 'need', 'help'],
#  ['acct',
#   'hold',
#   'expire',
#   'upload',
#   'txdeptofpublic',
#   'safety',
#   'letter',
#   'officialy',
#   'authorize',
#   'day',
#   'extension',
#   'online',
#   'ironical',
#   'represent',
#   'uber',
#   'well',
#   'treat',
#   'system',
#   'fail',
#   'go',
#   'work'],
#  ['thank', 'much', 'support'],
#  ['enough',
#   'uber',
#   'reward',
#   'apple',
#   'news',
#   'subscription',
#   'month',
#   'disappear',
#   'chance',
#   'redeem',
#   'happen',
#   'reward',
#   'point'],
#  ['try',
#   'month',
#   'retrieve',
#   'invoice',
#   'travel',
#   'avail',
#   'extremely',
#   'dishearten',
#   'encounter',
#   'service'],
#  ['send',
#   'dm',
#   'phone',
#   'number',
#   'thank',
#   'look',
#   'matter',
#   'deactivate',
#   'expire',
#   'registration',
#   'governor',
#   'extend',
#   'deadline',
#   'april',
#   'th'],
#  ['send',
#   'dm',
#   'day',
#   'ago',
#   'reply',
#   'side',
#   'really',
#   'upset',
#   'way',
#   'handle',
#   'customer',
#   'complaint',
#   'file',
#   'complaint',
#   'week',
#   'ago',
#   'also',
#   'reply',
#   'addition',
#   'unprofessional',
#   'supervisor',
#   'phone'],
#  ['human',
#   'help',
#   'submit',
#   'documentation',
#   'financial',
#   'assistance',
#   'appear',
#   'date',
#   'cut',
#   'top',
#   'image',
#   'doctor',
#   'letter',
#   'submit',
#   'get',
#   'attention',
#   'help',
#   'deny'],
#  ['add', 'uber', 'nhs', 'code', 'use', 'straight', 'away'],
#  ['day',
#   'simple',
#   'update',
#   'vehicle',
#   'inspection',
#   'submit',
#   'day',
#   'expiration',
#   'account',
#   'hold',
#   'day',
#   'suspend',
#   'people',
#   'account',
#   'man',
#   'power',
#   'review',
#   'document'],
#  ['start',
#   'think',
#   'box',
#   'due',
#   'covid',
#   'situation',
#   'licensing',
#   'commission',
#   'close',
#   'several',
#   'driver',
#   'unable',
#   'renew',
#   'permit',
#   'note',
#   'attach',
#   'screenshot',
#   'website'],
#  ['good',
#   'go',
#   'deliveroo',
#   'instead',
#   'honestly',
#   'guy',
#   'great',
#   'sort',
#   'tech',
#   'issue'],
#  ['give', 'coupon', 'last', 'day', 'add', 'code', 'say', 'expire', 'give'],
#  ['holy', 'bot', 'read', 'damn', 'thing', 'twunt'],
#  ['change', 'phone', 'login', 'account', 'help'],
#  ['check', 'dm'],
#  ['time',
#   'ride',
#   'still',
#   'refuse',
#   'fix',
#   'serious',
#   'safety',
#   'issue',
#   'happen',
#   'uber',
#   'absolutely',
#   'refuse',
#   'fix',
#   'serious',
#   'safety',
#   'issue'],
#  ['phone',
#   'system',
#   'say',
#   'live',
#   'order',
#   'location',
#   'close',
#   'hiw',
#   'tti',
#   'resolve'],
#  ['frustrated',
#   'stress',
#   'figure',
#   'refund',
#   'cancel',
#   'issue',
#   'new',
#   'card',
#   'still',
#   'wait',
#   'day',
#   'hack',
#   'account',
#   'permanently',
#   'delete',
#   'personal',
#   'information',
#   'stay',
#   'vulnerable'],
#  ['silkwood', 'phone', 'support', 'restaurant', 'close'],
#  ['need',
#   'help',
#   'nyc',
#   'dmv',
#   'cancel',
#   'resgistration',
#   'renewal',
#   'extend',
#   'resgistration',
#   'expire',
#   'march',
#   'oaye',
#   'registration',
#   'jo',
#   'way',
#   'get',
#   'keep',
#   'drive',
#   'document',
#   'expire',
#   'uber',
#   'account'],
#  ['mine', 'get', 'yet'],
#  ['payment', 'receive', 'pay', 'fair'],
#  ['s', 'find', 'way', 'send', 'concern', 'charge', 'multiple', 'time', 'card'],
#  ['bill',
#   'masucci',
#   'license',
#   'registration',
#   'do',
#   'car',
#   'account',
#   'sell',
#   'buy'],
#  ['app',
#   'break',
#   'charge',
#   'multiple',
#   'time',
#   's',
#   'support',
#   'available',
#   'app',
#   'site'],
#  ['help', 'register', 'number', 'uber', 'eat', 'private', 'message', 'look'],
#  ['dear',
#   'sir',
#   'uber',
#   'sell',
#   'zomato',
#   'receive',
#   'email',
#   'promise',
#   'zomato',
#   'gold',
#   'membership',
#   'place',
#   'certain',
#   'number',
#   'order',
#   'zomato',
#   'yest',
#   'offer',
#   'promise',
#   'month',
#   'free',
#   'zomato',
#   'gold',
#   'membership',
#   'promise',
#   'followup'],
#  ['initiate',
#   'uber',
#   'pass',
#   'january',
#   'year',
#   'feature',
#   'turn',
#   'cancel',
#   'march',
#   'utilize',
#   'uber',
#   'foreseeable',
#   'future',
#   'remove',
#   'charge'],
#  ['account',
#   'deactivate',
#   'really',
#   'never',
#   'help',
#   'represent',
#   'uber',
#   'excellence',
#   'get',
#   'crappy',
#   'deactivation',
#   'notice',
#   'email',
#   'unacceptable',
#   'pls',
#   'go',
#   'back',
#   'investigate',
#   'dept',
#   'public',
#   'safety',
#   'lettr',
#   'need',
#   'income',
#   'ubereat'],
#  ['hope',
#   'guy',
#   'save',
#   'lot',
#   'people',
#   'virus',
#   'many',
#   'reply',
#   'get',
#   'guy',
#   'guy',
#   'busy',
#   'help',
#   'people',
#   'virus',
#   'shit'],
#  ['last', 'week', 'account', 'keep', 'hold', 'whole', 'week'],
#  ['receive',
#   'email',
#   'free',
#   'meal',
#   'nhs',
#   'staff',
#   'previously',
#   'link',
#   'account',
#   'nhs',
#   'email',
#   'account',
#   'see',
#   'promotion',
#   'app'],
#  ['well', 'do', 'ola', 'wish', 'cab', 'operate', 'india', 'follow', 'suit'],
#  ['send', 'number', 'detail'],
#  ['know',
#   'give',
#   'contract',
#   'driver',
#   'program',
#   'tell',
#   'charge',
#   'return',
#   'vehicle',
#   'barely',
#   'charge',
#   'day',
#   'call',
#   'message',
#   'say',
#   'overdue',
#   'return'],
#  ['management',
#   'communicate',
#   'partner',
#   'driver',
#   'regard',
#   'movement',
#   'cessation',
#   'lago',
#   'affect',
#   'next',
#   'think',
#   'big',
#   'flop',
#   'path',
#   'information',
#   'integral',
#   'part',
#   'uber',
#   'system'],
#  ['contact',
#   'mobile',
#   'consent',
#   'response',
#   'process',
#   'ask',
#   'personal',
#   'information',
#   'want',
#   'uber',
#   'info',
#   'never',
#   'want',
#   'first',
#   'place',
#   'impressed'],
#  ['want',
#   'get',
#   'emergency',
#   'passenger',
#   'cab',
#   'help',
#   'get',
#   'register',
#   'system',
#   'wb'],
#  ['thank',
#   'free',
#   'ride',
#   'nhs',
#   'staff',
#   'meal',
#   'really',
#   'make',
#   'get',
#   'work',
#   'easy',
#   'hero',
#   'wear',
#   'cape',
#   'drop',
#   'work',
#   'free',
#   'charge',
#   'global',
#   'pandemic'],
#  [],
#  ['side',
#   'right',
#   'partner',
#   'uber',
#   'deserve',
#   'noncooperative',
#   'behavior',
#   'await',
#   'positive',
#   'action',
#   'revert'],
#  ['close',
#   'account',
#   'expect',
#   'company',
#   'uber',
#   'know',
#   'make',
#   'allegation',
#   'uber',
#   'justify'],
#  ['couple',
#   'negative',
#   'comment',
#   'ignore',
#   'entire',
#   'history',
#   'work',
#   'completely',
#   'unprofessional',
#   'act',
#   'call',
#   'uber',
#   'partner',
#   'treat',
#   'put',
#   'much',
#   'company'],
#  ['even',
#   'share',
#   'reason',
#   'uber',
#   'treat',
#   'loyal',
#   'hardworke',
#   'partner',
#   'specially',
#   'pandemic',
#   'situation',
#   'try',
#   'hard',
#   'give',
#   'service',
#   'fulfil',
#   'family',
#   'need'],
#  ['uber',
#   'partner',
#   'month',
#   'complete',
#   'trip',
#   'rating',
#   'many',
#   'positive',
#   'feedback',
#   'however',
#   'rider',
#   'wrong',
#   'accusation',
#   'allegation',
#   'surely',
#   'mistake',
#   'close',
#   'account'],
#  ['help', 'time', 'sensitive', 'really', 'need', 'account', 'freeze'],
#  ['try', 'hour', 'tomorrow', 'assist'],
#  ['people',
#   'hack',
#   'account',
#   'put',
#   'step',
#   'verification',
#   'know',
#   'phone',
#   'number',
#   'need',
#   'way',
#   'delete',
#   'account',
#   'asap',
#   'help',
#   'scared',
#   'card',
#   'attach',
#   'account'],
#  ['need',
#   'desperate',
#   'help',
#   'find',
#   'way',
#   'reach',
#   'guy',
#   'account',
#   'hack',
#   'log',
#   'know',
#   'hack',
#   'still',
#   'attach',
#   'email',
#   'address',
#   'charge',
#   'put',
#   'credit',
#   'card',
#   'uber',
#   'eat'],
#  ['thank'],
#  ['understand',
#   'thing',
#   'busy',
#   'right',
#   'order',
#   'cancel',
#   'hour',
#   'place',
#   'card',
#   'charge',
#   'food',
#   'make',
#   'uber',
#   'driver',
#   'restaurant',
#   'give',
#   'food',
#   'extremely',
#   'ridiculous',
#   'unprofessional',
#   'want',
#   'money'],
#  ['customer',
#   'service',
#   'email',
#   'uber',
#   'india',
#   'already',
#   'raise',
#   'request',
#   'rider',
#   'data',
#   'trip',
#   'info',
#   'know',
#   'specific',
#   'trip',
#   'arrival',
#   'time'],
#  ['midnight',
#   'fall',
#   'asleep',
#   'easily',
#   'give',
#   'enough',
#   'time',
#   'especially',
#   'phone',
#   'dead',
#   'fall',
#   'asleep',
#   'soon',
#   'get',
#   'home',
#   'even',
#   'watch',
#   'netflix'],
#  ['worry',
#   'thank',
#   'support',
#   'app',
#   'finally',
#   'respond',
#   'appreciate',
#   'get',
#   'back',
#   'good',
#   'night'],
#  ['suck', 'hope', 'refund'],
#  ['cool', 'take', 'note'],
#  ['wait',
#   'day',
#   'submit',
#   'document',
#   'financial',
#   'help',
#   'tell',
#   'kid',
#   'food',
#   'delay',
#   'due',
#   'volume',
#   'inquiry'],
#  ['guy',
#   'sit',
#   'halfway',
#   'drive',
#   'way',
#   'mess',
#   'around',
#   'get',
#   'notification',
#   'order',
#   'deliver',
#   'pull',
#   'eventually',
#   'uber',
#   'customer',
#   'support',
#   'right',
#   'send',
#   'email',
#   'pray'],
#  ['eat', 'definitely', 'eat', 'food'],
#  ['driver',
#   'come',
#   'way',
#   'house',
#   'spend',
#   'lot',
#   'time',
#   'front',
#   'never',
#   'bring',
#   'food',
#   'house',
#   'leave',
#   'report',
#   'delivery',
#   'do'],
#  ['want',
#   'delete',
#   'uber',
#   'account',
#   'sign',
#   'moment',
#   'delete',
#   'end',
#   'happy',
#   'share',
#   'personal',
#   'detail',
#   'make',
#   'process',
#   'easy',
#   'thank'],
#  ['still',
#   'receive',
#   'hear',
#   'driver',
#   'receive',
#   'cleaning',
#   'supply',
#   'promise',
#   'send',
#   'get'],
#  ['able',
#   'take',
#   'hold',
#   'put',
#   'maybe',
#   'next',
#   'time',
#   'resource',
#   'review',
#   'approve',
#   'document',
#   'maybe',
#   'suspend',
#   'diligent',
#   'driver'],
#  ['long'],
#  ['long',
#   'suppose',
#   'stay',
#   'suspend',
#   'expire',
#   'vehicle',
#   'inspection',
#   'send',
#   'update',
#   'old',
#   'expire',
#   'yet',
#   'suspend',
#   'account',
#   'tell',
#   'understand',
#   'frustration',
#   'bear',
#   'day'],
#  ['submit',
#   'update',
#   'registration',
#   'insurance',
#   'document',
#   'tomorrow',
#   'able',
#   'drive',
#   'say',
#   'document',
#   'pende',
#   'help'],
#  ['try',
#   'hold',
#   'hour',
#   'driver',
#   'accident',
#   'go',
#   'hospital',
#   'cancel',
#   'order'],
#  ['refund', 'money', 'want', 'resolve', 'use', 'uber', 'cab'],
#  ['thank',
#   'info',
#   'good',
#   'general',
#   'reference',
#   'plan',
#   'definition',
#   'contain',
#   'authority',
#   'mention',
#   'effect',
#   'order',
#   'ride',
#   'share',
#   'program',
#   'limit',
#   'passenger'],
#  ['today',
#   'log',
#   'uber',
#   'driver',
#   'app',
#   'say',
#   'account',
#   'need',
#   'attention',
#   'contact',
#   'uber',
#   'support',
#   'even',
#   'though',
#   'never',
#   'get',
#   'email',
#   'uber',
#   'tell',
#   'wrong',
#   'check'],
#  ['send', 'right', 'thank'],
#  ['problem', 'replace', 'number', 'account', 'doubt', 'association'],
#  ['review',
#   'new',
#   'insurance',
#   'week',
#   'think',
#   'use',
#   'excuse',
#   'keep',
#   'road',
#   'pay',
#   'get',
#   'covid',
#   'maybe',
#   'know',
#   'rider',
#   'withhold',
#   'information'],
#  ['hold',
#   'breath',
#   'review',
#   'new',
#   'insurance',
#   'week',
#   'think',
#   'use',
#   'excuse',
#   'get',
#   'driver',
#   'road',
#   'give',
#   'covid',
#   'money',
#   'get',
#   'conspiracy'],
#  ['yesterday', 'thank'],
#  ['driver', 'nyc', 'jersey', 'wear', 'mask', 'glove'],
#  ['uber', 'eat', 'work'],
#  ['thank',
#   'tipped',
#   'driver',
#   'really',
#   'penalize',
#   'number',
#   'mix',
#   'honest',
#   'mistake',
#   'go',
#   'walk',
#   'around',
#   'look'],
#  ['access',
#   'account',
#   'recently',
#   'change',
#   'number',
#   'keep',
#   'send',
#   'code',
#   'old',
#   'number',
#   'need',
#   'update',
#   'new',
#   'number'],
#  ['want',
#   'know',
#   'long',
#   'take',
#   'become',
#   'uber',
#   'eat',
#   'courier',
#   'hour',
#   'hear',
#   'guy'],
#  ['go', 'solve', 'problem'],
#  ['thank', 'respond', 'hopefully', 'resolve'],
#  ['respond', 'important', 'week'],
#  ['thank'],
#  ['need', 'help'],
#  ['thank', 'context'],
#  ['rethink',
#   'stop',
#   'ride',
#   'forever',
#   'come',
#   'first',
#   'stop',
#   'wait',
#   'charge'],
#  ['uber', 'essential', 'accord'],
#  ['update'],
#  ['explain',
#   'use',
#   'form',
#   'transport',
#   'happen',
#   'social',
#   'distancing',
#   'use',
#   'stretch',
#   'limos',
#   'london',
#   'see',
#   'daily',
#   'accident',
#   'involve',
#   'untrained',
#   'driver',
#   'become',
#   'laugh',
#   'stock',
#   'serious'],
#  ['guy',
#   'sudden',
#   'license',
#   'say',
#   'blurry',
#   'fine',
#   'year',
#   'take',
#   'new',
#   'picture',
#   'update',
#   'need',
#   'review',
#   'asap'],
#  ['thank',
#   'get',
#   'uber',
#   'eat',
#   'order',
#   'wrong',
#   'time',
#   'row',
#   'handle',
#   'horribly'],
#  ['soooo', 'julia', 'deliver', 'drink', 'chipotle', 'gon'],
#  ['need', 'uber', 'placard', 'vehicle'],
#  ['instead',
#   'uber',
#   'let',
#   'customer',
#   'cheat',
#   'uber',
#   'expense',
#   'upsetting',
#   'listen',
#   'accuse',
#   'true',
#   'listen',
#   'driver'],
#  ['matter',
#   'hard',
#   'work',
#   'driver',
#   'year',
#   'high',
#   'rating',
#   'honest',
#   'uber',
#   'take',
#   'right',
#   'uber',
#   'eat',
#   'accuse',
#   'fraud',
#   'make',
#   'delivery',
#   'lie',
#   'uber',
#   'give',
#   'detail',
#   'defend'],
#  ['life',
#   'figure',
#   'add',
#   'food',
#   'delivery',
#   'driver',
#   'account',
#   'point',
#   'right',
#   'direction'],
#  ['never',
#   'find',
#   'driver',
#   'hour',
#   'charge',
#   'cancellation',
#   'fee',
#   'need',
#   'human',
#   'correct',
#   'ai',
#   'support'],
#  ['get', 'answer', 'else'],
#  ['team', 'xxxx'],
#  ['get',
#   'problem',
#   'guy',
#   'get',
#   'unprofessional',
#   'driver',
#   'deliver',
#   'order',
#   'hand',
#   'mom',
#   'bag',
#   'drop',
#   'want',
#   'drink',
#   'help'],
#  ['already',
#   'try',
#   'web',
#   'site',
#   'awful',
#   'phone',
#   'number',
#   'chat',
#   'available',
#   'want',
#   'know',
#   'use',
#   'identity',
#   'get',
#   'uber'],
#  [],
#  ['girl',
#   'go',
#   'write',
#   'man',
#   'drive',
#   'crazy',
#   'hell',
#   'thank',
#   'god',
#   'make',
#   'alive',
#   'bday'],
#  ['switch',
#   'cc',
#   'eat',
#   'pass',
#   'accidentally',
#   'use',
#   'corp',
#   'card',
#   'find',
#   'help',
#   'anywhere',
#   'help'],
#  ['go',
#   'drive',
#   'lyft',
#   'support',
#   'driver',
#   'whew',
#   'uber',
#   'promise',
#   'pay',
#   'driver',
#   'quarantine',
#   'take',
#   'platform',
#   'end',
#   'quarantine',
#   'deny',
#   'claim',
#   'uber',
#   'care',
#   'driver',
#   'shieldvoc'],
#  ['mess',
#   'charge',
#   'entirely',
#   'different',
#   'route',
#   'actually',
#   'take',
#   'whole',
#   'difference',
#   'time',
#   'fuck',
#   'ppl',
#   'money'],
#  ['option'],
#  ['horrible',
#   'time',
#   'cut',
#   'support',
#   'staffing',
#   'perhaps',
#   'way',
#   'allow',
#   'work',
#   'home',
#   'driver',
#   'need',
#   'help',
#   'starve'],
# ...
#   'first',
#   'time',
#   'use',
#   'uber',
#   'ever',
#   'give',
#   'uber',
#   'credit',
#   'use',
#   'account',
#   'literally',
#   'change',
#   'number',
#   'time',
#   'voip',
#   'use',
#   'friend',
#   'number',
#   'get',
#   'today',
#   'alone'],
#  ['wait',
#   'answer',
#   'quarantine',
#   'due',
#   'symptom',
#   'contact',
#   'rider',
#   'pass',
#   'evaluate',
#   'doctor',
#   'reach',
#   'driver',
#   'app',
#   'yet',
#   'response'],
#  ['apply',
#   'uber',
#   'east',
#   'driver',
#   'week',
#   'ago',
#   'wonder',
#   'take',
#   'long',
#   'problem'],
#  ['call'],
#  ['unlock',
#   'account',
#   'get',
#   'correct',
#   'resolution',
#   'back',
#   'end',
#   'support',
#   'team',
#   'name',
#   'rahul',
#   'chitte',
#   'mobile',
#   'email'],
#  ['day',
#   'account',
#   'still',
#   'suspend',
#   'promise',
#   'financial',
#   'assistance',
#   'starve',
#   'afford',
#   'eat',
#   'day',
#   'fix',
#   'leader'],
#  ['wonder', 'team', 'work', 'weekend'],
#  ['read',
#   'coronavirusoutbreak',
#   'coronaupdate',
#   'uber',
#   'make',
#   'driver',
#   'drive',
#   'sick',
#   'lie',
#   'whole',
#   'world'],
#  ['refund', 'spoil', 'cold', 'food', 'basically', 'tell'],
#  ['march',
#   'book',
#   'cab',
#   'gaurcity',
#   'ghaziabad',
#   'railway',
#   'station',
#   'booking',
#   'fair',
#   'display',
#   'yesterday',
#   'see',
#   'fair',
#   'display',
#   'trip',
#   'actually',
#   'generally',
#   'pay',
#   'card',
#   'show',
#   'time'],
#  ['sick',
#   'covid',
#   'deathly',
#   'ill',
#   'tell',
#   'document',
#   'legit',
#   'medical',
#   'website',
#   'ridiculous',
#   'making',
#   'jump',
#   'hoop',
#   'deathly',
#   'ill'],
#  ['send',
#   'dm',
#   'already',
#   'respond',
#   'auto',
#   'reply',
#   'contact',
#   'support',
#   'already',
#   'do',
#   'time'],
#  ['say',
#   'qualify',
#   'assistance',
#   'still',
#   'acct',
#   'suspend',
#   'even',
#   'covid',
#   'neg',
#   'note',
#   'work',
#   'week',
#   'work',
#   'break',
#   'crazy',
#   'hang'],
#  ['bad',
#   'customer',
#   'service',
#   'ever',
#   'busy',
#   'worry',
#   'money',
#   'first',
#   'last',
#   'use',
#   'bum',
#   'ass',
#   'app'],
#  ['apply', 'week', 'ago', 'deliver', 'hold'],
#  ['glad', 'hear'],
#  ['keep',
#   'get',
#   'message',
#   'scam',
#   'suspect',
#   'scam',
#   'know',
#   'suppose',
#   'arrive',
#   'randomly'],
#  ['morning',
#   'worry',
#   'get',
#   'amex',
#   'charge',
#   'crazy',
#   'even',
#   'order',
#   'cancel',
#   'appreciate',
#   'guy'],
#  ['really', 'sad'],
#  ['try',
#   'use',
#   'ubereat',
#   'first',
#   'time',
#   'unpleasant',
#   'experience',
#   'charge',
#   'order'],
#  ['resolve', 'thank'],
#  ['try',
#   'sign',
#   'cycler',
#   'courier',
#   'upload',
#   'document',
#   'criminal',
#   'background',
#   'check',
#   'stay',
#   'grey',
#   'untouchable',
#   'keep',
#   'say',
#   'upload',
#   'remain',
#   'document',
#   'indicate',
#   'help'],
#  ['help',
#   'account',
#   'document',
#   'pende',
#   'change',
#   'mope',
#   'app',
#   'go',
#   'online',
#   'phone',
#   'number',
#   'asociate'],
#  ['uber',
#   'account',
#   'issue',
#   'try',
#   'get',
#   'elderly',
#   'father',
#   'set',
#   'bother',
#   'provide',
#   'phone',
#   'support',
#   'problem'],
#  ['already', 'tell', 'ask', 'set', 'account', 'read', 'damn', 'tweet'],
#  ['guy', 'review', 'insurance'],
#  ['access', 'menu', 'tab', 'update', 'hour'],
#  ['even', 'read', 'question', 'respond', 'question'],
#  ['need', 'help', 'cancel', 'order'],
#  ['drive',
#   'drop',
#   'food',
#   'wrong',
#   'place',
#   'never',
#   'contact',
#   'still',
#   'charge',
#   'food'],
#  ['actually', 'driver', 'aswell'],
#  ['take',
#   'day',
#   'authorize',
#   'new',
#   'insurance',
#   'get',
#   'back',
#   'online',
#   'meanwhile',
#   'lyft',
#   'take',
#   'hour'],
#  ['crap', 'getting', 'day', 'tell', 'give', 'day'],
#  ['promise',
#   'dm',
#   'update',
#   'email',
#   'get',
#   'need',
#   'update',
#   'stop',
#   'pass',
#   'buck'],
#  ['dm', 'send', 'many', 'thank', 'team'],
#  ['connect', 'driver', 'minute', 'away'],
#  ['receive',
#   'discount',
#   'mail',
#   'order',
#   'try',
#   'apply',
#   'discount',
#   'code',
#   'appear',
#   'code',
#   'long',
#   'available',
#   'deadline',
#   'today'],
#  ['maybe',
#   'receive',
#   'high',
#   'normal',
#   'support',
#   'volume',
#   'keep',
#   'send',
#   'needless',
#   'text',
#   'random',
#   'user',
#   'trust',
#   'credit',
#   'card',
#   'number',
#   'think'],
#  ['rather',
#   'cancel',
#   'eat',
#   'pass',
#   'subscription',
#   'seeing',
#   'deliver',
#   'whole',
#   'month',
#   'march',
#   'defer',
#   'payment',
#   'month'],
#  ['account', 'temporarily', 'place', 'hold', 'indianapolis', 'indiana', 'go'],
#  ['give', 'essential', 'worker', 'discount', 'ride', 'work'],
#  ['try',
#   'get',
#   'assistance',
#   'covid',
#   'mess',
#   'bad',
#   'thing',
#   'ever',
#   'do',
#   'way',
#   'care',
#   'people',
#   'work',
#   'give',
#   'run',
#   'around'],
#  ['upload',
#   'document',
#   'march',
#   'today',
#   'update',
#   'due',
#   'unable',
#   'drive',
#   'uber',
#   'reactivate',
#   'soon',
#   'possible'],
#  ['doubt', 'happen', 'say', 'question', 'tall', 'exactly', 'much', 'weigh'],
#  ['order',
#   'meal',
#   'gift',
#   'card',
#   'account',
#   'charge',
#   'total',
#   'amount',
#   'card',
#   'refund',
#   'money',
#   'order'],
#  ['try',
#   'change',
#   'phone',
#   'number',
#   'account',
#   'receive',
#   'message',
#   'phone',
#   'number',
#   'take',
#   'help',
#   'immediately'],
#  ['send'],
#  ['really', 'available', 'verify', 'driver', 'insurance', 'upload'],
#  ['se', 'reply', 'call', 'say', 'uber'],
#  ['file', 'unemployment', 'state', 'website'],
#  ['driver',
#   'sleep',
#   'food',
#   'watter',
#   'biscuit',
#   'help',
#   'm',
#   'also',
#   'driver',
#   'partner',
#   'alsoin',
#   'verry',
#   'trubbel'],
#  ['keep', 'send', 'uber', 'code', 'text', 'ask', 'go'],
#  ['perhaps', 'assist', 'query'],
#  ['good',
#   'morning',
#   'uber',
#   'help',
#   'approve',
#   'insurance',
#   'document',
#   'submit'],
#  ['pls',
#   'look',
#   'rego',
#   'pende',
#   'approval',
#   'day',
#   'work',
#   'past',
#   'day',
#   'mail',
#   'i',
#   'd',
#   'phone'],
#  ['file',
#   'week',
#   'half',
#   'ago',
#   'promise',
#   'day',
#   'get',
#   'thing',
#   'sort',
#   'submit',
#   'necessary',
#   'paperwork',
#   'response',
#   'imagine',
#   'lot',
#   'driver',
#   'work',
#   'sick',
#   'rather',
#   'notify',
#   'uber',
#   'family',
#   'starve'],
#  ['use', 'uber', 'eat', 'website', 'app', 'website', 'go', 'click', 'help'],
#  ['still', 'wait'],
#  ['buy', 'new', 'sim', 'mobile', 'find', 'already', 'block', 'help'],
#  ['issue',
#   'account',
#   'log',
#   'avon',
#   'solve',
#   'issue',
#   'love',
#   'promo',
#   'code',
#   'free',
#   'delivery',
#   'get',
#   'back'],
#  ['help',
#   'order',
#   'uber',
#   'eat',
#   'driver',
#   'say',
#   'food',
#   'door',
#   'charge',
#   'get'],
#  ['great',
#   'glad',
#   'hear',
#   'definitely',
#   'lot',
#   'question',
#   'figure',
#   'state',
#   'state',
#   'thing'],
#  ['thank', 'free', 'bike', 'ride'],
#  ['uber', 'support', 'help', 'get', 'contact', 'support'],
#  ['girl', 'mine'],
#  ['promotion', 'say', 'expire', 'april', 'th', 'date', 'happen', 'yet'],
#  ['dm'],
#  ['meal', 'order', 'deliver', 'feel', 'rip', 'follow', 'order', 'ddbd'],
#  ['well', 'hella', 'alarming'],
#  ['register',
#   'phone',
#   'number',
#   'upload',
#   'document',
#   'day',
#   'ago',
#   'order',
#   'uber',
#   'eat',
#   'driver',
#   'vevo',
#   'check',
#   'still',
#   'pende',
#   'also',
#   'thing',
#   'tell',
#   'upload',
#   'criminal',
#   'background',
#   'check'],
#  ['bank',
#   'transaction',
#   'day',
#   'never',
#   'take',
#   'uber',
#   'basically',
#   'question',
#   'transaction',
#   'need',
#   'help',
#   'make',
#   'sure',
#   'fraud',
#   'advise',
#   'thank'],
#  ['wait', 'respond', 'month', 'email', 'menssage', 'app', 'need', 'answer'],
#  ['reconcile',
#   'business',
#   'expense',
#   'look',
#   'period',
#   'jan',
#   'feb',
#   'get',
#   'bank',
#   'transaction',
#   'count',
#   'trip',
#   'happy',
#   'share',
#   'detail',
#   'transaction',
#   'pass',
#   'card',
#   'help'],
#  ['activate', 'uber', 'account', 'block', 'low', 'uber', 'rating'],
#  ['nope',
#   'close',
#   'enquiry',
#   'email',
#   'confirm',
#   'credit',
#   'know',
#   'part',
#   'business',
#   'plan',
#   'lie',
#   'tooth'],
#  ['actually',
#   'care',
#   'quality',
#   'food',
#   'client',
#   'receive',
#   'driver',
#   'take',
#   'order',
#   'say'],
#  ['guy', 'go', 'post', 'help', 'people', 'file', 'unemployment', 'mess'],
#  ['waitlisted',
#   'year',
#   'look',
#   'account',
#   'eligible',
#   'ubereat',
#   'uberx',
#   'pls',
#   'dm'],
#  ['uber',
#   'credit',
#   'amex',
#   'platinum',
#   'card',
#   'add',
#   'next',
#   'month',
#   'credit'],
#  ['uber',
#   'driver',
#   'partner',
#   'help',
#   'universal',
#   'calamity',
#   'donate',
#   'amount',
#   'uber',
#   'account',
#   'stand',
#   'corona',
#   'war',
#   'also',
#   'daily',
#   'wage',
#   'think'],
#  ['way',
#   'change',
#   'tip',
#   'amount',
#   'uber',
#   'eat',
#   'order',
#   'hour',
#   'credit',
#   'card',
#   'authorization',
#   'window',
#   'pass'],
#  ['dismiss', 'mistaking', 'woman', 'reality', 'lol', 'stupid', 'language'],
#  ['thank',
#   'concern',
#   'pal',
#   'fleet',
#   'partner',
#   'manage',
#   'somehow',
#   'even',
#   'recession',
#   'worry',
#   'million',
#   'driver',
#   'driver',
#   'organisation',
#   'try',
#   'well',
#   'save',
#   'humanity',
#   'take',
#   'care'],
#  ['lie',
#   'say',
#   'apply',
#   'credit',
#   'account',
#   'driver',
#   'try',
#   'endanger',
#   'health',
#   'want',
#   'take',
#   'lift',
#   'refund',
#   'money',
#   'credit',
#   'never',
#   'give',
#   'never',
#   'order'],
#  ['mate',
#   'dig',
#   'see',
#   'uber',
#   'driver',
#   'say',
#   'globe',
#   'mean',
#   'personal',
#   'account',
#   'hope',
#   'sort',
#   'uber',
#   'government',
#   'also',
#   'responsibility',
#   'care',
#   'keep',
#   'family',
#   'safe'],
#  ['do',
#   'want',
#   'try',
#   'help',
#   'least',
#   'word',
#   'partner',
#   'ola',
#   'worried',
#   'get',
#   'new',
#   'driver',
#   'partner',
#   'poor',
#   'family',
#   'starve',
#   'death'],
#  ['thing', 'finally', 'resolve'],
#  ['anywhere', 'class', 'self', 'employ', 'do', 'help'],
#  ['hour',
#   'great',
#   'need',
#   'driver',
#   'fleet',
#   'partner',
#   'company',
#   'pay',
#   'employee',
#   'wanna',
#   'people',
#   'earn',
#   'commission'],
#  ['harry',
#   'actively',
#   'work',
#   'gather',
#   'relevant',
#   'information',
#   'driver',
#   'vary',
#   'state',
#   'state',
#   'touch',
#   'soon',
#   'possible',
#   'likely',
#   'monday'],
#  ['well',
#   'verify',
#   'credit',
#   'card',
#   'bring',
#   'submit',
#   'app',
#   'charge',
#   'fraudulently',
#   'charge',
#   'today',
#   'system',
#   'guy',
#   'put',
#   'flag',
#   'catch',
#   'number',
#   'use',
#   'zip',
#   'code',
#   'match',
#   'billing',
#   'zip'],
#  ['guy', 'reset', 'rating', 'go', 'issue'],
#  ['guy', 'sleep', 'day', 'work', 'night'],
#  ['save', 'podcast', 'gem', 'lol'],
#  ['dm', 'send'],
#  ['canto', 'register', 'motorcycle'],
#  ['wait'],
#  ['payment',
#   'method',
#   'give',
#   'error',
#   'say',
#   'payment',
#   'method',
#   'unavailable',
#   'card',
#   'try'],
#  ['uber',
#   'allow',
#   'order',
#   'close',
#   'restaurant',
#   'driver',
#   'pull',
#   'clearly',
#   'get',
#   'food',
#   'try',
#   'use',
#   'help',
#   'support',
#   'option',
#   'order',
#   'never',
#   'arrive',
#   'app',
#   'still',
#   'mark',
#   'route',
#   'want',
#   'money',
#   'back'],
#  ['read', 'tweet', 'answer', 'question'],
#  ['covid',
#   'pandemic',
#   'lot',
#   'company',
#   'take',
#   'care',
#   'people',
#   'make',
#   'sure',
#   'pay',
#   'deal',
#   'public',
#   'premium',
#   'rate',
#   'fact',
#   'cut',
#   'driver',
#   'support',
#   'weekend',
#   'refuse',
#   'respond',
#   'driver'],
#  ['ola',
#   'uber',
#   'company',
#   'take',
#   'commission',
#   'unable',
#   'give',
#   'driver',
#   'hour',
#   'trouble'],
#  ['hell',
#   'happening',
#   'order',
#   'cancel',
#   'tell',
#   'still',
#   'pay',
#   'hang',
#   'disconnect',
#   'charge',
#   'order',
#   'back',
#   'delete',
#   'good'],
#  ['know', 'use', 'email', 'account'],
#  ['harsha',
#   'vardhan',
#   'know',
#   'covid',
#   'outbreake',
#   'hard',
#   'australia',
#   'tough',
#   'time',
#   'go',
#   'outside',
#   'cab',
#   'sincerely',
#   'request',
#   'uber',
#   'account',
#   'helpful',
#   'covid',
#   'outbreak'],
#  ['consider', 'benefit', 'fraud', 'felony'],
#  ['terrify', 'scamme'],
#  ['happen', 'course', 'nice', 'actually', 'get', 'touch'],
#  ['yrs',
#   'specifically',
#   'endorse',
#   'uber',
#   'yesterday',
#   'order',
#   'uber',
#   'car',
#   'filthy',
#   'dirty',
#   'car',
#   'show',
#   'huge',
#   'lyft',
#   'sign',
#   'interior',
#   'filthy',
#   'well',
#   'rusty',
#   'dirty',
#   'rag',
#   'back',
#   'seat',
#   'ewwwwe',
#   'upholstery',
#   'also',
#   'disgustingly',
#   'filthy'],
#  ['day', 'ago', 'still', 'hear', 'back'],
#  ['thank', 'able', 'get', 'thing', 'resolve', 'yesterday'],
#  ['man', 'get', 'response'],
#  ['go',
#   'state',
#   'level',
#   'feed',
#   'reimburse',
#   'state',
#   'keep',
#   'process',
#   'catch'],
#  ['order',
#   'first',
#   'time',
#   'tonight',
#   'use',
#   'first',
#   'order',
#   'coupon',
#   'get',
#   'apply',
#   'order',
#   'use',
#   'first',
#   'order',
#   'halp'],
#  ['need',
#   'help',
#   'try',
#   'create',
#   'account',
#   'keep',
#   'say',
#   'number',
#   'already',
#   'account',
#   'last',
#   'person',
#   'number',
#   'help'],
#  ['shout',
#   'guy',
#   'try',
#   'scam',
#   'uber',
#   'eat',
#   'pose',
#   'laugh',
#   'waaay',
#   'hard',
#   'lock',
#   'payout',
#   'close',
#   'praise',
#   'network',
#   'issue',
#   'work',
#   'app'],
#  ['get', 'response'],
#  ['corona',
#   'virus',
#   'relief',
#   'legislation',
#   'indicate',
#   'uber',
#   'driver',
#   'usa',
#   'apply',
#   'unemployment',
#   'guideline',
#   'process',
#   'follow',
#   'apply',
#   'benefit'],
#  ['issue', 'resolve', 'thank'],
#  ['uber', 'famous', 'fraud', 'ubersuck'],
#  ['s', 'absolutely', 'disgusting'],
#  ['understand', 'uninstalled', 'reinstalled', 'app', 'get', 'back', 'work'],
#  ['stop',
#   'surge',
#   'pricing',
#   'pandemic',
#   'pls',
#   'icu',
#   'nurse',
#   'try',
#   'get',
#   'work',
#   'help',
#   'affordably',
#   'wearethefrontline',
#   'gougeprice'],
#  ['electronic',
#   'fund',
#   'transfer',
#   'act',
#   'efta',
#   'deal',
#   'fraud',
#   'directly',
#   'card',
#   'issuer',
#   'cancel',
#   'card',
#   'issue',
#   'new',
#   'pain',
#   'change',
#   'new',
#   'number',
#   'automatic',
#   'bill',
#   'pay'],
#  ['already', 'contact', 'credit', 'union'],
#  ['call', 'past', 'wait', 'time', 'bit', 'long'],
#  ['call',
#   'debit',
#   'card',
#   'company',
#   'card',
#   'physically',
#   'lose',
#   'steal',
#   'day',
#   'report',
#   'fraudulent',
#   'transaction',
#   'liability',
#   'day',
#   'start',
#   'date',
#   'statement',
#   'fraudulent',
#   'transaction',
#   'appear'],
#  ['call', 'customer', 'service', 'dispute'],
#  ['vehicle',
#   'trunk',
#   'release',
#   'back',
#   'seat',
#   'make',
#   'false',
#   'accusation',
#   'even',
#   'lower',
#   'snitch'],
#  ['fraudulently',
#   'use',
#   'mother',
#   'debit',
#   'card',
#   'make',
#   'large',
#   'order',
#   'uber',
#   'eat',
#   'uber',
#   'account',
#   'public',
#   'phone',
#   'number',
#   'list',
#   'contact',
#   'get',
#   'touch'],
#  ['majiira', 'talk', 'hope', 'ur', 'well'],
#  ['time', 'phone', 'line', 'need', 'talk'],
#  ['still',
#   'get',
#   'text',
#   'well',
#   'homie',
#   'get',
#   'response',
#   'hack',
#   'russia'],
#  ['general',
#   'safe',
#   'make',
#   'sure',
#   'big',
#   'bold',
#   'driver',
#   'know',
#   'new',
#   'miss'],
#  ['excited',
#   'support',
#   'local',
#   'restaurant',
#   'tonight',
#   'ubereat',
#   'use',
#   'ubercash',
#   'giftcard',
#   'make',
#   'sure',
#   'uber',
#   'cash',
#   'ready',
#   'pay',
#   'instead',
#   'whole',
#   'meal',
#   'charge',
#   'credit',
#   'card',
#   'need',
#   'help'],
#  ['world',
#   'pandemic',
#   'go',
#   'people',
#   'loose',
#   'job',
#   'top',
#   'discount',
#   'trip',
#   'rate',
#   'charge',
#   'surge',
#   'peek',
#   'hour',
#   'uber',
#   'well'],
#  ['wrongfully',
#   'restrict',
#   'suspend',
#   'account',
#   'apparently',
#   'violate',
#   'term',
#   'service',
#   'file',
#   'ticket',
#   'tell',
#   'go',
#   'lift',
#   'wrongfully',
#   'system',
#   'apply',
#   'ban',
#   'say',
#   'kid',
#   'lift',
#   'suspension'],
#  ['send', 'dm', 'ave', 'get', 'automate', 'response'],
#  ['round',
#   'mail',
#   'chain',
#   'prof',
#   'answer',
#   'guy',
#   'shy',
#   'away',
#   'frm',
#   'acknowledge',
#   'mistake',
#   'uber',
#   'accept',
#   'shortcoming',
#   'least',
#   'refund',
#   'disgusting',
#   'shameful',
#   'pathetic',
#   'guy',
#   'lie',
#   'least'],
#  ['still',
#   'response',
#   'week',
#   'document',
#   'pende',
#   'ubereat',
#   'hand',
#   'ridiculous',
#   'need',
#   'do',
#   'need',
#   'handle',
#   'asap'],
#  ['thank', 'send', 'message'],
#  ['confused',
#   'want',
#   'give',
#   'driver',
#   'proper',
#   'tip',
#   'accidentally',
#   'send',
#   'meager',
#   'life',
#   'saving',
#   'help',
#   'hope'],
#  ['pleeeeze',
#   'help',
#   'desperately',
#   'need',
#   'send',
#   'message',
#   'uber',
#   'delivery',
#   'deliverer',
#   'help',
#   'private',
#   'help',
#   'section',
#   'give',
#   'option',
#   'send',
#   'message',
#   'go',
#   'thank',
#   'advance'],
#  ...]

# %% [markdown]
# ### Filter unfrequent words

# %%
#deleted_words = ['ahora', 'antes', 'después', 'tarde', 'luego', 'ayer', 'temprano', 'ya', 'todavía', 'anteayer', 'aún', 'pronto', 'hoy',
#           'aquí', 'ahí', 'allí', 'cerca', 'lejos', 'fuera', 'dentro', 'alrededor', 'aparte', 'encima', 'debajo', 'delante',
#           'detrás', 'así', 'bien', 'mal', 'despacio', 'deprisa', 'como', 'mucho', 'poco', 'muy', 'casi', 'todo', 'nada',
#           'algo', 'medio', 'demasiado', 'bastante', 'más', 'menos', 'además', 'incluso', 'también', 'sí', 'también',
#           'asimismo', 'no', 'tampoco', 'jamás', 'nunca', 'deber', 'poder', 'querer', 'saber', 'soler', 'cabify']

#no_accents_words = []
#for word in deleted_words:
#    no_accents_words.append(normalize(word))
    
#deleted_words = list(set(deleted_words+no_accents_words))

#rare_words_dic = dict((word,v )for word,v in cnt.items() if v <= 5 )
#rare_words = list(rare_words_dic.keys()) + deleted_words
#print(len(rare_words))



#texts = [[token for token in tweet if token not in rare_words] for tweet in texts]

# %%
word_list = [word for tweet in texts for word in tweet]
words_dist = FreqDist(word_list)

deleted_words = [token[0] for token in list(filter(lambda x: x[1]<=5,words_dist.items()))]
deleted_words = set(deleted_words)
texts = [[token for token in text if token not in deleted_words] for text in texts]

# %% [markdown]
# ### Stemming

# %%
#stemmer = SnowballStemmer("english")
#texts = [[stemmer.stem(token) for token in text] for text in texts]

# %% [markdown]
# ### Cleaning the texts

# %%
texts = [[word for word in tweet if len(word)>2] for tweet in texts]
texts = [tweet for tweet in texts if (len(tweet)>0)]
#texts

# %% [markdown]
# ### Bigrams

# %%
#bigram = gensim.models.Phrases(texts, min_count=20) 
#texts = [bigram[text] for text in texts]

# %% [markdown]
# ## Dictionary and corpus

# %%
dictionary = corpora.Dictionary(texts)
print(dictionary)
# Out:
# Dictionary(8276 unique tokens: ['agent', 'ask', 'call', 'car', 'disinfect']...)

# %%
corpus = [dictionary.doc2bow(doc) for doc in texts]
print(len(corpus))
# Out:
# 212386

# %%
words = []
for i in dictionary:
    words += [dictionary.get(i)] 

words.sort()

# %% [markdown]
# ## Save results

# %%
path = "./results/variables"
try:
    if not os.path.isdir(path):
        os.makedirs(path)
except OSError:
    print ("Creation of the directory %s failed" % path)
else:
    print ("Successfully created the directory %s " % path)
# Out:
# Successfully created the directory ./results/variables

# %%
with open("results/variables/dictionary_alphabetical.txt", "w") as out_file:
    for word in words:
        out_file.write(word)
        out_file.write("\n")
#words

# %%
joblib.dump(texts, "results/variables/texts.pkl")
dictionary.save('results/variables/dictionary.dict')
MmCorpus.serialize("results/variables/corpus.corp", corpus)

# %%
dic_ordered = sorted(words , key = len)
with open("results/variables/dictionary_ordered.txt", "w") as out_file:
    for word in dic_ordered:
        out_file.write(word)
        out_file.write("\n")

# %% [markdown]
# # LDA Models

# %% [markdown]
# ## Load variables

# %%
texts = joblib.load("results/variables/texts.pkl")
dictionary = corpora.Dictionary.load("results/variables/dictionary.dict")
corpus = MmCorpus("results/variables/corpus.corp")

# %% [markdown]
# ## Compute LDA coherence and perplexity

# %%
def compute_coherence_values(dictionary, corpus, texts, limit, start, iterations, random, passes):

    coherence_values = []
    perplexity = []
    model_list = []
    for num_topics in range(start, limit):
        model = gensim.models.LdaMulticore(corpus=corpus,
                                          id2word=dictionary,
                                          num_topics=num_topics,
                                          chunksize=100,
                                          random_state=random,
                                          iterations = iterations,
                                          passes=passes,
                                          #alpha=a,
                                          #eta=b,
                                          workers=33,
                                          per_word_topics=True)        
       # model = gensim.models.ldamodel.LdaModel(corpus=corpus, num_topics=num_topics, id2word=dictionary, random_state= random, iterations=iterations, passes = passes)
        model_list.append(model)
        
        coherencemodel = CoherenceModel(model=model, texts=texts, dictionary=dictionary, coherence='c_v')
        coherence_values.append(coherencemodel.get_coherence())
        
        perplexity_model_lda = model.log_perplexity(corpus)
        perplexity.append(perplexity_model_lda)
        
    return model_list, coherence_values, perplexity

# %%
start = time()
model_list, coherence_values, perplexity_model_lda  = compute_coherence_values(dictionary=dictionary, corpus=corpus, texts=texts, start=1, limit=40, iterations = 50, random = 100, passes = 10)
print('Time used for calculating LDA: {:.2f}s'.format(time()-start))
# Out:
# Time used for calculating LDA: 62774.19s

# %% [markdown]
# ## Load best coherence model

# %% [markdown]
# ### Word distriburtion

# %%
id = coherence_values.index(max(coherence_values))
best_model = model_list[id]
best_model.print_topics(num_words = 20)
# Out:
# [(0,
#   '0.086*"driver" + 0.053*"ride" + 0.045*"cancel" + 0.042*"trip" + 0.031*"uber" + 0.024*"charge" + 0.020*"time" + 0.020*"book" + 0.020*"cab" + 0.017*"ask" + 0.014*"fee" + 0.014*"call" + 0.014*"minute" + 0.014*"location" + 0.013*"pick" + 0.013*"show" + 0.012*"take" + 0.012*"drop" + 0.011*"wait" + 0.011*"min"'),
#  (1,
#   '0.053*"charge" + 0.052*"uber" + 0.045*"money" + 0.042*"pay" + 0.027*"payment" + 0.024*"account" + 0.022*"card" + 0.019*"refund" + 0.019*"cash" + 0.019*"take" + 0.018*"amount" + 0.016*"ride" + 0.015*"pass" + 0.015*"credit" + 0.015*"bank" + 0.013*"back" + 0.013*"app" + 0.012*"use" + 0.011*"trip" + 0.011*"want"'),
#  (2,
#   '0.097*"issue" + 0.035*"problem" + 0.031*"resolve" + 0.029*"hour" + 0.027*"fix" + 0.025*"get" + 0.019*"still" + 0.015*"day" + 0.015*"back" + 0.015*"support" + 0.014*"time" + 0.012*"sort" + 0.012*"app" + 0.012*"solve" + 0.012*"tell" + 0.012*"look" + 0.011*"call" + 0.010*"try" + 0.010*"week" + 0.009*"response"'),
#  (3,
#   '0.050*"driver" + 0.040*"uber" + 0.031*"take" + 0.026*"car" + 0.024*"drive" + 0.022*"complaint" + 0.015*"vehicle" + 0.013*"action" + 0.011*"document" + 0.010*"insurance" + 0.009*"upload" + 0.009*"reject" + 0.009*"license" + 0.009*"route" + 0.008*"need" + 0.008*"long" + 0.008*"picture" + 0.008*"name" + 0.007*"want" + 0.007*"also"'),
#  (4,
#   '0.091*"help" + 0.060*"account" + 0.053*"number" + 0.049*"phone" + 0.047*"uber" + 0.040*"need" + 0.035*"contact" + 0.034*"app" + 0.033*"support" + 0.033*"get" + 0.026*"try" + 0.023*"call" + 0.017*"email" + 0.013*"driver" + 0.012*"change" + 0.011*"delete" + 0.010*"eat" + 0.010*"find" + 0.008*"log" + 0.008*"access"'),
#  (5,
#   '0.133*"order" + 0.049*"food" + 0.036*"refund" + 0.029*"delivery" + 0.027*"get" + 0.023*"restaurant" + 0.022*"deliver" + 0.022*"eat" + 0.020*"cancel" + 0.020*"hour" + 0.019*"driver" + 0.017*"place" + 0.015*"say" + 0.014*"uber" + 0.014*"app" + 0.012*"never" + 0.012*"time" + 0.012*"wrong" + 0.011*"charge" + 0.011*"receive"'),
#  (6,
#   '0.033*"uber" + 0.024*"company" + 0.023*"tip" + 0.022*"driver" + 0.018*"think" + 0.017*"follow" + 0.015*"see" + 0.015*"happen" + 0.013*"people" + 0.013*"use" + 0.011*"know" + 0.011*"lol" + 0.010*"way" + 0.009*"give" + 0.009*"thing" + 0.008*"scam" + 0.008*"well" + 0.008*"treat" + 0.008*"business" + 0.007*"anymore"'),
#  (7,
#   '0.142*"service" + 0.141*"customer" + 0.049*"bad" + 0.033*"support" + 0.026*"experience" + 0.025*"ever" + 0.023*"care" + 0.020*"uber" + 0.014*"well" + 0.014*"company" + 0.013*"guy" + 0.013*"really" + 0.013*"terrible" + 0.011*"poor" + 0.011*"provide" + 0.011*"never" + 0.009*"absolutely" + 0.009*"horrible" + 0.009*"suck" + 0.008*"business"'),
#  (8,
#   '0.089*"thank" + 0.055*"check" + 0.049*"day" + 0.048*"still" + 0.035*"wait" + 0.033*"account" + 0.031*"week" + 0.020*"good" + 0.019*"month" + 0.019*"uber" + 0.016*"ago" + 0.016*"background" + 0.015*"work" + 0.015*"document" + 0.014*"update" + 0.012*"last" + 0.012*"year" + 0.011*"long" + 0.011*"much" + 0.011*"get"'),
#  (9,
#   '0.038*"driver" + 0.021*"uber" + 0.021*"get" + 0.019*"make" + 0.018*"people" + 0.013*"mask" + 0.011*"give" + 0.010*"know" + 0.010*"wear" + 0.010*"work" + 0.010*"time" + 0.009*"fuck" + 0.009*"take" + 0.009*"shit" + 0.008*"right" + 0.008*"price" + 0.007*"stop" + 0.007*"rider" + 0.007*"want" + 0.007*"say"'),
#  (10,
#   '0.072*"send" + 0.051*"message" + 0.048*"reply" + 0.047*"response" + 0.028*"respond" + 0.027*"get" + 0.024*"answer" + 0.023*"support" + 0.020*"email" + 0.014*"time" + 0.013*"help" + 0.013*"ask" + 0.013*"already" + 0.012*"still" + 0.011*"receive" + 0.011*"tweet" + 0.010*"question" + 0.010*"thank" + 0.010*"ignore" + 0.009*"detail"'),
#  (11,
#   '0.077*"use" + 0.040*"uber" + 0.039*"email" + 0.039*"code" + 0.032*"try" + 0.029*"say" + 0.027*"get" + 0.026*"work" + 0.021*"promo" + 0.021*"receive" + 0.021*"eat" + 0.020*"app" + 0.019*"card" + 0.015*"send" + 0.015*"account" + 0.013*"apply" + 0.013*"never" + 0.012*"help" + 0.011*"time" + 0.011*"keep"')]

# %% [markdown]
# ### Plot coherence results

# %%
x = range(1,40)

plt.plot(x, coherence_values, 'b')
plt.xlabel("Number of Topics")
plt.ylabel("Coherence score")
plt.grid(True,color='black')
plt.show()

# %% [markdown]
# ### Save lda, coherence and perplexity results

# %%
path = './results/ldamodel'
try:
    if not os.path.isdir(path):
        os.makedirs(path)
except OSError:
    print ("Creation of the directory %s failed" % path)
else:
    print ("Successfully created the directory %s " % path)
# Out:
# Successfully created the directory ./results/ldamodel

# %%
joblib.dump(model_list, "results/ldamodel/model_list_{}.pkl".format(y))
joblib.dump(coherence_values, "results/ldamodel/coherence_values_{}.pkl".format(y))
joblib.dump(perplexity_model_lda, "results/ldamodel/perplexity_model_lda_{}.pkl".format(y))
# Out:
# ['results/ldamodel/perplexity_model_lda_1.pkl']

# %%
import joblib

texts = joblib.load("results/variables/texts.pkl")
dictionary = corpora.Dictionary.load("results/variables/dictionary.dict")
corpus = MmCorpus("results/variables/corpus.corp")
model_list = joblib.load("results/ldamodel/model_list_3.pkl")
coherence_values = joblib.load("results/ldamodel/coherence_values_3.pkl")
id = coherence_values.index(max(coherence_values))
best_model = model_list[id]

# %% [markdown]
# ### pyLDAvis

# %%
pyLDAvis.enable_notebook()

model=pyLDAvis.gensim.prepare(best_model, corpus, dictionary=dictionary)
pyLDAvis.save_html(model,'results/ldamodel/best_model.html')

#model2=pyLDAvis.gensim.prepare(model_list[2], corpus, dictionary=dictionary)
#pyLDAvis.save_html(model2,'results/ldamodel/2best_model.html')

# %% [markdown]
# ## LDA Mallet for optimizing

# %% [markdown]
# ### Load variables

# %%
texts = joblib.load("results/variables/texts.pkl")
dictionary = corpora.Dictionary.load("results/variables/dictionary.dict")
corpus = MmCorpus("results/variables/corpus.corp")

# %% [markdown]
# ### Train Model

# %%
# Download File: http://mallet.cs.umass.edu/dist/mallet-2.0.8.zip
mallet_path = 'mallet-2.0.8/bin/mallet' # update this path

# %%
def compute_coherence_values_mallet(dictionary, corpus, texts, limit, start, step):
    """
    Compute c_v coherence for various number of topics

    Parameters:
    ----------
    dictionary : Gensim dictionary
    corpus : Gensim corpus
    texts : List of input texts
    limit : Max num of topics

    Returns:
    -------
    model_list : List of LDA topic models
    coherence_values : Coherence values corresponding to the LDA model with respective number of topics
    """
    coherence_values = []
    perplexity = []
    model_list = []
    
    for num_topics in range(start, limit, step):
        
        model = gensim.models.wrappers.LdaMallet(mallet_path, corpus=corpus, num_topics=num_topics, id2word=dictionary)
        model_list.append(model)
        
        coherencemodel = CoherenceModel(model=model, texts=texts, dictionary=dictionary, coherence='c_v')
        coherence_values.append(coherencemodel.get_coherence())
        
    return model_list, coherence_values

# %%
start = time()
model_list_mallet, coherence_values_mallet = compute_coherence_values_mallet(dictionary=dictionary, corpus=corpus, texts=texts, start=1, limit=40, step=1)
print('Time used for calculating LDA_MALLET: {:.2f}s'.format(time()-start))

# %% [markdown]
# ### Plot results

# %%
x = range(1,40)

plt.plot(x, coherence_values_mallet, 'b')
plt.xlabel("Number of Topics")
plt.ylabel("Coherence score")
plt.grid(True,color='black')
plt.show()

# %% [markdown]
# ### Save lda,coherence and perplexity results

# %%
path = './results/mallet'
try:
    if not os.path.isdir(path):
        os.makedirs(path)
except OSError:
    print ("Creation of the directory %s failed" % path)
else:
    print ("Successfully created the directory %s " % path)

# %%
joblib.dump(model_list_mallet, "results/mallet/model_list_{}.pkl".format(y))
joblib.dump(coherence_values_mallet, "results/mallet/coherence_values_{}.pkl".format(y))

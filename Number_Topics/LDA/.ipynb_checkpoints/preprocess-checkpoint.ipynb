# %% [markdown]
# # Dataframe

# %%
import numpy as np
import pandas as pd
import nltk
import re
import joblib
import gensim.corpora as corpora
from gensim.corpora import MmCorpus

import re
from nltk.tokenize import TweetTokenizer
from wordfreq import top_n_list
from collections import Counter

import gensim

import os

from time import time

from numpy import *
import math
import matplotlib.pyplot as plt


from gensim.models.coherencemodel import CoherenceModel

from nltk import FreqDist
from nltk.stem.snowball import SnowballStemmer
# Out:
# Downloading https://raw.githubusercontent.com/stanfordnlp/stanza-resources/master/resources_1.2.0.json: 128kB [00:00, 29.6MB/s]
# 2021-02-12 02:20:11 INFO: Downloading default packages for language: es (Spanish)...
# 2021-02-12 02:20:12 INFO: File exists: /home/alejandro/stanza_resources/es/default.zip.
# 2021-02-12 02:20:17 INFO: Finished downloading models and saved to /home/alejandro/stanza_resources.

# %% [markdown]
# # Number of Model

# %%
y = 1

# %% [markdown]
# # Dataset

# %%
df = pd.read_csv('../../ExtraccionDatos/cabify.csv')
df.shape
# Out:
# (80447, 17)

# %% [markdown]
# ## Drop duplicates

# %%
df.drop_duplicates(inplace=True, subset="tweet")

# %%
# No tweets from Cabify Support
df
# Out:
#        Unnamed: 0  Unnamed: 0.1               created_at        date  \
# 0               0             1  2020-12-29 09:13:17 UTC  2020-12-29
# 1               1             3  2020-12-29 09:08:04 UTC  2020-12-29
# 2               2             4  2020-12-29 09:00:01 UTC  2020-12-29
# 3               3             5  2020-12-29 08:59:56 UTC  2020-12-29
# 4               4             8  2020-12-29 08:38:00 UTC  2020-12-29
# ...           ...           ...                      ...         ...
# 80442       80442         94680  2019-12-29 00:18:57 UTC  2019-12-29
# 80443       80443         94681  2019-12-29 00:17:46 UTC  2019-12-29
# 80444       80444         94682  2019-12-29 00:14:59 UTC  2019-12-29
# 80445       80445         94683  2019-12-29 00:09:54 UTC  2019-12-29
# 80446       80446         94684  2019-12-29 00:04:41 UTC  2019-12-29
#
#            time         username               name  \
# 0      09:13:17  manuela36194504        ManuelAnton
# 1      09:08:04       jesuisvlca          Terrícola
# 2      09:00:01           tvn_es  The Video Network
# 3      08:59:56    manuel_parejo      Manuel Parejo
# 4      08:38:00        jose04488               Jose
# ...         ...              ...                ...
# 80442  00:18:57          yotrino            Yotrino
# 80443  00:17:46      vikysiempre               Viky
# 80444  00:14:59      vikysiempre               Viky
# 80445  00:09:54       mariluzfri            Mariluz
# 80446  00:04:41     elmioconagua            uceillo
#
#                                                    tweet language  \
# 0      Estimados usuarios de @Uber_ES y @cabify_espan...       es
# 1      @Pabloski_parra @JuanmaTxMad @cabify_espana Es...       es
# 2      #Blog ¿Quieres saber cuáles han sido las mejor...       es
# 3      @lliemsi @cabify_espana Desde luego que así no...       es
# 4      @Pabloski_parra @LeaksUberCabify @cabify_espan...       es
# ...                                                  ...      ...
# 80442  Cual es la diferencia entre taxi y taxi tip en...       es
# 80443  @pablo_otero @boss1house @cabify_espana @Uber_...       es
# 80444  @jmtrani @Solgamar2 @cabify_espana Nada no pas...       es
# 80445  @pablo_otero @cabify_espana @Uber_ES Siempre #...       es
# 80446  @jmtrani @LeaksUberCabify @cabify_espana Pues ...       es
#
#                                                 mentions  replies_count  \
# 0      [{'screen_name': 'uber_es', 'name': 'uber espa...              0
# 1                                                     []              0
# 2      [{'screen_name': 'amena', 'name': 'amena', 'id...              0
# 3                                                     []              0
# 4                                                     []              0
# ...                                                  ...            ...
# 80442                                                 []              0
# 80443                                                 []              0
# 80444                                                 []              0
# 80445                                                 []              0
# 80446                                                 []              0
#
#        retweets_count  likes_count                        hashtags  \
# 0                   0            0                              []
# 1                   0            0                              []
# 2                   0            0                        ['blog']
# 3                   0            0                              []
# 4                   0            1                              []
# ...               ...          ...                             ...
# 80442               0            0                  ['noentender']
# 80443               0            5                              []
# 80444               1           12                              []
# 80445               0            4  ['mejorentaxi', 'vtcnoestaxi']
# 80446               0            7                              []
#
#                                                     link  \
# 0      https://twitter.com/ManuelA36194504/status/134...
# 1      https://twitter.com/jesuisvlca/status/13438462...
# 2      https://twitter.com/TVN_Es/status/134384420820...
# 3      https://twitter.com/Manuel_Parejo/status/13438...
# 4      https://twitter.com/Jose04488/status/134383866...
# ...                                                  ...
# 80442  https://twitter.com/yotrino/status/12110791197...
# 80443  https://twitter.com/Vikysiempre/status/1211078...
# 80444  https://twitter.com/Vikysiempre/status/1211078...
# 80445  https://twitter.com/Mariluzfri/status/12110768...
# 80446  https://twitter.com/elmioconagua/status/121107...
#
#                                                 reply_to Polarity
# 0                                                     []        N
# 1      [{'screen_name': 'Pabloski_parra', 'name': 'An...       N+
# 2                                                     []        P
# 3      [{'screen_name': 'lliemsi', 'name': 'Gerardo M...     NONE
# 4      [{'screen_name': 'Pabloski_parra', 'name': 'An...     NONE
# ...                                                  ...      ...
# 80442                                                 []     NONE
# 80443  [{'screen_name': 'pablo_otero', 'name': 'Pablo...        P
# 80444  [{'screen_name': 'jmtrani', 'name': 'JMT', 'id...     NONE
# 80445  [{'screen_name': 'pablo_otero', 'name': 'Pablo...     NONE
# 80446  [{'screen_name': 'jmtrani', 'name': 'JMT', 'id...       P+
#
# [74981 rows x 17 columns]

# %% [markdown]
# ## Functions

# %%
# EMOTICONS OBTAINED FROM : https://github.com/NeelShah18/emot/blob/master/emot/emo_unicode.py

EMOTICONS = {
    u":‑\)":"Happy face or smiley",
    u":\)":"Happy face or smiley",
    u":-\]":"Happy face or smiley",
    u":\]":"Happy face or smiley",
    u":-3":"Happy face smiley",
    u":3":"Happy face smiley",
    u":->":"Happy face smiley",
    u":>":"Happy face smiley",
    u"8-\)":"Happy face smiley",
    u":o\)":"Happy face smiley",
    u":-\}":"Happy face smiley",
    u":\}":"Happy face smiley",
    u":-\)":"Happy face smiley",
    u":c\)":"Happy face smiley",
    u":\^\)":"Happy face smiley",
    u"=\]":"Happy face smiley",
    u"=\)":"Happy face smiley",
    u":‑D":"Laughing, big grin or laugh with glasses",
    u":D":"Laughing, big grin or laugh with glasses",
    u"8‑D":"Laughing, big grin or laugh with glasses",
    u"8D":"Laughing, big grin or laugh with glasses",
    u"X‑D":"Laughing, big grin or laugh with glasses",
    u"XD":"Laughing, big grin or laugh with glasses",
    u"=D":"Laughing, big grin or laugh with glasses",
    u"=3":"Laughing, big grin or laugh with glasses",
    u"B\^D":"Laughing, big grin or laugh with glasses",
    u":-\)\)":"Very happy",
    u":‑\(":"Frown, sad, andry or pouting",
    u":-\(":"Frown, sad, andry or pouting",
    u":\(":"Frown, sad, andry or pouting",
    u":‑c":"Frown, sad, andry or pouting",
    u":c":"Frown, sad, andry or pouting",
    u":‑<":"Frown, sad, andry or pouting",
    u":<":"Frown, sad, andry or pouting",
    u":‑\[":"Frown, sad, andry or pouting",
    u":\[":"Frown, sad, andry or pouting",
    u":-\|\|":"Frown, sad, andry or pouting",
    u">:\[":"Frown, sad, andry or pouting",
    u":\{":"Frown, sad, andry or pouting",
    u":@":"Frown, sad, andry or pouting",
    u">:\(":"Frown, sad, andry or pouting",
    u":'‑\(":"Crying",
    u":'\(":"Crying",
    u":'‑\)":"Tears of happiness",
    u":'\)":"Tears of happiness",
    u"D‑':":"Horror",
    u"D:<":"Disgust",
    u"D:":"Sadness",
    u"D8":"Great dismay",
    u"D;":"Great dismay",
    u"D=":"Great dismay",
    u"DX":"Great dismay",
    u":‑O":"Surprise",
    u":O":"Surprise",
    u":‑o":"Surprise",
    u":o":"Surprise",
    u":-0":"Shock",
    u"8‑0":"Yawn",
    u">:O":"Yawn",
    u":-\*":"Kiss",
    u":\*":"Kiss",
    u":X":"Kiss",
    u";‑\)":"Wink or smirk",
    u";\)":"Wink or smirk",
    u"\*-\)":"Wink or smirk",
    u"\*\)":"Wink or smirk",
    u";‑\]":"Wink or smirk",
    u";\]":"Wink or smirk",
    u";\^\)":"Wink or smirk",
    u":‑,":"Wink or smirk",
    u";D":"Wink or smirk",
    u":‑P":"Tongue sticking out, cheeky, playful or blowing a raspberry",
    u":P":"Tongue sticking out, cheeky, playful or blowing a raspberry",
    u"X‑P":"Tongue sticking out, cheeky, playful or blowing a raspberry",
    u"XP":"Tongue sticking out, cheeky, playful or blowing a raspberry",
    u":‑Þ":"Tongue sticking out, cheeky, playful or blowing a raspberry",
    u":Þ":"Tongue sticking out, cheeky, playful or blowing a raspberry",
    u":b":"Tongue sticking out, cheeky, playful or blowing a raspberry",
    u"d:":"Tongue sticking out, cheeky, playful or blowing a raspberry",
    u"=p":"Tongue sticking out, cheeky, playful or blowing a raspberry",
    u">:P":"Tongue sticking out, cheeky, playful or blowing a raspberry",
    u":‑/":"Skeptical, annoyed, undecided, uneasy or hesitant",
    u":/":"Skeptical, annoyed, undecided, uneasy or hesitant",
    u":-[.]":"Skeptical, annoyed, undecided, uneasy or hesitant",
    u">:[(\\\)]":"Skeptical, annoyed, undecided, uneasy or hesitant",
    u">:/":"Skeptical, annoyed, undecided, uneasy or hesitant",
    u":[(\\\)]":"Skeptical, annoyed, undecided, uneasy or hesitant",
    u"=/":"Skeptical, annoyed, undecided, uneasy or hesitant",
    u"=[(\\\)]":"Skeptical, annoyed, undecided, uneasy or hesitant",
    u":L":"Skeptical, annoyed, undecided, uneasy or hesitant",
    u"=L":"Skeptical, annoyed, undecided, uneasy or hesitant",
    u":S":"Skeptical, annoyed, undecided, uneasy or hesitant",
    u":‑\|":"Straight face",
    u":\|":"Straight face",
    u":$":"Embarrassed or blushing",
    u":‑x":"Sealed lips or wearing braces or tongue-tied",
    u":x":"Sealed lips or wearing braces or tongue-tied",
    u":‑#":"Sealed lips or wearing braces or tongue-tied",
    u":#":"Sealed lips or wearing braces or tongue-tied",
    u":‑&":"Sealed lips or wearing braces or tongue-tied",
    u":&":"Sealed lips or wearing braces or tongue-tied",
    u"O:‑\)":"Angel, saint or innocent",
    u"O:\)":"Angel, saint or innocent",
    u"0:‑3":"Angel, saint or innocent",
    u"0:3":"Angel, saint or innocent",
    u"0:‑\)":"Angel, saint or innocent",
    u"0:\)":"Angel, saint or innocent",
    u":‑b":"Tongue sticking out, cheeky, playful or blowing a raspberry",
    u"0;\^\)":"Angel, saint or innocent",
    u">:‑\)":"Evil or devilish",
    u">:\)":"Evil or devilish",
    u"\}:‑\)":"Evil or devilish",
    u"\}:\)":"Evil or devilish",
    u"3:‑\)":"Evil or devilish",
    u"3:\)":"Evil or devilish",
    u">;\)":"Evil or devilish",
    u"\|;‑\)":"Cool",
    u"\|‑O":"Bored",
    u":‑J":"Tongue-in-cheek",
    u"#‑\)":"Party all night",
    u"%‑\)":"Drunk or confused",
    u"%\)":"Drunk or confused",
    u":-###..":"Being sick",
    u":###..":"Being sick",
    u"<:‑\|":"Dump",
    u"\(>_<\)":"Troubled",
    u"\(>_<\)>":"Troubled",
    u"\(';'\)":"Baby",
    u"\(\^\^>``":"Nervous or Embarrassed or Troubled or Shy or Sweat drop",
    u"\(\^_\^;\)":"Nervous or Embarrassed or Troubled or Shy or Sweat drop",
    u"\(-_-;\)":"Nervous or Embarrassed or Troubled or Shy or Sweat drop",
    u"\(~_~;\) \(・\.・;\)":"Nervous or Embarrassed or Troubled or Shy or Sweat drop",
    u"\(-_-\)zzz":"Sleeping",
    u"\(\^_-\)":"Wink",
    u"\(\(\+_\+\)\)":"Confused",
    u"\(\+o\+\)":"Confused",
    u"\(o\|o\)":"Ultraman",
    u"\^_\^":"Joyful",
    u"\(\^_\^\)/":"Joyful",
    u"\(\^O\^\)／":"Joyful",
    u"\(\^o\^\)／":"Joyful",
    u"\(__\)":"Kowtow as a sign of respect, or dogeza for apology",
    u"_\(\._\.\)_":"Kowtow as a sign of respect, or dogeza for apology",
    u"<\(_ _\)>":"Kowtow as a sign of respect, or dogeza for apology",
    u"<m\(__\)m>":"Kowtow as a sign of respect, or dogeza for apology",
    u"m\(__\)m":"Kowtow as a sign of respect, or dogeza for apology",
    u"m\(_ _\)m":"Kowtow as a sign of respect, or dogeza for apology",
    u"\('_'\)":"Sad or Crying",
    u"\(/_;\)":"Sad or Crying",
    u"\(T_T\) \(;_;\)":"Sad or Crying",
    u"\(;_;":"Sad of Crying",
    u"\(;_:\)":"Sad or Crying",
    u"\(;O;\)":"Sad or Crying",
    u"\(:_;\)":"Sad or Crying",
    u"\(ToT\)":"Sad or Crying",
    u";_;":"Sad or Crying",
    u";-;":"Sad or Crying",
    u";n;":"Sad or Crying",
    u";;":"Sad or Crying",
    u"Q\.Q":"Sad or Crying",
    u"T\.T":"Sad or Crying",
    u"QQ":"Sad or Crying",
    u"Q_Q":"Sad or Crying",
    u"\(-\.-\)":"Shame",
    u"\(-_-\)":"Shame",
    u"\(一一\)":"Shame",
    u"\(；一_一\)":"Shame",
    u"\(=_=\)":"Tired",
    u"\(=\^\·\^=\)":"cat",
    u"\(=\^\·\·\^=\)":"cat",
    u"=_\^=	":"cat",
    u"\(\.\.\)":"Looking down",
    u"\(\._\.\)":"Looking down",
    u"\^m\^":"Giggling with hand covering mouth",
    u"\(\・\・?":"Confusion",
    u"\(?_?\)":"Confusion",
    u">\^_\^<":"Normal Laugh",
    u"<\^!\^>":"Normal Laugh",
    u"\^/\^":"Normal Laugh",
    u"\（\*\^_\^\*）" :"Normal Laugh",
    u"\(\^<\^\) \(\^\.\^\)":"Normal Laugh",
    u"\(^\^\)":"Normal Laugh",
    u"\(\^\.\^\)":"Normal Laugh",
    u"\(\^_\^\.\)":"Normal Laugh",
    u"\(\^_\^\)":"Normal Laugh",
    u"\(\^\^\)":"Normal Laugh",
    u"\(\^J\^\)":"Normal Laugh",
    u"\(\*\^\.\^\*\)":"Normal Laugh",
    u"\(\^—\^\）":"Normal Laugh",
    u"\(#\^\.\^#\)":"Normal Laugh",
    u"\（\^—\^\）":"Waving",
    u"\(;_;\)/~~~":"Waving",
    u"\(\^\.\^\)/~~~":"Waving",
    u"\(-_-\)/~~~ \($\·\·\)/~~~":"Waving",
    u"\(T_T\)/~~~":"Waving",
    u"\(ToT\)/~~~":"Waving",
    u"\(\*\^0\^\*\)":"Excited",
    u"\(\*_\*\)":"Amazed",
    u"\(\*_\*;":"Amazed",
    u"\(\+_\+\) \(@_@\)":"Amazed",
    u"\(\*\^\^\)v":"Laughing,Cheerful",
    u"\(\^_\^\)v":"Laughing,Cheerful",
    u"\(\(d[-_-]b\)\)":"Headphones,Listening to music",
    u'\(-"-\)':"Worried",
    u"\(ーー;\)":"Worried",
    u"\(\^0_0\^\)":"Eyeglasses",
    u"\(\＾ｖ\＾\)":"Happy",
    u"\(\＾ｕ\＾\)":"Happy",
    u"\(\^\)o\(\^\)":"Happy",
    u"\(\^O\^\)":"Happy",
    u"\(\^o\^\)":"Happy",
    u"\)\^o\^\(":"Happy",
    u":O o_O":"Surprised",
    u"o_0":"Surprised",
    u"o\.O":"Surpised",
    u"\(o\.o\)":"Surprised",
    u"oO":"Surprised",
    u"\(\*￣m￣\)":"Dissatisfied",
    u"\(‘A`\)":"Snubbed or Deflated"
}

# %%
import nltk
from nltk.tokenize import TweetTokenizer
from nltk.corpus import stopwords
import string
import re
from collections import Counter

def preprocess(words):
    
    tokens = []
   
    # Clean urls, punct, strange characters, emojis, emoticons
    char= re.compile(r'^[a-zA-Z]$')
    punct=re.compile(r'[.,-,:,<,;,(,=]')
    ht = re.compile(r'http.')
    bar = re.compile(r'//*')
    pr = ["rt","@","http","https","'s",'...', 'english', 'translation','):',
          '. .', '..','2-5','<3',']:','“','”','’','. ...','___','__','=(','‘','—','°','¢','•','®','—','…',
          '... .','--->','–','»','«','£','-->','×','->','©','\n','™','¤']
    no_emoji = re.compile("["
                           u"\U0001F600-\U0001F64F"  # emoticons
                           u"\U0001F300-\U0001F5FF"  # symbols & pictographs
                           u"\U0001F680-\U0001F6FF"  # transport & map symbols
                           u"\U0001F1E0-\U0001F1FF"  # flags (iOS)
                           u"\U00002702-\U000027B0"
                           u"\U000024C2-\U0001F251"
                           "]+", flags=re.UNICODE) 
    
    no_emoticon = re.compile(u'(' + u'|'.join(k for k in EMOTICONS) + u')')
    no_html_pattern = re.compile('<.*?>')
    
    stoplist = stopwords.words('spanish')
    punctuation = set(string.punctuation)
    
   
    # TOKENIZER
    tknzr = TweetTokenizer()
    tokens = tknzr.tokenize(words)
    tokens = [w.lower() for w in tokens] 
    
    #Remove numbers
    pattern = '[0-9]'
    tokens = [re.sub(pattern, '', i) for i in tokens] 
    
    # Punctuation
    tokens = [w for w in tokens if  w not in punctuation]
    
    #Hacer algo con los hastags
    
    # Clean emojis,urls,bars
    tokens = [w.replace('#', '') for w in tokens if not w.startswith('@') if w not in pr 
            if not bar.search(w) if not ht.search(w) if not char.search(w) if not punct.search(w)
            if not w.isdigit() if not no_emoji.search(w) if not no_emoticon.search(w) if not no_html_pattern.search(w)]
    
    # Remove non alphanumeric
    tokens = [w for w in tokens if w.isalpha()]

    
    # Remove spanish stopwords
    tokens = [w for w in tokens if w not in stoplist]
    
    #Remove tokens with length < 1
    tokens = [word for word in tokens if len(word)>1]  ##Posiblemente sean 2
    
    return tokens

# %%
def stanzaLemma(texts):
    stanza.download('es')
    nlp = stanza.Pipeline('es')  
    texts_out = []
    for tweet in texts:
        tweet_out = []
        doc = nlp(" ".join(tweet)) 
        for sent in doc.sentences:
            for word in sent.words:
                tweet_out.append(word.lemma)
                
        texts_out.append(tweet_out)
    return texts_out

# %%
def normalize(word):
    replacements = (
        ("á", "a"),
        ("é", "e"),
        ("í", "i"),
        ("ó", "o"),
        ("ú", "u"),
    )
    for a, b in replacements:
        word = word.replace(a, b).replace(a.upper(), b.upper())
    return word

# %%
def accentWords(texts):
    word_accent = []
    for tweet in texts:
        for word in tweet:
            if re.search(r'[ÁÉÍÓÚáéíóú]', word):
                word_accent.append(word)

    # Tengo el diccionario con las palabras con tilde
    dic_accent = list(set(word_accent)) #keys
    dic_no_accent = [normalize(word) for word in dic_accent] #values

    dic_accent_no_accent= {}

    # Creamos el diccionario
    for index, k in enumerate(dic_no_accent):
        dic_accent_no_accent[k] = dic_accent[index]

    for i, tweet in enumerate(texts):
        for j, word in enumerate(tweet):
            if word in list(dic_accent_no_accent.keys()):
                texts[i][j] = word.replace(word, dic_accent_no_accent.get(word))
    return texts

# %% [markdown]
# ## Preprocess

# %% [markdown]
# ### Simple preprocess

# %%
texts = [preprocess(document) for document in df['tweet']]

# %%
texts
# Out:
# [['estimados',
#   'usuarios',
#   'según',
#   'datos',
#   'cada',
#   'vtc',
#   'sido',
#   'sancionados',
#   'inspección',
#   'transportes',
#   'sancion',
#   'frecuente',
#   'llevar',
#   'debidamente',
#   'cumplimentada',
#   'hoja',
#   'ruta'],
#  ['putada', 'espero', 'daños', 'físicos', 'ver', 'si', 'suerte'],
#  ['blog',
#   'quieres',
#   'saber',
#   'cuáles',
#   'sido',
#   'mejores',
#   'campañas',
#   'sido',
#   'marcas',
#   'elegidas',
#   'ver',
#   'post'],
#  ['luego', 'así', 'hacen', 'cosas'],
#  ['cabify',
#   'ningún',
#   'coche',
#   'subcontratas',
#   'deseo',
#   'suerte',
#   'seguros',
#   'flota',
#   'ley',
#   'suerte'],
#  ['deja',
#   'tirado',
#   'último',
#   'minuto',
#   'reserva',
#   'hecha',
#   'ayer',
#   'tarde',
#   'tan',
#   'difícil',
#   'avisar',
#   'cita',
#   'médico',
#   'cancelada',
#   'así'],
#  ['seguro', 'culpable', 'contratados', 'mas', 'profesionales', 'planeta'],
#  ['mira',
#   'condiciones',
#   'uso',
#   'aceptas',
#   'instalar',
#   'app',
#   'luego',
#   've',
#   'abogado',
#   'pregunta',
#   'algún',
#   'amigo',
#   'expliquen',
#   'huevos',
#   'pillado',
#   'último',
#   'piensa',
#   'taxistas',
#   'ciudad',
#   'seguro',
#   'muchísimos',
#   'encantará',
#   'servicio'],
#  ['vale', 'grabado', 'si', 'espero', 'estes', 'bien'],
#  ['seguro'],
#  ['espero',
#   'suerte',
#   'cada',
#   'elemento',
#   'volante',
#   'además',
#   'lava',
#   'manos',
#   'mero',
#   'intermediario',
#   'responsabilidades',
#   'recaen',
#   'empresa',
#   'vtc',
#   'suerte'],
#  ['menos', 'humos', 'bloquean'],
#  ['nunca',
#   'entenderé',
#   'rechazan',
#   'derechos',
#   'cambio',
#   'coche',
#   'funebre',
#   'botellita',
#   'agua',
#   'cosas',
#   'ser',
#   'moderno',
#   'supongo'],
#  ['aceptar',
#   'terminos',
#   'contrato',
#   'descargaste',
#   'app',
#   'exoneraste',
#   'toda',
#   'responsabilidad',
#   'leerse',
#   'letra',
#   'pequeña',
#   'proxima',
#   'vez',
#   'utiliza',
#   'transporte',
#   'publico',
#   'garantizan',
#   'derechos',
#   'consumidor'],
#  ['namjoon',
#   'espera',
#   'bondi',
#   'puede',
#   'ser',
#   'sos',
#   'millonario',
#   'hermano',
#   'minimo',
#   'cabify'],
#  ['testigos', 'mucha', 'suerte'],
#  ['vaya', 'putada', 'espero', 'llamado', 'policía', 'testigos'],
#  ['pásate', 'sede', 'cabify', 'pardillo', 'antigua', 'sede', 'mundo'],
#  ['ver', 'cabify', 'accidente', 'si', 'cosa', 'terceros'],
#  ['acabo',
#   'tener',
#   'peor',
#   'mal',
#   'viaje',
#   'vida',
#   'todavia',
#   'sigo',
#   'temblando',
#   'pense',
#   'secuestraba',
#   'cabify'],
#  ['surge',
#   'duda',
#   'podran',
#   'detener',
#   'tambien',
#   'plataformas',
#   'uber',
#   'didi',
#   'cabify',
#   'mañana',
#   'vera',
#   'si',
#   'vamos',
#   'encerio',
#   'simulacion',
#   'mas'],
#  ['date', 'jodido', 'seguro', 'ver', 'si', 'suerte'],
#  ['si',
#   'necesitas',
#   'salir',
#   'aprovecha',
#   'cupones',
#   'descuentos',
#   'viajes',
#   'gratis',
#   'didi',
#   'mxau',
#   'uber',
#   'mefue',
#   'beat',
#   'fkd',
#   'cabify',
#   'lorenac',
#   'bolt',
#   'taxify',
#   'pex',
#   'regalo',
#   'cdmx',
#   'adiós',
#   'felízsemana',
#   'mexico'],
#  ['recién',
#   'vengo',
#   'cubrir',
#   'ambulancia',
#   'julio',
#   'san',
#   'lorenzo',
#   'quisieron',
#   'robar',
#   'fierro',
#   'cabify',
#   'policía',
#   'delincuente',
#   'muerto',
#   'herido',
#   'gravedad',
#   'pepazos',
#   'terminó',
#   'vecinal'],
#  ['nadie',
#   'absolutamente',
#   'nadie',
#   'cabify',
#   'mañana',
#   'movemos',
#   'tmb',
#   'quietos'],
#  ['metidos', 'tener', 'intereses', 'personales'],
#  ['che', 'loco', 'funque', 'hroa', 'pilar', 'onda', 'uber', 'prove', 'cabify'],
#  ['recibido', 'gracias'],
#  ['porsinolovio',
#   'partir',
#   'diciembre',
#   'reducción',
#   'horarios',
#   'transporte',
#   'público',
#   'puebla',
#   'incluidos',
#   'taxis',
#   'uber',
#   'didi',
#   'cabify'],
#  ['momento', 'dado', 'solución', 'ahora', 'van', 'cerrar', 'conversación'],
#  ['baje', 'cabify', 'aire', 'casa', 'horno', 'ventilador'],
#  ['pelotas',
#   'importadas',
#   'pakistán',
#   'aumentos',
#   'nafta',
#   'avisar',
#   'subsidio',
#   'lleva',
#   'dólares',
#   'país',
#   'perdonar'],
#  ['mafias',
#   'taxis',
#   'amarillos',
#   'enquistados',
#   'ponen',
#   'precios',
#   'jamás',
#   'utilizan',
#   'taxímetro',
#   'ello',
#   'prefiero',
#   'uber',
#   'cabify'],
#  ['mandó', 'coso', 'cabify'],
#  ['aquí', 'información'],
#  ['momento', 'tan', 'sereno', 'pedís', 'uber', 'cabify', 'traffic', 'blanca'],
#  ['conductor',
#   'cabify',
#   'subió',
#   'volumen',
#   'radio',
#   'pusieron',
#   'shakira',
#   'usted',
#   'merece',
#   'buena',
#   'propina',
#   'señor'],
#  ['taxistas',
#   'peelamos',
#   'apps',
#   'ilegales',
#   'manejan',
#   'fondos',
#   'buitres',
#   'ypf',
#   'paga',
#   'descuento',
#   'viajar',
#   'cabify',
#   'usa',
#   'plata',
#   'cabify',
#   'lleve',
#   'salga',
#   'viaje',
#   'exterior'],
#  ['chofer',
#   'cabify',
#   'dealer',
#   'enteré',
#   'puso',
#   'contestar',
#   'whatsapp',
#   'semáforo',
#   'rojo'],
#  ['si', 'chofer', 'ustedes', 'chequenlo', 'conduce', 'mal'],
#  ['carajos', 'porteños', 'obsesión', 'uber', 'cabify'],
#  ['pagan',
#   'mierdafy',
#   'telemadrid',
#   'ahora',
#   'después',
#   'tantos',
#   'años',
#   'dan',
#   'cuenta',
#   'juntaletras',
#   'telemierda',
#   'ilegalidades',
#   'mierdafy',
#   'mugre',
#   'pena',
#   'denigran',
#   'profesión',
#   'periodismo',
#   'normal',
#   'si',
#   'rosauro',
#   'ahora',
#   'consejero',
#   'prisa'],
#  ['único', 'último'],
#  ['pensabas',
#   'microcentro',
#   'podía',
#   'haber',
#   'peor',
#   'llegan',
#   'calor',
#   'barbijo',
#   'sé',
#   'fastidioso',
#   'si',
#   'épocas',
#   'subte',
#   'cabify',
#   'poder',
#   'poner',
#   'aire'],
#  ['vais',
#   'lamentar',
#   'ahora',
#   'rakuten',
#   'mete',
#   'pasta',
#   'dedicáis',
#   'hacer',
#   'cargos',
#   'pq',
#   'datos',
#   'bancarios',
#   'incautos',
#   'dieron',
#   'viaje',
#   'gratis',
#   'mierdafy',
#   'roba',
#   'clientes',
#   'merecen'],
#  ['tardando'],
#  ['busca', 'testigos', 'pq', 'mierdafy', 'dirán', 'lugar', 'accidente'],
#  ['cabify',
#   'vino',
#   'buscar',
#   'trabajo',
#   'mismo',
#   'perfume',
#   'ex',
#   'cada',
#   'dos',
#   'minutos',
#   'malflasho',
#   'miro',
#   'chequear',
#   'boluuuuuda'],
#  ['dos',
#   'cuadras',
#   'casa',
#   'escribe',
#   'perdido',
#   'barbijo',
#   'dije',
#   'descartable',
#   'darle',
#   'adivinen',
#   'si',
#   'salía',
#   'caro',
#   'cancelarlo',
#   'viaje'],
#  ['deseo', 'tomarme', 'uber', 'cabify', 'taxi', 'remis', 'chofer', 'pajero'],
#  ['tan',
#   'vivo',
#   'conurbano',
#   'tener',
#   'esperar',
#   'dos',
#   'horas',
#   'colectivo',
#   'terminar',
#   'compartiendo',
#   'cabify',
#   'alguien'],
#  ['voy',
#   'cabify',
#   'conductor',
#   'viene',
#   'oyendo',
#   'canciones',
#   'the',
#   'cure',
#   'puedo',
#   'pedir',
#   'vida'],
#  ['pues',
#   'misma',
#   'historia',
#   'siempre',
#   'todas',
#   'ciudades',
#   'españa',
#   'operan',
#   'empresas',
#   'tributan',
#   'españa',
#   'amparo',
#   'políticos',
#   'corruptos',
#   'esperemos',
#   'algún',
#   'día',
#   'fiscalía',
#   'anticorrupción',
#   'ponga',
#   'manos',
#   'obra',
#   'caerá',
#   'careta'],
#  ['ladrones',
#   'esperando',
#   'minutos',
#   'cerca',
#   'ubicación',
#   'cada',
#   'vez',
#   'alejaba',
#   'encima',
#   'cobran',
#   'cancelar',
#   'nunca',
#   'ladrones'],
#  ['actitudes',
#   'conductores',
#   'prefieren',
#   'alejarse',
#   'punto',
#   'carrera',
#   'cancelar',
#   'pésimo',
#   'servicio',
#   'puede',
#   'esperar'],
#  ['cabify',
#   'uber',
#   'cualquier',
#   'compañía',
#   'transporte',
#   'on',
#   'demand',
#   'solo',
#   'usa',
#   'vez',
#   'mes',
#   'completo',
#   'despropósito'],
#  ['jajaja',
#   'si',
#   'llega',
#   'cabify',
#   'lurin',
#   'menos',
#   'va',
#   'llegar',
#   'domingo',
#   'punta',
#   'hermosa'],
#  ['marketing',
#   'bien',
#   'luego',
#   'cuentan',
#   'creo',
#   'así',
#   'entiende',
#   'mejor',
#   'porqué',
#   'funcionan',
#   'así'],
#  ['codigo',
#   'cupón',
#   'rappi',
#   'oxs',
#   'codigo',
#   'cupón',
#   'ubereats',
#   'ln',
#   'codigo',
#   'cupon',
#   'glovo',
#   'lnlfqjl',
#   'codigo',
#   'cupon',
#   'cabify',
#   'ivano',
#   'cupon',
#   'uber',
#   'xaln',
#   'código',
#   'cupon',
#   'rappi',
#   'oxs',
#   'cupón',
#   'didi',
#   'ivan',
#   'cupones',
#   'rappi'],
#  ['cabify', 'pasa', 'trapo'],
#  ['acabo',
#   'tener',
#   'accidente',
#   'conductor',
#   'dado',
#   'fuga',
#   'manos',
#   'policía'],
#  ['llegado'],
#  ['entérate',
#   'taxis',
#   'podrán',
#   'prestar',
#   'servicios',
#   'noche',
#   'partir',
#   'mañana'],
#  ['ejemplo',
#   'bajando',
#   'sierra',
#   'uber',
#   'cabify',
#   'solo',
#   'línea',
#   'taxi',
#   'funcionó'],
#  ['gracias', 'acabo', 'enviar', 'texto'],
#  ['consejo',
#   'reviéntales',
#   'mensajes',
#   'app',
#   'haciendo',
#   'cargado',
#   'euros',
#   'fraudulentos',
#   'voy',
#   'parar',
#   'devuelvan',
#   'desistas'],
#  ['mitad',
#   'vehículos',
#   'vtc',
#   'controlados',
#   'sido',
#   'denunciados',
#   'trabajar',
#   'incumpliendo',
#   'alguna',
#   'norma',
#   'inocentada',
#   'bases',
#   'negocio',
#   'uber',
#   'cabify',
#   'trabajar',
#   'ilegalidad',
#   'taxienlucha'],
#  ['dedicáis',
#   'estafar',
#   'pequeñas',
#   'cantidades',
#   'clientes',
#   'pensáis',
#   'fechas',
#   'van',
#   'dar',
#   'cuenta',
#   'cargo',
#   'euros',
#   'directamente',
#   'van',
#   'preocupar',
#   'denunciarlo',
#   'pues',
#   'dignidad',
#   'tiempo',
#   'libre'],
#  ['empiezo',
#   'contactar',
#   'declaran',
#   'estafado',
#   'denunciamos',
#   'conjuntamente',
#   'además',
#   'factura',
#   'taxi',
#   'llevó',
#   'noche',
#   'casa',
#   'seguro',
#   'profesional',
#   'encantado',
#   'testificar',
#   'llevó'],
#  ['factura',
#   'espv',
#   'ns',
#   'llevo',
#   'domingo',
#   'reportando',
#   'incidencia',
#   'ayuda',
#   'cliente',
#   'dedican',
#   'decirme',
#   'viaje',
#   'realizó',
#   'bien',
#   'cobrado',
#   'reembolsáis',
#   'dinero',
#   'mañana',
#   'denunció',
#   'exijo',
#   'compensaciones',
#   'daños',
#   'perjuicios'],
#  ['suceso',
#   'reembolsarme',
#   'importe',
#   'impongo',
#   'denuncia',
#   'policía',
#   'fraude',
#   'exijo',
#   'compensaciones',
#   'daños',
#   'perjuicios',
#   'piensan',
#   'nadie',
#   'va',
#   'molestar',
#   'denunciar',
#   'dignidad',
#   'voy',
#   'permitir',
#   'roben'],
#  ['imaginas',
#   'cada',
#   'dos',
#   'tiendas',
#   'vas',
#   'ilegal',
#   'si',
#   'cada',
#   'dos',
#   'bares',
#   'incumpliera',
#   'normativa',
#   'si',
#   'clinicas',
#   'ilegales',
#   'locos',
#   'entonces',
#   'normalizado',
#   'vtc'],
#  ['factura',
#   'espv',
#   'ns',
#   'realizado',
#   'cargo',
#   'viaje',
#   'realizado',
#   'solicitado',
#   'conductor',
#   'matheus',
#   'matrícula',
#   'lkj',
#   'validado',
#   'viaje',
#   'realizado',
#   'cargo',
#   'tarjeta',
#   'consentimiento',
#   'servicio',
#   'fraudulento'],
#  ['suceso',
#   'reembolsarme',
#   'importe',
#   'si',
#   'impongo',
#   'denuncia',
#   'policía',
#   'exijo',
#   'compensaciones',
#   'daños',
#   'perjuicios',
#   'denuncio',
#   'superiores',
#   'personas',
#   'at',
#   'cliente',
#   'cabify',
#   'responden',
#   'mensajes',
#   'plantillas',
#   'niegan',
#   'ayudarme'],
#  ['bueno',
#   'empezó',
#   'bardear',
#   'cartoneros',
#   'dije',
#   'ahora',
#   'odio',
#   'dios',
#   'onda',
#   'tacheros',
#   'fachos',
#   'vinieron',
#   'cabify'],
#  ['cabify', 'tocó', 'hoy', 'full', 'leo', 'mattioli', 'amo'],
#  ['entérate',
#   'servicios',
#   'transportes',
#   'taxis',
#   'ejecutivos',
#   'darán',
#   'servicio',
#   'am',
#   'pm',
#   'así',
#   'anuncia',
#   'subsecretario',
#   'movilidad',
#   'transporte',
#   'yahir',
#   'vázquez'],
#  ['nacionales',
#   'obreros',
#   'uber',
#   'didi',
#   'cabify',
#   'economía',
#   'general',
#   'pandemia',
#   'creció',
#   'salud',
#   'muertos',
#   'aceptados',
#   'aceptados',
#   'médicos',
#   'niños',
#   'cancer',
#   'fallecidos'],
#  ['odio',
#   'tomarme',
#   'cabify',
#   'siento',
#   'voy',
#   'terminar',
#   'cualquier',
#   'lado',
#   'menos',
#   'casa'],
#  ['visto', 'taxi', 'lleva', 'momento', 'bien', 'ahí', 'mensajes', 'positivos'],
#  ['cabify',
#   'caro',
#   'uber',
#   'ahora',
#   'uber',
#   'caro',
#   'cabify',
#   'incluso',
#   'cabify',
#   'veces',
#   'resulta',
#   'económico',
#   'didi',
#   'beat',
#   'cojan',
#   'dato',
#   'chiques'],
#  ['pido', 'cabify', 'manda'],
#  ['suspendieron', 'cuenta', 'marido', 'veces', 'aclaran'],
#  ['nadie', 'va', 'devolver', 'libremente', 'pagado'],
#  ['baterías', 'cambian'],
#  ['pobre',
#   'autobusero',
#   'si',
#   'ponen',
#   'conducir',
#   'cualquiera',
#   'vtc',
#   'claro',
#   'pasa',
#   'pasa'],
#  ['si', 'sirve', 'data', 'conductor'],
#  ['mano',
#   'presentan',
#   'campaña',
#   'fin',
#   'año',
#   'hoyenlatinspots',
#   'flasheá',
#   'tranquilo',
#   'compuesta',
#   'spots',
#   'animados',
#   'podrán',
#   'ver',
#   'redes',
#   'marca',
#   'humorista',
#   'moveteseguro',
#   'movetemejor'],
#  ['hija',
#   'menor',
#   'empresa',
#   'unicenter',
#   'sigue',
#   'hmof',
#   'mayor',
#   'empresa',
#   'frente',
#   'colon',
#   'semana',
#   'medio',
#   'trabaja',
#   'in',
#   'situ',
#   'traslada',
#   'cabify',
#   'pago',
#   'empresa'],
#  ['demuestras',
#   'nivel',
#   'nivel',
#   'cucaracho',
#   'si',
#   'encima',
#   'compraste',
#   'estafado',
#   'sabes',
#   'pídele',
#   'explicaciones',
#   'rosauro'],
#  ['aún',
#   'tardarán',
#   'sabes',
#   'quién',
#   'vendido',
#   'división',
#   'investigación',
#   'coche',
#   'autónomo',
#   'seguro',
#   'caso',
#   'accidente',
#   'quién',
#   'culpable',
#   'pastar',
#   'neng'],
#  ['uber', 'cabify', 'obligó', 'bajar', 'precios', 'buena', 'competencia'],
#  ['perfecto',
#   'pues',
#   'vete',
#   'hospitales',
#   'delawer',
#   'holanda',
#   'paro',
#   'erte',
#   'ere',
#   'paguen',
#   'allí',
#   'jubilación',
#   'tb'],
#  ['pues',
#   'devolverlas',
#   'administración',
#   'si',
#   'sobran',
#   'coste',
#   'alguno',
#   'administración',
#   'ciudadano',
#   'pagar',
#   'negocios'],
#  ['trabajadores',
#   'tampoco',
#   'búscate',
#   'cuentas',
#   'presentan',
#   'registro',
#   'mercantil',
#   'tooooodos',
#   'impuestos',
#   'dicen',
#   'pagar',
#   'cerrar',
#   'ejercicio',
#   'sl',
#   'compensan',
#   'pérdidas',
#   'pq',
#   'pueden',
#   'desgravar',
#   'papel',
#   'higiénico',
#   'pagan'],
#  ['menos',
#   'queda',
#   'cucas',
#   'pregunta',
#   'conductores',
#   'cuanto',
#   'tiempo',
#   'llevan',
#   'cobrar',
#   'mierdafy',
#   'tb',
#   'pq',
#   'rakuten',
#   'mete',
#   'pasta',
#   'verás',
#   'clavadas',
#   'van',
#   'hacer',
#   'ahora',
#   'años',
#   'engañaron',
#   'vendiendo',
#   'autorización',
#   'dijeron',
#   'licencia'],
#  ['tranqui',
#   'sentimiento',
#   'mutuo',
#   'gente',
#   'cuánto',
#   'lejos',
#   'mejor',
#   'gana',
#   'tx',
#   'salud',
#   'vete',
#   'cucas',
#   'seguro',
#   'si',
#   'comprensible',
#   'defiendas',
#   'empresa',
#   'mierdafy'],
#  ['noticia',
#   'vieja',
#   'comentamos',
#   'aflelolu',
#   'taxistas',
#   'familias',
#   'comunicaríamos',
#   'allegados',
#   'osea',
#   'miembros',
#   'cada',
#   'familia',
#   'mala',
#   'publicidad'],
#  ['pues',
#   'hablemos',
#   'accidentes',
#   'cucas',
#   'twitter',
#   'varias',
#   'páginas',
#   'muestran',
#   'montón',
#   'pq',
#   'cucas',
#   'saben',
#   'conducir',
#   'van',
#   'mirando',
#   'rato',
#   'gps'],
#  ['poca',
#   'vergüenza',
#   'mierdafy',
#   'pagáis',
#   'impuestos',
#   'españa',
#   'seguro',
#   'hospitales',
#   'delawer',
#   'agradecen',
#   'mejor',
#   'experiencia',
#   'podría',
#   'tener',
#   'sanidad',
#   'pública',
#   'gratuita',
#   'españa'],
#  ['dar',
#   'vueltas',
#   'cucas',
#   'hacen',
#   'siempre',
#   'pq',
#   'guían',
#   'gps',
#   'vamos',
#   'saben',
#   'ir',
#   'ningún',
#   'sitio',
#   'sabes',
#   'gps',
#   'casi',
#   'nunca',
#   'va',
#   'camino',
#   'corto'],
#  ['volvemos',
#   'mismo',
#   'cobrando',
#   'multas',
#   'cancelación',
#   'viaje',
#   'conductores',
#   'llegando',
#   'da',
#   'gana'],
#  ['mierdafy',
#   'siempre',
#   'dado',
#   'buen',
#   'servicio',
#   'dices',
#   'crees',
#   'cuanto',
#   'robar',
#   'saben',
#   'mierdafy',
#   'mira',
#   'twitter',
#   'cantidad',
#   'gente',
#   'hacen',
#   'cargos',
#   'tarjeta',
#   'tx',
#   'piden',
#   'datos',
#   'bancarios',
#   'clientes'],
#  ['jajajajaja',
#   'mira',
#   'foros',
#   'cuánta',
#   'gente',
#   'estafado',
#   'dejado',
#   'si',
#   'contestado',
#   'conductor'],
#  ['vamos',
#   'sabes',
#   'monopolio',
#   'tx',
#   'autónomos',
#   'solo',
#   'licencia',
#   'precio',
#   'fijado',
#   'hacienda'],
#  ['esclavifly',
#   'mierdafy',
#   'mira',
#   'foros',
#   'confiables',
#   'cómo',
#   'hacen',
#   'cargos',
#   'tarjetas',
#   'servicios',
#   'prestados',
#   'manía',
#   'defender',
#   'empresa',
#   'mierdafy'],
#  ['mami', 'juqueao'],
#  ['supuesto', 'ver', 'si', 'crees', 'cucarachos', 'dóciles', 'menos'],
#  ['cabify',
#   'viajaba',
#   'barbijo',
#   'aire',
#   'tope',
#   'enfermero',
#   'adivinen',
#   'si',
#   'ofendió',
#   'bajé',
#   'ventana',
#   'negué',
#   'sacarme',
#   'barbijo'],
#  ['revisa', 'veras', 'único', 'pasado', 'cosa', 'peores'],
#  ['llevo', 'cabify', 'valdemingomez', 'micunda'],
#  ['primera',
#   'vez',
#   'lima',
#   'familia',
#   'instaló',
#   'celular',
#   'cabify',
#   'ver',
#   'iba',
#   'contaron',
#   'puesto',
#   'pago',
#   'tc',
#   'pues',
#   'viajes',
#   'pagaba',
#   'efectivo',
#   'vez',
#   'descontaban',
#   'tarjeta',
#   'xd',
#   'quitaron',
#   'soles',
#   'semana'],
#  ['hola',
#   'acaban',
#   'cobrar',
#   'hice',
#   'esperar',
#   'chofer',
#   'minutos',
#   'estacionado',
#   'lado',
#   'mandé',
#   'mensajes',
#   'llamé',
#   'varias',
#   'veces',
#   'gustaría',
#   'devolución',
#   'plata',
#   'gracias'],
#  ['pagar',
#   'impuestos',
#   'aqui',
#   'encargará',
#   'administraciones',
#   'financiar',
#   'sanidad',
#   'caer',
#   'cara',
#   'vergüenza'],
#  ['nono',
#   'epic',
#   'bien',
#   'compra',
#   'pavos',
#   'aparecio',
#   'cabify',
#   'compras',
#   'automaticas'],
#  ['abajo',
#   'cabify',
#   'dice',
#   'pago',
#   'automatico',
#   'tendria',
#   'ser',
#   'si',
#   'si'],
#  ['apreta',
#   'tuerca',
#   'anda',
#   'pagos',
#   'aparecer',
#   'cosa',
#   'cabify',
#   'desactivas'],
#  ['raro',
#   'igual',
#   'solo',
#   'retuvieron',
#   'pasado',
#   'encima',
#   'pagar',
#   'servicio',
#   'prestado'],
#  ['surrealista',
#   'pueda',
#   'haber',
#   'cabify',
#   'viendo',
#   'figura',
#   'aviso',
#   'retención',
#   'llegó',
#   'veo',
#   'descontado',
#   'así',
#   'supongo',
#   'debitó',
#   'final',
#   'sé',
#   'avisos',
#   'débito',
#   'llegaron',
#   'raro'],
#  ['totalmente',
#   'seguro',
#   'hecho',
#   'verdadero',
#   'esfuerzo',
#   'empatizar',
#   'debería',
#   'haber',
#   'sido',
#   'revés',
#   'alucinante',
#   'cuentes',
#   'cosas',
#   'allá',
#   'lea',
#   'ello',
#   'sigue',
#   'pareciendo',
#   'surrealista',
#   'espero',
#   'solucionen'],
#  ['gracias', 'referencia'],
#  ['necesito',
#   'ayuda',
#   'contactar',
#   'chofer',
#   'enviaron',
#   'casa',
#   'hacerme',
#   'estafa'],
#  ['realizó',
#   'llaman',
#   'retención',
#   'tarjeta',
#   'crédito',
#   'pocas',
#   'palabras',
#   'cobran',
#   'valor',
#   'tarjeta',
#   'crédito',
#   'explican',
#   'motivo',
#   'cobro',
#   'hicieron',
#   'inmediatamente',
#   'devolución',
#   'van',
#   'días',
#   'failcabify'],
#  ['demostrais',
#   'miseria',
#   'empresa',
#   'aún',
#   'espera',
#   'tributeis',
#   'españa',
#   'delaware',
#   'holanda',
#   'bien',
#   'quedaos',
#   'impuestos',
#   'aportan',
#   'vais',
#   'margen',
#   'ley',
#   'encima',
#   'utilizais',
#   'pobres',
#   'niños'],
#  ['media',
#   'hora',
#   'esperando',
#   'viendo',
#   'aleja',
#   'auto',
#   'cambian',
#   'auto',
#   'tiempo',
#   'perdido'],
#  ['sigues',
#   'esperando',
#   'cabify',
#   'hazlo',
#   'saber',
#   'conductor',
#   'regale',
#   'botella',
#   'agua',
#   'feliznavidad'],
#  ['juro',
#   'pensé',
#   'inocentada',
#   'noticia',
#   'diciembre',
#   'además',
#   'según',
#   'mayoría',
#   'gasto',
#   'sido',
#   'aumentar',
#   'inversión',
#   'red',
#   'ciclable',
#   'poquito',
#   'pedalada',
#   'pedalada'],
#  ['imaginas',
#   'infierno',
#   'vivido',
#   'cuesta',
#   'encargarse',
#   'cabify',
#   'cancelaron',
#   'viajes',
#   'debitados',
#   'tarjeta',
#   'reclamar',
#   'si',
#   'tiempo',
#   'hacerlo'],
#  ['hola',
#   'intento',
#   'registrarme',
#   'través',
#   'correo',
#   'empresarial',
#   'llega',
#   'correo',
#   'dígitos',
#   'correo',
#   'bien',
#   'escrito',
#   'revisé',
#   'todas',
#   'bandejas',
#   'correo'],
#  ['vtc',
#   've',
#   'mete',
#   'carril',
#   'mirar',
#   'tlf',
#   'saber',
#   'dónde',
#   'va',
#   'entra',
#   'servicio'],
#  ['indicarle',
#   'cuál',
#   'izquierda',
#   'derecha',
#   'chófer',
#   'cabify',
#   'agradando',
#   'mondayvibes'],
#  ['teo', 'viaja', 'cabify'],
#  ['inútiles',
#   'sacan',
#   'favor',
#   'carentes',
#   'mínimo',
#   'conocimiento',
#   'ciudad'],
#  ['lucas', 'cabify', 'tarjeta', 'cancela', 'walter', 'borracho', 'remis'],
#  ['todxs',
#   'recomienda',
#   'veterinarias',
#   'excelentes',
#   'kms',
#   'casa',
#   'díganme',
#   'cómo',
#   'hago',
#   'emergencia',
#   'si',
#   'viajar',
#   'hr',
#   'cómo',
#   'hago',
#   'ir',
#   'volver',
#   'coche',
#   'vivo',
#   'zona',
#   'uber',
#   'cabify',
#   'cancelan',
#   'viajes',
#   'remiserías',
#   'penas',
#   'coches'],
#  ['viviendo',
#   'pesadilla',
#   'ayer',
#   'vivo',
#   'zona',
#   'buenas',
#   'veterinarias',
#   'coche',
#   'depender',
#   'remis',
#   'cabify',
#   'viajar',
#   'suplicio',
#   'anoche',
#   'pasé',
#   'buscando',
#   'coche',
#   'coche',
#   'imagina',
#   'depender',
#   'ir',
#   'venir'],
#  ['fiat',
#   'tipo',
#   'hace',
#   'sospechar',
#   'aún',
#   'así',
#   'preguntaremos',
#   'especialistas',
#   'hostias',
#   'imposibles',
#   'ñiñiñiñi'],
#  ['factura',
#   'espv',
#   'ns',
#   'realizado',
#   'cargo',
#   'viaje',
#   'realizado',
#   'solicitado',
#   'conductor',
#   'matheus',
#   'matrícula',
#   'lkj',
#   'validado',
#   'viaje',
#   'consentimiento',
#   'realizado',
#   'cargo',
#   'tarjeta',
#   'consentimiento',
#   'servicio',
#   'solicitado'],
#  ['preguntale',
#   'alberto',
#   'sigue',
#   'permitiendo',
#   'fuga',
#   'divisas',
#   'empresas',
#   'piratas',
#   'evasoras',
#   'uber',
#   'cabify',
#   'etc',
#   'tambien',
#   'dólares',
#   'joda'],
#  ['sufrido', 'accidente', 'tráfico', 'ocupante', 'uber', 'cabify', 'seguros'],
#  ['pedí', 'cabify', 'llegar', 'barracas', 'creo', 'llegando', 'hora'],
#  ['chofer',
#   'cabify',
#   'escucha',
#   'porno',
#   'mientras',
#   'conduce',
#   'suena',
#   'novaresio',
#   'felando',
#   'ministro',
#   'salvarezza',
#   'gagging',
#   'mundicia'],
#  ['amazon',
#   'global',
#   'optimism',
#   'anunciado',
#   'boom',
#   'supersonic',
#   'cabify',
#   'jetblue',
#   'rivian',
#   'uber',
#   'unido',
#   'the',
#   'climate',
#   'pledge',
#   'compromiso',
#   'alcanzar',
#   'neutralidad',
#   'emisiones',
#   'carbono'],
#  ['bugeó',
#   'cabify',
#   'hace',
#   'veinte',
#   'minutos',
#   'mismo',
#   'lugar',
#   'chofer',
#   'si',
#   'necesitas',
#   'ayuda',
#   'pestañea',
#   'dos',
#   'veces'],
#  ['bien',
#   'cabify',
#   'bien',
#   'ahora',
#   'haced',
#   'mismo',
#   'demás',
#   'coches',
#   'vais',
#   'carajo',
#   'rato'],
#  ['sido',
#   'conductora',
#   'cabify',
#   'vtc',
#   'nunca',
#   'quedado',
#   'perdido',
#   'tiempo',
#   'dinero',
#   'devolverlo',
#   'veces',
#   'complicado',
#   'conseguir',
#   'conductor',
#   'misma',
#   'empresa',
#   'generalmente',
#   'mandan',
#   'correo',
#   'datos',
#   'viaje',
#   'ahí',
#   'saldrá',
#   'nombre'],
#  ['todss',
#   'veces',
#   'vine',
#   'vacuna',
#   'llegaba',
#   'hora',
#   'mas',
#   'tarde',
#   'cabify',
#   'hoy',
#   'media',
#   'hora',
#   'nunca',
#   'punto',
#   'medio'],
#  ['hace',
#   'casi',
#   'dos',
#   'horas',
#   'buscando',
#   'cabify',
#   'hablo',
#   'jefe',
#   'contesta',
#   'sticker',
#   'bernardo',
#   'dice',
#   'palabras'],
#  ['primer',
#   'viaje',
#   'gratis',
#   'didi',
#   'argentina',
#   'aplicación',
#   'cabify',
#   'uber',
#   'beat',
#   'ingresá',
#   'código',
#   'martina',
#   'ahora',
#   'activá',
#   'viaje'],
#  ['tampoco',
#   'mola',
#   'hagan',
#   'guiño',
#   'empresa',
#   'cabify',
#   'viniendo',
#   'personaje',
#   'interpreta',
#   'político',
#   'cargo',
#   'público',
#   'debe',
#   'utilizar',
#   'transporte',
#   'público',
#   'oficial'],
#  ['incomprendidos'],
#  ['umm', 'beso', 'tan', 'delicioso', 'jijiji'],
#  ['cabify',
#   'uber',
#   'disparan',
#   'incorporación',
#   'taxistas',
#   'realidad',
#   'querían',
#   'ver',
#   'taxista',
#   'grandes',
#   'plataformas',
#   'muerto',
#   'guste',
#   'guste',
#   'usuario',
#   'prefiere',
#   'través'],
#  ['taxienlucha',
#   'mejorentaxi',
#   'quejasvtc',
#   'eltaxiunido',
#   'eligetaxi',
#   'hace',
#   'momento',
#   'glorieta',
#   'estación',
#   'santa',
#   'justa',
#   'sevilla',
#   'parece',
#   'vtc',
#   'directo',
#   'autobús'],
#  ['motor', 'eléctrico', 'lleva', 'inventado', 'años'],
#  ['coche',
#   'autónomo',
#   'inventado',
#   'hace',
#   'años',
#   'siguen',
#   'resolver',
#   'mismos',
#   'problemas',
#   'hace',
#   'años'],
#  ['aquí', 'ejemplo', 'cualquier', 'cosa', 'ganar', 'hora'],
#  ['elite',
#   'informa',
#   'llegado',
#   'acuerdo',
#   'multinacional',
#   'americana',
#   'hacer',
#   'traslados',
#   'clientes',
#   'helicóptero',
#   'asi',
#   'poder',
#   'combatir',
#   'uber',
#   'cabify',
#   'seguiremos',
#   'informando'],
#  ['lindo', 'uber', 'cabify', 'habla', 'horas', 'mañana'],
#  ['chica',
#   'pierde',
#   'mochila',
#   'todas',
#   'cosas',
#   'veis',
#   'desesperada',
#   'diciendo',
#   'gilipolleces',
#   'taxis',
#   'cabify',
#   'queréis',
#   'hacer',
#   'hacer',
#   'llegar',
#   'mensaje',
#   'lejos',
#   'pidiendo',
#   'dejad',
#   'meteros',
#   'cosas',
#   'importa',
#   'gente'],
#  ['orgullo'],
#  ['clienteenisa',
#   'reinventa',
#   'logra',
#   'acuerdo',
#   'alain',
#   'afflelou',
#   'transportar',
#   'gratis',
#   'clientes',
#   'audiología',
#   'vía'],
#  ['dius',
#   'tornes',
#   'lloc',
#   'si',
#   'et',
#   'roben',
#   'però',
#   'bé',
#   'tornat',
#   'sé',
#   'rick',
#   'parece',
#   'falso',
#   'bolsa',
#   'patatas'],
#  ['imagino',
#   'contactado',
#   'cabify',
#   'si',
#   'sabe',
#   'sugiero',
#   'colgar',
#   'algún',
#   'cartelito',
#   'zona',
#   'puede',
#   'encontrase',
#   'alguien',
#   'redes',
#   'grupos',
#   'face',
#   'barrios',
#   'normalmente',
#   'grupos',
#   'objetos',
#   'perdidos',
#   'suerte'],
#  ['pasando',
#   'frecuencia',
#   'uber',
#   'beat',
#   'cabify',
#   'favor',
#   'harta',
#   'salir',
#   'saber',
#   'cuánto',
#   'tiempo',
#   'voy',
#   'tardar',
#   'esperando'],
#  ['miguel',
#   'bien',
#   'emocionarse',
#   'vez',
#   'emoción',
#   'sentirse',
#   'diario',
#   'suscríbete',
#   'plan',
#   'propia',
#   'bici',
#   'pedigrí',
#   'podrás',
#   'hacer',
#   'fotos',
#   'días'],
#  ['iras',
#   'mismo',
#   'conductores',
#   'trabajan',
#   'ambas',
#   'app',
#   'simultáneamente',
#   'problema',
#   'administración',
#   'exige',
#   'requisitos',
#   'acceso',
#   'vtc'],
#  ['acabo',
#   'ver',
#   'cheems',
#   'publicidad',
#   'cabify',
#   'mierda',
#   'partir',
#   'hoy',
#   'solo',
#   'uso',
#   'uber'],
#  ['oigan',
#   'hora',
#   'toque',
#   'queda',
#   'si',
#   'metros',
#   'micros',
#   'post',
#   'funcionarán',
#   'uber',
#   'cabify'],
#  ['mal',
#   'hace',
#   'volver',
#   'ebria',
#   'manija',
#   'casa',
#   'aparte',
#   'alta',
#   'demanda',
#   'cabify'],
#  ['estimados',
#   'llevo',
#   'mes',
#   'haciendo',
#   'seguimiento',
#   'objeto',
#   'enviado',
#   'conductor',
#   'comprometió',
#   'entregar',
#   'nunca',
#   'llegó',
#   'escribí',
#   'aplicación',
#   'inconveniente',
#   'acerque',
#   'oficinas',
#   'increíble',
#   'pueda',
#   'darme',
#   'solución'],
#  ['mandan',
#   'cabify',
#   'casa',
#   'lleva',
#   'hospital',
#   'militar',
#   'vez',
#   'hospital',
#   'dan',
#   'barbijo',
#   'nuevo',
#   'bolsa',
#   'cosas',
#   'picar',
#   'arranca',
#   'entrevista',
#   'medoco',
#   'explican',
#   'riesgos',
#   'procedimiento',
#   'acá',
#   'adelante',
#   'años',
#   'control'],
#  ['permite',
#   'evasión',
#   'fugas',
#   'divisas',
#   'empresas',
#   'piratas',
#   'uber',
#   'cabify',
#   'rappi',
#   'glovo',
#   'contexto',
#   'país',
#   'vivimos',
#   'puede',
#   'ir',
#   'solo',
#   'dólar',
#   'alberto',
#   'mira',
#   'costado'],
#  ['espero', 'respuesta', 'pronto', 'pasado', 'mas', 'días'],
#  ['preguntaste',
#   'alberto',
#   'sigue',
#   'permitiendo',
#   'evasión',
#   'fugas',
#   'divisas',
#   'empresas',
#   'piratas',
#   'uber',
#   'cabify',
#   'rapi',
#   'glovo',
#   'etc',
#   'mismo',
#   'prometió',
#   'campaña',
#   'acababa',
#   'uberizacion',
#   'economía',
#   'sos',
#   'periodista',
#   'opereta'],
#  ['lamentamos',
#   'sinceramente',
#   'publicidad',
#   'confusa',
#   'trabajaremos',
#   'mejorar',
#   'anuncios'],
#  ['viste',
#   'concha',
#   'madre',
#   'bueno',
#   'ahí',
#   'tenés',
#   'ir',
#   'fijate',
#   'cabify',
#   'barato',
#   'uber',
#   'pelotudo'],
#  ['fisicaoquimicaelreencuentro',
#   'cova',
#   'mucha',
#   'lucha',
#   'activismo',
#   'historias',
#   'luego',
#   'cabify',
#   'ola',
#   'ase'],
#  ['cabify', 'va', 'escuchando', 'nirvana'],
#  ['cabify',
#   'viene',
#   'escuchando',
#   'unas',
#   'baladas',
#   'domingo',
#   'hs',
#   'balazo'],
#  ['conductor',
#   'dejó',
#   'tirado',
#   'quiso',
#   'cancelar',
#   'viaje',
#   'irme',
#   'caminando',
#   'frío',
#   'espero',
#   'despidan',
#   'luego',
#   'uber',
#   'desfachatez',
#   'cobrarme',
#   'adiós',
#   'uber',
#   'hola'],
#  ['autito',
#   'cabify',
#   'partido',
#   'river',
#   'flasheé',
#   'howard',
#   'mars',
#   'rover'],
#  ['vergüenza', 'autito', 'cabify', 'si', 'voy', 'decir', 'fines', 'semana'],
#  ['cómo', 'violenta', 'autito', 'cabify', 'hermano'],
#  ['hola',
#   'conozco',
#   'varixs',
#   'conductores',
#   'cabi',
#   'pasado',
#   'mochila',
#   'si',
#   'dicen',
#   'aviso',
#   'supongo',
#   'habras',
#   'puesto',
#   'contacto',
#   'cabify',
#   'suerte'],
#  ['atención',
#   'usuarios',
#   'rideapps',
#   'didiargentina',
#   'confunde',
#   'promos',
#   'off',
#   'próximos',
#   'viajes',
#   'sólo',
#   'aplica',
#   'siguiente',
#   'viaje',
#   'cómo',
#   'diseñan',
#   'comunican',
#   'claridad',
#   'descuentos',
#   'marketing'],
#  ['bueno',
#   'tuits',
#   'cabify',
#   'borrados',
#   'acá',
#   'asustaron',
#   'viejo',
#   'cabreado',
#   'extraño'],
#  ['chavala',
#   'pierde',
#   'mochila',
#   'cosas',
#   'importantes',
#   'dentro',
#   'después',
#   'subir',
#   'cabify',
#   'cantidad',
#   'ingente',
#   'gilipollas',
#   'van',
#   'ponerle',
#   'tuits',
#   'joda',
#   'próxima',
#   'vez',
#   'coja',
#   'taxi',
#   'gente',
#   'mala',
#   'eh'],
#  ['abro',
#   'melón',
#   'incluirme',
#   'grupo',
#   'llevo',
#   'entré',
#   'uma',
#   'siendo',
#   'conductor',
#   'cabify',
#   'media',
#   'facultad'],
#  ['buenas',
#   'tardes',
#   'estan',
#   'disculpe',
#   'molestias',
#   'coferencia',
#   'nunca',
#   'mencionan',
#   'plataformas',
#   'taxi',
#   'uber',
#   'indriver',
#   'cabify',
#   'podemos',
#   'trabajar',
#   'dias',
#   'enero',
#   'saber',
#   'informado',
#   'espera',
#   'respuesta',
#   'gracias'],
#  ['casi',
#   'así',
#   'médico',
#   'entrando',
#   'trabajar',
#   'sanidad',
#   'mayoría',
#   'ccaas',
#   'gana',
#   'chofer',
#   'cabify',
#   'base',
#   'propinas',
#   'mes',
#   'quieren',
#   'hacer',
#   'creer',
#   'ganar',
#   'mes',
#   'limpios',
#   'insolidaridad'],
#  ['decir',
#   'buscar',
#   'cambio',
#   'único',
#   'sabéis',
#   'hacer',
#   'quejarse',
#   'romper',
#   'cabifys',
#   'pegarle',
#   'choferes'],
#  ['comments',
#   'dice',
#   'jajaja',
#   'chulería',
#   'taxistas',
#   'pisais',
#   'jajaja',
#   'así',
#   'va'],
#  ['si', 'muchas', 'gracias', 'buscar', 'google', 'llamé', 'taxis'],
#  ['jajaja',
#   'pastar',
#   'dice',
#   'luego',
#   'bloqueas',
#   'si',
#   'piel',
#   'tan',
#   'fina',
#   'vais',
#   'reclamar',
#   'derechos',
#   'cuanto',
#   'dicen',
#   'cuatro',
#   'verdades',
#   'ofendeis',
#   'cojeis',
#   'pataleta',
#   'normal',
#   'defiendas',
#   'mierdafy',
#   'mugre',
#   'merecéis'],
#  ['aún',
#   'existe',
#   'beat',
#   'empezó',
#   'semáforo',
#   'rojo',
#   'quería',
#   'autos',
#   'cerca',
#   'navidad',
#   'busqué',
#   'uber',
#   'didi',
#   'todavía',
#   'existe',
#   'cabify',
#   'opción'],
#  ['ir',
#   'denunciar',
#   'decir',
#   'montado',
#   'taxi',
#   'cabify',
#   'posiblemente',
#   'taxista',
#   'todavía',
#   'mochila',
#   'ánimo',
#   'suerte'],
#  ['abrazo',
#   'dormir',
#   'gustaría',
#   'ahogarse',
#   'labios',
#   'desquitarse',
#   'manera',
#   'menos',
#   'delicada',
#   'ambos',
#   'deseen',
#   'entregarse',
#   'necesita',
#   'pensar',
#   'necesita',
#   'saborearle',
#   'luna',
#   'posso',
#   'ordinare',
#   'cabify'],
#  ['tampoco',
#   'entiendo',
#   'único',
#   'ocurre',
#   'pueden',
#   'diferenciar',
#   'ubers',
#   'cabify',
#   'entonces',
#   'toca',
#   'colaborar'],
#  ['asi',
#   'lento',
#   'ven',
#   'entrando',
#   'cancha',
#   'pelota',
#   'auto',
#   'cabify',
#   'mas',
#   'rápido',
#   'cardona'],
#  ['ke',
#   'pague',
#   'cabify',
#   'ke',
#   'vaya',
#   'casa',
#   'ke',
#   'mimee',
#   'goxear',
#   'regla',
#   'ess',
#   'mas',
#   'bonito',
#   'hechoo',
#   'mess'],
#  ['vete', 'pastar', 'anda', 'enfermo'],
#  ['chabon',
#   'cabify',
#   'segundo',
#   'cualquier',
#   'momento',
#   'doy',
#   'bifes',
#   'pelada',
#   'cerrar',
#   'orto'],
#  ['publicidad',
#   'cabify',
#   'dice',
#   'viaja',
#   'legal',
#   'seguro',
#   'pasa',
#   'pija',
#   'cara',
#   'uber',
#   'jajajahs'],
#  ['autito', 'cabify', 'aparece'],
#  ['cabify', 'chollo'],
#  ['insulto', 'descripción', 'sé', 'si', 'sabes', 'diferencia'],
#  ['gracias', 'quedo', 'tranquilo'],
#  ['haces', 'bien', 'vete', 'bici', 'mejor', 'cardio'],
#  ['olor', 'cabify', 'siempre', 'va', 'recordar', 'mismo', 'trayecto'],
#  ['criado', 'hermanas', 'osea', 'mujeres', 'entiendo', 'bastante'],
#  ['defenderé',
#   'gana',
#   'si',
#   'compañero',
#   'compañera',
#   'tx',
#   'si',
#   'parece',
#   'actuó',
#   'caballero',
#   'pues',
#   'gracias',
#   'hoy',
#   'día',
#   'perdido',
#   'buenas',
#   'costumbres',
#   'educación',
#   'si',
#   'sabes',
#   'diferenciar',
#   'respecto',
#   'machismo',
#   'normal',
#   'pongas',
#   'pones'],
#  ['aquí',
#   'faltar',
#   'faltas',
#   'llamándome',
#   'corta',
#   'imbécil',
#   'integral',
#   'vete',
#   'pastar',
#   'anda'],
#  ['va', 'pinza'],
#  ['hecho', 'acuerdo'],
#  ['bueno',
#   'explico',
#   'dos',
#   'funciona',
#   'mundo',
#   'ninguna',
#   'mujer',
#   'necesita',
#   'venga',
#   'tío',
#   'dorada',
#   'armadura',
#   'defenderla',
#   'twitter',
#   'bueno',
#   'casi',
#   'ninguna',
#   'upgrades',
#   'siglo',
#   'xxi'],
#  ['what',
#   'peleando',
#   'dos',
#   'random',
#   'puto',
#   'tema',
#   'idioma',
#   'da',
#   'igual',
#   'trol',
#   'sólo',
#   'dije',
#   'cada',
#   'persona',
#   'hable',
#   'idioma',
#   'mejor',
#   'parezca',
#   'así',
#   'comunicaremos',
#   'mejor',
#   'escribí',
#   'alemán',
#   'aquello',
#   'cerrar',
#   'círculo'],
#  ['estudiante',
#   'pierde',
#   'mochila',
#   'crea',
#   'perfil',
#   'twitter',
#   'intentar',
#   'recuperarla',
#   'anormales',
#   'vez',
#   'ayudar',
#   'echan',
#   'cara',
#   'estudiar',
#   'cataluña',
#   'color',
#   'mochila',
#   'haber',
#   'cogido',
#   'cabify',
#   'vez',
#   'taxi',
#   'si',
#   'recua',
#   'tontos',
#   'ayudadla'],
#  ['contando',
#   'da',
#   'igual',
#   'cabify',
#   'uber',
#   'easy',
#   'freenow',
#   'voy',
#   'bici'],
#  ['app',
#   'malas',
#   'prácticas',
#   'usuarios',
#   'pasajeros',
#   'comerciantes',
#   'necesito',
#   'interesa',
#   'trabajar',
#   'uber',
#   'uso',
#   'pocas',
#   'veces',
#   'intenté',
#   'estafado',
#   'carrera',
#   'devolución',
#   'pagado',
#   'uso',
#   'solo',
#   'cabify'],
#  ['entonces',
#   'pq',
#   'defiendes',
#   'explican',
#   'saltas',
#   'incongruencias',
#   'compañera'],
#  ['seguid',
#   'adelante',
#   'taxi',
#   'juan',
#   'total',
#   'uso',
#   'cabify',
#   'hablo',
#   'catalá'],
#  ['divierto',
#   'aclarando',
#   'gente',
#   'funciona',
#   'mierdafy',
#   'mugre',
#   'familia',
#   'bien',
#   'gracias',
#   'pasatiempo',
#   'iluminar',
#   'gente',
#   'minusvalias',
#   'cognitivas',
#   'cosas',
#   'realidad',
#   'confundan',
#   'seres',
#   'conocimiento',
#   'realidad'],
#  ['señor', 'juan', 'vaya', 'atender', 'familia'],
#  ['mujer',
#   'depende',
#   'fina',
#   'piel',
#   'aguanta',
#   'carros',
#   'carretas',
#   'defender',
#   'indefendible',
#   'vamos',
#   'insulto',
#   'descripción'],
#  ['nerd', 'horrible', 'siento', 'mega', 'insultada'],
#  ['si', 'quieres', 'esclavos', 'sabes', 'llama', 'mierdafy', 'disfruta'],
#  ['traído',
#   'mierdafy',
#   'mejorar',
#   'transporte',
#   'persona',
#   'punto',
#   'punto',
#   'vamos',
#   'cada',
#   'comentario',
#   'queda',
#   'claro',
#   'cucaracha'],
#  ['suerte',
#   'años',
#   'cucas',
#   'quiebra',
#   'pregunta',
#   'mierdafy',
#   'pq',
#   'rakuten',
#   'da',
#   'pasta'],
#  ['che',
#   'pive',
#   'tí',
#   'si',
#   'hace',
#   'falta',
#   'adaptación',
#   'dicho',
#   'disfrutes',
#   'cucaracho',
#   'clientes',
#   'tx',
#   'crees',
#   'españa',
#   'cosas',
#   'hacen',
#   'argentina'],
#  ['cobraron',
#   'dos',
#   'veces',
#   'nunca',
#   'tomé',
#   'auto',
#   'necesito',
#   'devolución',
#   'dinero'],
#  ['jajajajaja', 'nerd', 'despectivo'],
#  ['falso',
#   'conductores',
#   'taxi',
#   'pueden',
#   'robar',
#   'ser',
#   'humano',
#   'conductores',
#   'cabify',
#   'empresa',
#   'trabajadores',
#   'dejad',
#   'criminalizar',
#   'trabajadores',
#   'cago',
#   'vais'],
#  ['ok',
#   'puedes',
#   'decir',
#   'adaptar',
#   'dia',
#   'hoy',
#   'nadie',
#   'preguntado',
#   'mismo',
#   'dicho',
#   'concreto'],
#  ['spot',
#   'cabify',
#   'sponsor',
#   'bover',
#   'dice',
#   'casualidad',
#   'primera',
#   'final',
#   'sido',
#   'canchita',
#   'asfalto',
#   'porteño',
#   'poder',
#   'llenar',
#   'formulario',
#   'vacunarte'],
#  ['dice', 'abierto', 'hs', 'cabify', 'lleva', 'animales', 'avísame', 'pido'],
#  ['suerte',
#   'vais',
#   'camino',
#   'desaparecer',
#   'si',
#   'adaptais',
#   'mundo',
#   'actual'],
#  ['llamé',
#   'teléfono',
#   'ningún',
#   'momento',
#   'dije',
#   'salí',
#   'calle',
#   'demora',
#   'minutos',
#   'aseguraban'],
#  ['señor', 'cabify', 'humor', 'hablar', 'insista'],
#  ['primer', 'viaje', 'descuento', 'cabify', 'código', 'lucilac'],
#  ['didi',
#   'app',
#   'cabify',
#   'uber',
#   'descuento',
#   'primer',
#   'viaje',
#   'código',
#   'lucila'],
#  ['evidentemente',
#   'si',
#   'sale',
#   'calle',
#   'hora',
#   'difícilmente',
#   'encuentre',
#   'hace',
#   'cuantos',
#   'años',
#   'taxi',
#   'puede',
#   'solicitar',
#   'teléfono',
#   'web',
#   'app',
#   'hecho',
#   'presente',
#   'ciudades',
#   'españa'],
#  ['válido',
#   'primeros',
#   'pedidos',
#   'si',
#   'tenés',
#   'cuenta',
#   'create',
#   'nueva',
#   'número',
#   'algún',
#   'familiar',
#   'amigo',
#   'usa',
#   'código'],
#  ['codigo',
#   'rappi',
#   'pedirte',
#   'quieras',
#   'envíos',
#   'gratis',
#   'código',
#   'santiagof'],
#  ['si',
#   'digo',
#   'forrest',
#   'gump',
#   'posible',
#   'interpretación',
#   'función',
#   'contexto'],
#  ['compraron',
#   'autorizaciones',
#   'pensando',
#   'compraban',
#   'licencias',
#   'hacen',
#   'clientes',
#   'cargos',
#   'tarjetas',
#   'tx',
#   'intrusismo',
#   'laboral',
#   'evaden',
#   'impuestos',
#   'delawer',
#   'holanda',
#   'estafa',
#   'refieres',
#   'pq',
#   'lista',
#   'continua'],
#  ['pues',
#   'especifiques',
#   'lame',
#   'varias',
#   'traducciones',
#   'dependiendo',
#   'contexto',
#   'neng',
#   'mu',
#   'cortito'],
#  ['estafa'],
#  ['uber', 'cabify'],
#  ['pronto', 'cabify', 'sale', 'menos', 'saludos'],
#  ['si',
#   'problema',
#   'hables',
#   'gana',
#   'decimos',
#   'luces',
#   'pq',
#   'defiendes',
#   'mierdafy',
#   'mugre',
#   'cucaracho'],
#  ['ubers', 'cabify', 'remises', 'jajajajaja'],
#  ['espera',
#   'puesto',
#   'denuncia',
#   'si',
#   'asi',
#   'espero',
#   'dieras',
#   'datos',
#   'conductor',
#   'cabify',
#   'llevó'],
#  ['persona',
#   'busca',
#   'mochila',
#   'arriesgo',
#   'contratando',
#   'empresa',
#   'cubre',
#   'tributa',
#   'aquí',
#   'explota',
#   'trabajadores',
#   'parece',
#   'genial',
#   'hable',
#   'catalán',
#   'tolero',
#   'falta',
#   'educación',
#   'idioma',
#   'precisamente'],
#  ['nunca',
#   'reclamado',
#   'dia',
#   'hoy',
#   'idea',
#   'derechos',
#   'obligaciones',
#   'solo',
#   'subiros',
#   'taxi',
#   'app',
#   'debes',
#   'aceptar',
#   'todas',
#   'condiciones',
#   'si',
#   'huele',
#   'mal',
#   'bajas',
#   'pagas',
#   'vol',
#   'radio',
#   'elección',
#   'dial',
#   'apagado',
#   'recorrido',
#   'elección'],
#  ['contestado',
#   'hora',
#   'tx',
#   'sobra',
#   'si',
#   'quieres',
#   'esclavos',
#   'vete',
#   'mierdafy'],
#  ['crees',
#   'viajes',
#   'mierdafy',
#   'mal',
#   'dice',
#   'anda',
#   'vete',
#   'paseo',
#   'mira',
#   'foros',
#   'internet',
#   'si',
#   'conductores',
#   'quejan',
#   'pq',
#   'cobran',
#   'erte',
#   'ere',
#   'paro',
#   'cuento',
#   'seguro',
#   'cuca'],
#  ['todas',
#   'quieras',
#   'alguien',
#   'defiende',
#   'mierdafy',
#   'pq',
#   'seguro',
#   'cucaracho',
#   'dado',
#   'cuenta',
#   'tomado',
#   'vais',
#   'palmar',
#   'pasta',
#   'cuca',
#   'vendido'],
#  ['mejor',
#   'sentencia',
#   'condenatoria',
#   'mierdafy',
#   'mugre',
#   'políticos',
#   'mierda',
#   'permitido',
#   'aberración',
#   'cierto',
#   'meten',
#   'pasta',
#   'rakuten',
#   'verás',
#   'van',
#   'cobrar',
#   'ahora',
#   'dinamica'],
#  ['tranqui',
#   'clientes',
#   'tampoco',
#   'queremos',
#   'sabes',
#   'ganamos',
#   'tranquilidad',
#   'mientras',
#   'amargas',
#   'vida',
#   'cucarachas',
#   'si',
#   'queréis',
#   'esclavos',
#   'sabéis',
#   'mierdafy',
#   'mugre'],
#  ['critico',
#   'casi',
#   'viajes',
#   'fallado',
#   'si',
#   'usuario',
#   'taxi',
#   'queja',
#   'olores',
#   'música',
#   'alta',
#   'malas',
#   'contestaciones',
#   'recorrido',
#   'largo',
#   'cobrar',
#   'tantas',
#   'malas',
#   'experiencias',
#   'fin'],
#  ['ok',
#   'pues',
#   'vas',
#   'bus',
#   'andando',
#   'gana',
#   'mierdafy',
#   'mugre',
#   'evaden',
#   'impuestos',
#   'hacen',
#   'intrusismo',
#   'laboral',
#   'luego',
#   'si',
#   'vas',
#   'hospitales',
#   'holanda',
#   'delawer'],
#  ['sabe', 'vehículo', 'llevo', 'barcelona'],
#  ['si',
#   'aquí',
#   'protestando',
#   'mal',
#   'servicio',
#   'dado',
#   'cacafay',
#   've',
#   'coherente',
#   'tarifas',
#   'absurdas',
#   'mejores',
#   'tarifas',
#   'dinámicas',
#   'anda',
#   'yaaaa',
#   'mal',
#   'trato',
#   'chulería',
#   'ahora',
#   'defiendes',
#   'criticabas',
#   'absurdo'],
#  ['va',
#   'mierdafy',
#   'seguro',
#   'tener',
#   'datos',
#   'bancarios',
#   'harán',
#   'cargos',
#   'salga',
#   'webs'],
#  ['hablo',
#   'da',
#   'gana',
#   'cerebro',
#   'funciona',
#   'divinamente',
#   'decir',
#   'estupideces',
#   'haces',
#   'divinamente'],
#  ['próxima', 'cabify', 'si'],
#  ['taxistas', 'cada', 'día', 'pierden', 'clientes', 'clinex'],
#  ['verdad',
#   'elegido',
#   'cada',
#   'día',
#   'perdéis',
#   'terreno',
#   'tarifas',
#   'absurdas',
#   'mal',
#   'trato',
#   'chulería',
#   'portais'],
#  ['acudo',
#   'dónde',
#   'parece',
#   'muchas',
#   'gracias',
#   'consejos',
#   'decirte',
#   'subo',
#   'taxi',
#   'nunca',
#   'vida',
#   'estafado',
#   'listillos',
#   'llevan',
#   'hacer',
#   'tour',
#   'ciudad'],
#  ['bloquearon', 'cuenta', 'mandan', 'correo', 'recuperarla'],
#  ['contento',
#   'general',
#   'cabify',
#   'seguiré',
#   'utilizándolo',
#   'precio',
#   'razonable',
#   'pillar',
#   'taxi',
#   'da',
#   'viaje',
#   'min',
#   'barbaridad',
#   'viendo',
#   'clientes',
#   'perdiendo'],
#  ['perdón',
#   'equivoqué',
#   'parada',
#   'media',
#   'mark',
#   'tampoco',
#   'ninguno',
#   'taxista',
#   'podrías',
#   'decir',
#   'menos',
#   'daría',
#   'taxi',
#   'llamando',
#   'radio',
#   'taxi',
#   'burjassot',
#   'bonrepos',
#   'menos'],
#  ['taxi',
#   'caro',
#   'tarifas',
#   'oficiales',
#   'cabify',
#   'sangra',
#   'altas',
#   'demandas',
#   'barato',
#   'acojonante'],
#  ['puedes',
#   'explicar',
#   'cooperativa',
#   'palacio',
#   'congresos',
#   'entiendo',
#   'siento',
#   'si',
#   'llamas',
#   'haces',
#   'app',
#   'máximo',
#   'llegada',
#   'vaya',
#   'dónde',
#   'vaya',
#   'coche',
#   'tarifas',
#   'marca',
#   'conselleria'],
#  ['usa',
#   'código',
#   'ginog',
#   'conseguir',
#   'descuento',
#   'próximos',
#   'viajes',
#   'cabify',
#   'descarga',
#   'app'],
#  ['parla', 'amb', 'jo', 'sé'],
#  ['si',
#   'cabify',
#   'perdido',
#   'si',
#   'sido',
#   'taxi',
#   'garantizo',
#   'recuperado',
#   'siento',
#   'próxima',
#   'sabes',
#   'mientras',
#   'ciudad',
#   'cono',
#   'dice',
#   'cabify',
#   'olvidado',
#   'clientes',
#   'ahora',
#   'reclama',
#   'ver',
#   'si',
#   'alguien',
#   'contesta'],
#  ['si',
#   'taxista',
#   'mira',
#   'si',
#   'miras',
#   'cortas',
#   'solo',
#   'ves',
#   'conductores',
#   'vtc',
#   'rodea',
#   'mismo',
#   'encima',
#   'faltona'],
#  ['amor',
#   'haberle',
#   'mandado',
#   'amiga',
#   'audios',
#   'am',
#   'super',
#   'ebria',
#   'llorando',
#   'volviendo',
#   'cabify',
#   'respondido',
#   'total',
#   'normalidad',
#   'si',
#   'contando',
#   'anecdota'],
#  ['prometido',
#   'eliminar',
#   'uber',
#   'cabify',
#   'etc',
#   'obviamente',
#   'traicionados',
#   'bien',
#   'entucados'],
#  ['tx',
#   'encantados',
#   'dieras',
#   'desplazamientos',
#   'además',
#   'tributar',
#   'improbable',
#   'caso',
#   'cumplamos',
#   'expectativas',
#   'hojas',
#   'reclamaciones',
#   'acudir',
#   'twitter',
#   'exigir',
#   'derechos'],
#  ['reitero',
#   'cooperativas',
#   'burjassot',
#   'palacio',
#   'congresos',
#   'hora',
#   'ningún',
#   'taxi',
#   'voy',
#   'llamar',
#   'lejos',
#   'voy',
#   'pagar',
#   'viaje',
#   'burjassot',
#   'almassera'],
#  ['cambio',
#   'pide',
#   'taxi',
#   'legal',
#   'llega',
#   'limusina',
#   'jamás',
#   'zapatico',
#   'cierto',
#   'precisamente',
#   'diversificacion',
#   'opciones',
#   'propone',
#   'tecnología',
#   'indriver',
#   'cabify',
#   'permiten',
#   'escoger',
#   'tipo',
#   'vehículo'],
#  ['tarifas',
#   'pone',
#   'taxi',
#   'pone',
#   'conselleria',
#   'transporte',
#   'contrario',
#   'cabify',
#   'cobran',
#   'rota',
#   'hora',
#   'alta',
#   'demanda',
#   'suerte'],
#  ['burjassot',
#   'solo',
#   'vamos',
#   'mismo',
#   'burjassot',
#   'godella',
#   'benimamet',
#   'zona',
#   'cortes',
#   'valencianas',
#   'radio',
#   'hora',
#   'menos',
#   'taxis',
#   'disposición',
#   'radio',
#   'taxi',
#   'tele',
#   'taxi',
#   'máximo',
#   'llegada',
#   'domicilio',
#   'taxista',
#   'valencia',
#   'conozco'],
#  ['alguien',
#   'sabe',
#   'si',
#   'alguna',
#   'aplicación',
#   'estilo',
#   'uber',
#   'funciona',
#   'córdoba',
#   'solo',
#   'cabify',
#   'pocos',
#   'choferes'],
#  ['chica',
#   'desesperada',
#   'dejaros',
#   'tonterias',
#   'si',
#   'usó',
#   'cabify',
#   'taxi',
#   'unicornio',
#   'propulsado',
#   'pedos',
#   'confeti',
#   'purpurina',
#   'si',
#   'aportas',
#   'aparta',
#   'suerte',
#   'belen',
#   'ojala',
#   'recuperes',
#   'mochila',
#   'denuncia',
#   'si',
#   'portatil',
#   'vendido'],
#  ['pagué',
#   'cabify',
#   'efectivo',
#   'ahora',
#   'di',
#   'cuenta',
#   'pagado',
#   'tarjetaaa',
#   'dios',
#   'encima',
#   'dije',
#   'quedate',
#   'vueltooo'],
#  ['acaba',
#   'decir',
#   'ex',
#   'conductor',
#   'beat',
#   'desinstale',
#   'xq',
#   'app',
#   'pide',
#   'licencia',
#   'antecedentes',
#   'perfiles',
#   'truchos',
#   'uber',
#   'cabify',
#   'app'],
#  ['hola',
#   'si',
#   'obtiene',
#   'respuesta',
#   'recomiendo',
#   'trate',
#   'localizar',
#   'empresa',
#   'transportó',
#   'matricula',
#   'podremos',
#   'dar',
#   'mire',
#   'historial'],
#  ['bannearon',
#   'uber',
#   'cabify',
#   'taxi',
#   'premium',
#   'ven',
#   'conductor',
#   'designado',
#   'nunca',
#   'escabio',
#   'sino',
#   'pasan',
#   'cosas'],
#  ['cabify', 'mierda'],
#  ['selección',
#   'quejasvtc',
#   'injusticia',
#   'abuso',
#   'usuari',
#   'uber',
#   'cabify',
#   'ilegal',
#   'fraude',
#   'engaño',
#   'timo',
#   'corrupción',
#   'políticos',
#   'transporte',
#   'inseguridad',
#   'rentabilidad',
#   'avaricia',
#   'atenciónalcliente',
#   'cliente',
#   'razón',
#   'comercio',
#   'manipulación'],
#  ['conductores',
#   'peligrosos',
#   'conductores',
#   'descuidados',
#   'clientes',
#   'estafados',
#   'clientes',
#   'decepcionados',
#   'quejasvtc',
#   'uber',
#   'cabify',
#   'estafacabifyuber'],
#  ['limita',
#   'recibe',
#   'descuento',
#   'pa',
#   'viaje',
#   'seguridad',
#   'aeropuerto',
#   'casa',
#   'bendito',
#   'capitalismo'],
#  ['belén',
#   'lleváis',
#   'apareció',
#   'mochila',
#   'amarilla',
#   'toda',
#   'vida',
#   'dentro'],
#  ['acaba',
#   'pasar',
#   'pregunté',
#   'servicio',
#   'traslado',
#   'capital',
#   'persona',
#   'iban',
#   'dejar',
#   'puerta',
#   'casa',
#   'pedí',
#   'cabify',
#   'salía',
#   'dejándome',
#   'puerta',
#   'casa'],
#  ['hola',
#   'recuerdo',
#   'dejarmela',
#   'noche',
#   'viernes',
#   'barcelona',
#   'cabify',
#   'bajarme',
#   'cabify',
#   'banco',
#   'altura',
#   'ganduxer',
#   'via',
#   'agusta',
#   'sabes'],
#  ['habla', 'ver', 'juan', 'respirad', 'dejar', 'llegue', 'oxígeno', 'cerebro'],
#  ['extraña',
#   'tx',
#   'horas',
#   'pq',
#   'diferencia',
#   'cucas',
#   'tx',
#   'presta',
#   'servicio',
#   'si',
#   'si',
#   'solo',
#   'rentable'],
#  ['pues', 'sabrás', 'idiomas', 'usas', 'mierdafy', 'osea', 'muchas', 'luces'],
#  ['pasa', 'usar', 'cabify', 'proxima', 'iras', 'taxi'],
#  ['gorka',
#   'feministra',
#   'mira',
#   'pija',
#   'progre',
#   'coche',
#   'oficial',
#   'cova',
#   'cabify',
#   'idiota',
#   'solo',
#   'asesora',
#   'momento',
#   'foqelreencuentro'],
#  ['podes', 'cancelar', 'preguntan', 'motivos', 'cobran'],
#  ['siempre',
#   'paso',
#   'mismo',
#   'deje',
#   'tolerar',
#   'empecé',
#   'bajar',
#   'espere',
#   'voy',
#   'bajar',
#   'porq',
#   'deje',
#   'pasar',
#   'coche',
#   'porq',
#   'die',
#   'aire',
#   'ac',
#   'elegí',
#   'viendo',
#   'servicio',
#   'ppal',
#   'voy',
#   'llegar',
#   'transpirada',
#   'hacerme',
#   'estudio',
#   'bajé'],
#  ['burjassot', 'valencia', 'hoy', 'imposible', 'encontrar', 'taxi'],
#  ['nota', 'comprensión', 'lectora', 'corta', 'quizás', 'conductor', 'vtc'],
#  ['usa', 'cabify', 'vayan', 'cagar', 'remiseros', 'así'],
#  ['modernos'],
#  ['tampoco',
#   'cucas',
#   'tx',
#   'bastante',
#   'venga',
#   'decir',
#   'cómo',
#   'funcionan',
#   'hacen',
#   'cucas',
#   'si',
#   'pregúntale',
#   'marido',
#   'arrimadas',
#   'abogado',
#   'mugre'],
#  ['ver',
#   'lengua',
#   'expresas',
#   'desaparezca',
#   'si',
#   'problema',
#   'cucaracho',
#   'fijo',
#   'si',
#   'muuuu',
#   'tonto',
#   'intentar',
#   'defender',
#   'indefendible',
#   'hoy',
#   'día',
#   'mundo',
#   'sabe',
#   'mierdafy',
#   'rakuten',
#   'da',
#   'pasta'],
#  ['atienden',
#   'tf',
#   'anda',
#   'mentiroso',
#   'foros',
#   'llenos',
#   'gente',
#   'capaces',
#   'comunicarse',
#   'van',
#   'atender',
#   'preferencia'],
#  ['si', 'bocachancla', 'verás', 'cero', 'coma', 'bloquea', 'tb'],
#  ['dentro',
#   'vas',
#   'palmar',
#   'pasta',
#   'tubo',
#   'pregunta',
#   'conductores',
#   'cobran',
#   'septiembre'],
#  ['mierdafy',
#   'aceptas',
#   'condiciones',
#   'vamos',
#   'puedes',
#   'reclamar',
#   'mierda',
#   'cuca',
#   'disfruta',
#   'sabes',
#   'estafado',
#   'autorización',
#   'vas',
#   'palmar',
#   'pasta',
#   'vendieron',
#   'autorización',
#   'diciendo',
#   'podrías',
#   'currar',
#   'tx',
#   'das',
#   'cada',
#   'viaje'],
#  ['respondes',
#   'tonterías',
#   'tonto',
#   'aquel',
#   'roban',
#   'encima',
#   'intenta',
#   'justificar',
#   'si',
#   'estafado',
#   'tx',
#   'denuncias',
#   'lerdo',
#   'si',
#   'defiendes',
#   'cucas',
#   'pq',
#   'hoy',
#   'día',
#   'mundo',
#   'sabe',
#   'cómo',
#   'funcionan',
#   'roban'],
#  ['cuatro',
#   'cervezas',
#   'adentro',
#   'dice',
#   'control',
#   'cuatro',
#   'campeón',
#   'cuatro',
#   'tomate',
#   'cabify',
#   'hdp'],
#  ['vuelvo',
#   'repetir',
#   'precios',
#   'licencias',
#   'ver',
#   'taxi',
#   'siempre',
#   'sido',
#   'trabajo',
#   'muchas',
#   'horas',
#   'dinero',
#   'hace',
#   'base',
#   'carreras',
#   'cambia',
#   'trabajo'],
#  ['set',
#   'educado',
#   'contestar',
#   'idioma',
#   'dirigen',
#   'vas',
#   'saber',
#   'educación'],
#  ['pruebas', 'denuncias', 'solo', 'bocachancla'],
#  ['aprender',
#   'conocer',
#   'saber',
#   'directamente',
#   'vive',
#   'diario',
#   'cree',
#   'aparece',
#   'twitter',
#   'listillo'],
#  ['próxima',
#   'vez',
# ...
#   'legal'],
#  ['año',
#   'malas',
#   'experiencias',
#   'app',
#   'conductores',
#   'malos',
#   'tratos',
#   'lenguaje',
#   'inapropiado',
#   'gps',
#   'debido',
#   'hacían',
#   'recargos',
#   'ubicaciones',
#   'erradas',
#   'enviar',
#   'mail',
#   'queja',
#   'así',
#   'dieron',
#   'compensación'],
#  ['espabilarás'],
#  ['vtc', 'diésel', 'posterior', 'enero', 'fácil', 'ver', 'multar'],
#  ['pasé', 'uber', 'cabify', 'funcionan', 'cambian', 'nombre'],
#  ['reservas',
#   'sirven',
#   'seleccionar',
#   'servicios',
#   'rentables',
#   'si',
#   'llegado',
#   'momento',
#   'realizar',
#   'servicio',
#   'existen',
#   'rentables',
#   'queda',
#   'relegado',
#   'ong',
#   'servicio',
#   'público',
#   'empresa',
#   'privada',
#   'lógicamente',
#   'rige',
#   'criterios',
#   'rentabilidad'],
#  ['claro',
#   'deja',
#   'mañana',
#   'noche',
#   'buena',
#   'todavía',
#   'definiendo',
#   'si',
#   'alta',
#   'demanda',
#   'va',
#   'ser'],
#  ['apretando',
#   'pie',
#   'alfombra',
#   'auto',
#   'quiero',
#   'cabify',
#   'acelere',
#   'cumplí'],
#  ['psicologo',
#   'videollamada',
#   'viene',
#   'mano',
#   'seguramente',
#   'arriba',
#   'cabify'],
#  ['amigo', 'prueba', 'taxi'],
#  ['tomo', 'taxi', 'solo', 'uber', 'cabify', 'claro', 'ahi', 'casos'],
#  ['casa', 'grande', 'vuelve', 'cabify', 'twitter', 'servicio'],
#  ['pago', 'cabify', 'regreso'],
#  ['llevarse',
#   'carros',
#   'euber',
#   'cabify',
#   'ahí',
#   'meten',
#   'harta',
#   'inteligencia'],
#  ['huy',
#   'corrector',
#   'quería',
#   'decir',
#   'si',
#   'expuesto',
#   'polemizar',
#   'qda',
#   'claro',
#   'usas',
#   'defiendes'],
#  ['vamos',
#   'doblo',
#   'expuesto',
#   'polemizar',
#   'dicho',
#   'pocos',
#   'taxis',
#   'usas'],
#  ['solo',
#   'uso',
#   'informar',
#   'gente',
#   'mentiras',
#   'ilegalidades',
#   'cometen',
#   'mierdafy',
#   'mugre',
#   'alguien',
#   'expone',
#   'inexactitudes',
#   'aclaro',
#   'amablemente'],
#  ['codigo',
#   'cupón',
#   'rappi',
#   'oxs',
#   'codigo',
#   'cupón',
#   'ubereats',
#   'ln',
#   'codigo',
#   'cupon',
#   'glovo',
#   'lnlfqjl',
#   'codigo',
#   'cupon',
#   'cabify',
#   'ivano',
#   'cupon',
#   'uber',
#   'xaln',
#   'código',
#   'cupon',
#   'rappi',
#   'oxs',
#   'cupón',
#   'didi',
#   'ivan',
#   'cupones',
#   'rappi'],
#  ['jodan'],
#  ['gracias', 'juan', 'uso', 'twitter', 'polemizar'],
#  ['pelotas',
#   'piso',
#   'choferes',
#   'hagan',
#   'esperar',
#   'minutos',
#   'terminan',
#   'viaje',
#   'después',
#   'quieren',
#   'ir',
#   'vas',
#   'cancelan',
#   'tiempo',
#   'odio'],
#  ['can',
#   'aló',
#   'cabifys',
#   'separador',
#   'plástico',
#   'policarbonato',
#   'falta',
#   'protocolo',
#   'motivo',
#   'cancelación',
#   'encuesta',
#   'perdiendo',
#   'información'],
#  ['conductores', 'separador', 'policarbonato', 'plástico', 'protojo', 'ojo'],
#  ['cojones', 'pasa', 'precios', 'cabify', 'cartagena'],
#  ['va',
#   'españa',
#   'hacen',
#   'cargos',
#   'tarjetas',
#   'conductores',
#   'despedido',
#   'cobran',
#   'septiembre',
#   'así',
#   'españa',
#   'misma',
#   'mierda',
#   'argentina'],
#  ['bienvenido', 'cabify', 'uber', 'desinstalar'],
#  ['volver',
#   'laburar',
#   'uber',
#   'tarifa',
#   'alta',
#   'cabify',
#   'zona',
#   'remis',
#   'demora',
#   'cap',
#   'taxi',
#   'colectivo'],
#  ['alguien',
#   'podría',
#   'explicarme',
#   'definir',
#   'preferencia',
#   'cuenta',
#   'si',
#   'ninguno',
#   'conductor',
#   'va',
#   'respetar',
#   'podrían',
#   'aprender'],
#  ['taxi',
#   'bilbao',
#   'peores',
#   'servicios',
#   'públicos',
#   'conocidos',
#   'supuesto',
#   'aceptan',
#   'reservas',
#   'nochebuena',
#   'usted',
#   'llame',
#   'momento',
#   'pena',
#   'cabify',
#   'haga',
#   'competencia'],
#  ['sabis',
#   'mismo',
#   'trato',
#   'preferir',
#   'taxi',
#   'necesito',
#   'hagan',
#   'show',
#   'defecto',
#   'cabify',
#   'uber',
#   'hab',
#   'tocado',
#   'autos',
#   'enanisimos',
#   'piden',
#   'sentarme',
#   'adelante',
#   'qur',
#   'apretarme',
#   'tocar',
#   'chofer'],
#  ['lamentable',
#   'lea',
#   'usted',
#   'condiciones',
#   'aceptó',
#   'usar',
#   'app',
#   'exoneran',
#   'cualquier',
#   'responsabilidad',
#   'empresa',
#   'temo',
#   'responsabilidad',
#   'enteramente',
#   'usted',
#   'ser',
#   'tan',
#   'incauto',
#   'reserva',
#   'anticipada',
#   'dice',
#   'existe'],
#  ['mandado',
#   'notificaciones',
#   'última',
#   'hora',
#   'valore',
#   'viaje',
#   'seguirán',
#   'llegando',
#   'miedo',
#   'poned',
#   'límite'],
#  ['cabify',
#   'tirando',
#   'tarifas',
#   'mas',
#   'baratas',
#   'menos',
#   'acá',
#   'zona',
#   'norte',
#   'baires'],
#  ['cada',
#   'vez',
#   'deficiente',
#   'uso',
#   'app',
#   'canse',
#   'disculpame',
#   'lados',
#   'llegar',
#   'tarde',
#   'imposible',
#   'predecir',
#   'tiempo',
#   'espera',
#   'nunca',
#   'móviles',
#   'disponibles',
#   'reserva',
#   'auto',
#   'fiasco',
#   'funciona',
#   'tal',
#   'cada',
#   'vez',
#   'peor'],
#  ['guapy',
#   'robamos',
#   'taxistas',
#   'dado',
#   'tener',
#   'renting',
#   'coche',
#   'molón',
#   'resto',
#   'pasta',
#   'delawer',
#   'allí',
#   'mejores',
#   'servicios',
#   'públicos',
#   'dinero',
#   'felices',
#   'fiestas',
#   'tambien'],
#  ['si',
#   'entiendo',
#   'denuncié',
#   'aplicación',
#   'dió',
#   'miedo',
#   'creo',
#   'pase',
#   'solo',
#   'mantén',
#   'siempre',
#   'seguridad',
#   'casa'],
#  ['tranquila',
#   'gente',
#   'cobarde',
#   'harán',
#   'si',
#   'acaso',
#   'contacta',
#   'alguien',
#   'confianza',
#   'comunica',
#   'puede',
#   'hacer',
#   'casos',
#   'ineptos',
#   'sino',
#   'xq',
#   'ley',
#   'ata',
#   'manos'],
#  ['preocupa', 'sobremanera', 'delincuente', 'conoce', 'casa'],
#  ['golpiza', 'palos', 'puños', 'envueltos', 'dejas', 'huella'],
#  ['pidan',
#   'dinero',
#   'devolverte',
#   'acepta',
#   'llama',
#   'cuatro',
#   'cinco',
#   'amigos',
#   'vecinos',
#   'apenas',
#   'llegue',
#   'entregue',
#   'producto',
#   'denle',
#   'paliza',
#   'padre',
#   'señor',
#   'funciona',
#   'digo',
#   'experiencia',
#   'extorsionadores',
#   'sigue',
#   'juego'],
#  ['chófer',
#   'cabify',
#   'va',
#   'dando',
#   'indicaciones',
#   'hija',
#   'hacer',
#   'matambre',
#   'arrollado',
#   'peceto',
#   'ternura'],
#  ['pay', 'attention', 'pls', 'usa', 'código', 'recibe', 'descuento', 'cabify'],
#  ['hecho',
#   'listado',
#   'startups',
#   'destacadas',
#   'madrid',
#   'cabify',
#   'spotahome',
#   'bnext',
#   'fintonic',
#   'lingokids',
#   'bipi',
#   'evidentemente',
#   'todas',
#   'si',
#   'relevantes',
#   'quieres',
#   'incluyamos',
#   'alguna',
#   'particular'],
#  ['grados',
#   'sol',
#   'pleno',
#   'mins',
#   'esperando',
#   'cabify',
#   'chocamos',
#   'llego',
#   'casa'],
#  ['codigo',
#   'cupón',
#   'rappi',
#   'oxs',
#   'codigo',
#   'cupón',
#   'ubereats',
#   'ln',
#   'codigo',
#   'cupon',
#   'glovo',
#   'lnlfqjl',
#   'codigo',
#   'cupon',
#   'cabify',
#   'ivano',
#   'cupon',
#   'uber',
#   'xaln',
#   'código',
#   'cupon',
#   'rappi',
#   'oxs',
#   'cupón',
#   'didi',
#   'ivan',
#   'cupones',
#   'rappi'],
#  ['cabify', 'mejor', 'uber', 'pasado', 'ciertos', 'asaltos'],
#  ['gracias',
#   'recorgerme',
#   'coche',
#   'guay',
#   'toda',
#   'flota',
#   'conductor',
#   'dani',
#   'mejor',
#   'cabify'],
#  ['hace',
#   'días',
#   'intento',
#   'solucionar',
#   'tema',
#   'tres',
#   'semanas',
#   'vía',
#   'medios',
#   'navidad',
#   'sincomida',
#   'sintecho',
#   'cabifynopaga'],
#  ['flasheá', 'tranquilo', 'nuevo', 'spots', 'nota'],
#  ['si', 'asociarse', 'mierdafy', 'bueno'],
#  ['deduje',
#   'similar',
#   'tema',
#   'empezó',
#   'pasar',
#   'hace',
#   'dos',
#   'semanas',
#   'aprox',
#   'venía',
#   'consiguiendo',
#   'auto',
#   'campeón'],
#  ['día', 'suba', 'cabify', 'pendiente', 'posible', 'secuestro'],
#  ['viene',
#   'pasando',
#   'deduje',
#   'mucha',
#   'gente',
#   'usando',
#   'transporte',
#   'público',
#   'deben',
#   'reventados',
#   'uber',
#   'mejor'],
#  ['dices',
#   'pare',
#   'pides',
#   'hoja',
#   'reclamaciones',
#   'apeas',
#   'llamas',
#   'cabify'],
#  ['sigo', 'tener', 'respuesta'],
#  ['ratonear', 'pesos', 'cabify', 'voy', 'llegar', 'tarde', 'peluquería'],
#  ['tomandome',
#   'meo',
#   'amiguito',
#   'jony',
#   'escupidas',
#   'frutillita',
#   'torta',
#   'comparto',
#   'delicia',
#   'meo',
#   'lluviadorada',
#   'goldenshower',
#   'watersport',
#   'uber',
#   'camioneros',
#   'beat',
#   'cabify',
#   'badbunny',
#   'rochos',
#   'presos',
#   'machosheteros',
#   'zonaoeste'],
#  ['bello'],
#  ['finde', 'amigos', 'quisieron', 'usarlo', 'tomaba', 'cara'],
#  ['gano',
#   'mes',
#   'trabajando',
#   'hs',
#   'día',
#   'cabify',
#   'restando',
#   'nafta',
#   'mantenimiento',
#   'deja',
#   'mierda'],
#  ['existen',
#   'aplicaciones',
#   'taxi',
#   'paga',
#   'servicio',
#   'brindan',
#   'seguridad',
#   'confianza',
#   'taxi',
#   'satelital',
#   'siempre',
#   'dicen',
#   'barato',
#   'sale',
#   'caro',
#   'elijamos',
#   'servicios',
#   'brinden',
#   'seguridad',
#   'pese',
#   'ser',
#   'tan',
#   'económicos'],
#  ['tosos', 'conductores', 'pelotudos', 'cabify', 'tocan'],
#  ['recomendaron',
#   'didi',
#   'aún',
#   'pude',
#   'probar',
#   'si',
#   'acepta',
#   'débito',
#   'crédito'],
#  ['si',
#   'así',
#   'recién',
#   'media',
#   'hora',
#   'pedir',
#   'después',
#   'tardo',
#   'minutos'],
#  ['recién',
#   'encontró',
#   'llegó',
#   'minutos',
#   'vez',
#   'solo',
#   'minutos',
#   'búsqueda',
#   'buscando',
#   'alternativas',
#   'acepten',
#   'débito',
#   'crédito',
#   'uber',
#   'trato',
#   'evitar',
#   'puedo'],
#  ['cabify', 'aunque', 'suele', 'ser', 'cara'],
#  ['martes',
#   'horas',
#   'literalmente',
#   'esperando',
#   'auto',
#   'hacian',
#   'dar',
#   'vueltas',
#   'cancele',
#   'cobrarme',
#   'igual',
#   'mande',
#   'mails',
#   'tweets',
#   'dms',
#   'termine',
#   'borrando',
#   'app'],
#  ['majos',
#   'cabify',
#   'dicen',
#   'si',
#   'quieres',
#   'música',
#   'suban',
#   'calefacción'],
#  ['gremio',
#   'taxi',
#   'lobotizado',
#   'visto',
#   'derechas',
#   'echado',
#   'brazos',
#   'uber',
#   'cabify',
#   'cómo',
#   'derecha',
#   'lleguen',
#   'poder',
#   'pueden',
#   'ir',
#   'vendiendo',
#   'licencias',
#   'xq',
#   'vamos',
#   'ver',
#   'uber',
#   'cabify',
#   'doquier'],
#  ['che',
#   'alguien',
#   'pasa',
#   'pide',
#   'tarda',
#   'miles',
#   'años',
#   'encontrar',
#   'conductor',
#   'encuentra',
#   'dice',
#   'llega',
#   'pasado',
#   'mañana'],
#  ['así', 'pago', 'cabify', 'vuelta'],
#  ['solo', 'cobramos', 'pago', 'cabify', 'mandarlo', 'zaragoza'],
#  ['odio'],
#  ['pues', 'preparate', 'nochebuena', 'vamos', 'dar'],
#  ['vehículo',
#   'ninguna',
#   'plataforma',
#   'denuncia',
#   'hacer',
#   'datos',
#   'públicos',
#   'marcha'],
#  ['vuelve', 'metro'],
#  ['seguí',
#   'tomando',
#   'cabify',
#   'pelotudo',
#   'así',
#   'ayudas',
#   'fugar',
#   'discurso'],
#  ['cabify', 'recomendado'],
#  ['tomes',
#   'servicio',
#   'pasó',
#   'similar',
#   'olvidé',
#   'paquete',
#   'pidió',
#   'dinero',
#   'volver',
#   'traerme',
#   'di',
#   'nunca',
#   'tomé',
#   'servicio',
#   'tomo',
#   'ahora',
#   'fallas',
#   'tocado',
#   'delicuentes',
#   'fecha'],
#  ['molesta',
#   'llamen',
#   'vtcs',
#   'taxi',
#   'locos',
#   'vivimos',
#   'mundo',
#   'tan',
#   'confuso',
#   'queda',
#   'llegar',
#   'ninguna',
#   'parte'],
#  ['cabify',
#   'burlando',
#   'soltería',
#   'cuál',
#   'novio',
#   'sé',
#   'forever',
#   'alone',
#   'necesario',
#   'burla'],
#  ['buen',
#   'dia',
#   'mandé',
#   'mensaje',
#   'privado',
#   'quiero',
#   'saber',
#   'horarios',
#   'mañana',
#   'hora',
#   'tarde',
#   'puede',
#   'pedir',
#   'auto',
#   'puede',
#   'dejar',
#   'reservado',
#   'gracias',
#   'saludos'],
#  ['gustan', 'cabify', 'hablan'],
#  ['amor',
#   'vito',
#   'vení',
#   'visita',
#   'casa',
#   'vito',
#   'tomate',
#   'cabify',
#   'espero'],
#  ['si',
#   'pagáis',
#   'ficha',
#   'mañana',
#   'llevo',
#   'hace',
#   'falta',
#   'saquéis',
#   'ave',
#   'mando',
#   'cabify'],
#  ['chiques',
#   'sucede',
#   'cabify',
#   'pasa',
#   'traicionar',
#   'bondi',
#   'noble',
#   'conurbano'],
#  ['opción', 'filtrar', 'taxis', 'aire', 'acondicionado'],
#  ['ver',
#   'heurtel',
#   'formas',
#   'parte',
#   'equipo',
#   'así',
#   'pillas',
#   'vuelo',
#   'cabify',
#   'búscate',
#   'vida',
#   'sé',
#   'viajas',
#   'cierto',
#   'todavía',
#   'contrato',
#   'cabrón'],
#  ['papa',
#   'noel',
#   'gustaría',
#   'deposite',
#   'trabaje',
#   'semanas',
#   'así',
#   'puedo',
#   'comer',
#   'pagar',
#   'alquileres'],
#  ['largue',
#   'libremente',
#   'competir',
#   'uber',
#   'cabify',
#   'taxis',
#   'rosarinos',
#   'transporte',
#   'mas',
#   'barato'],
#  ['manera',
#   'urgente',
#   'habilite',
#   'uber',
#   'cabify',
#   'ciudad',
#   'abro',
#   'hilo',
#   'fin',
#   'semana',
#   'capital',
#   'federal',
#   'taxis',
#   'cobran',
#   'bajada',
#   'bandera',
#   'sábado',
#   'am',
#   'mientras',
#   'anoche',
#   'rosario',
#   'bajada',
#   'bandera',
#   'salió'],
#  ['si',
#   'interesa',
#   'seguridad',
#   'ventanillas',
#   'abiertas',
#   'llevar',
#   'pasajeros',
#   'menos',
#   'pidan',
#   'manera',
#   'disminuir',
#   'riesgos',
#   'covid',
#   'debido',
#   'aire',
#   'entrando',
#   'saliendo',
#   'vehículo',
#   'aire',
#   'acondicionado',
#   'recircula',
#   'aire',
#   'puede',
#   'contaminado'],
#  ['claro', 'si', 'uber', 'cabify', 'comparto', 'viaje'],
#  ['mismo',
#   'si',
#   'taxi',
#   'facu',
#   'esperando',
#   'si',
#   'cabify',
#   'comparto',
#   'viaje',
#   'alguien'],
#  ['tomo',
#   'taxis',
#   'solo',
#   'uber',
#   'cabify',
#   'igual',
#   'par',
#   'momentos',
#   'incómodos',
#   'así',
#   'tal',
#   'vez',
#   'problema',
#   'sé',
#   'varones',
#   'manejan',
#   'mandar',
#   'audios',
#   'fingir',
#   'llamadas',
#   'aunque',
#   'vez',
#   'dio',
#   'cuenta',
#   'dijo',
#   'mentí',
#   'miedo',
#   'interior'],
#  ['claro', 'plata', 'choferes', 'paga', 'caso', 'hace', 'semanas'],
#  ['si', 'pagan', 'trabaje', 'díganme', 'dónde', 'voy', 'comer', 'vivir'],
#  ['dice', 'publicidad', 'cabify', 'ciudad', 'dice', 'larreta'],
#  ['hace',
#   'cobros',
#   'viajes',
#   'inexistentes',
#   'después',
#   'nunca',
#   'devuelve',
#   'dineros',
#   'llevo',
#   'descuentos',
#   'solo',
#   'mes',
#   'diciembre',
#   'dan',
#   'respuesta',
#   'solo',
#   'interesa',
#   'cobrar'],
#  ['hace',
#   'cobros',
#   'viajes',
#   'inexistentes',
#   'después',
#   'nunca',
#   'devuelve',
#   'dineros',
#   'llevo',
#   'descuentos',
#   'solo',
#   'mes',
#   'diciembre',
#   'dan',
#   'respuesta',
#   'solo',
#   'interesa',
#   'cobrar'],
#  ['hace',
#   'cobros',
#   'viajes',
#   'inexistentes',
#   'después',
#   'nunca',
#   'devuelve',
#   'dineros',
#   'llevo',
#   'descuentos',
#   'solo',
#   'mes',
#   'diciembre',
#   'dan',
#   'respuesta',
#   'solo',
#   'interesa',
#   'cobrar'],
#  ['re',
#   'puta',
#   'madre',
#   'didi',
#   'cabify',
#   'saben',
#   'hincha',
#   'ford',
#   'xq',
#   'puede',
#   'ser',
#   'vengan',
#   'siempre',
#   'autos',
#   'chevrolet',
#   'jajajaja',
#   'parece',
#   'joda'],
#  ['cuidando',
#   'medidas',
#   'bioseguridad',
#   'conductores',
#   'obligan',
#   'pasajeros',
#   'subirnos',
#   'adelante',
#   'encima',
#   'groseros',
#   'pésimo',
#   'terribleserviciocabify'],
#  ['existir',
#   'voluntad',
#   'autoridades',
#   'estatales',
#   'municipales',
#   'ningún',
#   'conductor',
#   'uber',
#   'didi',
#   'indriver',
#   'pronto',
#   'cabify',
#   'debería',
#   'llegar',
#   'pasar',
#   'agresiones',
#   'físicas',
#   'parte',
#   'taxistas',
#   'veracruz'],
#  ['basta',
#   'taxis',
#   'remises',
#   'toman',
#   'viaje',
#   'mientras',
#   'viaje',
#   'cuestas',
#   'hacen',
#   'perder',
#   'tiempo',
#   'mal'],
#  ['contestáis',
#   'mejor',
#   'quejas',
#   'servicio',
#   'luego',
#   'si',
#   'contestáis',
#   'buenos',
#   'propósitos',
#   'navidad',
#   'pasada'],
#  ['llegó', 'taxi', 'pudiera', 'pedir', 'cabify', 'salva'],
#  ['gracias', 'cabify'],
#  ['jajajjaajaj', 'denunciar', 'cabify', 'poner', 'cosas', 'fáciles'],
#  ['dios', 'vuelta', 'dan', 'cabify', 'ir', 'buscar', 'alguien'],
#  ['termina',
#   'conversación',
#   'silencio',
#   'rato',
#   'mientras',
#   'vamos',
#   'subiendo',
#   'vm',
#   'llegando',
#   'rancagua',
#   'habla',
#   'taxista',
#   'dice',
#   'gente',
#   'rara',
#   'respondo',
#   'taxista',
#   'continúa',
#   'cachaste',
#   'llamada',
#   'subiste',
#   'mina',
#   'llamó',
#   'app',
#   'cabify'],
#  ['buen',
#   'día',
#   'solo',
#   'recuerdo',
#   'necesario',
#   'poner',
#   'número',
#   'telefónico',
#   'detalle',
#   'llega',
#   'código',
#   'verificación',
#   'espero',
#   'solución'],
#  ['gracias', 'información', 'fiel', 'cabify'],
#  ['cargo',
#   'tarjeta',
#   'día',
#   'hoy',
#   'usado',
#   'servicio',
#   'además',
#   'cobro',
#   'uso',
#   'internacional',
#   'tarjeta',
#   'app',
#   'módulo',
#   'ayuda',
#   'pueden',
#   'explicar',
#   'robo'],
#  ['lado',
#   'responde',
#   'usuarios',
#   'paso',
#   'mismo',
#   'conductores',
#   'exactamente',
#   'misma',
#   'situación',
#   'llego',
#   'tarde',
#   'trabajo',
#   'gracias'],
#  ['vez',
#   'problema',
#   'conductores',
#   'tomo',
#   'viaje',
#   'completando',
#   'vez',
#   'terminando',
#   'vez',
#   'acercarse',
#   'alejo',
#   'cancelar',
#   'pedir',
#   'uber',
#   'si',
#   'necesitan',
#   'detalles',
#   'preguntan'],
#  ['cuáles',
#   'claves',
#   'actuales',
#   'poder',
#   'tomar',
#   'decisiones',
#   'correctas',
#   'crónica',
#   'mesa',
#   'debate',
#   'foro',
#   'financiero',
#   'eje',
#   'moderada',
#   'colíder',
#   'foro',
#   'financiero',
#   'talentosingenero'],
#  ...]

# %% [markdown]
# ### Lemmatize

# %%
texts = stanzaLemma(texts)
texts
# Out:
# Downloading https://raw.githubusercontent.com/stanfordnlp/stanza-resources/master/resources_1.2.0.json: 128kB [00:00, 6.10MB/s]
# 2021-02-11 16:21:48 INFO: Downloading default packages for language: es (Spanish)...
# 2021-02-11 16:21:49 INFO: File exists: /home/alejandro/stanza_resources/es/default.zip.
# 2021-02-11 16:21:53 INFO: Finished downloading models and saved to /home/alejandro/stanza_resources.
# 2021-02-11 16:21:54 INFO: Loading these models for language: es (Spanish):
# =======================
# | Processor | Package |
# -----------------------
# | tokenize  | ancora  |
# | mwt       | ancora  |
# | pos       | ancora  |
# | lemma     | ancora  |
# | depparse  | ancora  |
# | ner       | conll02 |
# =======================
#
# 2021-02-11 16:21:54 INFO: Use device: gpu
# 2021-02-11 16:21:54 INFO: Loading: tokenize
# 2021-02-11 16:21:56 INFO: Loading: mwt
# 2021-02-11 16:21:56 INFO: Loading: pos
# 2021-02-11 16:21:56 INFO: Loading: lemma
# 2021-02-11 16:21:56 INFO: Loading: depparse
# 2021-02-11 16:21:57 INFO: Loading: ner
# 2021-02-11 16:21:58 INFO: Done loading processors!
# [['estimado',
#   'usuario',
#   'según',
#   'dato',
#   'cada',
#   'vtc',
#   'ser',
#   'sancionar',
#   'inspección',
#   'transporte',
#   'sancion',
#   'frecuente',
#   'llevar',
#   'debidamente',
#   'cumplimentado',
#   'hoja',
#   'ruta'],
#  ['putado', 'esperar', 'daño', 'físico', 'ver', 'si', 'suerte'],
#  ['blog',
#   'querer',
#   'saber',
#   'cuál',
#   'ser',
#   'mejor',
#   'campaña',
#   'ser',
#   'marca',
#   'elegido',
#   'ver',
#   'post'],
#  ['luego', 'así', 'hacer', 'cosa'],
#  ['cabify',
#   'ninguno',
#   'coche',
#   'subcontrata',
#   'desear',
#   'suerte',
#   'seguro',
#   'flota',
#   'ley',
#   'suerte'],
#  ['dejar',
#   'tirado',
#   'último',
#   'minuto',
#   'reserva',
#   'hecho',
#   'ayer',
#   'tarde',
#   'tanto',
#   'difícil',
#   'avisar',
#   'cita',
#   'médico',
#   'cancelado',
#   'así'],
#  ['seguro', 'culpable', 'contratado', 'mas', 'profesional', 'planeta'],
#  ['mirar',
#   'condición',
#   'uso',
#   'aceptar',
#   'instalar',
#   'app',
#   'luego',
#   'ver',
#   'abogado',
#   'pregunta',
#   'alguno',
#   'amigo',
#   'explicar',
#   'huevo',
#   'pillar',
#   'último',
#   'pensar',
#   'taxista',
#   'ciudad',
#   'seguro',
#   'muchísimos',
#   'encantar',
#   'servicio'],
#  ['valer', 'grabado', 'si', 'esperar', 'estar', 'bien'],
#  ['seguro'],
#  ['esperar',
#   'suerte',
#   'cada',
#   'elemento',
#   'volante',
#   'además',
#   'lavo',
#   'mano',
#   'mero',
#   'intermediario',
#   'responsabilidad',
#   'recaer',
#   'empresa',
#   'vtc100',
#   'suerte'],
#  ['menos', 'humo', 'bloquear'],
#  ['nunca',
#   'entender',
#   'rechazar',
#   'derecho',
#   'cambio',
#   'coche',
#   'funebre',
#   'botellita',
#   'agua',
#   'cosa',
#   'ser',
#   'moderno',
#   'suponer'],
#  ['aceptar',
#   'termino',
#   'contrato',
#   'descargar',
#   'app',
#   'exoneraste',
#   'todo',
#   'responsabilidad',
#   'leer',
#   'él',
#   'letra',
#   'pequeño',
#   'proximo',
#   'vez',
#   'utilizar',
#   'transporte',
#   'publico',
#   'garantizar',
#   'derecho',
#   'consumidor'],
#  ['namjoon',
#   'esperar',
#   'bondi',
#   'poder',
#   'ser',
#   'ser',
#   'millonario',
#   'hermano',
#   'minimo',
#   'cabify'],
#  ['testigo', 'mucho', 'suerte'],
#  ['ir', 'putado', 'esperar', 'llamado', 'policía', 'testigo'],
#  ['pásatir', 'sede', 'cabify', 'pardillo', 'antiguo', 'sede', 'mundo'],
#  ['ver', 'cabify', 'accidente', 'si', 'cosa', 'tercero'],
#  ['acabar',
#   'tener',
#   'peor',
#   'mal',
#   'viaje',
#   'vida',
#   'todavia',
#   'seguir',
#   'temblar',
#   'pensar',
#   'secuestrar',
#   'cabify'],
#  ['surgir',
#   'duda',
#   'poder',
#   'detener',
#   'tambien',
#   'plataforma',
#   'uber',
#   'didi',
#   'cabify',
#   'mañana',
#   'vera',
#   'si',
#   'ir',
#   'encerio',
#   'simulacion',
#   'mas'],
#  ['datir', 'jodido', 'seguro', 'ver', 'si', 'suerte'],
#  ['si',
#   'necesitar',
#   'salir',
#   'aprovechar',
#   'cupón',
#   'descuento',
#   'viaje',
#   'gratis',
#   'didi',
#   'mxau',
#   'uber',
#   'mefue',
#   'beat',
#   'fkd',
#   'cabify',
#   'lorenac',
#   'bolt',
#   'taxify',
#   'pex',
#   'regalo',
#   'cdmx',
#   'adiós',
#   'felízsemana',
#   'mexico'],
#  ['recién',
#   'venir',
#   'cubrir',
#   'ambulancia',
#   'julio',
#   'san',
#   'lorenzo',
#   'querer',
#   'robar',
#   'fierro',
#   'cabify',
#   'policía',
#   'delincuente',
#   'muerto',
#   'herido',
#   'gravedad',
#   'pepazo',
#   'terminar',
#   'vecinal'],
#  ['nadie',
#   'absolutamente',
#   'nadie',
#   'cabifar',
#   'mañana',
#   'mover',
#   'tú',
#   'quieto'],
#  ['metido', 'tener', 'interés', 'personal'],
#  ['che', 'loco', 'funque', 'hroa', 'pilar', 'onda', 'uber', 'prove', 'cabify'],
#  ['recibido', 'gracias'],
#  ['porsinolovio',
#   'partir',
#   'diciembre',
#   'reducción',
#   'horario',
#   'transporte',
#   'público',
#   'puebla',
#   'incluido',
#   'taxi',
#   'uber',
#   'didi',
#   'cabify'],
#  ['momento', 'dado', 'solución', 'ahora', 'ir', 'cerrar', 'conversación'],
#  ['bajar', 'cabify', 'aire', 'casa', 'horno', 'ventilador'],
#  ['pelota',
#   'importado',
#   'pakistán',
#   'aumento',
#   'nafto',
#   'avisar',
#   'subsidio',
#   'llevar',
#   'dólar',
#   'país',
#   'perdonar'],
#  ['mafia',
#   'taxi',
#   'amarillo',
#   'enquistado',
#   'poner',
#   'precio',
#   'jamás',
#   'utilizar',
#   'taxímetro',
#   'él',
#   'preferir',
#   'uber',
#   'cabify'],
#  ['mandar', 'coso', 'cabify'],
#  ['aquí', 'información'],
#  ['momento',
#   'tanto',
#   'sereno',
#   'pedir',
#   'uber',
#   'cabify',
#   'traffic',
#   'blanco'],
#  ['conductor',
#   'cabify',
#   'subir',
#   'volumen',
#   'radio',
#   'poner',
#   'shakira',
#   'tú',
#   'merecer',
#   'buen',
#   'propina',
#   'señor'],
#  ['taxista',
#   'pelamar',
#   'apps',
#   'ilegal',
#   'manejar',
#   'fondo',
#   'buitre',
#   'ypf',
#   'pagar',
#   'descuento',
#   'viajar',
#   'cabify',
#   'usar',
#   'plata',
#   'cabify',
#   'llevar',
#   'salir',
#   'viaje',
#   'exterior'],
#  ['chofer',
#   'cabify',
#   'dealer',
#   'enterar',
#   'poner',
#   'contestar',
#   'whatsapp',
#   'semáforo',
#   'rojo'],
#  ['si', 'chofer', 'tú', 'checonlar', 'conducir', 'mal'],
#  ['carajar', 'porteño', 'obsesión', 'uber', 'cabify'],
#  ['pagar',
#   'mierdafy',
#   'telemadrid',
#   'ahora',
#   'después',
#   'tanto',
#   'año',
#   'dar',
#   'cuenta',
#   'juntaletro',
#   'telemierdo',
#   'ilegalidad',
#   'mierdafy',
#   'mugre',
#   'pena',
#   'denigrar',
#   'profesión',
#   'periodismo',
#   'normal',
#   'si',
#   'rosauro',
#   'ahora',
#   'consejero',
#   'prisa'],
#  ['único', 'último'],
#  ['pensar',
#   'microcentro',
#   'poder',
#   'haber',
#   'peor',
#   'llegar',
#   'calor',
#   'barbijo',
#   'saber',
#   'fastidioso',
#   'si',
#   'época',
#   'subte',
#   'cabify',
#   'poder',
#   'poner',
#   'aire'],
#  ['ir',
#   'lamentar',
#   'ahora',
#   'rakuten',
#   'meter',
#   'pasta',
#   'dedicar',
#   'hacer',
#   'cargo',
#   'pq',
#   'dato',
#   'bancario',
#   'incauto',
#   'dar',
#   'viaje',
#   'gratis',
#   'mierdafy',
#   'robar',
#   'cliente',
#   'merecer'],
#  ['tardar'],
#  ['buscar', 'testigo', 'pq', 'mierdafy', 'decir', 'lugar', 'accidente'],
#  ['cabify',
#   'venir',
#   'buscar',
#   'trabajo',
#   'mismo',
#   'perfume',
#   'ex',
#   'cada',
#   'dos',
#   'minuto',
#   'malflasho',
#   'mirar',
#   'chequear',
#   'boluuuuuda'],
#  ['dos',
#   'cuadras',
#   'casa',
#   'escribir',
#   'perdido',
#   'barbijo',
#   'decir',
#   'descartable',
#   'dar',
#   'él',
#   'adivinen',
#   'si',
#   'salir',
#   'caro',
#   'cancelar',
#   'él',
#   'viaje'],
#  ['desear',
#   'tomar',
#   'yo',
#   'uber',
#   'cabify',
#   'taxi',
#   'remis',
#   'chofer',
#   'pajero'],
#  ['tanto',
#   'vivo',
#   'conurbano',
#   'tener',
#   'esperar',
#   'dos',
#   'hora',
#   'colectivo',
#   'terminar',
#   'compartir',
#   'cabify',
#   'alguien'],
#  ['ir',
#   'cabify',
#   'conductor',
#   'venir',
#   'oír',
#   'canción',
#   'the',
#   'curar',
#   'poder',
#   'pedir',
#   'vida'],
#  ['pues',
#   'mismo',
#   'historia',
#   'siempre',
#   'todo',
#   'ciudad',
#   'españo',
#   'operar',
#   'empresa',
#   'tributar',
#   'españa',
#   'amparo',
#   'político',
#   'corrupto',
#   'esperar',
#   'alguno',
#   'día',
#   'fiscalía',
#   'anticorrupción',
#   'poner',
#   'mano',
#   'obra',
#   'caer',
#   'careta'],
#  ['ladrón',
#   'esperar',
#   'minuto',
#   'cerca',
#   'ubicación',
#   'cada',
#   'vez',
#   'alejar',
#   'encima',
#   'cobrar',
#   'cancelar',
#   'nunca',
#   'ladrón'],
#  ['actitud',
#   'conductor',
#   'preferir',
#   'alejar',
#   'él',
#   'punto',
#   'carrera',
#   'cancelar',
#   'pésimo',
#   'servicio',
#   'poder',
#   'esperar'],
#  ['cabify',
#   'uber',
#   'cualquiera',
#   'compañía',
#   'transporte',
#   'on',
#   'demand',
#   'solo',
#   'usar',
#   'vez',
#   'mes',
#   'completo',
#   'despropósito'],
#  ['jajajar',
#   'si',
#   'llegar',
#   'cabify',
#   'lurin',
#   'menos',
#   'ir',
#   'llegar',
#   'domingo',
#   'punta',
#   'hermoso'],
#  ['marketing',
#   'bien',
#   'luego',
#   'contar',
#   'creer',
#   'así',
#   'entender',
#   'mejor',
#   'porqué',
#   'funcionar',
#   'así'],
#  ['codigo',
#   'cupón',
#   'rappi',
#   'oxs',
#   'codigo',
#   'cupón',
#   'ubereats',
#   'ln',
#   'codigo',
#   'cupon',
#   'glovo',
#   'lnlfqjl',
#   'codigo',
#   'cupon',
#   'cabify',
#   'ivano',
#   'cupon',
#   'uber',
#   'xaln',
#   'código',
#   'cupon',
#   'rappi',
#   'oxs',
#   'cupón',
#   'didi',
#   'ivan',
#   'cupón',
#   'rappi'],
#  ['cabify', 'pasar', 'trapo'],
#  ['acabar',
#   'tener',
#   'accidente',
#   'conductor',
#   'dado',
#   'fuga',
#   'mano',
#   'policía'],
#  ['llegado'],
#  ['entérate',
#   'taxi',
#   'poder',
#   'prestar',
#   'servicio',
#   'noche',
#   'partir',
#   'mañana'],
#  ['ejemplo',
#   'bajar',
#   'sierra',
#   'uber',
#   'cabify',
#   'solo',
#   'línea',
#   'taxi',
#   'funcionar'],
#  ['gracias', 'acabar', 'enviar', 'texto'],
#  ['consejo',
#   'reviéntal',
#   'mensaje',
#   'app',
#   'hacer',
#   'cargado',
#   'euro',
#   'fraudulento',
#   'ir',
#   'parar',
#   'devolver',
#   'desistir'],
#  ['mitad',
#   'vehículo',
#   'vtir',
#   'controlado',
#   'ser',
#   'denunciado',
#   'trabajar',
#   'incumplir',
#   'alguno',
#   'norma',
#   'inocentado',
#   'base',
#   'negocio',
#   'uber',
#   'cabify',
#   'trabajar',
#   'ilegalidad',
#   'taxienlucho'],
#  ['dedicar',
#   'estafar',
#   'pequeño',
#   'cantidad',
#   'cliente',
#   'pensar',
#   'fecha',
#   'ir',
#   'dar',
#   'cuenta',
#   'cargo',
#   'euro',
#   'directamente',
#   'ir',
#   'preocupar',
#   'denunciar',
#   'él',
#   'pues',
#   'dignidad',
#   'tiempo',
#   'libre'],
#  ['empezar',
#   'contactar',
#   'declarar',
#   'estafado',
#   'denunciar',
#   'conjuntamente',
#   'además',
#   'factura',
#   'taxi',
#   'llevar',
#   'noche',
#   'casa',
#   'seguro',
#   'profesional',
#   'encantado',
#   'testificar',
#   'llevar'],
#  ['factura',
#   'espv',
#   'ns',
#   'llevar',
#   'domingo',
#   'reportar',
#   'incidencia',
#   'ayuda',
#   'cliente',
#   'dedicar',
#   'decir',
#   'yo',
#   'viaje',
#   'realizar',
#   'bien',
#   'cobrar',
#   'reembolsái',
#   'dinero',
#   'mañana',
#   'denunciar',
#   'exigir',
#   'compensación',
#   'daño',
#   'perjuicio'],
#  ['suceso',
#   'reembolsar',
#   'yo',
#   'importe',
#   'imponer',
#   'denuncia',
#   'policía',
#   'fraude',
#   'exigir',
#   'compensación',
#   'daño',
#   'perjuicio',
#   'pensar',
#   'nadie',
#   'ir',
#   'molestar',
#   'denunciar',
#   'dignidad',
#   'ir',
#   'permitir',
#   'rober'],
#  ['imaginar',
#   'cada',
#   'dos',
#   'tienda',
#   'ir',
#   'ilegal',
#   'si',
#   'cada',
#   'dos',
#   'bar',
#   'incumplir',
#   'normativa',
#   'si',
#   'clinica',
#   'ilegal',
#   'loco',
#   'entonces',
#   'normalizar',
#   'vtc'],
#  ['factura',
#   'espv',
#   'ns',
#   'realizado',
#   'cargo',
#   'viaje',
#   'realizado',
#   'solicitar',
#   'conductor',
#   'matheu',
#   'matrícula',
#   'lkj',
#   'validado',
#   'viaje',
#   'realizado',
#   'cargo',
#   'tarjeta',
#   'consentimiento',
#   'servicio',
#   'fraudulento'],
#  ['suceso',
#   'reembolsar',
#   'yo',
#   'importe',
#   'si',
#   'imponer',
#   'denuncia',
#   'policía',
#   'exigir',
#   'compensación',
#   'daño',
#   'perjuicio',
#   'denunciar',
#   'superior',
#   'persona',
#   'at',
#   'cliente',
#   'cabify',
#   'responder',
#   'mensaje',
#   'plantilla',
#   'negar',
#   'ayudar'],
#  ['buen',
#   'empezar',
#   'bardear',
#   'cartonero',
#   'decir',
#   'ahora',
#   'odio',
#   'dio',
#   'onda',
#   'tachero',
#   'facho',
#   'venir',
#   'cabify'],
#  ['cabify', 'tocar', 'hoy', 'full', 'leo', 'mattioli', 'amo'],
#  ['entérate',
#   'servicio',
#   'transporte',
#   'taxi',
#   'ejecutivo',
#   'dar',
#   'servicio',
#   'am',
#   'pm',
#   'así',
#   'anunciar',
#   'subsecretario',
#   'movilidad',
#   'transporte',
#   'yahir',
#   'vázquez'],
#  ['nacional',
#   'obrero',
#   'uber',
#   'didi',
#   'cabify',
#   'economía',
#   'general',
#   'pandemio',
#   'crecer',
#   'salud',
#   'muerto',
#   'aceptado',
#   'aceptado',
#   'médico',
#   'niño',
#   'cancer',
#   'fallecido'],
#  ['odio',
#   'tomar',
#   'yo',
#   'cabify',
#   'sentir',
#   'ir',
#   'terminar',
#   'cualquiera',
#   'lado',
#   'menos',
#   'casa'],
#  ['visto', 'taxi', 'llevar', 'momento', 'bien', 'ahí', 'mensaje', 'positivo'],
#  ['cabify',
#   'caro',
#   'uber',
#   'ahora',
#   'uber',
#   'caro',
#   'cabify',
#   'incluso',
#   'cabify',
#   'vez',
#   'resultar',
#   'económico',
#   'didi',
#   'beat',
#   'cojar',
#   'dato',
#   'chique'],
#  ['pedir', 'cabify', 'mandar'],
#  ['suspender', 'cuenta', 'marido', 'vez', 'aclarar'],
#  ['nadie', 'ir', 'devolver', 'libremente', 'pagado'],
#  ['batería', 'cambiar'],
#  ['pobre',
#   'autobusero',
#   'si',
#   'poner',
#   'conducir',
#   'cualquiera',
#   'vtc',
#   'claro',
#   'pasar',
#   'pasar'],
#  ['si', 'servir', 'datar', 'conductor'],
#  ['mano',
#   'presentar',
#   'campaña',
#   'fin',
#   'año',
#   'hoyenlatinspots',
#   'flasheá',
#   'tranquilo',
#   'compuesto',
#   'spots',
#   'animado',
#   'poder',
#   'ver',
#   'red',
#   'marca',
#   'humorista',
#   'movetesegurar',
#   'movetemejor'],
#  ['hija',
#   'menor',
#   'empresa',
#   'unicenter',
#   'seguir',
#   'hmof',
#   'mayor',
#   'empresa',
#   'frente',
#   'colon',
#   'semana',
#   'medio',
#   'trabajar',
#   'in',
#   'situ',
#   'trasladar',
#   'cabify',
#   'pago',
#   'empresa'],
#  ['demostrar',
#   'nivel',
#   'nivel',
#   'cucaracho',
#   'si',
#   'encima',
#   'comprastar',
#   'estafado',
#   'saber',
#   'podeler',
#   'explicación',
#   'rosauro'],
#  ['aún',
#   'tardar',
#   'saber',
#   'quién',
#   'vender',
#   'división',
#   'investigación',
#   'coche',
#   'autónomo',
#   'seguro',
#   'caso',
#   'accidente',
#   'quién',
#   'culpable',
#   'pastar',
#   'neng'],
#  ['uber', 'cabify', 'obligar', 'bajar', 'precio', 'buen', 'competencia'],
#  ['perfecto',
#   'pues',
#   'vete',
#   'hospital',
#   'delawer',
#   'holando',
#   'paro',
#   'erte',
#   'ere',
#   'pagar',
#   'allí',
#   'jubilación',
#   'tb'],
#  ['pues',
#   'devolver',
#   'el',
#   'administración',
#   'si',
#   'sobrar',
#   'coste',
#   'alguno',
#   'administración',
#   'ciudadano',
#   'pagar',
#   'negocio'],
#  ['trabajador',
#   'tampoco',
#   'búscatar',
#   'cuenta',
#   'presentar',
#   'registro',
#   'mercantil',
#   'tooooodo',
#   'impuesto',
#   'decir',
#   'pagar',
#   'cerrar',
#   'ejercicio',
#   'sl',
#   'compensar',
#   'pérdida',
#   'p/100',
#   'poder',
#   'desgravar',
#   'papel',
#   'higiénico',
#   'pagar'],
#  ['menos',
#   'quedar',
#   'cuca',
#   'pregunta',
#   'conductor',
#   'cuanto',
#   'tiempo',
#   'llevar',
#   'cobrar',
#   'mierdafy',
#   'tb',
#   'pq',
#   'rakuten',
#   'meter',
#   'pasta',
#   'ver',
#   'clavado',
#   'ir',
#   'hacer',
#   'ahora',
#   'año',
#   'engañar',
#   'vender',
#   'autorización',
#   'decir',
#   'licencia'],
#  ['trancar',
#   'sentimiento',
#   'mutuo',
#   'gente',
#   'cuánto',
#   'lejos',
#   'mejor',
#   'ganar',
#   'tx',
#   'salud',
#   'vete',
#   'cuca',
#   'seguro',
#   'si',
#   'comprensible',
#   'defender',
#   'empresa',
#   'mierdaf'],
#  ['noticia',
#   'viejo',
#   'comentar',
#   'aflelolu',
#   'taxista',
#   'familia',
#   'comunicar',
#   'allegado',
#   'osear',
#   'miembro',
#   'cada',
#   'familia',
#   'malo',
#   'publicidad'],
#  ['pues',
#   'hablar',
#   'accidente',
#   'cuco',
#   'twitter',
#   'varios',
#   'página',
#   'mostrar',
#   'montón',
#   'pq',
#   'cuca',
#   'saber',
#   'conducir',
#   'ir',
#   'mirar',
#   'rato',
#   'gps'],
#  ['poco',
#   'vergüenza',
#   'mierdafy',
#   'pagar',
#   'impuesto',
#   'españo',
#   'seguro',
#   'hospital',
#   'delawer',
#   'agradecer',
#   'mejor',
#   'experiencia',
#   'poder',
#   'tener',
#   'sanidad',
#   'público',
#   'gratuito',
#   'españo'],
#  ['dar',
#   'vuelta',
#   'cuco',
#   'hacer',
#   'siempre',
#   'p/100',
#   'guir',
#   'gps',
#   'ir',
#   'saber',
#   'ir',
#   'ninguno',
#   'sitio',
#   'saber',
#   'gps',
#   'casi',
#   'nunca',
#   'ir',
#   'camino',
#   'corto'],
#  ['volver',
#   'mismo',
#   'cobrar',
#   'multa',
#   'cancelación',
#   'viaje',
#   'conductor',
#   'llegar',
#   'dar',
#   'gana'],
#  ['mierdafy',
#   'siempre',
#   'dar',
#   'buen',
#   'servicio',
#   'decir',
#   'creer',
#   'cuanto',
#   'robar',
#   'saber',
#   'mierdafy',
#   'mira',
#   'twitter',
#   'cantidad',
#   'gente',
#   'hacer',
#   'cargo',
#   'tarjeta',
#   'tx',
#   'pedir',
#   'dato',
#   'bancario',
#   'cliente'],
#  ['jajajajaja',
#   'mirar',
#   'foro',
#   'cuánto',
#   'gente',
#   'estafado',
#   'dejar',
#   'si',
#   'contestado',
#   'conductor'],
#  ['ir',
#   'saber',
#   'monopolio',
#   'tx',
#   'autónomo',
#   'solo',
#   'licencia',
#   'precio',
#   'fijado',
#   'hacienda'],
#  ['esclavifly',
#   'mierdafy',
#   'mirar',
#   'foro',
#   'confiable',
#   'cómo',
#   'hacer',
#   'cargo',
#   'tarjeta',
#   'servicio',
#   'prestado',
#   'manía',
#   'defender',
#   'empresa',
#   'mierdafy'],
#  ['mami', 'juqueao'],
#  ['supuesto', 'ver', 'si', 'creer', 'cucaracho', 'dócil', 'menos'],
#  ['cabify',
#   'viajar',
#   'barbijo',
#   'aire',
#   'tope',
#   'enfermero',
#   'adivinen',
#   'si',
#   'ofender',
#   'bajar',
#   'ventana',
#   'negar',
#   'sacar',
#   'yo',
#   'barbijo'],
#  ['revisar', 'veras', 'único', 'pasado', 'cosa', 'peor'],
#  ['llevar', 'cabify', 'valdemingomez', 'micunda'],
#  ['primero',
#   'vez',
#   'lima',
#   'familia',
#   'instalar',
#   'celular',
#   'cabify',
#   'ver',
#   'ir',
#   'contar',
#   'puesto',
#   'pago',
#   'tc',
#   'pues',
#   'viaje',
#   'pagar',
#   'efectivo',
#   'vez',
#   'descontar',
#   'tarjeta',
#   'xd',
#   'quitar',
#   'sol',
#   'semana'],
#  ['holar',
#   'acabar',
#   'cobrar',
#   'hacer',
#   'esperar',
#   'chofer',
#   'minuto',
#   'estacionado',
#   'lado',
#   'mandar',
#   'mensaje',
#   'llamar',
#   'varios',
#   'vez',
#   'gustar',
#   'devolución',
#   'plata',
#   'gracias'],
#  ['pagar',
#   'impuesto',
#   'aqui',
#   'encargar',
#   'administración',
#   'financiar',
#   'sanidad',
#   'caer',
#   'cara',
#   'vergüenza'],
#  ['nono',
#   'epic',
#   'bien',
#   'comprar',
#   'pavo',
#   'aparecer',
#   'cabify',
#   'compra',
#   'automatico'],
#  ['abajo',
#   'cabify',
#   'decir',
#   'pago',
#   'automatico',
#   'tener',
#   'ser',
#   'si',
#   'si'],
#  ['apretar',
#   'tuerca',
#   'andar',
#   'pago',
#   'aparecer',
#   'cosa',
#   'cabify',
#   'desactivo'],
#  ['raro',
#   'igual',
#   'solo',
#   'retener',
#   'pasado',
#   'encima',
#   'pagar',
#   'servicio',
#   'prestado'],
#  ['surrealista',
#   'poder',
#   'haber',
#   'cabify',
#   'ver',
#   'figura',
#   'aviso',
#   'retención',
#   'llegar',
#   'ver',
#   'descontado',
#   'así',
#   'suponer',
#   'debitar',
#   'final',
#   'saber',
#   'aviso',
#   'débito',
#   'llegar',
#   'raro'],
#  ['totalmente',
#   'seguro',
#   'hecho',
#   'verdadero',
#   'esfuerzo',
#   'empatizar',
#   'deber',
#   'haber',
#   'ser',
#   'revés',
#   'alucinante',
#   'contar',
#   'cosa',
#   'allá',
#   'leer',
#   'él',
#   'seguir',
#   'parecer',
#   'surrealista',
#   'esperar',
#   'solucionar'],
#  ['gracias', 'referencia'],
#  ['necesitar',
#   'ayuda',
#   'contactar',
#   'chofer',
#   'enviar',
#   'casa',
#   'hacer',
#   'yo',
#   'estafa'],
#  ['realizar',
#   'llamar',
#   'retención',
#   'tarjeta',
#   'crédito',
#   'poco',
#   'palabra',
#   'cobrar',
#   'valor',
#   'tarjeta',
#   'crédito',
#   'explicar',
#   'motivo',
#   'cobro',
#   'hacer',
#   'inmediatamente',
#   'devolución',
#   'ir',
#   'día',
#   'failcabify'],
#  ['demostraí',
#   'miseria',
#   'empresa',
#   'aún',
#   'esperar',
#   'tribute',
#   'españa',
#   'delaware',
#   'holando',
#   'bien',
#   'quedar',
#   'impuesto',
#   'aportar',
#   'ir',
#   'margen',
#   'ley',
#   'encima',
#   'utilizar',
#   'pobre',
#   'niño'],
#  ['medio',
#   'hora',
#   'esperar',
#   'ver',
#   'alejar',
#   'auto',
#   'cambiar',
#   'auto',
#   'tiempo',
#   'perdido'],
#  ['seguir',
#   'esperar',
#   'cabify',
#   'hazlo',
#   'saber',
#   'conductor',
#   'regalar',
#   'botella',
#   'agua',
#   'feliznavidad'],
#  ['jurar',
#   'pensar',
#   'inocentada',
#   'noticia',
#   'diciembre',
#   'además',
#   'según',
#   'mayoría',
#   'gasto',
#   'ser',
#   'aumentar',
#   'inversión',
#   'red',
#   'ciclable',
#   'poquito',
#   'pedalada',
#   'pedalada'],
#  ['imagino',
#   'infierno',
#   'vivido',
#   'costar',
#   'encargar',
#   'él',
#   'cabify',
#   'cancelar',
#   'viaje',
#   'debitado',
#   'tarjeta',
#   'reclamar',
#   'si',
#   'tiempo',
#   'hacerlo'],
#  ['holar',
#   'intentar',
#   'registrar',
#   'yo',
#   'través',
#   'correo',
#   'empresarial',
#   'llegar',
#   'correo',
#   'dígito',
#   'correo',
#   'bien',
#   'escrito',
#   'revisar',
#   'todo',
#   'bandeja',
#   'correo'],
#  ['vtc',
#   'ver',
#   'meter',
#   'carril',
#   'mirar',
#   'tlf',
#   'saber',
#   'dónde',
#   'ir',
#   'entrar',
#   'servicio'],
#  ['indicar',
#   'él',
#   'cuál',
#   'izquierda',
#   'derecho',
#   'chófer',
#   'cabify',
#   'agradar',
#   'mondayvib'],
#  ['teo', 'viajar', 'cabify'],
#  ['inútil', 'sacar', 'favor', 'carente', 'mínimo', 'conocimiento', 'ciudad'],
#  ['luca', 'cabify', 'tarjeta', 'cancela', 'walter', 'borracho', 'remis'],
#  ['todxs',
#   'recomendar',
#   'veterinaria',
#   'excelente',
#   'kms',
#   'casa',
#   'díganmar',
#   'cómo',
#   'hacer',
#   'emergencia',
#   'si',
#   'viajar',
#   'hr',
#   'cómo',
#   'hacer',
#   'ir',
#   'volver',
#   'coche',
#   'vivo',
#   'zona',
#   'uber',
#   'cabify',
#   'cancelar',
#   'viaje',
#   'remiserío',
#   'pena',
#   'coche'],
#  ['vivir',
#   'pesadilla',
#   'ayer',
#   'vivo',
#   'zona',
#   'buen',
#   'veterinario',
#   'coche',
#   'depender',
#   'remis',
#   'cabify',
#   'viajar',
#   'suplicio',
#   'anoche',
#   'pasar',
#   'buscar',
#   'coche',
#   'coche',
#   'imaginar',
#   'depender',
#   'ir',
#   'venir'],
#  ['fiat',
#   'tipo',
#   'hacer',
#   'sospechar',
#   'aún',
#   'así',
#   'preguntar',
#   'especialista',
#   'hostia',
#   'imposible',
#   'ñiñiñiñi'],
#  ['factura',
#   'espv',
#   'ns',
#   'realizado',
#   'cargo',
#   'viaje',
#   'realizado',
#   'solicitar',
#   'conductor',
#   'matheu',
#   'matrícula',
#   'lkj',
#   'validado',
#   'viaje',
#   'consentimiento',
#   'realizado',
#   'cargo',
#   'tarjeta',
#   'consentimiento',
#   'servicio',
#   'solicitar'],
#  ['preguntalar',
#   'alberto',
#   'seguir',
#   'permitir',
#   'fuga',
#   'divisa',
#   'empresa',
#   'pirata',
#   'evasor',
#   'uber',
#   'cabify',
#   'etcétera',
#   'tambien',
#   'dólar',
#   'joda'],
#  ['sufrido', 'accidente', 'tráfico', 'ocupante', 'uber', 'cabify', 'seguro'],
#  ['pedir', 'cabify', 'llegar', 'barraca', 'creer', 'llegar', 'hora'],
#  ['chofer',
#   'cabify',
#   'escuchar',
#   'porno',
#   'mientras',
#   'conducir',
#   'sonar',
#   'novaresio',
#   'felar',
#   'ministro',
#   'salvarezza',
#   'gagging',
#   'mundicia'],
#  ['amazon',
#   'global',
#   'optimismar',
#   'anunciado',
#   'boom',
#   'supersonic',
#   'cabify',
#   'jetblue',
#   'rivian',
#   'uber',
#   'unido',
#   'the',
#   'climate',
#   'pledge',
#   'compromiso',
#   'alcanzar',
#   'neutralidad',
#   'emisión',
#   'carbono'],
#  ['bugear',
#   'cabify',
#   'hacer',
#   'veinte',
#   'minuto',
#   'mismo',
#   'lugar',
#   'chofer',
#   'si',
#   'necesitar',
#   'ayuda',
#   'pestañear',
#   'dos',
#   'vez'],
#  ['bien',
#   'cabify',
#   'bien',
#   'ahora',
#   'hacer',
#   'mismo',
#   'demás',
#   'coche',
#   'ir',
#   'carajo',
#   'rato'],
#  ['ser',
#   'conductor',
#   'cabify',
#   'vtc',
#   'nunca',
#   'quedar',
#   'perdido',
#   'tiempo',
#   'dinero',
#   'devolver',
#   'él',
#   'vez',
#   'complicado',
#   'conseguir',
#   'conductor',
#   'mismo',
#   'empresa',
#   'generalmente',
#   'mandar',
#   'correo',
#   'dato',
#   'viaje',
#   'ahí',
#   'salir',
#   'nombre'],
#  ['tods',
#   'vez',
#   'venir',
#   'vacuna',
#   'llegar',
#   'hora',
#   'mas',
#   'tarde',
#   'cabify',
#   'hoy',
#   'medio',
#   'hora',
#   'nunca',
#   'punto',
#   'medio'],
#  ['hacer',
#   'casi',
#   'dos',
#   'hora',
#   'buscar',
#   'cabify',
#   'hablar',
#   'jefe',
#   'contestar',
#   'sticker',
#   'bernardo',
#   'decir',
#   'palabra'],
#  ['primero',
#   'viaje',
#   'gratis',
#   'didi',
#   'argentino',
#   'aplicación',
#   'cabify',
#   'uber',
#   'beat',
#   'ingresar',
#   'código',
#   'martina',
#   'ahora',
#   'activar',
#   'viaje'],
#  ['tampoco',
#   'molar',
#   'hacer',
#   'guiño',
#   'empresa',
#   'cabify',
#   'venir',
#   'personaje',
#   'interpretar',
#   'político',
#   'cargo',
#   'público',
#   'deber',
#   'utilizar',
#   'transporte',
#   'público',
#   'oficial'],
#  ['incomprendido'],
#  ['ummar', 'beso', 'tanto', 'delicioso', 'jijiji'],
#  ['cabify',
#   'uber',
#   'disparar',
#   'incorporación',
#   'taxista',
#   'realidad',
#   'querer',
#   'ver',
#   'taxista',
#   'grande',
#   'plataforma',
#   'muerto',
#   'gustar',
#   'gustar',
#   'usuario',
#   'preferir',
#   'través'],
#  ['taxienlucha',
#   'mejorentaxi',
#   'quejasvtc',
#   'eltaxiunido',
#   'eligetaxi',
#   'hacer',
#   'momento',
#   'glorieta',
#   'estación',
#   'santo',
#   'justo',
#   'sevilla',
#   'parecer',
#   'vtcho',
#   'directo',
#   'autobús'],
#  ['motor', 'eléctrico', 'llevar', 'inventado', 'año'],
#  ['coche',
#   'autónomo',
#   'inventado',
#   'hacer',
#   'año',
#   'seguir',
#   'resolver',
#   'mismo',
#   'problema',
#   'hacer',
#   'año'],
#  ['aquí', 'ejemplo', 'cualquiera', 'cosa', 'ganar', 'hora'],
#  ['elite',
#   'informar',
#   'llegado',
#   'acuerdo',
#   'multinacional',
#   'americana',
#   'hacer',
#   'traslado',
#   'cliente',
#   'helicóptero',
#   'asi',
#   'poder',
#   'combatir',
#   'uber',
#   'cabify',
#   'seguir',
#   'informar'],
#  ['lindo', 'uber', 'cabify', 'hablar', 'hora', 'mañana'],
#  ['chica',
#   'perder',
#   'mochila',
#   'todo',
#   'cosa',
#   'ver',
#   'desesperado',
#   'decir',
#   'gilipollez',
#   'taxi',
#   'cabify',
#   'querer',
#   'hacer',
#   'hacer',
#   'llegar',
#   'mensaje',
#   'lejos',
#   'pedir',
#   'dejar',
#   'metero',
#   'cosa',
#   'importar',
#   'gente'],
#  ['orgullo'],
#  ['clienteenisa',
#   'reinventar',
#   'lograr',
#   'acuerdo',
#   'alain',
#   'afflelou',
#   'transportar',
#   'gratis',
#   'cliente',
#   'audiología',
#   'vía'],
#  ['diu',
#   'torne',
#   'lloc',
#   'si',
#   'et',
#   'rober',
#   'però',
#   'bé',
#   'tornat',
#   'saber',
#   'rick',
#   'parecer',
#   'falso',
#   'bolsa',
#   'patata'],
#  ['imaginar',
#   'contactado',
#   'cabify',
#   'si',
#   'saber',
#   'suger',
#   'colgar',
#   'alguno',
#   'cartelito',
#   'zona',
#   'poder',
#   'encontrar',
#   'alguien',
#   'red',
#   'grupo',
#   'face',
#   'barrio',
#   'normalmente',
#   'grupo',
#   'objeto',
#   'perdido',
#   'suerte'],
#  ['pasar',
#   'frecuencia',
#   'uber',
#   'beat',
#   'cabify',
#   'favor',
#   'harto',
#   'salir',
#   'saber',
#   'cuánto',
#   'tiempo',
#   'ir',
#   'tardar',
#   'esperar'],
#  ['miguel',
#   'bien',
#   'emocionar',
#   'él',
#   'vez',
#   'emoción',
#   'sentir',
#   'él',
#   'diario',
#   'suscríbete',
#   'plan',
#   'propio',
#   'bici',
#   'pedigrí',
#   'poder',
#   'hacer',
#   'foto',
#   'día'],
#  ['ira',
#   'mismo',
#   'conductor',
#   'trabajar',
#   'ambos',
#   'app',
#   'simultáneamente',
#   'problema',
#   'administración',
#   'exigir',
#   'requisito',
#   'acceso',
#   'vtc'],
#  ['acabar',
#   'ver',
#   'cheems',
#   'publicidad',
#   'cabify',
#   'mierda',
#   'partir',
#   'hoy',
#   'solo',
#   'uso',
#   'uber'],
#  ['oír',
#   'hora',
#   'toque',
#   'quedar',
#   'si',
#   'metro',
#   'micro',
#   'post',
#   'funcionar',
#   'uber',
#   'cabify'],
#  ['mal',
#   'hacer',
#   'volver',
#   'ebrio',
#   'manija',
#   'casa',
#   'aparte',
#   'alto',
#   'demanda',
#   'cabify'],
#  ['estimado',
#   'llevar',
#   'mes',
#   'hacer',
#   'seguimiento',
#   'objeto',
#   'enviado',
#   'conductor',
#   'comprometer',
#   'entregar',
#   'nunca',
#   'llegar',
#   'escribir',
#   'aplicación',
#   'inconveniente',
#   'acercar',
#   'oficina',
#   'increíble',
#   'poder',
#   'dar',
#   'yo',
#   'solución'],
#  ['mandar',
#   'cabify',
#   'casa',
#   'llevar',
#   'hospital',
#   'militar',
#   'vez',
#   'hospital',
#   'dar',
#   'barbijo',
#   'nuevo',
#   'bolsa',
#   'cosa',
#   'picar',
#   'arrancar',
#   'entrevista',
#   'medoco',
#   'explicar',
#   'riesgo',
#   'procedimiento',
#   'acá',
#   'adelante',
#   'año',
#   'control'],
#  ['permitir',
#   'evasión',
#   'fuga',
#   'divisa',
#   'empresa',
#   'pirata',
#   'uber',
#   'cabify',
#   'rappi',
#   'glovo',
#   'contexto',
#   'país',
#   'vivir',
#   'poder',
#   'ir',
#   'solo',
#   'dólar',
#   'alberto',
#   'mira',
#   'costar'],
#  ['esperar', 'respuesta', 'pronto', 'pasado', 'mas', 'día'],
#  ['preguntastar',
#   'alberto',
#   'seguir',
#   'permitir',
#   'evasión',
#   'fuga',
#   'divisa',
#   'empresa',
#   'pirata',
#   'uber',
#   'cabify',
#   'rapi',
#   'glovo',
#   'etcétera',
#   'mismo',
#   'prometer',
#   'campaña',
#   'acabar',
#   'uberizacion',
#   'economía',
#   'ser',
#   'periodista',
#   'opereta'],
#  ['lamentar',
#   'sinceramente',
#   'publicidad',
#   'confuso',
#   'trabajar',
#   'mejorar',
#   'anuncio'],
#  ['ver',
#   'concha',
#   'madre',
#   'buen',
#   'ahí',
#   'tener',
#   'ir',
#   'fijate',
#   'cabify',
#   'barato',
#   'uber',
#   'pelotudo'],
#  ['fisicaoquimicaelreencuentro',
#   'cova',
#   'mucho',
#   'lucha',
#   'activismo',
#   'historia',
#   'luego',
#   'cabify',
#   'ola',
#   'asar'],
#  ['cabify', 'ir', 'escuchar', 'nirvano'],
#  ['cabify', 'venir', 'escuchar', 'uno', 'balada', 'domingo', 'hs', 'balazo'],
#  ['conductor',
#   'dejar',
#   'tirado',
#   'querer',
#   'cancelar',
#   'viaje',
#   'irme',
#   'caminar',
#   'frío',
#   'esperar',
#   'despedir',
#   'luego',
#   'uber',
#   'desfachatez',
#   'cobrar',
#   'yo',
#   'adiós',
#   'uber',
#   'hola'],
#  ['autito',
#   'cabify',
#   'partido',
#   'river',
#   'flasheé',
#   'howard',
#   'mars',
#   'rover'],
#  ['vergüenza', 'autito', 'cabify', 'si', 'ir', 'decir', 'fin', 'semana'],
#  ['cómo', 'violento', 'autito', 'cabify', 'hermano'],
#  ['holar',
#   'conocer',
#   'varixs',
#   'conductor',
#   'cabi',
#   'pasado',
#   'mochila',
#   'si',
#   'decir',
#   'aviso',
#   'suponer',
#   'haber',
#   'poner',
#   'contacto',
#   'cabify',
#   'suerte'],
#  ['atención',
#   'usuario',
#   'rideapp',
#   'didiargentino',
#   'confundir',
#   'promo',
#   'off',
#   'próximo',
#   'viaje',
#   'sólo',
#   'aplicar',
#   'siguiente',
#   'viaje',
#   'cómo',
#   'diseñar',
#   'comunicar',
#   'claridad',
#   'descuento',
#   'marketing'],
#  ['buen',
#   'tuits',
#   'cabify',
#   'borrado',
#   'acáo',
#   'asustar',
#   'viejo',
#   'cabreado',
#   'extraño'],
#  ['chavala',
#   'perder',
#   'mochila',
#   'cosa',
#   'importante',
#   'dentro',
#   'después',
#   'subir',
#   'cabify',
#   'cantidad',
#   'ingente',
#   'gilipolla',
#   'ir',
#   'poner',
#   'él',
#   'tuits',
#   'joda',
#   'próximo',
#   'vez',
#   'cojo',
#   'taxi',
#   'gente',
#   'malo',
#   'eh'],
#  ['abrir',
#   'melón',
#   'incluir',
#   'yo',
#   'grupo',
#   'llevar',
#   'entrar',
#   'umo',
#   'ser',
#   'conductor',
#   'cabify',
#   'medio',
#   'facultad'],
#  ['buen',
#   'tarde',
#   'estar',
#   'disculpar',
#   'molestia',
#   'coferencio',
#   'nunca',
#   'mencionar',
#   'plataforma',
#   'taxi',
#   'uber',
#   'indriver',
#   'cabify',
#   'poder',
#   'trabajar',
#   'dia',
#   'enero',
#   'saber',
#   'informar',
#   'esperar',
#   'respuesta',
#   'gracias'],
#  ['casi',
#   'así',
#   'médico',
#   'entrar',
#   'trabajar',
#   'sanidad',
#   'mayoría',
#   'ccaa',
#   'ganar',
#   'chofer',
#   'cabify',
#   'base',
#   'propino',
#   'mes',
#   'querer',
#   'hacer',
#   'creer',
#   'ganar',
#   'mes',
#   'limpio',
#   'insolidaridad'],
#  ['decir',
#   'buscar',
#   'cambio',
#   'único',
#   'saber',
#   'hacer',
#   'quejar',
#   'él',
#   'romper',
#   'cabifys',
#   'pegar',
#   'él',
#   'chofer'],
#  ['comments',
#   'decir',
#   'jajaja',
#   'chulería',
#   'taxista',
#   'pisais',
#   'jajaja',
#   'así',
#   'ir'],
#  ['si', 'mucho', 'gracias', 'buscar', 'google', 'llamar', 'taxi'],
#  ['jajajar',
#   'pastar',
#   'decir',
#   'luego',
#   'bloquea',
#   'si',
#   'piel',
#   'tanto',
#   'fino',
#   'ir',
#   'reclamar',
#   'derecho',
#   'cuanto',
#   'decir',
#   'cuatro',
#   'verdad',
#   'ofendei',
#   'coje',
#   'pataleta',
#   'normal',
#   'defender',
#   'mierdafy',
#   'mugre',
#   'merecer'],
#  ['aún',
#   'existir',
#   'beat',
#   'empezar',
#   'semáforo',
#   'rojo',
#   'querer',
#   'auto',
#   'cerca',
#   'navidad',
#   'buscar',
#   'uber',
#   'didi',
#   'todavía',
#   'existir',
#   'cabify',
#   'opción'],
#  ['ir',
#   'denunciar',
#   'decir',
#   'montar',
#   'taxi',
#   'cabify',
#   'posiblemente',
#   'taxista',
#   'todavía',
#   'mochilar',
#   'ánimo',
#   'suerte'],
#  ['abrazo',
#   'dormir',
#   'gustar',
#   'ahogar',
#   'él',
#   'labio',
#   'desquitar',
#   'él',
#   'manera',
#   'menos',
#   'delicado',
#   'ambos',
#   'desear',
#   'entregar',
#   'él',
#   'necesitar',
#   'pensar',
#   'necesitar',
#   'saborear',
#   'él',
#   'luna',
#   'posso',
#   'ordinar',
#   'cabify'],
#  ['tampoco',
#   'entender',
#   'único',
#   'ocurrir',
#   'poder',
#   'diferenciar',
#   'ubers',
#   'cabify',
#   'entonces',
#   'tocar',
#   'colaborar'],
#  ['asi',
#   'lento',
#   'ver',
#   'entrar',
#   'cancha',
#   'pelota',
#   'auto',
#   'cabify',
#   'mas',
#   'rápido',
#   'cardona'],
#  ['ke',
#   'pagar',
#   'cabify',
#   'ke',
#   'ir',
#   'casa',
#   'ke',
#   'mimee',
#   'goxear',
#   'regla',
#   'ess',
#   'mas',
#   'bonito',
#   'hechoo',
#   'mess'],
#  ['vetar', 'pastar', 'andar', 'enfermo'],
#  ['chabon',
#   'cabify',
#   'segundo',
#   'cualquiera',
#   'momento',
#   'dar',
#   'bife',
#   'pelado',
#   'cerrar',
#   'orto'],
#  ['publicidad',
#   'cabify',
#   'decir',
#   'viajar',
#   'legal',
#   'seguro',
#   'pasar',
#   'pija',
#   'cara',
#   'uber',
#   'jajajahs'],
#  ['autito', 'cabify', 'aparecer'],
#  ['cabify', 'chollo'],
#  ['insulto', 'descripción', 'saber', 'si', 'saber', 'diferencia'],
#  ['gracias', 'quedar', 'tranquilo'],
#  ['hacer', 'bien', 'vete', 'bici', 'mejor', 'cardio'],
#  ['olor', 'cabify', 'siempre', 'ir', 'recordar', 'mismo', 'trayecto'],
#  ['criado', 'hermana', 'osear', 'mujer', 'entender', 'bastante'],
#  ['defender',
#   'ganar',
#   'si',
#   'compañero',
#   'compañera',
#   'tx',
#   'si',
#   'parecer',
#   'actuar',
#   'caballero',
#   'pues',
#   'gracias',
#   'hoy',
#   'día',
#   'perder',
#   'buen',
#   'costumbre',
#   'educación',
#   'si',
#   'saber',
#   'diferenciar',
#   'respecto',
#   'machismo',
#   'normal',
#   'poner',
#   'poner'],
#  ['aquí',
#   'faltar',
#   'falta',
#   'llamar',
#   'yo',
#   'corto',
#   'imbécil',
#   'integral',
#   'vete',
#   'pastar',
#   'andar'],
#  ['ir', 'pinza'],
#  ['hecho', 'acuerdo'],
#  ['buen',
#   'explicar',
#   'dos',
#   'funcionar',
#   'mundo',
#   'ninguno',
#   'mujer',
#   'necesitar',
#   'venir',
#   'tío',
#   'dorado',
#   'armadura',
#   'defender',
#   'el',
#   'twitter',
#   'buen',
#   'casi',
#   'ninguno',
#   'upgrad',
#   'siglo',
#   'xxi'],
#  ['what',
#   'pelear',
#   'dos',
#   'random',
#   'puto',
#   'tema',
#   'idioma',
#   'dar',
#   'igual',
#   'trol',
#   'sólo',
#   'decir',
#   'cada',
#   'persona',
#   'hablar',
#   'idioma',
#   'mejor',
#   'parecer',
#   'así',
#   'comunicar',
#   'mejor',
#   'escribir',
#   'alemán',
#   'aquel',
#   'cerrar',
#   'círculo'],
#  ['estudiante',
#   'perder',
#   'mochila',
#   'creer',
#   'perfil',
#   'twitter',
#   'intentar',
#   'recuperar',
#   'el',
#   'anormal',
#   'vez',
#   'ayudar',
#   'echar',
#   'cara',
#   'estudiar',
#   'cataluña',
#   'color',
#   'mochila',
#   'haber',
#   'coger',
#   'cabify',
#   'vez',
#   'taxi',
#   'si',
#   'recuar',
#   'tonto',
#   'ayudadlo'],
#  ['contar', 'dar', 'igual', 'cabify', 'uber', 'easy', 'freenow', 'ir', 'bici'],
#  ['app',
#   'malo',
#   'práctica',
#   'usuario',
#   'pasajero',
#   'comerciante',
#   'necesitar',
#   'interesar',
#   'trabajar',
#   'uber',
#   'uso',
#   'poco',
#   'vez',
#   'intentar',
#   'estafado',
#   'carrera',
#   'devolución',
#   'pagado',
#   'uso',
#   'solo',
#   'cabify'],
#  ['entonces',
#   'p/100',
#   'defender',
#   'explicar',
#   'salta',
#   'incongruencia',
#   'compañera'],
#  ['seguid',
#   'adelante',
#   'taxi',
#   'juan',
#   'total',
#   'uso',
#   'cabify',
#   'hablar',
#   'catalá'],
#  ['decir',
#   'aclarar',
#   'gente',
#   'funcionar',
#   'mierdafy',
#   'mugre',
#   'familia',
#   'bien',
#   'gracias',
#   'pasatiempo',
#   'iluminar',
#   'gente',
#   'minusvalia',
#   'cognitivo',
#   'cosa',
#   'realidad',
#   'confundir',
#   'ser',
#   'conocimiento',
#   'realidad'],
#  ['señor', 'juan', 'ir', 'atender', 'familia'],
#  ['mujer',
#   'depender',
#   'fino',
#   'piel',
#   'aguantar',
#   'carro',
#   'carreto',
#   'defender',
#   'indefendible',
#   'ir',
#   'insulto',
#   'descripción'],
#  ['nerd', 'horrible', 'sentir', 'mega', 'insultado'],
#  ['si', 'querer', 'esclavo', 'saber', 'llamar', 'mierdafy', 'disfrutar'],
#  ['traer',
#   'mierdafy',
#   'mejorar',
#   'transporte',
#   'persona',
#   'punto',
#   'punto',
#   'ir',
#   'cada',
#   'comentario',
#   'quedar',
#   'claro',
#   'cucaracha'],
#  ['suerte',
#   'año',
#   'cuco',
#   'quiebra',
#   'pregunta',
#   'mierdafy',
#   'pq',
#   'rakuten',
#   'dar',
#   'pasta'],
#  ['che',
#   'pive',
#   'tú',
#   'si',
#   'hacer',
#   'falta',
#   'adaptación',
#   'dicho',
#   'disfrutar',
#   'cucaracho',
#   'cliente',
#   'tx',
#   'creer',
#   'españa',
#   'cosa',
#   'hacer',
#   'argentino'],
#  ['cobrar',
#   'dos',
#   'vez',
#   'nunca',
#   'tomar',
#   'auto',
#   'necesitar',
#   'devolución',
#   'dinero'],
#  ['jajajajaja', 'nerd', 'despectivo'],
#  ['falso',
#   'conductor',
#   'taxi',
#   'poder',
#   'robar',
#   'ser',
#   'humano',
#   'conductor',
#   'cabify',
#   'empresa',
#   'trabajador',
#   'dejar',
#   'criminalizar',
#   'trabajador',
#   'cager',
#   'ir'],
#  ['ok',
#   'poder',
#   'decir',
#   'adaptar',
#   'dia',
#   'hoy',
#   'nadie',
#   'preguntado',
#   'mismo',
#   'dicho',
#   'concreto'],
#  ['spot',
#   'cabify',
#   'sponsor',
#   'bover',
#   'decir',
#   'casualidad',
#   'primero',
#   'final',
#   'ser',
#   'canchita',
#   'asfalto',
#   'porteño',
#   'poder',
#   'llenar',
#   'formulario',
#   'vacunarte'],
#  ['decir', 'abierto', 'hs', 'cabify', 'llevar', 'animal', 'avísame', 'pedir'],
#  ['suerte', 'ir', 'camino', 'desaparecer', 'si', 'adaptar', 'mundo', 'actual'],
#  ['llamar',
#   'teléfono',
#   'ninguno',
#   'momento',
#   'decir',
#   'salir',
#   'calle',
#   'demora',
#   'minuto',
#   'asegurar'],
#  ['señor', 'cabify', 'humor', 'hablar', 'insistir'],
#  ['primero', 'viaje', 'descuento', 'cabify', 'código', 'lucilac'],
#  ['didi',
#   'app',
#   'cabify',
#   'uber',
#   'descuento',
#   'primero',
#   'viaje',
#   'código',
#   'lucilo'],
#  ['evidentemente',
#   'si',
#   'salir',
#   'calle',
#   'hora',
#   'difícilmente',
#   'encontrar',
#   'hacer',
#   'cuanto',
#   'año',
#   'taxi',
#   'poder',
#   'solicitar',
#   'teléfono',
#   'web',
#   'app',
#   'hecho',
#   'presente',
#   'ciudad',
#   'españo'],
#  ['válido',
#   'primero',
#   'pedido',
#   'si',
#   'tener',
#   'cuenta',
#   'create',
#   'nuevo',
#   'número',
#   'alguno',
#   'familiar',
#   'amigo',
#   'usar',
#   'código'],
#  ['codigar',
#   'rappi',
#   'pedir',
#   'tú',
#   'querer',
#   'envío',
#   'gratis',
#   'código',
#   'santiagof'],
#  ['si',
#   'decir',
#   'forrest',
#   'gump',
#   'posible',
#   'interpretación',
#   'función',
#   'contexto'],
#  ['comprar',
#   'autorización',
#   'pensar',
#   'comprar',
#   'licencia',
#   'hacer',
#   'cliente',
#   'cargo',
#   'tarjeta',
#   'tx',
#   'intrusismo',
#   'laboral',
#   'evadir',
#   'impuesto',
#   'delawer',
#   'holanda',
#   'estafa',
#   'referir',
#   'p/100',
#   'lista',
#   'continuo'],
#  ['pues',
#   'especifecar',
#   'lamer',
#   'varios',
#   'traducción',
#   'depender',
#   'contexto',
#   'neng',
#   'mu',
#   'cortito'],
#  ['estafa'],
#  ['uber', 'cabify'],
#  ['pronto', 'cabify', 'salir', 'menos', 'saludo'],
#  ['si',
#   'problema',
#   'hablar',
#   'ganar',
#   'decir',
#   'luz',
#   'pq',
#   'defender',
#   'mierdafy',
#   'mugre',
#   'cucaracho'],
#  ['ubers', 'cabify', 'remis', 'jajajajaja'],
#  ['esperar',
#   'puesto',
#   'denuncia',
#   'si',
#   'asi',
#   'esperar',
#   'dar',
#   'dato',
#   'conductor',
#   'cabify',
#   'llevar'],
#  ['persona',
#   'buscar',
#   'mochila',
#   'arriesar',
#   'contratar',
#   'empresa',
#   'cubrir',
#   'tributa',
#   'aquí',
#   'explotar',
#   'trabajador',
#   'parecer',
#   'genial',
#   'hablar',
#   'catalán',
#   'toler',
#   'falta',
#   'educación',
#   'idioma',
#   'precisamente'],
#  ['nunca',
#   'reclamado',
#   'dia',
#   'hoy',
#   'idea',
#   'derecho',
#   'obligación',
#   'solo',
#   'subiro',
#   'taxi',
#   'app',
#   'deber',
#   'aceptar',
#   'todo',
#   'condición',
#   'si',
#   'holeer',
#   'mal',
#   'baja',
#   'pagar',
#   'vol',
#   'radio',
#   'elección',
#   'dial',
#   'apagado',
#   'recorrido',
#   'elección'],
#  ['contestado',
#   'hora',
#   'tx',
#   'sobrar',
#   'si',
#   'querer',
#   'esclavo',
#   'vete',
#   'mierdafy'],
#  ['creer',
#   'viaje',
#   'mierdafy',
#   'mal',
#   'decir',
#   'andar',
#   'vete',
#   'paseo',
#   'mirar',
#   'foro',
#   'internet',
#   'si',
#   'conductor',
#   'quejar',
#   'p/100',
#   'cobrar',
#   'erte',
#   'ere',
#   'paro',
#   'cuento',
#   'seguro',
#   'cuca'],
#  ['todo',
#   'querer',
#   'alguien',
#   'defender',
#   'mierdafy',
#   'pq',
#   'seguro',
#   'cucaracho',
#   'dado',
#   'cuenta',
#   'tomado',
#   'ir',
#   'palmar',
#   'pasta',
#   'cuca',
#   'vender'],
#  ['mejor',
#   'sentencia',
#   'condenatorio',
#   'mierdafy',
#   'mugre',
#   'político',
#   'mierda',
#   'permitido',
#   'aberración',
#   'cierto',
#   'meter',
#   'pasta',
#   'rakuten',
#   'ver',
#   'ir',
#   'cobrar',
#   'ahora',
#   'dinamica'],
#  ['trancar',
#   'cliente',
#   'tampoco',
#   'querer',
#   'saber',
#   'ganar',
#   'tranquilidad',
#   'mientras',
#   'amargo',
#   'vida',
#   'cucaracha',
#   'si',
#   'querer',
#   'esclavo',
#   'saber',
#   'mierdafy',
#   'mugre'],
#  ['criticar',
#   'casi',
#   'viaje',
#   'fallar',
#   'si',
#   'usuario',
#   'taxi',
#   'quejar',
#   'olor',
#   'música',
#   'alto',
#   'malo',
#   'contestación',
#   'recorrido',
#   'largo',
#   'cobrar',
#   'tanto',
#   'malo',
#   'experiencia',
#   'fin'],
#  ['ok',
#   'pues',
#   'ir',
#   'bus',
#   'andar',
#   'ganar',
#   'mierdafy',
#   'mugre',
#   'evadir',
#   'impuesto',
#   'hacer',
#   'intrusismo',
#   'laboral',
#   'luego',
#   'si',
#   'ir',
#   'hospital',
#   'holando',
#   'delawer'],
#  ['saber', 'vehículo', 'llevar', 'barcelona'],
#  ['si',
#   'aquí',
#   'protestar',
#   'mal',
#   'servicio',
#   'dado',
#   'cacafay',
#   'ver',
#   'coherente',
#   'tarifa',
#   'absurdo',
#   'mejor',
#   'tarifa',
#   'dinámico',
#   'andar',
#   'yaaaa',
#   'mal',
#   'trato',
#   'chulería',
#   'ahora',
#   'defender',
#   'criticar',
#   'absurdo'],
#  ['ir',
#   'mierdafy',
#   'seguro',
#   'tener',
#   'dato',
#   'bancario',
#   'hacer',
#   'cargo',
#   'salir',
#   'web'],
#  ['hablar',
#   'dar',
#   'gana',
#   'cerebro',
#   'funcionar',
#   'divinamente',
#   'decir',
#   'estupidez',
#   'hacer',
#   'divinamente'],
#  ['próximo', 'cabify', 'si'],
#  ['taxista', 'cada', 'día', 'perder', 'cliente', 'clinex'],
#  ['verdad',
#   'elegido',
#   'cada',
#   'día',
#   'perder',
#   'terreno',
#   'tarifa',
#   'absurdo',
#   'mal',
#   'tratar',
#   'chulería',
#   'portais'],
#  ['acudir',
#   'dónde',
#   'parecer',
#   'mucho',
#   'gracias',
#   'consejo',
#   'decir',
#   'tú',
#   'saber',
#   'taxi',
#   'nunca',
#   'vida',
#   'estafado',
#   'listillo',
#   'llevar',
#   'hacer',
#   'tour',
#   'ciudad'],
#  ['bloquear', 'cuenta', 'mandar', 'correo', 'recuperarlo'],
#  ['contento',
#   'general',
#   'cabify',
#   'seguir',
#   'utilizar',
#   'él',
#   'precio',
#   'razonable',
#   'pillar',
#   'taxi',
#   'dar',
#   'viaje',
#   'min',
#   'barbaridad',
#   'ver',
#   'cliente',
#   'perder'],
#  ['perdón',
#   'equivocar',
#   'parada',
#   'medio',
#   'mark',
#   'tampoco',
#   'ninguno',
#   'taxista',
#   'poder',
#   'decir',
#   'menos',
#   'dar',
#   'taxi',
#   'llamar',
#   'radio',
#   'taxi',
#   'burjassot',
#   'bonrepo',
#   'menos'],
#  ['taxi',
#   'caro',
#   'tarifa',
#   'oficial',
#   'cabify',
#   'sangrar',
#   'alto',
#   'demanda',
#   'barato',
#   'acojonante'],
#  ['poder',
#   'explicar',
#   'cooperativo',
#   'palacio',
#   'congreso',
#   'entender',
#   'sentir',
#   'si',
#   'llama',
#   'hacer',
#   'app',
#   'máximo',
#   'llegada',
#   'ir',
#   'dónde',
#   'ir',
#   'coche',
#   'tarifa',
#   'marcar',
#   'conselleria'],
#  ['usar',
#   'código',
#   'ginog',
#   'conseguir',
#   'descuento',
#   'próximo',
#   'viaje',
#   'cabify',
#   'descarga',
#   'app'],
#  ['par', 'el', 'amb', 'jo', 'saber'],
#  ['si',
#   'cabifar',
#   'perdido',
#   'si',
#   'ser',
#   'taxi',
#   'garantizar',
#   'recuperado',
#   'sentir',
#   'próximo',
#   'saber',
#   'mientras',
#   'ciudad',
#   'cono',
#   'decir',
#   'cabify',
#   'olvidado',
#   'cliente',
#   'ahora',
#   'reclamar',
#   'ver',
#   'si',
#   'alguien',
#   'contestar'],
#  ['si',
#   'taxista',
#   'mirar',
#   'si',
#   'mirar',
#   'corto',
#   'solo',
#   'ver',
#   'conductor',
#   'vtc',
#   'rodear',
#   'mismo',
#   'encima',
#   'faltona'],
#  ['amor',
#   'haber',
#   'él',
#   'mandar',
#   'amiga',
#   'audio',
#   'am',
#   'super',
#   'ebrio',
#   'llorar',
#   'volver',
#   'cabify',
#   'responder',
#   'total',
#   'normalidad',
#   'si',
#   'contar',
#   'anecdota'],
#  ['prometer',
#   'eliminar',
#   'uber',
#   'cabify',
#   'etcétera',
#   'obviamente',
#   'traicionado',
#   'bien',
#   'entucado'],
#  ['tx',
#   'encantado',
#   'dar',
#   'desplazamiento',
#   'además',
#   'tributar',
#   'improbable',
#   'caso',
#   'cumplir',
#   'expectativa',
#   'hoja',
#   'reclamación',
#   'acudir',
#   'twitter',
#   'exigir',
#   'derecho'],
#  ['reiterar',
#   'cooperativa',
#   'burjassot',
#   'palacio',
#   'congreso',
#   'hora',
#   'ninguno',
#   'taxi',
#   'ir',
#   'llamar',
#   'lejos',
#   'ir',
#   'pagar',
#   'viaje',
#   'burjassot',
#   'almassera'],
#  ['cambio',
#   'pedir',
#   'taxi',
#   'legal',
#   'llegar',
#   'limusina',
#   'jamás',
#   'zapatico',
#   'cierto',
#   'precisamente',
#   'diversificacion',
#   'opción',
#   'proponer',
#   'tecnología',
#   'indriver',
#   'cabify',
#   'permitir',
#   'escoger',
#   'tipo',
#   'vehículo'],
#  ['tarifa',
#   'poner',
#   'taxi',
#   'poner',
#   'conselleria',
#   'transporte',
#   'contrario',
#   'cabify',
#   'cobrar',
#   'roto',
#   'hora',
#   'alto',
#   'demanda',
#   'suerte'],
#  ['burjassot',
#   'solo',
#   'ir',
#   'mismo',
#   'burjassot',
#   'godello',
#   'benimamet',
#   'zona',
#   'corte',
#   'valenciano',
#   'radio',
#   'hora',
#   'menos',
#   'taxi',
#   'disposición',
#   'radio',
#   'taxi',
#   'tele',
#   'taxi',
#   'máximo',
#   'llegada',
#   'domicilio',
#   'taxista',
#   'valencia',
#   'conocer'],
#  ['alguien',
#   'saber',
#   'si',
#   'alguno',
#   'aplicación',
#   'estilo',
#   'uber',
#   'funcionar',
#   'córdoba',
#   'solo',
#   'cabify',
#   'poco',
#   'chofer'],
#  ['chica',
#   'desesperado',
#   'dejar',
#   'tonteria',
#   'si',
#   'usar',
#   'cabify',
#   'taxi',
#   'unicornio',
#   'propulsar',
#   'pedo',
#   'confeti',
#   'purpurina',
#   'si',
#   'aportar',
#   'apartar',
#   'suerte',
#   'belen',
#   'ojala',
#   'recuperar',
#   'mochila',
#   'denunciar',
#   'si',
#   'portatil',
#   'vender'],
#  ['pagar',
#   'cabify',
#   'efectivo',
#   'ahora',
#   'dar',
#   'cuenta',
#   'pagado',
#   'tarjetaaa',
#   'dio',
#   'encima',
#   'decir',
#   'quedatir',
#   'vueltooo'],
#  ['acabar',
#   'decir',
#   'ex',
#   'conductor',
#   'beat',
#   'desinstale',
#   'xq',
#   'app',
#   'pedir',
#   'licencia',
#   'antecedente',
#   'perfil',
#   'trucho',
#   'uber',
#   'cabify',
#   'app'],
#  ['holar',
#   'si',
#   'obtener',
#   'respuesta',
#   'recomer',
#   'tratar',
#   'localizar',
#   'empresa',
#   'transportar',
#   'matricula',
#   'poder',
#   'dar',
#   'mirar',
#   'historial'],
#  ['bannear',
#   'uber',
#   'cabify',
#   'taxi',
#   'premium',
#   'ver',
#   'conductor',
#   'designado',
#   'nunca',
#   'escabio',
#   'sino',
#   'pasar',
#   'cosa'],
#  ['cabify', 'mierda'],
#  ['selección',
#   'quejasvtc',
#   'injusticia',
#   'abuso',
#   'usuar',
#   'uber',
#   'cabify',
#   'ilegal',
#   'fraude',
#   'engaño',
#   'timo',
#   'corrupción',
#   'político',
#   'transporte',
#   'inseguridad',
#   'rentabilidad',
#   'avaricia',
#   'atenciónalcliente',
#   'cliente',
#   'razón',
#   'comercio',
#   'manipulación'],
#  ['conductor',
#   'peligroso',
#   'conductor',
#   'descuidado',
#   'cliente',
#   'estafado',
#   'cliente',
#   'decepcionado',
#   'quejasvtc',
#   'uber',
#   'cabify',
#   'estafacabifyuber'],
#  ['limitar',
#   'recibir',
#   'descuento',
#   'pa',
#   'viaje',
#   'seguridad',
#   'aeropuerto',
#   'casa',
#   'bendito',
#   'capitalismo'],
#  ['belén',
#   'llevar',
#   'aparecer',
#   'mochila',
#   'amarillo',
#   'todo',
#   'vida',
#   'dentro'],
#  ['acabar',
#   'pasar',
#   'preguntar',
#   'servicio',
#   'traslado',
#   'capital',
#   'persona',
#   'ir',
#   'dejar',
#   'puerta',
#   'casa',
#   'pedir',
#   'cabify',
#   'salir',
#   'dejar',
#   'yo',
#   'puerta',
#   'casa'],
#  ['holar',
#   'recordar',
#   'dejar',
#   'ma',
#   'noche',
#   'viernes',
#   'barcelona',
#   'cabify',
#   'bajar',
#   'yo',
#   'cabify',
#   'banco',
#   'altura',
#   'ganduxer',
#   'via',
#   'agusta',
#   'saber'],
#  ['hablar',
#   'ver',
#   'juan',
#   'respirad',
#   'dejar',
#   'llegar',
#   'oxígeno',
#   'cerebro'],
#  ['extraño',
#   'tx',
#   'hora',
#   'pq',
#   'diferencia',
#   'cuca',
#   'tx',
#   'prestar',
#   'servicio',
#   'si',
#   'si',
#   'solo',
#   'rentable'],
#  ['pues', 'saber', 'idioma', 'usar', 'mierdafy', 'osear', 'mucho', 'luz'],
#  ['pasar', 'usar', 'cabify', 'proximo', 'ira', 'taxi'],
#  ['gorka',
#   'feministra',
#   'mira',
#   'pija',
#   'progre',
#   'coche',
#   'oficial',
#   'cova',
#   'cabify',
#   'idiota',
#   'solo',
#   'asesora',
#   'momento',
#   'foqelreencuentro'],
#  ['poder', 'cancelar', 'preguntar', 'motivo', 'cobrar'],
#  ['siempre',
#   'paso',
#   'mismo',
#   'dejar',
#   'tolerar',
#   'empezar',
#   'bajar',
#   'esperar',
#   'ir',
#   'bajar',
#   'porqo',
#   'dejar',
#   'pasar',
#   'coche',
#   'porq',
#   'die',
#   'aire',
#   'ac',
#   'elegir',
#   'ver',
#   'servicio',
#   'ppal',
#   'ir',
#   'llegar',
#   'transpirado',
#   'hacer',
#   'yo',
#   'estudio',
#   'bajar'],
#  ['burjassot', 'valencia', 'hoy', 'imposible', 'encontrar', 'taxi'],
#  ['notar', 'comprensión', 'lectora', 'corto', 'quizás', 'conductor', 'vtc'],
#  ['usar', 'cabify', 'ir', 'cagar', 'remisero', 'así'],
#  ['moder', 'yo'],
#  ['tampoco',
#   'cuca',
#   'tx',
#   'bastante',
#   'venir',
#   'decir',
#   'cómo',
#   'funcionar',
#   'hacer',
#   'cuca',
#   'si',
#   'pregúntalar',
#   'marido',
#   'arrimado',
#   'abogado',
#   'mugre'],
#  ['ver',
#   'lengua',
#   'expreso',
#   'desaparecer',
#   'si',
#   'problema',
#   'cucar',
#   'fijo',
#   'si',
#   'muuuu',
#   'tonto',
#   'intentar',
#   'defender',
#   'indefendible',
#   'hoy',
#   'día',
#   'mundo',
#   'saber',
#   'mierdafy',
#   'rakuten',
#   'dar',
#   'pasta'],
#  ['atender',
#   'tf',
#   'andar',
#   'mentiroso',
#   'foro',
#   'lleno',
#   'gente',
#   'capaz',
#   'comunicar',
#   'él',
#   'ir',
#   'atender',
#   'preferencia'],
#  ['si', 'bocachancla', 'ver', 'cero', 'coma', 'bloquear', 'tb'],
#  ['dentro',
#   'ir',
#   'palmar',
#   'pasta',
#   'tubo',
#   'preguntar',
#   'conductor',
#   'cobrar',
#   'septiembre'],
#  ['mierdafy',
#   'aceptar',
#   'condición',
#   'ir',
#   'poder',
#   'reclamar',
#   'mierda',
#   'cuca',
#   'disfrutar',
#   'saber',
#   'estafado',
#   'autorización',
#   'ir',
#   'palmar',
#   'pasta',
#   'vender',
#   'autorización',
#   'decir',
#   'poder',
#   'currar',
#   'tx',
#   'dar',
#   'cada',
#   'viaje'],
#  ['responder',
#   'tontería',
#   'tonto',
#   'aquel',
#   'robar',
#   'encima',
#   'intentar',
#   'justificar',
#   'si',
#   'estafado',
#   'tx',
#   'denuncia',
#   'lerdo',
#   'si',
#   'defender',
#   'cuca',
#   'pq',
#   'hoy',
#   'día',
#   'mundo',
#   'saber',
#   'cómo',
#   'funcionar',
#   'robar'],
#  ['cuatro',
# ...
#   'pasar'],
#  ['poder',
#   'tú',
#   'llamar',
#   'teléfono',
#   'esperanza',
#   'poner',
#   'reclamación',
#   'nube',
#   'consejo',
#   'usar',
#   'taxi',
#   'servicio',
#   'regulado',
#   'legal'],
#  ['año',
#   'malo',
#   'experiencia',
#   'app',
#   'conductor',
#   'malo',
#   'trato',
#   'lenguaje',
#   'inapropiado',
#   'gps',
#   'debido',
#   'hacer',
#   'recargo',
#   'ubicación',
#   'errado',
#   'enviar',
#   'mail',
#   'queja',
#   'así',
#   'dar',
#   'compensación'],
#  ['espabilarás'],
#  ['vtir', 'diésel', 'posterior', 'enero', 'fácil', 'ver', 'multar'],
#  ['pasar', 'uber', 'cabify', 'funcionar', 'cambiar', 'nombre'],
#  ['reserva',
#   'servir',
#   'seleccionar',
#   'servicio',
#   'rentable',
#   'si',
#   'llegar',
#   'momento',
#   'realizar',
#   'servicio',
#   'existir',
#   'rentable',
#   'quedar',
#   'relegar',
#   'ong',
#   'servicio',
#   'público',
#   'empresa',
#   'privado',
#   'lógicamente',
#   'regir',
#   'criterio',
#   'rentabilidad'],
#  ['claro',
#   'dejar',
#   'mañana',
#   'noche',
#   'buen',
#   'todavía',
#   'definir',
#   'si',
#   'alto',
#   'demanda',
#   'ir',
#   'ser'],
#  ['apretar',
#   'pie',
#   'alfombra',
#   'auto',
#   'querer',
#   'cabify',
#   'acelerar',
#   'cumplir'],
#  ['psicologo',
#   'videollamado',
#   'venir',
#   'mano',
#   'seguramente',
#   'arriba',
#   'cabify'],
#  ['amigo', 'prueba', 'taxi'],
#  ['tomo', 'taxi', 'solo', 'uber', 'cabify', 'claro', 'ahi', 'caso'],
#  ['casa', 'grande', 'volver', 'cabify', 'twitter', 'servicio'],
#  ['pago', 'cabify', 'regreso'],
#  ['llevar',
#   'él',
#   'carro',
#   'euber',
#   'cabify',
#   'ahí',
#   'meter',
#   'harto',
#   'inteligencia'],
#  ['huy',
#   'corrector',
#   'querer',
#   'decir',
#   'si',
#   'expuesto',
#   'polemizar',
#   'cdar',
#   'claro',
#   'usar',
#   'defender'],
#  ['ir', 'doblar', 'expuesto', 'polemizar', 'dicho', 'poco', 'taxi', 'usar'],
#  ['solo',
#   'uso',
#   'informar',
#   'gente',
#   'mentira',
#   'ilegalidad',
#   'cometer',
#   'mierdafy',
#   'mugre',
#   'alguien',
#   'exponer',
#   'inexactitud',
#   'aclarar',
#   'amablemente'],
#  ['codigo',
#   'cupón',
#   'rappi',
#   'oxs',
#   'codigo',
#   'cupón',
#   'ubereats',
#   'ln',
#   'codigo',
#   'cupon',
#   'glovo',
#   'lnlfqjl',
#   'codigo',
#   'cupon',
#   'cabify',
#   'ivano',
#   'cupon',
#   'uber',
#   'xaln',
#   'código',
#   'cupon',
#   'rappi',
#   'oxs',
#   'cupón',
#   'didi',
#   'ivan',
#   'cupón',
#   'rappi'],
#  ['jodar'],
#  ['gracias', 'juan', 'uso', 'twitter', 'polemizar'],
#  ['pelota',
#   'piso',
#   'chofer',
#   'hacer',
#   'esperar',
#   'minuto',
#   'terminar',
#   'viaje',
#   'después',
#   'querer',
#   'ir',
#   'ir',
#   'cancelar',
#   'tiempo',
#   'odio'],
#  ['can',
#   'aló',
#   'cabef',
#   'separador',
#   'plástico',
#   'policarbonato',
#   'faltar',
#   'protocolo',
#   'motivo',
#   'cancelación',
#   'encuesta',
#   'perder',
#   'información'],
#  ['conductor', 'separador', 'policarbonato', 'plástico', 'protojo', 'ojo'],
#  ['cojón', 'pasar', 'precio', 'cabify', 'cartagena'],
#  ['ir',
#   'españa',
#   'hacer',
#   'cargo',
#   'tarjeta',
#   'conductor',
#   'despedido',
#   'cobrar',
#   'septiembre',
#   'así',
#   'españo',
#   'mismo',
#   'mierda',
#   'argentino'],
#  ['bienvenido', 'cabify', 'uber', 'desinstalar'],
#  ['volver',
#   'laburar',
#   'uber',
#   'tarifa',
#   'alto',
#   'cabify',
#   'zona',
#   'remis',
#   'demora',
#   'cap',
#   'taxi',
#   'colectivo'],
#  ['alguien',
#   'poder',
#   'explicar',
#   'yo',
#   'definir',
#   'preferencia',
#   'cuenta',
#   'si',
#   'ninguno',
#   'conductor',
#   'ir',
#   'respetar',
#   'poder',
#   'aprender'],
#  ['taxi',
#   'bilbao',
#   'peor',
#   'servicio',
#   'público',
#   'conocido',
#   'supuesto',
#   'aceptar',
#   'reserva',
#   'nochebuena',
#   'tú',
#   'llamar',
#   'momento',
#   'pena',
#   'cabify',
#   'hacer',
#   'competencia'],
#  ['sabis',
#   'mismo',
#   'trato',
#   'preferir',
#   'taxi',
#   'necesitar',
#   'hacer',
#   'show',
#   'defecto',
#   'cabify',
#   'uber',
#   'hab',
#   'tocado',
#   'auto',
#   'enanisir',
#   'pedir',
#   'sentar',
#   'yo',
#   'adelante',
#   'que',
#   'apretar',
#   'yo',
#   'tocar',
#   'chofer'],
#  ['lamentable',
#   'leer',
#   'tú',
#   'condición',
#   'aceptar',
#   'usar',
#   'app',
#   'exonerar',
#   'cualquiera',
#   'responsabilidad',
#   'empresa',
#   'temer',
#   'responsabilidad',
#   'enteramente',
#   'tú',
#   'ser',
#   'tanto',
#   'incauto',
#   'reserva',
#   'anticipado',
#   'decir',
#   'existir'],
#  ['mandar',
#   'notificación',
#   'último',
#   'hora',
#   'valorar',
#   'viaje',
#   'seguir',
#   'llegar',
#   'miedo',
#   'poner',
#   'límite'],
#  ['cabify',
#   'tirar',
#   'tarifa',
#   'mas',
#   'barato',
#   'menos',
#   'acá',
#   'zona',
#   'norte',
#   'bair'],
#  ['cada',
#   'vez',
#   'deficiente',
#   'uso',
#   'app',
#   'cansar',
#   'disculpar',
#   'lado',
#   'llegar',
#   'tarde',
#   'imposible',
#   'predecir',
#   'tiempo',
#   'espera',
#   'nunca',
#   'móvil',
#   'disponible',
#   'reserva',
#   'auto',
#   'fiasco',
#   'funcionar',
#   'tal',
#   'cada',
#   'vez',
#   'peor'],
#  ['guapy',
#   'robar',
#   'taxista',
#   'dado',
#   'tener',
#   'renting',
#   'coche',
#   'molón',
#   'resto',
#   'pasta',
#   'delawer',
#   'allí',
#   'mejor',
#   'servicio',
#   'público',
#   'dinero',
#   'feliz',
#   'fiesta',
#   'tambien'],
#  ['si',
#   'entender',
#   'denunciar',
#   'aplicación',
#   'dar',
#   'miedo',
#   'creer',
#   'pase',
#   'solo',
#   'mantar',
#   'siempre',
#   'seguridad',
#   'casa'],
#  ['tranquilo',
#   'gente',
#   'cobarde',
#   'hacer',
#   'si',
#   'acaso',
#   'contactar',
#   'alguien',
#   'confianza',
#   'comunicar',
#   'poder',
#   'hacer',
#   'caso',
#   'inepto',
#   'sino',
#   'xq',
#   'ley',
#   'atar',
#   'mano'],
#  ['preocupar', 'sobremanero', 'delincuente', 'conocer', 'casa'],
#  ['golpizar', 'palo', 'puño', 'envuelto', 'dejar', 'huella'],
#  ['pedir',
#   'dinero',
#   'devolver',
#   'tú',
#   'aceptar',
#   'llamar',
#   'cuatro',
#   'cinco',
#   'amigo',
#   'vecino',
#   'apenas',
#   'llegar',
#   'entregar',
#   'producto',
#   'denlar',
#   'paliza',
#   'padre',
#   'señor',
#   'funcionar',
#   'decir',
#   'experiencia',
#   'extorsionador',
#   'seguir',
#   'juego'],
#  ['chófer',
#   'cabify',
#   'ir',
#   'dar',
#   'indicación',
#   'hija',
#   'hacer',
#   'matambre',
#   'arrollado',
#   'peceto',
#   'ternura'],
#  ['pay',
#   'attention',
#   'pls',
#   'usar',
#   'código',
#   'recibir',
#   'descuento',
#   'cabify'],
#  ['hecho',
#   'listado',
#   'startup',
#   'destacado',
#   'madrid',
#   'cabify',
#   'spotahome',
#   'bnext',
#   'fintonic',
#   'lingokid',
#   'bipi',
#   'evidentemente',
#   'todo',
#   'si',
#   'relevante',
#   'querer',
#   'incluir',
#   'alguno',
#   'particular'],
#  ['grado',
#   'sol',
#   'pleno',
#   'mins',
#   'esperar',
#   'cabify',
#   'chocar',
#   'llegar',
#   'casa'],
#  ['codigo',
#   'cupón',
#   'rappi',
#   'oxs',
#   'codigo',
#   'cupón',
#   'ubereats',
#   'ln',
#   'codigo',
#   'cupon',
#   'glovo',
#   'lnlfqjl',
#   'codigo',
#   'cupon',
#   'cabify',
#   'ivano',
#   'cupon',
#   'uber',
#   'xaln',
#   'código',
#   'cupon',
#   'rappi',
#   'oxs',
#   'cupón',
#   'didi',
#   'ivan',
#   'cupón',
#   'rappi'],
#  ['cabify', 'mejor', 'uber', 'pasado', 'cierto', 'asalto'],
#  ['gracias',
#   'recorger',
#   'yo',
#   'coche',
#   'guay',
#   'todo',
#   'flota',
#   'conductor',
#   'dani',
#   'mejor',
#   'cabify'],
#  ['hacer',
#   'día',
#   'intentar',
#   'solucionar',
#   'tema',
#   'tres',
#   'semana',
#   'vía',
#   'medio',
#   'navidad',
#   'sincomida',
#   'sintecho',
#   'cabifynopaga'],
#  ['flashaár', 'tranquilo', 'nuevo', 'spots', 'notar'],
#  ['si', 'asociar', 'él', 'mierdaf', 'buen'],
#  ['deducir',
#   'similar',
#   'tema',
#   'empezar',
#   'pasar',
#   'hacer',
#   'dos',
#   'semana',
#   'aprox',
#   'venir',
#   'conseguir',
#   'auto',
#   'campeón'],
#  ['día', 'subir', 'cabify', 'pendiente', 'posible', 'secuestro'],
#  ['venir',
#   'pasar',
#   'deducir',
#   'mucho',
#   'gente',
#   'usar',
#   'transporte',
#   'público',
#   'deber',
#   'reventar',
#   'uber',
#   'mejor'],
#  ['decir', 'parir', 'pedir', 'hoja', 'reclamación', 'apeo', 'llama', 'cabify'],
#  ['seguir', 'tener', 'respuesta'],
#  ['ratonear', 'peso', 'cabify', 'ir', 'llegar', 'tarde', 'peluquería'],
#  ['tomar',
#   'yo',
#   'meo',
#   'amiguito',
#   'jony',
#   'escupido',
#   'frutillita',
#   'torta',
#   'compartir',
#   'delicio',
#   'meo',
#   'lluviadorado',
#   'goldenshower',
#   'watersport',
#   'uber',
#   'camionero',
#   'beat',
#   'cabify',
#   'badbunny',
#   'rocho',
#   'preso',
#   'machoshetero',
#   'zonaoeste'],
#  ['bello'],
#  ['finde', 'amigo', 'querer', 'usar', 'él', 'tomar', 'cara'],
#  ['ganar',
#   'mes',
#   'trabajar',
#   'hs',
#   'día',
#   'cabify',
#   'restar',
#   'nafto',
#   'mantenimiento',
#   'dejar',
#   'mierda'],
#  ['existir',
#   'aplicación',
#   'taxi',
#   'pagar',
#   'servicio',
#   'brindar',
#   'seguridad',
#   'confianza',
#   'taxi',
#   'satelital',
#   'siempre',
#   'decir',
#   'barato',
#   'salir',
#   'caro',
#   'elegir',
#   'servicio',
#   'brindir',
#   'seguridad',
#   'pese',
#   'ser',
#   'tanto',
#   'económico'],
#  ['toso', 'conductor', 'pelotudo', 'cabify', 'tocar'],
#  ['recomendar',
#   'didi',
#   'aún',
#   'poder',
#   'probar',
#   'si',
#   'aceptar',
#   'débito',
#   'crédito'],
#  ['si',
#   'así',
#   'recién',
#   'medio',
#   'hora',
#   'pedir',
#   'después',
#   'tardar',
#   'minuto'],
#  ['recién',
#   'encontrar',
#   'llegar',
#   'minuto',
#   'vez',
#   'solo',
#   'minuto',
#   'búsqueda',
#   'buscar',
#   'alternativa',
#   'aceptar',
#   'débito',
#   'crédito',
#   'uber',
#   'trato',
#   'evitar',
#   'poder'],
#  ['cabify', 'aunque', 'soler', 'ser', 'cara'],
#  ['martes',
#   'hora',
#   'literalmente',
#   'esperar',
#   'auto',
#   'hacer',
#   'dar',
#   'vuelta',
#   'cancelar',
#   'cobrar',
#   'yo',
#   'igual',
#   'mandar',
#   'mails',
#   'tweet',
#   'dms',
#   'terminar',
#   'borrar',
#   'app'],
#  ['majo', 'cabify', 'decir', 'si', 'querer', 'música', 'subir', 'calefacción'],
#  ['gremio',
#   'taxi',
#   'lobotizado',
#   'visto',
#   'derecha',
#   'echar',
#   'brazo',
#   'uber',
#   'cabify',
#   'cómo',
#   'derecha',
#   'llegar',
#   'poder',
#   'poder',
#   'ir',
#   'vender',
#   'licencia',
#   'xq',
#   'ir',
#   'ver',
#   'uber',
#   'cabify',
#   'doquier'],
#  ['che',
#   'alguien',
#   'pasar',
#   'pedir',
#   'tardar',
#   'mil',
#   'año',
#   'encontrar',
#   'conductor',
#   'encontrar',
#   'decir',
#   'llegar',
#   'pasado',
#   'mañana'],
#  ['así', 'pago', 'cabify', 'vuelta'],
#  ['solo', 'cobrar', 'pago', 'cabify', 'mandar', 'él', 'zaragoza'],
#  ['odio'],
#  ['pues', 'preparatar', 'nochebuena', 'ir', 'dar'],
#  ['vehículo',
#   'ninguno',
#   'plataforma',
#   'denunciar',
#   'hacer',
#   'dato',
#   'público',
#   'marcha'],
#  ['volver', 'metro'],
#  ['seguir',
#   'tomar',
#   'cabify',
#   'pelotudo',
#   'así',
#   'ayuda',
#   'fugarse',
#   'discurso'],
#  ['cabify', 'recomendado'],
#  ['tomar',
#   'servicio',
#   'pasar',
#   'similar',
#   'olvidar',
#   'paquete',
#   'pedir',
#   'dinero',
#   'volver',
#   'traer',
#   'yo',
#   'dar',
#   'nunca',
#   'tomar',
#   'servicio',
#   'tomo',
#   'ahora',
#   'falla',
#   'tocado',
#   'delicuente',
#   'fecha'],
#  ['molestar',
#   'llamar',
#   'vt/100',
#   'taxi',
#   'loco',
#   'vivir',
#   'mundo',
#   'tanto',
#   'confuso',
#   'quedar',
#   'llegar',
#   'ninguno',
#   'parte'],
#  ['cabify',
#   'burlar',
#   'soltería',
#   'cuál',
#   'novio',
#   'saber',
#   'forever',
#   'alone',
#   'necesario',
#   'burla'],
#  ['buen',
#   'dia',
#   'mandar',
#   'mensaje',
#   'privado',
#   'querer',
#   'saber',
#   'horario',
#   'mañana',
#   'hora',
#   'tarde',
#   'poder',
#   'pedir',
#   'auto',
#   'poder',
#   'dejar',
#   'reservado',
#   'gracias',
#   'saludo'],
#  ['gustar', 'cabify', 'hablar'],
#  ['amor',
#   'vito',
#   'venir',
#   'visitar',
#   'casa',
#   'vito',
#   'tomate',
#   'cabify',
#   'esperar'],
#  ['si',
#   'pagar',
#   'ficha',
#   'mañana',
#   'llevar',
#   'hacer',
#   'falta',
#   'sacuar',
#   'ave',
#   'mando',
#   'cabify'],
#  ['chique',
#   'suceder',
#   'cabify',
#   'pasar',
#   'traicionar',
#   'bondi',
#   'noble',
#   'conurbano'],
#  ['opción', 'filtrar', 'taxi', 'aire', 'acondicionado'],
#  ['ver',
#   'heurtel',
#   'forma',
#   'parte',
#   'equipo',
#   'así',
#   'pillar',
#   'vuelo',
#   'cabify',
#   'búscatar',
#   'vida',
#   'saber',
#   'viajar',
#   'cierto',
#   'todavía',
#   'contrato',
#   'cabrón'],
#  ['papa',
#   'noel',
#   'gustar',
#   'depositar',
#   'trabajar',
#   'semana',
#   'así',
#   'poder',
#   'comer',
#   'pagar',
#   'alquiler'],
#  ['largar',
#   'libremente',
#   'competir',
#   'uber',
#   'cabify',
#   'taxi',
#   'rosarino',
#   'transporte',
#   'mas',
#   'barato'],
#  ['manera',
#   'urgente',
#   'habilitar',
#   'uber',
#   'cabify',
#   'ciudad',
#   'abrir',
#   'hilo',
#   'fin',
#   'semana',
#   'capital',
#   'federal',
#   'taxi',
#   'cobrar',
#   'bajada',
#   'bandera',
#   'sábado',
#   'am',
#   'mientras',
#   'anoche',
#   'rosario',
#   'bajado',
#   'bandera',
#   'salir'],
#  ['si',
#   'interesar',
#   'seguridad',
#   'ventanilla',
#   'abierto',
#   'llevar',
#   'pasajero',
#   'menos',
#   'pedir',
#   'manera',
#   'disminuir',
#   'riesgo',
#   'covid',
#   'debido',
#   'aire',
#   'entrar',
#   'salir',
#   'vehículo',
#   'aire',
#   'acondicionado',
#   'recirculo',
#   'aire',
#   'poder',
#   'contaminar'],
#  ['claro', 'si', 'uber', 'cabify', 'compartir', 'viaje'],
#  ['mismo',
#   'si',
#   'taxi',
#   'facar',
#   'esperar',
#   'si',
#   'cabify',
#   'compartir',
#   'viaje',
#   'alguien'],
#  ['tomo',
#   'taxi',
#   'solo',
#   'uber',
#   'cabify',
#   'igual',
#   'par',
#   'momento',
#   'incómodo',
#   'así',
#   'tal',
#   'vez',
#   'problema',
#   'saber',
#   'varón',
#   'manejar',
#   'mandar',
#   'audio',
#   'fingir',
#   'llamado',
#   'aunque',
#   'vez',
#   'dar',
#   'cuenta',
#   'decir',
#   'mentir',
#   'miedo',
#   'interior'],
#  ['claro', 'plata', 'chofer', 'pagar', 'caso', 'hacer', 'semana'],
#  ['si', 'pagar', 'trabajar', 'díganmar', 'dónde', 'ir', 'comer', 'vivir'],
#  ['decir', 'publicidad', 'cabify', 'ciudad', 'decir', 'larreta'],
#  ['hacer',
#   'cobro',
#   'viaje',
#   'inexistente',
#   'después',
#   'nunca',
#   'devolver',
#   'dinero',
#   'llevar',
#   'descuento',
#   'solo',
#   'mes',
#   'diciembre',
#   'dar',
#   'respuesta',
#   'solo',
#   'interesar',
#   'cobrar'],
#  ['hacer',
#   'cobro',
#   'viaje',
#   'inexistente',
#   'después',
#   'nunca',
#   'devolver',
#   'dinero',
#   'llevar',
#   'descuento',
#   'solo',
#   'mes',
#   'diciembre',
#   'dar',
#   'respuesta',
#   'solo',
#   'interesar',
#   'cobrar'],
#  ['hacer',
#   'cobro',
#   'viaje',
#   'inexistente',
#   'después',
#   'nunca',
#   'devolver',
#   'dinero',
#   'llevar',
#   'descuento',
#   'solo',
#   'mes',
#   'diciembre',
#   'dar',
#   'respuesta',
#   'solo',
#   'interesar',
#   'cobrar'],
#  ['re',
#   'puta',
#   'madre',
#   'didi',
#   'cabify',
#   'saber',
#   'hincha',
#   'ford',
#   'xq',
#   'poder',
#   'ser',
#   'venir',
#   'siempre',
#   'auto',
#   'chevrolet',
#   'jajajaja',
#   'parecer',
#   'joda'],
#  ['cuidar',
#   'medida',
#   'bioseguridad',
#   'conductor',
#   'obligar',
#   'pasajero',
#   'subirno',
#   'adelante',
#   'encima',
#   'grosero',
#   'pésimo',
#   'terribleserviciocabify'],
#  ['existir',
#   'voluntad',
#   'autoridad',
#   'estatal',
#   'municipal',
#   'ninguno',
#   'conductor',
#   'uber',
#   'didi',
#   'indriver',
#   'pronto',
#   'cabify',
#   'deber',
#   'llegar',
#   'pasar',
#   'agresión',
#   'físico',
#   'parte',
#   'taxista',
#   'veracruz'],
#  ['bastar',
#   'taxi',
#   'remis',
#   'tomar',
#   'viaje',
#   'mientras',
#   'viaje',
#   'cuestas',
#   'hacer',
#   'perder',
#   'tiempo',
#   'mal'],
#  ['contestar',
#   'mejor',
#   'queja',
#   'servicio',
#   'luego',
#   'si',
#   'contestar',
#   'buen',
#   'propósito',
#   'navidad',
#   'pasado'],
#  ['llegar', 'taxi', 'poder', 'pedir', 'cabify', 'salvar'],
#  ['gracias', 'cabify'],
#  ['jajajjar', 'denunciar', 'cabify', 'poner', 'cosa', 'fácil'],
#  ['dio', 'vuelta', 'dar', 'cabify', 'ir', 'buscar', 'alguien'],
#  ['terminar',
#   'conversación',
#   'silencio',
#   'rato',
#   'mientras',
#   'ir',
#   'subir',
#   'vm',
#   'llegar',
#   'rancagua',
#   'hablar',
#   'taxista',
#   'decir',
#   'gente',
#   'raro',
#   'responder',
#   'taxista',
#   'continuar',
#   'cachaste',
#   'llamado',
#   'subir',
#   'mina',
#   'llamar',
#   'app',
#   'cabify'],
#  ['buen',
#   'día',
#   'solo',
#   'recordar',
#   'necesario',
#   'poner',
#   'número',
#   'telefónico',
#   'detalle',
#   'llegar',
#   'código',
#   'verificación',
#   'esperar',
#   'solución'],
#  ['gracias', 'información', 'fiel', 'cabify'],
#  ['cargo',
#   'tarjeta',
#   'día',
#   'hoy',
#   'usado',
#   'servicio',
#   'además',
#   'cobro',
#   'uso',
#   'internacional',
#   'tarjeta',
#   'app',
#   'módulo',
#   'ayuda',
#   'poder',
#   'explicar',
#   'robo'],
#  ['lado',
#   'responder',
#   'usuario',
#   'paso',
#   'mismo',
#   'conductor',
#   'exactamente',
#   'mismo',
#   'situación',
#   'llegar',
#   'tarde',
#   'trabajo',
#   'gracias'],
#  ['vez',
#   'problema',
#   'conductor',
#   'tomo',
#   'viaje',
#   'completar',
#   'vez',
#   'terminar',
#   'vez',
#   'acercar',
#   'él',
#   'alejo',
#   'cancelar',
#   'pedir',
#   'uber',
#   'si',
#   'necesitar',
#   'detalle',
#   'preguntar'],
#  ['cuál',
#   'clave',
#   'actual',
#   'poder',
#   'tomar',
#   'decisión',
#   'correcto',
#   'crónica',
#   'mesa',
#   'debate',
#   'foro',
#   'financiero',
#   'eje',
#   'moderado',
#   'colíder',
#   'foro',
#   'financiero',
#   'talentosingenero'],
#  ...]

# %% [markdown]
# ## Save texts for tests

# %%
joblib.dump(texts, 'texts.pkl')
# Out:
# ['texts.pkl']

# %%
texts = joblib.load('results/variables/texts.pkl')

# %% [markdown]
# ### Most common words

# %%
word_list = [word for tweet in texts for word in tweet]
words_dist = FreqDist(word_list)
frequent_texts_words = [token[0] for token in words_dist.most_common()]

most_spanish_freq_words = top_n_list('es', 100000000, wordlist="best")

del_words = list(set(frequent_texts_words[0:500]).intersection(most_spanish_freq_words[0:1000]))
#texts = [[token for token in text if token not in del_words] for text in texts]

# %% [markdown]
# ### Rare common words

# %%
# LO HACE BIEN

#deleted_words = ['ahora', 'antes', 'después', 'tarde', 'luego', 'ayer', 'temprano', 'ya', 'todavía', 'anteayer', 'aún', 'pronto', 'hoy',
#           'aquí', 'ahí', 'allí', 'cerca', 'lejos', 'fuera', 'dentro', 'alrededor', 'aparte', 'encima', 'debajo', 'delante',
#           'detrás', 'así', 'bien', 'mal', 'despacio', 'deprisa', 'como', 'mucho', 'poco', 'muy', 'casi', 'todo', 'nada',
#           'algo', 'medio', 'demasiado', 'bastante', 'más', 'menos', 'además', 'incluso', 'también', 'sí', 'también',
#           'asimismo', 'no', 'tampoco', 'jamás', 'nunca', 'deber', 'poder', 'querer', 'saber', 'soler', 'cabify']

#no_accents_words = []
#for word in deleted_words:
#    no_accents_words.append(normalize(word))
    
#deleted_words = list(set(deleted_words+no_accents_words))

#rare_words_dic = dict((word,v )for word,v in cnt.items() if v <= 5 )
#rare_words = list(rare_words_dic.keys()) + deleted_words
#print(len(rare_words))


# Join adverbs and modals
#texts = [[token for token in tweet if token not in rare_words] for tweet in texts]

# %%
deleted_words = ['ahora', 'antes', 'después', 'tarde', 'luego', 'ayer', 'temprano', 'ya', 'todavía', 'anteayer', 'aún', 'pronto', 'hoy',
           'aquí', 'ahí', 'allí', 'cerca', 'lejos', 'fuera', 'dentro', 'alrededor', 'aparte', 'encima', 'debajo', 'delante',
           'detrás', 'así', 'bien', 'mal', 'despacio', 'deprisa', 'como', 'mucho', 'poco', 'muy', 'casi', 'todo', 'nada',
           'algo', 'medio', 'demasiado', 'bastante', 'más', 'menos', 'además', 'incluso', 'también', 'sí', 'también',
           'asimismo', 'no', 'tampoco', 'jamás', 'nunca', 'deber', 'poder', 'querer', 'saber', 'soler', 'cabify']
no_accents_words = []
for word in deleted_words:
    no_accents_words.append(normalize(word))
deleted_words = list(set(deleted_words+no_accents_words))

print(deleted_words)

deleted_words += [token[0] for token in list(filter(lambda x: x[1]<=5,words_dist.items()))]
# Out:
# ['todavía', 'así', 'casi', 'saber', 'ademas', 'algo', 'jamas', 'tambien', 'ahora', 'como', 'muy', 'asi', 'medio', 'demasiado', 'aún', 'mas', 'todo', 'alli', 'lejos', 'delante', 'mal', 'poco', 'detrás', 'pronto', 'detras', 'jamás', 'aqui', 'alrededor', 'despacio', 'deber', 'bastante', 'sí', 'ya', 'tarde', 'después', 'nada', 'menos', 'soler', 'luego', 'hoy', 'dentro', 'nunca', 'tampoco', 'bien', 'aparte', 'antes', 'cerca', 'allí', 'encima', 'deprisa', 'no', 'anteayer', 'además', 'también', 'querer', 'incluso', 'cabify', 'mucho', 'ahi', 'temprano', 'debajo', 'más', 'poder', 'ahí', 'aun', 'fuera', 'todavia', 'asimismo', 'despues', 'aquí', 'ayer', 'si']

# %%
deleted_words_2 = ['holar', 'hacer', 'dar','vez','decir',
                 'beat', 'hacer', 'alto', 'decir', 'llevar', 'valer', 'ver', 'tanto', 'creer','dar', 'ser',
                'etcétera', 'seguir',
                'salir', 'decir', 'volver', 'poner', 'seguir', 'ver', 'pues',
                'explicar',
                'ver', 'pasar', 'mismo', 'vez', 'cosa', 'creer', 'cada', 'nuevo', 'dos', 'mil',
                 'jaja', 'jajaj', 'jajaja', 'jajajaa', 'jajajaa', 'jajajaa', 'jajajaa', 'jajajaa', 'jajajaa', 'jajajaj', 'jajajaj',
                'jajajaj', 'jajajaj', 'jajajaja', 'jajajaja', 'jajajaja', 'jajajajaj', 'jajajajaj', 'jajajajaja', 'jajajajajaj', 'jajajajajaja', 'jajajajajajaj', 'jajajajajajaja',
                'jajajajajajajaja', 'jajajajajajajajajajajaja', 'jajajajajajajajajo', 'jajajajajajajo', 'jajajajajajo', 'jajajajajar', 'jajajajajja', 'jajajajajo',
                'jajajajar', 'jajajajja','jajajajo', 'jajajar', 'jajajja', 'jajajjaja', 'jajajo', 'jajar'
                 ] 
deleted_words_3 = ['siempre', 'servicio', 'mejor', 'tal', 'día', 'dia', 'quién', 'quien', 'mes', 'solo', 'parecer', 'empresa', 'contar', 'encontar', 'alguien', 
                   'persona', 'gente', 'mañana', 'ninguno', 'cualquiera', 'elegir']
deleted_words_4 = ['tomar', 'usar', 'usuario', 'usar', 'cómo', 'como', 'haber', 'tener', 'acabar']

deleted_words = set(deleted_words+ deleted_words_2 + deleted_words_3 + deleted_words_4)
texts = [[token for token in text if token not in deleted_words] for text in texts]

# %%
for tweet in texts:
    for word in tweet:
        if(word == 'usar'):
            print('a')

# %%
for i, tweet in enumerate(texts):
    for j, word in enumerate(tweet):
        if ((word == 'vehículo') or (word == 'carro') or (word == 'car') or (word == 'auto')):
            texts[i][j] = word.replace(word, 'coche')
        if ((word == 'trabajar')):
            texts[i][j] = word.replace(word, 'trabajo')
        if ((word == 'app') or (word == 'aplicacion')  ):
            texts[i][j] = word.replace(word, 'aplicación')
        if ((word == 'coronaviru') or (word == 'coronavirus')):
            texts[i][j] = word.replace(word, 'covid')
        if ((word == 'cobrer')):
            texts[i][j] = word.replace(word, 'cobrar')
        if ((word == 'españo') or (word == 'español')): ##
            texts[i][j] = word.replace(word, 'españa')
for i, tweet in enumerate(texts):
    for j, word in enumerate(tweet):
        if ((word == 'cupon')):
            texts[i][j] = word.replace(word, 'cupón')

# %% [markdown]
# ### Stemming

# %%
texts = joblib.load('results/variables/texts.pkl')

# %%
stemmer = SnowballStemmer("spanish")
texts = [[stemmer.stem(token) for token in text] for text in texts]

# %% [markdown]
# ### Cleaning the texts again before making dictionary

# %%
texts = [[word for word in tweet if len(word)>2] for tweet in texts]
#texts = [[word for word in tweet if word.isalpha()] for tweet in texts]
#texts

# %% [markdown]
# ### Bigrams

# %%
#bigram = gensim.models.Phrases(texts, min_count=100) 
#texts = [bigram[text] for text in texts]

# %% [markdown]
# ### Dictionary and corpus

# %%
dictionary = corpora.Dictionary(texts)
print(dictionary)
# Out:
# Dictionary(5770 unique tokens: ['dat', 'debid', 'estim', 'frecuent', 'hoj']...)

# %%
corpus = [dictionary.doc2bow(doc) for doc in texts]
print(len(corpus))
# Out:
# 74981

# %%
words = []
for i in dictionary:
    words += [dictionary.get(i)] 

words.sort()

# %% [markdown]
# ## Save results

# %%
path = "./results/variables"
try:
    if not os.path.isdir(path):
        os.makedirs(path)
except OSError:
    print ("Creation of the directory %s failed" % path)
else:
    print ("Successfully created the directory %s " % path)
# Out:
# Successfully created the directory ./results/variables

# %%
with open("results/variables/dictionary_alphabetical.txt", "w") as out_file:
    for word in words:
        out_file.write(word)
        out_file.write("\n")
#words

# %%
joblib.dump(texts, "results/variables/texts.pkl")
dictionary.save('results/variables/dictionary.dict')
MmCorpus.serialize("results/variables/corpus.corp", corpus)

# %%
dic_ordered = sorted(words , key = len)
with open("results/variables/dictionary_ordered.txt", "w") as out_file:
    for word in dic_ordered:
        out_file.write(word)
        out_file.write("\n")

# %% [markdown]
# # LDA

# %% [markdown]
# ## Load variables

# %%
texts = joblib.load("results/variables/texts.pkl")
dictionary = corpora.Dictionary.load("results/variables/dictionary.dict")
corpus = MmCorpus("results/variables/corpus.corp")

# %% [markdown]
# ## LDA Multicore

# %%
def compute_coherence_values(dictionary, corpus, texts, limit, start, iterations, random, passes):
    """
    Compute c_v coherence for various number of topics

    Parameters:
    ----------
    dictionary : Gensim dictionary
    corpus : Gensim corpus
    texts : List of input texts
    limit : Max num of topics
    iterations: Number of iterations fro LDA model
    random: mantain 

    Returns:
    -------
    model_list : List of LDA topic models
    coherence_values : Coherence values for each topic
    """
    coherence_values = []
    perplexity = []
    model_list = []
    for num_topics in range(start, limit):
        model = gensim.models.LdaMulticore(corpus=corpus,
                                          id2word=dictionary,
                                          num_topics=num_topics,
                                          chunksize=100,
                                          random_state=random,
                                          iterations = iterations,
                                          passes=passes,
                                          #alpha=a,
                                          #eta=b,
                                          workers=33,
                                          per_word_topics=True)        
       # model = gensim.models.ldamodel.LdaModel(corpus=corpus, num_topics=num_topics, id2word=dictionary, random_state= random, iterations=iterations, passes = passes)
        model_list.append(model)
        
        coherencemodel = CoherenceModel(model=model, texts=texts, dictionary=dictionary, coherence='c_v')
        coherence_values.append(coherencemodel.get_coherence())
        
        perplexity_model_lda = model.log_perplexity(corpus)
        perplexity.append(perplexity_model_lda)
        
    return model_list, coherence_values, perplexity

# %%
start = time()
model_list, coherence_values, perplexity_model_lda  = compute_coherence_values(dictionary=dictionary, corpus=corpus, texts=texts, start=1, limit=65, iterations = 50, random = 100, passes = 10)
print('Time used for calculating LDA: {:.2f}s'.format(time()-start))
# Out:
# Time used for calculating LDA: 4588.78s

# %%
id = coherence_values.index(max(coherence_values))
best_model = model_list[id]
best_model.print_topics(num_words = 20)
# Out:
# [(40,
#   '0.112*"descuent" + 0.096*"aplic" + 0.096*"proxim" + 0.077*"consegu" + 0.075*"viaj" + 0.070*"descarg" + 0.064*"codig" + 0.057*"punt" + 0.029*"esclav" + 0.023*"extranjer" + 0.019*"corrupt" + 0.017*"primer" + 0.015*"caj" + 0.014*"sigl" + 0.012*"didi" + 0.012*"entrad" + 0.012*"colombian" + 0.010*"pes" + 0.008*"map" + 0.008*"localiz"'),
#  (18,
#   '0.148*"perd" + 0.121*"opcion" + 0.080*"sin" + 0.048*"situacion" + 0.042*"crisis" + 0.038*"objet" + 0.036*"corre" + 0.033*"inclu" + 0.029*"resolv" + 0.022*"herman" + 0.017*"lleg" + 0.016*"principi" + 0.015*"dej" + 0.015*"hotel" + 0.014*"turism" + 0.013*"europ" + 0.012*"haciend" + 0.012*"content" + 0.010*"abon" + 0.010*"cas"'),
#  (61,
#   '0.086*"control" + 0.073*"mund" + 0.072*"barcelon" + 0.068*"lug" + 0.062*"estar" + 0.039*"compet" + 0.031*"practic" + 0.028*"airbnb" + 0.025*"aplic" + 0.022*"plataform" + 0.022*"acces" + 0.022*"confi" + 0.020*"cuatr" + 0.018*"lav" + 0.018*"guerr" + 0.017*"espaci" + 0.015*"pis" + 0.014*"motor" + 0.013*"ciud" + 0.012*"avanz"'),
#  (44,
#   '0.151*"gratis" + 0.074*"tra" + 0.066*"pobr" + 0.039*"lleg" + 0.034*"quer" + 0.033*"bogot" + 0.030*"ric" + 0.028*"prim" + 0.027*"cant" + 0.023*"grit" + 0.022*"filtr" + 0.021*"drog" + 0.019*"cas" + 0.019*"horribl" + 0.017*"feo" + 0.017*"porq" + 0.016*"com" + 0.015*"navid" + 0.014*"bla" + 0.013*"rop"'),
#  (47,
#   '0.142*"algun" + 0.087*"exist" + 0.058*"olvid" + 0.057*"solicit" + 0.047*"peligr" + 0.046*"colombi" + 0.045*"dud" + 0.029*"anim" + 0.029*"mejorent" + 0.028*"riesg" + 0.028*"tip" + 0.024*"contrari" + 0.022*"doming" + 0.019*"muchisim" + 0.018*"didi" + 0.018*"verdader" + 0.016*"disposicion" + 0.016*"driv" + 0.012*"aplic" + 0.012*"diferent"'),
#  (28,
#   '0.123*"reclam" + 0.097*"verd" + 0.074*"derech" + 0.044*"famili" + 0.044*"twitt" + 0.043*"prueb" + 0.042*"puest" + 0.034*"exig" + 0.030*"rut" + 0.029*"encant" + 0.028*"sueld" + 0.024*"estafacabifyub" + 0.024*"hoj" + 0.021*"especial" + 0.021*"client" + 0.021*"padr" + 0.019*"music" + 0.018*"sosten" + 0.018*"quejasvtc" + 0.016*"cas"'),
#  (38,
#   '0.148*"glov" + 0.118*"cupon" + 0.106*"codig" + 0.104*"rappi" + 0.087*"diari" + 0.045*"eat" + 0.041*"ped" + 0.040*"pedidosy" + 0.025*"ubereats" + 0.024*"delivero" + 0.020*"didi" + 0.020*"indeb" + 0.014*"concept" + 0.014*"ivan" + 0.014*"descuent" + 0.011*"onlin" + 0.011*"oxs" + 0.010*"otorg" + 0.010*"valencian" + 0.009*"modal"'),
#  (52,
#   '0.103*"cov" + 0.078*"encontr" + 0.042*"med" + 0.038*"amarill" + 0.031*"cual" + 0.031*"soci" + 0.030*"taximetr" + 0.030*"jug" + 0.030*"aplic" + 0.030*"bas" + 0.029*"plac" + 0.028*"real" + 0.028*"sancion" + 0.024*"mafi" + 0.021*"confirm" + 0.018*"tio" + 0.017*"alegr" + 0.016*"maxim" + 0.015*"recorr" + 0.014*"fond"'),
#  (6,
#   '0.257*"españ" + 0.151*"oper" + 0.149*"ley" + 0.091*"salt" + 0.040*"echar" + 0.022*"netflix" + 0.018*"pais" + 0.013*"renunci" + 0.013*"sinvergüenz" + 0.013*"ris" + 0.010*"penal" + 0.010*"empez" + 0.010*"dej" + 0.009*"ciud" + 0.008*"malag" + 0.008*"victim" + 0.007*"rob" + 0.007*"legal" + 0.006*"intencion" + 0.006*"comis"'),
#  (25,
#   '0.141*"explot" + 0.130*"vari" + 0.126*"laboral" + 0.078*"permis" + 0.042*"bienven" + 0.034*"extra" + 0.030*"corpor" + 0.028*"precariz" + 0.025*"glob" + 0.024*"fech" + 0.023*"luc" + 0.017*"trabaj" + 0.016*"condicion" + 0.015*"arruin" + 0.015*"sac" + 0.013*"individual" + 0.012*"fil" + 0.012*"bat" + 0.012*"ped" + 0.011*"intrus"'),
#  (24,
#   '0.152*"primer" + 0.110*"salud" + 0.056*"personal" + 0.047*"ojo" + 0.043*"min" + 0.038*"dad" + 0.037*"ayunt" + 0.036*"oir" + 0.036*"ocurr" + 0.033*"habilit" + 0.026*"prepar" + 0.020*"cabez" + 0.020*"niñ" + 0.020*"pur" + 0.018*"bici" + 0.017*"juli" + 0.016*"esper" + 0.016*"coñ" + 0.016*"requisit" + 0.015*"aparc"'),
#  (30,
#   '0.135*"public" + 0.090*"impuest" + 0.071*"pag" + 0.071*"utiliz" + 0.056*"fiscal" + 0.056*"pais" + 0.055*"españ" + 0.049*"tribut" + 0.038*"parais" + 0.032*"sanid" + 0.029*"transport" + 0.029*"delawar" + 0.026*"multinacional" + 0.018*"diner" + 0.018*"legal" + 0.018*"amazon" + 0.016*"aport" + 0.014*"defend" + 0.010*"basur" + 0.010*"plataform"'),
#  (17,
#   '0.101*"vtcho" + 0.074*"llor" + 0.048*"incumpl" + 0.047*"llen" + 0.044*"recomend" + 0.043*"articul" + 0.038*"program" + 0.036*"cdmx" + 0.030*"transport" + 0.029*"jorn" + 0.025*"mercanc" + 0.022*"explic" + 0.021*"previ" + 0.020*"peset" + 0.017*"porf" + 0.016*"amor" + 0.016*"rid" + 0.015*"legaliz" + 0.015*"didi" + 0.015*"resum"'),
#  (53,
#   '0.115*"amig" + 0.096*"apps" + 0.090*"ley" + 0.086*"cumpl" + 0.075*"comun" + 0.057*"benefici" + 0.038*"didi" + 0.037*"madr" + 0.032*"transport" + 0.032*"orden" + 0.031*"mexic" + 0.026*"recom" + 0.024*"suced" + 0.024*"huelg" + 0.022*"autor" + 0.020*"continu" + 0.017*"soport" + 0.015*"fuert" + 0.013*"repartidor" + 0.011*"botellit"'),
#  (20,
#   '0.144*"vtc" + 0.102*"via" + 0.080*"sector" + 0.063*"igual" + 0.045*"ciudadan" + 0.042*"circul" + 0.040*"tir" + 0.030*"madr" + 0.027*"medic" + 0.024*"compañer" + 0.022*"larg" + 0.020*"mod" + 0.019*"matricul" + 0.018*"estudi" + 0.018*"distint" + 0.017*"dej" + 0.016*"vtir" + 0.016*"exact" + 0.015*"dificil" + 0.013*"actu"'),
#  (34,
#   '0.167*"entend" + 0.068*"contest" + 0.059*"activ" + 0.058*"marc" + 0.045*"imagin" + 0.041*"mentir" + 0.031*"menud" + 0.027*"consider" + 0.027*"proteccion" + 0.025*"sevill" + 0.025*"repart" + 0.023*"inteligent" + 0.021*"ose" + 0.020*"emergent" + 0.019*"calific" + 0.019*"beb" + 0.018*"boton" + 0.017*"roj" + 0.016*"tech" + 0.015*"parec"'),
#  (9,
#   '0.147*"final" + 0.078*"entreg" + 0.069*"salv" + 0.046*"siguient" + 0.046*"guay" + 0.044*"vent" + 0.039*"revis" + 0.035*"cuc" + 0.023*"global" + 0.023*"alcanz" + 0.020*"gananci" + 0.018*"guard" + 0.016*"captur" + 0.016*"band" + 0.015*"expert" + 0.015*"compromis" + 0.014*"audi" + 0.014*"the" + 0.014*"payas" + 0.013*"obrer"'),
#  (31,
#   '0.101*"import" + 0.067*"man" + 0.062*"emple" + 0.055*"oblig" + 0.042*"pesim" + 0.041*"ingres" + 0.034*"rap" + 0.031*"gremi" + 0.031*"recuper" + 0.023*"necesari" + 0.020*"cam" + 0.020*"mail" + 0.019*"maner" + 0.019*"cre" + 0.017*"patriot" + 0.015*"reglament" + 0.014*"anterior" + 0.014*"didi" + 0.014*"amenaz" + 0.014*"proces"'),
#  (33,
#   '0.160*"favor" + 0.082*"numer" + 0.075*"traves" + 0.049*"report" + 0.046*"lament" + 0.043*"aplic" + 0.039*"cas" + 0.034*"vot" + 0.033*"incident" + 0.025*"domicili" + 0.024*"respuest" + 0.017*"conect" + 0.017*"unicorni" + 0.016*"enlac" + 0.014*"inutil" + 0.013*"mediant" + 0.013*"pint" + 0.013*"graci" + 0.013*"canal" + 0.011*"necesit"'),
#  (45,
#   '0.070*"indic" + 0.068*"tranquil" + 0.054*"asalt" + 0.046*"product" + 0.046*"manifest" + 0.042*"qued" + 0.037*"regres" + 0.036*"didi" + 0.029*"obten" + 0.024*"cas" + 0.022*"trag" + 0.022*"confund" + 0.022*"pagin" + 0.018*"facebook" + 0.017*"papel" + 0.016*"tramit" + 0.015*"centim" + 0.014*"adem" + 0.013*"exig" + 0.012*"ajen"')]

# %% [markdown]
# ### Plot results

# %%
x = range(1,65)

plt.plot(x, coherence_values, 'b')
plt.xlabel("Number of Topics")
plt.ylabel("Coherence score")
plt.grid(True,color='black')
plt.show()

# %% [markdown]
# ### Save lda, coherence and perplexity results

# %%
path = './results/ldamodel'
try:
    if not os.path.isdir(path):
        os.makedirs(path)
except OSError:
    print ("Creation of the directory %s failed" % path)
else:
    print ("Successfully created the directory %s " % path)
# Out:
# Successfully created the directory ./results/ldamodel

# %%
joblib.dump(model_list, "results/ldamodel/model_list_{}.pkl".format(y))
joblib.dump(coherence_values, "results/ldamodel/coherence_values_{}.pkl".format(y))
joblib.dump(perplexity_model_lda, "results/ldamodel/perplexity_model_lda_{}.pkl".format(y))
# Out:
# ['results/ldamodel/perplexity_model_lda_9.pkl']

# %%
x = range(5,35)

plt.plot(x, perplexity_model_lda, 'b')
plt.xlabel("Number of Topics")
plt.ylabel("Coherence score")
plt.grid(True,color='black')
plt.show()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-21-558b9a847861> in <module>
#       1 x = range(5,35)
#       2
# ----> 3 plt.plot(x, perplexity_model_lda, 'b')
#       4 plt.xlabel("Number of Topics")
#       5 plt.ylabel("Coherence score")
#
# ~/anaconda3/lib/python3.7/site-packages/matplotlib/pyplot.py in plot(scalex, scaley, data, *args, **kwargs)
#    2840     return gca().plot(
#    2841         *args, scalex=scalex, scaley=scaley,
# -> 2842         **({"data": data} if data is not None else {}), **kwargs)
#    2843
#    2844
#
# ~/anaconda3/lib/python3.7/site-packages/matplotlib/axes/_axes.py in plot(self, scalex, scaley, data, *args, **kwargs)
#    1741         """
#    1742         kwargs = cbook.normalize_kwargs(kwargs, mlines.Line2D)
# -> 1743         lines = [*self._get_lines(*args, data=data, **kwargs)]
#    1744         for line in lines:
#    1745             self.add_line(line)
#
# ~/anaconda3/lib/python3.7/site-packages/matplotlib/axes/_base.py in __call__(self, data, *args, **kwargs)
#     271                 this += args[0],
#     272                 args = args[1:]
# --> 273             yield from self._plot_args(this, kwargs)
#     274
#     275     def get_next_color(self):
#
# ~/anaconda3/lib/python3.7/site-packages/matplotlib/axes/_base.py in _plot_args(self, tup, kwargs)
#     397
#     398         if x.shape[0] != y.shape[0]:
# --> 399             raise ValueError(f"x and y must have same first dimension, but "
#     400                              f"have shapes {x.shape} and {y.shape}")
#     401         if x.ndim > 2 or y.ndim > 2:
#
# ValueError: x and y must have same first dimension, but have shapes (30,) and (64,)

# %% [markdown]
# ### pyLDAvis

# %%
import pyLDAvis.gensim
pyLDAvis.enable_notebook()

model=pyLDAvis.gensim.prepare(best_model, corpus, dictionary=dictionary)
pyLDAvis.save_html(model,'results/ldamodel/best_model.html')

#model2=pyLDAvis.gensim.prepare(model_list[8], corpus, dictionary=dictionary)
#pyLDAvis.save_html(model2,'results/ldamodel/2best_model.html')

# %% [markdown]
# ## LDA Mallet

# %% [markdown]
# ### Load variables

# %%
texts = joblib.load("results/variables/texts.pkl")
dictionary = corpora.Dictionary.load("results/variables/dictionary.dict")
corpus = MmCorpus("results/variables/corpus.corp")
# Out:
# /home/alejandro/anaconda3/lib/python3.7/site-packages/ipykernel/ipkernel.py:283: DeprecationWarning: `should_run_async` will not call `transform_cell` automatically in the future. Please pass the result to `transformed_cell` argument and any exception that happen during thetransform in `preprocessing_exc_tuple` in IPython 7.17 and above.
#   and should_run_async(code)

# %% [markdown]
# ### Train Model

# %%
# Download File: http://mallet.cs.umass.edu/dist/mallet-2.0.8.zip
mallet_path = 'mallet-2.0.8/bin/mallet' # update this path
# Out:
# /home/alejandro/anaconda3/lib/python3.7/site-packages/ipykernel/ipkernel.py:283: DeprecationWarning: `should_run_async` will not call `transform_cell` automatically in the future. Please pass the result to `transformed_cell` argument and any exception that happen during thetransform in `preprocessing_exc_tuple` in IPython 7.17 and above.
#   and should_run_async(code)

# %%
def compute_coherence_values_mallet(dictionary, corpus, texts, limit, start, step):
    """
    Compute c_v coherence for various number of topics

    Parameters:
    ----------
    dictionary : Gensim dictionary
    corpus : Gensim corpus
    texts : List of input texts
    limit : Max num of topics

    Returns:
    -------
    model_list : List of LDA topic models
    coherence_values : Coherence values corresponding to the LDA model with respective number of topics
    """
    coherence_values = []
    perplexity = []
    model_list = []
    
    for num_topics in range(start, limit, step):
        
        model = gensim.models.wrappers.LdaMallet(mallet_path, corpus=corpus, num_topics=num_topics, id2word=dictionary)
        model_list.append(model)
        
        coherencemodel = CoherenceModel(model=model, texts=texts, dictionary=dictionary, coherence='c_v')
        coherence_values.append(coherencemodel.get_coherence())
        
    return model_list, coherence_values
# Out:
# /home/alejandro/anaconda3/lib/python3.7/site-packages/ipykernel/ipkernel.py:283: DeprecationWarning: `should_run_async` will not call `transform_cell` automatically in the future. Please pass the result to `transformed_cell` argument and any exception that happen during thetransform in `preprocessing_exc_tuple` in IPython 7.17 and above.
#   and should_run_async(code)

# %%
start = time()
model_list_mallet, coherence_values_mallet = compute_coherence_values_mallet(dictionary=dictionary, corpus=corpus, texts=texts, start=1, limit=40, step=1)
print('Time used for calculating LDA_MALLET: {:.2f}s'.format(time()-start))
# Out:
# /home/alejandro/anaconda3/lib/python3.7/site-packages/ipykernel/ipkernel.py:283: DeprecationWarning: `should_run_async` will not call `transform_cell` automatically in the future. Please pass the result to `transformed_cell` argument and any exception that happen during thetransform in `preprocessing_exc_tuple` in IPython 7.17 and above.
#   and should_run_async(code)
# ---------------------------------------------------------------------------
# CalledProcessError                        Traceback (most recent call last)
# <ipython-input-45-189900fdc1bb> in <module>
#       1 start = time()
# ----> 2 model_list_mallet, coherence_values_mallet = compute_coherence_values_mallet(dictionary=dictionary, corpus=corpus, texts=texts, start=1, limit=40, step=1)
#       3 print('Time used for calculating LDA_MALLET: {:.2f}s'.format(time()-start))
#
# <ipython-input-44-5890d44700cb> in compute_coherence_values_mallet(dictionary, corpus, texts, limit, start, step)
#      21     for num_topics in range(start, limit, step):
#      22
# ---> 23         model = gensim.models.wrappers.LdaMallet(mallet_path, corpus=corpus, num_topics=num_topics, id2word=dictionary)
#      24         model_list.append(model)
#      25
#
# ~/anaconda3/lib/python3.7/site-packages/gensim/models/wrappers/ldamallet.py in __init__(self, mallet_path, corpus, num_topics, alpha, id2word, workers, prefix, optimize_interval, iterations, topic_threshold, random_seed)
#     129         self.random_seed = random_seed
#     130         if corpus is not None:
# --> 131             self.train(corpus)
#     132
#     133     def finferencer(self):
#
# ~/anaconda3/lib/python3.7/site-packages/gensim/models/wrappers/ldamallet.py in train(self, corpus)
#     270
#     271         """
# --> 272         self.convert_input(corpus, infer=False)
#     273         cmd = self.mallet_path + ' train-topics --input %s --num-topics %s  --alpha %s --optimize-interval %s '\
#     274             '--num-threads %s --output-state %s --output-doc-topics %s --output-topic-keys %s '\
#
# ~/anaconda3/lib/python3.7/site-packages/gensim/models/wrappers/ldamallet.py in convert_input(self, corpus, infer, serialize_corpus)
#     259             cmd = cmd % (self.fcorpustxt(), self.fcorpusmallet())
#     260         logger.info("converting temporary corpus to MALLET format with %s", cmd)
# --> 261         check_output(args=cmd, shell=True)
#     262
#     263     def train(self, corpus):
#
# ~/anaconda3/lib/python3.7/site-packages/gensim/utils.py in check_output(stdout, *popenargs, **kwargs)
#    1916             error = subprocess.CalledProcessError(retcode, cmd)
#    1917             error.output = output
# -> 1918             raise error
#    1919         return output
#    1920     except KeyboardInterrupt:
#
# CalledProcessError: Command 'mallet-2.0.8/bin/mallet import-file --preserve-case --keep-sequence --remove-stopwords --token-regex "\S+" --input /tmp/a79fab_corpus.txt --output /tmp/a79fab_corpus.mallet' returned non-zero exit status 127.

# %% [markdown]
# ### Plot results

# %%
x = range(1,40)

plt.plot(x, coherence_values_mallet, 'b')
plt.xlabel("Number of Topics")
plt.ylabel("Coherence score")
plt.grid(True,color='black')
plt.show()

# %% [markdown]
# ### Save lda,coherence and perplexity results

# %%
path = './results/mallet'
try:
    if not os.path.isdir(path):
        os.makedirs(path)
except OSError:
    print ("Creation of the directory %s failed" % path)
else:
    print ("Successfully created the directory %s " % path)

# %%
joblib.dump(model_list_mallet, "results/mallet/model_list_{}.pkl".format(y))
joblib.dump(coherence_values_mallet, "results/mallet/coherence_values_{}.pkl".format(y))

# %%
import scattertext as st
import spacy

import numpy as np
import pandas as pd
import nltk
import joblib
from nltk.corpus import stopwords
import string
import re

from nltk.tokenize import TweetTokenizer

from collections import Counter
from nltk.tokenize.treebank import TreebankWordDetokenizer

nltk.download('stopwords')
# Out:
# [nltk_data] Downloading package stopwords to
# [nltk_data]     /home/alejandro/nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# True

# %% [markdown]
# # Load Dataset

# %%
df = pd.read_csv('uber_support_sent140.csv')
df.shape
# Out:
# (215387, 36)

# %% [markdown]
# # Preprocess Tweets

# %%
EMOTICONS = {
    u":‑\)":"Happy face or smiley",
    u":\)":"Happy face or smiley",
    u":-\]":"Happy face or smiley",
    u":\]":"Happy face or smiley",
    u":-3":"Happy face smiley",
    u":3":"Happy face smiley",
    u":->":"Happy face smiley",
    u":>":"Happy face smiley",
    u"8-\)":"Happy face smiley",
    u":o\)":"Happy face smiley",
    u":-\}":"Happy face smiley",
    u":\}":"Happy face smiley",
    u":-\)":"Happy face smiley",
    u":c\)":"Happy face smiley",
    u":\^\)":"Happy face smiley",
    u"=\]":"Happy face smiley",
    u"=\)":"Happy face smiley",
    u":‑D":"Laughing, big grin or laugh with glasses",
    u":D":"Laughing, big grin or laugh with glasses",
    u"8‑D":"Laughing, big grin or laugh with glasses",
    u"8D":"Laughing, big grin or laugh with glasses",
    u"X‑D":"Laughing, big grin or laugh with glasses",
    u"XD":"Laughing, big grin or laugh with glasses",
    u"=D":"Laughing, big grin or laugh with glasses",
    u"=3":"Laughing, big grin or laugh with glasses",
    u"B\^D":"Laughing, big grin or laugh with glasses",
    u":-\)\)":"Very happy",
    u":‑\(":"Frown, sad, andry or pouting",
    u":-\(":"Frown, sad, andry or pouting",
    u":\(":"Frown, sad, andry or pouting",
    u":‑c":"Frown, sad, andry or pouting",
    u":c":"Frown, sad, andry or pouting",
    u":‑<":"Frown, sad, andry or pouting",
    u":<":"Frown, sad, andry or pouting",
    u":‑\[":"Frown, sad, andry or pouting",
    u":\[":"Frown, sad, andry or pouting",
    u":-\|\|":"Frown, sad, andry or pouting",
    u">:\[":"Frown, sad, andry or pouting",
    u":\{":"Frown, sad, andry or pouting",
    u":@":"Frown, sad, andry or pouting",
    u">:\(":"Frown, sad, andry or pouting",
    u":'‑\(":"Crying",
    u":'\(":"Crying",
    u":'‑\)":"Tears of happiness",
    u":'\)":"Tears of happiness",
    u"D‑':":"Horror",
    u"D:<":"Disgust",
    u"D:":"Sadness",
    u"D8":"Great dismay",
    u"D;":"Great dismay",
    u"D=":"Great dismay",
    u"DX":"Great dismay",
    u":‑O":"Surprise",
    u":O":"Surprise",
    u":‑o":"Surprise",
    u":o":"Surprise",
    u":-0":"Shock",
    u"8‑0":"Yawn",
    u">:O":"Yawn",
    u":-\*":"Kiss",
    u":\*":"Kiss",
    u":X":"Kiss",
    u";‑\)":"Wink or smirk",
    u";\)":"Wink or smirk",
    u"\*-\)":"Wink or smirk",
    u"\*\)":"Wink or smirk",
    u";‑\]":"Wink or smirk",
    u";\]":"Wink or smirk",
    u";\^\)":"Wink or smirk",
    u":‑,":"Wink or smirk",
    u";D":"Wink or smirk",
    u":‑P":"Tongue sticking out, cheeky, playful or blowing a raspberry",
    u":P":"Tongue sticking out, cheeky, playful or blowing a raspberry",
    u"X‑P":"Tongue sticking out, cheeky, playful or blowing a raspberry",
    u"XP":"Tongue sticking out, cheeky, playful or blowing a raspberry",
    u":‑Þ":"Tongue sticking out, cheeky, playful or blowing a raspberry",
    u":Þ":"Tongue sticking out, cheeky, playful or blowing a raspberry",
    u":b":"Tongue sticking out, cheeky, playful or blowing a raspberry",
    u"d:":"Tongue sticking out, cheeky, playful or blowing a raspberry",
    u"=p":"Tongue sticking out, cheeky, playful or blowing a raspberry",
    u">:P":"Tongue sticking out, cheeky, playful or blowing a raspberry",
    u":‑/":"Skeptical, annoyed, undecided, uneasy or hesitant",
    u":/":"Skeptical, annoyed, undecided, uneasy or hesitant",
    u":-[.]":"Skeptical, annoyed, undecided, uneasy or hesitant",
    u">:[(\\\)]":"Skeptical, annoyed, undecided, uneasy or hesitant",
    u">:/":"Skeptical, annoyed, undecided, uneasy or hesitant",
    u":[(\\\)]":"Skeptical, annoyed, undecided, uneasy or hesitant",
    u"=/":"Skeptical, annoyed, undecided, uneasy or hesitant",
    u"=[(\\\)]":"Skeptical, annoyed, undecided, uneasy or hesitant",
    u":L":"Skeptical, annoyed, undecided, uneasy or hesitant",
    u"=L":"Skeptical, annoyed, undecided, uneasy or hesitant",
    u":S":"Skeptical, annoyed, undecided, uneasy or hesitant",
    u":‑\|":"Straight face",
    u":\|":"Straight face",
    u":$":"Embarrassed or blushing",
    u":‑x":"Sealed lips or wearing braces or tongue-tied",
    u":x":"Sealed lips or wearing braces or tongue-tied",
    u":‑#":"Sealed lips or wearing braces or tongue-tied",
    u":#":"Sealed lips or wearing braces or tongue-tied",
    u":‑&":"Sealed lips or wearing braces or tongue-tied",
    u":&":"Sealed lips or wearing braces or tongue-tied",
    u"O:‑\)":"Angel, saint or innocent",
    u"O:\)":"Angel, saint or innocent",
    u"0:‑3":"Angel, saint or innocent",
    u"0:3":"Angel, saint or innocent",
    u"0:‑\)":"Angel, saint or innocent",
    u"0:\)":"Angel, saint or innocent",
    u":‑b":"Tongue sticking out, cheeky, playful or blowing a raspberry",
    u"0;\^\)":"Angel, saint or innocent",
    u">:‑\)":"Evil or devilish",
    u">:\)":"Evil or devilish",
    u"\}:‑\)":"Evil or devilish",
    u"\}:\)":"Evil or devilish",
    u"3:‑\)":"Evil or devilish",
    u"3:\)":"Evil or devilish",
    u">;\)":"Evil or devilish",
    u"\|;‑\)":"Cool",
    u"\|‑O":"Bored",
    u":‑J":"Tongue-in-cheek",
    u"#‑\)":"Party all night",
    u"%‑\)":"Drunk or confused",
    u"%\)":"Drunk or confused",
    u":-###..":"Being sick",
    u":###..":"Being sick",
    u"<:‑\|":"Dump",
    u"\(>_<\)":"Troubled",
    u"\(>_<\)>":"Troubled",
    u"\(';'\)":"Baby",
    u"\(\^\^>``":"Nervous or Embarrassed or Troubled or Shy or Sweat drop",
    u"\(\^_\^;\)":"Nervous or Embarrassed or Troubled or Shy or Sweat drop",
    u"\(-_-;\)":"Nervous or Embarrassed or Troubled or Shy or Sweat drop",
    u"\(~_~;\) \(・\.・;\)":"Nervous or Embarrassed or Troubled or Shy or Sweat drop",
    u"\(-_-\)zzz":"Sleeping",
    u"\(\^_-\)":"Wink",
    u"\(\(\+_\+\)\)":"Confused",
    u"\(\+o\+\)":"Confused",
    u"\(o\|o\)":"Ultraman",
    u"\^_\^":"Joyful",
    u"\(\^_\^\)/":"Joyful",
    u"\(\^O\^\)／":"Joyful",
    u"\(\^o\^\)／":"Joyful",
    u"\(__\)":"Kowtow as a sign of respect, or dogeza for apology",
    u"_\(\._\.\)_":"Kowtow as a sign of respect, or dogeza for apology",
    u"<\(_ _\)>":"Kowtow as a sign of respect, or dogeza for apology",
    u"<m\(__\)m>":"Kowtow as a sign of respect, or dogeza for apology",
    u"m\(__\)m":"Kowtow as a sign of respect, or dogeza for apology",
    u"m\(_ _\)m":"Kowtow as a sign of respect, or dogeza for apology",
    u"\('_'\)":"Sad or Crying",
    u"\(/_;\)":"Sad or Crying",
    u"\(T_T\) \(;_;\)":"Sad or Crying",
    u"\(;_;":"Sad of Crying",
    u"\(;_:\)":"Sad or Crying",
    u"\(;O;\)":"Sad or Crying",
    u"\(:_;\)":"Sad or Crying",
    u"\(ToT\)":"Sad or Crying",
    u";_;":"Sad or Crying",
    u";-;":"Sad or Crying",
    u";n;":"Sad or Crying",
    u";;":"Sad or Crying",
    u"Q\.Q":"Sad or Crying",
    u"T\.T":"Sad or Crying",
    u"QQ":"Sad or Crying",
    u"Q_Q":"Sad or Crying",
    u"\(-\.-\)":"Shame",
    u"\(-_-\)":"Shame",
    u"\(一一\)":"Shame",
    u"\(；一_一\)":"Shame",
    u"\(=_=\)":"Tired",
    u"\(=\^\·\^=\)":"cat",
    u"\(=\^\·\·\^=\)":"cat",
    u"=_\^=	":"cat",
    u"\(\.\.\)":"Looking down",
    u"\(\._\.\)":"Looking down",
    u"\^m\^":"Giggling with hand covering mouth",
    u"\(\・\・?":"Confusion",
    u"\(?_?\)":"Confusion",
    u">\^_\^<":"Normal Laugh",
    u"<\^!\^>":"Normal Laugh",
    u"\^/\^":"Normal Laugh",
    u"\（\*\^_\^\*）" :"Normal Laugh",
    u"\(\^<\^\) \(\^\.\^\)":"Normal Laugh",
    u"\(^\^\)":"Normal Laugh",
    u"\(\^\.\^\)":"Normal Laugh",
    u"\(\^_\^\.\)":"Normal Laugh",
    u"\(\^_\^\)":"Normal Laugh",
    u"\(\^\^\)":"Normal Laugh",
    u"\(\^J\^\)":"Normal Laugh",
    u"\(\*\^\.\^\*\)":"Normal Laugh",
    u"\(\^—\^\）":"Normal Laugh",
    u"\(#\^\.\^#\)":"Normal Laugh",
    u"\（\^—\^\）":"Waving",
    u"\(;_;\)/~~~":"Waving",
    u"\(\^\.\^\)/~~~":"Waving",
    u"\(-_-\)/~~~ \($\·\·\)/~~~":"Waving",
    u"\(T_T\)/~~~":"Waving",
    u"\(ToT\)/~~~":"Waving",
    u"\(\*\^0\^\*\)":"Excited",
    u"\(\*_\*\)":"Amazed",
    u"\(\*_\*;":"Amazed",
    u"\(\+_\+\) \(@_@\)":"Amazed",
    u"\(\*\^\^\)v":"Laughing,Cheerful",
    u"\(\^_\^\)v":"Laughing,Cheerful",
    u"\(\(d[-_-]b\)\)":"Headphones,Listening to music",
    u'\(-"-\)':"Worried",
    u"\(ーー;\)":"Worried",
    u"\(\^0_0\^\)":"Eyeglasses",
    u"\(\＾ｖ\＾\)":"Happy",
    u"\(\＾ｕ\＾\)":"Happy",
    u"\(\^\)o\(\^\)":"Happy",
    u"\(\^O\^\)":"Happy",
    u"\(\^o\^\)":"Happy",
    u"\)\^o\^\(":"Happy",
    u":O o_O":"Surprised",
    u"o_0":"Surprised",
    u"o\.O":"Surpised",
    u"\(o\.o\)":"Surprised",
    u"oO":"Surprised",
    u"\(\*￣m￣\)":"Dissatisfied",
    u"\(‘A`\)":"Snubbed or Deflated"
}

# %%
def preprocess(words):
    
    tokens = []
   
    # Clean urls, punct, strange characters, emojis, emoticons
    char= re.compile(r'^[a-zA-Z]$')
    punct=re.compile(r'[.,-,:,<,;,(,=]')
    ht = re.compile(r'http.')
    bar = re.compile(r'//*')
    pr = ["rt","@","http","https","'s",'...', 'english', 'translation','):',
          '. .', '..','2-5','<3',']:','“','”','’','. ...','___','__','=(','‘','—','°','¢','•','®','—','…',
          '... .','--->','–','»','«','£','-->','×','->','©','\n','™','¤']
    no_emoji = re.compile("["
                           u"\U0001F600-\U0001F64F"  # emoticons
                           u"\U0001F300-\U0001F5FF"  # symbols & pictographs
                           u"\U0001F680-\U0001F6FF"  # transport & map symbols
                           u"\U0001F1E0-\U0001F1FF"  # flags (iOS)
                           u"\U00002702-\U000027B0"
                           u"\U000024C2-\U0001F251"
                           "]+", flags=re.UNICODE) 
    
    no_emoticon = re.compile(u'(' + u'|'.join(k for k in EMOTICONS) + u')')
    no_html_pattern = re.compile('<.*?>')
    
    stoplist = stopwords.words('english')
    punctuation = set(string.punctuation)
    
   
    # TOKENIZER
    tknzr = TweetTokenizer()
    tokens = tknzr.tokenize(words)
    tokens = [w.lower() for w in tokens] 
    
    #Remove numbers
    pattern = '[0-9]'
    tokens = [re.sub(pattern, '', i) for i in tokens] 
    
    # Punctuation
    tokens = [w for w in tokens if  w not in punctuation]
    
    #Hacer algo con los hastags
    
    # Clean emojis,urls,bars
    tokens = [w.replace('#', '') for w in tokens if not w.startswith('@') if w not in pr 
            if not bar.search(w) if not ht.search(w) if not char.search(w) if not punct.search(w)
            if not w.isdigit() if not no_emoji.search(w) if not no_emoticon.search(w) if not no_html_pattern.search(w)]
    
    # Remove non alphanumeric
    tokens = [w for w in tokens if w.isalpha()]

    
    # Remove english stopwords
    tokens = [w for w in tokens if w not in stoplist]
    
    #Remove tokens with length < 1
    tokens = [word for word in tokens if len(word)>1]  ##Posiblemente sean 2
    
    return tokens

# %% [markdown]
# ## Simple preprocess

# %%
texts = [preprocess(document) for document in df['tweet']]
texts
# Out:
# [['follow',
#   'thru',
#   'promise',
#   'disinfecting',
#   'materials',
#   'drivers',
#   'cars',
#   'supplies',
#   'keep',
#   'drivers',
#   'safe',
#   'tele',
#   'agents',
#   'hang',
#   'drivers',
#   'call',
#   'ask',
#   'sbout',
#   'supplies'],
#  ['uber',
#   'follow',
#   'thru',
#   'promise',
#   'disinfecting',
#   'materials',
#   'drivers',
#   'cars',
#   'supplies',
#   'keep',
#   'drivers',
#   'safe',
#   'tele',
#   'agents',
#   'hang',
#   'drivers',
#   'call',
#   'ask',
#   'sbout',
#   'supplies',
#   'explain',
#   'please'],
#  ['follow',
#   'thru',
#   'promise',
#   'disinfecting',
#   'materials',
#   'drivers',
#   'cars',
#   'supplies',
#   'keep',
#   'drivers',
#   'safe',
#   'tele',
#   'agents',
#   'hang',
#   'drivers',
#   'call',
#   'ask',
#   'sbout',
#   'supplies',
#   'explain',
#   'please'],
#  ['song',
#   'dance',
#   'dead',
#   'wrong',
#   'handling',
#   'pandemic',
#   'plight',
#   'workers',
#   'know'],
#  ['hey', 'receiving', 'ride', 'reports', 'email', 'even', 'account', 'guys'],
#  ['done'],
#  ['uber', 'gives', 'ride', 'request', 'go', 'app', 'gone', 'right', 'away'],
#  ['way',
#   'worried',
#   'privacy',
#   'dm',
#   'said',
#   'please',
#   'continue',
#   'working',
#   'support',
#   'team',
#   'even',
#   'though',
#   'one',
#   'emailing',
#   'help',
#   'deception'],
#  ['trying',
#   'file',
#   'california',
#   'state',
#   'unemployment',
#   'insurance',
#   'ever',
#   'since',
#   'pay',
#   'cut',
#   'dramatically',
#   'uber',
#   'ca',
#   'state',
#   'etin',
#   'tried',
#   'find',
#   'number',
#   'call',
#   'hr',
#   'department',
#   'find',
#   'one',
#   'also',
#   'still',
#   'waiting',
#   'file',
#   'tax'],
#  ['please', 'answer', 'message', 'box'],
#  ['contact',
#   'info',
#   'avoid',
#   'charges',
#   'driver',
#   'says',
#   'business',
#   'closed'],
#  ['read', 'original', 'tweet', 'answer', 'question', 'nothing', 'account'],
#  ['handling',
#   'drivers',
#   'situation',
#   'restricted',
#   'lockdown',
#   'example',
#   'panama',
#   'central',
#   'america'],
#  ['insurance', 'pending', 'approval', 'hours'],
#  ['hello',
#   'ordered',
#   'worth',
#   'east',
#   'sides',
#   'came',
#   'cold',
#   'chicken',
#   'cooked',
#   'veggies',
#   'fries',
#   'cooked',
#   'pasta',
#   'cold',
#   'desert',
#   'kids',
#   'meal',
#   'worst',
#   'time',
#   'ever',
#   'eating',
#   'food',
#   'restaurant',
#   'said',
#   'bad',
#   'night',
#   'call',
#   'uber',
#   'refund'],
#  ['help', 'justification', 'horrible', 'practice'],
#  ['hi',
#   'way',
#   'bicycle',
#   'delivery',
#   'profile',
#   'modified',
#   'enable',
#   'use',
#   'vehicle',
#   'provided',
#   'every',
#   'necessary',
#   'nyc',
#   'clearance',
#   'start',
#   'delivery',
#   'vehicle',
#   'thanks',
#   'look',
#   'forward',
#   'getting',
#   'support'],
#  ['called', 'multiple', 'times', 'one', 'approve', 'insurance', 'days'],
#  ['uber',
#   'going',
#   'provide',
#   'drivers',
#   'sanitizing',
#   'wipes',
#   'vehicle',
#   'interiors',
#   'hands',
#   'keep',
#   'seeing',
#   'emails',
#   'yet',
#   'word',
#   'shipment',
#   'products',
#   'actual',
#   'drivers'],
#  ['local',
#   'greenlight',
#   'hub',
#   'support',
#   'offices',
#   'closed',
#   'til',
#   'least',
#   'april',
#   'prob',
#   'longer',
#   'gave',
#   'us',
#   'paper',
#   'call',
#   'uber',
#   'support',
#   'get',
#   'boston',
#   'driver',
#   'certificate',
#   'called',
#   'told',
#   'hubs',
#   'get',
#   'certificate'],
#  ['help', 'uber', 'eats', 'order', 'issue', 'going', 'bonkers'],
#  ['hello',
#   'recieve',
#   'thermal',
#   'bag',
#   'start',
#   'delivery',
#   'job',
#   'went',
#   'office',
#   'told',
#   'closed',
#   'due',
#   'covid',
#   'situation',
#   'hand',
#   'yet',
#   'recieve',
#   'texts',
#   'emails',
#   'everyday',
#   'collection',
#   'told',
#   'back',
#   'th'],
#  ['still', 'nothing'],
#  ['one', 'checking', 'important', 'dm'],
#  ['latin',
#   'creations',
#   'senor',
#   'frog',
#   'cancel',
#   'wrong',
#   'menu',
#   'able',
#   'contact',
#   'branden',
#   'plan'],
#  ['email', 'ever', 'access', 'account', 'changed', 'phone', 'number'],
#  ['ya',
#   'love',
#   'getting',
#   'charged',
#   'cancelling',
#   'driver',
#   'went',
#   'double',
#   'distance',
#   'way',
#   'absolutely',
#   'ridiculous',
#   'second',
#   'time',
#   'shit',
#   'like',
#   'happened',
#   'taken',
#   'money',
#   'reason',
#   'bunch',
#   'thieves'],
#  ['hoping',
#   'someone',
#   'smart',
#   'enough',
#   'realize',
#   'drivers',
#   'keep',
#   'current',
#   'uber',
#   'pro',
#   'status',
#   'time',
#   'fair',
#   'reasonable',
#   'thing',
#   'ask',
#   'people',
#   'ride',
#   'thanks'],
#  ['ordered',
#   'restaurant',
#   'screwed',
#   'order',
#   'talk',
#   'get',
#   'item',
#   'eat',
#   'since',
#   'toppings',
#   'included',
#   'make',
#   'gag'],
#  ['deny', 'claim', 'self', 'isolation', 'compensation'],
#  ['send',
#   'uber',
#   'customer',
#   'service',
#   'number',
#   'live',
#   'person',
#   'stat',
#   'lawyer',
#   'call'],
#  ['stop',
#   'unauthorized',
#   'removal',
#   'funds',
#   'bank',
#   'account',
#   'global',
#   'pandemic',
#   'resources',
#   'already',
#   'scarce',
#   'taken',
#   'uber',
#   'months',
#   'absurd',
#   'give',
#   'money',
#   'back'],
#  ['week',
#   'waiting',
#   'support',
#   'got',
#   'copy',
#   'paste',
#   'reply',
#   'dm',
#   'first',
#   'last',
#   'time',
#   'using',
#   'guys',
#   'understand',
#   'increase',
#   'due',
#   'everything',
#   'going',
#   'week',
#   'insane'],
#  ['anyone',
#   'else',
#   'issues',
#   'second',
#   'day',
#   'row',
#   'food',
#   'never',
#   'arrived',
#   'app',
#   'says',
#   'delivered',
#   'hell'],
#  ['tell', 'deny', 'claim'],
#  ['still', 'received', 'uber', 'eats', 'support'],
#  ['want',
#   'know',
#   'ignored',
#   'weeks',
#   'ok',
#   'completely',
#   'unacceptable',
#   'unprofessional',
#   'company',
#   'blatantly',
#   'lie',
#   'drivers',
#   'covid'],
#  ['app',
#   'talk',
#   'someone',
#   'emails',
#   'charged',
#   'twice',
#   'trip',
#   'car',
#   'never',
#   'showed',
#   'different',
#   'info'],
#  ['please', 'help', 'help'],
#  ['still', 'looking', 'answers'],
#  ['took',
#   'uber',
#   'restaurant',
#   'give',
#   'order',
#   'cause',
#   'given',
#   'driver',
#   'spend',
#   'money',
#   'retrieving',
#   'order',
#   'unsuccessful',
#   'still',
#   'nothing',
#   'support',
#   'good',
#   'enough'],
#  ['weeks', 'unacceptable', 'stated', 'days', 'payment', 'think', 'ok'],
#  ['help', 'uber', 'support', 'wont', 'help', 'please', 'help'],
#  ['tell',
#   'three',
#   'weeks',
#   'since',
#   'waiting',
#   'get',
#   'paid',
#   'point',
#   'believe',
#   'lying',
#   'drivers'],
#  ['promotion', 'expire', 'april', 'th', 'yet'],
#  ['leave',
#   'bottle',
#   'coke',
#   'see',
#   'going',
#   'find',
#   'reliable',
#   'delivery',
#   'service',
#   'make',
#   'second',
#   'time',
#   'messed',
#   'left',
#   'item',
#   'order'],
#  ['pls',
#   'hurry',
#   'last',
#   'dime',
#   'showering',
#   'neighbors',
#   'sprinkler',
#   'going',
#   'report',
#   'soon'],
#  ['met',
#   'criteria',
#   'current',
#   'time',
#   'submission',
#   'enough',
#   'instead',
#   'keep',
#   'getting',
#   'denied',
#   'criteria',
#   'gets',
#   'changed',
#   'way',
#   'anything',
#   'help'],
#  ['still', 'looking', 'callback', 'worstcustomerservice'],
#  ['way', 'go'],
#  ['yet',
#   'reaching',
#   'something',
#   'answer',
#   'application',
#   'put',
#   'uber',
#   'driver',
#   'months',
#   'ago',
#   'reviewed',
#   'thanks'],
#  ['dm', 'number', 'text', 'set', 'time', 'chat'],
#  ['uber',
#   'drivers',
#   'beware',
#   'uber',
#   'paying',
#   'promised',
#   'quarantined',
#   'drive',
#   'lyft',
#   'another',
#   'company',
#   'protect',
#   'needed',
#   'uber',
#   'breaking',
#   'texas',
#   'payday',
#   'law'],
#  ['shouldnt',
#   'guys',
#   'treating',
#   'couriers',
#   'like',
#   'gold',
#   'instead',
#   'keeping',
#   'tips',
#   'shorting',
#   'pay',
#   'outs',
#   'pandemic',
#   'ones',
#   'essential',
#   'wew',
#   'making',
#   'millions',
#   'yoy',
#   'still',
#   'uner',
#   'pay',
#   'us'],
#  ['uber',
#   'breaking',
#   'texas',
#   'payday',
#   'law',
#   'uber',
#   'refusing',
#   'pay',
#   'drivers',
#   'shieldvoc'],
#  ['hear', 'yet'],
#  ['still', 'get'],
#  ['uber',
#   'account',
#   'let',
#   'update',
#   'email',
#   'address',
#   'activate',
#   'nhs',
#   'promo'],
#  ['happy',
#   'mcdonald',
#   'uk',
#   'dream',
#   'abt',
#   'restaurants',
#   'co',
#   'closed',
#   'wont',
#   'open',
#   'anytime',
#   'soon',
#   'id',
#   'love',
#   'double',
#   'cheeseburger',
#   'even',
#   'ubereats',
#   'deliver'],
#  ['uber',
#   'got',
#   'another',
#   'problem',
#   'check',
#   'dms',
#   'got',
#   'charged',
#   'wrong'],
#  ['live',
#   'portugal',
#   'ordered',
#   'delivery',
#   'man',
#   'asked',
#   'go',
#   'downstairs',
#   'collect',
#   'food',
#   'outside',
#   'building',
#   'said',
#   'due',
#   'covid',
#   'new',
#   'rules',
#   'get',
#   'covid',
#   'leave',
#   'flat',
#   'get',
#   'food',
#   'downstairs',
#   'outside',
#   'comments'],
#  ['worst', 'support', 'world', 'goes'],
#  ['need', 'help', 'verification', 'code', 'email', 'getting'],
#  ['need',
#   'know',
#   'uber',
#   'driver',
#   'probably',
#   'back',
#   'work',
#   'due',
#   'covid',
#   'rule',
#   'please',
#   'let',
#   'know',
#   'soon',
#   'thank'],
#  ['dear',
#   'first',
#   'responder',
#   'driver',
#   'quarantine',
#   'heard',
#   'back',
#   'guys',
#   'far',
#   'submit',
#   'paperwork',
#   'get',
#   'help'],
#  ['please',
#   'follow',
#   'dm',
#   'locked',
#   'nhs',
#   'uber',
#   'eats',
#   'account',
#   'please',
#   'help'],
#  ['good',
#   'afternoon',
#   'name',
#   'tina',
#   'ordered',
#   'uber',
#   'eats',
#   'app',
#   'first',
#   'time',
#   'used',
#   'promotional',
#   'code',
#   'given',
#   'manager',
#   'place',
#   'work',
#   'registered',
#   'nurse',
#   'first',
#   'responder',
#   'covid',
#   'pandemic'],
#  ['essential',
#   'workers',
#   'ny',
#   'ever',
#   'considered',
#   'giving',
#   'us',
#   'discount',
#   'trips',
#   'work',
#   'since',
#   'risk',
#   'work',
#   'risk',
#   'commutes',
#   'flattenthecurvetogether'],
#  ['clear',
#   'whether',
#   'worked',
#   'let',
#   'yet',
#   'price',
#   'remains',
#   'unchanged',
#   'go',
#   'help',
#   'page',
#   'way',
#   'interract',
#   'tweet',
#   'twitter',
#   'address'],
#  ['got',
#   'couple',
#   'issues',
#   'trying',
#   'work',
#   'feel',
#   'like',
#   'getting',
#   'run',
#   'around',
#   'online',
#   'outlets',
#   'text',
#   'uber',
#   'app',
#   'twitter',
#   'direct',
#   'messaging',
#   'need',
#   'help',
#   'direction',
#   'assistance',
#   'advice',
#   'support',
#   'tried',
#   'go',
#   'kc',
#   'greenlight',
#   'hub',
#   'closed'],
#  ['loooooool', 'nearly', 'spat', 'one', 'good', 'slice'],
#  ['could', 'get', 'uberxl', 'use', 'pick', 'flatpack', 'furniture'],
#  ['hi',
#   'guys',
#   'trying',
#   'use',
#   'uber',
#   'eats',
#   'promo',
#   'code',
#   'emailed',
#   'meant',
#   'valid',
#   'pm',
#   'tonight',
#   'apply',
#   'tried',
#   'phone',
#   'website',
#   'help'],
#  ['thanks', 'usual', 'email', 'stated', 'got', 'papers'],
#  ['uh', 'huh'],
#  ['looool', 'man', 'got', 'calzone'],
#  ['week', 'guys', 'still', 'verified', 'insurance', 'registration'],
#  ['go', 'getting', 'pizzas', 'redelivered', 'refund'],
#  ['hello',
#   'doctor',
#   'nhs',
#   'recently',
#   'updated',
#   'ubereats',
#   'email',
#   'nhs',
#   'email',
#   'still',
#   'received',
#   'promo',
#   'code'],
#  ['leave', 'answer', 'dms'],
#  ['nhsapril',
#   'code',
#   'work',
#   'says',
#   'applied',
#   'show',
#   'promotions',
#   'fully',
#   'charged'],
#  ['unable',
#   'pay',
#   'bills',
#   'unable',
#   'work',
#   'even',
#   'though',
#   'sent',
#   'documents',
#   'days',
#   'ago',
#   'lack',
#   'response',
#   'hurting',
#   'vulnerable',
#   'drivers',
#   'already',
#   'loosing',
#   'money',
#   'due',
#   'scenario',
#   'shameful'],
#  ['week',
#   'since',
#   'applied',
#   'nothing',
#   'checked',
#   'please',
#   'help',
#   'really',
#   'like',
#   'work',
#   'need',
#   'new',
#   'form',
#   'income',
#   'soon',
#   'please',
#   'let',
#   'know',
#   'something',
#   'wrong',
#   'application'],
#  ['hello',
#   'somebody',
#   'trying',
#   'register',
#   'uber',
#   'number',
#   'got',
#   'verification',
#   'codes',
#   'phone',
#   'need',
#   'dont',
#   'use',
#   'uber',
#   'help',
#   'would',
#   'greatly',
#   'appreciated'],
#  ['go', 'days', 'without', 'work'],
#  ['replied', 'back', 'refunded', 'please'],
#  ['able', 'update', 'documentation', 'via', 'driver', 'app', 'uber', 'brasil'],
#  ['since',
#   'state',
#   'oklahoma',
#   'extended',
#   'validity',
#   'drivers',
#   'licenses',
#   'impact',
#   'ability',
#   'continue',
#   'running',
#   'trips',
#   'even',
#   'mine',
#   'originally',
#   'set',
#   'expire',
#   'april'],
#  ['attitude', 'employees', 'disgusting', 'talk', 'awful', 'support'],
#  ['state',
#   'stay',
#   'home',
#   'mandate',
#   'stop',
#   'permitted',
#   'work',
#   'obtain',
#   'paperwork',
#   'say',
#   'work'],
#  ['cancelling',
#   'delivery',
#   'requests',
#   'get',
#   'really',
#   'could',
#   'care',
#   'less',
#   'diamond',
#   'rating',
#   'spoken',
#   'unprofessionally',
#   'manager',
#   'cambridge',
#   'franklin',
#   'rd',
#   'half'],
#  ['food', 'never', 'arrived'],
#  ['days',
#   'able',
#   'work',
#   'one',
#   'approved',
#   'insurance',
#   'forward',
#   'messages',
#   'tell',
#   'going'],
#  ['help'],
#  ['ok',
#   'looks',
#   'like',
#   'someone',
#   'manually',
#   'fixed',
#   'account',
#   'appreciate',
#   'support',
#   'team',
#   'still',
#   'needs',
#   'better',
#   'understand',
#   'requests',
#   'respond',
#   'context',
#   'rather',
#   'using',
#   'canned',
#   'responses'],
#  ['email',
#   'send',
#   'documents',
#   'guys',
#   'four',
#   'years',
#   'new',
#   'bull',
#   'shit',
#   'sick',
#   'say',
#   'sure',
#   'news',
#   'find',
#   'interesting',
#   'one'],
#  ['hey',
#   'shady',
#   'fall',
#   'guidelines',
#   'financial',
#   'support',
#   'sent',
#   'required',
#   'docs',
#   'doctor',
#   'getti',
#   'fucking',
#   'run',
#   'around',
#   'suspend',
#   'account'],
#  ['still', 'heard', 'order', 'still', 'pending', 'app', 'please', 'reach'],
#  ['access', 'account', 'cel', 'doesnt', 'receive', 'msm', 'code', 'number'],
#  ['phone', 'number', 'email', 'iam', 'located', 'chihuahua', 'mexico'],
#  ['please', 'respond', 'dm', 'concerning', 'uber', 'rewards'],
#  ['hey',
#   'need',
#   'help',
#   'account',
#   'need',
#   'get',
#   'back',
#   'know',
#   'email',
#   'registration',
#   'pending',
#   'pending',
#   'week',
#   'please',
#   'help'],
#  ['linked',
#   'nhs',
#   'email',
#   'uber',
#   'account',
#   'long',
#   'take',
#   'get',
#   'code',
#   'thanks'],
#  ['ill',
#   'reaching',
#   'near',
#   'future',
#   'im',
#   'disgusted',
#   'even',
#   'talk',
#   'people',
#   'today'],
#  ['absolute',
#   'worst',
#   'trying',
#   'coming',
#   'days',
#   'get',
#   'tax',
#   'information',
#   'issue',
#   'got',
#   'problem',
#   'solved',
#   'less',
#   'minutes',
#   'uberistrash'],
#  ['hey',
#   'uber',
#   'received',
#   'ubereats',
#   'nhs',
#   'promotion',
#   'code',
#   'email',
#   'yet',
#   'help',
#   'please'],
#  ['signed',
#   'driver',
#   'got',
#   'message',
#   'contact',
#   'support',
#   'due',
#   'coronavirus'],
#  ['anyone', 'customer', 'service', 'anyone', 'answering'],
#  ['need', 'help', 'promo', 'code'],
#  ['need', 'speak', 'someone', 'setting', 'corporate', 'account'],
#  ['sent', 'two', 'dm', 'keep', 'getting', 'automated', 'response', 'covid'],
#  ['documentation',
#   'need',
#   'give',
#   'prove',
#   'unable',
#   'renew',
#   'license',
#   'plate',
#   'registration',
#   'since',
#   'emissions',
#   'stations',
#   'closed',
#   'illinois',
#   'extended',
#   'expiration',
#   'dates',
#   'days',
#   'past',
#   'time',
#   'lockdown',
#   'ended'],
#  ['uber', 'eats', 'order', 'never', 'arrived', 'someone', 'please', 'reach'],
#  ['hi',
#   'trying',
#   'add',
#   'nhs',
#   'discount',
#   'account',
#   'try',
#   'verify',
#   'email',
#   'address',
#   'opens',
#   'duplicate',
#   'tab',
#   'browser',
#   'please',
#   'help'],
#  ['leeches',
#   'parasites',
#   'world',
#   'surprised',
#   'make',
#   'fact',
#   'drain',
#   'country'],
#  ['need',
#   'help',
#   'approval',
#   'uber',
#   'eats',
#   'deliver',
#   'partner',
#   'documents',
#   'days',
#   'since',
#   'uploaded',
#   'please',
#   'help'],
#  ['need', 'send', 'bank', 'transactions', 'review', 'tell', 'send'],
#  ['hi', 'nhs', 'staff', 'code', 'yet'],
#  ['dm', 'requested', 'got', 'response', 'help', 'number', 'please', 'respond'],
#  ['issue', 'lol', 'taken', 'care'],
#  ['work',
#   'nhs',
#   'activated',
#   'code',
#   'free',
#   'rides',
#   'still',
#   'received',
#   'email',
#   'regarding',
#   'uber',
#   'eats'],
#  ['one', 'answered', 'dozen', 'times', 'sent'],
#  ['able', 'app', 'working'],
#  ['promo', 'code', 'valid', 'today', 'work', 'checkout'],
#  ['ordered',
#   'food',
#   'almost',
#   'hours',
#   'app',
#   'still',
#   'unable',
#   'find',
#   'driver',
#   'pick',
#   'food',
#   'eta',
#   'time',
#   'keep',
#   'going',
#   'canceled',
#   'get',
#   'charge',
#   'fee',
#   'lose',
#   'promo',
#   'fault',
#   'app',
#   'cant',
#   'find',
#   'driver'],
#  ['replied', 'never', 'got', 'response'],
#  ['license',
#   'expired',
#   'renew',
#   'dmv',
#   'closed',
#   'service',
#   'state',
#   'extended',
#   'expiration',
#   'days',
#   'drive',
#   'update',
#   'license',
#   'yet'],
#  ['order', 'waiting', 'hrs'],
#  ['tried',
#   'set',
#   'uber',
#   'eats',
#   'business',
#   'account',
#   'days',
#   'ago',
#   'hold',
#   'around',
#   'hours',
#   'phone',
#   'times',
#   'already',
#   'either',
#   'one',
#   'someone',
#   'transferred',
#   'nothing',
#   'set',
#   'new',
#   'restaurant',
#   'trying',
#   'set',
#   'delivery'],
#  ['sending', 'phone', 'number', 'twitter', 'even', 'dms'],
#  ['tried',
#   'set',
#   'uber',
#   'eats',
#   'business',
#   'account',
#   'days',
#   'ago',
#   'hold',
#   'around',
#   'hours',
#   'phone',
#   'times',
#   'already',
#   'either',
#   'one',
#   'someone',
#   'transferred',
#   'nothing',
#   'set',
#   'new',
#   'restaurant',
#   'trying',
#   'set',
#   'delivery'],
#  ['middle',
#   'maddening',
#   'case',
#   'support',
#   'reps',
#   'clearly',
#   'even',
#   'reading',
#   'messages',
#   'looking',
#   'screenshots',
#   'getting',
#   'canned',
#   'responses',
#   'might',
#   'well',
#   'delete',
#   'account',
#   'already'],
#  ['goog',
#   'guys',
#   'really',
#   'add',
#   'automated',
#   'chat',
#   'response',
#   'sets',
#   'expectations',
#   'instead',
#   'response'],
#  ['changed',
#   'email',
#   'address',
#   'still',
#   'recieved',
#   'message',
#   'uber',
#   'eats',
#   'code',
#   'trying',
#   'suss',
#   'behalf',
#   'us',
#   'hosp',
#   'dying',
#   'pizza'],
#  ['sent'],
#  ['lucky',
#   'talked',
#   'live',
#   'person',
#   'email',
#   'support',
#   'takes',
#   'hrs',
#   'get',
#   'reply',
#   'back'],
#  ['uber',
#   'driver',
#   'almost',
#   'year',
#   'would',
#   'like',
#   'able',
#   'drive',
#   'uber',
#   'eats',
#   'well',
#   'get',
#   'capability'],
#  ['read', 'looks', 'like', 'tip', 'drivers', 'restaurants', 'pick', 'stuff'],
#  ['need', 'years', 'ago', 'funny', 'story', 'get', 'tell'],
#  ['phone', 'number', 'going', 'twitter', 'even', 'dms'],
#  ['hey',
#   'really',
#   'cool',
#   'charged',
#   'ride',
#   'direct',
#   'means',
#   'customer',
#   'service'],
#  ['dm'],
#  ['nhs', 'code', 'uber', 'eats', 'arrived', 'nhs', 'mail', 'account'],
#  ['thank', 'added', 'details', 'requested'],
#  ['shame',
#   'uber',
#   'set',
#   'qualifications',
#   'make',
#   'getting',
#   'payment',
#   'impossible'],
#  ['thanks', 'help'],
#  ['got',
#   'response',
#   'really',
#   'answer',
#   'grammatically',
#   'correct',
#   'enough',
#   'actually',
#   'tell',
#   'mean',
#   'concerned',
#   'account',
#   'compromised',
#   'getting',
#   'bunch',
#   'needless',
#   'messages',
#   'phone',
#   'please',
#   'try',
#   'harder'],
#  ['hospitals',
#   'cant',
#   'legally',
#   'put',
#   'documentation',
#   'quarantine',
#   'covid',
#   'unless',
#   'tested',
#   'test',
#   'positive',
#   'uber',
#   'requires',
#   'covid',
#   'specifically',
#   'noted',
#   'reason',
#   'quarantined',
#   'tested',
#   'results',
#   'immediate',
#   'impossible',
#   'get',
#   'paid'],
#  ['dynamic', 'day', 'dollars', 'way', 'pay', 'go', 'blocks'],
#  ['think',
#   'uber',
#   'want',
#   'approve',
#   'documents',
#   'reduce',
#   'amount',
#   'drivers'],
#  ['still',
#   'need',
#   'customer',
#   'support',
#   'ubereats',
#   'tablet',
#   'working',
#   'cannot',
#   'get',
#   'thru',
#   'ubereats',
#   'phone',
#   'please',
#   'live',
#   'person',
#   'contact',
#   'us'],
#  ['uploaded',
#   'insurance',
#   'days',
#   'ago',
#   'still',
#   'times',
#   'still',
#   'pending',
#   'expire',
#   'suppose'],
#  ['ordered',
#   'ramen',
#   'pickup',
#   'way',
#   'tip',
#   'restaurant',
#   'figure',
#   'intuitively',
#   'ubereats',
#   'tipyourwaitstaff',
#   'covid',
#   'yow',
#   'hospitalityindustry',
#   'socialdistancing',
#   'covidottawa',
#   'uber'],
#  ['use', 'nhs', 'discount', 'ubereats'],
#  ['cant',
#   'get',
#   'app',
#   'link',
#   'email',
#   'one',
#   'sent',
#   'delete',
#   'account',
#   'let',
#   'start'],
#  ['way',
#   'disable',
#   'uber',
#   'cash',
#   'used',
#   'rider',
#   'using',
#   'business',
#   'profile'],
#  ['hi',
#   'made',
#   'order',
#   'order',
#   'completely',
#   'wrong',
#   'told',
#   'delivery',
#   'driver',
#   'said',
#   'problem',
#   'restaurant',
#   'called'],
#  ['already',
#   'contacted',
#   'night',
#   'incident',
#   'told',
#   'look',
#   'thats',
#   'communication'],
#  ['received',
#   'uber',
#   'code',
#   'via',
#   'sms',
#   'even',
#   'though',
#   'accessed',
#   'app',
#   'two',
#   'weeks',
#   'account',
#   'compromised',
#   'could',
#   'glitch',
#   'thank'],
#  ['resolved', 'thank'],
#  ['got',
#   'money',
#   'taken',
#   'account',
#   'used',
#   'uber',
#   'almost',
#   'year',
#   'please',
#   'help'],
#  ['agree',
#   'rosie',
#   'try',
#   'talking',
#   'sometime',
#   'joke',
#   'nothing',
#   'canned',
#   'responses',
#   'till',
#   'run',
#   'read',
#   'anything',
#   'else',
#   'help',
#   'today',
#   'uber'],
#  ['received', 'email', 'ubereats', 'promo', 'code', 'nhs', 'workers', 'get'],
#  ['thanks',
#   'replied',
#   'hrs',
#   'ago',
#   'response',
#   'yet',
#   'better',
#   'efficient',
#   'way',
#   'support',
#   'access',
#   'account',
#   'hrs',
#   'since',
#   'initia',
#   'contact',
#   'moved',
#   'inch',
#   'resolving'],
#  ['hi',
#   'trying',
#   'make',
#   'account',
#   'nhs',
#   'id',
#   'claim',
#   'free',
#   'ride',
#   'food',
#   'however',
#   'got',
#   'uber',
#   'mobile',
#   'number',
#   'already',
#   'allowing',
#   'way',
#   'round',
#   'please'],
#  ['believe',
#   'please',
#   'explain',
#   'understand',
#   'decision',
#   'unfair',
#   'bias',
#   'incorrect',
#   'pax',
#   'accusations',
#   'based',
#   'odor',
#   'shall',
#   'lawyer',
#   'false',
#   'accusations',
#   'really',
#   'unfair',
#   'really',
#   'need',
#   'assistance'],
#  ['uber', 'pay', 'drivers'],
#  ['thanks',
#   'pass',
#   'along',
#   'appears',
#   'user',
#   'error',
#   'hope',
#   'find',
#   'use'],
#  ['hold', 'support', 'hopefully', 'figure'],
#  ['happened',
#   'talk',
#   'earlier',
#   'steps',
#   'going',
#   'protect',
#   'driver',
#   'partners',
#   'pandemic',
#   'supposed',
#   'supply',
#   'us',
#   'sanitizers',
#   'abd',
#   'kinds',
#   'stuff',
#   'instead',
#   'close',
#   'leave',
#   'us',
#   'hanging',
#   'good',
#   'job'],
#  ['fever',
#   'still',
#   'feeling',
#   'like',
#   'shit',
#   'something',
#   'going',
#   'cost',
#   'lives',
#   'cannot',
#   'sit',
#   'let',
#   'happen'],
#  ['unable', 'go', 'online', 'driver', 'restricted', 'access', 'drivers'],
#  ['hey', 'im', 'place', 'uber', 'eats', 'order', 'cant', 'keep', 'getting'],
#  ['dm', 'alot', 'people', 'point', 'willing', 'meet'],
#  ['update'],
#  ['mama', 'never', 'raised', 'snitch'],
#  ['hello',
#   'thanks',
#   'kind',
#   'free',
#   'meal',
#   'offer',
#   'nhs',
#   'finished',
#   'long',
#   'shift',
#   'would',
#   'love',
#   'food',
#   'sent',
#   'promo',
#   'code',
#   'yet',
#   'could',
#   'please',
#   'send',
#   'sarah'],
#  ['please',
#   'update',
#   'driver',
#   'navigation',
#   'app',
#   'townsend',
#   'street',
#   'suggested',
#   'dropoff',
#   'caltrain',
#   'station',
#   'bike',
#   'lane',
#   'dangerous',
#   'stopping',
#   'allowed'],
#  ['great', 'decision', 'worstcompany'],
#  ['boys',
#   'girls',
#   'rideshare',
#   'world',
#   'refer',
#   'paxhole',
#   'word',
#   'used',
#   'interchangeably',
#   'arsehole',
#   'asshole',
#   'anus'],
#  ['hi',
#   'trying',
#   'use',
#   'discount',
#   'code',
#   'due',
#   'expire',
#   'end',
#   'today',
#   'working',
#   'says',
#   'promotion',
#   'expired'],
#  ['rating', 'apps', 'work'],
#  ['seriously', 'week', 'disappointing'],
#  ['verify',
#   'documents',
#   'background',
#   'check',
#   'week',
#   'could',
#   'appreciate',
#   'work'],
#  ['thanks'],
#  ['blind',
#   'voiceover',
#   'user',
#   'please',
#   'let',
#   'know',
#   'order',
#   'coke',
#   'ice',
#   'mcdonalds',
#   'since',
#   'refuse',
#   'fix',
#   'bug',
#   'customization',
#   'screen'],
#  ['surely',
#   'going',
#   'possible',
#   'please',
#   'dm',
#   'us',
#   'additional',
#   'details',
#   'experience',
#   'team',
#   'assist',
#   'appreciate',
#   'chance',
#   'review',
#   'concerns'],
#  ['difficult',
#   'find',
#   'phone',
#   'number',
#   'need',
#   'call',
#   'complain',
#   'food',
#   'order',
#   'morning',
#   'want',
#   'refund',
#   'want',
#   'wait',
#   'hours',
#   'want',
#   'food',
#   'hungry',
#   'understand',
#   'please',
#   'give',
#   'number'],
#  ['keep', 'sending', 'dm', 'provide', 'assistance'],
#  ['need',
#   'help',
#   'account',
#   'car',
#   'insurance',
#   'still',
#   'pending',
#   'need',
#   'get',
#   'second',
#   'day',
#   'loosing',
#   'money',
#   'please',
#   'fix',
#   'account'],
#  ['im',
#   'unable',
#   'cancel',
#   'uber',
#   'pass',
#   'never',
#   'signed',
#   'uber',
#   'pass',
#   'get',
#   'canceled',
#   'get',
#   'refund',
#   'money',
#   'tight',
#   'unacceptable'],
#  ['done', 'thank'],
#  ['yesterday',
#   'governor',
#   'maryland',
#   'said',
#   'one',
#   'leave',
#   'house',
#   'unless',
#   'essential',
#   'job',
#   'go',
#   'doctor',
#   'would',
#   'like',
#   'know',
#   'continue',
#   'uber',
#   'eats',
#   'need',
#   'letter'],
#  ['issue'],
#  ['calling',
#   'chicago',
#   'based',
#   'uber',
#   'drivers',
#   'planning',
#   'protest',
#   'outside',
#   'uber',
#   'greenlight',
#   'hub',
#   'north',
#   'ave',
#   'wants'],
#  ['download',
#   'invoice',
#   'homepage',
#   'options',
#   'file',
#   'support',
#   'case',
#   'bad',
#   'performance'],
#  ['dm', 'sent'],
#  ['received',
#   'nhs',
#   'uber',
#   'eat',
#   'code',
#   'registered',
#   'yesterday',
#   'thank'],
#  ['would',
#   'need',
#   'taxi',
#   'outstation',
#   'travel',
#   'medical',
#   'condition',
#   'arrange',
#   'pass',
#   'uninterrupted',
#   'journey',
#   'please',
#   'suggest',
#   'possible',
#   'destination',
#   'bhadohi',
#   'approx',
#   'km',
#   'delhi'],
#  ['heys',
#   'guys',
#   'helping',
#   'covid',
#   'sent',
#   'documents',
#   'guys',
#   'answering'],
#  ['thank', 'hard', 'work', 'thankyounhs'],
#  ['free', 'food', 'nhs', 'code', 'work'],
#  ['wont', 'work', 'dude', 'haha', 'cheerio'],
#  ['uber',
#   'want',
#   'pay',
#   'days',
#   'financial',
#   'aid',
#   'affected',
#   'corona',
#   'virus',
#   'hospital',
#   'tell',
#   'lock',
#   'home',
#   'symptoms'],
#  ['sorry',
#   'hear',
#   'seems',
#   'uber',
#   'overwhelmed',
#   'many',
#   'new',
#   'drivers',
#   'joining',
#   'uber',
#   'due',
#   'unemployment',
#   'uber',
#   'also',
#   'cancelled',
#   'referral',
#   'bonus',
#   'joke',
#   'ideas',
#   'free',
#   'book',
#   'work',
#   'home',
#   'free',
#   'ebook',
#   'makemoney',
#   'workfromhome',
#   'take',
#   'care'],
#  ['weeks',
#   'old',
#   'risk',
#   'two',
#   'passengers',
#   'driving',
#   'presenting',
#   'symptoms',
#   'hospital',
#   'denied',
#   'medical',
#   'attention',
#   'uber',
#   'denied',
#   'financial',
#   'help',
#   'stay',
#   'locked',
#   'home'],
#  ['impossible'],
#  ['question',
#   'able',
#   'access',
#   'accounts',
#   'drivers',
#   'shoppers',
#   'adjust',
#   'acceptance',
#   'ratings',
#   'seems',
#   'like',
#   'simple',
#   'thing',
#   'implement',
#   'anything',
#   'done',
#   'fix'],
#  ['still', 'find', 'help'],
#  ['th',
#   'day',
#   'since',
#   'uploaded',
#   'insurance',
#   'certificate',
#   'still',
#   'pending',
#   'without',
#   'covid',
#   'unacceptable',
#   'apologises',
#   'put',
#   'food',
#   'table',
#   'pay',
#   'bills'],
#  ['five', 'days', 'still', 'waiting', 'respond', 'please', 'help'],
#  ['trying',
#   'add',
#   'nhs',
#   'account',
#   'existin',
#   'uber',
#   'account',
#   'unable',
#   'says',
#   'cannot',
#   'send',
#   'email',
#   'account',
#   'help'],
#  ['support',
#   'site',
#   'uber',
#   'eats',
#   'work',
#   'trying',
#   'get',
#   'help',
#   'since',
#   'order',
#   'never',
#   'delivered',
#   'last',
#   'saturday',
#   'app',
#   'marked',
#   'delivered',
#   'want',
#   'money',
#   'back'],
#  ['taking', 'two', 'days', 'approve', 'insurance', 'doc', 'unacceptable'],
#  ['deleting', 'never', 'using'],
#  ['need', 'contact', 'uber'],
#  ['uber',
#   'told',
#   'weeks',
#   'one',
#   'point',
#   'right',
#   'supposed',
#   'business',
#   'days',
#   'wtaf'],
#  ['resolved', 'quickly', 'thank', 'much'],
#  ['still',
#   'waiting',
#   'uberdriver',
#   'uber',
#   'driverssupport',
#   'uberseattle',
#   'kingcounty',
#   'wa'],
#  ['help',
#   'understand',
#   'rating',
#   'trips',
#   'account',
#   'put',
#   'hold',
#   'need',
#   'consent',
#   'background',
#   'check',
#   'agreed',
#   'many',
#   'terms',
#   'gives',
#   'consent',
#   'drive',
#   'continually',
#   'provided',
#   'par',
#   'service'],
#  ['new',
#   'jersey',
#   'motor',
#   'vehicle',
#   'agencies',
#   'closed',
#   'month',
#   'extension',
#   'documents',
#   'despite',
#   'trying',
#   'proactive',
#   'uber',
#   'put',
#   'platform',
#   'morning',
#   'global',
#   'pandemic',
#   'making',
#   'bad',
#   'situation',
#   'worse'],
#  ['registered',
#   'nhs',
#   'email',
#   'account',
#   'added',
#   'nhs',
#   'promo',
#   'promo',
#   'showing',
#   'uber',
#   'eats',
#   'uber',
#   'try',
#   'enter',
#   'checkout',
#   'says',
#   'enter',
#   'code',
#   'twice',
#   'discount',
#   'applied',
#   'please',
#   'help'],
#  ['received',
#   'email',
#   'saying',
#   'charged',
#   'cancelled',
#   'ride',
#   'yet',
#   'corporate',
#   'card',
#   'charged',
#   'yesterday',
#   'assist'],
#  ['given',
#   'complete',
#   'documents',
#   'including',
#   'everything',
#   'told',
#   'needed',
#   'pmt',
#   'took',
#   'platform',
#   'based',
#   'documents',
#   'end',
#   'quarantine',
#   'refusing',
#   'pay'],
#  ['need',
#   'copy',
#   'cases',
#   'covid',
#   'yall',
#   'dealt',
#   'fucking',
#   'way',
#   'able',
#   'use',
#   'uber',
#   'cash',
#   'week',
#   'response',
#   'legit',
#   'fucking',
#   'messages',
#   'told'],
#  ['orderedmeal',
#   'food',
#   'arrived',
#   'cold',
#   'chicken',
#   'felt',
#   'like',
#   'old',
#   'kept',
#   'chicken',
#   'last',
#   'dhs',
#   'compensation',
#   'dhs',
#   'order',
#   'enough',
#   'need',
#   'refund',
#   'back',
#   'asap',
#   'worst',
#   'food',
#   'delivery',
#   'expected'],
#  ['nobody',
#   'addressing',
#   'issue',
#   'uber',
#   'required',
#   'incomplete',
#   'uber',
#   'took',
#   'platform',
#   'despite',
#   'required',
#   'uber',
#   'refusing',
#   'pay',
#   'single',
#   'mom',
#   'please',
#   'help',
#   'shieldvoc'],
#  ['store',
#   'cancel',
#   'order',
#   'arrived',
#   'store',
#   'didnt',
#   'compensation',
#   'money',
#   'cancel',
#   'order'],
#  ['know', 'hopefully', 'get', 'one', 'later', 'today', 'tomorrow'],
#  ['ima',
#   'post',
#   'supporting',
#   'documents',
#   'conversations',
#   'show',
#   'drivers',
#   'may',
#   'issue',
#   'gave',
#   'false',
#   'hope'],
#  ['offered',
#   'drivers',
#   'financial',
#   'assistance',
#   'taken',
#   'road',
#   'gave',
#   'false',
#   'hope',
#   'instead',
#   'said',
#   'help',
#   'drivers',
#   'taken',
#   'road',
#   'lay',
#   'turn',
#   'app',
#   'tell',
#   'deal'],
#  ['lose',
#   'gold',
#   'status',
#   'virus',
#   'chosen',
#   'drive',
#   'taking',
#   'classes',
#   'asu',
#   'right',
#   'want',
#   'lose',
#   'ability',
#   'get',
#   'paid',
#   'uber',
#   'thanks'],
#  ['disabled',
#   'app',
#   'able',
#   'make',
#   'money',
#   'feed',
#   'goes',
#   'denies',
#   'assistance',
#   'even',
#   'though',
#   'documents',
#   'saying',
#   'drive',
#   'find',
#   'good',
#   'companies',
#   'times',
#   'like'],
#  ['please', 'check', 'dm'],
#  ['since',
#   'seen',
#   'elsewhere',
#   'twitter',
#   'offer',
#   'available',
#   'first',
#   'despite',
#   'cs',
#   'pretty',
#   'sure',
#   'legal',
#   'anyway',
#   'delete',
#   'app',
#   'justeat',
#   'cheaper',
#   'reliable'],
#  ['thanks', 'never', 'use', 'uber', 'service'],
#  ['simply',
#   'type',
#   'steps',
#   'taking',
#   'ensure',
#   'driver',
#   'ill',
#   'words',
#   'none',
#   'uber',
#   'might',
#   'greatest',
#   'threat',
#   'health',
#   'safety',
#   'employed',
#   'many',
#   'terrorists',
#   'know',
#   'guess',
#   'germ',
#   'warfare',
#   'next',
#   'uber',
#   'scary'],
#  ['willing',
#   'pay',
#   'way',
#   'get',
#   'contact',
#   'someone',
#   'need',
#   'one',
#   'document',
#   'reviewed',
#   'approved',
#   'even',
#   'new',
#   'document',
#   'updated',
#   'one',
#   'account',
#   'hold',
#   'almost',
#   'days',
#   'limited',
#   'staff',
#   'quick',
#   'fix'],
#  ['anyone',
#   'unpublished',
#   'phone',
#   'numbers',
#   'know',
#   'someone',
#   'work',
#   'uber',
#   'uber',
#   'support',
#   'dm',
#   'woth',
#   'info',
#   'need',
#   'drive',
#   'days',
#   'zero',
#   'income',
#   'done',
#   'nothing',
#   'wrong',
#   'except',
#   'choose',
#   'drive',
#   'versus',
#   'need',
#   'one',
#   'person'],
#  ['waiting',
#   'two',
#   'circles',
#   'expand',
#   'year',
#   'software',
#   'design',
#   'issue',
#   'deliver',
#   'locations',
#   'neighborhood',
#   'drive',
#   'house',
#   'add',
#   'feature',
#   'something',
#   'people',
#   'trying',
#   'food',
#   'delivery',
#   'right'],
#  ['wow',
#   'bull',
#   'drivers',
#   'fam',
#   'got',
#   'uber',
#   'cash',
#   'credits',
#   'gave',
#   'cant',
#   'use',
#   'em',
#   'cause',
#   'invalid',
#   'keep',
#   'trying',
#   'get',
#   'shit',
#   'make',
#   'sense',
#   'screen',
#   'shot',
#   'phone',
#   'setting',
#   'ro',
#   'price',
#   'number',
#   'real',
#   'illegal'],
#  ['account', 'activation', 'email', 'number'],
#  ['hi', 'kylie', 'please', 'direct', 'inquiry', 'able', 'assist'],
#  ['already', 'reached', 'via', 'link', 'check', 'dms', 'please'],
#  ['worst',
#   'customer',
#   'service',
#   'ever',
#   'dealt',
#   'stuck',
#   'home',
#   'trying',
#   'order',
#   'food',
#   'contacted',
#   'via',
#   'dms',
#   'get',
#   'automated',
#   'message',
#   'trying',
#   'order',
#   'breakfast',
#   'family'],
#  ['still',
#   'willing',
#   'put',
#   'risk',
#   'financial',
#   'option',
#   'suspended',
#   'account',
#   'expired',
#   'document',
#   'even',
#   'though',
#   'current',
#   'one',
#   'provided',
#   'many',
#   'days',
#   'expiration',
#   'days',
#   'waited',
#   'one',
#   'person',
#   'review'],
#  ['sure',
#   'allowed',
#   'buy',
#   'voucher',
#   'us',
#   'dollars',
#   'refund',
#   'quote',
#   'happy',
#   'hear',
#   'experience',
#   'described',
#   'unfortunately',
#   'making',
#   'refunds'],
#  ['day',
#   'still',
#   'waiting',
#   'response',
#   'emailed',
#   'year',
#   'ago',
#   'last',
#   'week',
#   'able',
#   'create',
#   'account',
#   'today',
#   'uber',
#   'ubereats',
#   'ubersupport',
#   'uberfail',
#   'ubereatsfail',
#   'ubercustomerservice',
#   'rideshareapp',
#   'ridesharing',
#   'fooddelivery'],
#  ['ive',
#   'lost',
#   'gift',
#   'code',
#   'due',
#   'ur',
#   'system',
#   'days',
#   'still',
#   'help',
#   'fuck'],
#  ['want',
#   'organize',
#   'protest',
#   'outside',
#   'ubers',
#   'greenlight',
#   'hub',
#   'chicago'],
#  ['moved',
#   'delaware',
#   'set',
#   'open',
#   'inspection',
#   'test',
#   'place',
#   'hours',
#   'away',
#   'tolls',
#   'uber',
#   'pay',
#   'car',
#   'tiguan',
#   'vw'],
#  ['fix',
#   'support',
#   'system',
#   'suspended',
#   'accounts',
#   'resources',
#   'available',
#   'review',
#   'doxuments',
#   'perhaps',
#   'time',
#   'change',
#   'review',
#   'process',
#   'still',
#   'earn',
#   'living'],
#  ['talking',
#   'trip',
#   'showing',
#   'link',
#   'talking',
#   'trip',
#   'ordered',
#   'yesterday',
#   'mins',
#   'going',
#   'charged',
#   'order',
#   'total',
#   'taking',
#   'advantage',
#   'situation',
#   'make',
#   'profit'],
#  ['nothing',
#   'delivery',
#   'fee',
#   'service',
#   'charge',
#   'tip',
#   'right',
#   'add',
#   'another',
#   'tip',
#   'restaurants',
#   'option',
#   'adding',
#   'tip',
#   'placing',
#   'online',
#   'order',
#   'ubereats'],
#  ['days',
#   'starving',
#   'girl',
#   'tries',
#   'help',
#   'deactivate',
#   'acc',
#   'use',
#   'code',
#   'wasting',
#   'ppl',
#   'money'],
#  ['also',
#   'try',
#   'contact',
#   'paypal',
#   'bank',
#   'fighting',
#   'covid',
#   'bad',
#   'getting',
#   'hold',
#   'uber',
#   'eats',
#   'even',
#   'worse',
#   'would',
#   'rather',
#   'spend',
#   'days',
#   'relaxing',
#   'stressing',
#   'losing',
#   'money'],
#  ['also',
#   'tried',
#   'cancel',
#   'order',
#   'vendor',
#   'cancel',
#   'food',
#   'left',
#   'outside',
#   'door',
#   'thank',
#   'uber',
#   'eats',
#   'totally',
#   'messing',
#   'day',
#   'emergency',
#   'ambulance',
#   'day',
#   'resting',
#   'ringing',
#   'around'],
#  ['would',
#   'also',
#   'like',
#   'report',
#   'serious',
#   'payment',
#   'option',
#   'breach',
#   'point',
#   'authorise',
#   'save',
#   'paypal',
#   'payment',
#   'details',
#   'pressing',
#   'paypal',
#   'option',
#   'take',
#   'paypal',
#   'site',
#   'pay',
#   'items',
#   'purchased',
#   'uber',
#   'eats',
#   'company'],
#  ['fuck',
#   'cannot',
#   'one',
#   'members',
#   'uber',
#   'leadership',
#   'team',
#   'leaders',
#   'reach',
#   'lifeblood',
#   'company',
#   'dont',
#   'give',
#   'shit',
#   'drivers'],
#  ['help',
#   'quarantined',
#   'documents',
#   'submitted',
#   'uber',
#   'took',
#   'platform',
#   'end',
#   'quarantine',
#   'still',
#   'platform',
#   'uber',
#   'pay',
#   'promised'],
#  ['thanks',
#   'reply',
#   'taking',
#   'delivery',
#   'though',
#   'talking',
#   'food',
#   'preparation',
#   'guarantee',
#   'chef',
#   'symptoms',
#   'spreading',
#   'virus',
#   'delivering',
#   'food',
#   'responsibility',
#   'customers',
#   'make',
#   'ill'],
#  ['help',
#   'quarantined',
#   'documents',
#   'submitted',
#   'uber',
#   'took',
#   'platform',
#   'end',
#   'quarantine',
#   'still',
#   'platform',
#   'uber',
#   'pay',
#   'promised'],
#  ['sent',
#   'info',
#   'right',
#   'away',
#   'hope',
#   'hear',
#   'would',
#   'make',
#   'sense',
#   'send',
#   'excel',
#   'bank',
#   'transactions',
#   'ahead',
#   'time',
#   'go',
#   'initial',
#   'explanation'],
#  ['appears',
#   'uber',
#   'stopped',
#   'supporting',
#   'drivers',
#   'absolutely',
#   'zero',
#   'response',
#   'via',
#   'avenue',
#   'smh',
#   'good',
#   'news',
#   'lyft',
#   'supporting',
#   'users',
#   'add',
#   'vehicle',
#   'normal',
#   'car',
#   'shop',
#   'lyft',
#   'driving',
#   'mins',
#   'waiting',
#   'uber',
#   'week'],
#  ['recieved',
#   'email',
#   'wont',
#   'helping',
#   'taken',
#   'account',
#   'recieved',
#   'email',
#   'charge',
#   'order',
#   'make'],
#  ['taken', 'care', 'already', 'thanks'],
#  ['sent', 'guys', 'message'],
#  ['everything',
#   'comes',
#   'put',
#   'mouths',
#   'nothing',
#   'lies',
#   'submitted',
#   'damn',
#   'paperwork',
#   'asked',
#   'claim',
#   'denied',
#   'suck'],
#  ['crazy',
#   'drivers',
#   'take',
#   'money',
#   'never',
#   'pick',
#   'defend',
#   'refund',
#   'us',
#   'better',
#   'go',
#   'guess'],
#  ['update',
#   'order',
#   'cancelled',
#   'also',
#   'pressed',
#   'paypal',
#   'take',
#   'paypal',
#   'sign',
#   'took',
#   'money',
#   'straight',
#   'away',
#   'without',
#   'signing',
#   'security',
#   'breached',
#   'time',
#   'authorise',
#   'save',
#   'details'],
#  ['keep', 'rejecting', 'drivers', 'license', 'drive', 'uber', 'eats'],
#  ['careful', 'posting', 'online'],
#  ['order',
#   'restaurant',
#   'still',
#   'open',
#   'explicitly',
#   'selecting',
#   'want',
#   'order',
#   'fulfilled',
#   'later',
#   'opened'],
#  ['okay',
#   'spoke',
#   'someone',
#   'app',
#   'really',
#   'resolve',
#   'issue',
#   'take',
#   'bank',
#   'instead',
#   'thanks',
#   'reaching'],
#  ['hey',
#   'talked',
#   'rep',
#   'phone',
#   'sent',
#   'several',
#   'messages',
#   'week',
#   'one',
#   'turn',
#   'ubereats',
#   'please',
#   'help'],
#  ['know',
#   'change',
#   'tip',
#   'made',
#   'one',
#   'ubereats',
#   'tip',
#   'first',
#   'place',
#   'cannot'],
#  ['totally', 'agree'],
#  ['contacting', 'bank', 'charge', 'back', 'order', 'cancelled', 'uber'],
#  ['neither'],
#  ['shocking',
#   'service',
#   'uber',
#   'eats',
#   'one',
#   'answering',
#   'phones',
#   'cancelled',
#   'order',
#   'cancellation',
#   'confirmations',
#   'cancelled',
#   'instantly',
#   'within',
#   'seconds',
#   'promo',
#   'applied',
#   'discount',
#   'subtracted',
#   'total',
#   'contact',
#   'method',
#   'rediculous',
#   'nobody',
#   'answering'],
#  ['hi',
#   'couple',
#   'promo',
#   'codes',
#   'ubereats',
#   'account',
#   'use',
#   'australia',
#   'please',
#   'help'],
#  ['think', 'someone', 'trying', 'use', 'uber', 'account'],
#  ['uber',
#   'eats',
#   'credits',
#   'unable',
#   'use',
#   'credits',
#   'zomato',
#   'benefit',
#   'given',
#   'zomato',
#   'like',
#   'free',
#   'zomato',
#   'gold',
#   'membership'],
#  ['financial', 'support', 'guarantee', 'uber'],
#  ['top',
#   'priority',
#   'follow',
#   'sir',
#   'uber',
#   'cancellation',
#   'trending',
#   'finding',
#   'solutions',
#   'reoccurring',
#   'issues',
#   'hyderabad',
#   'secunderabad',
#   'delhi',
#   'bengaluru',
#   'chennai',
#   'kolkata',
#   'mumbai'],
#  ['done',
#   'twice',
#   'first',
#   'time',
#   'lot',
#   'decided',
#   'ignore',
#   'next',
#   'one',
#   'force',
#   'fixed'],
#  ['done', 'thanks'],
#  ['issue',
#   'order',
#   'day',
#   'kindly',
#   'refunded',
#   'part',
#   'money',
#   'checked',
#   'bank',
#   'statement',
#   'money',
#   'refunded',
#   'taken',
#   'along',
#   'original',
#   'price',
#   'meal',
#   'taking',
#   'account',
#   'double',
#   'meal',
#   'cost'],
#  ['sending', 'dms', 'nobody', 'reply', 'need', 'help', 'please'],
#  ['acct',
#   'hold',
#   'expired',
#   'uploaded',
#   'txdeptofpublic',
#   'safety',
#   'letter',
#   'officialy',
#   'authorizing',
#   'days',
#   'extension',
#   'online',
#   'ironical',
#   'represent',
#   'uber',
#   'well',
#   'treated',
#   'system',
#   'fails',
#   'us',
#   'go',
#   'work'],
#  ['thank', 'much', 'support'],
#  ['hello',
#   'enough',
#   'uber',
#   'rewards',
#   'apple',
#   'news',
#   'subscription',
#   'two',
#   'months',
#   'disappeared',
#   'chance',
#   'redeem',
#   'happened',
#   'rewards',
#   'points'],
#  ['trying',
#   'months',
#   'retrieve',
#   'invoices',
#   'travel',
#   'avail',
#   'extremely',
#   'disheartening',
#   'encounter',
#   'service'],
#  ['sent',
#   'dm',
#   'phone',
#   'number',
#   'thank',
#   'looking',
#   'matter',
#   'deactivated',
#   'expired',
#   'registration',
#   'governor',
#   'extended',
#   'deadline',
#   'till',
#   'april',
#   'th'],
#  ['sent',
#   'dm',
#   'days',
#   'ago',
#   'reply',
#   'side',
#   'till',
#   'really',
#   'upset',
#   'way',
#   'handling',
#   'customer',
#   'complaint',
#   'filed',
#   'complaint',
#   'weeks',
#   'ago',
#   'also',
#   'reply',
#   'addition',
#   'unprofessional',
#   'supervisors',
#   'phone'],
#  ['human',
#   'please',
#   'help',
#   'submitted',
#   'documentation',
#   'financial',
#   'assistance',
#   'appears',
#   'date',
#   'cut',
#   'top',
#   'image',
#   'doctors',
#   'letter',
#   'submitted',
#   'cant',
#   'get',
#   'anyone',
#   'attention',
#   'help',
#   'denied'],
#  ['added', 'uber', 'nhs', 'code', 'used', 'straight', 'away'],
#  ['hey',
#   'days',
#   'simple',
#   'updated',
#   'vehicle',
#   'inspection',
#   'submitted',
#   'days',
#   'expiration',
#   'account',
#   'hold',
#   'days',
#   'suspend',
#   'people',
#   'accounts',
#   'man',
#   'power',
#   'review',
#   'documents'],
#  ['could',
#   'please',
#   'start',
#   'thinking',
#   'outside',
#   'box',
#   'due',
#   'covid',
#   'situation',
#   'tn',
#   'licensing',
#   'commission',
#   'closed',
#   'several',
#   'drivers',
#   'unable',
#   'renew',
#   'permit',
#   'please',
#   'note',
#   'attached',
#   'screenshot',
#   'website'],
#  ['good',
#   'went',
#   'deliveroo',
#   'instead',
#   'honestly',
#   'guys',
#   'great',
#   'sort',
#   'tech',
#   'issues'],
#  ['gave',
#   'coupon',
#   'lasted',
#   'seven',
#   'days',
#   'added',
#   'code',
#   'said',
#   'expired',
#   'gives'],
#  ['holy', 'bots', 'read', 'damn', 'thing', 'one', 'twunts'],
#  ['changed', 'phone', 'cannot', 'login', 'account', 'help'],
#  ['please', 'check', 'dm'],
#  ['times',
#   'rides',
#   'still',
#   'refuse',
#   'fix',
#   'serious',
#   'safety',
#   'issue',
#   'happening',
#   'since',
#   'april',
#   'uber',
#   'absolutely',
#   'refuse',
#   'fix',
#   'serious',
#   'safety',
#   'issue'],
#  ['phone',
#   'system',
#   'says',
#   'live',
#   'order',
#   'location',
#   'closed',
#   'hiw',
#   'tti',
#   'resolve'],
#  ['frustrated',
#   'stress',
#   'figuring',
#   'refunds',
#   'canceling',
#   'issuing',
#   'new',
#   'card',
#   'still',
#   'wait',
#   'days',
#   'hacked',
#   'account',
#   'permanently',
#   'deleted',
#   'personal',
#   'information',
#   'stays',
#   'vulnerable'],
#  ['silkwood', 'phone', 'support', 'restaurant', 'closed'],
#  ['need',
#   'help',
#   'nyc',
#   'dmv',
#   'cancelled',
#   'resgistration',
#   'renewals',
#   'extended',
#   'resgistration',
#   'expiring',
#   'march',
#   'oayed',
#   'registration',
#   'jo',
#   'way',
#   'get',
#   'keep',
#   'driving',
#   'documents',
#   'expired',
#   'uber',
#   'account'],
#  ['mine', 'either', 'got', 'yet'],
#  ['payment', 'receive', 'pay', 'fair', 'us'],
#  ['theres',
#   'nothing',
#   'found',
#   'way',
#   'sending',
#   'concern',
#   'charged',
#   'multiple',
#   'times',
#   'card'],
#  ['bill',
#   'masucci',
#   'license',
#   'registration',
#   'done',
#   'two',
#   'cars',
#   'account',
#   'sold',
#   'one',
#   'bought',
#   'another'],
#  ['app',
#   'broken',
#   'charged',
#   'multiple',
#   'times',
#   'theres',
#   'support',
#   'available',
#   'app',
#   'site'],
#  ['hey',
#   'please',
#   'help',
#   'us',
#   'registered',
#   'number',
#   'uber',
#   'eats',
#   'via',
#   'private',
#   'message',
#   'look'],
#  ['dear',
#   'sir',
#   'uber',
#   'eats',
#   'sold',
#   'zomato',
#   'received',
#   'emails',
#   'promising',
#   'us',
#   'zomato',
#   'gold',
#   'membership',
#   'placed',
#   'certain',
#   'number',
#   'orders',
#   'zomato',
#   'yest',
#   'offered',
#   'us',
#   'promised',
#   'months',
#   'free',
#   'zomato',
#   'gold',
#   'membership',
#   'promised',
#   'please',
#   'followup'],
#  ['initiated',
#   'uber',
#   'pass',
#   'january',
#   'year',
#   'feature',
#   'turned',
#   'cancelled',
#   'march',
#   'utilizing',
#   'uber',
#   'foreseeable',
#   'future',
#   'please',
#   'remove',
#   'charge'],
#  ['account',
#   'deactivated',
#   'really',
#   'never',
#   'helped',
#   'represent',
#   'uber',
#   'excellence',
#   'get',
#   'crappy',
#   'deactivation',
#   'notice',
#   'email',
#   'unacceptable',
#   'pls',
#   'go',
#   'back',
#   'investigate',
#   'tx',
#   'dept',
#   'public',
#   'safety',
#   'lettr',
#   'need',
#   'income',
#   'ubereats'],
#  ['hope',
#   'guys',
#   'saved',
#   'lots',
#   'people',
#   'virus',
#   'cuz',
#   'many',
#   'replies',
#   'got',
#   'guys',
#   'guys',
#   'busy',
#   'helping',
#   'people',
#   'virus',
#   'shit'],
#  ['last', 'week', 'account', 'kept', 'hold', 'whole', 'week'],
#  ['hi',
#   'received',
#   'email',
#   'free',
#   'meals',
#   'nhs',
#   'staff',
#   'previously',
#   'linked',
#   'account',
#   'nhs',
#   'email',
#   'account',
#   'see',
#   'promotion',
#   'app'],
#  ['well',
#   'done',
#   'ola',
#   'wish',
#   'cabs',
#   'operating',
#   'india',
#   'follow',
#   'suit'],
#  ['sent', 'number', 'details'],
#  ['know',
#   'giving',
#   'contracts',
#   'driver',
#   'program',
#   'telling',
#   'us',
#   'charged',
#   'return',
#   'vehicle',
#   'barely',
#   'charging',
#   'day',
#   'called',
#   'message',
#   'saying',
#   'overdue',
#   'return'],
#  ['management',
#   'communicate',
#   'partner',
#   'drivers',
#   'regards',
#   'movement',
#   'cessation',
#   'lagos',
#   'whether',
#   'affected',
#   'next',
#   'think',
#   'big',
#   'flop',
#   'path',
#   'information',
#   'integral',
#   'part',
#   'uber',
#   'system'],
#  ['contacted',
#   'via',
#   'mobile',
#   'without',
#   'consent',
#   'response',
#   'process',
#   'ask',
#   'personal',
#   'information',
#   'want',
#   'uber',
#   'info',
#   'never',
#   'wanted',
#   'first',
#   'place',
#   'impressed'],
#  ['want',
#   'get',
#   'emergency',
#   'passengers',
#   'cab',
#   'plz',
#   'help',
#   'us',
#   'get',
#   'registered',
#   'system',
#   'wb'],
#  ['hey',
#   'thanks',
#   'free',
#   'rides',
#   'nhs',
#   'staff',
#   'meals',
#   'really',
#   'making',
#   'getting',
#   'work',
#   'easier',
#   'heroes',
#   'wear',
#   'capes',
#   'drop',
#   'work',
#   'free',
#   'charge',
#   'global',
#   'pandemic'],
#  [],
#  ['side',
#   'per',
#   'right',
#   'partners',
#   'uber',
#   'deserve',
#   'noncooperative',
#   'behavior',
#   'awaiting',
#   'positive',
#   'action',
#   'revert',
#   'please'],
#  ['close',
#   'account',
#   'expected',
#   'company',
#   'like',
#   'uber',
#   'need',
#   'know',
#   'made',
#   'allegations',
#   'uber',
#   'without',
#   'letting',
#   'justify'],
#  ['couple',
#   'negative',
#   'comments',
#   'ignoring',
#   'entire',
#   'history',
#   'work',
#   'completely',
#   'unprofessional',
#   'act',
#   'called',
#   'uber',
#   'partner',
#   'treated',
#   'like',
#   'nothing',
#   'putting',
#   'much',
#   'company'],
#  ['without',
#   'even',
#   'sharing',
#   'reason',
#   'uber',
#   'treat',
#   'loyal',
#   'hardworking',
#   'partners',
#   'specially',
#   'pandemic',
#   'situation',
#   'trying',
#   'hard',
#   'give',
#   'services',
#   'fulfilling',
#   'family',
#   'needs'],
#  ['uber',
#   'partner',
#   'months',
#   'completed',
#   'trips',
#   'ratings',
#   'many',
#   'positive',
#   'feedbacks',
#   'however',
#   'one',
#   'rider',
#   'wrong',
#   'accusation',
#   'allegations',
#   'surely',
#   'mistake',
#   'closed',
#   'account'],
#  ['please',
#   'help',
#   'time',
#   'sensitive',
#   'really',
#   'need',
#   'account',
#   'frozen'],
#  ['trying', 'hour', 'tomorrow', 'assist'],
#  ['people',
#   'hacked',
#   'account',
#   'put',
#   'step',
#   'verification',
#   'know',
#   'phone',
#   'number',
#   'need',
#   'way',
#   'delete',
#   'account',
#   'asap',
#   'please',
#   'help',
#   'scared',
#   'cards',
#   'attached',
#   'account'],
#  ['need',
#   'desperate',
#   'help',
#   'find',
#   'way',
#   'reach',
#   'guys',
#   'account',
#   'hacked',
#   'log',
#   'know',
#   'hacked',
#   'still',
#   'attached',
#   'email',
#   'address',
#   'charge',
#   'around',
#   'put',
#   'credit',
#   'card',
#   'uber',
#   'eats'],
#  ['thank'],
#  ['understand',
#   'things',
#   'busy',
#   'right',
#   'order',
#   'canceled',
#   'hour',
#   'placed',
#   'card',
#   'charged',
#   'food',
#   'made',
#   'uber',
#   'driver',
#   'restaurant',
#   'give',
#   'food',
#   'extremely',
#   'ridiculous',
#   'unprofessional',
#   'want',
#   'money'],
#  ['customer',
#   'service',
#   'email',
#   'uber',
#   'india',
#   'already',
#   'raise',
#   'request',
#   'riders',
#   'data',
#   'trip',
#   'info',
#   'know',
#   'specific',
#   'trip',
#   'arrival',
#   'time'],
#  ['midnight',
#   'fell',
#   'asleep',
#   'easily',
#   'gives',
#   'enough',
#   'time',
#   'especially',
#   'phone',
#   'dead',
#   'fell',
#   'asleep',
#   'soon',
#   'got',
#   'home',
#   'didnt',
#   'even',
#   'watch',
#   'netflix'],
#  ['worries',
#   'thank',
#   'support',
#   'app',
#   'finally',
#   'respond',
#   'appreciate',
#   'getting',
#   'back',
#   'good',
#   'night'],
#  ['sucks', 'hope', 'get', 'refunded'],
#  ['cool', 'take', 'note'],
#  ['waiting',
#   'days',
#   'submitted',
#   'documents',
#   'financial',
#   'help',
#   'tell',
#   'kids',
#   'food',
#   'delay',
#   'due',
#   'volume',
# ...
#   'worrying',
#   'money',
#   'first',
#   'last',
#   'using',
#   'bum',
#   'ass',
#   'app'],
#  ['applied', 'week', 'ago', 'deliver', 'hold'],
#  ['glad', 'hear'],
#  ['keep',
#   'getting',
#   'messages',
#   'scam',
#   'suspect',
#   'scam',
#   'know',
#   'supposed',
#   'arrive',
#   'randomly'],
#  ['morning',
#   'pls',
#   'worries',
#   'get',
#   'ty',
#   'amex',
#   'getting',
#   'charged',
#   'like',
#   'crazy',
#   'even',
#   'tho',
#   'orders',
#   'canceled',
#   'appreciate',
#   'guys'],
#  ['really', 'sad'],
#  ['tried',
#   'use',
#   'ubereats',
#   'first',
#   'time',
#   'unpleasant',
#   'experience',
#   'charged',
#   'twice',
#   'order'],
#  ['resolved', 'thanks'],
#  ['trying',
#   'sign',
#   'cycler',
#   'courier',
#   'despite',
#   'uploading',
#   'documents',
#   'criminal',
#   'background',
#   'check',
#   'stays',
#   'grey',
#   'untouchable',
#   'keep',
#   'getting',
#   'say',
#   'please',
#   'upload',
#   'remaining',
#   'documents',
#   'indicate',
#   'help'],
#  ['please',
#   'help',
#   'account',
#   'documents',
#   'pending',
#   'change',
#   'moped',
#   'app',
#   'let',
#   'go',
#   'online',
#   'th',
#   'phone',
#   'number',
#   'asociate',
#   'app'],
#  ['uber',
#   'account',
#   'issue',
#   'trying',
#   'get',
#   'elderly',
#   'father',
#   'set',
#   'could',
#   'bothered',
#   'providing',
#   'phone',
#   'support',
#   'problem'],
#  ['already', 'told', 'asking', 'setting', 'account', 'read', 'damn', 'tweet'],
#  ['guys', 'review', 'insurance', 'please'],
#  ['access', 'menu', 'tab', 'update', 'hours'],
#  ['even', 'read', 'question', 'please', 'respond', 'question'],
#  ['need', 'help', 'cancelling', 'order', 'pls'],
#  ['drive',
#   'dropped',
#   'food',
#   'wrong',
#   'place',
#   'never',
#   'contacted',
#   'still',
#   'charged',
#   'food'],
#  ['actually', 'driver', 'aswell'],
#  ['took',
#   'days',
#   'authorize',
#   'new',
#   'insurance',
#   'get',
#   'back',
#   'online',
#   'meanwhile',
#   'lyft',
#   'took',
#   'hour'],
#  ['crap', 'getting', 'days', 'told', 'give', 'days'],
#  ['promised',
#   'via',
#   'dm',
#   'update',
#   'email',
#   'got',
#   'nothing',
#   'need',
#   'update',
#   'stop',
#   'passing',
#   'buck'],
#  ['dm', 'sent', 'many', 'thanks', 'team'],
#  ['tf', 'connecting', 'drivers', 'minutes', 'away'],
#  ['received',
#   'discount',
#   'mail',
#   'order',
#   'trying',
#   'apply',
#   'discount',
#   'code',
#   'appears',
#   'code',
#   'longer',
#   'available',
#   'whilst',
#   'deadline',
#   'today'],
#  ['maybe',
#   'receiving',
#   'higher',
#   'normal',
#   'support',
#   'volume',
#   'keep',
#   'sending',
#   'needless',
#   'texts',
#   'random',
#   'users',
#   'trusted',
#   'credit',
#   'card',
#   'numbers',
#   'thought'],
#  ['rather',
#   'cancel',
#   'eats',
#   'pass',
#   'subscription',
#   'seeing',
#   'delivering',
#   'whole',
#   'month',
#   'march',
#   'defer',
#   'payment',
#   'month'],
#  ['account',
#   'temporarily',
#   'placed',
#   'hold',
#   'indianapolis',
#   'indiana',
#   'going'],
#  ['give', 'essential', 'workers', 'discounts', 'rides', 'work'],
#  ['trying',
#   'get',
#   'assistance',
#   'covid',
#   'mess',
#   'worse',
#   'thing',
#   'ever',
#   'done',
#   'way',
#   'care',
#   'people',
#   'work',
#   'giving',
#   'run',
#   'around'],
#  ['uploaded',
#   'document',
#   'since',
#   'th',
#   'march',
#   'till',
#   'today',
#   'updated',
#   'due',
#   'unable',
#   'drive',
#   'uber',
#   'please',
#   'reactivate',
#   'soon',
#   'possible'],
#  ['doubt', 'happened', 'say', 'questions', 'tall', 'exactly', 'much', 'weigh'],
#  ['ordered',
#   'meal',
#   'gift',
#   'card',
#   'account',
#   'got',
#   'charged',
#   'total',
#   'amount',
#   'card',
#   'please',
#   'refund',
#   'money',
#   'order'],
#  ['hi',
#   'tried',
#   'change',
#   'phone',
#   'number',
#   'account',
#   'received',
#   'message',
#   'phone',
#   'number',
#   'taken',
#   'please',
#   'help',
#   'immediately'],
#  ['sent'],
#  ['really',
#   'nobody',
#   'available',
#   'verify',
#   'driver',
#   'insurance',
#   'uploaded'],
#  ['cannot', 'se', 'reply', 'calls', 'say', 'heck', 'uber'],
#  ['file', 'unemployment', 'states', 'website'],
#  ['driver',
#   'sleeping',
#   'food',
#   'watter',
#   'biscuits',
#   'help',
#   'im',
#   'also',
#   'driver',
#   'partner',
#   'im',
#   'alsoin',
#   'verry',
#   'trubbel'],
#  ['hey', 'keep', 'getting', 'sent', 'uber', 'code', 'texts', 'ask', 'going'],
#  ['perhaps', 'could', 'assist', 'query'],
#  ['good',
#   'morning',
#   'uber',
#   'please',
#   'help',
#   'approve',
#   'insurance',
#   'document',
#   'submitted',
#   'past',
#   'hrs'],
#  ['one',
#   'pls',
#   'look',
#   'rego',
#   'pending',
#   'approval',
#   'days',
#   'work',
#   'past',
#   'days',
#   'mail',
#   'id',
#   'phone'],
#  ['filed',
#   'week',
#   'half',
#   'ago',
#   'promised',
#   'days',
#   'get',
#   'things',
#   'sorted',
#   'submitted',
#   'necessary',
#   'paperwork',
#   'response',
#   'imagine',
#   'lot',
#   'drivers',
#   'work',
#   'sick',
#   'rather',
#   'notifying',
#   'uber',
#   'families',
#   'starve'],
#  ['use',
#   'uber',
#   'eats',
#   'website',
#   'app',
#   'website',
#   'go',
#   'clicking',
#   'help'],
#  ['still', 'waiting'],
#  ['bought',
#   'new',
#   'sim',
#   'mobile',
#   'find',
#   'already',
#   'blocked',
#   'please',
#   'help'],
#  ['issues',
#   'account',
#   'logged',
#   'avon',
#   'solved',
#   'issue',
#   'love',
#   'promo',
#   'codes',
#   'free',
#   'delivery',
#   'get',
#   'back'],
#  ['please',
#   'help',
#   'ordered',
#   'uber',
#   'eats',
#   'driver',
#   'said',
#   'food',
#   'door',
#   'nothing',
#   'got',
#   'charged',
#   'something',
#   'get'],
#  ['great',
#   'glad',
#   'hear',
#   'definitely',
#   'lot',
#   'questions',
#   'figured',
#   'state',
#   'state',
#   'thing'],
#  ['thank', 'free', 'bike', 'rides'],
#  ['anyone', 'uber', 'support', 'help', 'cant', 'get', 'contact', 'support'],
#  ['girl', 'mine'],
#  ['promotion', 'saying', 'expired', 'april', 'th', 'date', 'happened', 'yet'],
#  ['dm'],
#  ['meal', 'order', 'delivered', 'feel', 'ripped', 'follow', 'order', 'ddbd'],
#  ['well', 'hella', 'alarming'],
#  ['registered',
#   'phone',
#   'number',
#   'uploaded',
#   'documents',
#   'around',
#   'days',
#   'ago',
#   'order',
#   'uber',
#   'eats',
#   'driver',
#   'vevo',
#   'check',
#   'still',
#   'pending',
#   'also',
#   'one',
#   'thing',
#   'please',
#   'tell',
#   'upload',
#   'criminal',
#   'background',
#   'check'],
#  ['bank',
#   'transactions',
#   'day',
#   'never',
#   'took',
#   'uber',
#   'basically',
#   'questioning',
#   'transactions',
#   'would',
#   'need',
#   'help',
#   'making',
#   'sure',
#   'fraud',
#   'please',
#   'advise',
#   'thanks'],
#  ['waiting',
#   'respond',
#   'month',
#   'emails',
#   'menssages',
#   'app',
#   'need',
#   'answer'],
#  ['reconciling',
#   'business',
#   'expense',
#   'looking',
#   'period',
#   'jan',
#   'feb',
#   'got',
#   'bank',
#   'transaction',
#   'count',
#   'trips',
#   'happy',
#   'share',
#   'details',
#   'transactions',
#   'passed',
#   'card',
#   'help'],
#  ['please', 'activate', 'uber', 'account', 'blocked', 'low', 'uber', 'rating'],
#  ['nope',
#   'closed',
#   'enquiry',
#   'email',
#   'confirmed',
#   'credits',
#   'know',
#   'part',
#   'business',
#   'plan',
#   'lie',
#   'teeth'],
#  ['actually',
#   'care',
#   'quality',
#   'food',
#   'client',
#   'receiving',
#   'driver',
#   'take',
#   'orders',
#   'saying'],
#  ['guys',
#   'going',
#   'post',
#   'anything',
#   'help',
#   'people',
#   'file',
#   'unemployment',
#   'mess'],
#  ['hey',
#   'waitlisted',
#   'years',
#   'pls',
#   'look',
#   'account',
#   'eligible',
#   'ubereats',
#   'uberx',
#   'pls',
#   'dm'],
#  ['uber',
#   'credit',
#   'amex',
#   'platinum',
#   'card',
#   'added',
#   'next',
#   'month',
#   'credit'],
#  ['one',
#   'uber',
#   'driver',
#   'partner',
#   'please',
#   'help',
#   'us',
#   'universal',
#   'calamities',
#   'please',
#   'donate',
#   'amount',
#   'uber',
#   'account',
#   'stand',
#   'corona',
#   'war',
#   'also',
#   'daily',
#   'wages',
#   'labour',
#   'pls',
#   'think',
#   'us'],
#  ['way',
#   'change',
#   'tip',
#   'amount',
#   'uber',
#   'eats',
#   'order',
#   'hour',
#   'credit',
#   'card',
#   'authorization',
#   'window',
#   'passed'],
#  ['nah',
#   'dismissed',
#   'mistaking',
#   'woman',
#   'reality',
#   'lol',
#   'stupid',
#   'languages'],
#  ['thanks',
#   'concern',
#   'pal',
#   'fleet',
#   'partner',
#   'manage',
#   'somehow',
#   'even',
#   'recession',
#   'worried',
#   'millions',
#   'drivers',
#   'drivers',
#   'every',
#   'organisation',
#   'trying',
#   'best',
#   'save',
#   'humanity',
#   'one',
#   'take',
#   'care'],
#  ['hey',
#   'lied',
#   'said',
#   'applied',
#   'credits',
#   'account',
#   'driver',
#   'tried',
#   'endanger',
#   'health',
#   'want',
#   'take',
#   'lift',
#   'refund',
#   'money',
#   'credit',
#   'never',
#   'gave',
#   'never',
#   'order'],
#  ['know',
#   'mate',
#   'wasnt',
#   'dig',
#   'seen',
#   'uber',
#   'drivers',
#   'say',
#   'around',
#   'globe',
#   'mean',
#   'personal',
#   'account',
#   'hope',
#   'get',
#   'sorted',
#   'uber',
#   'government',
#   'also',
#   'responsibility',
#   'care',
#   'keep',
#   'family',
#   'safe'],
#  ['done',
#   'something',
#   'wanted',
#   'like',
#   'trying',
#   'help',
#   'least',
#   'words',
#   'partners',
#   'ola',
#   'like',
#   'worried',
#   'get',
#   'new',
#   'drivers',
#   'partners',
#   'poor',
#   'families',
#   'starves',
#   'death'],
#  ['hello', 'things', 'finally', 'resolved'],
#  ['get', 'anywhere', 'classed', 'self', 'employed', 'dont', 'help'],
#  ['hour',
#   'greatest',
#   'need',
#   'driver',
#   'fleet',
#   'partners',
#   'every',
#   'company',
#   'paying',
#   'employees',
#   'wanna',
#   'something',
#   'people',
#   'earn',
#   'commission'],
#  ['hi',
#   'harry',
#   'actively',
#   'working',
#   'gather',
#   'relevant',
#   'information',
#   'drivers',
#   'varies',
#   'state',
#   'state',
#   'touch',
#   'soon',
#   'possible',
#   'likely',
#   'monday'],
#  ['better',
#   'verify',
#   'credit',
#   'cards',
#   'bring',
#   'submitted',
#   'app',
#   'charges',
#   'fraudulently',
#   'charged',
#   'today',
#   'system',
#   'guys',
#   'put',
#   'flag',
#   'catch',
#   'number',
#   'used',
#   'zip',
#   'code',
#   'match',
#   'billing',
#   'zip'],
#  ['guys', 'resetting', 'something', 'rating', 'went', 'issue'],
#  ['guys', 'sleep', 'day', 'work', 'night'],
#  ['save', 'podcast', 'gem', 'lol'],
#  ['dm', 'sent'],
#  ['canto', 'register', 'motorcycle'],
#  ['wait'],
#  ['payment',
#   'methods',
#   'give',
#   'error',
#   'saying',
#   'payment',
#   'method',
#   'unavailable',
#   'every',
#   'card',
#   'try'],
#  ['uber',
#   'eats',
#   'allowed',
#   'order',
#   'closed',
#   'restaurant',
#   'drivers',
#   'keep',
#   'pulling',
#   'clearly',
#   'get',
#   'food',
#   'trying',
#   'use',
#   'help',
#   'support',
#   'option',
#   'order',
#   'never',
#   'arrived',
#   'app',
#   'still',
#   'marking',
#   'en',
#   'route',
#   'want',
#   'money',
#   'back',
#   'please'],
#  ['could', 'read', 'tweet', 'answer', 'question'],
#  ['covid',
#   'pandemic',
#   'lot',
#   'companies',
#   'taking',
#   'care',
#   'people',
#   'making',
#   'sure',
#   'pay',
#   'dealing',
#   'public',
#   'premium',
#   'rate',
#   'fact',
#   'cut',
#   'driver',
#   'support',
#   'weekends',
#   'refuse',
#   'respond',
#   'drivers'],
#  ['ola',
#   'uber',
#   'company',
#   'takes',
#   'commission',
#   'unable',
#   'give',
#   'drivers',
#   'hour',
#   'trouble'],
#  ['hell',
#   'happening',
#   'order',
#   'cancelled',
#   'told',
#   'still',
#   'pay',
#   'hung',
#   'disconnected',
#   'charging',
#   'order',
#   'back',
#   'deleting',
#   'good'],
#  ['someone', 'know', 'using', 'email', 'account'],
#  ['hey',
#   'harsha',
#   'vardhan',
#   'know',
#   'covid',
#   'outbreaking',
#   'hard',
#   'australia',
#   'tough',
#   'time',
#   'go',
#   'outside',
#   'without',
#   'cab',
#   'please',
#   'would',
#   'sincerely',
#   'request',
#   'please',
#   'uber',
#   'account',
#   'helpful',
#   'covid',
#   'outbreak'],
#  ['would', 'considered', 'benefits', 'fraud', 'felony'],
#  ['terrified', 'got', 'scammed'],
#  ['happen', 'course', 'would', 'nice', 'could', 'actually', 'get', 'touch'],
#  ['yrs',
#   'specifically',
#   'endorsing',
#   'uber',
#   'yesterday',
#   'ordered',
#   'uber',
#   'car',
#   'filthy',
#   'dirty',
#   'car',
#   'showed',
#   'huge',
#   'lyft',
#   'sign',
#   'interior',
#   'filthy',
#   'well',
#   'rusty',
#   'dirty',
#   'rags',
#   'back',
#   'seat',
#   'ewwwwe',
#   'upholstery',
#   'also',
#   'disgustingly',
#   'filthy'],
#  ['days', 'ago', 'still', 'heard', 'back'],
#  ['thank', 'able', 'get', 'things', 'resolved', 'yesterday'],
#  ['man', 'get', 'response'],
#  ['going',
#   'state',
#   'level',
#   'fed',
#   'reimburse',
#   'states',
#   'keep',
#   'process',
#   'catching'],
#  ['ordered',
#   'first',
#   'time',
#   'tonight',
#   'used',
#   'first',
#   'order',
#   'coupon',
#   'get',
#   'applied',
#   'order',
#   'use',
#   'since',
#   'first',
#   'order',
#   'halp',
#   'plz'],
#  ['need',
#   'help',
#   'trying',
#   'create',
#   'account',
#   'keeps',
#   'saying',
#   'number',
#   'already',
#   'account',
#   'must',
#   'last',
#   'person',
#   'number',
#   'help'],
#  ['shout',
#   'guy',
#   'tried',
#   'scam',
#   'uber',
#   'eats',
#   'posing',
#   'laughed',
#   'waaay',
#   'hard',
#   'locked',
#   'payouts',
#   'closed',
#   'praise',
#   'network',
#   'issues',
#   'working',
#   'app'],
#  ['get', 'response'],
#  ['corona',
#   'virus',
#   'relief',
#   'legislation',
#   'indicates',
#   'uber',
#   'drivers',
#   'usa',
#   'apply',
#   'unemployment',
#   'guideline',
#   'process',
#   'follow',
#   'apply',
#   'benefit'],
#  ['issue', 'resolved', 'thanks'],
#  ['uber', 'famous', 'fraud', 'ubersucks'],
#  ['thats', 'absolutely', 'disgusting'],
#  ['understood', 'uninstalled', 'reinstalled', 'app', 'get', 'back', 'working'],
#  ['stop',
#   'surge',
#   'pricing',
#   'pandemic',
#   'pls',
#   'icu',
#   'nurse',
#   'trying',
#   'get',
#   'work',
#   'help',
#   'affordably',
#   'wearethefrontline',
#   'gougepricing'],
#  ['electronic',
#   'funds',
#   'transfer',
#   'act',
#   'efta',
#   'deal',
#   'fraud',
#   'directly',
#   'card',
#   'issuer',
#   'cancel',
#   'card',
#   'issue',
#   'new',
#   'one',
#   'pain',
#   'change',
#   'new',
#   'number',
#   'automatic',
#   'bill',
#   'pay'],
#  ['yes', 'knows', 'already', 'contacted', 'credit', 'union'],
#  ['called', 'past', 'wait', 'time', 'bit', 'long'],
#  ['call',
#   'debit',
#   'card',
#   'company',
#   'card',
#   'physically',
#   'lost',
#   'stolen',
#   'days',
#   'report',
#   'fraudulent',
#   'transactions',
#   'zero',
#   'liability',
#   'days',
#   'starts',
#   'date',
#   'statement',
#   'fraudulent',
#   'transaction',
#   'appears'],
#  ['call', 'customer', 'service', 'dispute'],
#  ['vehicle',
#   'trunk',
#   'release',
#   'back',
#   'seat',
#   'making',
#   'false',
#   'accusations',
#   'even',
#   'lower',
#   'snitching'],
#  ['hey',
#   'someone',
#   'fraudulently',
#   'used',
#   'mother',
#   'debit',
#   'card',
#   'make',
#   'three',
#   'large',
#   'orders',
#   'uber',
#   'eats',
#   'uber',
#   'account',
#   'public',
#   'phone',
#   'number',
#   'listed',
#   'contact',
#   'get',
#   'touch'],
#  ['hi', 'majiira', 'talk', 'hope', 'ur', 'well'],
#  ['time', 'phone', 'line', 'need', 'talk'],
#  ['still',
#   'getting',
#   'texts',
#   'better',
#   'homie',
#   'get',
#   'response',
#   'getting',
#   'hacked',
#   'russia'],
#  ['general',
#   'everyone',
#   'safe',
#   'make',
#   'sure',
#   'big',
#   'bold',
#   'drivers',
#   'know',
#   'new',
#   'missed'],
#  ['excited',
#   'support',
#   'local',
#   'restaurant',
#   'tonight',
#   'ubereats',
#   'using',
#   'ubercash',
#   'giftcard',
#   'made',
#   'sure',
#   'uber',
#   'cash',
#   'ready',
#   'pay',
#   'instead',
#   'whole',
#   'meal',
#   'charged',
#   'credit',
#   'card',
#   'need',
#   'help'],
#  ['world',
#   'pandemic',
#   'going',
#   'people',
#   'loosing',
#   'jobs',
#   'top',
#   'discount',
#   'trip',
#   'rates',
#   'charging',
#   'surge',
#   'peek',
#   'hours',
#   'smh',
#   'uber',
#   'better'],
#  ['wrongfully',
#   'restricted',
#   'suspended',
#   'account',
#   'apparently',
#   'violating',
#   'terms',
#   'service',
#   'file',
#   'ticket',
#   'tell',
#   'going',
#   'lift',
#   'wrongfully',
#   'system',
#   'applied',
#   'ban',
#   'say',
#   'kidding',
#   'lifting',
#   'suspension'],
#  ['sent', 'dm', 'ave', 'got', 'automated', 'response'],
#  ['round',
#   'mail',
#   'chain',
#   'prof',
#   'nd',
#   'answer',
#   'guys',
#   'shying',
#   'away',
#   'frm',
#   'acknowledging',
#   'mistake',
#   'uber',
#   'nd',
#   'accepting',
#   'shortcoming',
#   'least',
#   'cant',
#   'refund',
#   'disgusting',
#   'shameful',
#   'nd',
#   'pathetic',
#   'guys',
#   'lied',
#   'least'],
#  ['still',
#   'response',
#   'three',
#   'weeks',
#   'documents',
#   'pending',
#   'ubereats',
#   'hand',
#   'ridiculous',
#   'something',
#   'needs',
#   'done',
#   'someone',
#   'needs',
#   'handle',
#   'asap'],
#  ['thanks', 'sent', 'message'],
#  ['confused',
#   'want',
#   'give',
#   'driver',
#   'proper',
#   'tip',
#   'without',
#   'accidentally',
#   'sending',
#   'meager',
#   'life',
#   'savings',
#   'help',
#   'hope'],
#  ['hi',
#   'pleeeeze',
#   'help',
#   'desperately',
#   'need',
#   'send',
#   'message',
#   'uber',
#   'delivery',
#   'deliverers',
#   'help',
#   'private',
#   'help',
#   'section',
#   'giving',
#   'options',
#   'send',
#   'message',
#   'go',
#   'thanks',
#   'advance'],
#  ...]

# %% [markdown]
# ## Detokenize texts

# %%
texts = [TreebankWordDetokenizer().detokenize(document) for document in texts]
texts
# Out:
# ['follow thru promise disinfecting materials drivers cars supplies keep drivers safe tele agents hang drivers call ask sbout supplies',
#  'uber follow thru promise disinfecting materials drivers cars supplies keep drivers safe tele agents hang drivers call ask sbout supplies explain please',
#  'follow thru promise disinfecting materials drivers cars supplies keep drivers safe tele agents hang drivers call ask sbout supplies explain please',
#  'song dance dead wrong handling pandemic plight workers know',
#  'hey receiving ride reports email even account guys',
#  'done',
#  'uber gives ride request go app gone right away',
#  'way worried privacy dm said please continue working support team even though one emailing help deception',
#  'trying file california state unemployment insurance ever since pay cut dramatically uber ca state etin tried find number call hr department find one also still waiting file tax',
#  'please answer message box',
#  'contact info avoid charges driver says business closed',
#  'read original tweet answer question nothing account',
#  'handling drivers situation restricted lockdown example panama central america',
#  'insurance pending approval hours',
#  'hello ordered worth east sides came cold chicken cooked veggies fries cooked pasta cold desert kids meal worst time ever eating food restaurant said bad night call uber refund',
#  'help justification horrible practice',
#  'hi way bicycle delivery profile modified enable use vehicle provided every necessary nyc clearance start delivery vehicle thanks look forward getting support',
#  'called multiple times one approve insurance days',
#  'uber going provide drivers sanitizing wipes vehicle interiors hands keep seeing emails yet word shipment products actual drivers',
#  'local greenlight hub support offices closed til least april prob longer gave us paper call uber support get boston driver certificate called told hubs get certificate',
#  'help uber eats order issue going bonkers',
#  'hello recieve thermal bag start delivery job went office told closed due covid situation hand yet recieve texts emails everyday collection told back th',
#  'still nothing',
#  'one checking important dm',
#  'latin creations senor frog cancel wrong menu able contact branden plan',
#  'email ever access account changed phone number',
#  'ya love getting charged cancelling driver went double distance way absolutely ridiculous second time shit like happened taken money reason bunch thieves',
#  'hoping someone smart enough realize drivers keep current uber pro status time fair reasonable thing ask people ride thanks',
#  'ordered restaurant screwed order talk get item eat since toppings included make gag',
#  'deny claim self isolation compensation',
#  'send uber customer service number live person stat lawyer call',
#  'stop unauthorized removal funds bank account global pandemic resources already scarce taken uber months absurd give money back',
#  'week waiting support got copy paste reply dm first last time using guys understand increase due everything going week insane',
#  'anyone else issues second day row food never arrived app says delivered hell',
#  'tell deny claim',
#  'still received uber eats support',
#  'want know ignored weeks ok completely unacceptable unprofessional company blatantly lie drivers covid',
#  'app talk someone emails charged twice trip car never showed different info',
#  'please help help',
#  'still looking answers',
#  'took uber restaurant give order cause given driver spend money retrieving order unsuccessful still nothing support good enough',
#  'weeks unacceptable stated days payment think ok',
#  'help uber support wont help please help',
#  'tell three weeks since waiting get paid point believe lying drivers',
#  'promotion expire april th yet',
#  'leave bottle coke see going find reliable delivery service make second time messed left item order',
#  'pls hurry last dime showering neighbors sprinkler going report soon',
#  'met criteria current time submission enough instead keep getting denied criteria gets changed way anything help',
#  'still looking callback worstcustomerservice',
#  'way go',
#  'yet reaching something answer application put uber driver months ago reviewed thanks',
#  'dm number text set time chat',
#  'uber drivers beware uber paying promised quarantined drive lyft another company protect needed uber breaking texas payday law',
#  'shouldnt guys treating couriers like gold instead keeping tips shorting pay outs pandemic ones essential wew making millions yoy still uner pay us',
#  'uber breaking texas payday law uber refusing pay drivers shieldvoc',
#  'hear yet',
#  'still get',
#  'uber account let update email address activate nhs promo',
#  'happy mcdonald uk dream abt restaurants co closed wont open anytime soon id love double cheeseburger even ubereats deliver',
#  'uber got another problem check dms got charged wrong',
#  'live portugal ordered delivery man asked go downstairs collect food outside building said due covid new rules get covid leave flat get food downstairs outside comments',
#  'worst support world goes',
#  'need help verification code email getting',
#  'need know uber driver probably back work due covid rule please let know soon thank',
#  'dear first responder driver quarantine heard back guys far submit paperwork get help',
#  'please follow dm locked nhs uber eats account please help',
#  'good afternoon name tina ordered uber eats app first time used promotional code given manager place work registered nurse first responder covid pandemic',
#  'essential workers ny ever considered giving us discount trips work since risk work risk commutes flattenthecurvetogether',
#  'clear whether worked let yet price remains unchanged go help page way interract tweet twitter address',
#  'got couple issues trying work feel like getting run around online outlets text uber app twitter direct messaging need help direction assistance advice support tried go kc greenlight hub closed',
#  'loooooool nearly spat one good slice',
#  'could get uberxl use pick flatpack furniture',
#  'hi guys trying use uber eats promo code emailed meant valid pm tonight apply tried phone website help',
#  'thanks usual email stated got papers',
#  'uh huh',
#  'looool man got calzone',
#  'week guys still verified insurance registration',
#  'go getting pizzas redelivered refund',
#  'hello doctor nhs recently updated ubereats email nhs email still received promo code',
#  'leave answer dms',
#  'nhsapril code work says applied show promotions fully charged',
#  'unable pay bills unable work even though sent documents days ago lack response hurting vulnerable drivers already loosing money due scenario shameful',
#  'week since applied nothing checked please help really like work need new form income soon please let know something wrong application',
#  'hello somebody trying register uber number got verification codes phone need dont use uber help would greatly appreciated',
#  'go days without work',
#  'replied back refunded please',
#  'able update documentation via driver app uber brasil',
#  'since state oklahoma extended validity drivers licenses impact ability continue running trips even mine originally set expire april',
#  'attitude employees disgusting talk awful support',
#  'state stay home mandate stop permitted work obtain paperwork say work',
#  'cancelling delivery requests get really could care less diamond rating spoken unprofessionally manager cambridge franklin rd half',
#  'food never arrived',
#  'days able work one approved insurance forward messages tell going',
#  'help',
#  'ok looks like someone manually fixed account appreciate support team still needs better understand requests respond context rather using canned responses',
#  'email send documents guys four years new bull shit sick say sure news find interesting one',
#  'hey shady fall guidelines financial support sent required docs doctor getti fucking run around suspend account',
#  'still heard order still pending app please reach',
#  'access account cel doesnt receive msm code number',
#  'phone number email iam located chihuahua mexico',
#  'please respond dm concerning uber rewards',
#  'hey need help account need get back know email registration pending pending week please help',
#  'linked nhs email uber account long take get code thanks',
#  'ill reaching near future im disgusted even talk people today',
#  'absolute worst trying coming days get tax information issue got problem solved less minutes uberistrash',
#  'hey uber received ubereats nhs promotion code email yet help please',
#  'signed driver got message contact support due coronavirus',
#  'anyone customer service anyone answering',
#  'need help promo code',
#  'need speak someone setting corporate account',
#  'sent two dm keep getting automated response covid',
#  'documentation need give prove unable renew license plate registration since emissions stations closed illinois extended expiration dates days past time lockdown ended',
#  'uber eats order never arrived someone please reach',
#  'hi trying add nhs discount account try verify email address opens duplicate tab browser please help',
#  'leeches parasites world surprised make fact drain country',
#  'need help approval uber eats deliver partner documents days since uploaded please help',
#  'need send bank transactions review tell send',
#  'hi nhs staff code yet',
#  'dm requested got response help number please respond',
#  'issue lol taken care',
#  'work nhs activated code free rides still received email regarding uber eats',
#  'one answered dozen times sent',
#  'able app working',
#  'promo code valid today work checkout',
#  'ordered food almost hours app still unable find driver pick food eta time keep going canceled get charge fee lose promo fault app cant find driver',
#  'replied never got response',
#  'license expired renew dmv closed service state extended expiration days drive update license yet',
#  'order waiting hrs',
#  'tried set uber eats business account days ago hold around hours phone times already either one someone transferred nothing set new restaurant trying set delivery',
#  'sending phone number twitter even dms',
#  'tried set uber eats business account days ago hold around hours phone times already either one someone transferred nothing set new restaurant trying set delivery',
#  'middle maddening case support reps clearly even reading messages looking screenshots getting canned responses might well delete account already',
#  'goog guys really add automated chat response sets expectations instead response',
#  'changed email address still recieved message uber eats code trying suss behalf us hosp dying pizza',
#  'sent',
#  'lucky talked live person email support takes hrs get reply back',
#  'uber driver almost year would like able drive uber eats well get capability',
#  'read looks like tip drivers restaurants pick stuff',
#  'need years ago funny story get tell',
#  'phone number going twitter even dms',
#  'hey really cool charged ride direct means customer service',
#  'dm',
#  'nhs code uber eats arrived nhs mail account',
#  'thank added details requested',
#  'shame uber set qualifications make getting payment impossible',
#  'thanks help',
#  'got response really answer grammatically correct enough actually tell mean concerned account compromised getting bunch needless messages phone please try harder',
#  'hospitals cant legally put documentation quarantine covid unless tested test positive uber requires covid specifically noted reason quarantined tested results immediate impossible get paid',
#  'dynamic day dollars way pay go blocks',
#  'think uber want approve documents reduce amount drivers',
#  'still need customer support ubereats tablet working cannot get thru ubereats phone please live person contact us',
#  'uploaded insurance days ago still times still pending expire suppose',
#  'ordered ramen pickup way tip restaurant figure intuitively ubereats tipyourwaitstaff covid yow hospitalityindustry socialdistancing covidottawa uber',
#  'use nhs discount ubereats',
#  'cant get app link email one sent delete account let start',
#  'way disable uber cash used rider using business profile',
#  'hi made order order completely wrong told delivery driver said problem restaurant called',
#  'already contacted night incident told look thats communication',
#  'received uber code via sms even though accessed app two weeks account compromised could glitch thank',
#  'resolved thank',
#  'got money taken account used uber almost year please help',
#  'agree rosie try talking sometime joke nothing canned responses till run read anything else help today uber',
#  'received email ubereats promo code nhs workers get',
#  'thanks replied hrs ago response yet better efficient way support access account hrs since initia contact moved inch resolving',
#  'hi trying make account nhs id claim free ride food however got uber mobile number already allowing way round please',
#  'believe please explain understand decision unfair bias incorrect pax accusations based odor shall lawyer false accusations really unfair really need assistance',
#  'uber pay drivers',
#  'thanks pass along appears user error hope find use',
#  'hold support hopefully figure',
#  'happened talk earlier steps going protect driver partners pandemic supposed supply us sanitizers abd kinds stuff instead close leave us hanging good job',
#  'fever still feeling like shit something going cost lives cannot sit let happen',
#  'unable go online driver restricted access drivers',
#  'hey im place uber eats order cant keep getting',
#  'dm alot people point willing meet',
#  'update',
#  'mama never raised snitch',
#  'hello thanks kind free meal offer nhs finished long shift would love food sent promo code yet could please send sarah',
#  'please update driver navigation app townsend street suggested dropoff caltrain station bike lane dangerous stopping allowed',
#  'great decision worstcompany',
#  'boys girls rideshare world refer paxhole word used interchangeably arsehole asshole anus',
#  'hi trying use discount code due expire end today working says promotion expired',
#  'rating apps work',
#  'seriously week disappointing',
#  'verify documents background check week could appreciate work',
#  'thanks',
#  'blind voiceover user please let know order coke ice mcdonalds since refuse fix bug customization screen',
#  'surely going possible please dm us additional details experience team assist appreciate chance review concerns',
#  'difficult find phone number need call complain food order morning want refund want wait hours want food hungry understand please give number',
#  'keep sending dm provide assistance',
#  'need help account car insurance still pending need get second day loosing money please fix account',
#  'im unable cancel uber pass never signed uber pass get canceled get refund money tight unacceptable',
#  'done thank',
#  'yesterday governor maryland said one leave house unless essential job go doctor would like know continue uber eats need letter',
#  'issue',
#  'calling chicago based uber drivers planning protest outside uber greenlight hub north ave wants',
#  'download invoice homepage options file support case bad performance',
#  'dm sent',
#  'received nhs uber eat code registered yesterday thank',
#  'would need taxi outstation travel medical condition arrange pass uninterrupted journey please suggest possible destination bhadohi approx km delhi',
#  'heys guys helping covid sent documents guys answering',
#  'thank hard work thankyounhs',
#  'free food nhs code work',
#  'wont work dude haha cheerio',
#  'uber want pay days financial aid affected corona virus hospital tell lock home symptoms',
#  'sorry hear seems uber overwhelmed many new drivers joining uber due unemployment uber also cancelled referral bonus joke ideas free book work home free ebook makemoney workfromhome take care',
#  'weeks old risk two passengers driving presenting symptoms hospital denied medical attention uber denied financial help stay locked home',
#  'impossible',
#  'question able access accounts drivers shoppers adjust acceptance ratings seems like simple thing implement anything done fix',
#  'still find help',
#  'th day since uploaded insurance certificate still pending without covid unacceptable apologises put food table pay bills',
#  'five days still waiting respond please help',
#  'trying add nhs account existin uber account unable says cannot send email account help',
#  'support site uber eats work trying get help since order never delivered last saturday app marked delivered want money back',
#  'taking two days approve insurance doc unacceptable',
#  'deleting never using',
#  'need contact uber',
#  'uber told weeks one point right supposed business days wtaf',
#  'resolved quickly thank much',
#  'still waiting uberdriver uber driverssupport uberseattle kingcounty wa',
#  'help understand rating trips account put hold need consent background check agreed many terms gives consent drive continually provided par service',
#  'new jersey motor vehicle agencies closed month extension documents despite trying proactive uber put platform morning global pandemic making bad situation worse',
#  'registered nhs email account added nhs promo promo showing uber eats uber try enter checkout says enter code twice discount applied please help',
#  'received email saying charged cancelled ride yet corporate card charged yesterday assist',
#  'given complete documents including everything told needed pmt took platform based documents end quarantine refusing pay',
#  'need copy cases covid yall dealt fucking way able use uber cash week response legit fucking messages told',
#  'orderedmeal food arrived cold chicken felt like old kept chicken last dhs compensation dhs order enough need refund back asap worst food delivery expected',
#  'nobody addressing issue uber required incomplete uber took platform despite required uber refusing pay single mom please help shieldvoc',
#  'store cancel order arrived store didnt compensation money cancel order',
#  'know hopefully get one later today tomorrow',
#  'ima post supporting documents conversations show drivers may issue gave false hope',
#  'offered drivers financial assistance taken road gave false hope instead said help drivers taken road lay turn app tell deal',
#  'lose gold status virus chosen drive taking classes asu right want lose ability get paid uber thanks',
#  'disabled app able make money feed goes denies assistance even though documents saying drive find good companies times like',
#  'please check dm',
#  'since seen elsewhere twitter offer available first despite cs pretty sure legal anyway delete app justeat cheaper reliable',
#  'thanks never use uber service',
#  'simply type steps taking ensure driver ill words none uber might greatest threat health safety employed many terrorists know guess germ warfare next uber scary',
#  'willing pay way get contact someone need one document reviewed approved even new document updated one account hold almost days limited staff quick fix',
#  'anyone unpublished phone numbers know someone work uber uber support dm woth info need drive days zero income done nothing wrong except choose drive versus need one person',
#  'waiting two circles expand year software design issue deliver locations neighborhood drive house add feature something people trying food delivery right',
#  'wow bull drivers fam got uber cash credits gave cant use em cause invalid keep trying get shit make sense screen shot phone setting ro price number real illegal',
#  'account activation email number',
#  'hi kylie please direct inquiry able assist',
#  'already reached via link check dms please',
#  'worst customer service ever dealt stuck home trying order food contacted via dms get automated message trying order breakfast family',
#  'still willing put risk financial option suspended account expired document even though current one provided many days expiration days waited one person review',
#  'sure allowed buy voucher us dollars refund quote happy hear experience described unfortunately making refunds',
#  'day still waiting response emailed year ago last week able create account today uber ubereats ubersupport uberfail ubereatsfail ubercustomerservice rideshareapp ridesharing fooddelivery',
#  'ive lost gift code due ur system days still help fuck',
#  'want organize protest outside ubers greenlight hub chicago',
#  'moved delaware set open inspection test place hours away tolls uber pay car tiguan vw',
#  'fix support system suspended accounts resources available review doxuments perhaps time change review process still earn living',
#  'talking trip showing link talking trip ordered yesterday mins going charged order total taking advantage situation make profit',
#  'nothing delivery fee service charge tip right add another tip restaurants option adding tip placing online order ubereats',
#  'days starving girl tries help deactivate acc use code wasting ppl money',
#  'also try contact paypal bank fighting covid bad getting hold uber eats even worse would rather spend days relaxing stressing losing money',
#  'also tried cancel order vendor cancel food left outside door thank uber eats totally messing day emergency ambulance day resting ringing around',
#  'would also like report serious payment option breach point authorise save paypal payment details pressing paypal option take paypal site pay items purchased uber eats company',
#  'fuck cannot one members uber leadership team leaders reach lifeblood company dont give shit drivers',
#  'help quarantined documents submitted uber took platform end quarantine still platform uber pay promised',
#  'thanks reply taking delivery though talking food preparation guarantee chef symptoms spreading virus delivering food responsibility customers make ill',
#  'help quarantined documents submitted uber took platform end quarantine still platform uber pay promised',
#  'sent info right away hope hear would make sense send excel bank transactions ahead time go initial explanation',
#  'appears uber stopped supporting drivers absolutely zero response via avenue smh good news lyft supporting users add vehicle normal car shop lyft driving mins waiting uber week',
#  'recieved email wont helping taken account recieved email charge order make',
#  'taken care already thanks',
#  'sent guys message',
#  'everything comes put mouths nothing lies submitted damn paperwork asked claim denied suck',
#  'crazy drivers take money never pick defend refund us better go guess',
#  'update order cancelled also pressed paypal take paypal sign took money straight away without signing security breached time authorise save details',
#  'keep rejecting drivers license drive uber eats',
#  'careful posting online',
#  'order restaurant still open explicitly selecting want order fulfilled later opened',
#  'okay spoke someone app really resolve issue take bank instead thanks reaching',
#  'hey talked rep phone sent several messages week one turn ubereats please help',
#  'know change tip made one ubereats tip first place cannot',
#  'totally agree',
#  'contacting bank charge back order cancelled uber',
#  'neither',
#  'shocking service uber eats one answering phones cancelled order cancellation confirmations cancelled instantly within seconds promo applied discount subtracted total contact method rediculous nobody answering',
#  'hi couple promo codes ubereats account use australia please help',
#  'think someone trying use uber account',
#  'uber eats credits unable use credits zomato benefit given zomato like free zomato gold membership',
#  'financial support guarantee uber',
#  'top priority follow sir uber cancellation trending finding solutions reoccurring issues hyderabad secunderabad delhi bengaluru chennai kolkata mumbai',
#  'done twice first time lot decided ignore next one force fixed',
#  'done thanks',
#  'issue order day kindly refunded part money checked bank statement money refunded taken along original price meal taking account double meal cost',
#  'sending dms nobody reply need help please',
#  'acct hold expired uploaded txdeptofpublic safety letter officialy authorizing days extension online ironical represent uber well treated system fails us go work',
#  'thank much support',
#  'hello enough uber rewards apple news subscription two months disappeared chance redeem happened rewards points',
#  'trying months retrieve invoices travel avail extremely disheartening encounter service',
#  'sent dm phone number thank looking matter deactivated expired registration governor extended deadline till april th',
#  'sent dm days ago reply side till really upset way handling customer complaint filed complaint weeks ago also reply addition unprofessional supervisors phone',
#  'human please help submitted documentation financial assistance appears date cut top image doctors letter submitted cant get anyone attention help denied',
#  'added uber nhs code used straight away',
#  'hey days simple updated vehicle inspection submitted days expiration account hold days suspend people accounts man power review documents',
#  'could please start thinking outside box due covid situation tn licensing commission closed several drivers unable renew permit please note attached screenshot website',
#  'good went deliveroo instead honestly guys great sort tech issues',
#  'gave coupon lasted seven days added code said expired gives',
#  'holy bots read damn thing one twunts',
#  'changed phone cannot login account help',
#  'please check dm',
#  'times rides still refuse fix serious safety issue happening since april uber absolutely refuse fix serious safety issue',
#  'phone system says live order location closed hiw tti resolve',
#  'frustrated stress figuring refunds canceling issuing new card still wait days hacked account permanently deleted personal information stays vulnerable',
#  'silkwood phone support restaurant closed',
#  'need help nyc dmv cancelled resgistration renewals extended resgistration expiring march oayed registration jo way get keep driving documents expired uber account',
#  'mine either got yet',
#  'payment receive pay fair us',
#  'theres nothing found way sending concern charged multiple times card',
#  'bill masucci license registration done two cars account sold one bought another',
#  'app broken charged multiple times theres support available app site',
#  'hey please help us registered number uber eats via private message look',
#  'dear sir uber eats sold zomato received emails promising us zomato gold membership placed certain number orders zomato yest offered us promised months free zomato gold membership promised please followup',
#  'initiated uber pass january year feature turned cancelled march utilizing uber foreseeable future please remove charge',
#  'account deactivated really never helped represent uber excellence get crappy deactivation notice email unacceptable pls go back investigate tx dept public safety lettr need income ubereats',
#  'hope guys saved lots people virus cuz many replies got guys guys busy helping people virus shit',
#  'last week account kept hold whole week',
#  'hi received email free meals nhs staff previously linked account nhs email account see promotion app',
#  'well done ola wish cabs operating india follow suit',
#  'sent number details',
#  'know giving contracts driver program telling us charged return vehicle barely charging day called message saying overdue return',
#  'management communicate partner drivers regards movement cessation lagos whether affected next think big flop path information integral part uber system',
#  'contacted via mobile without consent response process ask personal information want uber info never wanted first place impressed',
#  'want get emergency passengers cab plz help us get registered system wb',
#  'hey thanks free rides nhs staff meals really making getting work easier heroes wear capes drop work free charge global pandemic',
#  '',
#  'side per right partners uber deserve noncooperative behavior awaiting positive action revert please',
#  'close account expected company like uber need know made allegations uber without letting justify',
#  'couple negative comments ignoring entire history work completely unprofessional act called uber partner treated like nothing putting much company',
#  'without even sharing reason uber treat loyal hardworking partners specially pandemic situation trying hard give services fulfilling family needs',
#  'uber partner months completed trips ratings many positive feedbacks however one rider wrong accusation allegations surely mistake closed account',
#  'please help time sensitive really need account frozen',
#  'trying hour tomorrow assist',
#  'people hacked account put step verification know phone number need way delete account asap please help scared cards attached account',
#  'need desperate help find way reach guys account hacked log know hacked still attached email address charge around put credit card uber eats',
#  'thank',
#  'understand things busy right order canceled hour placed card charged food made uber driver restaurant give food extremely ridiculous unprofessional want money',
#  'customer service email uber india already raise request riders data trip info know specific trip arrival time',
#  'midnight fell asleep easily gives enough time especially phone dead fell asleep soon got home didnt even watch netflix',
#  'worries thank support app finally respond appreciate getting back good night',
#  'sucks hope get refunded',
#  'cool take note',
#  'waiting days submitted documents financial help tell kids food delay due volume inquiries',
#  'guy sitting halfway drive way messing around get notification order delivered pulls eventually uber customer support right send email pray',
#  'eating definitely eating food',
#  'driver came way house spent lot time front never brought food house left reporting delivery done',
#  'hey want delete uber account sign moment could someone delete end happy share personal details make process easier thanks',
#  'hey still received heard driver receiving cleaning supplies promised send getting',
#  'able earn take hold put maybe next time resources review approve documents maybe suspend diligent drivers like',
#  'long',
#  'hey long supposed stay suspended expired vehicle inspection sent updated one old one expired yet suspended account tell understand frustration bear days',
#  'submitted updated registration insurance documents tomorrow able drive says documents pending help',
#  'trying get hold someone hour driver accident went hospital cancel order',
#  'refund money want resolve anything use uber cabs',
#  'thank info good general reference plans definitions contain authority mention effect orders dc ride share programs limited passengers',
#  'today cannot log uber driver app says account needs attention contact uber support even though never got email uber tell wrong could please check',
#  'okay sent right thank',
#  'problem replaced number account doubt association',
#  'reviewed new insurance week think using excuse keep road pay get covid maybe know something rider withholding information',
#  'hold breath reviewed new insurance week think using excuse get drivers road give covid money get conspiracy',
#  'yesterday thanks',
#  'hey drivers nyc jersey wear masks gloves',
#  'uber eats work',
#  'thank tipped driver would really like get penalized number mix honest mistake going walk around looking',
#  'access account recently changed number keep sending code old number need update new number',
#  'want know long takes become uber eats courier hours heard anything guys',
#  'going solve problem',
#  'thank responded hopefully resolve',
#  'please respond important week',
#  'thank',
#  'need help please',
#  'thank context',
#  'rethink two stop rides take forever come first stop waiting charge',
#  'uber essential according',
#  'update',
#  'please explain using form transport happened social distancing use stretch limos london seeing daily accidents involving untrained drivers becoming laughing stock serious',
#  'guys sudden license says blurry fine year took new picture updated need someone review asap',
#  'thanks getting uber eats orders wrong times row handling horribly',
#  'soooo julia deliver drink chipotle gonna',
#  'need uber placards vehicle',
#  'instead uber lets customer lie cheat uber expense upsetting listen accusing something true listen drivers',
#  'matter hard working driver years high rating honest uber taken rights uber eats accusing fraud making deliveries lie uber give details defend',
#  'hey cant life figure add food delivery driver account point right direction',
#  'hey app never found driver hour charged cancellation fee need human correct ai support',
#  'get answer else',
#  'team xxxx',
#  'got problem guys got unprofessional driver deliver order hand mom bag drop want another drink please help',
#  'already tried web site awful phone number chat available wanted know one using identity get uber whatever',
#  'hello',
#  'girl gone write man driving crazy hell thank god made alive bday',
#  'would like switch cc eats pass accidentally used corp card find help anywhere please help',
#  'go drive lyft support drivers whew uber promising pay drivers quarantined taking platform end quarantine denying claim uber care drivers shieldvoc',
#  'got messed charging entirely different route one actually took whole difference time fucking ppl money',
#  'option',
#  'horrible time cut support staffing perhaps way allow work home drivers need help starving',
#  'someone dm regarding issue ubereats order',
#  'update issue dm hrs since replied heard nothing',
#  'nah type help',
#  'uber scam',
#  'im looking start working asap please get back',
#  'dm option',
#  'thank getting back refund sorry crazy',
#  'waiting documents approved im signing uber eats courier help',
#  'uber promising pay quarantined drivers refusing pay quarantine period please help single mom money',
#  'ordered via uber eats first time tonight placed order total included service charge supposed delivery another receipt email also added another tip shown placed order',
#  'suggest ola give traning cab drivers cab sanitization disinfection',
#  'send dm',
#  'lies declined',
#  'lies',
#  'see told needed submitted uber took platform based documentation submitted end quarantine telling turn enough documentation qualify lawsuit',
#  'hey order messed add tip got email receipt uber still helped sucks driver thinking stiffed tip',
#  'applied driver weeks ago background check taking long time long usually take',
#  'would chevy cavalier meet requirements drive want know buy',
#  'thank much able get everything figured working',
#  'uber removed platform due documentation quarantine denying claim refusing pay help',
#  'thay actually happens tell based gps location like bruh paid',
#  'company sucks seriously guys allow trashy riders get free rides letting driver drive across country get account placed hold cause trashy cheap rider wants tell horrible lie get cash back',
#  'handling current messages sent regards public health matter cut paste responses received getting responses accounts still able log since extreme detriment american',
#  'driver chicago keep sending notifications vehicle registration expiring march governor illinois extended registration till april th due deactivated tomorrow updated',
#  'get dm trying see worth getting car driving time cus appointment st',
#  'worries delay voucher expired anyway',
#  'sure rider account suddenly deactivated anything violate uber regulations please look account asap send customer support morning hours still response thanks',
#  'submitted updated registration several days ago still pending please take care',
#  'stop working work',
#  'got papers already approved since one week still start use app drivers',
#  'dm guys',
#  'talk someone trying set restaurant hold almost hours today day hours still havent talked person',
#  'good job know job starbucks uber city toronto receive clean fee thank nothing',
#  'dear need help searching contact number due major account issues',
#  'denying claims documents required turned fraud uber committing fraud calling state representative calling labor lawyer violation texas payday law',
#  'getting really sick shit quick close drivers accounts selfish asshole riders lie guys fair ass wanting pay food rides want free make easy',
#  'daily reminder support local businesses pick delivery team bring food stop using since help drivers consumers pandemic trust tried',
#  'maryland got stay home order gov uber drivers considered necessary allowed transport ppl stay home period drivers calling definitive answer thanks',
#  'system telling subscribed mobile number system definitely months end received support',
#  'hello trying get signed drive week account halfway ready please finish get driving please thanks',
#  'quarantined emergency room doctor documents turned taking platform unable drive quarantine end quarantine uber tells going pay somehow meet qualifications nobody help use lyft',
#  'help mgmt cannot believe one contacted today nila spoke thurs said willcall tday another notice upld lic txdept ofsafety extended days mgmt pls platinum rating yet uber cant provide quality serv help',
#  'end day still help uber support called times today think uber lying helping drivers much needed financial assistance leadership respond either',
#  'dm email please let know',
#  'nyc driver need vehicle change tlc nyc need forms signed uber closed work filled',
#  'anything turn cxl swear switch biz lyft grub hub get fixed',
#  'avail guys charging subscription know use uber offers one month back credit toward account even subscription said turn cxl',
#  'uber extending driver lic expiration date based letter submitted texas dept public safety license expires day helping solve keeps asking upld assess case individually',
#  'deactivated accident even fault sorry break bad news care certainly care',
#  'really task contact people highly annoying attaching screenshots charged pending amount even bill amount rs app showed rs denied calling police paid',
#  'email account contact support uber eats mexico please',
#  'hello sent message problem answer',
#  'dm assist uber eats driver account',
#  'part shame representative taking stance uber care drivers crisis treats one drivers like shame let everyone know lack caring horrible',
#  'part tell world reality ask become driver chose become driver problem disease figure',
#  'contract phone number',
#  'part said willing tell news independent reporter well statement uber willing help one drivers like care tell news matter',
#  'part furthermore said official statement uber care drivers willing help people infected virus situation simple renewing like care matter fact name',
#  'furthermore said uber create disease obligation help drivers like go find job elsewhere tried explain situation like going cry getting',
#  'drivers still dc md va areas shelter place order implemented thanks',
#  'thank',
#  'part create disease independent contractor explained care huebner calling said care independent contractor',
#  'worry business went elsewhere',
#  'part called exactly one week ago spoke representative named gina said policy policy like deactivated explained suspended said problem',
#  'part support helping drivers especially ones registration coming able purchase trying seek clarity need delayed able renew particular state suspended',
#  'received text message uber verification code morning didnt use uber account',
#  'issue taken care thank response',
#  'got refund last night thank',
#  'totally understand little rant aimed im pretty sure sauces bag drivers throw observation wondering happens use delivery service go',
#  'get dm please',
#  'mean still work collecting unemployment',
#  'need assistance sent documents review waiting asked documentation submitted today give signed legal doc veterans administration emergency room',
#  'sucks account jump jump uber jump account dis money publish contact us phone number',
#  'waiting ready bike please confirm documents',
#  'drivers still accepting rides think adding hazard pay ride least hazard fee drivers putting way deserve drivers also need sanitation supplies',
#  'open business today hrs since dm ed still update response',
#  'dm',
#  'go',
#  'days since provided required document financial assistance claim dire need assistance done rides uber',
#  'thank appears busy',
#  'received charge sunday trip never took bug phishing issue email',
#  'clear active account simply update current insurance',
#  'pls contact',
#  'hey change menu hours even log restaurant manager account try things hold times hours long think someone could help also please stop robo calling system know',
#  'uber offices open dallas fort worth area',
#  'need vehicle inspection form email copy',
#  'hate tell rachel customer service piss poor give shit issue good luck',
#  'get inspection form vehicle',
#  'maybe heard mind business',
#  '',
#  'worst customer service ever manager experience knows manage issues outside instructional manual child could read message please',
#  'get together',
#  'get help uber send help useless frustrated licence registration done current car delete older car',
#  'jumped every hoop verify account said escalated one resolved issue literally thing standing small business staying afloat using services digit pin',
#  'months since signing uber driver background check approved even submit exactly asks please get touch via email approved',
#  'way tax faq section need help someone download please help',
#  'claim nhs uber eats meal code mobile number already registered personal uber account',
#  'course talk directly answer questions happened wait well done',
#  'trying get someone longest time restaurant asking cancel order considering already accepted need refunded',
#  'applied online delivery driver wondering status',
#  'want tip driver guys helping want help someone brought food us needed',
#  'still waiting someone actually help leave tip order older days still cannot',
#  'uber uberpro points reset fix account pay bills driver',
#  'nhs discount ride food also apply working social care risking lives work young people yet recognition',
#  'thanks sharing experience stephen please direct inquiry able assist',
#  'drivers currently infected asymptomatic tested working',
#  'extremely dissapointed impossible get touch anyone speak problem question help section app useless',
#  'need help want use uber disabled months',
#  'always ensure trip ended right sorry experience drivers unbecoming',
#  'uploaded documents days ago still waiting still pending absolutely way contacting either bullshit drove years',
#  'ok sent dm account',
#  'want ask heart activate account make deliveries difficult time others need help promise act utmost responsibility',
#  'uber eats processing taking long two weeks',
#  'hi link nhs email address uber account',
#  'guys alrdy last time refunded without investigating driver despite experience racist please comment shit lol',
#  'urge every uber driver contact ceo describing situation telling going corrupt company needs held accountable actions needs take care drivers keeping business alive',
#  'hi team follows behind support tickets team denies request provide valid reasons violated terms service account hacked user another country covid refused listen users',
#  'need help regards uber eats delivery someone contact please',
#  'snitchin',
#  'fuck drivers partner screaming picked fare young man alpha condition driver ignored',
#  'difficulty day covid support drivers support nitpicking wording doctor note rewrite multiple times',
#  'really gonna snitch someone struggling instead talking moment maybe pet rat helps anxiety enlightened pretty shitty ask',
#  'pinche uber eats seas cabron',
#  'doesnt help everyone',
#  'guys charged trip cancelled driver',
#  'dm hurry pls im broke',
#  'help people family members compromised immune systems want expose someone diagnosed mean need help please better help people keep company working',
#  'hi reward picked applied ride',
#  'site ridiculously hostile want ride drive want eat sign using number already taken',
#  'enforcing curfew maryland going effect tonight ride share services',
#  'intuitive option directly food orders guess include warning post website avoid world wide readers ever using services better get refund',
#  'hi ordered food promo code free delivery still charged shown receipt refund pls',
#  'would use uber debit card also delivering postmates accept lyft uber debits methods need money make next couple days instantly one place thanks advance',
#  'sent support message via app need issue resolved today reason guys middle name instead last name letting update expiration date debit card need receive payments',
#  'discount code working please help',
#  'call center open help issues weekend deliveries currently live tried call live refused available',
#  'spoken customers uber eats drivers picking food restaurants cancelling order keep food need find way crack stealing restaurants consumer',
#  'yes already replied provisional number',
#  'green light location tempe az open vehicle inspections shows active setup process',
#  'thank emailing someone',
#  'update response receive payment last delivery compensated work',
#  'use promise deliver quick time disclaimer work waitr personally promise anything',
#  'hey realize guys probably lot people signing drivers applied week progress getting able drive since way expedite',
#  'promos code date location working uber eats',
#  'hi email saying get march promo code ukmar go use uber eats app told promo longer available email says ok st march pm',
#  'still charging order place due internal app error literally told still place app place order never received food literally stealing people notright',
#  'changed pw still kept happening luckily way sign kept getting alerted one responded finally deleted whole account',
#  'get help technical support trying place order keep getting internal server error message saying order error',
#  'partners name payment come bank account send photos poor response received reply needed telephone customer service want know',
#  'someone take account got message',
#  'two us corporations claim care contractors drivers app users customers last tweeted march last tweeted october may next time flippin ask em wtf',
#  'solution jus apologise charge extra toppings cheese bt deliver nrml items shame isnt scan twice',
#  'funny done continue tobget canned responses sure care social media privately case diabetes staying home option st moment',
#  'ordered restaurant items ordered claim cancel order tea',
#  'need speak live person regarding charge nearly one ride',
#  'im need form form asap',
#  'received promotion tried use got error message please advise validity period expired',
#  'get hold literally got hold idk many times essential please putty part risking life',
#  'going exact thing issue refund',
#  'able visit kandy office colombo area curfew issue clearly make selfie',
#  'wont deliver town live minutes away tim hortons restaurants minutes store',
#  'hey receive countless texts uber codes tried delete account still getting please arrange account totally deleted stop receiving',
#  'received gift card usd uber eats canada way use change cad',
#  'days response account got deactivated trying use gift card smh',
#  'cant use help app stuff cuz account deactivated wtf get help sheesh',
#  'issue due wait understand things currently hectic issue last communication service tried cancel earlier told would charged dollars cancel',
#  'vp krawc cbc ctv cnn uber plz alsoseefeb reply pl see full detailed nov twtr sent core info sent dm dec pm',
#  'wow recent replies yesterday one source got back',
#  'high surged area radious atleast willingly provide trip boundry provide less surged booking fault time get booking belongs surged area withou surge',
#  'im shift manager donatos lexington ky cant log account even website gm sent support request havent heard help beaumont donatos store thanks',
#  'promised update saturday response ok still ok still need rx son',
#  'turned un documents still response promised update days ago',
#  'months actually long pandemic hit already reached via dms emails customer service team nothing short atrocious',
#  'responding',
#  'ive sent email days ago regarding first time account deactived trying use gift card girlfriend sent highly upset im getting support',
#  'trouble logging driver app help',
#  'actually got weekend thank',
#  'cannot click complete trip many bugs update',
#  'hi anyone help',
# ...
#  'lost backpack one uber trips took kindly help',
#  'please help nobody talked yet yesterday went greenlight open supposedly closed help reactivate account please',
#  'uber writing account disable told someone reviewing situation get email message app nothing yesterday went greenlight open closed help',
#  'probably computer real person could resolve',
#  'driver app hours app says hours problem got request expect many current conditions',
#  'changed phone number sign account requires old number verify raised three tickets uber last half month never heard back uber eats account still active still charged',
#  'old phone attached email need reset password keeps saying stop text msgs reset things',
#  'back forth support team getting automated messages back real help back forth days',
#  'understand request reply long time face problem many drivers face problem taiwan',
#  'drivers getting help get live help active delivery getting disconnected',
#  'trying yesterday ordered using uber cash entire order went onto credit card contacted customer service response help please',
#  'code still valid uber eats working',
#  'please stop fraudulent charges already emailed dm answer phone number either',
#  'sent dm keep word resolve issue',
#  'app help offer solution problem telling people dm get automated response supposed get help',
#  'bhai time pe social distancing rakhte hain log tagged hain mein',
#  'hello losing mind level support receiving via app worst experience ever supervisor contact',
#  'driver trying get document updated uploaded several days ago needs done march possibility help',
#  'need help locating pin restaurant partner point contact number call trying get restaurant set partner',
#  'hello sent updated vehicle insurance week ago yet approved date expect approved',
#  'account suspended reason need back runing please source income',
#  'yes money',
#  'heeelllllpppp jjeerrreeemmmmyyyy',
#  'exact situation found way get touch competent support staff actually job give pointer',
#  'someone attend charged uber rides months sometimes bank transactions day reconciling business expenses definitely match rides app share details',
#  'code keeps telling invalid even though today within time frame using tthw code ukmar',
#  'issues took place years ago doubtfully anything could done point',
#  'one answers phone one answers messages anyone job assist drivers',
#  'thanks',
#  'hey thanks setting system verify lost phone uber call',
#  'fuck owe company driver stole food nothing never use',
#  'sent dm regarding error order refunded',
#  'concerns right',
#  'sending information',
#  'yet get help need account still hacked used somebody else freeze bank accounts explained cannot recover password still got normal password reset help need help yesterday',
#  'ok thank',
#  'suck today covid fault order minutes late good lohrt',
#  'settled',
#  'full time drivers qualify unemployment due fact ability work also qualify make nobody wants take account overhead driver',
#  'drivers able secure driving job like career respected deactivated driver account without warning authority abuse heartless actions even worse covid much pressure',
#  'hey cannot go online vehicle listed although uploaded required documents',
#  'sent dm get generic response back',
#  'pleas help trying add chevy limo add limo certificate get chevy approved limo',
#  'info awaiting response thanks',
#  'currently waiting days get document approved get back work help',
#  'someone already helped',
#  'drivers getting minimum points per ride crisis',
#  'thank',
#  'right trying reach since covid lmao',
#  'thank sending information right',
#  'hello would like access history chat delivery person order cbc access',
#  'following application submitted week ago please let know updates may sent dm',
#  'awwhhhh worrie uber use replying messages thanks covid update',
#  'need help adding non limo licensed car account please help help app tell trying weeks',
#  'uk business good uber every promotional code pushing promoting anywhere united kingdom wtf badservice wheresthelove',
#  'anyone please update documents work uploaded yesterday today',
#  'day still waiting response emailed year ago last week able create account today uber ubereats ubersupport uberfail ubereatsfail ubercustomerservice rideshareapp ridesharing fooddelivery',
#  'support nonexistent missing wanting need help way get',
#  'dm sent thank',
#  'none support cites helps try someone go onto sites try get help impossible email addresses useless returned anyone suggestions help',
#  'phone number ogm website charge account recognize contact person help problem',
#  'hey get little assistance please',
#  'covet patent referring weeks financial assistance referring unemployment insurance pls help guidelines file unemployment insurance made available federal government covet relief bill',
#  'dont give damn new customer legit first time using uber ever since gave uber credits cant use account literally one helps changed number times voip used friends numbers mine got today alone',
#  'waiting answer quarantined due symptoms contact rider since passed away since evaluated doctor reached via driver app yet response',
#  'applied uber east driver week ago wondering taking long problem',
#  'call',
#  'please unlock account getting correct resolution back end support team name rahul chitte mobile email',
#  'day account still suspended promised financial assistance starving cannot afford eat days fix leaders',
#  'wondering whether team working weekends',
#  'hmm read coronavirusoutbreak coronaupdate uber making driver drive sick lied whole world',
#  'wow refund spoiled cold food basically told screw',
#  'th march booked cab gaurcity ghaziabad railway station booking fair displayed yesterday seen fair displayed trip actually generally paid card show time please',
#  'sick covid deathly ill telling documents legit medical website ridiculous making jump hoops deathly ill',
#  'sent dm already responded except auto reply contact support already done like times',
#  'say qualify assistance still acct suspended even tho covid neg note work weeks work broke crazy hang',
#  'worst customer service ever busy worrying money first last using bum ass app',
#  'applied week ago deliver hold',
#  'glad hear',
#  'keep getting messages scam suspect scam know supposed arrive randomly',
#  'morning pls worries get ty amex getting charged like crazy even tho orders canceled appreciate guys',
#  'really sad',
#  'tried use ubereats first time unpleasant experience charged twice order',
#  'resolved thanks',
#  'trying sign cycler courier despite uploading documents criminal background check stays grey untouchable keep getting say please upload remaining documents indicate help',
#  'please help account documents pending change moped app let go online th phone number asociate app',
#  'uber account issue trying get elderly father set could bothered providing phone support problem',
#  'already told asking setting account read damn tweet',
#  'guys review insurance please',
#  'access menu tab update hours',
#  'even read question please respond question',
#  'need help cancelling order pls',
#  'drive dropped food wrong place never contacted still charged food',
#  'actually driver aswell',
#  'took days authorize new insurance get back online meanwhile lyft took hour',
#  'crap getting days told give days',
#  'promised via dm update email got nothing need update stop passing buck',
#  'dm sent many thanks team',
#  'tf connecting drivers minutes away',
#  'received discount mail order trying apply discount code appears code longer available whilst deadline today',
#  'maybe receiving higher normal support volume keep sending needless texts random users trusted credit card numbers thought',
#  'rather cancel eats pass subscription seeing delivering whole month march defer payment month',
#  'account temporarily placed hold indianapolis indiana going',
#  'give essential workers discounts rides work',
#  'trying get assistance covid mess worse thing ever done way care people work giving run around',
#  'uploaded document since th march till today updated due unable drive uber please reactivate soon possible',
#  'doubt happened say questions tall exactly much weigh',
#  'ordered meal gift card account got charged total amount card please refund money order',
#  'hi tried change phone number account received message phone number taken please help immediately',
#  'sent',
#  'really nobody available verify driver insurance uploaded',
#  'cannot se reply calls say heck uber',
#  'file unemployment states website',
#  'driver sleeping food watter biscuits help im also driver partner im alsoin verry trubbel',
#  'hey keep getting sent uber code texts ask going',
#  'perhaps could assist query',
#  'good morning uber please help approve insurance document submitted past hrs',
#  'one pls look rego pending approval days work past days mail id phone',
#  'filed week half ago promised days get things sorted submitted necessary paperwork response imagine lot drivers work sick rather notifying uber families starve',
#  'use uber eats website app website go clicking help',
#  'still waiting',
#  'bought new sim mobile find already blocked please help',
#  'issues account logged avon solved issue love promo codes free delivery get back',
#  'please help ordered uber eats driver said food door nothing got charged something get',
#  'great glad hear definitely lot questions figured state state thing',
#  'thank free bike rides',
#  'anyone uber support help cant get contact support',
#  'girl mine',
#  'promotion saying expired april th date happened yet',
#  'dm',
#  'meal order delivered feel ripped follow order ddbd',
#  'well hella alarming',
#  'registered phone number uploaded documents around days ago order uber eats driver vevo check still pending also one thing please tell upload criminal background check',
#  'bank transactions day never took uber basically questioning transactions would need help making sure fraud please advise thanks',
#  'waiting respond month emails menssages app need answer',
#  'reconciling business expense looking period jan feb got bank transaction count trips happy share details transactions passed card help',
#  'please activate uber account blocked low uber rating',
#  'nope closed enquiry email confirmed credits know part business plan lie teeth',
#  'actually care quality food client receiving driver take orders saying',
#  'guys going post anything help people file unemployment mess',
#  'hey waitlisted years pls look account eligible ubereats uberx pls dm',
#  'uber credit amex platinum card added next month credit',
#  'one uber driver partner please help us universal calamities please donate amount uber account stand corona war also daily wages labour pls think us',
#  'way change tip amount uber eats order hour credit card authorization window passed',
#  'nah dismissed mistaking woman reality lol stupid languages',
#  'thanks concern pal fleet partner manage somehow even recession worried millions drivers drivers every organisation trying best save humanity one take care',
#  'hey lied said applied credits account driver tried endanger health want take lift refund money credit never gave never order',
#  'know mate wasnt dig seen uber drivers say around globe mean personal account hope get sorted uber government also responsibility care keep family safe',
#  'done something wanted like trying help least words partners ola like worried get new drivers partners poor families starves death',
#  'hello things finally resolved',
#  'get anywhere classed self employed dont help',
#  'hour greatest need driver fleet partners every company paying employees wanna something people earn commission',
#  'hi harry actively working gather relevant information drivers varies state state touch soon possible likely monday',
#  'better verify credit cards bring submitted app charges fraudulently charged today system guys put flag catch number used zip code match billing zip',
#  'guys resetting something rating went issue',
#  'guys sleep day work night',
#  'save podcast gem lol',
#  'dm sent',
#  'canto register motorcycle',
#  'wait',
#  'payment methods give error saying payment method unavailable every card try',
#  'uber eats allowed order closed restaurant drivers keep pulling clearly get food trying use help support option order never arrived app still marking en route want money back please',
#  'could read tweet answer question',
#  'covid pandemic lot companies taking care people making sure pay dealing public premium rate fact cut driver support weekends refuse respond drivers',
#  'ola uber company takes commission unable give drivers hour trouble',
#  'hell happening order cancelled told still pay hung disconnected charging order back deleting good',
#  'someone know using email account',
#  'hey harsha vardhan know covid outbreaking hard australia tough time go outside without cab please would sincerely request please uber account helpful covid outbreak',
#  'would considered benefits fraud felony',
#  'terrified got scammed',
#  'happen course would nice could actually get touch',
#  'yrs specifically endorsing uber yesterday ordered uber car filthy dirty car showed huge lyft sign interior filthy well rusty dirty rags back seat ewwwwe upholstery also disgustingly filthy',
#  'days ago still heard back',
#  'thank able get things resolved yesterday',
#  'man get response',
#  'going state level fed reimburse states keep process catching',
#  'ordered first time tonight used first order coupon get applied order use since first order halp plz',
#  'need help trying create account keeps saying number already account must last person number help',
#  'shout guy tried scam uber eats posing laughed waaay hard locked payouts closed praise network issues working app',
#  'get response',
#  'corona virus relief legislation indicates uber drivers usa apply unemployment guideline process follow apply benefit',
#  'issue resolved thanks',
#  'uber famous fraud ubersucks',
#  'thats absolutely disgusting',
#  'understood uninstalled reinstalled app get back working',
#  'stop surge pricing pandemic pls icu nurse trying get work help affordably wearethefrontline gougepricing',
#  'electronic funds transfer act efta deal fraud directly card issuer cancel card issue new one pain change new number automatic bill pay',
#  'yes knows already contacted credit union',
#  'called past wait time bit long',
#  'call debit card company card physically lost stolen days report fraudulent transactions zero liability days starts date statement fraudulent transaction appears',
#  'call customer service dispute',
#  'vehicle trunk release back seat making false accusations even lower snitching',
#  'hey someone fraudulently used mother debit card make three large orders uber eats uber account public phone number listed contact get touch',
#  'hi majiira talk hope ur well',
#  'time phone line need talk',
#  'still getting texts better homie get response getting hacked russia',
#  'general everyone safe make sure big bold drivers know new missed',
#  'excited support local restaurant tonight ubereats using ubercash giftcard made sure uber cash ready pay instead whole meal charged credit card need help',
#  'world pandemic going people loosing jobs top discount trip rates charging surge peek hours smh uber better',
#  'wrongfully restricted suspended account apparently violating terms service file ticket tell going lift wrongfully system applied ban say kidding lifting suspension',
#  'sent dm ave got automated response',
#  'round mail chain prof nd answer guys shying away frm acknowledging mistake uber nd accepting shortcoming least cant refund disgusting shameful nd pathetic guys lied least',
#  'still response three weeks documents pending ubereats hand ridiculous something needs done someone needs handle asap',
#  'thanks sent message',
#  'confused want give driver proper tip without accidentally sending meager life savings help hope',
#  'hi pleeeeze help desperately need send message uber delivery deliverers help private help section giving options send message go thanks advance',
#  ...]

# %% [markdown]
# # Filter neutral tweets and empty tweets

# %%
df['text'] = texts
df = df[df.text != ""]
df = df[df.polarity140 != "marl:Neutral"]
df
# Out:
#        cashtags    created_at                 date  day  geo hashtags  hour  \
# 7            []  1.585697e+12  2020-03-31 23:28:49  2.0  NaN       []  23.0
# 8            []  1.585697e+12  2020-03-31 23:28:13  2.0  NaN       []  23.0
# 10           []  1.585697e+12  2020-03-31 23:21:43  2.0  NaN       []  23.0
# 11           []  1.585697e+12  2020-03-31 23:21:19  2.0  NaN       []  23.0
# 14           []  1.585696e+12  2020-03-31 23:11:02  2.0  NaN       []  23.0
# ...         ...           ...                  ...  ...  ...      ...   ...
# 215376       []  1.596241e+12  2020-08-01 00:17:31  6.0  NaN       []   0.0
# 215377       []  1.596241e+12  2020-08-01 00:13:43  6.0  NaN       []   0.0
# 215378       []  1.596241e+12  2020-08-01 00:09:15  6.0  NaN       []   0.0
# 215380       []  1.596240e+12  2020-08-01 00:07:31  6.0  NaN       []   0.0
# 215384       []  1.596240e+12  2020-08-01 00:04:39  6.0  NaN       []   0.0
#
#                   id language  \
# 7       1.245131e+18       en
# 8       1.245131e+18       en
# 10      1.245129e+18       en
# 11      1.245129e+18       en
# 14      1.245126e+18       en
# ...              ...      ...
# 215376  1.289355e+18       en
# 215377  1.289354e+18       en
# 215378  1.289352e+18       en
# 215380  1.289352e+18       en
# 215384  1.289351e+18       en
#
#                                                      link  ...  \
# 7       https://twitter.com/JohnKir74833568/status/124...  ...
# 8       https://twitter.com/OneTruGreenberg/status/124...  ...
# 10      https://twitter.com/1Chronicler/status/1245129...  ...
# 11      https://twitter.com/andrew_the_pom/status/1245...  ...
# 14      https://twitter.com/cherylj22/status/124512648...  ...
# ...                                                   ...  ...
# 215376  https://twitter.com/gailifshin/status/12893545...  ...
# 215377  https://twitter.com/DeJai24/status/12893535804...  ...
# 215378  https://twitter.com/KitOConnell/status/1289352...  ...
# 215380  https://twitter.com/kittenpocalypse/status/128...  ...
# 215384  https://twitter.com/ninjitalia/status/12893513...  ...
#
#                                                     tweet  \
# 7       @Uber_Support No way. I’m not worried about my...
# 8       @Uber_Support I'm trying to file for my Califo...
# 10      @Uber_Support Why is there no contact info? Ho...
# 11      @Uber_Support Read my original tweet and answe...
# 14      @Uber_Support hello ordered 70$ worth of east ...
# ...                                                   ...
# 215376  wow @ubereats...you see $900+ of charges in on...
# 215377  @UberEats @Uber_Support I will literally pay e...
# 215378  @Uber @lyft @chadloder @Uber_Support Update: L...
# 215380  @Real_CGThomas @Uber @Uber_Support @dkhos @che...
# 215384  @Uber_Support @Tesla 2 trips in a row now as I...
#
#                                                      urls       user_id  \
# 7                                                      []  1.244829e+18
# 8                                                      []  1.007368e+08
# 10                                                     []  4.138178e+07
# 11                                                     []  5.892575e+08
# 14                                                     []  3.302313e+07
# ...                                                   ...           ...
# 215376                                                 []  9.467706e+07
# 215377                                                 []  1.041376e+18
# 215378  ['https://twitter.com/alcaprari23/status/12893...  2.094630e+07
# 215380                                                 []  4.141801e+09
# 215384                                                 []  1.800323e+08
#
#          user_id_str  user_rt user_rt_id         username video  \
# 7       1.244829e+18      NaN        NaN  JohnKir74833568   0.0
# 8       1.007368e+08      NaN        NaN  OneTruGreenberg   0.0
# 10      4.138178e+07      NaN        NaN      1Chronicler   0.0
# 11      5.892575e+08      NaN        NaN   andrew_the_pom   0.0
# 14      3.302313e+07      NaN        NaN        cherylj22   0.0
# ...              ...      ...        ...              ...   ...
# 215376  9.467706e+07      NaN        NaN       gailifshin   0.0
# 215377  1.041376e+18      NaN        NaN          DeJai24   0.0
# 215378  2.094630e+07      NaN        NaN      KitOConnell   0.0
# 215380  4.141801e+09      NaN        NaN  kittenpocalypse   0.0
# 215384  1.800323e+08      NaN        NaN       ninjitalia   0.0
#
#           polarity140                                               text
# 7       marl:Negative  way worried privacy dm said please continue wo...
# 8       marl:Negative  trying file california state unemployment insu...
# 10      marl:Negative  contact info avoid charges driver says busines...
# 11      marl:Positive  read original tweet answer question nothing ac...
# 14      marl:Negative  hello ordered worth east sides came cold chick...
# ...               ...                                                ...
# 215376  marl:Negative  wow see charges one day make difficult get sor...
# 215377  marl:Negative  literally pay extra food grouped another order...
# 215378  marl:Positive             update lyft says would still good hear
# 215380  marl:Negative  bruh doordash driver fine update lisecse turni...
# 215384  marl:Negative  trips row gone slide end trip button another t...
#
# [111184 rows x 37 columns]

# %%
#convention_df = st.SampleCorpora.ConventionData2012.get_data() 
df.iloc[0]
# Out:
# cashtags                                                       []
# created_at                                        1585697329000.0
# date                                          2020-03-31 23:28:49
# day                                                           2.0
# geo                                                           NaN
# hashtags                                                       []
# hour                                                         23.0
# id                                          1245130962113003520.0
# language                                                       en
# link            https://twitter.com/JohnKir74833568/status/124...
# name                                                 JohnKirkland
# near                                                          NaN
# nlikes                                                        2.0
# nreplies                                                      1.0
# nretweets                                                     0.0
# photos                                                         []
# quote_url                                                     NaN
# reply_to        [{'screen_name': 'Uber_Support', 'name': 'Uber...
# retweet_date                                                  NaN
# retweet_id                                                    NaN
# search                                              @Uber_Support
# source                                                        NaN
# thumbnail                                                     NaN
# timezone                                                      0.0
# trans_dest                                                    NaN
# trans_src                                                     NaN
# translate                                                     NaN
# tweet           @Uber_Support No way. I’m not worried about my...
# urls                                                           []
# user_id                                     1244828914847027200.0
# user_id_str                                 1244828914847027200.0
# user_rt                                                       NaN
# user_rt_id                                                    NaN
# username                                          JohnKir74833568
# video                                                         0.0
# polarity140                                         marl:Negative
# text            way worried privacy dm said please continue wo...
# Name: 7, dtype: object

# %% [markdown]
# # Scattertext process

# %%
nlp = spacy.load("en_core_web_sm")
corpus = st.CorpusFromPandas(df, 
                              category_col='polarity140', 
                              text_col='text',
                              nlp=nlp).build()

# %%
html = st.produce_scattertext_explorer(corpus,
          category='marl:Positive',
          category_name='Positive',
          not_category_name='Negative',
          width_in_pixels=1000,
          metadata=df['username']
        )
open("Sentiment2.html", 'wb').write(html.encode('utf-8'))
# Out:
# 15848516
